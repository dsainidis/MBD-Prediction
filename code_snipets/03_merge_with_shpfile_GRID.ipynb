# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import sys

sys.path.insert(0, r"E:\Drive\NOA\MBD-Prediction\Modules")

from utils import describe_dataframe, process_greek

enc = 'utf-8'

pd.set_option('display.max_columns', None)

# %%
base_folder = 'E:/Drive/NOA/MBD-Prediction/Grid Level/data'

# %%
region_dict = {'Attica': 'EL30',
               'Central Macedonia': 'EL52',
               'Thessaly': 'EL61',
               'Thrace': 'EL51'}

# %%
NUTS2 = 'Thrace'
NUTS2_ID = region_dict.get(NUTS2)
YEAR = 2025

# %%
print(f'NUTS2: {NUTS2} \nNUTS2_ID: {NUTS2_ID} \nYEAR: {YEAR}')
# Out:
# NUTS2: Thrace,
# NUTS2_ID: EL51,
# YEAR: 2025

# %%
data = pd.read_csv(f'{base_folder}/{NUTS2}/GR_{NUTS2}_Timeline_GRID_{YEAR}_filled_mean_rain.csv', encoding=enc)
greece_nuts3 = gpd.read_file(r"E:\Drive\NOA\MBD-Prediction\Europe Shapefiles\Greece\data\EL_Whole.shp",  encoding=enc)
greece_lau1 = gpd.read_file(r"E:\Drive\NOA\MBD-Prediction\Shapefiles\Greece Shapefiles\el_lau1.shp",  encoding=enc)

# %%
try:
    data.drop(columns=['Unnamed: 0'], inplace=True)
except Exception:
    print("No column named \'Unnamed: 0\'")

# %%
try:
    data.drop(columns=['rainfall.1'], inplace=True)
except Exception:
    print("No column named \'rainfall.1\'")
# Out:
# No column named 'rainfall.1'

# %%
data
# Out:
#                x         y  cell_number dt_placement NUTS2_ID  year  month  \
# 0       23.65882  41.33542            0   2025-01-01     EL51  2025      1
# 1       23.65882  41.33542            0   2025-01-02     EL51  2025      1
# 2       23.65882  41.33542            0   2025-01-03     EL51  2025      1
# 3       23.65882  41.33542            0   2025-01-04     EL51  2025      1
# 4       23.65882  41.33542            0   2025-01-05     EL51  2025      1
# ...          ...       ...          ...          ...      ...   ...    ...
# 695653  26.60756  41.40729         3265   2025-07-28     EL51  2025      7
# 695654  26.60756  41.40729         3265   2025-07-29     EL51  2025      7
# 695655  26.60756  41.40729         3265   2025-07-30     EL51  2025      7
# 695656  26.60756  41.40729         3265   2025-07-31     EL51  2025      7
# 695657  26.60756  41.40729         3265   2025-08-01     EL51  2025      8
#
#             ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  \
# 0            NaN       NaN       NaN       NaN        NaN        NaN
# 1       0.078916  0.146433  0.098425 -0.146433   0.183488   0.070950
# 2       0.078916  0.146433  0.098425 -0.146433   0.183488   0.070950
# 3       0.078916  0.146433  0.098425 -0.146433   0.183488   0.070950
# 4       0.078916  0.146433  0.098425 -0.146433   0.183488   0.070950
# ...          ...       ...       ...       ...        ...        ...
# 695653  0.204166 -0.061573 -0.329764  0.061573   0.285078   0.009914
# 695654  0.204166 -0.061573 -0.329764  0.061573   0.285078   0.009914
# 695655  0.199012 -0.066923 -0.335658  0.066923   0.290737   0.006155
# 695656  0.199012 -0.066923 -0.335658  0.066923   0.290737   0.006155
# 695657       NaN       NaN       NaN       NaN        NaN        NaN
#
#         ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  \
# 0             NaN        NaN       NaN       NaN       NaN       NaN  13893.0
# 1       -0.082637  -0.070950  0.087655  0.112251  0.138840  0.112251  13803.0
# 2       -0.082637  -0.070950  0.087655  0.112251  0.138840  0.112251  13803.0
# 3       -0.082637  -0.070950  0.087655  0.112251  0.138840  0.112251  13803.0
# 4       -0.082637  -0.070950  0.087655  0.112251  0.138840  0.112251  13803.0
# ...           ...        ...       ...       ...       ...       ...      ...
# 695653  -0.357723  -0.009914  0.052429  0.049809  0.021683  0.049809  15502.0
# 695654  -0.357723  -0.009914  0.052429  0.049809  0.021683  0.049809  15422.0
# 695655  -0.368628  -0.006155  0.060766  0.052472  0.025781  0.052472  15453.0
# 695656  -0.368628  -0.006155  0.060766  0.052472  0.025781  0.052472  15453.0
# 695657        NaN        NaN       NaN       NaN       NaN       NaN      NaN
#
#         lst_night  rainfall  day  lst_day_jan_mean  lst_night_jan_mean  \
# 0         13684.0      0.00    1      13864.935484        13732.064516
# 1         13667.0      0.00    2      13864.935484        13732.064516
# 2         13667.0      6.45    3      13864.935484        13732.064516
# 3         13546.0      4.76    4      13864.935484        13732.064516
# 4         13649.0      2.02    5      13864.935484        13732.064516
# ...           ...       ...  ...               ...                 ...
# 695653    14934.0      0.00   28      14100.551724        13825.290323
# 695654    14942.0      0.00   29      14100.551724        13825.290323
# 695655    14865.0      0.00   30      14100.551724        13825.290323
# 695656    14865.0      0.00   31      14100.551724        13825.290323
# 695657        NaN      0.00    1      14100.551724        13825.290323
#
#         lst_day_feb_mean  lst_night_feb_mean  lst_day_mar_mean  \
# 0           13718.714286        13448.535714      14232.535714
# 1           13718.714286        13448.535714      14232.535714
# 2           13718.714286        13448.535714      14232.535714
# 3           13718.714286        13448.535714      14232.535714
# 4           13718.714286        13448.535714      14232.535714
# ...                  ...                 ...               ...
# 695653      13973.440000        13530.678571      14492.000000
# 695654      13973.440000        13530.678571      14492.000000
# 695655      13973.440000        13530.678571      14492.000000
# 695656      13973.440000        13530.678571      14492.000000
# 695657      13973.440000        13530.678571      14492.000000
#
#         lst_night_mar_mean  lst_day_apr_mean  lst_night_apr_mean  \
# 0             13851.206897      14335.652174         13977.26087
# 1             13851.206897      14335.652174         13977.26087
# 2             13851.206897      14335.652174         13977.26087
# 3             13851.206897      14335.652174         13977.26087
# 4             13851.206897      14335.652174         13977.26087
# ...                    ...               ...                 ...
# 695653        13844.551724      14692.666667         14029.26087
# 695654        13844.551724      14692.666667         14029.26087
# 695655        13844.551724      14692.666667         14029.26087
# 695656        13844.551724      14692.666667         14029.26087
# 695657        13844.551724      14692.666667         14029.26087
#
#         acc_rainfall_1week  acc_rainfall_2week  acc_rainfall_month  \
# 0                     0.00            0.000000            0.000000
# 1                     0.00            0.000000            0.000000
# 2                     6.45            6.450000            6.450000
# 3                    11.21           11.210000           11.210000
# 4                    13.23           13.230000           13.230000
# ...                    ...                 ...                 ...
# 695653                0.00            4.984314            5.040588
# 695654                0.00            4.984314            5.040588
# 695655                0.00            4.984314            4.984314
# 695656                0.00            4.984314            4.984314
# 695657                0.00            0.160784            4.984314
#
#         acc_rainfall_jan
# 0               0.000000
# 1               0.000000
# 2               6.450000
# 3              11.210000
# 4              13.230000
# ...                  ...
# 695653        197.451171
# 695654        197.451171
# 695655        197.451171
# 695656        197.451171
# 695657        197.451171
#
# [695658 rows x 35 columns]

# %%
greece_grid = gpd.GeoDataFrame(data, geometry=gpd.points_from_xy(data.x, data.y), crs='EPSG:4326')

greece_grid.head()
# Out:
#           x         y  cell_number dt_placement NUTS2_ID  year  month  \
# 0  23.65882  41.33542            0   2025-01-01     EL51  2025      1
# 1  23.65882  41.33542            0   2025-01-02     EL51  2025      1
# 2  23.65882  41.33542            0   2025-01-03     EL51  2025      1
# 3  23.65882  41.33542            0   2025-01-04     EL51  2025      1
# 4  23.65882  41.33542            0   2025-01-05     EL51  2025      1
#
#        ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  \
# 0       NaN       NaN       NaN       NaN        NaN        NaN        NaN
# 1  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095  -0.082637
# 2  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095  -0.082637
# 3  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095  -0.082637
# 4  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095  -0.082637
#
#    ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  lst_night  \
# 0        NaN       NaN       NaN       NaN       NaN  13893.0    13684.0
# 1   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0    13667.0
# 2   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0    13667.0
# 3   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0    13546.0
# 4   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0    13649.0
#
#    rainfall  day  lst_day_jan_mean  lst_night_jan_mean  lst_day_feb_mean  \
# 0      0.00    1      13864.935484        13732.064516      13718.714286
# 1      0.00    2      13864.935484        13732.064516      13718.714286
# 2      6.45    3      13864.935484        13732.064516      13718.714286
# 3      4.76    4      13864.935484        13732.064516      13718.714286
# 4      2.02    5      13864.935484        13732.064516      13718.714286
#
#    lst_night_feb_mean  lst_day_mar_mean  lst_night_mar_mean  lst_day_apr_mean  \
# 0        13448.535714      14232.535714        13851.206897      14335.652174
# 1        13448.535714      14232.535714        13851.206897      14335.652174
# 2        13448.535714      14232.535714        13851.206897      14335.652174
# 3        13448.535714      14232.535714        13851.206897      14335.652174
# 4        13448.535714      14232.535714        13851.206897      14335.652174
#
#    lst_night_apr_mean  acc_rainfall_1week  acc_rainfall_2week  \
# 0         13977.26087                0.00                0.00
# 1         13977.26087                0.00                0.00
# 2         13977.26087                6.45                6.45
# 3         13977.26087               11.21               11.21
# 4         13977.26087               13.23               13.23
#
#    acc_rainfall_month  acc_rainfall_jan                   geometry
# 0                0.00              0.00  POINT (23.65882 41.33542)
# 1                0.00              0.00  POINT (23.65882 41.33542)
# 2                6.45              6.45  POINT (23.65882 41.33542)
# 3               11.21             11.21  POINT (23.65882 41.33542)
# 4               13.23             13.23  POINT (23.65882 41.33542)

# %%
greece_nuts3 = greece_nuts3.to_crs(epsg=4326)
greece_lau1 = greece_lau1.to_crs(epsg=4326)
greece_grid = greece_grid.to_crs(epsg=4326)

# %%
greece_lau1.drop(columns=['KWD_YPES'], inplace = True)
greece_lau1.drop(greece_lau1[greece_lau1['NAME'] == 'Άθως'].index, inplace = True)
greece_lau1.rename(columns={"NAME": "LAU1_NAME", "geometry": "lau1_geom"}, inplace = True)
greece_lau1.set_geometry("lau1_geom", inplace = True)
greece_lau1['lau1_centroid'] = greece_lau1['lau1_geom'].centroid
greece_lau1['lau1_rpoint'] = greece_lau1['lau1_geom'].representative_point()
greece_lau1.reset_index(drop=True, inplace=True)

greece_nuts3.rename(columns={"geometry": "nuts3_geom"}, inplace = True)
greece_nuts3.set_geometry("nuts3_geom", inplace = True)
# Out:
# C:\Users\dimit\AppData\Local\Temp\ipykernel_7580\2894926608.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   greece_lau1['lau1_centroid'] = greece_lau1['lau1_geom'].centroid

# %%
print(f'greece_nuts3 CRS: {greece_nuts3.crs}')
print(f'greece_lau1 CRS: {greece_lau1.crs}')
print(f'greece_grid CRS: {greece_grid.crs}')
# Out:
# greece_nuts3 CRS: EPSG:4326
# greece_lau1 CRS: EPSG:4326
# greece_grid CRS: EPSG:4326

# %%
greece_lau1.set_geometry("lau1_rpoint", inplace = True)
greece_nuts3 = greece_nuts3.to_crs(epsg=4326)
greece_lau1 = greece_lau1.to_crs(epsg=4326)

greece_gdf = greece_lau1.sjoin(greece_nuts3, predicate="within", how = "left")
greece_gdf.head()
# Out:
#            LAU1_NAME                                          lau1_geom  \
# 0          Αμυνταίου  POLYGON ((21.70746 40.85172, 21.70955 40.85119...
# 1  Άκτιου - Βόνιτσας  MULTIPOLYGON (((20.79456 38.75371, 20.79456 38...
# 2             Άνδρου  MULTIPOLYGON (((24.95917 37.69039, 24.95897 37...
# 3   Άργους - Μυκηνών  POLYGON ((22.52084 37.83857, 22.52111 37.83829...
# 4            Έδεσσας  POLYGON ((21.99535 40.90380, 21.99562 40.90344...
#
#                lau1_centroid                lau1_rpoint  index_right  \
# 0  POINT (21.63479 40.67528)  POINT (21.67171 40.68676)           30
# 1  POINT (20.95158 38.82289)  POINT (20.93655 38.81891)           41
# 2  POINT (24.84814 37.85801)  POINT (24.86216 37.84094)           11
# 3  POINT (22.62532 37.66339)  POINT (22.62833 37.65584)           49
# 4  POINT (21.92931 40.79799)  POINT (21.93215 40.79303)           24
#
#   CNTR_CODE CNTR_NAME NUTS1_ID            NUTS1_LATN            NUTS1_NAME  \
# 0        EL    Greece      EL5         Voreia Elláda         Βόρεια Ελλάδα
# 1        EL    Greece      EL6       Kentriki Elláda       Κεντρική Ελλάδα
# 2        EL    Greece      EL4  Nisia Aigaiou, Kriti  Νησιά Αιγαίου, Κρήτη
# 3        EL    Greece      EL6       Kentriki Elláda       Κεντρική Ελλάδα
# 4        EL    Greece      EL5         Voreia Elláda         Βόρεια Ελλάδα
#
#   NUTS2_ID          NUTS2_LATN          NUTS2_NAME NUTS3_ID  \
# 0     EL53    Dytiki Makedonia    Δυτική Μακεδονία    EL533
# 1     EL63       Dytiki Elláda       Δυτική Ελλάδα    EL631
# 2     EL42        Notio Aigaio        Νότιο Αιγαίο    EL422
# 3     EL65        Peloponnisos        Πελοπόννησος    EL651
# 4     EL52  Kentriki Makedonia  Κεντρική Μακεδονία    EL524
#
#                                           NUTS3_LATN  \
# 0                                            Florina
# 1                                    Aitoloakarnania
# 2  Andros, Thira, Kea, Milos, Mykonos, Naxos, Par...
# 3                                  Argolida, Arkadia
# 4                                              Pella
#
#                                           NUTS3_NAME  MOUNT_TYPE  URBN_TYPE  \
# 0                                            Φλώρινα         3.0          3
# 1                                    Αιτωλοακαρνανία         2.0          3
# 2  Άνδρος, Θήρα, Κέα, Μήλος, Μύκονος, Νάξος, Πάρο...         2.0          3
# 3                                  Αργολίδα, Αρκαδία         3.0          3
# 4                                              Πέλλα         2.0          3
#
#    COAST_TYPE
# 0           3
# 1           1
# 2           1
# 3           1
# 4           2

# %%
greece_gdf.drop(columns = ['lau1_centroid',	'lau1_rpoint', 'index_right', 'CNTR_CODE', 'CNTR_NAME', 'NUTS1_LATN', 'NUTS2_LATN', 'NUTS3_LATN'], inplace = True)

# %%
greece_gdf.set_geometry('lau1_geom', inplace = True)
greece_grid.set_geometry('geometry', inplace = True)

# %%
greece_gdf = greece_gdf.to_crs(epsg=4326)
greece_grid = greece_grid.to_crs(epsg=4326)

# %%
greece_gdf_sub = greece_gdf[greece_gdf['NUTS2_ID'] == NUTS2_ID].copy()
greece_gdf_sub.reset_index(drop=True, inplace=True)

# %%
greece_grid.head()
# Out:
#           x         y  cell_number dt_placement NUTS2_ID  year  month  \
# 0  23.65882  41.33542            0   2025-01-01     EL51  2025      1
# 1  23.65882  41.33542            0   2025-01-02     EL51  2025      1
# 2  23.65882  41.33542            0   2025-01-03     EL51  2025      1
# 3  23.65882  41.33542            0   2025-01-04     EL51  2025      1
# 4  23.65882  41.33542            0   2025-01-05     EL51  2025      1
#
#        ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  \
# 0       NaN       NaN       NaN       NaN        NaN        NaN        NaN
# 1  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095  -0.082637
# 2  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095  -0.082637
# 3  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095  -0.082637
# 4  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095  -0.082637
#
#    ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  lst_night  \
# 0        NaN       NaN       NaN       NaN       NaN  13893.0    13684.0
# 1   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0    13667.0
# 2   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0    13667.0
# 3   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0    13546.0
# 4   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0    13649.0
#
#    rainfall  day  lst_day_jan_mean  lst_night_jan_mean  lst_day_feb_mean  \
# 0      0.00    1      13864.935484        13732.064516      13718.714286
# 1      0.00    2      13864.935484        13732.064516      13718.714286
# 2      6.45    3      13864.935484        13732.064516      13718.714286
# 3      4.76    4      13864.935484        13732.064516      13718.714286
# 4      2.02    5      13864.935484        13732.064516      13718.714286
#
#    lst_night_feb_mean  lst_day_mar_mean  lst_night_mar_mean  lst_day_apr_mean  \
# 0        13448.535714      14232.535714        13851.206897      14335.652174
# 1        13448.535714      14232.535714        13851.206897      14335.652174
# 2        13448.535714      14232.535714        13851.206897      14335.652174
# 3        13448.535714      14232.535714        13851.206897      14335.652174
# 4        13448.535714      14232.535714        13851.206897      14335.652174
#
#    lst_night_apr_mean  acc_rainfall_1week  acc_rainfall_2week  \
# 0         13977.26087                0.00                0.00
# 1         13977.26087                0.00                0.00
# 2         13977.26087                6.45                6.45
# 3         13977.26087               11.21               11.21
# 4         13977.26087               13.23               13.23
#
#    acc_rainfall_month  acc_rainfall_jan                   geometry
# 0                0.00              0.00  POINT (23.65882 41.33542)
# 1                0.00              0.00  POINT (23.65882 41.33542)
# 2                6.45              6.45  POINT (23.65882 41.33542)
# 3               11.21             11.21  POINT (23.65882 41.33542)
# 4               13.23             13.23  POINT (23.65882 41.33542)

# %%
greece_gdf_sub.head()
# Out:
#          LAU1_NAME                                          lau1_geom  \
# 0          Αβδήρων  MULTIPOLYGON (((25.11115 41.00509, 25.11129 41...
# 1  Αλεξανδρούπολης  MULTIPOLYGON (((26.02534 40.77036, 26.02556 40...
# 2         Αρριανών  POLYGON ((25.84128 41.33854, 25.84157 41.33852...
# 3     Διδυμοτείχου  POLYGON ((26.33233 41.51492, 26.33276 41.51469...
# 4          Δοξάτου  POLYGON ((24.33347 41.14739, 24.33534 41.14657...
#
#   NUTS1_ID     NUTS1_NAME NUTS2_ID                  NUTS2_NAME NUTS3_ID  \
# 0      EL5  Βόρεια Ελλάδα     EL51  Aνατολική Μακεδονία, Θράκη    EL512
# 1      EL5  Βόρεια Ελλάδα     EL51  Aνατολική Μακεδονία, Θράκη    EL511
# 2      EL5  Βόρεια Ελλάδα     EL51  Aνατολική Μακεδονία, Θράκη    EL513
# 3      EL5  Βόρεια Ελλάδα     EL51  Aνατολική Μακεδονία, Θράκη    EL511
# 4      EL5  Βόρεια Ελλάδα     EL51  Aνατολική Μακεδονία, Θράκη    EL514
#
#   NUTS3_NAME  MOUNT_TYPE  URBN_TYPE  COAST_TYPE
# 0      Ξάνθη         2.0          2           1
# 1      Έβρος         4.0          2           1
# 2     Ροδόπη         2.0          3           1
# 3      Έβρος         4.0          2           1
# 4      Δράμα         2.0          2           2

# %%
cm_grid = greece_grid.sjoin_nearest(greece_gdf, how='left', max_distance=0.01, distance_col='dist')
# Out:
# c:\Users\dimit\Python Virtual Environments\noa_eywa\Lib\site-packages\geopandas\array.py:365: UserWarning: Geometry is in a geographic CRS. Results from 'sjoin_nearest' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   warnings.warn(

# %%
cm_grid.head()
# Out:
#           x         y  cell_number dt_placement NUTS2_ID_left  year  month  \
# 0  23.65882  41.33542            0   2025-01-01          EL51  2025      1
# 1  23.65882  41.33542            0   2025-01-02          EL51  2025      1
# 2  23.65882  41.33542            0   2025-01-03          EL51  2025      1
# 3  23.65882  41.33542            0   2025-01-04          EL51  2025      1
# 4  23.65882  41.33542            0   2025-01-05          EL51  2025      1
#
#        ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  \
# 0       NaN       NaN       NaN       NaN        NaN        NaN        NaN
# 1  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095  -0.082637
# 2  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095  -0.082637
# 3  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095  -0.082637
# 4  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095  -0.082637
#
#    ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  lst_night  \
# 0        NaN       NaN       NaN       NaN       NaN  13893.0    13684.0
# 1   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0    13667.0
# 2   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0    13667.0
# 3   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0    13546.0
# 4   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0    13649.0
#
#    rainfall  day  lst_day_jan_mean  lst_night_jan_mean  lst_day_feb_mean  \
# 0      0.00    1      13864.935484        13732.064516      13718.714286
# 1      0.00    2      13864.935484        13732.064516      13718.714286
# 2      6.45    3      13864.935484        13732.064516      13718.714286
# 3      4.76    4      13864.935484        13732.064516      13718.714286
# 4      2.02    5      13864.935484        13732.064516      13718.714286
#
#    lst_night_feb_mean  lst_day_mar_mean  lst_night_mar_mean  lst_day_apr_mean  \
# 0        13448.535714      14232.535714        13851.206897      14335.652174
# 1        13448.535714      14232.535714        13851.206897      14335.652174
# 2        13448.535714      14232.535714        13851.206897      14335.652174
# 3        13448.535714      14232.535714        13851.206897      14335.652174
# 4        13448.535714      14232.535714        13851.206897      14335.652174
#
#    lst_night_apr_mean  acc_rainfall_1week  acc_rainfall_2week  \
# 0         13977.26087                0.00                0.00
# 1         13977.26087                0.00                0.00
# 2         13977.26087                6.45                6.45
# 3         13977.26087               11.21               11.21
# 4         13977.26087               13.23               13.23
#
#    acc_rainfall_month  acc_rainfall_jan                   geometry  \
# 0                0.00              0.00  POINT (23.65882 41.33542)
# 1                0.00              0.00  POINT (23.65882 41.33542)
# 2                6.45              6.45  POINT (23.65882 41.33542)
# 3               11.21             11.21  POINT (23.65882 41.33542)
# 4               13.23             13.23  POINT (23.65882 41.33542)
#
#    index_right         LAU1_NAME NUTS1_ID     NUTS1_NAME NUTS2_ID_right  \
# 0          129  Κάτω Νευροκοπίου      EL5  Βόρεια Ελλάδα           EL51
# 1          129  Κάτω Νευροκοπίου      EL5  Βόρεια Ελλάδα           EL51
# 2          129  Κάτω Νευροκοπίου      EL5  Βόρεια Ελλάδα           EL51
# 3          129  Κάτω Νευροκοπίου      EL5  Βόρεια Ελλάδα           EL51
# 4          129  Κάτω Νευροκοπίου      EL5  Βόρεια Ελλάδα           EL51
#
#                    NUTS2_NAME NUTS3_ID NUTS3_NAME  MOUNT_TYPE  URBN_TYPE  \
# 0  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα         2.0          2
# 1  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα         2.0          2
# 2  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα         2.0          2
# 3  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα         2.0          2
# 4  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα         2.0          2
#
#    COAST_TYPE  dist
# 0           2   0.0
# 1           2   0.0
# 2           2   0.0
# 3           2   0.0
# 4           2   0.0

# %%
describe_dataframe(cm_grid, remove_zeros=True)
# Out:
#                 Column  Missing
# 7                 ndvi  33.4775
# 8                 ndmi  33.4775
# 9                 ndwi  33.4775
# 10                ndbi  33.4775
# 11           ndvi_mean  29.4172
# 12           ndmi_mean  29.4172
# 13           ndwi_mean  29.4172
# 14           ndbi_mean  29.4172
# 15            ndvi_std  29.4172
# 16            ndmi_std  29.4172
# 17            ndwi_std  29.4172
# 18            ndbi_std  29.4172
# 19             lst_day  23.8127
# 20           lst_night  24.1213
# 21            rainfall  12.2066
# 23    lst_day_jan_mean   3.9192
# 24  lst_night_jan_mean   3.9498
# 25    lst_day_feb_mean   3.9192
# 26  lst_night_feb_mean   3.9498
# 27    lst_day_mar_mean   3.9192
# 28  lst_night_mar_mean   3.9192
# 29    lst_day_apr_mean   3.9192
# 30  lst_night_apr_mean   3.9192

# %%
cm_grid.columns
# Out:
# Index(['x', 'y', 'cell_number', 'dt_placement', 'NUTS2_ID_left', 'year',
#        'month', 'ndvi', 'ndmi', 'ndwi', 'ndbi', 'ndvi_mean', 'ndmi_mean',
#        'ndwi_mean', 'ndbi_mean', 'ndvi_std', 'ndmi_std', 'ndwi_std',
#        'ndbi_std', 'lst_day', 'lst_night', 'rainfall', 'day',
#        'lst_day_jan_mean', 'lst_night_jan_mean', 'lst_day_feb_mean',
#        'lst_night_feb_mean', 'lst_day_mar_mean', 'lst_night_mar_mean',
#        'lst_day_apr_mean', 'lst_night_apr_mean', 'acc_rainfall_1week',
#        'acc_rainfall_2week', 'acc_rainfall_month', 'acc_rainfall_jan',
#        'geometry', 'index_right', 'LAU1_NAME', 'NUTS1_ID', 'NUTS1_NAME',
#        'NUTS2_ID_right', 'NUTS2_NAME', 'NUTS3_ID', 'NUTS3_NAME', 'MOUNT_TYPE',
#        'URBN_TYPE', 'COAST_TYPE', 'dist'],
#       dtype='object')

# %%
cm_grid.rename(columns={'NUTS2_ID_left': 'NUTS2_ID'}, inplace=True)

# %%
new_order = ['x', 'y', 'cell_number', 'dt_placement','NUTS1_ID', 'NUTS1_NAME', 'NUTS2_ID', 'NUTS2_NAME', 'NUTS3_ID', 'NUTS3_NAME', 'LAU1_NAME', 'year', 'month',
             'ndvi', 'ndmi', 'ndwi', 'ndbi', 'ndvi_mean', 'ndmi_mean',
             'ndwi_mean', 'ndbi_mean', 'ndvi_std', 'ndmi_std', 'ndwi_std',
             'ndbi_std', 'lst_day', 'lst_night', 'rainfall', 'day',
             'lst_day_jan_mean', 'lst_night_jan_mean', 'lst_day_feb_mean',
             'lst_night_feb_mean', 'lst_day_mar_mean', 'lst_night_mar_mean',
             'lst_day_apr_mean', 'lst_night_apr_mean', 'acc_rainfall_1week',
             'acc_rainfall_2week', 'acc_rainfall_month', 'acc_rainfall_jan',
             'MOUNT_TYPE','URBN_TYPE', 'COAST_TYPE']

# %%
cm_grid = cm_grid[new_order]

# %%
cm_grid.head()
# Out:
#           x         y  cell_number dt_placement NUTS1_ID     NUTS1_NAME  \
# 0  23.65882  41.33542            0   2025-01-01      EL5  Βόρεια Ελλάδα
# 1  23.65882  41.33542            0   2025-01-02      EL5  Βόρεια Ελλάδα
# 2  23.65882  41.33542            0   2025-01-03      EL5  Βόρεια Ελλάδα
# 3  23.65882  41.33542            0   2025-01-04      EL5  Βόρεια Ελλάδα
# 4  23.65882  41.33542            0   2025-01-05      EL5  Βόρεια Ελλάδα
#
#   NUTS2_ID                  NUTS2_NAME NUTS3_ID NUTS3_NAME         LAU1_NAME  \
# 0     EL51  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα  Κάτω Νευροκοπίου
# 1     EL51  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα  Κάτω Νευροκοπίου
# 2     EL51  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα  Κάτω Νευροκοπίου
# 3     EL51  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα  Κάτω Νευροκοπίου
# 4     EL51  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα  Κάτω Νευροκοπίου
#
#    year  month      ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  \
# 0  2025      1       NaN       NaN       NaN       NaN        NaN        NaN
# 1  2025      1  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095
# 2  2025      1  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095
# 3  2025      1  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095
# 4  2025      1  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095
#
#    ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  \
# 0        NaN        NaN       NaN       NaN       NaN       NaN  13893.0
# 1  -0.082637   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0
# 2  -0.082637   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0
# 3  -0.082637   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0
# 4  -0.082637   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0
#
#    lst_night  rainfall  day  lst_day_jan_mean  lst_night_jan_mean  \
# 0    13684.0      0.00    1      13864.935484        13732.064516
# 1    13667.0      0.00    2      13864.935484        13732.064516
# 2    13667.0      6.45    3      13864.935484        13732.064516
# 3    13546.0      4.76    4      13864.935484        13732.064516
# 4    13649.0      2.02    5      13864.935484        13732.064516
#
#    lst_day_feb_mean  lst_night_feb_mean  lst_day_mar_mean  lst_night_mar_mean  \
# 0      13718.714286        13448.535714      14232.535714        13851.206897
# 1      13718.714286        13448.535714      14232.535714        13851.206897
# 2      13718.714286        13448.535714      14232.535714        13851.206897
# 3      13718.714286        13448.535714      14232.535714        13851.206897
# 4      13718.714286        13448.535714      14232.535714        13851.206897
#
#    lst_day_apr_mean  lst_night_apr_mean  acc_rainfall_1week  \
# 0      14335.652174         13977.26087                0.00
# 1      14335.652174         13977.26087                0.00
# 2      14335.652174         13977.26087                6.45
# 3      14335.652174         13977.26087               11.21
# 4      14335.652174         13977.26087               13.23
#
#    acc_rainfall_2week  acc_rainfall_month  acc_rainfall_jan  MOUNT_TYPE  \
# 0                0.00                0.00              0.00         2.0
# 1                0.00                0.00              0.00         2.0
# 2                6.45                6.45              6.45         2.0
# 3               11.21               11.21             11.21         2.0
# 4               13.23               13.23             13.23         2.0
#
#    URBN_TYPE  COAST_TYPE
# 0          2           2
# 1          2           2
# 2          2           2
# 3          2           2
# 4          2           2

# %%
process_greek(cm_grid, 'NUTS1_NAME')
process_greek(cm_grid, 'NUTS2_NAME')
process_greek(cm_grid, 'NUTS3_NAME')
process_greek(cm_grid, 'LAU1_NAME')

# %%
cm_grid.head()
# Out:
#           x         y  cell_number dt_placement NUTS1_ID     NUTS1_NAME  \
# 0  23.65882  41.33542            0   2025-01-01      EL5  βορεια ελλαδα
# 1  23.65882  41.33542            0   2025-01-02      EL5  βορεια ελλαδα
# 2  23.65882  41.33542            0   2025-01-03      EL5  βορεια ελλαδα
# 3  23.65882  41.33542            0   2025-01-04      EL5  βορεια ελλαδα
# 4  23.65882  41.33542            0   2025-01-05      EL5  βορεια ελλαδα
#
#   NUTS2_ID                  NUTS2_NAME NUTS3_ID NUTS3_NAME         LAU1_NAME  \
# 0     EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  κατω νευροκοπιου
# 1     EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  κατω νευροκοπιου
# 2     EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  κατω νευροκοπιου
# 3     EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  κατω νευροκοπιου
# 4     EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  κατω νευροκοπιου
#
#    year  month      ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  \
# 0  2025      1       NaN       NaN       NaN       NaN        NaN        NaN
# 1  2025      1  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095
# 2  2025      1  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095
# 3  2025      1  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095
# 4  2025      1  0.078916  0.146433  0.098425 -0.146433   0.183488    0.07095
#
#    ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  \
# 0        NaN        NaN       NaN       NaN       NaN       NaN  13893.0
# 1  -0.082637   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0
# 2  -0.082637   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0
# 3  -0.082637   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0
# 4  -0.082637   -0.07095  0.087655  0.112251   0.13884  0.112251  13803.0
#
#    lst_night  rainfall  day  lst_day_jan_mean  lst_night_jan_mean  \
# 0    13684.0      0.00    1      13864.935484        13732.064516
# 1    13667.0      0.00    2      13864.935484        13732.064516
# 2    13667.0      6.45    3      13864.935484        13732.064516
# 3    13546.0      4.76    4      13864.935484        13732.064516
# 4    13649.0      2.02    5      13864.935484        13732.064516
#
#    lst_day_feb_mean  lst_night_feb_mean  lst_day_mar_mean  lst_night_mar_mean  \
# 0      13718.714286        13448.535714      14232.535714        13851.206897
# 1      13718.714286        13448.535714      14232.535714        13851.206897
# 2      13718.714286        13448.535714      14232.535714        13851.206897
# 3      13718.714286        13448.535714      14232.535714        13851.206897
# 4      13718.714286        13448.535714      14232.535714        13851.206897
#
#    lst_day_apr_mean  lst_night_apr_mean  acc_rainfall_1week  \
# 0      14335.652174         13977.26087                0.00
# 1      14335.652174         13977.26087                0.00
# 2      14335.652174         13977.26087                6.45
# 3      14335.652174         13977.26087               11.21
# 4      14335.652174         13977.26087               13.23
#
#    acc_rainfall_2week  acc_rainfall_month  acc_rainfall_jan  MOUNT_TYPE  \
# 0                0.00                0.00              0.00         2.0
# 1                0.00                0.00              0.00         2.0
# 2                6.45                6.45              6.45         2.0
# 3               11.21               11.21             11.21         2.0
# 4               13.23               13.23             13.23         2.0
#
#    URBN_TYPE  COAST_TYPE
# 0          2           2
# 1          2           2
# 2          2           2
# 3          2           2
# 4          2           2

# %%
cm_grid.to_csv(f'{base_folder}/{NUTS2}/GR_{NUTS2}_Timeline_GRID_{YEAR}_filled_mean_rain_shp.csv', encoding=enc, index = False)
