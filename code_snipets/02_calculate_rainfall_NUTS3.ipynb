# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

enc = 'utf-8'

# %%
base_folder = 'E:/Drive/NOA/MBD-Prediction/NUTS3 Level/Greece/data/'

# %%
NUTS2 = 'Thrace'
YEAR = '2024'

# %%
data = pd.read_csv(f'{base_folder}/{NUTS2}/GR_{NUTS2}_Timeline_NUTS3_{YEAR}_filled_mean.csv', encoding=enc)

# %%
try:
    data.drop(columns=['Unnamed: 0'], inplace=True)
except Exception:
    print("No column named \'Unnamed: 0\'")

# %%
data['dt_placement'] = pd.to_datetime(data['dt_placement'])

# Extract year, month, and day from the 'date' column
data['year'] = data['dt_placement'].dt.year
data['month'] = data['dt_placement'].dt.month
data['day'] = data['dt_placement'].dt.day

# %%
data
# Out:
#        NUTS2_ID                  NUTS2_NAME NUTS3_ID NUTS3_NAME         x  \
# 0          EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  23.69482
# 1          EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  23.69482
# 2          EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  23.69482
# 3          EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  23.69482
# 4          EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  23.69482
# ...         ...                         ...      ...        ...       ...
# 120958     EL51  ανατολικη μακεδονια, θρακη    EL513     ροδοπη  25.49776
# 120959     EL51  ανατολικη μακεδονια, θρακη    EL513     ροδοπη  25.45025
# 120960     EL51  ανατολικη μακεδονια, θρακη    EL513     ροδοπη  25.45025
# 120961     EL51  ανατολικη μακεδονια, θρακη    EL513     ροδοπη  25.49776
# 120962     EL51  ανατολικη μακεδονια, θρακη    EL513     ροδοπη  25.45025
#
#                y dt_placement  year  month      ndvi     ndmi      ndwi  \
# 0       41.34493   2024-01-01  2024      1  0.284574 -0.14387 -0.272169
# 1       41.34493   2024-01-02  2024      1  0.284574 -0.14387 -0.272169
# 2       41.34493   2024-01-03  2024      1  0.284574 -0.14387 -0.272169
# 3       41.34493   2024-01-04  2024      1  0.284574 -0.14387 -0.272169
# 4       41.34493   2024-01-05  2024      1  0.284574 -0.14387 -0.272169
# ...          ...          ...   ...    ...       ...      ...       ...
# 120958  40.91163   2024-07-01  2024      7       NaN      NaN       NaN
# 120959  41.23503   2024-07-01  2024      7       NaN      NaN       NaN
# 120960  41.19910   2024-07-01  2024      7       NaN      NaN       NaN
# 120961  41.19910   2024-07-01  2024      7       NaN      NaN       NaN
# 120962  41.09130   2024-07-01  2024      7       NaN      NaN       NaN
#
#            ndbi  ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  \
# 0       0.14387   0.270964  -0.054752  -0.207973   0.054752  0.024776
# 1       0.14387   0.270964  -0.054752  -0.207973   0.054752  0.024776
# 2       0.14387   0.270964  -0.054752  -0.207973   0.054752  0.024776
# 3       0.14387   0.270964  -0.054752  -0.207973   0.054752  0.024776
# 4       0.14387   0.270964  -0.054752  -0.207973   0.054752  0.024776
# ...         ...        ...        ...        ...        ...       ...
# 120958      NaN        NaN        NaN        NaN        NaN       NaN
# 120959      NaN        NaN        NaN        NaN        NaN       NaN
# 120960      NaN        NaN        NaN        NaN        NaN       NaN
# 120961      NaN        NaN        NaN        NaN        NaN       NaN
# 120962      NaN        NaN        NaN        NaN        NaN       NaN
#
#         ndmi_std  ndwi_std  ndbi_std  lst_day  lst_night  rainfall  day  \
# 0       0.054316  0.051266  0.054316  13998.0    13676.0  0.001530    1
# 1       0.054316  0.051266  0.054316  13998.0    13755.0  0.310446    2
# 2       0.054316  0.051266  0.054316  13998.0    13755.0  0.512597    3
# 3       0.054316  0.051266  0.054316  13756.0    13905.0  0.000000    4
# 4       0.054316  0.051266  0.054316  13756.0    13905.0  0.000000    5
# ...          ...       ...       ...      ...        ...       ...  ...
# 120958       NaN       NaN       NaN  15625.0    14732.0       NaN    1
# 120959       NaN       NaN       NaN  15217.0    14654.0       NaN    1
# 120960       NaN       NaN       NaN  15430.0    14702.0       NaN    1
# 120961       NaN       NaN       NaN  15416.0    14717.0       NaN    1
# 120962       NaN       NaN       NaN  15881.0    14729.0       NaN    1
#
#         lst_day_jan_mean  lst_night_jan_mean  lst_day_feb_mean  \
# 0           13917.050069        13619.718979      14162.914322
# 1           13917.050069        13619.718979      14162.914322
# 2           13917.050069        13619.718979      14162.914322
# 3           13917.050069        13619.718979      14162.914322
# 4           13917.050069        13619.718979      14162.914322
# ...                  ...                 ...               ...
# 120958      14099.633715        13711.818158      14306.535039
# 120959      14099.633715        13711.818158      14306.535039
# 120960      14099.633715        13711.818158      14306.535039
# 120961      14099.633715        13711.818158      14306.535039
# 120962      14099.633715        13711.818158      14306.535039
#
#         lst_night_feb_mean  lst_day_mar_mean  lst_night_mar_mean  \
# 0             13779.140106      14311.732634        13880.081948
# 1             13779.140106      14311.732634        13880.081948
# 2             13779.140106      14311.732634        13880.081948
# 3             13779.140106      14311.732634        13880.081948
# 4             13779.140106      14311.732634        13880.081948
# ...                    ...               ...                 ...
# 120958        13899.578420      14459.404266        13932.547867
# 120959        13899.578420      14459.404266        13932.547867
# 120960        13899.578420      14459.404266        13932.547867
# 120961        13899.578420      14459.404266        13932.547867
# 120962        13899.578420      14459.404266        13932.547867
#
#         lst_day_apr_mean  lst_night_apr_mean
# 0           14751.354397        14127.758487
# 1           14751.354397        14127.758487
# 2           14751.354397        14127.758487
# 3           14751.354397        14127.758487
# 4           14751.354397        14127.758487
# ...                  ...                 ...
# 120958      14842.184409        14233.125806
# 120959      14842.184409        14233.125806
# 120960      14842.184409        14233.125806
# 120961      14842.184409        14233.125806
# 120962      14842.184409        14233.125806
#
# [120963 rows x 33 columns]

# %%
dataset_list = []
groups = data.groupby(['x', 'y', 'year'])

# %%
num_of_groups = len(groups)

# %%
c = 0

for group, frame in groups:
    print(f"Iteration: {c}/{num_of_groups}", end='\r')
    temp_df = frame.copy()
    temp_df.reset_index(drop=True, inplace=True)
    temp_df['acc_rainfall_1week'] = temp_df['rainfall'].rolling(window=7, min_periods=0).sum()
    temp_df['acc_rainfall_2week'] = temp_df['rainfall'].rolling(window=14, min_periods=0).sum()
    temp_df['acc_rainfall_month'] = temp_df['rainfall'].rolling(window=30, min_periods=0).sum()
    temp_df['acc_rainfall_jan'] = temp_df['dt_placement'].apply(lambda x: temp_df.loc[temp_df['dt_placement'] <= x, 'rainfall'].sum())
    dataset_list.append(temp_df)
    c = c + 1
# Out:
# Iteration: 660/661

# %%
dataset = pd.concat(dataset_list, ignore_index=True)
dataset.reset_index(drop=True, inplace=True)

# %%
dataset
# Out:
#        NUTS2_ID                  NUTS2_NAME NUTS3_ID NUTS3_NAME         x  \
# 0          EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  23.69482
# 1          EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  23.69482
# 2          EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  23.69482
# 3          EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  23.69482
# 4          EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  23.69482
# ...         ...                         ...      ...        ...       ...
# 120958     EL51  ανατολικη μακεδονια, θρακη    EL511      εβρος  26.60558
# 120959     EL51  ανατολικη μακεδονια, θρακη    EL511      εβρος  26.60558
# 120960     EL51  ανατολικη μακεδονια, θρακη    EL511      εβρος  26.60558
# 120961     EL51  ανατολικη μακεδονια, θρακη    EL511      εβρος  26.60558
# 120962     EL51  ανατολικη μακεδονια, θρακη    EL511      εβρος  26.60558
#
#                y dt_placement  year  month      ndvi     ndmi      ndwi  \
# 0       41.34493   2024-01-01  2024      1  0.284574 -0.14387 -0.272169
# 1       41.34493   2024-01-02  2024      1  0.284574 -0.14387 -0.272169
# 2       41.34493   2024-01-03  2024      1  0.284574 -0.14387 -0.272169
# 3       41.34493   2024-01-04  2024      1  0.284574 -0.14387 -0.272169
# 4       41.34493   2024-01-05  2024      1  0.284574 -0.14387 -0.272169
# ...          ...          ...   ...    ...       ...      ...       ...
# 120958  41.38034   2024-06-27  2024      6       NaN      NaN       NaN
# 120959  41.38034   2024-06-28  2024      6       NaN      NaN       NaN
# 120960  41.38034   2024-06-29  2024      6       NaN      NaN       NaN
# 120961  41.38034   2024-06-30  2024      6       NaN      NaN       NaN
# 120962  41.38034   2024-07-01  2024      7       NaN      NaN       NaN
#
#            ndbi  ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  \
# 0       0.14387   0.270964  -0.054752  -0.207973   0.054752  0.024776
# 1       0.14387   0.270964  -0.054752  -0.207973   0.054752  0.024776
# 2       0.14387   0.270964  -0.054752  -0.207973   0.054752  0.024776
# 3       0.14387   0.270964  -0.054752  -0.207973   0.054752  0.024776
# 4       0.14387   0.270964  -0.054752  -0.207973   0.054752  0.024776
# ...         ...        ...        ...        ...        ...       ...
# 120958      NaN        NaN        NaN        NaN        NaN       NaN
# 120959      NaN        NaN        NaN        NaN        NaN       NaN
# 120960      NaN        NaN        NaN        NaN        NaN       NaN
# 120961      NaN        NaN        NaN        NaN        NaN       NaN
# 120962      NaN        NaN        NaN        NaN        NaN       NaN
#
#         ndmi_std  ndwi_std  ndbi_std  lst_day  lst_night  rainfall  day  \
# 0       0.054316  0.051266  0.054316  13998.0    13676.0  0.001530    1
# 1       0.054316  0.051266  0.054316  13998.0    13755.0  0.310446    2
# 2       0.054316  0.051266  0.054316  13998.0    13755.0  0.512597    3
# 3       0.054316  0.051266  0.054316  13756.0    13905.0  0.000000    4
# 4       0.054316  0.051266  0.054316  13756.0    13905.0  0.000000    5
# ...          ...       ...       ...      ...        ...       ...  ...
# 120958       NaN       NaN       NaN  15339.0    14709.0       NaN   27
# 120959       NaN       NaN       NaN  15339.0    14709.0       NaN   28
# 120960       NaN       NaN       NaN  15222.0    14576.0       NaN   29
# 120961       NaN       NaN       NaN  15541.0    14736.0       NaN   30
# 120962       NaN       NaN       NaN  15718.0    14747.0       NaN    1
#
#         lst_day_jan_mean  lst_night_jan_mean  lst_day_feb_mean  \
# 0           13917.050069        13619.718979      14162.914322
# 1           13917.050069        13619.718979      14162.914322
# 2           13917.050069        13619.718979      14162.914322
# 3           13917.050069        13619.718979      14162.914322
# 4           13917.050069        13619.718979      14162.914322
# ...                  ...                 ...               ...
# 120958      14086.249032        13726.772419      14341.048276
# 120959      14086.249032        13726.772419      14341.048276
# 120960      14086.249032        13726.772419      14341.048276
# 120961      14086.249032        13726.772419      14341.048276
# 120962      14086.249032        13726.772419      14341.048276
#
#         lst_night_feb_mean  lst_day_mar_mean  lst_night_mar_mean  \
# 0             13779.140106      14311.732634        13880.081948
# 1             13779.140106      14311.732634        13880.081948
# 2             13779.140106      14311.732634        13880.081948
# 3             13779.140106      14311.732634        13880.081948
# 4             13779.140106      14311.732634        13880.081948
# ...                    ...               ...                 ...
# 120958        13920.649138      14444.408548        13928.651290
# 120959        13920.649138      14444.408548        13928.651290
# 120960        13920.649138      14444.408548        13928.651290
# 120961        13920.649138      14444.408548        13928.651290
# 120962        13920.649138      14444.408548        13928.651290
#
#         lst_day_apr_mean  lst_night_apr_mean  acc_rainfall_1week  \
# 0           14751.354397        14127.758487            0.001530
# 1           14751.354397        14127.758487            0.311976
# 2           14751.354397        14127.758487            0.824574
# 3           14751.354397        14127.758487            0.824574
# 4           14751.354397        14127.758487            0.824574
# ...                  ...                 ...                 ...
# 120958      14865.151500        14220.632667            0.000000
# 120959      14865.151500        14220.632667            0.000000
# 120960      14865.151500        14220.632667            0.000000
# 120961      14865.151500        14220.632667            0.000000
# 120962      14865.151500        14220.632667            0.000000
#
#         acc_rainfall_2week  acc_rainfall_month  acc_rainfall_jan
# 0                 0.001530            0.001530          0.001530
# 1                 0.311976            0.311976          0.311976
# 2                 0.824574            0.824574          0.824574
# 3                 0.824574            0.824574          0.824574
# 4                 0.824574            0.824574          0.824574
# ...                    ...                 ...               ...
# 120958            0.000000            0.000000        160.586929
# 120959            0.000000            0.000000        160.586929
# 120960            0.000000            0.000000        160.586929
# 120961            0.000000            0.000000        160.586929
# 120962            0.000000            0.000000        160.586929
#
# [120963 rows x 37 columns]

# %%
dataset.to_csv(f'{base_folder}/{NUTS2}/GR_{NUTS2}_Timeline_NUTS3_{YEAR}_filled_mean_rain.csv', encoding='utf-8')
