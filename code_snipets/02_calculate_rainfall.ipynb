# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv(r'E:\Drive\NOA\MBD-Prediction\Grid Level\data\Attica\GR_Attica_Timeline_GRID_2011_filled_mean.csv', encoding='utf-8')

# %%
try:
    data.drop(columns=['Unnamed: 0'], inplace=True)
except Exception:
    print("No column named \'Unnamed: 0\'")

# %%
data['dt_placement'] = pd.to_datetime(data['dt_placement'])

# Extract year, month, and day from the 'date' column
data['year'] = data['dt_placement'].dt.year
data['month'] = data['dt_placement'].dt.month
data['day'] = data['dt_placement'].dt.day

# %%
data
# Out:
#                x         y  cell_number dt_placement NUTS2_ID  year  month  \
# 0       22.92536  36.22923            0   2011-01-01     EL30  2011      1
# 1       22.92536  36.22923            0   2011-01-02     EL30  2011      1
# 2       22.92536  36.22923            0   2011-01-03     EL30  2011      1
# 3       22.92536  36.22923            0   2011-01-04     EL30  2011      1
# 4       22.92536  36.22923            0   2011-01-05     EL30  2011      1
# ...          ...       ...          ...          ...      ...   ...    ...
# 269000  24.05547  37.79233          736   2011-12-27     EL30  2011     12
# 269001  24.05547  37.79233          736   2011-12-28     EL30  2011     12
# 269002  24.05547  37.79233          736   2011-12-29     EL30  2011     12
# 269003  24.05547  37.79233          736   2011-12-30     EL30  2011     12
# 269004  24.05547  37.79233          736   2011-12-31     EL30  2011     12
#
#             ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  \
# 0            NaN       NaN       NaN       NaN   0.298096   0.192858
# 1            NaN       NaN       NaN       NaN   0.298096   0.192858
# 2            NaN       NaN       NaN       NaN        NaN        NaN
# 3            NaN       NaN       NaN       NaN   0.298096   0.192858
# 4            NaN       NaN       NaN       NaN   0.298096   0.192858
# ...          ...       ...       ...       ...        ...        ...
# 269000       NaN       NaN       NaN       NaN        NaN        NaN
# 269001       NaN       NaN       NaN       NaN        NaN        NaN
# 269002  0.181882 -0.028344 -0.219983  0.028344   0.182326  -0.024150
# 269003  0.181882 -0.028344 -0.219983  0.028344   0.182326  -0.024150
# 269004  0.181882 -0.028344 -0.219983  0.028344   0.182326  -0.024150
#
#         ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  \
# 0       -0.030036  -0.192858  0.115468  0.076475  0.207660  0.076475  14115.0
# 1       -0.030036  -0.192858  0.115468  0.076475  0.207660  0.076475  14115.0
# 2             NaN        NaN       NaN       NaN       NaN       NaN  14115.0
# 3       -0.030036  -0.192858  0.115468  0.076475  0.207660  0.076475  14257.0
# 4       -0.030036  -0.192858  0.115468  0.076475  0.207660  0.076475  14257.0
# ...           ...        ...       ...       ...       ...       ...      ...
# 269000        NaN        NaN       NaN       NaN       NaN       NaN  14031.0
# 269001        NaN        NaN       NaN       NaN       NaN       NaN  14186.0
# 269002  -0.214190   0.024150  0.014287  0.019814  0.036058  0.019814  14255.0
# 269003  -0.214190   0.024150  0.014287  0.019814  0.036058  0.019814  14255.0
# 269004  -0.214190   0.024150  0.014287  0.019814  0.036058  0.019814  14062.0
#
#         lst_night    rainfall  day  lst_day_jan_mean  lst_night_jan_mean  \
# 0         14006.0    0.103795    1      14201.483871        14011.612903
# 1         14109.0  132.058654    2      14201.483871        14011.612903
# 2         14109.0    0.219865    3      14201.483871        14011.612903
# 3         13988.0    0.312082    4      14201.483871        14011.612903
# 4         13988.0    1.513182    5      14201.483871        14011.612903
# ...           ...         ...  ...               ...                 ...
# 269000    13918.0    0.000000   27      14271.483871        13981.193548
# 269001    14053.0    0.000000   28      14271.483871        13981.193548
# 269002    14053.0    1.019003   29      14271.483871        13981.193548
# 269003    14053.0    0.813852   30      14271.483871        13981.193548
# 269004    13969.0    0.295510   31      14271.483871        13981.193548
#
#         lst_day_feb_mean  lst_night_feb_mean  lst_day_mar_mean  \
# 0           14331.821429        13982.714286      14356.774194
# 1           14331.821429        13982.714286      14356.774194
# 2           14331.821429        13982.714286      14356.774194
# 3           14331.821429        13982.714286      14356.774194
# 4           14331.821429        13982.714286      14356.774194
# ...                  ...                 ...               ...
# 269000      14340.250000        13896.678571      14544.193548
# 269001      14340.250000        13896.678571      14544.193548
# 269002      14340.250000        13896.678571      14544.193548
# 269003      14340.250000        13896.678571      14544.193548
# 269004      14340.250000        13896.678571      14544.193548
#
#         lst_night_mar_mean  lst_day_apr_mean  lst_night_apr_mean
# 0             14027.677419      14585.166667        14110.800000
# 1             14027.677419      14585.166667        14110.800000
# 2             14027.677419      14585.166667        14110.800000
# 3             14027.677419      14585.166667        14110.800000
# 4             14027.677419      14585.166667        14110.800000
# ...                    ...               ...                 ...
# 269000        13975.516129      14610.900000        14179.966667
# 269001        13975.516129      14610.900000        14179.966667
# 269002        13975.516129      14610.900000        14179.966667
# 269003        13975.516129      14610.900000        14179.966667
# 269004        13975.516129      14610.900000        14179.966667
#
# [269005 rows x 31 columns]

# %%
dataset_list = []
groups = data.groupby(['x', 'y', 'year'])

# %%
num_of_groups = len(groups)

# %%
c = 0

for group, frame in groups:
    print(f"Iteration: {c}/{num_of_groups}", end='\r')
    temp_df = frame.copy()
    temp_df.reset_index(drop=True, inplace=True)
    temp_df['acc_rainfall_1week'] = temp_df['rainfall'].rolling(window=7, min_periods=0).sum()
    temp_df['acc_rainfall_2week'] = temp_df['rainfall'].rolling(window=14, min_periods=0).sum()
    temp_df['acc_rainfall_month'] = temp_df['rainfall'].rolling(window=30, min_periods=0).sum()
    temp_df['acc_rainfall_jan'] = temp_df['dt_placement'].apply(lambda x: temp_df.loc[temp_df['dt_placement'] <= x, 'rainfall'].sum())
    dataset_list.append(temp_df)
    c = c + 1
# Out:
# Iteration: 736/737

# %%
dataset = pd.concat(dataset_list, ignore_index=True)
dataset.reset_index(drop=True, inplace=True)

# %%
dataset
# Out:
#                x         y  cell_number dt_placement NUTS2_ID  year  month  \
# 0       22.92536  36.22923            0   2011-01-01     EL30  2011      1
# 1       22.92536  36.22923            0   2011-01-02     EL30  2011      1
# 2       22.92536  36.22923            0   2011-01-03     EL30  2011      1
# 3       22.92536  36.22923            0   2011-01-04     EL30  2011      1
# 4       22.92536  36.22923            0   2011-01-05     EL30  2011      1
# ...          ...       ...          ...          ...      ...   ...    ...
# 269000  24.05547  37.79233          736   2011-12-27     EL30  2011     12
# 269001  24.05547  37.79233          736   2011-12-28     EL30  2011     12
# 269002  24.05547  37.79233          736   2011-12-29     EL30  2011     12
# 269003  24.05547  37.79233          736   2011-12-30     EL30  2011     12
# 269004  24.05547  37.79233          736   2011-12-31     EL30  2011     12
#
#             ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  \
# 0            NaN       NaN       NaN       NaN   0.298096   0.192858
# 1            NaN       NaN       NaN       NaN   0.298096   0.192858
# 2            NaN       NaN       NaN       NaN        NaN        NaN
# 3            NaN       NaN       NaN       NaN   0.298096   0.192858
# 4            NaN       NaN       NaN       NaN   0.298096   0.192858
# ...          ...       ...       ...       ...        ...        ...
# 269000       NaN       NaN       NaN       NaN        NaN        NaN
# 269001       NaN       NaN       NaN       NaN        NaN        NaN
# 269002  0.181882 -0.028344 -0.219983  0.028344   0.182326  -0.024150
# 269003  0.181882 -0.028344 -0.219983  0.028344   0.182326  -0.024150
# 269004  0.181882 -0.028344 -0.219983  0.028344   0.182326  -0.024150
#
#         ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  \
# 0       -0.030036  -0.192858  0.115468  0.076475  0.207660  0.076475  14115.0
# 1       -0.030036  -0.192858  0.115468  0.076475  0.207660  0.076475  14115.0
# 2             NaN        NaN       NaN       NaN       NaN       NaN  14115.0
# 3       -0.030036  -0.192858  0.115468  0.076475  0.207660  0.076475  14257.0
# 4       -0.030036  -0.192858  0.115468  0.076475  0.207660  0.076475  14257.0
# ...           ...        ...       ...       ...       ...       ...      ...
# 269000        NaN        NaN       NaN       NaN       NaN       NaN  14031.0
# 269001        NaN        NaN       NaN       NaN       NaN       NaN  14186.0
# 269002  -0.214190   0.024150  0.014287  0.019814  0.036058  0.019814  14255.0
# 269003  -0.214190   0.024150  0.014287  0.019814  0.036058  0.019814  14255.0
# 269004  -0.214190   0.024150  0.014287  0.019814  0.036058  0.019814  14062.0
#
#         lst_night    rainfall  day  lst_day_jan_mean  lst_night_jan_mean  \
# 0         14006.0    0.103795    1      14201.483871        14011.612903
# 1         14109.0  132.058654    2      14201.483871        14011.612903
# 2         14109.0    0.219865    3      14201.483871        14011.612903
# 3         13988.0    0.312082    4      14201.483871        14011.612903
# 4         13988.0    1.513182    5      14201.483871        14011.612903
# ...           ...         ...  ...               ...                 ...
# 269000    13918.0    0.000000   27      14271.483871        13981.193548
# 269001    14053.0    0.000000   28      14271.483871        13981.193548
# 269002    14053.0    1.019003   29      14271.483871        13981.193548
# 269003    14053.0    0.813852   30      14271.483871        13981.193548
# 269004    13969.0    0.295510   31      14271.483871        13981.193548
#
#         lst_day_feb_mean  lst_night_feb_mean  lst_day_mar_mean  \
# 0           14331.821429        13982.714286      14356.774194
# 1           14331.821429        13982.714286      14356.774194
# 2           14331.821429        13982.714286      14356.774194
# 3           14331.821429        13982.714286      14356.774194
# 4           14331.821429        13982.714286      14356.774194
# ...                  ...                 ...               ...
# 269000      14340.250000        13896.678571      14544.193548
# 269001      14340.250000        13896.678571      14544.193548
# 269002      14340.250000        13896.678571      14544.193548
# 269003      14340.250000        13896.678571      14544.193548
# 269004      14340.250000        13896.678571      14544.193548
#
#         lst_night_mar_mean  lst_day_apr_mean  lst_night_apr_mean  \
# 0             14027.677419      14585.166667        14110.800000
# 1             14027.677419      14585.166667        14110.800000
# 2             14027.677419      14585.166667        14110.800000
# 3             14027.677419      14585.166667        14110.800000
# 4             14027.677419      14585.166667        14110.800000
# ...                    ...               ...                 ...
# 269000        13975.516129      14610.900000        14179.966667
# 269001        13975.516129      14610.900000        14179.966667
# 269002        13975.516129      14610.900000        14179.966667
# 269003        13975.516129      14610.900000        14179.966667
# 269004        13975.516129      14610.900000        14179.966667
#
#         acc_rainfall_1week  acc_rainfall_2week  acc_rainfall_month  \
# 0                 0.103795            0.103795            0.103795
# 1               132.162450          132.162450          132.162450
# 2               132.382314          132.382314          132.382314
# 3               132.694397          132.694397          132.694397
# 4               134.207578          134.207578          134.207578
# ...                    ...                 ...                 ...
# 269000           58.581730          111.698848          131.004068
# 269001           49.972854          111.698848          130.819427
# 269002           14.498666          110.433525          130.710955
# 269003            1.832855          110.007446          131.374415
# 269004            2.128365          106.279571          131.669925
#
#         acc_rainfall_jan
# 0               0.103795
# 1             132.162450
# 2             132.382314
# 3             132.694397
# 4             134.207578
# ...                  ...
# 269000       1212.057612
# 269001       1212.057612
# 269002       1213.076615
# 269003       1213.890468
# 269004       1214.185978
#
# [269005 rows x 35 columns]

# %%
dataset.to_csv(r'E:\Drive\NOA\MBD-Prediction\Grid Level\data\Attica\GR_Attica_Timeline_GRID_2011_filled_mean_rain.csv', encoding='utf-8')
