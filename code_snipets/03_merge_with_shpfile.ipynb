# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import sys

sys.path.insert(0, r"E:\Drive\NOA\MBD-Prediction\Modules")

from utils import describe_dataframe, process_greek

enc = 'utf-8'

folder_path = "C:/Users/dimit/Documents/noa hoard/Greece Shapefiles"

pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv(r'E:\Drive\NOA\MBD-Prediction\Grid Level\data\Thrace\GR_Thrace_Timeline_GRID_2018-2020_filled_mean_rain.csv', encoding=enc)
greece_nuts3 = gpd.read_file(r"E:\Drive\NOA\MBD-Prediction\Europe NUTS - LAU Shapefiles\Greece\data\EL_Whole.shp",  encoding=enc)
greece_lau1 = gpd.read_file(f"{folder_path}/el_lau1.shp",  encoding=enc)

# %%
try:
    data.drop(columns=['Unnamed: 0'], inplace=True)
except Exception:
    print("No column named \'Unnamed: 0\'")

# %%
try:
    data.drop(columns=['rainfall.1'], inplace=True)
except Exception:
    print("No column named \'rainfall.1\'")
# Out:
# No column named 'rainfall.1'

# %%
data
# Out:
#                 x         y  cell_number dt_placement NUTS2_ID  year  month  \
# 0        23.65882  41.33542            0   2018-01-01     EL51  2018      1
# 1        23.65882  41.33542            0   2018-01-02     EL51  2018      1
# 2        23.65882  41.33542            0   2018-01-03     EL51  2018      1
# 3        23.65882  41.33542            0   2018-01-04     EL51  2018      1
# 4        23.65882  41.33542            0   2018-01-05     EL51  2018      1
# ...           ...       ...          ...          ...      ...   ...    ...
# 3579531  26.60756  41.40729         3265   2020-12-27     EL51  2020     12
# 3579532  26.60756  41.40729         3265   2020-12-28     EL51  2020     12
# 3579533  26.60756  41.40729         3265   2020-12-29     EL51  2020     12
# 3579534  26.60756  41.40729         3265   2020-12-30     EL51  2020     12
# 3579535  26.60756  41.40729         3265   2020-12-31     EL51  2020     12
#
#              ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  \
# 0        0.075421  0.163148  0.062645 -0.163148   0.146046   0.072780
# 1        0.075421  0.163148  0.062645 -0.163148   0.146046   0.072780
# 2        0.075421  0.163148  0.062645 -0.163148   0.146046   0.072780
# 3        0.075421  0.163148  0.062645 -0.163148   0.146046   0.072780
# 4        0.075421  0.163148  0.062645 -0.163148   0.146046   0.072780
# ...           ...       ...       ...       ...        ...        ...
# 3579531  0.450774  0.156466 -0.351211 -0.156466   0.200367  -0.010449
# 3579532  0.450774  0.156466 -0.351211 -0.156466   0.200367  -0.010449
# 3579533  0.450774  0.156466 -0.351211 -0.156466   0.200367  -0.010449
# 3579534  0.450774  0.156466 -0.351211 -0.156466   0.200367  -0.010449
# 3579535  0.450774  0.156466 -0.351211 -0.156466   0.200367  -0.010449
#
#          ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  \
# 0        -0.063395  -0.072780  0.097993  0.055410  0.113606  0.055410
# 1        -0.063395  -0.072780  0.097993  0.055410  0.113606  0.055410
# 2        -0.063395  -0.072780  0.097993  0.055410  0.113606  0.055410
# 3        -0.063395  -0.072780  0.097993  0.055410  0.113606  0.055410
# 4        -0.063395  -0.072780  0.097993  0.055410  0.113606  0.055410
# ...            ...        ...       ...       ...       ...       ...
# 3579531  -0.132835   0.010449  0.117562  0.077335  0.106493  0.077335
# 3579532  -0.132835   0.010449  0.117562  0.077335  0.106493  0.077335
# 3579533  -0.132835   0.010449  0.117562  0.077335  0.106493  0.077335
# 3579534  -0.132835   0.010449  0.117562  0.077335  0.106493  0.077335
# 3579535  -0.132835   0.010449  0.117562  0.077335  0.106493  0.077335
#
#          lst_day     lst_night   rainfall  day  lst_day_jan_mean  \
# 0        14093.0  13642.000000   0.000000    1      13877.354839
# 1        13931.0  13642.000000   2.953801    2      13877.354839
# 2        13783.0  13488.000000   0.000000    3      13877.354839
# 3        13783.0  13515.000000   3.852192    4      13877.354839
# 4        13783.0  13515.000000   0.000000    5      13877.354839
# ...          ...           ...        ...  ...               ...
# 3579531      NaN     41.405597  40.110161   27      14099.225806
# 3579532      NaN     41.405597  10.648291   28      14099.225806
# 3579533      NaN     41.405597   1.150095   29      14099.225806
# 3579534      NaN     41.405597   0.027165   30      14099.225806
# 3579535      NaN     41.405597   0.257085   31      14099.225806
#
#          lst_night_jan_mean  lst_day_feb_mean  lst_night_feb_mean  \
# 0              13637.354839      13989.714286        13643.392857
# 1              13637.354839      13989.714286        13643.392857
# 2              13637.354839      13989.714286        13643.392857
# 3              13637.354839      13989.714286        13643.392857
# 4              13637.354839      13989.714286        13643.392857
# ...                     ...               ...                 ...
# 3579531        13492.870968      14269.241379        13800.586207
# 3579532        13492.870968      14269.241379        13800.586207
# 3579533        13492.870968      14269.241379        13800.586207
# 3579534        13492.870968      14269.241379        13800.586207
# 3579535        13492.870968      14269.241379        13800.586207
#
#          lst_day_mar_mean  lst_night_mar_mean  lst_day_apr_mean  \
# 0            14153.612903        13769.354839      14733.700000
# 1            14153.612903        13769.354839      14733.700000
# 2            14153.612903        13769.354839      14733.700000
# 3            14153.612903        13769.354839      14733.700000
# 4            14153.612903        13769.354839      14733.700000
# ...                   ...                 ...               ...
# 3579531      14750.290323        13907.612903      14912.933333
# 3579532      14750.290323        13907.612903      14912.933333
# 3579533      14750.290323        13907.612903      14912.933333
# 3579534      14750.290323        13907.612903      14912.933333
# 3579535      14750.290323        13907.612903      14912.933333
#
#          lst_night_apr_mean  acc_rainfall_1week  acc_rainfall_2week  \
# 0              14052.000000            0.000000            0.000000
# 1              14052.000000            2.953801            2.953801
# 2              14052.000000            2.953801            2.953801
# 3              14052.000000            6.805993            6.805993
# 4              14052.000000            6.805993            6.805993
# ...                     ...                 ...                 ...
# 3579531        13992.366667           41.386282           66.425832
# 3579532        13992.366667           51.427257           55.530515
# 3579533        13992.366667           52.577352           53.184668
# 3579534        13992.366667           52.604516           53.211832
# 3579535        13992.366667           52.859634           53.468917
#
#          acc_rainfall_month  acc_rainfall_jan
# 0                  0.000000          0.000000
# 1                  2.953801          2.953801
# 2                  2.953801          2.953801
# 3                  6.805993          6.805993
# 4                  6.805993          6.805993
# ...                     ...               ...
# 3579531          178.760248        945.448095
# 3579532          189.246326        956.096386
# 3579533          190.396420        957.246481
# 3579534          187.858429        957.273646
# 3579535          188.115514        957.530731
#
# [3579536 rows x 35 columns]

# %%
greece_grid = gpd.GeoDataFrame(data, geometry=gpd.points_from_xy(data.x, data.y), crs='EPSG:4326')

greece_grid.head()
# Out:
#           x         y  cell_number dt_placement NUTS2_ID  year  month  \
# 0  23.65882  41.33542            0   2018-01-01     EL51  2018      1
# 1  23.65882  41.33542            0   2018-01-02     EL51  2018      1
# 2  23.65882  41.33542            0   2018-01-03     EL51  2018      1
# 3  23.65882  41.33542            0   2018-01-04     EL51  2018      1
# 4  23.65882  41.33542            0   2018-01-05     EL51  2018      1
#
#        ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  \
# 0  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278  -0.063395
# 1  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278  -0.063395
# 2  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278  -0.063395
# 3  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278  -0.063395
# 4  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278  -0.063395
#
#    ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  lst_night  \
# 0   -0.07278  0.097993   0.05541  0.113606   0.05541  14093.0    13642.0
# 1   -0.07278  0.097993   0.05541  0.113606   0.05541  13931.0    13642.0
# 2   -0.07278  0.097993   0.05541  0.113606   0.05541  13783.0    13488.0
# 3   -0.07278  0.097993   0.05541  0.113606   0.05541  13783.0    13515.0
# 4   -0.07278  0.097993   0.05541  0.113606   0.05541  13783.0    13515.0
#
#    rainfall  day  lst_day_jan_mean  lst_night_jan_mean  lst_day_feb_mean  \
# 0  0.000000    1      13877.354839        13637.354839      13989.714286
# 1  2.953801    2      13877.354839        13637.354839      13989.714286
# 2  0.000000    3      13877.354839        13637.354839      13989.714286
# 3  3.852192    4      13877.354839        13637.354839      13989.714286
# 4  0.000000    5      13877.354839        13637.354839      13989.714286
#
#    lst_night_feb_mean  lst_day_mar_mean  lst_night_mar_mean  lst_day_apr_mean  \
# 0        13643.392857      14153.612903        13769.354839           14733.7
# 1        13643.392857      14153.612903        13769.354839           14733.7
# 2        13643.392857      14153.612903        13769.354839           14733.7
# 3        13643.392857      14153.612903        13769.354839           14733.7
# 4        13643.392857      14153.612903        13769.354839           14733.7
#
#    lst_night_apr_mean  acc_rainfall_1week  acc_rainfall_2week  \
# 0             14052.0            0.000000            0.000000
# 1             14052.0            2.953801            2.953801
# 2             14052.0            2.953801            2.953801
# 3             14052.0            6.805993            6.805993
# 4             14052.0            6.805993            6.805993
#
#    acc_rainfall_month  acc_rainfall_jan                   geometry
# 0            0.000000          0.000000  POINT (23.65882 41.33542)
# 1            2.953801          2.953801  POINT (23.65882 41.33542)
# 2            2.953801          2.953801  POINT (23.65882 41.33542)
# 3            6.805993          6.805993  POINT (23.65882 41.33542)
# 4            6.805993          6.805993  POINT (23.65882 41.33542)

# %%
greece_nuts3 = greece_nuts3.to_crs(epsg=4326)
greece_lau1 = greece_lau1.to_crs(epsg=4326)
greece_grid = greece_grid.to_crs(epsg=4326)

# %%
greece_lau1.drop(columns=['KWD_YPES'], inplace = True)
greece_lau1.drop(greece_lau1[greece_lau1['NAME'] == 'Άθως'].index, inplace = True)
greece_lau1.rename(columns={"NAME": "LAU1_NAME", "geometry": "lau1_geom"}, inplace = True)
greece_lau1.set_geometry("lau1_geom", inplace = True)
greece_lau1['lau1_centroid'] = greece_lau1['lau1_geom'].centroid
greece_lau1['lau1_rpoint'] = greece_lau1['lau1_geom'].representative_point()
greece_lau1.reset_index(drop=True, inplace=True)

greece_nuts3.rename(columns={"geometry": "nuts3_geom"}, inplace = True)
greece_nuts3.set_geometry("nuts3_geom", inplace = True)
# Out:
# C:\Users\dimit\AppData\Local\Temp\ipykernel_16968\2894926608.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   greece_lau1['lau1_centroid'] = greece_lau1['lau1_geom'].centroid

# %%
print(f'greece_nuts3 CRS: {greece_nuts3.crs}')
print(f'greece_lau1 CRS: {greece_lau1.crs}')
print(f'greece_grid CRS: {greece_grid.crs}')
# Out:
# greece_nuts3 CRS: EPSG:4326
# greece_lau1 CRS: EPSG:4326
# greece_grid CRS: EPSG:4326

# %%
greece_lau1.set_geometry("lau1_rpoint", inplace = True)
greece_nuts3 = greece_nuts3.to_crs(epsg=4326)
greece_lau1 = greece_lau1.to_crs(epsg=4326)

greece_gdf = greece_lau1.sjoin(greece_nuts3, predicate="within", how = "left")
greece_gdf.head()
# Out:
#            LAU1_NAME                                          lau1_geom  \
# 0          Αμυνταίου  POLYGON ((21.70746 40.85172, 21.70955 40.85119...
# 1  Άκτιου - Βόνιτσας  MULTIPOLYGON (((20.79456 38.75371, 20.79456 38...
# 2             Άνδρου  MULTIPOLYGON (((24.95917 37.69039, 24.95897 37...
# 3   Άργους - Μυκηνών  POLYGON ((22.52084 37.83857, 22.52111 37.83829...
# 4            Έδεσσας  POLYGON ((21.99535 40.90380, 21.99562 40.90344...
#
#                lau1_centroid                lau1_rpoint  index_right  \
# 0  POINT (21.63479 40.67528)  POINT (21.67171 40.68676)           30
# 1  POINT (20.95158 38.82289)  POINT (20.93655 38.81891)           41
# 2  POINT (24.84814 37.85801)  POINT (24.86216 37.84094)           11
# 3  POINT (22.62532 37.66339)  POINT (22.62833 37.65584)           49
# 4  POINT (21.92931 40.79799)  POINT (21.93215 40.79303)           24
#
#   CNTR_CODE CNTR_NAME NUTS1_ID            NUTS1_LATN            NUTS1_NAME  \
# 0        EL    Greece      EL5         Voreia Elláda         Βόρεια Ελλάδα
# 1        EL    Greece      EL6       Kentriki Elláda       Κεντρική Ελλάδα
# 2        EL    Greece      EL4  Nisia Aigaiou, Kriti  Νησιά Αιγαίου, Κρήτη
# 3        EL    Greece      EL6       Kentriki Elláda       Κεντρική Ελλάδα
# 4        EL    Greece      EL5         Voreia Elláda         Βόρεια Ελλάδα
#
#   NUTS2_ID          NUTS2_LATN          NUTS2_NAME NUTS3_ID  \
# 0     EL53    Dytiki Makedonia    Δυτική Μακεδονία    EL533
# 1     EL63       Dytiki Elláda       Δυτική Ελλάδα    EL631
# 2     EL42        Notio Aigaio        Νότιο Αιγαίο    EL422
# 3     EL65        Peloponnisos        Πελοπόννησος    EL651
# 4     EL52  Kentriki Makedonia  Κεντρική Μακεδονία    EL524
#
#                                           NUTS3_LATN  \
# 0                                            Florina
# 1                                    Aitoloakarnania
# 2  Andros, Thira, Kea, Milos, Mykonos, Naxos, Par...
# 3                                  Argolida, Arkadia
# 4                                              Pella
#
#                                           NUTS3_NAME  MOUNT_TYPE  URBN_TYPE  \
# 0                                            Φλώρινα         3.0          3
# 1                                    Αιτωλοακαρνανία         2.0          3
# 2  Άνδρος, Θήρα, Κέα, Μήλος, Μύκονος, Νάξος, Πάρο...         2.0          3
# 3                                  Αργολίδα, Αρκαδία         3.0          3
# 4                                              Πέλλα         2.0          3
#
#    COAST_TYPE
# 0           3
# 1           1
# 2           1
# 3           1
# 4           2

# %%
greece_gdf.drop(columns = ['lau1_centroid',	'lau1_rpoint', 'index_right', 'CNTR_CODE', 'CNTR_NAME', 'NUTS1_LATN', 'NUTS2_LATN', 'NUTS3_LATN'], inplace = True)

# %%
greece_gdf.set_geometry('lau1_geom', inplace = True)
greece_grid.set_geometry('geometry', inplace = True)

# %%
greece_gdf = greece_gdf.to_crs(epsg=4326)
greece_grid = greece_grid.to_crs(epsg=4326)

# %%
greece_gdf_sub = greece_gdf[greece_gdf['NUTS2_ID'] == 'EL51'].copy()
greece_gdf_sub.reset_index(drop=True, inplace=True)

# %%
greece_grid.head()
# Out:
#           x         y  cell_number dt_placement NUTS2_ID  year  month  \
# 0  23.65882  41.33542            0   2018-01-01     EL51  2018      1
# 1  23.65882  41.33542            0   2018-01-02     EL51  2018      1
# 2  23.65882  41.33542            0   2018-01-03     EL51  2018      1
# 3  23.65882  41.33542            0   2018-01-04     EL51  2018      1
# 4  23.65882  41.33542            0   2018-01-05     EL51  2018      1
#
#        ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  \
# 0  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278  -0.063395
# 1  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278  -0.063395
# 2  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278  -0.063395
# 3  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278  -0.063395
# 4  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278  -0.063395
#
#    ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  lst_night  \
# 0   -0.07278  0.097993   0.05541  0.113606   0.05541  14093.0    13642.0
# 1   -0.07278  0.097993   0.05541  0.113606   0.05541  13931.0    13642.0
# 2   -0.07278  0.097993   0.05541  0.113606   0.05541  13783.0    13488.0
# 3   -0.07278  0.097993   0.05541  0.113606   0.05541  13783.0    13515.0
# 4   -0.07278  0.097993   0.05541  0.113606   0.05541  13783.0    13515.0
#
#    rainfall  day  lst_day_jan_mean  lst_night_jan_mean  lst_day_feb_mean  \
# 0  0.000000    1      13877.354839        13637.354839      13989.714286
# 1  2.953801    2      13877.354839        13637.354839      13989.714286
# 2  0.000000    3      13877.354839        13637.354839      13989.714286
# 3  3.852192    4      13877.354839        13637.354839      13989.714286
# 4  0.000000    5      13877.354839        13637.354839      13989.714286
#
#    lst_night_feb_mean  lst_day_mar_mean  lst_night_mar_mean  lst_day_apr_mean  \
# 0        13643.392857      14153.612903        13769.354839           14733.7
# 1        13643.392857      14153.612903        13769.354839           14733.7
# 2        13643.392857      14153.612903        13769.354839           14733.7
# 3        13643.392857      14153.612903        13769.354839           14733.7
# 4        13643.392857      14153.612903        13769.354839           14733.7
#
#    lst_night_apr_mean  acc_rainfall_1week  acc_rainfall_2week  \
# 0             14052.0            0.000000            0.000000
# 1             14052.0            2.953801            2.953801
# 2             14052.0            2.953801            2.953801
# 3             14052.0            6.805993            6.805993
# 4             14052.0            6.805993            6.805993
#
#    acc_rainfall_month  acc_rainfall_jan                   geometry
# 0            0.000000          0.000000  POINT (23.65882 41.33542)
# 1            2.953801          2.953801  POINT (23.65882 41.33542)
# 2            2.953801          2.953801  POINT (23.65882 41.33542)
# 3            6.805993          6.805993  POINT (23.65882 41.33542)
# 4            6.805993          6.805993  POINT (23.65882 41.33542)

# %%
greece_gdf_sub.head()
# Out:
#          LAU1_NAME                                          lau1_geom  \
# 0          Αβδήρων  MULTIPOLYGON (((25.11115 41.00509, 25.11129 41...
# 1  Αλεξανδρούπολης  MULTIPOLYGON (((26.02534 40.77036, 26.02556 40...
# 2         Αρριανών  POLYGON ((25.84128 41.33854, 25.84157 41.33852...
# 3     Διδυμοτείχου  POLYGON ((26.33233 41.51492, 26.33276 41.51469...
# 4          Δοξάτου  POLYGON ((24.33347 41.14739, 24.33534 41.14657...
#
#   NUTS1_ID     NUTS1_NAME NUTS2_ID                  NUTS2_NAME NUTS3_ID  \
# 0      EL5  Βόρεια Ελλάδα     EL51  Aνατολική Μακεδονία, Θράκη    EL512
# 1      EL5  Βόρεια Ελλάδα     EL51  Aνατολική Μακεδονία, Θράκη    EL511
# 2      EL5  Βόρεια Ελλάδα     EL51  Aνατολική Μακεδονία, Θράκη    EL513
# 3      EL5  Βόρεια Ελλάδα     EL51  Aνατολική Μακεδονία, Θράκη    EL511
# 4      EL5  Βόρεια Ελλάδα     EL51  Aνατολική Μακεδονία, Θράκη    EL514
#
#   NUTS3_NAME  MOUNT_TYPE  URBN_TYPE  COAST_TYPE
# 0      Ξάνθη         2.0          2           1
# 1      Έβρος         4.0          2           1
# 2     Ροδόπη         2.0          3           1
# 3      Έβρος         4.0          2           1
# 4      Δράμα         2.0          2           2

# %%
cm_grid = greece_grid.sjoin_nearest(greece_gdf, how='left', max_distance=0.01, distance_col='dist')
# Out:
# c:\Users\dimit\Python Virtual Environments\noa_eywa\Lib\site-packages\geopandas\array.py:365: UserWarning: Geometry is in a geographic CRS. Results from 'sjoin_nearest' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   warnings.warn(

# %%
cm_grid.head()
# Out:
#           x         y  cell_number dt_placement NUTS2_ID_left  year  month  \
# 0  23.65882  41.33542            0   2018-01-01          EL51  2018      1
# 1  23.65882  41.33542            0   2018-01-02          EL51  2018      1
# 2  23.65882  41.33542            0   2018-01-03          EL51  2018      1
# 3  23.65882  41.33542            0   2018-01-04          EL51  2018      1
# 4  23.65882  41.33542            0   2018-01-05          EL51  2018      1
#
#        ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  \
# 0  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278  -0.063395
# 1  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278  -0.063395
# 2  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278  -0.063395
# 3  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278  -0.063395
# 4  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278  -0.063395
#
#    ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  lst_night  \
# 0   -0.07278  0.097993   0.05541  0.113606   0.05541  14093.0    13642.0
# 1   -0.07278  0.097993   0.05541  0.113606   0.05541  13931.0    13642.0
# 2   -0.07278  0.097993   0.05541  0.113606   0.05541  13783.0    13488.0
# 3   -0.07278  0.097993   0.05541  0.113606   0.05541  13783.0    13515.0
# 4   -0.07278  0.097993   0.05541  0.113606   0.05541  13783.0    13515.0
#
#    rainfall  day  lst_day_jan_mean  lst_night_jan_mean  lst_day_feb_mean  \
# 0  0.000000    1      13877.354839        13637.354839      13989.714286
# 1  2.953801    2      13877.354839        13637.354839      13989.714286
# 2  0.000000    3      13877.354839        13637.354839      13989.714286
# 3  3.852192    4      13877.354839        13637.354839      13989.714286
# 4  0.000000    5      13877.354839        13637.354839      13989.714286
#
#    lst_night_feb_mean  lst_day_mar_mean  lst_night_mar_mean  lst_day_apr_mean  \
# 0        13643.392857      14153.612903        13769.354839           14733.7
# 1        13643.392857      14153.612903        13769.354839           14733.7
# 2        13643.392857      14153.612903        13769.354839           14733.7
# 3        13643.392857      14153.612903        13769.354839           14733.7
# 4        13643.392857      14153.612903        13769.354839           14733.7
#
#    lst_night_apr_mean  acc_rainfall_1week  acc_rainfall_2week  \
# 0             14052.0            0.000000            0.000000
# 1             14052.0            2.953801            2.953801
# 2             14052.0            2.953801            2.953801
# 3             14052.0            6.805993            6.805993
# 4             14052.0            6.805993            6.805993
#
#    acc_rainfall_month  acc_rainfall_jan                   geometry  \
# 0            0.000000          0.000000  POINT (23.65882 41.33542)
# 1            2.953801          2.953801  POINT (23.65882 41.33542)
# 2            2.953801          2.953801  POINT (23.65882 41.33542)
# 3            6.805993          6.805993  POINT (23.65882 41.33542)
# 4            6.805993          6.805993  POINT (23.65882 41.33542)
#
#    index_right         LAU1_NAME NUTS1_ID     NUTS1_NAME NUTS2_ID_right  \
# 0          129  Κάτω Νευροκοπίου      EL5  Βόρεια Ελλάδα           EL51
# 1          129  Κάτω Νευροκοπίου      EL5  Βόρεια Ελλάδα           EL51
# 2          129  Κάτω Νευροκοπίου      EL5  Βόρεια Ελλάδα           EL51
# 3          129  Κάτω Νευροκοπίου      EL5  Βόρεια Ελλάδα           EL51
# 4          129  Κάτω Νευροκοπίου      EL5  Βόρεια Ελλάδα           EL51
#
#                    NUTS2_NAME NUTS3_ID NUTS3_NAME  MOUNT_TYPE  URBN_TYPE  \
# 0  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα         2.0          2
# 1  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα         2.0          2
# 2  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα         2.0          2
# 3  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα         2.0          2
# 4  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα         2.0          2
#
#    COAST_TYPE  dist
# 0           2   0.0
# 1           2   0.0
# 2           2   0.0
# 3           2   0.0
# 4           2   0.0

# %%
describe_dataframe(cm_grid, remove_zeros=True)
# Out:
#                 Column  Missing
# 7                 ndvi   6.4314
# 8                 ndmi   6.4314
# 9                 ndwi   6.4312
# 10                ndbi   6.4314
# 11           ndvi_mean   6.2455
# 12           ndmi_mean   6.2455
# 13           ndwi_mean   6.2455
# 14           ndbi_mean   6.2996
# 15            ndvi_std   6.2455
# 16            ndmi_std   6.2455
# 17            ndwi_std   6.2455
# 18            ndbi_std   6.2996
# 19             lst_day  10.5990
# 20           lst_night   6.2047
# 23    lst_day_jan_mean   3.9192
# 24  lst_night_jan_mean   3.9192
# 25    lst_day_feb_mean   3.9192
# 26  lst_night_feb_mean   3.9192
# 27    lst_day_mar_mean   3.9192
# 28  lst_night_mar_mean   3.9192
# 29    lst_day_apr_mean   3.9192
# 30  lst_night_apr_mean   3.9192

# %%
cm_grid.columns
# Out:
# Index(['x', 'y', 'cell_number', 'dt_placement', 'NUTS2_ID_left', 'year',
#        'month', 'ndvi', 'ndmi', 'ndwi', 'ndbi', 'ndvi_mean', 'ndmi_mean',
#        'ndwi_mean', 'ndbi_mean', 'ndvi_std', 'ndmi_std', 'ndwi_std',
#        'ndbi_std', 'lst_day', 'lst_night', 'rainfall', 'day',
#        'lst_day_jan_mean', 'lst_night_jan_mean', 'lst_day_feb_mean',
#        'lst_night_feb_mean', 'lst_day_mar_mean', 'lst_night_mar_mean',
#        'lst_day_apr_mean', 'lst_night_apr_mean', 'acc_rainfall_1week',
#        'acc_rainfall_2week', 'acc_rainfall_month', 'acc_rainfall_jan',
#        'geometry', 'index_right', 'LAU1_NAME', 'NUTS1_ID', 'NUTS1_NAME',
#        'NUTS2_ID_right', 'NUTS2_NAME', 'NUTS3_ID', 'NUTS3_NAME', 'MOUNT_TYPE',
#        'URBN_TYPE', 'COAST_TYPE', 'dist'],
#       dtype='object')

# %%
cm_grid.rename(columns={'NUTS2_ID_left': 'NUTS2_ID'}, inplace=True)

# %%
new_order = ['x', 'y', 'cell_number', 'dt_placement','NUTS1_ID', 'NUTS1_NAME', 'NUTS2_ID', 'NUTS2_NAME', 'NUTS3_ID', 'NUTS3_NAME', 'LAU1_NAME', 'year', 'month',
             'ndvi', 'ndmi', 'ndwi', 'ndbi', 'ndvi_mean', 'ndmi_mean',
             'ndwi_mean', 'ndbi_mean', 'ndvi_std', 'ndmi_std', 'ndwi_std',
             'ndbi_std', 'lst_day', 'lst_night', 'rainfall', 'day',
             'lst_day_jan_mean', 'lst_night_jan_mean', 'lst_day_feb_mean',
             'lst_night_feb_mean', 'lst_day_mar_mean', 'lst_night_mar_mean',
             'lst_day_apr_mean', 'lst_night_apr_mean', 'acc_rainfall_1week',
             'acc_rainfall_2week', 'acc_rainfall_month', 'acc_rainfall_jan',
             'MOUNT_TYPE','URBN_TYPE', 'COAST_TYPE']

# %%
cm_grid = cm_grid[new_order]

# %%
cm_grid.head()
# Out:
#           x         y  cell_number dt_placement NUTS1_ID     NUTS1_NAME  \
# 0  23.65882  41.33542            0   2018-01-01      EL5  Βόρεια Ελλάδα
# 1  23.65882  41.33542            0   2018-01-02      EL5  Βόρεια Ελλάδα
# 2  23.65882  41.33542            0   2018-01-03      EL5  Βόρεια Ελλάδα
# 3  23.65882  41.33542            0   2018-01-04      EL5  Βόρεια Ελλάδα
# 4  23.65882  41.33542            0   2018-01-05      EL5  Βόρεια Ελλάδα
#
#   NUTS2_ID                  NUTS2_NAME NUTS3_ID NUTS3_NAME         LAU1_NAME  \
# 0     EL51  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα  Κάτω Νευροκοπίου
# 1     EL51  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα  Κάτω Νευροκοπίου
# 2     EL51  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα  Κάτω Νευροκοπίου
# 3     EL51  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα  Κάτω Νευροκοπίου
# 4     EL51  Aνατολική Μακεδονία, Θράκη    EL514      Δράμα  Κάτω Νευροκοπίου
#
#    year  month      ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  \
# 0  2018      1  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278
# 1  2018      1  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278
# 2  2018      1  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278
# 3  2018      1  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278
# 4  2018      1  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278
#
#    ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  \
# 0  -0.063395   -0.07278  0.097993   0.05541  0.113606   0.05541  14093.0
# 1  -0.063395   -0.07278  0.097993   0.05541  0.113606   0.05541  13931.0
# 2  -0.063395   -0.07278  0.097993   0.05541  0.113606   0.05541  13783.0
# 3  -0.063395   -0.07278  0.097993   0.05541  0.113606   0.05541  13783.0
# 4  -0.063395   -0.07278  0.097993   0.05541  0.113606   0.05541  13783.0
#
#    lst_night  rainfall  day  lst_day_jan_mean  lst_night_jan_mean  \
# 0    13642.0  0.000000    1      13877.354839        13637.354839
# 1    13642.0  2.953801    2      13877.354839        13637.354839
# 2    13488.0  0.000000    3      13877.354839        13637.354839
# 3    13515.0  3.852192    4      13877.354839        13637.354839
# 4    13515.0  0.000000    5      13877.354839        13637.354839
#
#    lst_day_feb_mean  lst_night_feb_mean  lst_day_mar_mean  lst_night_mar_mean  \
# 0      13989.714286        13643.392857      14153.612903        13769.354839
# 1      13989.714286        13643.392857      14153.612903        13769.354839
# 2      13989.714286        13643.392857      14153.612903        13769.354839
# 3      13989.714286        13643.392857      14153.612903        13769.354839
# 4      13989.714286        13643.392857      14153.612903        13769.354839
#
#    lst_day_apr_mean  lst_night_apr_mean  acc_rainfall_1week  \
# 0           14733.7             14052.0            0.000000
# 1           14733.7             14052.0            2.953801
# 2           14733.7             14052.0            2.953801
# 3           14733.7             14052.0            6.805993
# 4           14733.7             14052.0            6.805993
#
#    acc_rainfall_2week  acc_rainfall_month  acc_rainfall_jan  MOUNT_TYPE  \
# 0            0.000000            0.000000          0.000000         2.0
# 1            2.953801            2.953801          2.953801         2.0
# 2            2.953801            2.953801          2.953801         2.0
# 3            6.805993            6.805993          6.805993         2.0
# 4            6.805993            6.805993          6.805993         2.0
#
#    URBN_TYPE  COAST_TYPE
# 0          2           2
# 1          2           2
# 2          2           2
# 3          2           2
# 4          2           2

# %%
process_greek(cm_grid, 'NUTS1_NAME')
process_greek(cm_grid, 'NUTS2_NAME')
process_greek(cm_grid, 'NUTS3_NAME')
process_greek(cm_grid, 'LAU1_NAME')

# %%
cm_grid.head()
# Out:
#           x         y  cell_number dt_placement NUTS1_ID     NUTS1_NAME  \
# 0  23.65882  41.33542            0   2018-01-01      EL5  βορεια ελλαδα
# 1  23.65882  41.33542            0   2018-01-02      EL5  βορεια ελλαδα
# 2  23.65882  41.33542            0   2018-01-03      EL5  βορεια ελλαδα
# 3  23.65882  41.33542            0   2018-01-04      EL5  βορεια ελλαδα
# 4  23.65882  41.33542            0   2018-01-05      EL5  βορεια ελλαδα
#
#   NUTS2_ID                  NUTS2_NAME NUTS3_ID NUTS3_NAME         LAU1_NAME  \
# 0     EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  κατω νευροκοπιου
# 1     EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  κατω νευροκοπιου
# 2     EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  κατω νευροκοπιου
# 3     EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  κατω νευροκοπιου
# 4     EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα  κατω νευροκοπιου
#
#    year  month      ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  \
# 0  2018      1  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278
# 1  2018      1  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278
# 2  2018      1  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278
# 3  2018      1  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278
# 4  2018      1  0.075421  0.163148  0.062645 -0.163148   0.146046    0.07278
#
#    ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  \
# 0  -0.063395   -0.07278  0.097993   0.05541  0.113606   0.05541  14093.0
# 1  -0.063395   -0.07278  0.097993   0.05541  0.113606   0.05541  13931.0
# 2  -0.063395   -0.07278  0.097993   0.05541  0.113606   0.05541  13783.0
# 3  -0.063395   -0.07278  0.097993   0.05541  0.113606   0.05541  13783.0
# 4  -0.063395   -0.07278  0.097993   0.05541  0.113606   0.05541  13783.0
#
#    lst_night  rainfall  day  lst_day_jan_mean  lst_night_jan_mean  \
# 0    13642.0  0.000000    1      13877.354839        13637.354839
# 1    13642.0  2.953801    2      13877.354839        13637.354839
# 2    13488.0  0.000000    3      13877.354839        13637.354839
# 3    13515.0  3.852192    4      13877.354839        13637.354839
# 4    13515.0  0.000000    5      13877.354839        13637.354839
#
#    lst_day_feb_mean  lst_night_feb_mean  lst_day_mar_mean  lst_night_mar_mean  \
# 0      13989.714286        13643.392857      14153.612903        13769.354839
# 1      13989.714286        13643.392857      14153.612903        13769.354839
# 2      13989.714286        13643.392857      14153.612903        13769.354839
# 3      13989.714286        13643.392857      14153.612903        13769.354839
# 4      13989.714286        13643.392857      14153.612903        13769.354839
#
#    lst_day_apr_mean  lst_night_apr_mean  acc_rainfall_1week  \
# 0           14733.7             14052.0            0.000000
# 1           14733.7             14052.0            2.953801
# 2           14733.7             14052.0            2.953801
# 3           14733.7             14052.0            6.805993
# 4           14733.7             14052.0            6.805993
#
#    acc_rainfall_2week  acc_rainfall_month  acc_rainfall_jan  MOUNT_TYPE  \
# 0            0.000000            0.000000          0.000000         2.0
# 1            2.953801            2.953801          2.953801         2.0
# 2            2.953801            2.953801          2.953801         2.0
# 3            6.805993            6.805993          6.805993         2.0
# 4            6.805993            6.805993          6.805993         2.0
#
#    URBN_TYPE  COAST_TYPE
# 0          2           2
# 1          2           2
# 2          2           2
# 3          2           2
# 4          2           2

# %%
cm_grid.to_csv(r'E:\Drive\NOA\MBD-Prediction\Grid Level\data\Thrace\GR_Thrace_Timeline_GRID_2018-2020_filled_mean_rain_shp.csv', encoding=enc, index = False)
