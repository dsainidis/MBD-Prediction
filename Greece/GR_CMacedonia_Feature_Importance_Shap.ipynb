# %%
import numpy as np
import pandas as pd
import random
import math
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import KNNImputer
from imblearn.under_sampling import NearMiss 
from imblearn.over_sampling import BorderlineSMOTE
from sklearn.model_selection import train_test_split
import shap
import sys

sys.path.insert(0, "../Modules")

pd.set_option('display.max_columns', None)
random.seed(0)
np.random.seed(0)

from utils import *

# %%
NUTS0 = 'GR'
NUTS2 = 'CMacedonia'

# %%
f = open(f"data/{NUTS0}_WNV_{NUTS2}_cases_dates.txt", "r")
print(f.read())
# Out:
# months: 6, 7, 8, 9, 10,
# years: 2010, 2011, 2012, 2013, 2018, 2019, 2020, 2021,

# %%
r_u = 0.05
near_u = 0.25
smote = 1
scaler = 'minmax'
#years_to_remove = [year for year in range(2012, 2018)]
years_to_remove = []
path = f'data/{NUTS0}_{NUTS2}_WNV_Dataset_2010_2021.csv'

# %%
dataset = read_data(path, exclude_years = years_to_remove)
dataset.head()
# Out:
#           x         y dt_placement                 nuts2  \
# 0  24.12740  40.28807   2010-01-01  κεντρικης μακεδονιας
# 1  22.41314  40.63121   2010-01-01  κεντρικης μακεδονιας
# 2  22.07467  40.99173   2010-01-01  κεντρικης μακεδονιας
# 3  22.89198  40.65603   2010-01-01  κεντρικης μακεδονιας
# 4  23.97067  40.91960   2010-01-01  κεντρικης μακεδονιας
#
#                     lau1  lau1_id  day  month  week  year   day_sin  day_cos  \
# 0                   αθως       28    1      1    53  2010  0.201299  0.97953
# 1           αλεξανδρειας        7    1      1    53  2010  0.201299  0.97953
# 2               αλμωπιας       13    1      1    53  2010  0.201299  0.97953
# 3  αμπελοκηπων μενεμενης       17    1      1    53  2010  0.201299  0.97953
# 4              αμφιπολης       35    1      1    53  2010  0.201299  0.97953
#
#    month_sin  month_cos      week_sin  week_cos   area  population  \
# 0        0.5   0.866025 -2.449294e-16       1.0    NaN         NaN
# 1        0.5   0.866025 -2.449294e-16       1.0  478.8     38293.0
# 2        0.5   0.866025 -2.449294e-16       1.0  985.8     24924.0
# 3        0.5   0.866025 -2.449294e-16       1.0    9.8     49674.0
# 4        0.5   0.866025 -2.449294e-16       1.0  411.8      7169.0
#
#    population_density  eq_distance  ndvi  ndmi  ndwi  ndbi  ndvi_mean  \
# 0                 NaN     46.96020   NaN   NaN   NaN   NaN        NaN
# 1                86.8     46.40306   NaN   NaN   NaN   NaN        NaN
# 2                28.0     46.55763   NaN   NaN   NaN   NaN        NaN
# 3              5319.1     46.65786   NaN   NaN   NaN   NaN        NaN
# 4                22.3     47.42369   NaN   NaN   NaN   NaN        NaN
#
#    ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  \
# 0        NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 1        NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 2        NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 3        NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 4        NaN        NaN        NaN       NaN       NaN       NaN       NaN
#
#          lst    lst_day  lst_night  lst_jan_day_mean  lst_jan_night_mean  \
# 0  12.642500  15.530000   9.755000         10.633286            6.832500
# 1   9.705000  12.360000   7.050000          6.907708            4.406161
# 2   7.388182   9.579091   5.197273          3.313442            2.001560
# 3  11.180000  13.470000   8.890000         12.730000            5.510000
# 4  10.135000  12.090000   8.180000          8.143000            3.953714
#
#    lst_feb_day_mean  lst_feb_night_mean  lst_mar_day_mean  lst_mar_night_mean  \
# 0          8.883182            3.811746         13.083628            6.037902
# 1         10.730556            1.957517         19.149590            4.396618
# 2          3.998298            0.826676         11.100321            2.044771
# 3          9.853333            3.612000         18.272222            6.046667
# 4         10.209315            2.185636         15.249258            3.555705
#
#    lst_apr_day_mean  lst_apr_night_mean  acc_rainfall_1week  \
# 0         16.634859            8.565833           34.075000
# 1         28.020071            9.308866           14.800000
# 2         19.138418            5.884069           20.218182
# 3         26.770000           11.750000           15.000000
# 4         20.722821            8.455035           20.225000
#
#    acc_rainfall_2week  acc_rainfall_jan  distance_to_coast  distance_to_river  \
# 0           97.500000          0.575000         741.395353        5480.994362
# 1           40.250000          0.000000       19302.853155         218.518170
# 2           39.590909          0.045455       23100.611480         687.499343
# 3           39.900000          0.000000         783.725557        1072.158690
# 4           29.825000          0.000000       16692.000632         304.097354
#
#    slope_mean_1km  aspect_mean_200m  elevation_mean_1km  hillshade_mean_1km  \
# 0               0        229.615930          142.067691          199.028237
# 1               4        165.845298            4.439405          180.217997
# 2               0        127.752566          125.810202          179.704207
# 3               3        157.852939            3.721570          180.299131
# 4               4        255.084988          347.388991          187.472171
#
#      fs_area_1km  flow_accu_200m  mosq_pred  mosq_previous  case
# 0  134451.168165        1.385666          1              0     0
# 1       0.000000      252.542758          1              0     0
# 2       0.000000        1.162002          1              0     0
# 3       0.000000       56.126569          3              0     0
# 4       0.000000       20.820754          1              0     0

# %%
dataset = dataset.query('month >= 6 & month <= 10')
dataset.reset_index(inplace=True, drop=True)

# %%
dsc = dataframe_describe(dataset)
dsc.head(15)
# Out:
#     year non-case case total percentage
# 0   2010      301  250   551     11.07%
# 1   2011      366   31   397      7.98%
# 2   2012      371   20   391      7.86%
# 3   2013      373   21   394      7.92%
# 4   2014      390    0   390      7.84%
# 5   2015      390    0   390      7.84%
# 6   2016      390    0   390      7.84%
# 7   2017      390    0   390      7.84%
# 8   2018      321  117   438      8.80%
# 9   2019      354   53   407      8.18%
# 10  2020      333   93   426      8.56%
# 11  2021      365   47   412      8.28%

# %%
X_train = dataset.select_dtypes(exclude=['object']).drop(columns = ['case'])
y_train = dataset['case']

features = X_train.columns

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)

imputer = KNNImputer()
X_train = imputer.fit_transform(X_train)

try:
    class_0_counts = y_train.value_counts()[0]
except KeyError:
    class_0_counts = 0
try:
    class_1_counts = y_train.value_counts()[1]
except KeyError:
    class_1_counts = 0
        
if (near_u != 0):
    nm = NearMiss(sampling_strategy = {0: math.ceil(class_0_counts * (1 - near_u)), 1: class_1_counts}, version = 1, n_jobs = -1)
    X_train, y_train = nm.fit_resample(X_train, y_train)
    
if (smote != 0):
    class_0_counts = y_train.value_counts()[0]
    sm = BorderlineSMOTE(sampling_strategy = {0: class_0_counts, 1: math.ceil(class_1_counts * (1 + smote))}, n_jobs = -1, random_state = 0)
    X_train, y_train = sm.fit_resample(X_train, y_train)

w0,w1 = calculate_weights(y_train)

model = LogisticRegression(max_iter = 1000, class_weight = {0.0: w0, 1.0:w1}, n_jobs = -1, random_state = 0)
model.fit(X_train, y_train)

masker = shap.maskers.Independent(data = X_train)
explainer = shap.LinearExplainer(model, masker = masker)
shap_values = explainer.shap_values(X_train)

# %%
shap.summary_plot(shap_values, features = X_train, feature_names = features)

# %%
shap.summary_plot(shap_values, features = X_train, feature_names = features, plot_type='bar')

# %%
mean_shap_values = shap_values.mean(axis=0)

# %%
ft_importance = pd.DataFrame()

for i in range(len(features)):
    ft_importance = ft_importance.append({'Feature': features[i],
                                          'Shap': mean_shap_values[i]}, ignore_index = True)

# %%
ft_importance.sort_values(by='Shap', key=pd.Series.abs, inplace = True, ascending = False)

# %%
ft_importance
# Out:
#                Feature      Shap
# 12            week_cos  0.129339
# 9            month_sin -0.103027
# 33  lst_jan_night_mean -0.090135
# 1                    y  0.089587
# 11            week_sin -0.086183
# 13                area  0.058171
# 6                 year  0.056909
# 42    acc_rainfall_jan  0.051286
# 2              lau1_id -0.049007
# 4                month -0.030963
# 49         fs_area_1km  0.026553
# 50      flow_accu_200m  0.022442
# 44   distance_to_river -0.019535
# 14          population  0.018430
# 35  lst_feb_night_mean  0.018368
# 10           month_cos  0.016137
# 34    lst_feb_day_mean -0.012505
# 48  hillshade_mean_1km -0.011905
# 5                 week -0.011420
# 38    lst_apr_day_mean  0.010715
# 36    lst_mar_day_mean -0.010453
# 46    aspect_mean_200m  0.010035
# 17                ndvi -0.009870
# 16         eq_distance  0.009828
# 37  lst_mar_night_mean  0.009798
# 32    lst_jan_day_mean -0.009123
# 22           ndmi_mean -0.006250
# 24           ndbi_mean -0.006185
# 23           ndwi_mean  0.006142
# 39  lst_apr_night_mean  0.005146
# 43   distance_to_coast  0.004619
# 45      slope_mean_1km  0.004600
# 47  elevation_mean_1km  0.004597
# 20                ndbi  0.004477
# 18                ndmi  0.004386
# 8              day_cos  0.004270
# 7              day_sin  0.004270
# 3                  day  0.004024
# 52       mosq_previous -0.003658
# 15  population_density  0.003050
# 0                    x  0.002139
# 28            ndbi_std  0.001682
# 26            ndmi_std  0.001682
# 19                ndwi  0.001549
# 21           ndvi_mean -0.001324
# 27            ndwi_std  0.001157
# 31           lst_night -0.001079
# 29                 lst  0.000358
# 30             lst_day -0.000289
# 40  acc_rainfall_1week  0.000277
# 25            ndvi_std -0.000169
# 51           mosq_pred -0.000131
# 41  acc_rainfall_2week  0.000057

# %%
mean_shap = ft_importance['Shap']
shp = mean_shap.shape[0]
mean_shap = mean_shap.to_numpy().reshape(1,shp)

# %%
plot_feature_importance(mean_shap, ft_importance['Feature'], x_label = 'Mean Shap', title = f'{NUTS2} Feature Importance (all years)', title_size=18)

# %%
plot_feature_importance(mean_shap, ft_importance['Feature'], top=15, x_label = 'Mean Shap', figure_size=(8,5))
