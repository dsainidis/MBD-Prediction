# %%
import pandas as pd
import datetime
import math
import numpy as np
import missingno
import json
from statistics import mean
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
import sys

sys.path.insert(0, "../Mamoth Modules")
sys.path.insert(0, "../Modules")

from preprocessing_utils import *

from Preprocessing_Module import read_data, select_columns, reshape_dataset
from Initializer_Module import initializer
from Neural_Network_Module import Dataset, transformations, FeedforwardNeuralNetModel, train_nn, give_predictions
from Model_Validation_Module import validation_plots, metrics

enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 10
# Out:
# c:\Users\dimit\AppData\Local\Programs\Python\Python39\lib\site-packages\geopandas\_compat.py:112: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %%
NUTS0 = 'GR'
NUTS2 = 'CMacedonia'
NUTS2_EL = 'κεντρικης μακεδονιας'

# %%
shape_file = pd.read_csv(f'data/{NUTS0}_{NUTS2}_Timeline_Biweekly_2022_filled.csv', encoding=enc)
wnv_file = pd.read_csv(f'data/{NUTS0}_{NUTS2}_WNV_Timeline_2022.csv', encoding=enc)

# %%
shape_file.head()
# Out:
#            lau1                region         x         y dt_placement  year  \
# 0  αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2022-01-01  2022
# 1  αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2022-01-16  2022
# 2  αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2022-01-01  2022
# 3  αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2022-01-16  2022
# 4  αλεξανδρειας  κεντρικης μακεδονιας  22.48988  40.62222   2022-01-01  2022
#
#    month indices_image_date  indices_lat  indices_lon  ndvi_new  ndmi_new  \
# 0      1         2022-01-30    40.659996    22.397246       NaN       NaN
# 1      1         2022-01-15    40.659996    22.397246  0.142113  0.034418
# 2      1         2022-01-30    40.677962    22.464619       NaN       NaN
# 3      1         2022-01-15    40.677962    22.464619  0.076590 -0.163135
# 4      1         2022-01-30    40.624063    22.491569       NaN       NaN
#
#    ndwi_new  ndbi_new  ndvi_mean_new  ndmi_mean_new  ndwi_mean_new  \
# 0       NaN       NaN            NaN            NaN            NaN
# 1 -0.080788 -0.034418       0.145660       0.038404      -0.081313
# 2       NaN       NaN            NaN            NaN            NaN
# 3 -0.077990  0.163135      -0.022336       0.409936       0.003850
# 4       NaN       NaN            NaN            NaN            NaN
#
#    ndbi_mean_new  ndvi_std_new  ndmi_std_new  ndwi_std_new  ndbi_std_new  \
# 0            NaN           NaN           NaN           NaN           NaN
# 1      -0.038404      0.078844      0.047882      0.070993      0.047882
# 2            NaN           NaN           NaN           NaN           NaN
# 3      -0.409936      0.000000      0.000000      0.000000      0.000000
# 4            NaN           NaN           NaN           NaN           NaN
#
#   lst_image_date    lst_lat    lst_lon  lst_day_new  lst_night_new  \
# 0     2022-01-01  40.659996  22.397246          NaN        14057.0
# 1     2022-01-16  40.659996  22.397246      14007.0        13622.0
# 2     2022-01-01  40.677962  22.464619          NaN        14024.0
# 3     2022-01-16  40.677962  22.464619      13967.0        13629.0
# 4     2022-01-01  40.624063  22.491569          NaN        14023.0
#
#    monthly_lst_lat  monthly_lst_lon  lst_jan_day_mean_new  \
# 0        40.659996        22.397246          14131.687500
# 1        40.659996        22.397246          14131.687500
# 2        40.677962        22.464619          14030.071429
# 3        40.677962        22.464619          14030.071429
# 4        40.624063        22.491569          14056.294118
#
#    lst_jan_night_mean_new  lst_feb_day_mean_new  lst_feb_night_mean_new  \
# 0            13577.052632          14572.333333            13689.200000
# 1            13577.052632          14572.333333            13689.200000
# 2            13577.200000          14453.583333            13712.866667
# 3            13577.200000          14453.583333            13712.866667
# 4            13594.476190          14382.785714            13694.000000
#
#    lst_mar_day_mean_new  lst_mar_night_mean_new  lst_apr_day_mean_new  \
# 0          14624.375000              13729.6875          15343.625000
# 1          14624.375000              13729.6875          15343.625000
# 2          14550.285714              13730.3125          15255.066667
# 3          14550.285714              13730.3125          15255.066667
# 4          14483.375000              13759.6000          15223.230769
#
#    lst_apr_night_mean_new indices_image_date.1  indices_lat.1  indices_lon.1  \
# 0            14111.600000           2022-01-01      40.650186      22.350102
# 1            14111.600000           2022-01-16      40.650186      22.350102
# 2            14095.750000           2022-01-01      40.650186      22.450103
# 3            14095.750000           2022-01-16      40.650186      22.450103
# 4            14119.235294           2022-01-01      40.650186      22.450103
#
#    acc_rainfall_jan_new dt_placement_minus_7 dt_placement_minus_14  \
# 0              0.067996           2021-12-25            2021-12-18
# 1             44.292047           2022-01-09            2022-01-02
# 2              0.142430           2021-12-25            2021-12-18
# 3            117.033710           2022-01-09            2022-01-02
# 4              0.142430           2021-12-25            2021-12-18
#
#   dt_placement_minus_7_avail dt_placement_minus_14_avail  \
# 0                 2022-12-16                  2022-12-16
# 1                 2022-01-09                  2022-01-02
# 2                 2022-12-16                  2022-12-16
# 3                 2022-01-09                  2022-01-02
# 4                 2022-12-16                  2022-12-16
#
#    acc_rainfall_1week_new  acc_rainfall_2week_new
# 0                0.067996                0.067996
# 1               44.220266               44.224051
# 2                0.142430                0.142430
# 3              116.890733              116.891279
# 4                0.142430                0.142430

# %%
wnv_file.head()
# Out:
#            lau1                 nuts2 dt_placement  case
# 0  αλεξανδρειας  κεντρικης μακεδονιας   2022-07-01     0
# 1  αλεξανδρειας  κεντρικης μακεδονιας   2022-07-16     0
# 2  αλεξανδρειας  κεντρικης μακεδονιας   2022-08-01     1
# 3  αλεξανδρειας  κεντρικης μακεδονιας   2022-08-16     3
# 4  αλεξανδρειας  κεντρικης μακεδονιας   2022-09-01     2

# %%
shape_file.rename(columns={"region": "nuts2"}, inplace=True)

# %%
process_greek(shape_file, 'lau1')
process_greek(shape_file, 'nuts2')

# %%
shape_file = shape_file.rename(columns=lambda x: re.sub('_new', '', x))

# %%
shape_file.drop(columns=['indices_image_date', 'indices_lat', 'indices_lon' , 'lst_image_date', 'lst_lat','lst_lon' ,'monthly_lst_lat', 'monthly_lst_lon', 
                         'indices_image_date.1', 'indices_lat.1', 'indices_lon.1', 'dt_placement_minus_7', 'dt_placement_minus_14', 'dt_placement_minus_7_avail',
                         'dt_placement_minus_14_avail'], inplace = True)

# %%
shape_file.head(5)
# Out:
#            lau1                 nuts2         x         y dt_placement  year  \
# 0  αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2022-01-01  2022
# 1  αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2022-01-16  2022
# 2  αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2022-01-01  2022
# 3  αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2022-01-16  2022
# 4  αλεξανδρειας  κεντρικης μακεδονιας  22.48988  40.62222   2022-01-01  2022
#
#    month      ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  \
# 0      1       NaN       NaN       NaN       NaN        NaN        NaN
# 1      1  0.142113  0.034418 -0.080788 -0.034418   0.145660   0.038404
# 2      1       NaN       NaN       NaN       NaN        NaN        NaN
# 3      1  0.076590 -0.163135 -0.077990  0.163135  -0.022336   0.409936
# 4      1       NaN       NaN       NaN       NaN        NaN        NaN
#
#    ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  \
# 0        NaN        NaN       NaN       NaN       NaN       NaN      NaN
# 1  -0.081313  -0.038404  0.078844  0.047882  0.070993  0.047882  14007.0
# 2        NaN        NaN       NaN       NaN       NaN       NaN      NaN
# 3   0.003850  -0.409936  0.000000  0.000000  0.000000  0.000000  13967.0
# 4        NaN        NaN       NaN       NaN       NaN       NaN      NaN
#
#    lst_night  lst_jan_day_mean  lst_jan_night_mean  lst_feb_day_mean  \
# 0    14057.0      14131.687500        13577.052632      14572.333333
# 1    13622.0      14131.687500        13577.052632      14572.333333
# 2    14024.0      14030.071429        13577.200000      14453.583333
# 3    13629.0      14030.071429        13577.200000      14453.583333
# 4    14023.0      14056.294118        13594.476190      14382.785714
#
#    lst_feb_night_mean  lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  \
# 0        13689.200000      14624.375000          13729.6875      15343.625000
# 1        13689.200000      14624.375000          13729.6875      15343.625000
# 2        13712.866667      14550.285714          13730.3125      15255.066667
# 3        13712.866667      14550.285714          13730.3125      15255.066667
# 4        13694.000000      14483.375000          13759.6000      15223.230769
#
#    lst_apr_night_mean  acc_rainfall_jan  acc_rainfall_1week  \
# 0        14111.600000          0.067996            0.067996
# 1        14111.600000         44.292047           44.220266
# 2        14095.750000          0.142430            0.142430
# 3        14095.750000        117.033710          116.890733
# 4        14119.235294          0.142430            0.142430
#
#    acc_rainfall_2week
# 0            0.067996
# 1           44.224051
# 2            0.142430
# 3          116.891279
# 4            0.142430

# %%
wnv_file.head(5)
# Out:
#            lau1                 nuts2 dt_placement  case
# 0  αλεξανδρειας  κεντρικης μακεδονιας   2022-07-01     0
# 1  αλεξανδρειας  κεντρικης μακεδονιας   2022-07-16     0
# 2  αλεξανδρειας  κεντρικης μακεδονιας   2022-08-01     1
# 3  αλεξανδρειας  κεντρικης μακεδονιας   2022-08-16     3
# 4  αλεξανδρειας  κεντρικης μακεδονιας   2022-09-01     2

# %%
## Find if there are lau1 units in the epidemiological file and are not contained in the spatiotemporal file.

names_from_wnv_file = wnv_file["lau1"].drop_duplicates().sort_values().tolist()
names_from_shapefile = shape_file["lau1"].drop_duplicates().sort_values().tolist()
diff = []

for element in names_from_wnv_file:
    if element not in names_from_shapefile:
        diff.append(element)
        

print(f"{diff}\n\nLength: {len(diff)}")
# Out:
# ['ηρωικης πολεως ναουσας']
#
# Length: 1

# %%
wnv_file['lau1'] = wnv_file['lau1'].apply(lambda x : x.replace('ηρωικης πολεως ναουσας','ναουσας'))

# %%
## Check again

names_from_wnv_file = wnv_file["lau1"].drop_duplicates().sort_values().tolist()
names_from_shapefile = shape_file["lau1"].drop_duplicates().sort_values().tolist()
diff = []

for element in names_from_wnv_file:
    if element not in names_from_shapefile:
        diff.append(element)
        

print(f"{diff}\n\nLength: {len(diff)}")
# Out:
# []
#
# Length: 0

# %%
merged = shape_file.merge(wnv_file, how='left', on=['dt_placement', 'lau1', 'nuts2'] )

# %%
merged
# Out:
#               lau1                 nuts2         x         y dt_placement  \
# 0     αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2022-01-01
# 1     αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2022-01-16
# 2     αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2022-01-01
# 3     αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2022-01-16
# 4     αλεξανδρειας  κεντρικης μακεδονιας  22.48988  40.62222   2022-01-01
# ...            ...                   ...       ...       ...          ...
# 4315    χαλκηδονος  κεντρικης μακεδονιας  22.73880  40.73560   2022-12-16
# 4316  ωραιοκαστρου  κεντρικης μακεδονιας  22.94073  40.74476   2022-12-01
# 4317  ωραιοκαστρου  κεντρικης μακεδονιας  22.94073  40.74476   2022-12-16
# 4318  ωραιοκαστρου  κεντρικης μακεδονιας  22.94073  40.79866   2022-12-01
# 4319  ωραιοκαστρου  κεντρικης μακεδονιας  22.94073  40.79866   2022-12-16
#
#       year  month      ndvi      ndmi      ndwi      ndbi  ndvi_mean  \
# 0     2022      1       NaN       NaN       NaN       NaN        NaN
# 1     2022      1  0.142113  0.034418 -0.080788 -0.034418   0.145660
# 2     2022      1       NaN       NaN       NaN       NaN        NaN
# 3     2022      1  0.076590 -0.163135 -0.077990  0.163135  -0.022336
# 4     2022      1       NaN       NaN       NaN       NaN        NaN
# ...    ...    ...       ...       ...       ...       ...        ...
# 4315  2022     12  0.114680 -0.217958 -0.170179  0.217958   0.130997
# 4316  2022     12  0.579832  0.212192 -0.453268 -0.212192   0.458220
# 4317  2022     12  0.579832  0.212192 -0.453268 -0.212192   0.458220
# 4318  2022     12  0.306598 -0.064526 -0.273644  0.064526   0.233045
# 4319  2022     12  0.306598 -0.064526 -0.273644  0.064526   0.233045
#
#       ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  \
# 0           NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 1      0.038404  -0.081313  -0.038404  0.078844  0.047882  0.070993  0.047882
# 2           NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 3      0.409936   0.003850  -0.409936  0.000000  0.000000  0.000000  0.000000
# 4           NaN        NaN        NaN       NaN       NaN       NaN       NaN
# ...         ...        ...        ...       ...       ...       ...       ...
# 4315  -0.214337  -0.178496   0.214337  0.012815  0.018021  0.007255  0.018021
# 4316   0.113062  -0.366387  -0.113062  0.069645  0.064833  0.052248  0.064833
# 4317   0.113062  -0.366387  -0.113062  0.069645  0.064833  0.052248  0.064833
# 4318  -0.132934  -0.238670   0.132934  0.071058  0.048331  0.039217  0.048331
# 4319  -0.132934  -0.238670   0.132934  0.071058  0.048331  0.039217  0.048331
#
#       lst_day  lst_night  lst_jan_day_mean  lst_jan_night_mean  \
# 0         NaN    14057.0      14131.687500        13577.052632
# 1     14007.0    13622.0      14131.687500        13577.052632
# 2         NaN    14024.0      14030.071429        13577.200000
# 3     13967.0    13629.0      14030.071429        13577.200000
# 4         NaN    14023.0      14056.294118        13594.476190
# ...       ...        ...               ...                 ...
# 4315  14452.0    13850.0      14065.684211        13661.894737
# 4316  14284.0    13905.0      13986.222222        13632.526316
# 4317  14317.0    13741.0      13986.222222        13632.526316
# 4318  14282.0    13824.0      13999.100000        13574.600000
# 4319  14257.0    13745.0      13999.100000        13574.600000
#
#       lst_feb_day_mean  lst_feb_night_mean  lst_mar_day_mean  \
# 0         14572.333333        13689.200000      14624.375000
# 1         14572.333333        13689.200000      14624.375000
# 2         14453.583333        13712.866667      14550.285714
# 3         14453.583333        13712.866667      14550.285714
# 4         14382.785714        13694.000000      14483.375000
# ...                ...                 ...               ...
# 4315      14364.333333        13768.071429      14454.800000
# 4316      14256.000000        13763.692308      14372.250000
# 4317      14256.000000        13763.692308      14372.250000
# 4318      14300.357143        13720.062500      14451.687500
# 4319      14300.357143        13720.062500      14451.687500
#
#       lst_mar_night_mean  lst_apr_day_mean  lst_apr_night_mean  \
# 0           13729.687500      15343.625000        14111.600000
# 1           13729.687500      15343.625000        14111.600000
# 2           13730.312500      15255.066667        14095.750000
# 3           13730.312500      15255.066667        14095.750000
# 4           13759.600000      15223.230769        14119.235294
# ...                  ...               ...                 ...
# 4315        13711.400000      14855.823529        14090.733333
# 4316        13748.333333      14826.437500        14105.133333
# 4317        13748.333333      14826.437500        14105.133333
# 4318        13668.117647      14861.294118        14053.000000
# 4319        13668.117647      14861.294118        14053.000000
#
#       acc_rainfall_jan  acc_rainfall_1week  acc_rainfall_2week  case
# 0             0.067996            0.067996            0.067996   NaN
# 1            44.292047           44.220266           44.224051   NaN
# 2             0.142430            0.142430            0.142430   NaN
# 3           117.033710          116.890733          116.891279   NaN
# 4             0.142430            0.142430            0.142430   NaN
# ...                ...                 ...                 ...   ...
# 4315       1032.736334            9.585400           10.057034   NaN
# 4316        977.700661           11.707804           13.303774   NaN
# 4317        985.487502            7.662622            7.786842   NaN
# 4318        977.700661           11.707804           13.303774   NaN
# 4319        985.487502            7.662622            7.786842   NaN
#
# [4320 rows x 33 columns]

# %%
merged = fillna(merged,{'case': 0})

# %%
merged['case'].value_counts()
# Out:
# 0.0    3873
# 1.0     309
# 2.0     121
# 3.0      17
# Name: case, dtype: int64

# %%
grouped = merged.groupby(['dt_placement', 'lau1', 'nuts2'], as_index = False)

# %%
dataset = grouped.mean()

# %%
dataset
# Out:
#     dt_placement                   lau1                 nuts2          x  \
# 0     2022-01-01           αλεξανδρειας  κεντρικης μακεδονιας  22.483978
# 1     2022-01-01               αλμωπιας  κεντρικης μακεδονιας  21.940791
# 2     2022-01-01  αμπελοκηπων μενεμενης  κεντρικης μακεδονιας  22.891980
# 3     2022-01-01              αμφιπολης  κεντρικης μακεδονιας  23.982527
# 4     2022-01-01             αριστοτελη  κεντρικης μακεδονιας  23.691080
# ..           ...                    ...                   ...        ...
# 907   2022-12-16               σιθωνιας  κεντρικης μακεδονιας  23.828106
# 908   2022-12-16               σιντικης  κεντρικης μακεδονιας  23.388058
# 909   2022-12-16                σκυδρας  κεντρικης μακεδονιας  22.146700
# 910   2022-12-16             χαλκηδονος  κεντρικης μακεδονιας  22.723020
# 911   2022-12-16           ωραιοκαστρου  κεντρικης μακεδονιας  22.940730
#
#              y    year  month      ndvi      ndmi      ndwi      ndbi  \
# 0    40.644680  2022.0    1.0       NaN       NaN       NaN       NaN
# 1    40.977027  2022.0    1.0       NaN       NaN       NaN       NaN
# 2    40.656030  2022.0    1.0       NaN       NaN       NaN       NaN
# 3    40.915102  2022.0    1.0       NaN       NaN       NaN       NaN
# 4    40.495934  2022.0    1.0       NaN       NaN       NaN       NaN
# ..         ...     ...    ...       ...       ...       ...       ...
# 907  40.110264  2022.0   12.0  0.348392  0.315455 -0.175847 -0.315455
# 908  41.313484  2022.0   12.0  0.324119 -0.016353 -0.319365  0.016353
# 909  40.822940  2022.0   12.0  0.431693 -0.011406 -0.376042  0.011406
# 910  40.753567  2022.0   12.0  0.133472 -0.224825 -0.195777  0.224825
# 911  40.771710  2022.0   12.0  0.443215  0.073833 -0.363456 -0.073833
#
#      ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  \
# 0          NaN        NaN        NaN        NaN       NaN       NaN       NaN
# 1          NaN        NaN        NaN        NaN       NaN       NaN       NaN
# 2          NaN        NaN        NaN        NaN       NaN       NaN       NaN
# 3          NaN        NaN        NaN        NaN       NaN       NaN       NaN
# 4          NaN        NaN        NaN        NaN       NaN       NaN       NaN
# ..         ...        ...        ...        ...       ...       ...       ...
# 907   0.321459   0.284695  -0.162175  -0.284695  0.049445  0.081901  0.026801
# 908   0.319459  -0.032765  -0.317519   0.032765  0.036188  0.047272  0.029911
# 909   0.445152   0.024967  -0.382060  -0.024967  0.045625  0.040591  0.032540
# 910   0.129031  -0.192451  -0.173992   0.192451  0.009124  0.021056  0.006975
# 911   0.345633  -0.009936  -0.302529   0.009936  0.070352  0.056582  0.045733
#
#      ndbi_std       lst_day     lst_night  lst_jan_day_mean  \
# 0         NaN           NaN  14030.000000      14063.820954
# 1         NaN  14269.300000  14026.777778      13915.309398
# 2         NaN           NaN  14146.000000      14067.833333
# 3         NaN           NaN  13954.250000      13932.817503
# 4         NaN  14116.833333  13999.625000      13938.808799
# ..        ...           ...           ...               ...
# 907  0.081901  14404.400000  13924.600000      14113.254627
# 908  0.047272  14196.727273  14045.909091      13920.943024
# 909  0.040591  14386.500000  13944.500000      14107.928571
# 910  0.021056  14406.000000  13853.666667      14074.708462
# 911  0.056582  14287.000000  13743.000000      13992.661111
#
#      lst_jan_night_mean  lst_feb_day_mean  lst_feb_night_mean  \
# 0          13590.484837      14468.300595        13708.083333
# 1          13636.003976      14107.602292        13717.692280
# 2          13718.666667      14362.800000        13842.600000
# 3          13615.039474      14165.935731        13716.711538
# 4          13658.863648      14098.852751        13750.368087
# ..                  ...               ...                 ...
# 907        13746.490983      14260.784848        13859.238462
# 908        13528.460588      14177.193660        13697.943198
# 909        13637.659226      14385.648810        13763.046154
# 910        13644.743779      14357.583333        13769.619048
# 911        13603.563158      14278.178571        13741.877404
#
#      lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  \
# 0        14558.508929        13735.790625      15289.587752
# 1        14070.920095        13690.252876      14702.039802
# 2        14521.076923        13801.692308      14997.562500
# 3        14333.937255        13674.185897      14785.123575
# 4        14261.988374        13706.476705      14695.345661
# ..                ...                 ...               ...
# 907      14357.626667        13795.363590      14704.595588
# 908      14348.607324        13661.292154      14753.370364
# 909      14538.080420        13729.107143      14910.325893
# 910      14456.141667        13726.852288      14890.659314
# 911      14411.968750        13708.225490      14843.865809
#
#      lst_apr_night_mean  acc_rainfall_jan  acc_rainfall_1week  \
# 0          14102.322794          0.113685            0.113685
# 1          13994.966620          2.557299            2.557299
# 2          14152.333333          0.000000            0.000000
# 3          14065.600000          0.417504            0.417504
# 4          14077.126151          0.000000            0.000000
# ..                  ...               ...                 ...
# 907        14148.220476       1495.600132           12.732685
# 908        14043.566767        851.593307            2.938464
# 909        14065.906593       1035.991965            3.440041
# 910        14100.306944       1032.736334            9.585400
# 911        14079.066667        985.487502            7.662622
#
#      acc_rainfall_2week  case
# 0              0.113685   0.0
# 1              2.557299   0.0
# 2              0.000000   0.0
# 3              0.417504   0.0
# 4              0.000000   0.0
# ..                  ...   ...
# 907           13.911125   0.0
# 908            2.989762   0.0
# 909            3.728177   0.0
# 910           10.057034   0.0
# 911            7.786842   0.0
#
# [912 rows x 33 columns]

# %%
dataset = dataset.astype({'case': 'int'})

# %%
dataset['dt_placement'] = pd.to_datetime(dataset['dt_placement'])

# %%
dataset['x'] = dataset['x'].apply(lambda x : round(x,5))
dataset['y'] = dataset['y'].apply(lambda x : round(x,5))
dataset['day'] = dataset['dt_placement'].apply(lambda x : x.day)
dataset['month'] = dataset['dt_placement'].apply(lambda x : x.month)
dataset['year'] = dataset['dt_placement'].apply(lambda x : x.year)
dataset['week'] = dataset.apply(lambda row: datetime.date(int(row['year']), int(row['month']), int(row['day'])).isocalendar().week, axis=1)

# %%
lau1_map = lau1_mapping(dataset, 0, 0)

# %%
with open(f'data/{NUTS0}_WNV_{NUTS2}_LAU1_mapping_2022.json', 'w', encoding=enc) as file:
     json.dump(lau1_map,file,sort_keys=True, indent=4, ensure_ascii=False)

# %%
dataset["lau1_id"] = dataset["lau1"].map(lau1_map)

dataset = encode_cyclical(dataset, 'day', 31)
dataset = encode_cyclical(dataset, 'month', 12)
dataset = encode_cyclical(dataset, 'week', 53)

# %%
dataset
# Out:
#     dt_placement                   lau1                 nuts2         x  \
# 0     2022-01-01           αλεξανδρειας  κεντρικης μακεδονιας  22.48398
# 1     2022-01-01               αλμωπιας  κεντρικης μακεδονιας  21.94079
# 2     2022-01-01  αμπελοκηπων μενεμενης  κεντρικης μακεδονιας  22.89198
# 3     2022-01-01              αμφιπολης  κεντρικης μακεδονιας  23.98253
# 4     2022-01-01             αριστοτελη  κεντρικης μακεδονιας  23.69108
# ..           ...                    ...                   ...       ...
# 907   2022-12-16               σιθωνιας  κεντρικης μακεδονιας  23.82811
# 908   2022-12-16               σιντικης  κεντρικης μακεδονιας  23.38806
# 909   2022-12-16                σκυδρας  κεντρικης μακεδονιας  22.14670
st_mar_night_mean  lst_apr_day_mean  lst_apr_night_mean  \
# 0          13735.790625      15289.587752        14102.322794
# 1          13690.252876      14702.039802        13994.966620
# 2          13801.692308      14997.562500        14152.333333
# 3          13674.185897      14785.123575        14065.600000
# 4          13706.476705      14695.345661        14077.126151
# ..                  ...               ...                 ...
# 907        13795.363590      14704.595588        14148.220476
# 908        13661.292154      14753.370364        14043.566767
# 909        13729.107143      14910.325893        14065.906593
# 910        13726.852288      14890.659314        14100.306944
# 911        13708.225490      14843.865809        14079.066667
#
#      acc_rainfall_jan  acc_rainfall_1week  acc_rainfall_2week  case  day  \
# 0            0.113685            0.113685            0.113685     0    1
# 1            2.557299            2.557299            2.557299     0    1
# 2            0.000000            0.000000            0.000000     0    1
# 3            0.417504            0.417504            0.417504     0    1
# 4            0.000000            0.000000            0.000000     0    1
# ..                ...                 ...                 ...   ...  ...
# 907       1495.600132           12.732685           13.911125     0   16
# 908        851.593307            2.938464            2.989762     0   16
# 909       1035.991965            3.440041            3.728177     0   16
# 910       1032.736334            9.585400           10.057034     0   16
# 911        985.487502            7.662622            7.786842     0   16
#
#      week  eq_distance  lau1_id   day_sin   day_cos     month_sin  month_cos  \
# 0      52     46.44911        8  0.201299  0.979530  5.000000e-01   0.866025
# 1      52     46.48134        9  0.201299  0.979530  5.000000e-01   0.866025
# 2      52     46.65786       17  0.201299  0.979530  5.000000e-01   0.866025
# 3      52     47.42581       33  0.201299  0.979530  5.000000e-01   0.866025
# 4      52     46.91682       27  0.201299  0.979530  5.000000e-01   0.866025
# ..    ...          ...      ...       ...       ...           ...        ...
# 907    50     46.65417       16 -0.101168 -0.994869 -2.449294e-16   1.000000
# 908    50     47.47426       35 -0.101168 -0.994869 -2.449294e-16   1.000000
# 909    50     46.44339        7 -0.101168 -0.994869 -2.449294e-16   1.000000
# 910    50     46.66036       19 -0.101168 -0.994869 -2.449294e-16   1.000000
# 911    50     46.78258       26 -0.101168 -0.994869 -2.449294e-16   1.000000
#
#      week_sin  week_cos
# 0   -0.118273  0.992981
# 1   -0.118273  0.992981
# 2   -0.118273  0.992981
# 3   -0.118273  0.992981
# 4   -0.118273  0.992981
# ..        ...       ...
# 907 -0.348202  0.937420
# 908 -0.348202  0.937420
# 909 -0.348202  0.937420
# 910 -0.348202  0.937420
# 911 -0.348202  0.937420
#
# [912 rows x 43 columns]

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
df_demographics = pd.read_csv(f'data/{NUTS0}_WEB_Demographics_Processed.csv', encoding = enc)

# %%
df_demographics
# Out:
#                  lau1                             nuts2                 nuts3  \
# 0             αβδηρων  ανατολικης μακεδονιας και θρακης                ξανθης
# 1         αγαθονησιου                    νοτιου αιγαιου              καλυμνου
# 2               αγιας                         θεσσαλιας               λαρισας
# 3      αγιας βαρβαρας                           αττικης  δυτικου τομεα αθηνων
# 4    αγιας παρασκευης                           αττικης  βορειου τομεα αθηνων
# ..                ...                               ...                   ...
# 327            χανιων                            κρητης                χανιων
# 328        χερσονησου                            κρητης             ηρακλειου
# 329              χιου                   βορειου αιγαιου                  χιου
# 330      ωραιοκαστρου              κεντρικης μακεδονιας          θεσσαλονικης
# 331            ωρωπου                           αττικης    ανατολικης αττικης
#
#       area  population_density  population
# 0    352.0                54.0     17860.0
# 1     14.5                12.8       203.0
# 2    661.8                17.3     10705.0
# 3      2.4             10925.9     26759.0
# 4      7.9              7557.5     62157.0
# ..     ...                 ...         ...
# 327  351.3               309.3    110646.0
# 328  272.2                98.2     27229.0
# 329  842.3                61.0     50483.0
# 330  217.9               175.8     40114.0
# 331  338.2                99.8     33977.0
#
# [332 rows x 6 columns]

# %%
df_demographics_nuts2 = df_demographics.query(f"nuts2 == '{NUTS2_EL}'").copy()

# %%
df_demographics_nuts2.drop(columns=['nuts2', 'nuts3'], inplace=True)
df_demographics_nuts2.reset_index(inplace=True, drop=True)

# %%
df_demographics_nuts2
# Out:
#                      lau1    area  population_density  population
# 0            αλεξανδρειας   478.8                86.8     38293.0
# 1                αλμωπιας   985.8                28.0     24924.0
# 2   αμπελοκηπων μενεμενης     9.8              5319.1     49674.0
# 3               αμφιπολης   411.8                22.3      7169.0
# 4              αριστοτελη   747.0                24.5     16994.0
# ..                    ...     ...                 ...         ...
# 33               σιθωνιας   516.8                24.0     11631.0
# 34               σιντικης  1103.4                20.1     18532.0
# 35                σκυδρας   239.5                84.3     18080.0
# 36             χαλκηδονος   391.5                86.0     29951.0
# 37           ωραιοκαστρου   217.9               175.8     40114.0
#
# [38 rows x 4 columns]

# %%
names_from_merged = dataset["lau1"].drop_duplicates().sort_values().tolist()
names_from_demographics = df_demographics_nuts2["lau1"].drop_duplicates().sort_values().tolist()
diff = []

for element in names_from_merged:
    if element not in names_from_demographics:
        diff.append(element)
        

print(f"{diff}\n\nLength: {len(diff)}")
# Out:
# ['ναουσας']
#
# Length: 1

# %%
df_demographics_nuts2['lau1'] = df_demographics_nuts2['lau1'].apply(lambda x : x.replace('ηρωικης πολεως ναουσας','ναουσας'))

# %%
names_from_merged = dataset["lau1"].drop_duplicates().sort_values().tolist()
names_from_demographics = df_demographics_nuts2["lau1"].drop_duplicates().sort_values().tolist()
diff = []

for element in names_from_merged:
    if element not in names_from_demographics:
        diff.append(element)
        

print(f"{diff}\n\nLength: {len(diff)}")
# Out:
# []
#
# Length: 0

# %%
dataset = pd.merge(dataset, df_demographics_nuts2,  how='left', on=['lau1'])

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
missing = describe_dataframe(dataset)

# %%
dataset
# Out:
#     dt_placement                   lau1                 nuts2         x  \
# 0     2022-01-01           αλεξανδρειας  κεντρικης μακεδονιας  22.48398
# 1     2022-01-01               αλμωπιας  κεντρικης μακεδονιας  21.94079
# 2     2022-01-01  αμπελοκηπων μενεμενης  κεντρικης μακεδονιας  22.89198
# 3     2022-01-01              αμφιπολης  κεντρικης μακεδονιας  23.98253
# 4     2022-01-01             αριστοτελη  κεντρικης μακεδονιας  23.69108
# ..           ...                    ...                   ...       ...
# 907   2022-12-16               σιθωνιας  κεντρικης μακεδονιας  23.82811
# 908   2022-12-16               σιντικης  κεντρικης μακεδονιας  23.38806
# 909   2022-12-16                σκυδρας  κεντρικης μακεδονιας  22.14670
# 910   2022-12-16             χαλκηδονος  κεντρικης μακεδονιας  22.72302
# 911   2022-12-16           ωραιοκαστρου  κεντρικης μακεδονιας  22.94073
#
# 911        13708.225490      14843.865809        14079.066667
#
#      acc_rainfall_jan  acc_rainfall_1week  acc_rainfall_2week  case  day  \
# 0            0.113685            0.113685            0.113685     0    1
# 1            2.557299            2.557299            2.557299     0    1
# 2            0.000000            0.000000            0.000000     0    1
# 3            0.417504            0.417504            0.417504     0    1
# 4            0.000000            0.000000            0.000000     0    1
# ..                ...                 ...                 ...   ...  ...
# 907       1495.600132           12.732685           13.911125     0   16
# 908        851.593307            2.938464            2.989762     0   16
# 909       1035.991965            3.440041            3.728177     0   16
# 910       1032.736334            9.585400           10.057034     0   16
# 911        985.487502            7.662622            7.786842     0   16
#
#      week  eq_distance  lau1_id   day_sin   day_cos     month_sin  month_cos  \
# 0      52     46.44911        8  0.201299  0.979530  5.000000e-01   0.866025
# 1      52     46.48134        9  0.201299  0.979530  5.000000e-01   0.866025
# 2      52     46.65786       17  0.201299  0.979530  5.000000e-01   0.866025
# 3      52     47.42581       33  0.201299  0.979530  5.000000e-01   0.866025
# 4      52     46.91682       27  0.201299  0.979530  5.000000e-01   0.866025
# ..    ...          ...      ...       ...       ...           ...        ...
# 907    50     46.65417       16 -0.101168 -0.994869 -2.449294e-16   1.000000
# 908    50     47.47426       35 -0.101168 -0.994869 -2.449294e-16   1.000000
# 909    50     46.44339        7 -0.101168 -0.994869 -2.449294e-16   1.000000
# 910    50     46.66036       19 -0.101168 -0.994869 -2.449294e-16   1.000000
# 911    50     46.78258       26 -0.101168 -0.994869 -2.449294e-16   1.000000
#
#      week_sin  week_cos    area  population_density  population
# 0   -0.118273  0.992981   478.8                86.8     38293.0
# 1   -0.118273  0.992981   985.8                28.0     24924.0
# 2   -0.118273  0.992981     9.8              5319.1     49674.0
# 3   -0.118273  0.992981   411.8                22.3      7169.0
# 4   -0.118273  0.992981   747.0                24.5     16994.0
# ..        ...       ...     ...                 ...         ...
# 907 -0.348202  0.937420   516.8                24.0     11631.0
# 908 -0.348202  0.937420  1103.4                20.1     18532.0
# 909 -0.348202  0.937420   239.5                84.3     18080.0
# 910 -0.348202  0.937420   391.5                86.0     29951.0
# 911 -0.348202  0.937420   217.9               175.8     40114.0
#
# [912 rows x 46 columns]

# %%
mosquito_data = read_data(f'data/{NUTS0}_MSQ_culex_2011-2022_processed.csv')
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
mosquito_data.nuts2.unique()
# Out:
# array(['CENTRAL MACEDONIA', 'THESSALY', 'CRETE', 'WESTERN GREECE'],
#       dtype=object)

# %%
mosquito_data_nuts2 = mosquito_data.query("nuts2 == 'CENTRAL MACEDONIA'").copy()
mosquito_data_nuts2.reset_index(inplace = True, drop = True)

# %%
mosq_columns = mosquito_data_nuts2.columns

# %%
mosq_columns
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
                'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
                'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
                'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
                'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
                'acc_rainfall_jan', 'mosq_now']

mosquito_data_nuts2 = select_columns(mosquito_data_nuts2, columns_to_keep, columns_to_keep)

mosquito_data_nuts2 = reshape_dataset(mosquito_data_nuts2,['x','y','dt_placement'])

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()
# Out:
# c:\Users\dimit\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#quantile might change based on sns plots
mosq_quantilie = mosquito_data_nuts2['mosq_now'].quantile(0.90)

mosquito_data_nuts2['mosq_now'][mosquito_data_nuts2['mosq_now'] > mosq_quantilie] = mosq_quantilie+1
# Out:
# C:\Users\dimit\AppData\Local\Temp/ipykernel_21380/187358562.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mosquito_data_nuts2['mosq_now'][mosquito_data_nuts2['mosq_now'] > mosq_quantilie] = mosq_quantilie+1

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()
# Out:
# c:\Users\dimit\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <AxesSubplot:>

# %%
imputer = KNNImputer()

features_for_impute = ['x', 'y', 'day', 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 
                        'lst_day', 'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean', 'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan']

mosquito_data_sub = mosquito_data_nuts2[features_for_impute]

imputed_data = pd.DataFrame(imputer.fit_transform(mosquito_data_sub), columns = mosquito_data_sub.columns)

# %%
imputed_columns = ['ndvi','ndmi', 'ndwi', 'ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std', 'ndmi_std','ndwi_std','ndbi_std',
                   'lst_day','lst_night','lst_jan_mean','lst_feb_mean','lst_mar_mean','lst_apr_mean']

mosquito_data_nuts2[imputed_columns] = imputed_data[imputed_columns]

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <AxesSubplot:>

# %%
step = 15
only_env = True
case_title = 'NN mosq regression'
exp = False
date_col = 'dt_placement'
model_type = 'mosquito_regression'
transform_target = True
augment = True

# %%
mosquito_data_nuts2 = initializer(mosquito_data_nuts2,2,10,25,step,[date_col], env=only_env, date_column = date_col, mosq_column='mosq_now')
# Out:
# Bounds: [  0.  85. 755.]
# c:\Users\dimit\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.25, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

model = FeedforwardNeuralNetModel(num_features=len(train_X[0]), num_class=1, hidden_layers = [264,128,128,64], dropout=0.2, model_type=model_type, transform = transform_target)

# Epoch 134: | Train Loss: 11.92880 | Val Loss: 25.12576 | Train Acc: 1.342| Val Acc: 2.035
# Epoch 135: | Train Loss: 11.98638 | Val Loss: 25.44439 | Train Acc: 1.357| Val Acc: 2.054
# Epoch 136: | Train Loss: 11.94420 | Val Loss: 25.67361 | Train Acc: 1.344| Val Acc: 2.119
# Epoch 137: | Train Loss: 11.92137 | Val Loss: 24.71572 | Train Acc: 1.343| Val Acc: 1.997
# Epoch 138: | Train Loss: 12.00044 | Val Loss: 25.42136 | Train Acc: 1.341| Val Acc: 2.088
# Epoch 139: | Train Loss: 11.97398 | Val Loss: 25.17518 | Train Acc: 1.337| Val Acc: 2.094
# Epoch 140: | Train Loss: 11.83562 | Val Loss: 25.15271 | Train Acc: 1.334| Val Acc: 2.065
# Epoch 141: | Train Loss: 11.94883 | Val Loss: 24.65419 | Train Acc: 1.348| Val Acc: 2.008
# Epoch 142: | Train Loss: 11.87360 | Val Loss: 25.39897 | Train Acc: 1.342| Val Acc: 2.098
# Epoch 143: | Train Loss: 11.94062 | Val Loss: 24.88699 | Train Acc: 1.341| Val Acc: 2.016
# Epoch 144: | Train Loss: 12.03071 | Val Loss: 24.72010 | Train Acc: 1.345| Val Acc: 2.007
# Epoch 145: | Train Loss: 11.95563 | Val Loss: 24.94535 | Train Acc: 1.336| Val Acc: 2.019
# Epoch 146: | Train Loss: 11.95720 | Val Loss: 24.54447 | Train Acc: 1.348| Val Acc: 2.003
# Epoch 147: | Train Loss: 12.06648 | Val Loss: 25.09838 | Train Acc: 1.336| Val Acc: 2.053
# Epoch 148: | Train Loss: 11.84067 | Val Loss: 24.72530 | Train Acc: 1.320| Val Acc: 2.000
# Epoch 149: | Train Loss: 11.89454 | Val Loss: 25.29477 | Train Acc: 1.329| Val Acc: 2.035
# Epoch 150: | Train Loss: 11.96199 | Val Loss: 25.25921 | Train Acc: 1.325| Val Acc: 2.058

# %%
metrics(train, test, threshold=30)
# Out:
# MAE on train set:  171.38164847548794
# min prediction: 1
# max prediction: 2819
#
# MAE on test set:  184.498812674585
# Error ⩽ 30: 16.08 %
# min prediction: 1
# max prediction: 1396

# %%
validation_plots(test,model_type)

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.000001, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)
# Out:
# Epoch 001: | Train Loss: 13.75451 | Val Loss: 5.24224 | Train Acc: 1.589| Val Acc: 2.633
# Epoch 002: | Train Loss: 13.53480 | Val Loss: 4.65764 | Train Acc: 1.557| Val Acc: 2.633
# Epoch 003: | Train Loss: 13.51789 | Val Loss: 5.97932 | Train Acc: 1.546| Val Acc: 2.633
# Epoch 004: | Train Loss: 13.14963 | Val Loss: 4.07427 | Train Acc: 1.515| Val Acc: 1.633
# Epoch 139: | Train Loss: 11.97545 | Val Loss: 3.32640 | Train Acc: 1.318| Val Acc: 1.633
# Epoch 140: | Train Loss: 11.99069 | Val Loss: 3.84629 | Train Acc: 1.305| Val Acc: 1.633
# Epoch 141: | Train Loss: 12.02056 | Val Loss: 2.42330 | Train Acc: 1.315| Val Acc: 1.633
# Epoch 142: | Train Loss: 11.93572 | Val Loss: 2.72174 | Train Acc: 1.305| Val Acc: 1.633
# Epoch 143: | Train Loss: 11.91988 | Val Loss: 1.77440 | Train Acc: 1.285| Val Acc: 1.633
# Epoch 144: | Train Loss: 11.87527 | Val Loss: 1.01000 | Train Acc: 1.290| Val Acc: 0.633
# Epoch 145: | Train Loss: 11.90003 | Val Loss: 2.39615 | Train Acc: 1.306| Val Acc: 1.633
# Epoch 146: | Train Loss: 11.83614 | Val Loss: 2.37123 | Train Acc: 1.286| Val Acc: 1.633
# Epoch 147: | Train Loss: 11.81177 | Val Loss: 2.77896 | Train Acc: 1.277| Val Acc: 1.633
# Epoch 148: | Train Loss: 11.82780 | Val Loss: 3.00094 | Train Acc: 1.269| Val Acc: 1.633
# Epoch 149: | Train Loss: 11.77169 | Val Loss: 2.64415 | Train Acc: 1.271| Val Acc: 1.633
# Epoch 150: | Train Loss: 11.95078 | Val Loss: 2.36594 | Train Acc: 1.300| Val Acc: 1.633

# %%
# mamoth_columns = ['x','y','dt_placement','day','month','week','year', 
#                   'day_sin','day_cos','month_sin','month_cos','week_sin','week_cos',
#                   'ndvi','ndmi','ndwi','ndbi', 'ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean', 
#                   'ndvi_std','ndmi_std','ndwi_std','ndbi_std',
#                   'lst_day','lst_night','lst_jan_mean','lst_feb_mean','lst_mar_mean','lst_apr_mean', 
#                   'acc_rainfall_1week','acc_rainfall_2week','acc_rainfall_jan', 'mosq_now' ]

# %%
dataset_mamoth = dataset_mamoth_preparation(dataset, columns_to_keep)

# %%
mosqutio_predictions = dataset_mamoth[['x', 'y', 'dt_placement']].copy()

# %%
dataset_mamoth.drop(columns=['dt_placement'], inplace=True)

# %%
dataset_mamoth_sub = dataset_mamoth[features_for_impute]

# %%
mamoth_imputed = pd.DataFrame(imputer.transform(dataset_mamoth_sub), columns = dataset_mamoth_sub.columns)

# %%
dataset_mamoth[features_for_impute] = mamoth_imputed[features_for_impute]

# %%
missingno.matrix(dataset_mamoth)
# Out:
# <AxesSubplot:>

# %%
dataset_mamoth_X, dataset_mamoth_y = dataset_mamoth.iloc[:,:-1], dataset_mamoth.iloc[:,-1]

dataset_mamoth_X = scaler.transform(dataset_mamoth_X)

# %%
dataset_mamoth = Dataset(dataset_mamoth_X, dataset_mamoth_y, model_type=model_type, transform = transform_target)

# %%
predictions = give_predictions(model, dataset_mamoth)

# %%
mosqutio_predictions['mosq_pred'] = predictions

# %%
mosqutio_predictions
# Out:
#             x         y dt_placement  mosq_pred
# 0    22.48398  40.64468   2022-01-01         39
# 1    21.94079  40.97703   2022-01-01         18
# 2    22.89198  40.65603   2022-01-01         19
# 3    23.98253  40.91510   2022-01-01          5
# 4    23.69108  40.49593   2022-01-01          6
# ..        ...       ...          ...        ...
# 907  23.82811  40.11026   2022-12-16          1
# 908  23.38806  41.31348   2022-12-16          2
# 909  22.14670  40.82294   2022-12-16          1
# 910  22.72302  40.75357   2022-12-16          1
# 911  22.94073  40.77171   2022-12-16          3
#
# [912 rows x 4 columns]

# %%
dataset = pd.merge(dataset, mosqutio_predictions,  how='left', on=['x','y','dt_placement'])

# %%
dataset
# Out:
#     dt_placement                   lau1                 nuts2         x  \
# 0     2022-01-01           αλεξανδρειας  κεντρικης μακεδονιας  22.48398
# 1     2022-01-01               αλμωπιας  κεντρικης μακεδονιας  21.94079
# 2     2022-01-01  αμπελοκηπων μενεμενης  κεντρικης μακεδονιας  22.89198
# 3     2022-01-01              αμφιπολης  κεντρικης μακεδονιας  23.98253
# 4     2022-01-01             αριστοτελη  κεντρικης μακεδονιας  23.69108
# ..           ...                    ...                   ...       ...
# 907   2022-12-16               σιθωνιας  κεντρικης μακεδονιας  23.82811
# 908   2022-12-16               σιντικης  κεντρικης μακεδονιας  23.38806
# 909   2022-12-16                σκυδρας  κεντρικης μακεδονιας  22.14670
# 910   2022-12-16             χαλκηδονος  κεντρικης μακεδονιας  22.72302
# 911   2022-12-16           ωραιοκαστρου  κεντρικης μακεδονιας  22.94073
#
#             y  year  month      ndvi      ndmi      ndwi      ndbi  ndvi_mean  \
# 0    40.64468  2022      1       NaN       NaN       NaN       NaN        NaN
# 1    40.97703  2022      1       NaN       NaN       NaN       NaN        NaN
# 2    40.65603  2022      1       NaN       NaN       NaN       NaN        NaN
# 3    40.91510  2022      1       NaN       NaN       NaN       NaN        NaN
# 4    40.49593  2022      1       NaN       NaN       NaN       NaN        NaN
# ..        ...   ...    ...       ...       ...       ...       ...        ...
# 907  40.11026  2022     12  0.348392  0.315455 -0.175847 -0.315455   0.321459
# 908  41.31348  2022     12  0.324119 -0.016353 -0.319365  0.016353   0.319459
# 909  40.82294  2022     12  0.431693 -0.011406 -0.376042  0.011406   0.445152
# 910  40.75357  2022     12  0.133472 -0.224825 -0.195777  0.224825   0.129031
# 911  40.77171  2022     12  0.443215  0.073833 -0.363456 -0.073833   0.345633
#
#      ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  \
# 0          NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 1          NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 2          NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 3          NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 4          NaN        NaN        NaN       NaN       NaN       NaN       NaN
# ..         ...        ...        ...       ...       ...       ...       ...
# 907   0.284695  -0.162175  -0.284695  0.049445  0.081901  0.026801  0.081901
# 908  -0.032765  -0.317519   0.032765  0.036188  0.047272  0.029911  0.047272
# 909   0.024967  -0.382060  -0.024967  0.045625  0.040591  0.032540  0.040591
# 910  -0.192451  -0.173992   0.192451  0.009124  0.021056  0.006975  0.021056
# 911  -0.009936  -0.302529   0.009936  0.070352  0.056582  0.045733  0.056582
#
#           lst_day     lst_night  lst_jan_day_mean  lst_jan_night_mean  \
# 0             NaN  14030.000000      14063.820954        13590.484837
# 1    14269.300000  14026.777778      13915.309398        13636.003976
# 1   -0.118273  0.992981   985.8                28.0     24924.0         18
# 2   -0.118273  0.992981     9.8              5319.1     49674.0         19
# 3   -0.118273  0.992981   411.8                22.3      7169.0          5
# 4   -0.118273  0.992981   747.0                24.5     16994.0          6
# ..        ...       ...     ...                 ...         ...        ...
# 907 -0.348202  0.937420   516.8                24.0     11631.0          1
# 908 -0.348202  0.937420  1103.4                20.1     18532.0          2
# 909 -0.348202  0.937420   239.5                84.3     18080.0          1
# 910 -0.348202  0.937420   391.5                86.0     29951.0          1
# 911 -0.348202  0.937420   217.9               175.8     40114.0          3
#
# [912 rows x 47 columns]

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
dataset.reset_index(inplace=True, drop=True)

# %%
dataset = calculate_mosq_previous(dataset)

# %%
dataset = convert_temperature(dataset)

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
dataset['case'].value_counts()
# Out:
# 0    806
# 1     69
# 2     32
# 3      5
# Name: case, dtype: int64

# %%
dataset = dataset.astype({'mosq_pred' : 'int', 'mosq_previous' : 'int'})

# %%
dataset = convert_multiple_cases(dataset)

# %%
dataset['case'].value_counts()
# Out:
# 0    806
# 1    148
# Name: case, dtype: int64

# %%
cols = dataset.columns

# %%
cols
# Out:
# Index(['dt_placement', 'lau1', 'nuts2', 'x', 'y', 'year', 'month', 'ndvi',
#        'ndmi', 'ndwi', 'ndbi', 'ndvi_mean', 'ndmi_mean', 'ndwi_mean',
#        'ndbi_mean', 'ndvi_std', 'ndmi_std', 'ndwi_std', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_day_mean', 'lst_jan_night_mean',
#        'lst_feb_day_mean', 'lst_feb_night_mean', 'lst_mar_day_mean',
#        'lst_mar_night_mean', 'lst_apr_day_mean', 'lst_apr_night_mean',
#        'acc_rainfall_jan', 'acc_rainfall_1week', 'acc_rainfall_2week', 'case',
#        'day', 'week', 'eq_distance', 'lau1_id', 'day_sin', 'day_cos',
#        'month_sin', 'month_cos', 'week_sin', 'week_cos', 'area',
#        'population_density', 'population', 'mosq_pred', 'mosq_previous',
#        'lst'],
#       dtype='object')

# %%
len(cols)
# Out:
# 49

# %%
# check columns

# %%
final_columns = ['x', 'y', 'dt_placement', 'nuts2', 'lau1', 'lau1_id', 'day', 
                 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 
                 'month_cos', 'week_sin', 'week_cos', 'area', 'population',
                 'population_density', 'eq_distance', 'ndvi', 'ndmi', 'ndwi', 'ndbi', 
                 'ndvi_mean', 'ndmi_mean', 'ndwi_mean', 'ndbi_mean', 
                 'ndvi_std', 'ndmi_std', 'ndwi_std', 'ndbi_std', 'lst',
                 'lst_day', 'lst_night','lst_jan_day_mean', 'lst_jan_night_mean', 
                 'lst_feb_day_mean','lst_feb_night_mean', 'lst_mar_day_mean', 
                 'lst_mar_night_mean', 'lst_apr_day_mean', 'lst_apr_night_mean',
                 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan',
                 'mosq_pred', 'mosq_previous', 'case']

# %%
len(final_columns)
# Out:
# 49

# %%
dataset_final = dataset[final_columns].copy()

# %%
dataset_final
# Out:
#             x         y dt_placement                 nuts2  \
# 0    22.48398  40.64468   2022-01-01  κεντρικης μακεδονιας
# 1    21.94079  40.97703   2022-01-01  κεντρικης μακεδονιας
# 2    22.89198  40.65603   2022-01-01  κεντρικης μακεδονιας
# 3    23.98253  40.91510   2022-01-01  κεντρικης μακεδονιας
# 4    23.69108  40.49593   2022-01-01  κεντρικης μακεδονιας
# ..        ...       ...          ...                   ...
# 949  22.48398  40.64468   2022-08-16  κεντρικης μακεδονιας
# 950  22.15177  40.44520   2022-08-16  κεντρικης μακεδονιας
# 951  22.95369  40.62334   2022-08-16  κεντρικης μακεδονιας
# 952  23.24414  40.32110   2022-08-16  κεντρικης μακεδονιας
# 953  23.05120  40.60697   2022-08-16  κεντρικης μακεδονιας
#
#                       lau1  lau1_id  day  month  week  year   day_sin  \
# 0             αλεξανδρειας        8    1      1    52  2022  0.201299
# 1                 αλμωπιας        9    1      1    52  2022  0.201299
# 2    αμπελοκηπων μενεμενης       17    1      1    52  2022  0.201299
# 3                αμφιπολης       33    1      1    52  2022  0.201299
# 4               αριστοτελη       27    1      1    52  2022  0.201299
# ..                     ...      ...  ...    ...   ...   ...       ...
# 949           αλεξανδρειας        8   16      8    33  2022 -0.101168
# 950                βεροιας        2   16      8    33  2022 -0.101168
# 951           θεσσαλονικης       18   16      8    33  2022 -0.101168
# 952       νεας προποντιδας       12   16      8    33  2022 -0.101168
# 953       πυλαιας χορτιατη       21   16      8    33  2022 -0.101168
#
#       day_cos  month_sin  month_cos  week_sin  week_cos   area  population  \
# 0    0.979530   0.500000   0.866025 -0.118273  0.992981  478.8     38293.0
# 1    0.979530   0.500000   0.866025 -0.118273  0.992981  985.8     24924.0
# 2    0.979530   0.500000   0.866025 -0.118273  0.992981    9.8     49674.0
# 3    0.979530   0.500000   0.866025 -0.118273  0.992981  411.8      7169.0
# 4    0.979530   0.500000   0.866025 -0.118273  0.992981  747.0     16994.0
# ..        ...        ...        ...       ...       ...    ...         ...
# 949 -0.994869  -0.866025  -0.500000 -0.696551 -0.717507  478.8     38293.0
# 950 -0.994869  -0.866025  -0.500000 -0.696551 -0.717507  796.5     62064.0
# 951 -0.994869  -0.866025  -0.500000 -0.696551 -0.717507   19.3    317778.0
# 952 -0.994869  -0.866025  -0.500000 -0.696551 -0.717507  372.3     34391.0
# 953 -0.994869  -0.866025  -0.500000 -0.696551 -0.717507  155.6     72223.0
#
#      population_density  eq_distance      ndvi      ndmi      ndwi      ndbi  \
# 0                  86.8     46.44911       NaN       NaN       NaN       NaN
# 1                  28.0     46.48134       NaN       NaN       NaN       NaN
# 2                5319.1     46.65786       NaN       NaN       NaN       NaN
# 3                  22.3     47.42581       NaN       NaN       NaN       NaN
# 4                  24.5     46.91682       NaN       NaN       NaN       NaN
# ..                  ...          ...       ...       ...       ...       ...
# 949                86.8     46.44911  0.694571  0.353325 -0.589602 -0.353325
# 950                83.5     46.11415  0.626029  0.198500 -0.535367 -0.198500
# 951             16848.8     46.65970  0.192811 -0.006628 -0.214006  0.006628
# 952                98.0     46.54118  0.323303 -0.028801 -0.362826  0.028801
# 953               450.6     46.69351  0.383580  0.040619 -0.369631 -0.040619
#
#      ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  \
# 0          NaN        NaN        NaN        NaN       NaN       NaN       NaN
# 1          NaN        NaN        NaN        NaN       NaN       NaN       NaN
# 2          NaN        NaN        NaN        NaN       NaN       NaN       NaN
# 3          NaN        NaN        NaN        NaN       NaN       NaN       NaN
# 4          NaN        NaN        NaN        NaN       NaN       NaN       NaN
# ..         ...        ...        ...        ...       ...       ...       ...
# 949   0.685882   0.343081  -0.584848  -0.343081  0.043877  0.051278  0.035686
# 950   0.616168   0.191642  -0.529950  -0.191642  0.075760  0.067731  0.054042
# 951   0.082588   0.015971  -0.068460  -0.015971  0.118560  0.130964  0.205887
# 952   0.318196  -0.038290  -0.363848   0.038290  0.050504  0.034735  0.033718
# 953   0.395833   0.053213  -0.381372  -0.053213  0.067984  0.058193  0.039231
#
#      ndbi_std        lst    lst_day  lst_night  lst_jan_day_mean  \
# 0         NaN        NaN        NaN   7.450000          8.126419
# 1         NaN   9.810778  12.236000   7.385556          5.156188
# 2         NaN        NaN        NaN   9.770000          8.206667
# 3         NaN        NaN        NaN   5.935000          5.506350
# 4         NaN   8.014583   9.186667   6.842500          5.626176
# ..        ...        ...        ...        ...               ...
# 949  0.051278  25.332500  31.340000  19.325000          8.126419
# 950  0.067731  23.221429  30.087143  16.355714          3.678481
# 951  0.130964        NaN        NaN        NaN               NaN
# 952  0.034735  29.003333  38.143333  19.863333         10.509905
# 953  0.058193  27.405000  34.790000  20.020000          6.053960
#
#      lst_jan_night_mean  lst_feb_day_mean  lst_feb_night_mean  \
# 0             -1.340303         16.216012            1.011667
# 1             -0.429920          9.002046            1.203846
# 2              1.223333         14.106000            3.702000
# 3             -0.849211         10.168715            1.184231
# 4              0.027273          8.827055            1.857362
# ..                  ...               ...                 ...
# 949           -1.340303         16.216012            1.011667
# 950            0.405016          6.749489            2.093469
# 951                 NaN               NaN                 NaN
# 952            0.591280         14.209359            2.818828
# 953           -0.244618         11.039295            2.596474
#
#      lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  \
# 0           18.020179            1.565813         32.641755
# 1            8.268402            0.655058         20.890796
# 2           17.271538            2.883846         26.801250
# 3           13.528745            0.333718         22.552471
# 4           12.089767            0.979534         20.756913
# ..                ...                 ...               ...
# 949         18.020179            1.565813         32.641755
# 950          6.703573           -0.614043         20.082834
# 951               NaN                 NaN               NaN
# 952         16.059402            1.388444         25.020417
# 953         13.741231            1.628667         22.957647
#
#      lst_apr_night_mean  acc_rainfall_1week  acc_rainfall_2week  \
# 0              8.896456            0.113685            0.113685
# 1              6.749332            2.557299            2.557299
# 2              9.896667            0.000000            0.000000
# 3              8.162000            0.417504            0.417504
# 4              8.392523            0.000000            0.000000
# ..                  ...                 ...                 ...
# 949            8.896456           33.114033           35.279590
# 950            7.265003           39.399950           40.288825
# 951                 NaN           10.839940           19.326230
# 952            8.645154           33.442790           34.047510
# 953            9.294667           28.918219           32.245201
#
#      acc_rainfall_jan  mosq_pred  mosq_previous  case
# 0            0.113685         39              0     0
# 1            2.557299         18              0     0
# 2            0.000000         19              0     0
# 3            0.417504          5              0     0
# 4            0.000000          6              0     0
# ..                ...        ...            ...   ...
# 949        701.852196         28             71     1
# 950        783.684469         18             63     1
# 951        849.966242         59             84     1
# 952        972.080135         28             92     1
# 953        855.411301         31             70     1
#
# [954 rows x 49 columns]

# %%
dataset_final.to_csv(f"data/{NUTS0}_{NUTS2}_WNV_Dataset_2022.csv", encoding = enc, index = False)
