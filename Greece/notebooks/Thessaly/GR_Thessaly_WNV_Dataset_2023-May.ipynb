# %% [markdown]
# ## Merges all the availble information into a **Final Dataset** to be used for modeling ##

# %%
import pandas as pd
import datetime
import math
import numpy as np
import missingno
import json
from statistics import mean
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
import sys

sys.path.insert(0, "../../../Modules")

from preprocessing_utils import *


enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 10

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
NUTS0 = 'GR'
NUTS2 = 'Thessaly'
NUTS2_EL = 'θεσσαλιας'

# %%
timeline_file = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Timeline_Biweekly_2023-May_filled.csv', encoding=enc)
#wnv_file = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Timeline_2022.csv', encoding=enc)

# %%
timeline_file.head()
# Out:
#     lau1     region         x         y dt_placement  year  month  \
# 0  αγιας  θεσσαλιας  22.63715  39.66477   2023-05-01  2023      5
# 1  αγιας  θεσσαλιας  22.63715  39.66477   2023-05-16  2023      5
# 2  αγιας  θεσσαλιας  22.70702  39.75460   2023-05-01  2023      5
# 3  αγιας  θεσσαλιας  22.70702  39.75460   2023-05-16  2023      5
# 4  αγιας  θεσσαλιας  22.73031  39.79054   2023-05-01  2023      5
#
#   indices_image_date  indices_lat  indices_lon  ndvi_new  ndmi_new  ndwi_new  \
# 0         2023-04-30    39.662866    22.635299  0.320605  0.010753 -0.297699
# 1         2023-05-15    39.662866    22.635299  0.240125 -0.026575 -0.239737
# 2         2023-04-30    39.752697    22.707165  0.506922  0.087536 -0.458373
# 3         2023-05-15    39.752697    22.707165  0.506922  0.087536 -0.458373
# 4         2023-04-30    39.788630    22.729622  0.398340 -0.021568 -0.405003
#
#    ndbi_new  ndvi_mean_new  ndmi_mean_new  ndwi_mean_new  ndbi_mean_new  \
# 0 -0.010753       0.505039       0.205061      -0.442851      -0.205061
# 1  0.026575       0.378440       0.113461      -0.354095      -0.113461
# 2 -0.087536       0.521654       0.109084      -0.459319      -0.109084
# 3 -0.087536       0.521654       0.109084      -0.459319      -0.109084
# 4  0.021568       0.148230       0.267161      -0.058763      -0.267161
#
#    ndvi_std_new  ndmi_std_new  ndwi_std_new  ndbi_std_new lst_image_date  \
# 0      0.125752      0.119283      0.096853      0.119283     2023-05-01
# 1      0.096435      0.088987      0.075341      0.088987     2023-05-15
# 2      0.056933      0.073780      0.034842      0.073780     2023-05-01
# 3      0.056933      0.073780      0.034842      0.073780     2023-05-15
# 4      0.041401      0.077481      0.012572      0.077481     2023-05-01
#
#      lst_lat    lst_lon  lst_day_new  lst_night_new  monthly_lst_lat  \
# 0  39.662866  22.635299      14966.0        14353.0        39.662866
# 1  39.662866  22.635299      14659.0        13889.0        39.662866
# 2  39.752697  22.707165      14569.0        14025.0        39.752697
# 3  39.752697  22.707165      14401.0        14149.0        39.752697
# 4  39.788630  22.729622      14419.0        13927.0        39.788630
#
#    monthly_lst_lon  lst_jan_day_mean_new  lst_jan_night_mean_new  \
# 0        22.635299          14219.000000            13818.000000
# 1        22.635299          14219.000000            13818.000000
# 2        22.707165          14223.600000            13741.846154
# 3        22.707165          14223.600000            13741.846154
# 4        22.729622          14031.307692            13745.444444
#
#    lst_feb_day_mean_new  lst_feb_night_mean_new  lst_mar_day_mean_new  \
# 0          14307.062500            13704.263158          14637.352941
# 1          14307.062500            13704.263158          14637.352941
# 2          14084.133333            13737.714286          14400.923077
# 3          14084.133333            13737.714286          14400.923077
# 4          13840.846154            13747.428571          14317.428571
#
#    lst_mar_night_mean_new  lst_apr_day_mean_new  lst_apr_night_mean_new  \
# 0            13943.333333          14850.466667            14041.625000
# 1            13943.333333          14850.466667            14041.625000
# 2            13793.692308          14395.000000            13897.142857
# 3            13793.692308          14395.000000            13897.142857
# 4            13781.400000          14333.600000            13838.888889
#
#   indices_image_date.1  indices_lat.1  indices_lon.1  acc_rainfall_jan_new  \
# 0           2023-05-01      39.650181      22.650104             70.551421
# 1           2023-05-16      39.650181      22.650104             91.643375
# 2           2023-05-01      39.750182      22.750104             80.850409
# 3           2023-05-16      39.750182      22.750104            112.728533
# 4           2023-05-01      39.750182      22.750104             80.850409
#
#   dt_placement_minus_7 dt_placement_minus_14 dt_placement_minus_7_avail  \
# 0           2023-04-24            2023-04-17                 2023-04-24
# 1           2023-05-09            2023-05-02                 2023-05-09
# 2           2023-04-24            2023-04-17                 2023-04-24
# 3           2023-05-09            2023-05-02                 2023-05-09
# 4           2023-04-24            2023-04-17                 2023-04-24
#
#   dt_placement_minus_14_avail  acc_rainfall_1week_new  acc_rainfall_2week_new
# 0                  2023-04-17                0.462882               28.530567
# 1                  2023-05-02               11.616080               20.296991
# 2                  2023-04-17                2.064366               13.038493
# 3                  2023-05-02               16.491027               26.945055
# 4                  2023-04-17                2.064366               13.038493

# %%
#wnv_file.head()

# %%
timeline_file.rename(columns={"region": "nuts2"}, inplace=True)

# %%
timeline_file = timeline_file.rename(columns=lambda x: re.sub('_new', '', x))

# %%
timeline_file.drop(columns=['indices_image_date', 'indices_lat', 'indices_lon' , 'lst_image_date', 'lst_lat','lst_lon' ,'monthly_lst_lat', 'monthly_lst_lon', 
                         'indices_image_date.1', 'indices_lat.1', 'indices_lon.1', 'dt_placement_minus_7', 'dt_placement_minus_14', 'dt_placement_minus_7_avail',
                         'dt_placement_minus_14_avail'], inplace = True)

# %%
timeline_file.head(5)
# Out:
#     lau1      nuts2         x         y dt_placement  year  month      ndvi  \
# 0  αγιας  θεσσαλιας  22.63715  39.66477   2023-05-01  2023      5  0.320605
# 1  αγιας  θεσσαλιας  22.63715  39.66477   2023-05-16  2023      5  0.240125
# 2  αγιας  θεσσαλιας  22.70702  39.75460   2023-05-01  2023      5  0.506922
# 3  αγιας  θεσσαλιας  22.70702  39.75460   2023-05-16  2023      5  0.506922
# 4  αγιας  θεσσαλιας  22.73031  39.79054   2023-05-01  2023      5  0.398340
#
#        ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  \
# 0  0.010753 -0.297699 -0.010753   0.505039   0.205061  -0.442851  -0.205061
# 1 -0.026575 -0.239737  0.026575   0.378440   0.113461  -0.354095  -0.113461
# 2  0.087536 -0.458373 -0.087536   0.521654   0.109084  -0.459319  -0.109084
# 3  0.087536 -0.458373 -0.087536   0.521654   0.109084  -0.459319  -0.109084
# 4 -0.021568 -0.405003  0.021568   0.148230   0.267161  -0.058763  -0.267161
#
#    ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  lst_night  \
# 0  0.125752  0.119283  0.096853  0.119283  14966.0    14353.0
# 1  0.096435  0.088987  0.075341  0.088987  14659.0    13889.0
# 2  0.056933  0.073780  0.034842  0.073780  14569.0    14025.0
# 3  0.056933  0.073780  0.034842  0.073780  14401.0    14149.0
# 4  0.041401  0.077481  0.012572  0.077481  14419.0    13927.0
#
#    lst_jan_day_mean  lst_jan_night_mean  lst_feb_day_mean  lst_feb_night_mean  \
# 0      14219.000000        13818.000000      14307.062500        13704.263158
# 1      14219.000000        13818.000000      14307.062500        13704.263158
# 2      14223.600000        13741.846154      14084.133333        13737.714286
# 3      14223.600000        13741.846154      14084.133333        13737.714286
# 4      14031.307692        13745.444444      13840.846154        13747.428571
#
#    lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  lst_apr_night_mean  \
# 0      14637.352941        13943.333333      14850.466667        14041.625000
# 1      14637.352941        13943.333333      14850.466667        14041.625000
# 2      14400.923077        13793.692308      14395.000000        13897.142857
# 3      14400.923077        13793.692308      14395.000000        13897.142857
# 4      14317.428571        13781.400000      14333.600000        13838.888889
#
#    acc_rainfall_jan  acc_rainfall_1week  acc_rainfall_2week
# 0         70.551421            0.462882           28.530567
# 1         91.643375           11.616080           20.296991
# 2         80.850409            2.064366           13.038493
# 3        112.728533           16.491027           26.945055
# 4         80.850409            2.064366           13.038493

# %%
#wnv_file.head(5)

# %%
# ## Find if there are lau1 units in the epidemiological file and are not contained in the spatiotemporal file.

# names_from_wnv_file = wnv_file["lau1"].drop_duplicates().sort_values().tolist()
# names_from_shapefile = timeline_file["lau1"].drop_duplicates().sort_values().tolist()
# diff = []

# for element in names_from_wnv_file:
#     if element not in names_from_shapefile:
#         diff.append(element)
        

# print(f"{diff}\n\nLength: {len(diff)}")

# %%
#wnv_file['lau1'] = wnv_file['lau1'].apply(lambda x : x.replace('ηρωικης πολεως ναουσας','ναουσας'))

# %%
# ## Check again

# names_from_wnv_file = wnv_file["lau1"].drop_duplicates().sort_values().tolist()
# names_from_shapefile = timeline_file["lau1"].drop_duplicates().sort_values().tolist()
# diff = []

# for element in names_from_wnv_file:
#     if element not in names_from_shapefile:
#         diff.append(element)
        

# print(f"{diff}\n\nLength: {len(diff)}")

# %%
# merged = timeline_file.merge(wnv_file, how='left', on=['dt_placement', 'lau1', 'nuts2'] )
merged = timeline_file

# %%
# merged

# %%
# merged = fillna(merged,{'case': 0})
merged['case'] = 0

# %%
merged['case'].value_counts()
# Out:
# 0    252
# Name: case, dtype: int64

# %%
grouped = merged.groupby(['dt_placement', 'lau1', 'nuts2'], as_index = False)

# %%
dataset = grouped.mean()

# %%
dataset
# Out:
#    dt_placement        lau1      nuts2          x          y    year  month  \
# 0    2023-05-01       αγιας  θεσσαλιας  22.750267  39.710970  2023.0    5.0
# 1    2023-05-01     αλμυρου  θεσσαλιας  22.692366  39.136391  2023.0    5.0
# 2    2023-05-01   αλοννησου  θεσσαλιας  24.073790  39.328960  2023.0    5.0
# 3    2023-05-01    αργιθεας  θεσσαλιας  21.430513  39.221380  2023.0    5.0
# 4    2023-05-01       βολου  θεσσαλιας  22.883800  39.351977  2023.0    5.0
# ..          ...         ...        ...        ...        ...     ...    ...
# 45   2023-05-16      τεμπων  θεσσαλιας  22.553160  39.852112  2023.0    5.0
# 45        13710.264791      14425.669118        13892.648535
# 46        13765.126176      14621.389846        13986.928283
# 47        13720.940664      14569.709428        13922.793269
# 48        13813.812500      14609.167725        14019.155400
# 49        13740.169656      14604.642700        13973.223738
#
#     lst_apr_day_mean  lst_apr_night_mean  acc_rainfall_jan  \
# 0       14528.540407        14007.143707         76.675988
# 1       14640.452078        14072.106614        208.946587
# 2       14543.000000        14215.666667        163.677945
# 3       14318.077381        13868.033333        141.474393
# 4       14708.583333        14067.142857        146.622452
# ..               ...                 ...               ...
# 45      14496.147902        13987.089286         90.443463
# 46      14689.561490        14047.238095        176.999873
# 47      14687.921314        14042.280258         67.877909
# 48      14719.909041        14095.839286        137.263723
# 49      14727.316497        14039.512472        146.754341
#
#     acc_rainfall_1week  acc_rainfall_2week  case
# 0             2.381410           17.837466   0.0
# 1             3.480882           69.269711   0.0
# 2             7.946645           55.220344   0.0
# 3             8.412601           10.754827   0.0
# 4             1.161971           49.566698   0.0
# ..                 ...                 ...   ...
# 45            6.463702           27.740014   0.0
# 46           13.713732           32.495788   0.0
# 47            5.999722           12.930523   0.0
# 48           17.629915           34.227020   0.0
# 49           15.536300           27.173840   0.0
#
# [50 rows x 33 columns]

# %%
dataset = dataset.astype({'case': 'int'})

# %%
dataset['dt_placement'] = pd.to_datetime(dataset['dt_placement'])

# %%
dataset['x'] = dataset['x'].apply(lambda x : round(x,5))
dataset['y'] = dataset['y'].apply(lambda x : round(x,5))
dataset['day'] = dataset['dt_placement'].apply(lambda x : x.day)
dataset['month'] = dataset['dt_placement'].apply(lambda x : x.month)
dataset['year'] = dataset['dt_placement'].apply(lambda x : x.year)
dataset['week'] = dataset.apply(lambda row: datetime.date(int(row['year']), int(row['month']), int(row['day'])).isocalendar().week, axis=1)

# %%
lau1_map = lau1_mapping(dataset, 0, 0)

# %%
dataset = encode_cyclical(dataset, 'day', 31)
dataset = encode_cyclical(dataset, 'month', 12)
dataset = encode_cyclical(dataset, 'week', 53)

# %%
dataset
# Out:
#    dt_placement        lau1      nuts2         x         y  year  month  \
# 0    2023-05-01       αγιας  θεσσαλιας  22.75027  39.71097  2023      5
# 1    2023-05-01     αλμυρου  θεσσαλιας  22.69237  39.13639  2023      5
# 2    2023-05-01   αλοννησου  θεσσαλιας  24.07379  39.32896  2023      5
# 3    2023-05-01    αργιθεας  θεσσαλιας  21.43051  39.22138  2023      5
# 4    2023-05-01       βολου  θεσσαλιας  22.88380  39.35198  2023      5
# ..          ...         ...        ...       ...       ...   ...    ...
# 45   2023-05-16      τεμπων  θεσσαλιας  22.55316  39.85211  2023      5
# 46   2023-05-16   τρικκαιων  θεσσαλιας  21.79756  39.63506  2023      5
# 47   2023-05-16    τυρναβου  θεσσαλιας  22.34300  39.82847  2023      5
# 48   2023-05-16  φαρκαδονας  θεσσαλιας  22.02056  39.60375  2023      5
# 49   2023-05-16    φαρσαλων  θεσσαλιας  22.46590  39.31130  2023      5
#
#         ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  \
# 
# ..               ...                 ...               ...
# 45      14496.147902        13987.089286         90.443463
# 46      14689.561490        14047.238095        176.999873
# 47      14687.921314        14042.280258         67.877909
# 48      14719.909041        14095.839286        137.263723
# 49      14727.316497        14039.512472        146.754341
#
#     acc_rainfall_1week  acc_rainfall_2week  case  day  week  eq_distance  \
# 0             2.381410           17.837466     0    1    18     45.76610
# 1             3.480882           69.269711     0    1    18     45.23937
# 2             7.946645           55.220344     0    1    18     46.11198
# 3             8.412601           10.754827     0    1    18     44.69433
# 4             1.161971           49.566698     0    1    18     45.52194
# ..                 ...                 ...   ...  ...   ...          ...
# 45            6.463702           27.740014     0   16    20     45.79122
# 46           13.713732           32.495788     0   16    20     45.23352
# 47            5.999722           12.930523     0   16    20     45.66746
# 48           17.629915           34.227020     0   16    20     45.31404
# 49           15.536300           27.173840     0   16    20     45.27797
#
#      day_sin   day_cos  month_sin  month_cos  week_sin  week_cos
# 0   0.201299  0.979530        0.5  -0.866025  0.845596 -0.533823
# 1   0.201299  0.979530        0.5  -0.866025  0.845596 -0.533823
# 2   0.201299  0.979530        0.5  -0.866025  0.845596 -0.533823
# 3   0.201299  0.979530        0.5  -0.866025  0.845596 -0.533823
# 4   0.201299  0.979530        0.5  -0.866025  0.845596 -0.533823
# ..       ...       ...        ...        ...       ...       ...
# 45 -0.101168 -0.994869        0.5  -0.866025  0.696551 -0.717507
# 46 -0.101168 -0.994869        0.5  -0.866025  0.696551 -0.717507
# 47 -0.101168 -0.994869        0.5  -0.866025  0.696551 -0.717507
# 48 -0.101168 -0.994869        0.5  -0.866025  0.696551 -0.717507
# 49 -0.101168 -0.994869        0.5  -0.866025  0.696551 -0.717507
#
# [50 rows x 42 columns]

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
df_demographics = pd.read_csv(f'../../data/{NUTS0}_WEB_Demographics_Processed.csv', encoding = enc)

# %%
df_demographics
# Out:
#                  lau1                             nuts2                 nuts3  \
# 0             αβδηρων  ανατολικης μακεδονιας και θρακης                ξανθης
# 1         αγαθονησιου                    νοτιου αιγαιου              καλυμνου
# 2               αγιας                         θεσσαλιας               λαρισας
# 3      αγιας βαρβαρας                           αττικης  δυτικου τομεα αθηνων
# 4    αγιας παρασκευης                           αττικης  βορειου τομεα αθηνων
# ..                ...                               ...                   ...
# 327            χανιων                            κρητης                χανιων
# 328        χερσονησου                            κρητης             ηρακλειου
# 329              χιου                   βορειου αιγαιου                  χιου
# 330      ωραιοκαστρου              κεντρικης μακεδονιας          θεσσαλονικης
# 331            ωρωπου                           αττικης    ανατολικης αττικης
#
#       area  population_density  population
# 0    352.0                54.0     17860.0
# 1     14.5                12.8       203.0
# 2    661.8                17.3     10705.0
# 3      2.4             10925.9     26759.0
# 4      7.9              7557.5     62157.0
# ..     ...                 ...         ...
# 327  351.3               309.3    110646.0
# 328  272.2                98.2     27229.0
# 329  842.3                61.0     50483.0
# 330  217.9               175.8     40114.0
# 331  338.2                99.8     33977.0
#
# [332 rows x 6 columns]

# %%
df_demographics_nuts2 = df_demographics.query(f"nuts2 == '{NUTS2_EL}'").copy()

# %%
df_demographics_nuts2.drop(columns=['nuts2', 'nuts3'], inplace=True)
df_demographics_nuts2.reset_index(inplace=True, drop=True)

# %%
df_demographics_nuts2
# Out:
#           lau1   area  population_density  population
# 0        αγιας  661.8                17.3    10705.00
# 1      αλμυρου  905.4                20.6    16004.00
# 2    αλοννησου  129.6                21.2     3153.00
# 3     αργιθεας  372.9                 9.3     3515.00
# 4        βολου  385.6               374.6   138865.00
# ..         ...    ...                 ...         ...
# 20      τεμπων  576.7                23.8       11.99
# 21   τρικκαιων  607.6               133.9    78508.00
# 22    τυρναβου  525.3                47.7    22252.00
# 23  φαρκαδονος  368.7                36.3    11348.00
# 24    φαρσαλων  739.7                25.1    16310.00
#
# [25 rows x 4 columns]

# %%
names_from_merged = dataset["lau1"].drop_duplicates().sort_values().tolist()
names_from_demographics = df_demographics_nuts2["lau1"].drop_duplicates().sort_values().tolist()
diff = []

for element in names_from_merged:
    if element not in names_from_demographics:
        diff.append(element)
        

print(f"{diff}\n\nLength: {len(diff)}")
# Out:
# ['καλαμπακας', 'λαρισαιων', 'ρηγα φερραιου', 'φαρκαδονας']
#
# Length: 4

# %%
df_demographics_nuts2['lau1'] = df_demographics_nuts2['lau1'].apply(lambda x : x.replace('μετεωρων','καλαμπακας'))
df_demographics_nuts2['lau1'] = df_demographics_nuts2['lau1'].apply(lambda x : x.replace('λαρισας','λαρισαιων'))
df_demographics_nuts2['lau1'] = df_demographics_nuts2['lau1'].apply(lambda x : x.replace('ρηγα φεραιου','ρηγα φερραιου'))
df_demographics_nuts2['lau1'] = df_demographics_nuts2['lau1'].apply(lambda x : x.replace('φαρκαδονος','φαρκαδονας'))

# %%
names_from_merged = dataset["lau1"].drop_duplicates().sort_values().tolist()
names_from_demographics = df_demographics_nuts2["lau1"].drop_duplicates().sort_values().tolist()
diff = []

for element in names_from_merged:
    if element not in names_from_demographics:
        diff.append(element)
        

print(f"{diff}\n\nLength: {len(diff)}")
# Out:
# []
#
# Length: 0

# %%
dataset = pd.merge(dataset, df_demographics_nuts2,  how='left', on=['lau1'])

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
missing = describe_dataframe(dataset)

# %%
dataset
# Out:
#    dt_placement        lau1      nuts2         x         y  year  month  \
# 0    2023-05-01       αγιας  θεσσαλιας  22.75027  39.71097  2023      5
# 1    2023-05-01     αλμυρου  θεσσαλιας  22.69237  39.13639  2023      5
# 2    2023-05-01   αλοννησου  θεσσαλιας  24.07379  39.32896  2023      5
# 3    2023-05-01    αργιθεας  θεσσαλιας  21.43051  39.22138  2023      5
# 4    2023-05-01       βολου  θεσσαλιας  22.88380  39.35198  2023      5
# ..          ...         ...        ...       ...       ...   ...    ...
# 45   2023-05-16      τεμπων  θεσσαλιας  22.55316  39.85211  2023      5
# 46   2023-05-16   τρικκαιων  θεσσαλιας  21.79756  39.63506  2023      5
# 47   2023-05-16    τυρναβου  θεσσαλιας  22.34300  39.82847  2023      5
# 48   2023-05-16  φαρκαδονας  θεσσαλιας  22.02056  39.60375  2023      5
# 49   2023-05-16    φαρσαλων  θεσσαλιας  22.46590  39.31130  2023      5
#
#         ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  \
# 
# 2       14543.000000        14215.666667        163.677945
# 3       14318.077381        13868.033333        141.474393
# 4       14708.583333        14067.142857        146.622452
# ..               ...                 ...               ...
# 45      14496.147902        13987.089286         90.443463
# 46      14689.561490        14047.238095        176.999873
# 47      14687.921314        14042.280258         67.877909
# 48      14719.909041        14095.839286        137.263723
# 49      14727.316497        14039.512472        146.754341
#
#     acc_rainfall_1week  acc_rainfall_2week  case  day  week  eq_distance  \
# 0             2.381410           17.837466     0    1    18     45.76610
# 1             3.480882           69.269711     0    1    18     45.23937
# 2             7.946645           55.220344     0    1    18     46.11198
# 3             8.412601           10.754827     0    1    18     44.69433
# 4             1.161971           49.566698     0    1    18     45.52194
# ..                 ...                 ...   ...  ...   ...          ...
# 45            6.463702           27.740014     0   16    20     45.79122
# 46           13.713732           32.495788     0   16    20     45.23352
# 47            5.999722           12.930523     0   16    20     45.66746
# 48           17.629915           34.227020     0   16    20     45.31404
# 49           15.536300           27.173840     0   16    20     45.27797
#
#      day_sin   day_cos  month_sin  month_cos  week_sin  week_cos   area  \
# 0   0.201299  0.979530        0.5  -0.866025  0.845596 -0.533823  661.8
# 1   0.201299  0.979530        0.5  -0.866025  0.845596 -0.533823  905.4
# 2   0.201299  0.979530        0.5  -0.866025  0.845596 -0.533823  129.6
# 3   0.201299  0.979530        0.5  -0.866025  0.845596 -0.533823  372.9
# 4   0.201299  0.979530        0.5  -0.866025  0.845596 -0.533823  385.6
# ..       ...       ...        ...        ...       ...       ...    ...
# 45 -0.101168 -0.994869        0.5  -0.866025  0.696551 -0.717507  576.7
# 46 -0.101168 -0.994869        0.5  -0.866025  0.696551 -0.717507  607.6
# 47 -0.101168 -0.994869        0.5  -0.866025  0.696551 -0.717507  525.3
# 48 -0.101168 -0.994869        0.5  -0.866025  0.696551 -0.717507  368.7
# 49 -0.101168 -0.994869        0.5  -0.866025  0.696551 -0.717507  739.7
#
#     population_density  population
# 0                 17.3    10705.00
# 1                 20.6    16004.00
# 2                 21.2     3153.00
# 3                  9.3     3515.00
# 4                374.6   138865.00
# ..                 ...         ...
# 45                23.8       11.99
# 46               133.9    78508.00
# 47                47.7    22252.00
# 48                36.3    11348.00
# 49                25.1    16310.00
#
# [50 rows x 45 columns]

# %%
df_mosquitoes = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Culex_Predictions_2023-May.csv', encoding = enc)
df_mosquitoes
# Out:
#             x          y dt_placement  mosq_pred
# 0   22.750267  39.710970   2023-05-01         35
# 1   22.692366  39.136391   2023-05-01          6
# 2   24.073790  39.328960   2023-05-01          1
# 3   21.430513  39.221380   2023-05-01        105
# 4   22.883800  39.351977   2023-05-01         30
# ..        ...        ...          ...        ...
# 45  22.553160  39.852112   2023-05-16        139
# 46  21.797560  39.635058   2023-05-16         77
# 47  22.343000  39.828472   2023-05-16         98
# 48  22.020557  39.603750   2023-05-16        110
# 49  22.465904  39.311296   2023-05-16         29
#
# [50 rows x 4 columns]

# %%
df_mosquitoes['dt_placement'] = pd.to_datetime(dataset['dt_placement'])
df_mosquitoes['x'] = df_mosquitoes['x'].apply(lambda x : round(x,5))
df_mosquitoes['y'] = df_mosquitoes['y'].apply(lambda x : round(x,5))

# %%
distances, indicies = calculate_nearest_topological(dataset, df_mosquitoes)

# %%
print(f'Min distance: {min(distances)}')
print(f'Max distance: {max(distances)}')
# Out:
# Min distance: 0.0
# Max distance: 0.0008571819480130482

# %%
df_mosq = pd.DataFrame(columns=df_mosquitoes.columns)

# %%
for index in indicies:
    df_mosq = df_mosq.append(df_mosquitoes.iloc[[index]])

df_mosq.drop(columns=['x', 'y', 'dt_placement'], inplace = True)
df_mosq.reset_index(drop=True, inplace=True)

# %%
dataset = pd.concat([dataset, df_mosq], axis=1, join = 'outer')

# %%
dataset.head()
# Out:
#   dt_placement       lau1      nuts2         x         y  year  month  \
# 0   2023-05-01      αγιας  θεσσαλιας  22.75027  39.71097  2023      5
# 1   2023-05-01    αλμυρου  θεσσαλιας  22.69237  39.13639  2023      5
# 2   2023-05-01  αλοννησου  θεσσαλιας  24.07379  39.32896  2023      5
# 3   2023-05-01   αργιθεας  θεσσαλιας  21.43051  39.22138  2023      5
# 4   2023-05-01      βολου  θεσσαλιας  22.88380  39.35198  2023      5
#
#        ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  \
# 0  0.509207  0.119405 -0.451816 -0.119405   0.531592   0.254587  -0.428750
# 1  0.645191  0.302370 -0.529492 -0.302370   0.618919   0.280067  -0.511682
# 2  0.493058  0.137236 -0.431136 -0.137236   0.499103   0.137082  -0.425521
# 3  0.597637  0.302454 -0.493106 -0.302454   0.560003   0.257320  -0.465701
# 4  0.510673  0.128033 -0.451844 -0.128033   0.513199   0.149993  -0.449576
#
#    ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std       lst_day  \
# 0  -0.254587  0.077768  0.058778  0.056475  0.058778  14608.285714
# 1  -0.280067  0.056373  0.054701  0.034039  0.054701  14633.444444
# 2  -0.137082  0.036059  0.052143  0.019232  0.052143  14533.000000
# 3  -0.257320  0.040313  0.053018  0.024440  0.053018  14526.000000
# 4  -0.149993  0.048106  0.049815  0.032318  0.049815  14920.000000
#
#       lst_night  lst_jan_day_mean  lst_jan_night_mean  lst_feb_day_mean  \
# 0  14153.000000      14158.229570        13810.607919      14132.381348
# 1  14200.333333      14236.213555        13871.070700      14235.830525
# 2  14299.000000      14303.111111        14120.666667      14247.800000
# 3  13953.000000      13984.796537        13767.640659      13972.290278
# 4  14251.333333      14310.624820        13874.456288      14320.436508
#
#    lst_feb_night_mean  lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  \
# 0        13770.111663      14483.438175        13900.012383      14528.540407
# 1        13815.772792      14503.039805        14000.498550      14640.452078
# 2        14074.285714      14424.133333        14144.066667      14543.000000
# 3        13581.276389      14264.541026        13850.111111      14318.077381
# 4        13834.927778      14589.631410        13978.820513      14708.583333
#
#    lst_apr_night_mean  acc_rainfall_jan  acc_rainfall_1week  \
# 0        14007.143707         76.675988            2.381410
# 1        14072.106614        208.946587            3.480882
# 2        14215.666667        163.677945            7.946645
# 3        13868.033333        141.474393            8.412601
# 4        14067.142857        146.622452            1.161971
#
#    acc_rainfall_2week  case  day  week  eq_distance   day_sin  day_cos  \
# 0           17.837466     0    1    18     45.76610  0.201299  0.97953
# 1           69.269711     0    1    18     45.23937  0.201299  0.97953
# 2           55.220344     0    1    18     46.11198  0.201299  0.97953
# 3           10.754827     0    1    18     44.69433  0.201299  0.97953
# 4           49.566698     0    1    18     45.52194  0.201299  0.97953
#
#    month_sin  month_cos  week_sin  week_cos   area  population_density  \
# 0        0.5  -0.866025  0.845596 -0.533823  661.8                17.3
# 1        0.5  -0.866025  0.845596 -0.533823  905.4                20.6
# 2        0.5  -0.866025  0.845596 -0.533823  129.6                21.2
# 3        0.5  -0.866025  0.845596 -0.533823  372.9                 9.3
# 4        0.5  -0.866025  0.845596 -0.533823  385.6               374.6
#
#    population mosq_pred
# 0     10705.0        35
# 1     16004.0         6
# 2      3153.0         1
# 3      3515.0       105
# 4    138865.0        30

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
dataset.reset_index(inplace=True, drop=True)

# %%
dataset = calculate_mosq_previous(dataset)

# %%
dataset = convert_temperature(dataset)

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
dataset['case'].value_counts()
# Out:
# 0    50
# Name: case, dtype: int64

# %%
dataset = dataset.astype({'mosq_pred' : 'int', 'mosq_previous' : 'int'})

# %%
dataset = convert_multiple_cases(dataset)

# %%
dataset['case'].value_counts()
# Out:
# 0    50
# Name: case, dtype: int64

# %%
cols = dataset.columns

# %%
cols
# Out:
# Index(['dt_placement', 'lau1', 'nuts2', 'x', 'y', 'year', 'month', 'ndvi',
#        'ndmi', 'ndwi', 'ndbi', 'ndvi_mean', 'ndmi_mean', 'ndwi_mean',
#        'ndbi_mean', 'ndvi_std', 'ndmi_std', 'ndwi_std', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_day_mean', 'lst_jan_night_mean',
#        'lst_feb_day_mean', 'lst_feb_night_mean', 'lst_mar_day_mean',
#        'lst_mar_night_mean', 'lst_apr_day_mean', 'lst_apr_night_mean',
#        'acc_rainfall_jan', 'acc_rainfall_1week', 'acc_rainfall_2week', 'case',
#        'day', 'week', 'eq_distance', 'day_sin', 'day_cos', 'month_sin',
#        'month_cos', 'week_sin', 'week_cos', 'area', 'population_density',
#        'population', 'mosq_pred', 'mosq_previous', 'lst'],
#       dtype='object')

# %%
len(cols)
# Out:
# 48

# %%
# check columns

# %%
final_columns = ['x', 'y', 'dt_placement', 'nuts2', 'lau1', 'day', 
                 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 
                 'month_cos', 'week_sin', 'week_cos', 'area', 'population',
                 'population_density', 'eq_distance', 'ndvi', 'ndmi', 'ndwi', 'ndbi', 
                 'ndvi_mean', 'ndmi_mean', 'ndwi_mean', 'ndbi_mean', 
                 'ndvi_std', 'ndmi_std', 'ndwi_std', 'ndbi_std', 'lst',
                 'lst_day', 'lst_night','lst_jan_day_mean', 'lst_jan_night_mean', 
                 'lst_feb_day_mean','lst_feb_night_mean', 'lst_mar_day_mean', 
                 'lst_mar_night_mean', 'lst_apr_day_mean', 'lst_apr_night_mean',
                 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan',
                 'mosq_pred', 'mosq_previous', 'case']

# %%
len(final_columns)
# Out:
# 48

# %%
dataset_final = dataset[final_columns].copy()

# %%
dataset_final
# Out:
#            x         y dt_placement      nuts2        lau1  day  month  week  \
# 0   22.75027  39.71097   2023-05-01  θεσσαλιας       αγιας    1      5    18
# 1   22.69237  39.13639   2023-05-01  θεσσαλιας     αλμυρου    1      5    18
# 2   24.07379  39.32896   2023-05-01  θεσσαλιας   αλοννησου    1      5    18
# 3   21.43051  39.22138   2023-05-01  θεσσαλιας    αργιθεας    1      5    18
# 4   22.88380  39.35198   2023-05-01  θεσσαλιας       βολου    1      5    18
# ..       ...       ...          ...        ...         ...  ...    ...   ...
# 45  22.55316  39.85211   2023-05-16  θεσσαλιας      τεμπων   16      5    20
# 46  21.79756  39.63506   2023-05-16  θεσσαλιας   τρικκαιων   16      5    20
# 47  22.34300  39.82847   2023-05-16  θεσσαλιας    τυρναβου   16      5    20
# 48  22.02056  39.60375   2023-05-16  θεσσαλιας  φαρκαδονας   16      5    20
# 49  22.46590  39.31130   2023-05-16  θεσσαλιας    φαρσαλων   16      5    20
#
#     year   day_sin   day_cos  month_sin  month_cos  week_sin  week_cos   area  \
# 0   2023  0.201299  0.979530        0.5  -0.866025  0.845596 -0.533823  661.8
# 1   2023  0.201299  0.979530        0.5  -0.866025  0.845596 -0.533823  905.4
# 2   2023  0.201299  0.979530        0.5  -0.866025  0.845596 -0.533823  129.6
# 3   2023  0.201299  0.979530        0.5  -0.866025  0.845596 -0.533823  372.9
# 4   2023  0.201299  0.979530        0.5  -0.866025  0.845596 -0.533823  385.6
# ..   ...       ...       ...        ...        ...       ...       ...    ...
# 45  2023 -0.101168 -0.994869        0.5  -0.866025  0.696551 -0.717507  576.7
# 46  2023 -0.101168 -0.994869        0.5  -0.866025  0.696551 -0.717507  607.6
# 47  2023 -0.101168 -0.994869        0.5  -0.866025  0.696551 -0.717507  525.3
# 48  2023 -0.101168 -0.994869        0.5  -0.866025  0.696551 -0.717507  368.7
# 49  2023 -0.101168 -0.994869        0.5  -0.866025  0.696551 -0.717507  739.7
#
#     population  population_density  eq_distance      ndvi      ndmi      ndwi  \
# 0     10705.00                17.3     45.76610  0.509207  0.119405 -0.451816
# 1     16004.00                20.6     45.23937  0.645191  0.302370 -0.529492
# 2      3153.00                21.2     46.11198  0.493058  0.137236 -0.431136
# 3      3515.00                 9.3     44.69433  0.597637  0.302454 -0.493106
# 4    138865.00               374.6     45.52194  0.510673  0.128033 -0.451844
# ..         ...                 ...          ...       ...       ...       ...
# 45       11.99                23.8     45.79122  0.511804  0.199036 -0.425108
# 46    78508.00               133.9     45.23352  0.503202  0.197929 -0.443614
# 47    22252.00                47.7     45.66746  0.598336  0.234130 -0.507208
# 48    11348.00                36.3     45.31404  0.462285  0.109702 -0.426134
# 49    16310.00                25.1     45.27797  0.618303  0.341987 -0.529362
#
#         ndbi  ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  \
# 0  -0.119405   0.531592   0.254587  -0.428750  -0.254587  0.077768  0.058778
# 1  -0.302370   0.618919   0.280067  -0.511682  -0.280067  0.056373  0.054701
# 2  -0.137236   0.499103   0.137082  -0.425521  -0.137082  0.036059  0.052143
# 3  -0.302454   0.560003   0.257320  -0.465701  -0.257320  0.040313  0.053018
# 4  -0.128033   0.513199   0.149993  -0.449576  -0.149993  0.048106  0.049815
# ..       ...        ...        ...        ...        ...       ...       ...
# 45 -0.199036   0.487281   0.195427  -0.402644  -0.195427  0.026293  0.042519
# 46 -0.197929   0.551718   0.234198  -0.473066  -0.234198  0.062168  0.069954
# 47 -0.234130   0.481039   0.179341  -0.408239  -0.179341  0.027967  0.045633
# 48 -0.109702   0.478616   0.147639  -0.435837  -0.147639  0.061883  0.067354
# 49 -0.341987   0.515243   0.257331  -0.451428  -0.257331  0.043641  0.055413
#
#     ndwi_std  ndbi_std        lst    lst_day  lst_night  lst_jan_day_mean  \
# 0   0.056475  0.058778  14.462857  19.015714   9.910000         10.014591
# 1   0.034039  0.054701  15.187778  19.518889  10.856667         11.574271
# 2   0.019232  0.052143  15.170000  17.510000  12.830000         12.912222
# 3   0.024440  0.053018  11.640000  17.370000   5.910000          6.545931
# 4   0.032318  0.049815  18.563333  25.250000  11.876667         13.062496
# ..       ...       ...        ...        ...        ...               ...
# 45  0.016377  0.042519  14.990000  19.258000  10.722000          9.486897
# 46  0.045223  0.069954  15.660000  22.366000   8.954000         10.673662
# 47  0.018021  0.045633  17.030000  22.135000  11.925000         10.962639
# 48  0.036424  0.067354  16.656667  21.450000  11.863333         10.430500
# 49  0.030781  0.055413  16.817143  22.644286  10.990000         11.498953
#
#     lst_jan_night_mean  lst_feb_day_mean  lst_feb_night_mean  \
# 0             3.062158          9.497627            2.252233
# 1             4.271414         11.566611            3.165456
# 2             9.263333         11.806000            8.335714
# 3             2.202813          6.295806           -1.524472
# 4             4.339126         13.258730            3.548556
# ..                 ...               ...                 ...
# 45            2.246400          9.153402            1.055296
# 46            2.566048         13.918486            2.152524
# 47            1.977582         11.857741            1.268813
# 48            3.139634         13.365417            3.126250
# 49            3.291616         13.132560            1.653393
#
#     lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  \
# 0          16.518764            4.850248         17.420808
# 1          16.910796            6.859971         19.659042
# 2          15.332667            9.731333         17.710000
# 3          12.140821            3.852222         13.211548
# 4          18.642628            6.426410         21.021667
# ..               ...                 ...               ...
# 45         15.363382            4.702971         16.772958
# 46         19.277797            6.588566         20.641230
# 47         18.244189            5.305865         20.608426
# 48         19.033354            7.233108         21.248181
# 49         18.942854            6.314475         21.396330
#
#     lst_apr_night_mean  acc_rainfall_1week  acc_rainfall_2week  \
# 0             6.992874            2.381410           17.837466
# 1             8.292132            3.480882           69.269711
# 2            11.163333            7.946645           55.220344
# 3             4.210667            8.412601           10.754827
# 4             8.192857            1.161971           49.566698
# ..                 ...                 ...                 ...
# 45            6.591786            6.463702           27.740014
# 46            7.794762           13.713732           32.495788
# 47            7.695605            5.999722           12.930523
# 48            8.766786           17.629915           34.227020
# 49            7.640249           15.536300           27.173840
#
#     acc_rainfall_jan  mosq_pred  mosq_previous  case
# 0          76.675988         35              0     0
# 1         208.946587          6              0     0
# 2         163.677945          1              0     0
# 3         141.474393        105              0     0
# 4         146.622452         30              0     0
# ..               ...        ...            ...   ...
# 45         90.443463        154            154     0
# 46        176.999873         69             69     0
# 47         67.877909         83             83     0
# 48        137.263723        113            113     0
# 49        146.754341         20             20     0
#
# [50 rows x 48 columns]

# %%
dataset_final.to_csv(f"../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Dataset_2023-May.csv", encoding = enc, index = False)
