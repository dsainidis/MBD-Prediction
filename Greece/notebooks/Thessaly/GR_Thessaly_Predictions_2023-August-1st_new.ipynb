# %%
import numpy as np
import pandas as pd
import random
import csv
import geopandas as gpd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, MaxAbsScaler
from sklearn.impute import KNNImputer
import sys
import pickle

sys.path.insert(0, "../../../Modules")

pd.set_option('display.max_columns', None)
random.seed(0)
np.random.seed(0)

from utils import *
from utils import process_greek

enc = 'utf-8'
shapefiles_folder = "C:/Users/dimit/Documents/noa hoard/Greece Shapefiles"
# Out:
# c:\Users\dimit\AppData\Local\Programs\Python\Python39\lib\site-packages\geopandas\_compat.py:112: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
NUTS0 = 'GR'
NUTS2 = 'Thessaly'

# %%
YEAR = 2023
MONTH = 'August'
PERIOD = '1st'

# %%
model = pickle.load(open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Linear_model_new.pkl', 'rb'))
scaler = pickle.load(open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Scaler_new.pkl', 'rb'))
imputer = pickle.load(open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Imputer_new.pkl', 'rb'))

# %%
data_test = read_data(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Dataset_{YEAR}-{MONTH}-{PERIOD}.csv')
data_test.head()
# Out:
#           x         y dt_placement      nuts2       lau1  day  month  week  \
# 0  22.76105  39.69186   2023-08-01  θεσσαλιας      αγιας    1      8    31
# 1  22.72671  39.12560   2023-08-01  θεσσαλιας    αλμυρου    1      8    31
# 2  23.99842  39.24585   2023-08-01  θεσσαλιας  αλοννησου    1      8    31
# 3  21.48510  39.29630   2023-08-01  θεσσαλιας   αργιθεας    1      8    31
# 4  22.93502  39.38117   2023-08-01  θεσσαλιας      βολου    1      8    31
#
#    year   day_sin  day_cos  month_sin  month_cos  week_sin  week_cos   area  \
# 0  2023  0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044  661.8
# 1  2023  0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044  905.4
# 2  2023  0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044  129.6
# 3  2023  0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044  372.9
# 4  2023  0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044  385.6
#
#    population  population_density  eq_distance      ndvi      ndmi      ndwi  \
# 0     10705.0                17.3     45.75488  0.557438  0.178412 -0.487907
# 1     16004.0                20.6     45.24728  0.420595  0.107140 -0.386961
# 2      3153.0                21.2     46.00175 -0.253788  0.387324  0.474667
# 3      3515.0                 9.3     44.78626  0.555144  0.196079 -0.487694
# 4    138865.0               374.6     45.57293  0.390260  0.033993 -0.363181
#
#        ndbi  ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  \
# 0 -0.178412   0.520525   0.179898  -0.454158  -0.179898  0.051547  0.045856
# 1 -0.107140   0.395690   0.099732  -0.366670  -0.099732  0.072532  0.065109
# 2 -0.387324  -0.232008   0.321657   0.441268  -0.321657  0.015256  0.046027
# 3 -0.196079   0.557115   0.191109  -0.488342  -0.191109  0.077085  0.064546
# 4 -0.033993   0.334020   0.026989  -0.317529  -0.026989  0.057719  0.059415
#
#    ndwi_std  ndbi_std        lst    lst_day  lst_night  lst_jan_day_mean  \
# 0  0.036236  0.045856  26.007188  30.631250  21.383125         10.418186
# 1  0.051319  0.065109  28.216667  34.460833  21.972500         11.219310
# 2  0.024071  0.046027        NaN        NaN        NaN               NaN
# 3  0.052469  0.064546  22.970769  26.848462  19.093077          6.942786
# 4  0.050660  0.059415  28.627500  34.916667  22.338333         12.159420
#
#    lst_jan_night_mean  lst_feb_day_mean  lst_feb_night_mean  lst_mar_day_mean  \
# 0            4.056923         10.285211            3.423839         16.670680
# 1            3.845804         10.731281            3.006374         16.701534
# 2                 NaN               NaN                 NaN               NaN
# 3            1.831897          7.062325           -0.605892         13.120876
# 4            4.198851         11.394699            3.845437         17.241419
#
#    lst_mar_night_mean  lst_apr_day_mean  lst_apr_night_mean  \
# 0            6.227661         17.857476            7.916795
# 1            6.377584         19.115966            8.094541
# 2                 NaN               NaN                 NaN
# 3            3.695211         13.925591            4.285066
# 4            5.994943         19.899661            8.124530
#
#    acc_rainfall_1week  acc_rainfall_2week  acc_rainfall_jan  \
# 0            0.000000            0.000000        184.584776
# 1            0.000111            0.000111        278.949415
# 2            0.000000            0.000000        255.685311
# 3            0.000000            0.000000        229.373225
# 4            0.000000            0.000000        208.427446
#
#    distance_to_coast  distance_to_river  slope_mean_1km  aspect_mean_200m  \
# 0        8282.127022        1331.619869               1        123.585589
# 1       10017.207897        1610.666116              14        259.585198
# 2        1484.683259       55302.082778              24        302.637680
# 3       19327.278832        1925.318354              27        284.268894
# 4        5935.142744        3071.988689               5        143.181190
#
#    elevation_mean_1km  hillshade_mean_1km  fs_area_1km  flow_accu_200m  \
# 0          121.767859          183.036108          0.0       21.311709
# 1          342.571837          171.163634          0.0        3.415750
# 2          165.397106          195.027810          0.0        1.676994
# 3         1127.254453          234.678996          0.0        1.719393
# 4          234.931813          174.426021          0.0        4.643743
#
#    lc_prop1  lc_prop1_assessment  lc_prop2  lc_prop2_assessment  lc_prop3  \
# 0        31                   90        30                 90.0        30
# 1        11                   80        10                 72.0        10
# 2        21                   94        20                 94.0        20
# 3        21                   88        20                 88.0        20
# 4        31                   91        30                 91.0        30
#
#    lc_prop3_assessment  lc_type1  lc_type2  lc_type3  lc_type4  lc_type5  lw  \
# 0                   90        10        10         1         6         6   2
# 1                   72         1         1         7         1         1   2
# 2                   94         8         8         4         1         1   2
# 3                   88         8         8         4         1         1   2
# 4                   91        10        10         1         6         6   2
#
#    qc  mosq_pred  mosq_previous  case
# 0   0         33              0     0
# 1   0         35              0     0
# 2   0          1              0     0
# 3   0         41              0     0
# 4   0         50              0     0

# %%
features_to_remove = ['x', 'y', 'eq_distance','day', 'month', 'week', 'year', 'lc_prop1_assessment',
                    'lc_prop2', 'lc_prop2_assessment', 'lc_prop3', 'lc_prop3_assessment',
                    'lc_type2', 'lc_type3', 'lc_type4', 'lc_type5', 'lw', 'qc','ndvi_mean', 'ndmi_mean', 'ndwi_mean', 'ndbi_mean', 'ndvi_std',
                    'ndmi_std', 'ndwi_std', 'ndbi_std',]

# %%
object_cols = data_test.select_dtypes(include=['object']).columns.to_list()
removed_cols = features_to_remove

X_test = data_test.drop(columns = ['case'] + object_cols + removed_cols)
y_test = data_test['case']

X_test = scaler.transform(X_test)
X_test = imputer.fit_transform(X_test)

results_test = inference_lin_model(model, data_test, X_test, y_test)

# %%
results_test.drop(columns='case', inplace= True)
results_test
# Out:
#            x         y               lau1  day  month  year     score
# 0   22.34107  39.61048          λαρισαιων    1      8  2023  0.987173
# 1   22.29611  39.76297           τυρναβου    1      8  2023  0.950297
# 2   22.51098  39.51390            κιλελερ    1      8  2023  0.927724
# 3   22.54288  39.85090             τεμπων    1      8  2023  0.925084
# 4   22.15952  39.95174          ελασσονας    1      8  2023  0.925042
# 5   21.77435  39.61293          τρικκαιων    1      8  2023  0.910933
# 6   22.02629  39.60300         φαρκαδονας    1      8  2023  0.901044
# 7   22.93502  39.38117              βολου    1      8  2023  0.900567
# 8   21.48510  39.29630           αργιθεας    1      8  2023  0.900520
# 9   22.43796  39.30328           φαρσαλων    1      8  2023  0.866652
# 10  22.08995  39.24048            σοφαδων    1      8  2023  0.832299
# 11  21.89535  39.26951          καρδιτσας    1      8  2023  0.812009
# 12  22.09265  39.48079             παλαμα    1      8  2023  0.794789
# 13  22.72671  39.12560            αλμυρου    1      8  2023  0.764615
# 14  22.76105  39.69186              αγιας    1      8  2023  0.713592
# 15  22.80830  39.43236      ρηγα φερραιου    1      8  2023  0.624732
# 16  21.69908  39.40010          μουζακιου    1      8  2023  0.442844
# 17  21.49996  39.73065         καλαμπακας    1      8  2023  0.433273
# 18  21.42866  39.48142              πυλης    1      8  2023  0.423178
# 19  23.45788  39.16770            σκιαθου    1      8  2023  0.279857
# 20  23.69076  39.11627           σκοπελου    1      8  2023  0.220381
# 21  21.72247  39.30345    λιμνης πλαστηρα    1      8  2023  0.187360
# 22  23.23259  39.25367      νοτιου πηλιου    1      8  2023  0.175751
# 23  23.07800  39.45774  ζαγορας μουρεσιου    1      8  2023  0.062185
# 24  23.99842  39.24585          αλοννησου    1      8  2023  0.037187

# %%
bins_path = f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Bins_{YEAR}.csv'

bins = []

with open(bins_path, mode='r', newline='') as file:
    reader = csv.reader(file)
    for row in reader:
        bins.extend(map(float, row))

print(bins)
# Out:
# [0.0, 0.0080309448997414, 0.0860446074909823, 0.5109550767195234, 0.8201371322355278, 0.9305335064919854, 1.0]

# %%
results_test['risk_class'] = pd.cut(results_test['score'], bins=bins, labels=False, include_lowest=True)
results_test
# Out:
#            x         y               lau1  day  month  year     score  \
# 0   22.34107  39.61048          λαρισαιων    1      8  2023  0.987173
# 1   22.29611  39.76297           τυρναβου    1      8  2023  0.950297
# 2   22.51098  39.51390            κιλελερ    1      8  2023  0.927724
# 3   22.54288  39.85090             τεμπων    1      8  2023  0.925084
# 4   22.15952  39.95174          ελασσονας    1      8  2023  0.925042
# 5   21.77435  39.61293          τρικκαιων    1      8  2023  0.910933
# 6   22.02629  39.60300         φαρκαδονας    1      8  2023  0.901044
# 7   22.93502  39.38117              βολου    1      8  2023  0.900567
# 8   21.48510  39.29630           αργιθεας    1      8  2023  0.900520
# 9   22.43796  39.30328           φαρσαλων    1      8  2023  0.866652
# 10  22.08995  39.24048            σοφαδων    1      8  2023  0.832299
# 11  21.89535  39.26951          καρδιτσας    1      8  2023  0.812009
# 12  22.09265  39.48079             παλαμα    1      8  2023  0.794789
# 13  22.72671  39.12560            αλμυρου    1      8  2023  0.764615
# 14  22.76105  39.69186              αγιας    1      8  2023  0.713592
# 15  22.80830  39.43236      ρηγα φερραιου    1      8  2023  0.624732
# 16  21.69908  39.40010          μουζακιου    1      8  2023  0.442844
# 17  21.49996  39.73065         καλαμπακας    1      8  2023  0.433273
# 18  21.42866  39.48142              πυλης    1      8  2023  0.423178
# 19  23.45788  39.16770            σκιαθου    1      8  2023  0.279857
# 20  23.69076  39.11627           σκοπελου    1      8  2023  0.220381
# 21  21.72247  39.30345    λιμνης πλαστηρα    1      8  2023  0.187360
# 22  23.23259  39.25367      νοτιου πηλιου    1      8  2023  0.175751
# 23  23.07800  39.45774  ζαγορας μουρεσιου    1      8  2023  0.062185
# 24  23.99842  39.24585          αλοννησου    1      8  2023  0.037187
#
#     risk_class
# 0            5
# 1            5
# 2            4
# 3            4
# 4            4
# 5            4
# 6            4
# 7            4
# 8            4
# 9            4
# 10           4
# 11           3
# 12           3
# 13           3
# 14           3
# 15           3
# 16           2
# 17           2
# 18           2
# 19           2
# 20           2
# 21           2
# 22           2
# 23           1
# 24           1

# %%
# results_test.to_csv(f"../../data/{NUTS2}/results/{NUTS0}_{NUTS2}_Results_{YEAR}-{MONTH}-{PERIOD}.csv", encoding = enc, index = False)

# %%
##TODO Visualisation of results
