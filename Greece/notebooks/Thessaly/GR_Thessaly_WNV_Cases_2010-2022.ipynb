# %% [markdown]
# ## Creates the **Epidemiological Timeline** for a specific region by using the available data on WNV Cases ##

# %%
import pandas as pd

enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 10

# %%
NUTS0 = 'GR'
NUTS2 = 'Thessaly'
NUTS2_EL = 'θεσσαλιας'

# %% [markdown]
# ## 2010 - 2021 ##

# %%
data_2021 = pd.read_csv(f'../../data/{NUTS0}_WNV_cases_2010-2021_processed.csv', encoding = enc)
data_2021.head(5)
# Out:
#   onset of symptoms  year  month  day                 nuts2         nuts3  \
# 0        2010-07-28  2010      7   28  κεντρικης μακεδονιας  θεσσαλονικης
# 1        2010-07-22  2010      7   22  κεντρικης μακεδονιας       ημαθιας
# 2        2010-07-24  2010      7   24  κεντρικης μακεδονιας        κιλκις
# 3        2010-07-30  2010      7   30  κεντρικης μακεδονιας        κιλκις
# 4        2010-07-06  2010      7    6  κεντρικης μακεδονιας        σερρων
#
#            lau1                 lau2  age sex
# 0  θεσσαλονικης  παπαφη, θεσσαλονικη   75   f
# 1       βεροιας               βεροια   78   m
# 2        κιλκις          λεβεντοχωρι   70   f
# 3        κιλκις              καμπανη   74   m
# 4     ηρακλειας           ποντισμενο   19   f

# %%
df_21 = data_2021[data_2021['nuts2'].isin([NUTS2_EL])].copy()

# %%
df_21.reset_index(drop = True, inplace = True)

# %%
df_21
# Out:
#     onset of symptoms  year  month  day      nuts2      nuts3       lau1  \
# 0          2010-07-28  2010      7   28  θεσσαλιας    λαρισας      αγιας
# 1          2010-08-11  2010      8   11  θεσσαλιας    λαρισας  ελασσονας
# 2          2010-08-21  2010      8   21  θεσσαλιας    λαρισας  λαρισαιων
# 3          2010-08-27  2010      8   27  θεσσαλιας    λαρισας  ελασσονας
# 4          2010-09-02  2010      9    2  θεσσαλιας    λαρισας  ελασσονας
# ..                ...   ...    ...  ...        ...        ...        ...
# 104        2020-08-03  2020      8    3  θεσσαλιας    λαρισας  λαρισαιων
# 105        2020-08-10  2020      8   10  θεσσαλιας  καρδιτσας  καρδιτσας
# 106        2020-08-20  2020      8   20  θεσσαλιας  καρδιτσας  καρδιτσας
# 107        2020-09-05  2020      9    5  θεσσαλιας   τρικαλων      πυλης
# 108        2020-09-10  2020      9   10  θεσσαλιας   τρικαλων  τρικκαιων
#
#                   lau2  age sex
# 0               ομολιο   59   m
# 1           τσαριτσανη   58   f
# 2               λαρισα   72   f
# 3             μεσοχωρι   77   f
# 4             ελασσονα   80   f
# ..                 ...  ...  ..
# 104             λαρισα   87   f
# 105         πτελοπουλα   28   f
# 106  μυρινα (η μυρινη)   70   m
# 107    παλαιομοναστηρο   71   m
# 108           πατουλια   81   m
#
# [109 rows x 10 columns]

# %%
wnv_lau1_list = df_21['lau1'].drop_duplicates().sort_values().tolist()

with open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_2010-2021_LAU1_Units_Processed.txt', 'w', encoding=enc) as f:
    for item in wnv_lau1_list:
        f.write("%s\n" % item)
  
print(f"Number of LAU1 Units in {NUTS2} (from cases): {len(wnv_lau1_list)}")
# Out:
# Number of LAU1 Units in Thessaly (from cases): 15

# %%
df_21['period'] = df_21.apply(lambda row: 1 if (row['day']>=1 and row['day']<=15) else 2, axis = 1)
df_21['dt_placement'] = df_21.apply(lambda row: f"{row['year']:04}-{row['month']:02}-{1 if row['period'] == 1 else 16:02}", axis = 1)

df_21['dt_placement']= pd.to_datetime(df_21['dt_placement'])
df_21['case'] = 1

# %%
df_21
# Out:
#     onset of symptoms  year  month  day      nuts2      nuts3       lau1  \
# 0          2010-07-28  2010      7   28  θεσσαλιας    λαρισας      αγιας
# 1          2010-08-11  2010      8   11  θεσσαλιας    λαρισας  ελασσονας
# 2          2010-08-21  2010      8   21  θεσσαλιας    λαρισας  λαρισαιων
# 3          2010-08-27  2010      8   27  θεσσαλιας    λαρισας  ελασσονας
# 4          2010-09-02  2010      9    2  θεσσαλιας    λαρισας  ελασσονας
# ..                ...   ...    ...  ...        ...        ...        ...
# 104        2020-08-03  2020      8    3  θεσσαλιας    λαρισας  λαρισαιων
# 105        2020-08-10  2020      8   10  θεσσαλιας  καρδιτσας  καρδιτσας
# 106        2020-08-20  2020      8   20  θεσσαλιας  καρδιτσας  καρδιτσας
# 107        2020-09-05  2020      9    5  θεσσαλιας   τρικαλων      πυλης
# 108        2020-09-10  2020      9   10  θεσσαλιας   τρικαλων  τρικκαιων
#
#                   lau2  age sex  period dt_placement  case
# 0               ομολιο   59   m       2   2010-07-16     1
# 1           τσαριτσανη   58   f       1   2010-08-01     1
# 2               λαρισα   72   f       2   2010-08-16     1
# 3             μεσοχωρι   77   f       2   2010-08-16     1
# 4             ελασσονα   80   f       1   2010-09-01     1
# ..                 ...  ...  ..     ...          ...   ...
# 104             λαρισα   87   f       1   2020-08-01     1
# 105         πτελοπουλα   28   f       1   2020-08-01     1
# 106  μυρινα (η μυρινη)   70   m       2   2020-08-16     1
# 107    παλαιομοναστηρο   71   m       1   2020-09-01     1
# 108           πατουλια   81   m       1   2020-09-01     1
#
# [109 rows x 13 columns]

# %%
df_21.drop(columns = ['onset of symptoms', 'day', 'nuts3', 'lau2', 'age', 'sex', 'period'], inplace = True)

# %%
df_21 = df_21[['month', 'year', 'lau1', 'nuts2', 'dt_placement', 'case']]

# %%
df_21
# Out:
#      month  year       lau1      nuts2 dt_placement  case
# 0        7  2010      αγιας  θεσσαλιας   2010-07-16     1
# 1        8  2010  ελασσονας  θεσσαλιας   2010-08-01     1
# 2        8  2010  λαρισαιων  θεσσαλιας   2010-08-16     1
# 3        8  2010  ελασσονας  θεσσαλιας   2010-08-16     1
# 4        9  2010  ελασσονας  θεσσαλιας   2010-09-01     1
# ..     ...   ...        ...        ...          ...   ...
# 104      8  2020  λαρισαιων  θεσσαλιας   2020-08-01     1
# 105      8  2020  καρδιτσας  θεσσαλιας   2020-08-01     1
# 106      8  2020  καρδιτσας  θεσσαλιας   2020-08-16     1
# 107      9  2020      πυλης  θεσσαλιας   2020-09-01     1
# 108      9  2020  τρικκαιων  θεσσαλιας   2020-09-01     1
#
# [109 rows x 6 columns]

# %%
case_months = df_21['month'].drop_duplicates().sort_values().tolist()
case_months
# Out:
# [7, 8, 9, 10]

# %%
case_years = df_21['year'].drop_duplicates().sort_values().tolist()
case_years
# Out:
# [2010, 2011, 2018, 2019, 2020]

# %%
with open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_2010-2021_Cases_Dates.txt', 'w', encoding=enc) as f:

    f.write("%s: " % 'months')
    for item in case_months:
        f.write("%s, " % item)

    f.write("\n")

    f.write("%s: " % 'years')
    for item in case_years:
        f.write("%s, " % item)

# %%
## Creating DataFrame to hold negative examples

df_timeline = pd.DataFrame(columns = ['lau1', 'nuts2', 'dt_placement', 'case'])

for municipality in df_21['lau1'].drop_duplicates().sort_values():
    for year in range(2010, 2023):
        for month in range (6,11):
            df_timeline = df_timeline.append({'lau1' : municipality, 'nuts2' : NUTS2_EL, 'dt_placement' : f"{year:04}-{month:02}-{1:02}", 'case' : 0}, ignore_index = True)
            df_timeline = df_timeline.append({'lau1' : municipality, 'nuts2' : NUTS2_EL, 'dt_placement' : f"{year:04}-{month:02}-{16:02}", 'case' : 0}, ignore_index = True)
            
df_timeline
# Out:
#           lau1      nuts2 dt_placement case
# 0        αγιας  θεσσαλιας   2010-06-01    0
# 1        αγιας  θεσσαλιας   2010-06-16    0
# 2        αγιας  θεσσαλιας   2010-07-01    0
# 3        αγιας  θεσσαλιας   2010-07-16    0
# 4        αγιας  θεσσαλιας   2010-08-01    0
# ...        ...        ...          ...  ...
# 1945  φαρσαλων  θεσσαλιας   2022-08-16    0
# 1946  φαρσαλων  θεσσαλιας   2022-09-01    0
# 1947  φαρσαλων  θεσσαλιας   2022-09-16    0
# 1948  φαρσαλων  θεσσαλιας   2022-10-01    0
# 1949  φαρσαλων  θεσσαλιας   2022-10-16    0
#
# [1950 rows x 4 columns]

# %%
df_timeline['dt_placement']= pd.to_datetime(df_timeline['dt_placement'])

# %%
df_21.reset_index(inplace = True, drop=True)
df_timeline.reset_index(inplace = True, drop=True)

# %%
## Add cases to negative examples DataFrame

#iterrate DataFrame with cases by row
for index, row in df_21.iterrows():
    #find index at DataFrame with negative examples where location and date matches the DataFrame with cases
    idx = df_timeline.index[(df_timeline['lau1']==row['lau1']) & (df_timeline['dt_placement']==row['dt_placement'])]
    #get the previous case number using index
    previous_case = df_timeline._get_value(idx.values[0], 'case')
    #add 1 (one) to column case
    df_timeline.at[idx.values[0],'case'] = previous_case+1

# %%
df_timeline['case'].value_counts().sort_index()
# Out:
# 0    1877
# 1      47
# 2      20
# 3       5
# 7       1
# Name: case, dtype: int64

# %%
df_timeline
# Out:
#           lau1      nuts2 dt_placement case
# 0        αγιας  θεσσαλιας   2010-06-01    0
# 1        αγιας  θεσσαλιας   2010-06-16    0
# 2        αγιας  θεσσαλιας   2010-07-01    0
# 3        αγιας  θεσσαλιας   2010-07-16    1
# 4        αγιας  θεσσαλιας   2010-08-01    0
# ...        ...        ...          ...  ...
# 1945  φαρσαλων  θεσσαλιας   2022-08-16    0
# 1946  φαρσαλων  θεσσαλιας   2022-09-01    0
# 1947  φαρσαλων  θεσσαλιας   2022-09-16    0
# 1948  φαρσαλων  θεσσαλιας   2022-10-01    0
# 1949  φαρσαλων  θεσσαλιας   2022-10-16    0
#
# [1950 rows x 4 columns]

# %%
df_timeline.case.sum()
# Out:
# 109

# %% [markdown]
# ## 2022 ##

# %%
data_2022 = pd.read_csv(f'../../data/{NUTS0}_WNV_cases_2022_processed.csv', encoding = enc)
data_2022.head(5)
# Out:
#   onset of symptoms  year  month  day                 nuts2         nuts3  \
# 0        2022-07-12  2022      7   12  κεντρικης μακεδονιας  θεσσαλονικης
# 1        2022-07-19  2022      7   19  κεντρικης μακεδονιας  θεσσαλονικης
# 2        2022-07-19  2022      7   19  κεντρικης μακεδονιας  θεσσαλονικης
# 3        2022-07-16  2022      7   16  κεντρικης μακεδονιας  θεσσαλονικης
# 4        2022-07-16  2022      7   16  κεντρικης μακεδονιας  θεσσαλονικης
#
#                     lau1  cases
# 0  αμπελοκηπων μενεμενης      1
# 1                  δελτα      2
# 2             χαλκηδονος      1
# 3                  δελτα      1
# 4                 θερμης      1

# %%
data_2022.shape
# Out:
# (177, 8)

# %%
df_22 = data_2022[data_2022['nuts2'].isin([NUTS2_EL])].copy()
df_22.reset_index(drop = True, inplace = True)
df_22
# Out:
#    onset of symptoms  year  month  day      nuts2     nuts3        lau1  cases
# 0         2022-07-16  2022      7   16  θεσσαλιας   λαρισας      τεμπων      1
# 1         2022-08-16  2022      8   16  θεσσαλιας  τρικαλων  φαρκαδονας      1
# 2         2022-08-23  2022      8   23  θεσσαλιας   λαρισας   λαρισαιων      3
# 3         2022-08-23  2022      8   23  θεσσαλιας  τρικαλων  φαρκαδονας      1
# 4         2022-08-30  2022      8   30  θεσσαλιας   λαρισας   λαρισαιων      1
# ..               ...   ...    ...  ...        ...       ...         ...    ...
# 17        2022-10-04  2022     10    4  θεσσαλιας   λαρισας   λαρισαιων      2
# 18        2022-10-04  2022     10    4  θεσσαλιας   λαρισας     κιλελερ      1
# 19        2022-10-04  2022     10    4  θεσσαλιας   λαρισας    φαρσαλων      1
# 20        2022-10-11  2022     10   11  θεσσαλιας   λαρισας   λαρισαιων      2
# 21        2022-10-18  2022     10   18  θεσσαλιας   λαρισας   λαρισαιων      1
#
# [22 rows x 8 columns]

# %%
wnv_lau1_list = df_22['lau1'].drop_duplicates().sort_values().tolist()

with open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_2022_LAU1_Units_Processed.txt', 'w', encoding=enc) as f:
    for item in wnv_lau1_list:
        f.write("%s\n" % item)
  
print(f"Number of LAU1 Units in {NUTS2} (from cases): {len(wnv_lau1_list)}")
# Out:
# Number of LAU1 Units in Thessaly (from cases): 6

# %%
df_22['period'] = df_22.apply(lambda row: 1 if (row['day']>=1 and row['day']<=15) else 2, axis = 1)
df_22['dt_placement'] = df_22.apply(lambda row: f"{row['year']:04}-{row['month']:02}-{1 if row['period'] == 1 else 16:02}", axis = 1)

df_22['dt_placement']= pd.to_datetime(df_22['dt_placement'])
df_22
# Out:
#    onset of symptoms  year  month  day      nuts2     nuts3        lau1  \
# 0         2022-07-16  2022      7   16  θεσσαλιας   λαρισας      τεμπων
# 1         2022-08-16  2022      8   16  θεσσαλιας  τρικαλων  φαρκαδονας
# 2         2022-08-23  2022      8   23  θεσσαλιας   λαρισας   λαρισαιων
# 3         2022-08-23  2022      8   23  θεσσαλιας  τρικαλων  φαρκαδονας
# 4         2022-08-30  2022      8   30  θεσσαλιας   λαρισας   λαρισαιων
# ..               ...   ...    ...  ...        ...       ...         ...
# 17        2022-10-04  2022     10    4  θεσσαλιας   λαρισας   λαρισαιων
# 18        2022-10-04  2022     10    4  θεσσαλιας   λαρισας     κιλελερ
# 19        2022-10-04  2022     10    4  θεσσαλιας   λαρισας    φαρσαλων
# 20        2022-10-11  2022     10   11  θεσσαλιας   λαρισας   λαρισαιων
# 21        2022-10-18  2022     10   18  θεσσαλιας   λαρισας   λαρισαιων
#
#     cases  period dt_placement
# 0       1       2   2022-07-16
# 1       1       2   2022-08-16
# 2       3       2   2022-08-16
# 3       1       2   2022-08-16
# 4       1       2   2022-08-16
# ..    ...     ...          ...
# 17      2       1   2022-10-01
# 18      1       1   2022-10-01
# 19      1       1   2022-10-01
# 20      2       1   2022-10-01
# 21      1       2   2022-10-16
#
# [22 rows x 10 columns]

# %%
df_22.drop(columns = ['onset of symptoms', 'day', 'nuts3', 'period'], inplace = True)
df_22 = df_22[['month', 'year', 'lau1', 'nuts2', 'dt_placement', 'cases']]
df_22
# Out:
#     month  year        lau1      nuts2 dt_placement  cases
# 0       7  2022      τεμπων  θεσσαλιας   2022-07-16      1
# 1       8  2022  φαρκαδονας  θεσσαλιας   2022-08-16      1
# 2       8  2022   λαρισαιων  θεσσαλιας   2022-08-16      3
# 3       8  2022  φαρκαδονας  θεσσαλιας   2022-08-16      1
# 4       8  2022   λαρισαιων  θεσσαλιας   2022-08-16      1
# ..    ...   ...         ...        ...          ...    ...
# 17     10  2022   λαρισαιων  θεσσαλιας   2022-10-01      2
# 18     10  2022     κιλελερ  θεσσαλιας   2022-10-01      1
# 19     10  2022    φαρσαλων  θεσσαλιας   2022-10-01      1
# 20     10  2022   λαρισαιων  θεσσαλιας   2022-10-01      2
# 21     10  2022   λαρισαιων  θεσσαλιας   2022-10-16      1
#
# [22 rows x 6 columns]

# %%
df_22.cases.sum()
# Out:
# 40

# %%
case_months = df_22['month'].drop_duplicates().sort_values().tolist()
case_months
# Out:
# [7, 8, 9, 10]

# %%
case_years = df_22['year'].drop_duplicates().sort_values().tolist()
case_years
# Out:
# [2022]

# %%
with open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_2022_Cases_Dates.txt', 'w', encoding=enc) as f:

    f.write("%s: " % 'months')
    for item in case_months:
        f.write("%s, " % item)

    f.write("\n")

    f.write("%s: " % 'years')
    for item in case_years:
        f.write("%s, " % item)

# %%
df_22.reset_index(inplace = True, drop=True)

# %%
## Add cases to negative examples DataFrame

#iterrate DataFrame with cases by row
for index, row in df_22.iterrows():
    #find index at DataFrame with negative examples where location and date matches the DataFrame with cases
    idx = df_timeline.index[(df_timeline['lau1']==row['lau1']) & (df_timeline['dt_placement']==row['dt_placement'])]
    #get the previous case number using index
    previous_case = df_timeline._get_value(idx.values[0], 'case')
    current_case = row['cases']
    #add 1 (one) to column case
    df_timeline.at[idx.values[0],'case'] = previous_case+current_case

# %%
df_timeline['case'].value_counts().sort_index()
# Out:
# 0     1862
# 1       55
# 2       23
# 3        5
# 4        2
# 5        1
# 7        1
# 13       1
# Name: case, dtype: int64

# %%
df_timeline.case.sum()
# Out:
# 149

# %%
df_timeline.to_csv(f"../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Cases_2010-2022.csv", encoding = enc, index = False)
