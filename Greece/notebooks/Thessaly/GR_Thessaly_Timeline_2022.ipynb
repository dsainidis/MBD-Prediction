# %% [markdown]
# ## Creates the **Timeline** for a specific region by using the Grid File and the required dates ##

# %%
import pandas as pd
from datetime import date, timedelta

import random
import geopandas as gpd
import numpy as np

import sys

sys.path.insert(0, "../../../Modules")

from preprocessing_utils import *

enc = 'utf-8'
dec = 'greek8'
random.seed(0)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
NUTS0 = 'GR'
NUTS2 = 'Thessaly'
NUTS2_EL = 'θεσσαλιας'

# %%
nuts2_grid = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Grid.csv', encoding = enc)
nuts2_grid.head()
# Out:
#        nuts2   lau1         x         y
# 0  θεσσαλιας  αγιας  22.63715  39.66477
# 1  θεσσαλιας  αγιας  22.70702  39.75460
# 2  θεσσαλιας  αγιας  22.73031  39.79054
# 3  θεσσαλιας  αγιας  22.77688  39.66477
# 4  θεσσαλιας  αγιας  22.77688  39.70070

# %%
## start and end date is defined from available epidemiological file

# %%
start = start_dt = date(2022, 1, 1)
end = end_dt = date(2022, 12, 31)
delta = timedelta(days=1)

# %%
dates = []

while start_dt <= end_dt:
    dates.append(start_dt.isoformat())
    start_dt += delta

# %%
print('Dates between', start, 'and', end)
print(dates)
# Out:
# Dates between 2022-01-01 and 2022-12-31
# ['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04', '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08', '2022-01-09', '2022-01-10', '2022-01-11', '2022-01-12', '2022-01-13', '2022-01-14', '2022-01-15', '2022-01-16', '2022-01-17', '2022-01-18', '2022-01-19', '2022-01-20', '2022-01-21', '2022-01-22', '2022-01-23', '2022-01-24', '2022-01-25', '2022-01-26', '2022-01-27', '2022-01-28', '2022-01-29', '2022-01-30', '2022-01-31', '2022-02-01', '2022-02-02', '2022-02-03', '2022-02-04', '2022-02-05', '2022-02-06', '2022-02-07', '2022-02-08', '2022-02-09', '2022-02-10', '2022-02-11', '2022-02-12', '2022-02-13', '2022-02-14', '2022-02-15', '2022-02-16', '2022-02-17', '2022-02-18', '2022-02-19', '2022-02-20', '2022-02-21', '2022-02-22', '2022-02-23', '2022-02-24', '2022-02-25', '2022-02-26', '2022-02-27', '2022-02-28', '2022-03-01', '2022-03-02', '2022-03-03', '2022-03-04', '2022-03-05', '2022-03-06', '2022-03-07', '2022-03-08', '2022-03-09', '2022-03-10', '2022-03-11', '2022-03-12', '2022-03-13', '2022-03-14', '2022-03-15', '2022-03-16', '2022-03-17', '2022-03-18', '2022-03-19', '2022-03-20', '2022-03-21', '2022-03-22', '2022-03-23', '2022-03-24', '2022-03-25', '2022-03-26', '2022-03-27', '2022-03-28', '2022-03-29', '2022-03-30', '2022-03-31', '2022-04-01', '2022-04-02', '2022-04-03', '2022-04-04', '2022-04-05', '2022-04-06', '2022-04-07', '2022-04-08', '2022-04-09', '2022-04-10', '2022-04-11', '2022-04-12', '2022-04-13', '2022-04-14', '2022-04-15', '2022-04-16', '2022-04-17', '2022-04-18', '2022-04-19', '2022-04-20', '2022-04-21', '2022-04-22', '2022-04-23', '2022-04-24', '2022-04-25', '2022-04-26', '2022-04-27', '2022-
nuts2_timeline = pd.DataFrame(data)

# %%
nuts2_timeline
# Out:
#            lau1     region         x         y dt_placement
# 0         αγιας  θεσσαλιας  22.63715  39.66477   2022-01-01
# 1         αγιας  θεσσαλιας  22.63715  39.66477   2022-01-02
# 2         αγιας  θεσσαλιας  22.63715  39.66477   2022-01-03
# 3         αγιας  θεσσαλιας  22.63715  39.66477   2022-01-04
# 4         αγιας  θεσσαλιας  22.63715  39.66477   2022-01-05
# ...         ...        ...       ...       ...          ...
# 45985  φαρσαλων  θεσσαλιας  22.59495  39.30103   2022-12-27
# 45986  φαρσαλων  θεσσαλιας  22.59495  39.30103   2022-12-28
# 45987  φαρσαλων  θεσσαλιας  22.59495  39.30103   2022-12-29
# 45988  φαρσαλων  θεσσαλιας  22.59495  39.30103   2022-12-30
# 45989  φαρσαλων  θεσσαλιας  22.59495  39.30103   2022-12-31
#
# [45990 rows x 5 columns]

# %%
nuts2_timeline['dt_placement'] = pd.to_datetime(nuts2_timeline['dt_placement'])

# %%
nuts2_timeline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45990 entries, 0 to 45989
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   lau1          45990 non-null  object
#  1   region        45990 non-null  object
#  2   x             45990 non-null  float64
#  3   y             45990 non-null  float64
#  4   dt_placement  45990 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 1.8+ MB

# %%
nuts2_timeline.to_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Timeline_2022.csv', index = False)

# %%
nuts2_timeline
# Out:
#            lau1     region         x         y dt_placement
# 0         αγιας  θεσσαλιας  22.63715  39.66477   2022-01-01
# 1         αγιας  θεσσαλιας  22.63715  39.66477   2022-01-02
# 2         αγιας  θεσσαλιας  22.63715  39.66477   2022-01-03
# 3         αγιας  θεσσαλιας  22.63715  39.66477   2022-01-04
# 4         αγιας  θεσσαλιας  22.63715  39.66477   2022-01-05
# ...         ...        ...       ...       ...          ...
# 45985  φαρσαλων  θεσσαλιας  22.59495  39.30103   2022-12-27
# 45986  φαρσαλων  θεσσαλιας  22.59495  39.30103   2022-12-28
# 45987  φαρσαλων  θεσσαλιας  22.59495  39.30103   2022-12-29
# 45988  φαρσαλων  θεσσαλιας  22.59495  39.30103   2022-12-30
# 45989  φαρσαλων  θεσσαλιας  22.59495  39.30103   2022-12-31
#
# [45990 rows x 5 columns]

# %%
nuts2_timeline['dt_placement'].iloc[15].day
# Out:
# 16

# %%
nuts2_timeline_biweekly = nuts2_timeline.copy()
remove = []

for index, row in nuts2_timeline.iterrows():
    if row['dt_placement'].day == 1 or row['dt_placement'].day == 16:
        pass
    else:
        remove.append(index)


nuts2_timeline_biweekly.drop(index = remove, axis = 1, inplace = True)
nuts2_timeline_biweekly.reset_index(inplace = True, drop = True)

# %%
nuts2_timeline_biweekly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3024 entries, 0 to 3023
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   lau1          3024 non-null   object
#  1   region        3024 non-null   object
#  2   x             3024 non-null   float64
#  3   y             3024 non-null   float64
#  4   dt_placement  3024 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 118.2+ KB

# %%
nuts2_timeline_biweekly.to_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Timeline_Biweekly_2022.csv', index = False)
