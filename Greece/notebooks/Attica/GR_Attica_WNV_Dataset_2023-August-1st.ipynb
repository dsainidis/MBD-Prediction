# %% [markdown]
# ## Merges all the availble information into a **Final Dataset** to be used for modeling ##

# %%
import pandas as pd
import datetime
import math
import numpy as np
import missingno
import json
from statistics import mean
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
import sys

sys.path.insert(0, "../../../Modules")

from preprocessing_utils import *


enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 10
# Out:
# c:\Users\dimit\AppData\Local\Programs\Python\Python39\lib\site-packages\geopandas\_compat.py:112: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
NUTS0 = 'GR'
NUTS2 = 'Attica'
NUTS2_EL = 'αττικης'

# %%
YEAR = 2023
MONTH = 'August'
PERIOD = '1st'

# %%
timeline_file = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Timeline_{YEAR}-{MONTH}-{PERIOD}_filled.csv', encoding=enc)
#wnv_file = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Timeline_2022.csv', encoding=enc)

# %%
timeline_file.head()
# Out:
#                         lau1   region         x         y dt_placement  year  \
# 0             αγιας βαρβαρας  αττικης  23.65697  37.99220   2023-08-01  2023
# 1           αγιας παρασκευης  αττικης  23.82642  38.00806   2023-08-01  2023
# 2            αγιου δημητριου  αττικης  23.73031  37.93357   2023-08-01  2023
# 3  αγιων αναργυρων καματερου  αττικης  23.71341  38.04721   2023-08-01  2023
# 4                 αγκιστριου  αττικης  23.34009  37.69503   2023-08-01  2023
#
#    month indices_image_date  indices_lat  indices_lon      ndvi      ndmi  \
# 0      8         2023-08-01    37.991999    23.654887  0.072597 -0.056274
# 1      8         2023-08-01    38.009965    23.825567  0.191321  0.024308
# 2      8         2023-08-01    37.933609    23.731244  0.117532 -0.028843
# 3      8         2023-08-01    38.045898    23.713278  0.130143 -0.065602
# 4      8         2023-08-01    37.695555    23.340477  0.279617 -0.046090
#
#        ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  \
# 0 -0.140735  0.056274   0.102353  -0.053480  -0.161769   0.053480  0.033199
# 1 -0.222122 -0.024308   0.194652   0.028120  -0.220625  -0.028120  0.022706
# 2 -0.179234  0.028843   0.098477  -0.034221  -0.159017   0.034221  0.022599
# 3 -0.186687  0.065602   0.157629  -0.065827  -0.208062   0.065827  0.036587
# 4 -0.223027  0.046090   0.291183  -0.031676  -0.237061   0.031676  0.024057
#
#    ndmi_std  ndwi_std  ndbi_std  lst_day  lst_night  monthly_lst_lat  \
# 0  0.012476  0.027588  0.012476      NaN        NaN        37.991999
# 1  0.014833  0.016365  0.014833      NaN        NaN        38.009965
# 2  0.009434  0.018917  0.009434      NaN        NaN        37.933609
# 3  0.016287  0.024380  0.016287      NaN        NaN        38.045898
# 4  0.052899  0.012071  0.052899      NaN        NaN        37.695555
#
#    monthly_lst_lon  lst_jan_day_mean  lst_jan_night_mean  lst_feb_day_mean  \
# 0        23.654887      14383.000000        14058.500000      14342.555556
# 1        23.825567      14333.928571        14047.200000      14411.600000
# 2        23.731244      14390.461538        14124.550000      14357.363636
# 3        23.713278      14369.750000        14037.578947      14313.300000
# 4        23.340477      14368.608696        14189.722222      14305.315789
#
#    lst_feb_night_mean  lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  \
# 0        13972.380952      14651.923077        14207.846154      14829.846154
# 1        13959.363636      14596.000000        14136.000000      14752.555556
# 2        13996.130435      14688.400000        14187.062500      14885.647059
# 3        13963.473684      14693.000000        14156.333333      14841.250000
# 4        14124.388889      14433.318182        14238.400000      14545.680000
#
#    lst_apr_night_mean indices_image_date.1  indices_lat.1  indices_lon.1  \
# 0        14265.500000           2023-07-31      37.950174      23.650108
# 1        14223.200000           2023-07-31      38.050174      23.850109
# 2        14302.500000           2023-07-31      37.950174      23.750109
# 3        14223.666667           2023-07-31      38.050174      23.750109
# 4        14261.666667           2023-07-31      37.650172      23.350107
#
#    acc_rainfall_jan dt_placement_minus_7 dt_placement_minus_14  \
# 0        348.910701           2023-07-25            2023-07-18
# 1        425.951674           2023-07-25            2023-07-18
# 2        365.646401           2023-07-25            2023-07-18
# 3        437.278102           2023-07-25            2023-07-18
# 4        485.607975           2023-07-25            2023-07-18
#
#   dt_placement_minus_7_avail dt_placement_minus_14_avail  acc_rainfall_1week  \
# 0                 2023-07-25                  2023-07-18            0.000000
# 1                 2023-07-25                  2023-07-18            0.000000
# 2                 2023-07-25                  2023-07-18            0.000000
# 3                 2023-07-25                  2023-07-18            0.000000
# 4                 2023-07-25                  2023-07-18            0.000664
#
#    acc_rainfall_2week
# 0            0.000000
# 1            0.000000
# 2            0.000000
# 3            0.000000
# 4            0.000664

# %%
#wnv_file.head()

# %%
timeline_file.rename(columns={"region": "nuts2"}, inplace=True)

# %%
timeline_file = timeline_file.rename(columns=lambda x: re.sub('_new', '', x))

# %%
timeline_file.drop(columns=['indices_image_date', 'indices_lat', 'indices_lon'  ,'monthly_lst_lat', 'monthly_lst_lon', 
                         'indices_image_date.1', 'indices_lat.1', 'indices_lon.1', 'dt_placement_minus_7', 'dt_placement_minus_14', 'dt_placement_minus_7_avail',
                         'dt_placement_minus_14_avail'], inplace = True)

# %%
timeline_file.head(5)
# Out:
#                         lau1    nuts2         x         y dt_placement  year  \
# 0             αγιας βαρβαρας  αττικης  23.65697  37.99220   2023-08-01  2023
# 1           αγιας παρασκευης  αττικης  23.82642  38.00806   2023-08-01  2023
# 2            αγιου δημητριου  αττικης  23.73031  37.93357   2023-08-01  2023
# 3  αγιων αναργυρων καματερου  αττικης  23.71341  38.04721   2023-08-01  2023
# 4                 αγκιστριου  αττικης  23.34009  37.69503   2023-08-01  2023
#
#    month      ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  \
# 0      8  0.072597 -0.056274 -0.140735  0.056274   0.102353  -0.053480
# 1      8  0.191321  0.024308 -0.222122 -0.024308   0.194652   0.028120
# 2      8  0.117532 -0.028843 -0.179234  0.028843   0.098477  -0.034221
# 3      8  0.130143 -0.065602 -0.186687  0.065602   0.157629  -0.065827
# 4      8  0.279617 -0.046090 -0.223027  0.046090   0.291183  -0.031676
#
#    ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  \
# 0  -0.161769   0.053480  0.033199  0.012476  0.027588  0.012476      NaN
# 1  -0.220625  -0.028120  0.022706  0.014833  0.016365  0.014833      NaN
# 2  -0.159017   0.034221  0.022599  0.009434  0.018917  0.009434      NaN
# 3  -0.208062   0.065827  0.036587  0.016287  0.024380  0.016287      NaN
# 4  -0.237061   0.031676  0.024057  0.052899  0.012071  0.052899      NaN
#
#    lst_night  lst_jan_day_mean  lst_jan_night_mean  lst_feb_day_mean  \
# 0        NaN      14383.000000        14058.500000      14342.555556
# 1        NaN      14333.928571        14047.200000      14411.600000
# 2        NaN      14390.461538        14124.550000      14357.363636
# 3        NaN      14369.750000        14037.578947      14313.300000
# 4        NaN      14368.608696        14189.722222      14305.315789
#
#    lst_feb_night_mean  lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  \
# 0        13972.380952      14651.923077        14207.846154      14829.846154
# 1        13959.363636      14596.000000        14136.000000      14752.555556
# 2        13996.130435      14688.400000        14187.062500      14885.647059
# 3        13963.473684      14693.000000        14156.333333      14841.250000
# 4        14124.388889      14433.318182        14238.400000      14545.680000
#
#    lst_apr_night_mean  acc_rainfall_jan  acc_rainfall_1week  \
# 0        14265.500000        348.910701            0.000000
# 1        14223.200000        425.951674            0.000000
# 2        14302.500000        365.646401            0.000000
# 3        14223.666667        437.278102            0.000000
# 4        14261.666667        485.607975            0.000664
#
#    acc_rainfall_2week
# 0            0.000000
# 1            0.000000
# 2            0.000000
# 3            0.000000
# 4            0.000664

# %%
#wnv_file.head(5)

# %%
# ## Find if there are lau1 units in the epidemiological file and are not contained in the spatiotemporal file.

# names_from_wnv_file = wnv_file["lau1"].drop_duplicates().sort_values().tolist()
# names_from_shapefile = timeline_file["lau1"].drop_duplicates().sort_values().tolist()
# diff = []

# for element in names_from_wnv_file:
#     if element not in names_from_shapefile:
#         diff.append(element)
        

# print(f"{diff}\n\nLength: {len(diff)}")

# %%
#wnv_file['lau1'] = wnv_file['lau1'].apply(lambda x : x.replace('ηρωικης πολεως ναουσας','ναουσας'))

# %%
# ## Check again

# names_from_wnv_file = wnv_file["lau1"].drop_duplicates().sort_values().tolist()
# names_from_shapefile = timeline_file["lau1"].drop_duplicates().sort_values().tolist()
# diff = []

# for element in names_from_wnv_file:
#     if element not in names_from_shapefile:
#         diff.append(element)
        

# print(f"{diff}\n\nLength: {len(diff)}")

# %%
# merged = timeline_file.merge(wnv_file, how='left', on=['dt_placement', 'lau1', 'nuts2'] )
merged = timeline_file

# %%
# merged

# %%
# merged = fillna(merged,{'case': 0})
merged['case'] = 0

# %%
merged['case'].value_counts()
# Out:
# 0    152
# Name: case, dtype: int64

# %%
grouped = merged.groupby(['dt_placement', 'lau1', 'nuts2'], as_index = False)

# %%
dataset = grouped.mean()

# %%
dataset
# Out:
#    dt_placement                       lau1    nuts2          x          y  \
# 0    2023-08-01             αγιας βαρβαρας  αττικης  23.656970  37.992200
# 1    2023-08-01           αγιας παρασκευης  αττικης  23.826420  38.008060
# 2    2023-08-01            αγιου δημητριου  αττικης  23.730310  37.933570
# 3    2023-08-01  αγιων αναργυρων καματερου  αττικης  23.713410  38.047210
# 4    2023-08-01                 αγκιστριου  αττικης  23.340090  37.695030
# ..          ...                        ...      ...        ...        ...
# 61   2023-08-01           φιλοθεης ψυχικου  αττικης  23.776280  38.014770
# 62   2023-08-01                      φυλης  αττικης  23.688620  38.106703
# 63   2023-08-01                 χαλανδριου  αττικης  23.809410  38.022260
# 64   2023-08-01                  χαϊδαριου  αττικης  23.630840  38.009420
# 65   2023-08-01                     ωρωπου  αττικης  23.799331  38.257611
#
#       year  month      ndvi      ndmi      ndwi      ndbi  ndvi_mean  \
# 0   2023.0    8.0  0.072597 -0.056274 -0.140735  0.056274   0.102353
st_mar_night_mean  lst_apr_day_mean  lst_apr_night_mean  \
# 0         14207.846154      14829.846154        14265.500000
# 1         14136.000000      14752.555556        14223.200000
# 2         14187.062500      14885.647059        14302.500000
# 3         14156.333333      14841.250000        14223.666667
# 4         14238.400000      14545.680000        14261.666667
# ..                 ...               ...                 ...
# 61        14136.722222      14814.133333        14253.928571
# 62        14007.878571      14697.305556        14082.353535
# 63        14128.588235      14793.333333        14171.142857
# 64        14147.933333      14794.058824        14248.400000
# 65        14002.080553      14643.221787        14091.100419
#
#     acc_rainfall_jan  acc_rainfall_1week  acc_rainfall_2week  case
# 0         348.910701            0.000000            0.000000   0.0
# 1         425.951674            0.000000            0.000000   0.0
# 2         365.646401            0.000000            0.000000   0.0
# 3         437.278102            0.000000            0.000000   0.0
# 4         485.607975            0.000664            0.000664   0.0
# ..               ...                 ...                 ...   ...
# 61        437.278102            0.000000            0.000000   0.0
# 62        400.114421            0.000000            0.000000   0.0
# 63        425.951674            0.000000            0.000000   0.0
# 64        439.846210            0.000000            0.000000   0.0
# 65        385.292602            0.000000            0.000000   0.0
#
# [66 rows x 33 columns]

# %%
dataset = dataset.astype({'case': 'int'})

# %%
dataset['dt_placement'] = pd.to_datetime(dataset['dt_placement'])

# %%
dataset['x'] = dataset['x'].apply(lambda x : round(x,5))
dataset['y'] = dataset['y'].apply(lambda x : round(x,5))
dataset['day'] = dataset['dt_placement'].apply(lambda x : x.day)
dataset['month'] = dataset['dt_placement'].apply(lambda x : x.month)
dataset['year'] = dataset['dt_placement'].apply(lambda x : x.year)
dataset['week'] = dataset.apply(lambda row: datetime.date(int(row['year']), int(row['month']), int(row['day'])).isocalendar().week, axis=1)

# %%
lau1_map = lau1_mapping(dataset, 0, 0)

# %%
dataset = encode_cyclical(dataset, 'day', 31)
dataset = encode_cyclical(dataset, 'month', 12)
dataset = encode_cyclical(dataset, 'week', 53)

# %%
dataset
# Out:
#    dt_placement                       lau1    nuts2         x         y  year  \
# 0    2023-08-01             αγιας βαρβαρας  αττικης  23.65697  37.99220  2023
# 1    2023-08-01           αγιας παρασκευης  αττικης  23.82642  38.00806  2023
# 2    2023-08-01            αγιου δημητριου  αττικης  23.73031  37.93357  2023
# 3    2023-08-01  αγιων αναργυρων καματερου  αττικης  23.71341  38.04721  2023
# 4    2023-08-01                 αγκιστριου  αττικης  23.34009  37.69503  2023
# ..          ...                        ...      ...       ...       ...   ...
# 61   2023-08-01           φιλοθεης ψυχικου  αττικης  23.77628  38.01477  2023
# 62   2023-08-01                      φυλης  αττικης  23.68862  38.10670  2023
# 63   2023-08-01                 χαλανδριου  αττικης  23.80941  38.02226  2023
# 64   2023-08-01                  χαϊδαριου  αττικης  23.63084  38.00942  2023
# 65   2023-08-01                     ωρωπου  αττικης  23.79933  38.25761  2023
#
#     month      ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  \
# 0       8  0.072597 -0.056274 -0.140735  0.056274   0.102353  -0.053480
# 1       8  0.191321  0.024308 -0.222122 -0.024308   0.194652   0.028120
# 2       8  0.117532 -0.028843 -0.179234  0.028843   0.098477  -0.034221
# 3       8  0.130143 -0.065602 -0.186687  0.065602   0.157629  -0.065827
# 4       8  0.279617 -0.046090 -0.223027  0.046090   0.291183  -0.031676
# ..    ...       ...       ...       ...       ...        ...        ...
# 61      8  0.270066  0.052220 -0.277910 -0.052220   0.241266   0.033742
# 62      8  0.261451 -0.021141 -0.281693  0.021141   0.295244   0.000835
# 63      8  0.216582  0.039957 -0.243138 -0.039957   0.223762   0.039369
# 64      8  0.276525 -0.059599 -0.261055  0.059599   0.280146  -0.032418
# 65      8  0.380497  0.053933 -0.362486 -0.053933   0.367148   0.038504
#
#     ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day
# 2             0.000000            0.000000     0    1    31     44.74465
# 3             0.000000            0.000000     0    1    31     44.83209
# 4             0.000664            0.000664     0    1    31     44.33593
# ..                 ...                 ...   ...  ...   ...          ...
# 61            0.000000            0.000000     0    1    31     44.83787
# 62            0.000000            0.000000     0    1    31     44.86949
# 63            0.000000            0.000000     0    1    31     44.86179
# 64            0.000000            0.000000     0    1    31     44.75637
# 65            0.000000            0.000000     0    1    31     45.05611
#
#      day_sin  day_cos  month_sin  month_cos  week_sin  week_cos
# 0   0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044
# 1   0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044
# 2   0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044
# 3   0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044
# 4   0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044
# ..       ...      ...        ...        ...       ...       ...
# 61  0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044
# 62  0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044
# 63  0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044
# 64  0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044
# 65  0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044
#
# [66 rows x 42 columns]

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
df_demographics = pd.read_csv(f'../../data/{NUTS0}_WEB_Demographics_Processed.csv', encoding = enc)

# %%
df_demographics
# Out:
#                  lau1                             nuts2                 nuts3  \
# 0             αβδηρων  ανατολικης μακεδονιας και θρακης                ξανθης
# 1         αγαθονησιου                    νοτιου αιγαιου              καλυμνου
# 2               αγιας                         θεσσαλιας               λαρισας
# 3      αγιας βαρβαρας                           αττικης  δυτικου τομεα αθηνων
# 4    αγιας παρασκευης                           αττικης  βορειου τομεα αθηνων
# ..                ...                               ...                   ...
# 327            χανιων                            κρητης                χανιων
# 328        χερσονησου                            κρητης             ηρακλειου
# 329              χιου                   βορειου αιγαιου                  χιου
# 330      ωραιοκαστρου              κεντρικης μακεδονιας          θεσσαλονικης
# 331            ωρωπου                           αττικης    ανατολικης αττικης
#
#       area  population_density  population
# 0    352.0                54.0     17860.0
# 1     14.5                12.8       203.0
# 2    661.8                17.3     10705.0
# 3      2.4             10925.9     26759.0
# 4      7.9              7557.5     62157.0
# ..     ...                 ...         ...
# 327  351.3               309.3    110646.0
# 328  272.2                98.2     27229.0
# 329  842.3                61.0     50483.0
# 330  217.9               175.8     40114.0
# 331  338.2                99.8     33977.0
#
# [332 rows x 6 columns]

# %%
df_demographics_nuts2 = df_demographics.query(f"nuts2 == '{NUTS2_EL}'").copy()

# %%
df_demographics_nuts2.drop(columns=['nuts2', 'nuts3'], inplace=True)
df_demographics_nuts2.reset_index(inplace=True, drop=True)

# %%
df_demographics_nuts2
# Out:
#                          lau1   area  population_density  population
# 0              αγιας βαρβαρας    2.4             10925.9     26759.0
# 1            αγιας παρασκευης    7.9              7557.5     62157.0
# 2             αγιου δημητριου    5.0             14402.8     71747.0
# 3   αγιων αναργυρων καματερου    9.2              6833.8     61427.0
# 4                  αγκιστριου   13.4                85.2      1107.0
# ..                        ...    ...                 ...         ...
# 61           φιλοθεης ψυχικου    6.1              4421.0     27400.0
# 62                      φυλης  109.1               421.2     48255.0
# 63                  χαϊδαριου   22.7              2069.6     46983.0
# 64                 χαλανδριου   10.8              6869.6     77118.0
# 65                     ωρωπου  338.2                99.8     33977.0
#
# [66 rows x 4 columns]

# %%
names_from_merged = dataset["lau1"].drop_duplicates().sort_values().tolist()
names_from_demographics = df_demographics_nuts2["lau1"].drop_duplicates().sort_values().tolist()
diff = []

for element in names_from_merged:
    if element not in names_from_demographics:
        diff.append(element)
        

print(f"{diff}\n\nLength: {len(diff)}")
# Out:
# ['νικαιας αγιου ι. ρεντη', 'πειραιως', 'τροιζηνιας', 'φιλαδελφειας χαλκηδονος']
#
# Length: 4

# %%
df_demographics_nuts2['lau1'] = df_demographics_nuts2['lau1'].apply(lambda x : x.replace('νικαιας αγιου ιωαννη ρεντη', 'νικαιας αγιου ι. ρεντη'))
df_demographics_nuts2['lau1'] = df_demographics_nuts2['lau1'].apply(lambda x : x.replace('πειραια', 'πειραιως',))
df_demographics_nuts2['lau1'] = df_demographics_nuts2['lau1'].apply(lambda x : x.replace('τροιζηνιας μεθανων', 'τροιζηνιας'))
df_demographics_nuts2['lau1'] = df_demographics_nuts2['lau1'].apply(lambda x : x.replace('νεας φιλαδελφειας νεας χαλκηδονας','φιλαδελφειας χαλκηδονος'))

# %%
names_from_merged = dataset["lau1"].drop_duplicates().sort_values().tolist()
names_from_demographics = df_demographics_nuts2["lau1"].drop_duplicates().sort_values().tolist()
diff = []

for element in names_from_merged:
    if element not in names_from_demographics:
        diff.append(element)
        

print(f"{diff}\n\nLength: {len(diff)}")
# Out:
# []
#
# Length: 0

# %%
dataset = pd.merge(dataset, df_demographics_nuts2,  how='left', on=['lau1'])

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
missing = describe_dataframe(dataset)

# %%
dataset
# Out:
#    dt_placement                       lau1    nuts2         x         y  year  \
# 0    2023-08-01             αγιας βαρβαρας  αττικης  23.65697  37.99220  2023
# 1    2023-08-01           αγιας παρασκευης  αττικης  23.82642  38.00806  2023
# 2    2023-08-01            αγιου δημητριου  αττικης  23.73031  37.93357  2023
# 3    2023-08-01  αγιων αναργυρων καματερου  αττικης  23.71341  38.04721  2023
# 4    2023-08-01                 αγκιστριου  αττικης  23.34009  37.69503  2023
# ..          ...                        ...      ...       ...       ...   ...
# 61   2023-08-01           φιλοθεης ψυχικου  αττικης  23.77628  38.01477  2023
# 62   2023-08-01                      φυλης  αττικης  23.68862  38.10670  2023
# 63   2023-08-01                 χαλανδριου  αττικης  23.80941  38.02226  2023
# 64   2023-08-01                  χαϊδαριου  αττικης  23.63084  38.00942  2023
# 65   2023-08-01                     ωρωπου  αττικης  23.79933  38.25761  2023
#
#     month      ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean
# 62      14697.305556        14082.353535        400.114421
# 63      14793.333333        14171.142857        425.951674
# 64      14794.058824        14248.400000        439.846210
# 65      14643.221787        14091.100419        385.292602
#
#     acc_rainfall_1week  acc_rainfall_2week  case  day  week  eq_distance  \
# 0             0.000000            0.000000     0    1    31     44.75555
# 1             0.000000            0.000000     0    1    31     44.85879
# 2             0.000000            0.000000     0    1    31     44.74465
# 3             0.000000            0.000000     0    1    31     44.83209
# 4             0.000664            0.000664     0    1    31     44.33593
# ..                 ...                 ...   ...  ...   ...          ...
# 61            0.000000            0.000000     0    1    31     44.83787
# 62            0.000000            0.000000     0    1    31     44.86949
# 63            0.000000            0.000000     0    1    31     44.86179
# 64            0.000000            0.000000     0    1    31     44.75637
# 65            0.000000            0.000000     0    1    31     45.05611
#
#      day_sin  day_cos  month_sin  month_cos  week_sin  week_cos   area  \
# 0   0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044    2.4
# 1   0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044    7.9
# 2   0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044    5.0
# 3   0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044    9.2
# 4   0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044   13.4
# ..       ...      ...        ...        ...       ...       ...    ...
# 61  0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044    6.1
# 62  0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044  109.1
# 63  0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044   10.8
# 64  0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044   22.7
# 65  0.201299  0.97953  -0.866025       -0.5 -0.508531 -0.861044  338.2
#
#     population_density  population
# 0              10925.9     26759.0
# 1               7557.5     62157.0
# 2              14402.8     71747.0
# 3               6833.8     61427.0
# 4                 85.2      1107.0
# ..                 ...         ...
# 61              4421.0     27400.0
# 62               421.2     48255.0
# 63              6869.6     77118.0
# 64              2069.6     46983.0
# 65                99.8     33977.0
#
# [66 rows x 45 columns]

# %%
df_mosquitoes = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Culex_Predictions_{YEAR}-{MONTH}-{PERIOD}.csv', encoding = enc)
df_mosquitoes
# Out:
#             x          y dt_placement  mosq_pred
# 0   23.656970  37.992200   2023-08-01         43
# 1   23.826420  38.008060   2023-08-01         32
# 2   23.730310  37.933570   2023-08-01         37
# 3   23.713410  38.047210   2023-08-01         36
# 4   23.340090  37.695030   2023-08-01         35
# ..        ...        ...          ...        ...
# 61  23.776280  38.014770   2023-08-01         32
# 62  23.688620  38.106703   2023-08-01         26
# 63  23.809410  38.022260   2023-08-01         30
# 64  23.630840  38.009420   2023-08-01         31
# 65  23.799331  38.257611   2023-08-01         24
#
# [66 rows x 4 columns]

# %%
df_mosquitoes['dt_placement'] = pd.to_datetime(dataset['dt_placement'])
df_mosquitoes['x'] = df_mosquitoes['x'].apply(lambda x : round(x,5))
df_mosquitoes['y'] = df_mosquitoes['y'].apply(lambda x : round(x,5))

# %%
distances, indicies = calculate_nearest_topological(dataset, df_mosquitoes)

# %%
print(f'Min distance: {min(distances)}')
print(f'Max distance: {max(distances)}')
# Out:
# Min distance: 0.0
# Max distance: 0.0

# %%
df_mosq = pd.DataFrame(columns=df_mosquitoes.columns)

# %%
for index in indicies:
    df_mosq = df_mosq.append(df_mosquitoes.iloc[[index]])

df_mosq.drop(columns=['x', 'y', 'dt_placement'], inplace = True)
df_mosq.reset_index(drop=True, inplace=True)

# %%
dataset = pd.concat([dataset, df_mosq], axis=1, join = 'outer')

# %%
dataset.head()
# Out:
#   dt_placement                       lau1    nuts2         x         y  year  \
# 0   2023-08-01             αγιας βαρβαρας  αττικης  23.65697  37.99220  2023
# 1   2023-08-01           αγιας παρασκευης  αττικης  23.82642  38.00806  2023
# 2   2023-08-01            αγιου δημητριου  αττικης  23.73031  37.93357  2023
# 3   2023-08-01  αγιων αναργυρων καματερου  αττικης  23.71341  38.04721  2023
# 4   2023-08-01                 αγκιστριου  αττικης  23.34009  37.69503  2023
#
#    month      ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  \
# 0      8  0.072597 -0.056274 -0.140735  0.056274   0.102353  -0.053480
# 1      8  0.191321  0.024308 -0.222122 -0.024308   0.194652   0.028120
# 2      8  0.117532 -0.028843 -0.179234  0.028843   0.098477  -0.034221
# 3      8  0.130143 -0.065602 -0.186687  0.065602   0.157629  -0.065827
# 4      8  0.279617 -0.046090 -0.223027  0.046090   0.291183  -0.031676
#
#    ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  \
# 0  -0.161769   0.053480  0.033199  0.012476  0.027588  0.012476      NaN
# 1  -0.220625  -0.028120  0.022706  0.014833  0.016365  0.014833      NaN
# 2  -0.159017   0.034221  0.022599  0.009434  0.018917  0.009434      NaN
# 3  -0.208062   0.065827  0.036587  0.016287  0.024380  0.016287      NaN
# 4  -0.237061   0.031676  0.024057  0.052899  0.012071  0.052899      NaN
#
#    lst_night  lst_jan_day_mean  lst_jan_night_mean  lst_feb_day_mean  \
# 0        NaN      14383.000000        14058.500000      14342.555556
# 1        NaN      14333.928571        14047.200000      14411.600000
# 2        NaN      14390.461538        14124.550000      14357.363636
# 3        NaN      14369.750000        14037.578947      14313.300000
# 4        NaN      14368.608696        14189.722222      14305.315789
#
#    lst_feb_night_mean  lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  \
# 0        13972.380952      14651.923077        14207.846154      14829.846154
# 1        13959.363636      14596.000000        14136.000000      14752.555556
# 2        13996.130435      14688.400000        14187.062500      14885.647059
# 3        13963.473684      14693.000000        14156.333333      14841.250000
# 4        14124.388889      14433.318182        14238.400000      14545.680000
#
#    lst_apr_night_mean  acc_rainfall_jan  acc_rainfall_1week  \
# 0        14265.500000        348.910701            0.000000
# 1        14223.200000        425.951674            0.000000
# 2        14302.500000        365.646401            0.000000
# 3        14223.666667        437.278102            0.000000
# 4        14261.666667        485.607975            0.000664
#
#    acc_rainfall_2week  case  day  week  eq_distance   day_sin  day_cos  \
# 0            0.000000     0    1    31     44.75555  0.201299  0.97953
# 1            0.000000     0    1    31     44.85879  0.201299  0.97953
# 2            0.000000     0    1    31     44.74465  0.201299  0.97953
# 3            0.000000     0    1    31     44.83209  0.201299  0.97953
# 4            0.000664     0    1    31     44.33593  0.201299  0.97953
#
#    month_sin  month_cos  week_sin  week_cos  area  population_density  \
# 0  -0.866025       -0.5 -0.508531 -0.861044   2.4             10925.9
# 1  -0.866025       -0.5 -0.508531 -0.861044   7.9              7557.5
# 2  -0.866025       -0.5 -0.508531 -0.861044   5.0             14402.8
# 3  -0.866025       -0.5 -0.508531 -0.861044   9.2              6833.8
# 4  -0.866025       -0.5 -0.508531 -0.861044  13.4                85.2
#
#    population mosq_pred
# 0     26759.0        43
# 1     62157.0        32
# 2     71747.0        37
# 3     61427.0        36
# 4      1107.0        35

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
dataset.reset_index(inplace=True, drop=True)

# %%
dataset = calculate_mosq_previous(dataset)

# %%
dataset = convert_temperature(dataset)

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
dataset['case'].value_counts()
# Out:
# 0    66
# Name: case, dtype: int64

# %%
dataset = dataset.astype({'mosq_pred' : 'int', 'mosq_previous' : 'int'})

# %%
dataset = convert_multiple_cases(dataset)

# %%
dataset['case'].value_counts()
# Out:
# 0    66
# Name: case, dtype: int64

# %%
cols = dataset.columns

# %%
cols
# Out:
# Index(['dt_placement', 'lau1', 'nuts2', 'x', 'y', 'year', 'month', 'ndvi',
#        'ndmi', 'ndwi', 'ndbi', 'ndvi_mean', 'ndmi_mean', 'ndwi_mean',
#        'ndbi_mean', 'ndvi_std', 'ndmi_std', 'ndwi_std', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_day_mean', 'lst_jan_night_mean',
#        'lst_feb_day_mean', 'lst_feb_night_mean', 'lst_mar_day_mean',
#        'lst_mar_night_mean', 'lst_apr_day_mean', 'lst_apr_night_mean',
#        'acc_rainfall_jan', 'acc_rainfall_1week', 'acc_rainfall_2week', 'case',
#        'day', 'week', 'eq_distance', 'day_sin', 'day_cos', 'month_sin',
#        'month_cos', 'week_sin', 'week_cos', 'area', 'population_density',
#        'population', 'mosq_pred', 'mosq_previous', 'lst'],
#       dtype='object')

# %%
len(cols)
# Out:
# 48

# %%
# check columns

# %%
final_columns = ['x', 'y', 'dt_placement', 'nuts2', 'lau1', 'day', 
                 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 
                 'month_cos', 'week_sin', 'week_cos', 'area', 'population',
                 'population_density', 'eq_distance', 'ndvi', 'ndmi', 'ndwi', 'ndbi', 
                 'ndvi_mean', 'ndmi_mean', 'ndwi_mean', 'ndbi_mean', 
                 'ndvi_std', 'ndmi_std', 'ndwi_std', 'ndbi_std', 'lst',
                 'lst_day', 'lst_night','lst_jan_day_mean', 'lst_jan_night_mean', 
                 'lst_feb_day_mean','lst_feb_night_mean', 'lst_mar_day_mean', 
                 'lst_mar_night_mean', 'lst_apr_day_mean', 'lst_apr_night_mean',
                 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan',
                 'mosq_pred', 'mosq_previous', 'case']

# %%
len(final_columns)
# Out:
# 48

# %%
dataset_final = dataset[final_columns].copy()

# %%
dataset_final
# Out:
#            x         y dt_placement    nuts2                       lau1  day  \
# 0   23.65697  37.99220   2023-08-01  αττικης             αγιας βαρβαρας    1
# 1   23.82642  38.00806   2023-08-01  αττικης           αγιας παρασκευης    1
ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst  lst_day  lst_night  \
# 0   0.033199  0.012476  0.027588  0.012476  NaN      NaN        NaN
# 1   0.022706  0.014833  0.016365  0.014833  NaN      NaN        NaN
# 2   0.022599  0.009434  0.018917  0.009434  NaN      NaN        NaN
# 3   0.036587  0.016287  0.024380  0.016287  NaN      NaN        NaN
# 4   0.024057  0.052899  0.012071  0.052899  NaN      NaN        NaN
# ..       ...       ...       ...       ...  ...      ...        ...
# 61  0.028055  0.024144  0.020873  0.024144  NaN      NaN        NaN
# 62  0.041412  0.041924  0.021443  0.041924  NaN      NaN        NaN
# 63  0.047232  0.033458  0.032985  0.033458  NaN      NaN        NaN
# 64  0.025868  0.039354  0.012063  0.039354  NaN      NaN        NaN
# 65  0.052177  0.042314  0.026526  0.042314  NaN      NaN        NaN
#
#     lst_jan_day_mean  lst_jan_night_mean  lst_feb_day_mean  \
# 0          14.510000            8.020000         13.701111
# 1          13.528571            7.794000         15.082000
# 2          14.659231            9.341000         13.997273
# 3          14.245000            7.601579         13.116000
# 4          14.222174           10.644444         12.956316
# ..               ...                 ...               ...
# 61         13.582632            8.011053         13.871667
# 62         12.587124            5.249197         12.091667
# 63         13.810000            8.001579         14.400000
# 64         13.957619            7.282222         14.100667
# 65         11.865984            6.031929         12.192081
#
#     lst_feb_night_mean  lst_mar_day_mean  lst_mar_night_mean  \
# 0             6.297619         19.888462           11.006923
# 1             6.037273         18.770000            9.570000
# 2             6.772609         20.618000           10.591250
# 3             6.119474         20.710000            9.976667
# 4             9.337778         15.516364           11.618000
# ..                 ...               ...                 ...
# 61            6.102174         18.886923            9.584444
# 62            4.206046         16.850254            7.007571
# 63            6.572857         19.803333            9.421765
# 64            5.342000         18.247500            9.808667
# 65            4.148453         16.165030            6.891611
#
#     lst_apr_day_mean  lst_apr_night_mean  acc_rainfall_1week  \
# 0          23.446923           12.160000            0.000000
# 1          21.901111           11.314000            0.000000
# 2          24.562941           12.900000            0.000000
# 3          23.675000           11.323333            0.000000
# 4          17.763600           12.083333            0.000664
# ..               ...                 ...                 ...
# 61         23.132667           11.928571            0.000000
# 62         20.796111            8.497071            0.000000
# 63         22.716667           10.272857            0.000000
# 64         22.731176           11.818000            0.000000
# 65         19.714436            8.672008            0.000000
#
#     acc_rainfall_2week  acc_rainfall_jan  mosq_pred  mosq_previous  case
# 0             0.000000        348.910701         43              0     0
# 1             0.000000        425.951674         32              0     0
# 2             0.000000        365.646401         37              0     0
# 3             0.000000        437.278102         36              0     0
# 4             0.000664        485.607975         35              0     0
# ..                 ...               ...        ...            ...   ...
# 61            0.000000        437.278102         32              0     0
# 62            0.000000        400.114421         26              0     0
# 63            0.000000        425.951674         30              0     0
# 64            0.000000        439.846210         31              0     0
# 65            0.000000        385.292602         24              0     0
#
# [66 rows x 48 columns]

# %%
dataset_final.to_csv(f"../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Dataset_{YEAR}-{MONTH}-{PERIOD}.csv", encoding = enc, index = False)
