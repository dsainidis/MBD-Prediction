# %%
import numpy as np
import pandas as pd
import random
import csv
import geopandas as gpd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, MaxAbsScaler
from sklearn.impute import KNNImputer
import sys
import pickle

sys.path.insert(0, "../../../Modules")

pd.set_option('display.max_columns', None)
random.seed(0)
np.random.seed(0)

from utils import *
from utils import process_greek

enc = 'utf-8'
shapefiles_folder = "C:/Users/dimit/Documents/noa hoard/Greece Shapefiles"
# Out:
# c:\Users\dimit\AppData\Local\Programs\Python\Python39\lib\site-packages\geopandas\_compat.py:112: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
NUTS0 = 'GR'
NUTS2 = 'Attica'

# %%
YEAR = 2023
MONTH = 'May'
PERIOD = '2nd'

# %%
model = pickle.load(open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Linear_model.pkl', 'rb'))

# %%
data_test = read_data(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Dataset_{YEAR}-{MONTH}-{PERIOD}.csv')
data_test.head()
# Out:
#           x         y dt_placement    nuts2                       lau1  day  \
# 0  23.65697  37.99220   2023-05-16  αττικης             αγιας βαρβαρας   16
# 1  23.82642  38.00806   2023-05-16  αττικης           αγιας παρασκευης   16
# 2  23.73031  37.93357   2023-05-16  αττικης            αγιου δημητριου   16
# 3  23.71341  38.04721   2023-05-16  αττικης  αγιων αναργυρων καματερου   16
# 4  23.34009  37.69503   2023-05-16  αττικης                 αγκιστριου   16
#
#    month  week  year   day_sin   day_cos  month_sin  month_cos  week_sin  \
# 0      5    20  2023 -0.101168 -0.994869        0.5  -0.866025  0.696551
# 1      5    20  2023 -0.101168 -0.994869        0.5  -0.866025  0.696551
# 2      5    20  2023 -0.101168 -0.994869        0.5  -0.866025  0.696551
# 3      5    20  2023 -0.101168 -0.994869        0.5  -0.866025  0.696551
# 4      5    20  2023 -0.101168 -0.994869        0.5  -0.866025  0.696551
#
#    week_cos  area  population  population_density  eq_distance      ndvi  \
# 0 -0.717507   2.4     26759.0             10925.9     44.75555  0.090353
# 1 -0.717507   7.9     62157.0              7557.5     44.85879  0.216025
# 2 -0.717507   5.0     71747.0             14402.8     44.74465  0.143494
# 3 -0.717507   9.2     61427.0              6833.8     44.83209  0.166491
# 4 -0.717507  13.4      1107.0                85.2     44.33593  0.307242
#
#        ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  \
# 0  0.019062 -0.139872 -0.019062   0.065006   0.003119  -0.091801  -0.003119
# 1  0.057148 -0.243549 -0.057148   0.160986   0.074110  -0.153925  -0.074110
# 2 -0.014576 -0.195956  0.014576   0.112242  -0.014837  -0.161088   0.014837
# 3  0.029767 -0.187131 -0.029767   0.183561   0.031259  -0.200059  -0.031259
# 4  0.014311 -0.222549 -0.014311   0.319639   0.036386  -0.233963  -0.036386
#
#    ndvi_std  ndmi_std  ndwi_std  ndbi_std    lst  lst_day  lst_night  \
# 0  0.001933  0.004045  0.006257  0.004045  20.20    23.35      17.05
# 1  0.005639  0.008020  0.001707  0.008020  19.83    24.57      15.09
# 2  0.031192  0.022430  0.036681  0.022430  22.05    26.83      17.27
# 3  0.040949  0.022205  0.037270  0.022205  25.22    33.61      16.83
# 4  0.024963  0.053015  0.011530  0.053015  18.16    20.23      16.09
#
#    lst_jan_day_mean  lst_jan_night_mean  lst_feb_day_mean  lst_feb_night_mean  \
# 0         14.510000            8.020000         13.701111            6.297619
# 1         13.528571            7.794000         15.082000            6.037273
# 2         14.659231            9.341000         13.997273            6.772609
# 3         14.245000            7.601579         13.116000            6.119474
# 4         14.222174           10.644444         12.956316            9.337778
#
#    lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  lst_apr_night_mean  \
# 0         19.888462           11.006923         23.446923           12.160000
# 1         18.770000            9.570000         21.901111           11.314000
# 2         20.618000           10.591250         24.562941           12.900000
# 3         20.710000            9.976667         23.675000           11.323333
# 4         15.516364           11.618000         17.763600           12.083333
#
#    acc_rainfall_1week  acc_rainfall_2week  acc_rainfall_jan  \
# 0                 0.0                 0.0        318.222359
# 1                 0.0                 0.0        389.356250
# 2                 0.0                 0.0        355.883585
# 3                 0.0                 0.0        397.347602
# 4                 0.0                 0.0        472.697967
#
#    distance_to_coast  distance_to_river  slope_mean_1km  aspect_mean_200m  \
# 0        4986.234414        2455.349701               5        136.450508
# 1       14419.406690        1186.404835              17        195.624294
# 2        3030.589205         923.760750               6        197.484591
# 3       10104.114693         102.938851               2        185.470524
# 4         703.682089       16702.208116               8        264.649030
#
#    elevation_mean_1km  hillshade_mean_1km  fs_area_1km  flow_accu_200m  \
# 0          101.355755          167.697476     0.000000        1.730851
# 1          247.122730          186.152654     0.000000        4.727984
# 2           76.843700          185.824323     0.000000       10.672627
# 3          110.515124          178.698121     0.000000      247.581759
# 4          132.349467          189.350397     0.115955        1.705489
#
#    lc_prop1  lc_prop1_assessment  lc_prop2  lc_prop2_assessment  lc_prop3  \
# 0        32                   96         9                 99.0        30
# 1        32                   97         9                 99.0        30
# 2        32                   80         9                 79.0        30
# 3        32                   87         9                 99.0        30
# 4        21                   71        20                 71.0        20
#
#    lc_prop3_assessment  lc_type1  lc_type2  lc_type3  lc_type4  lc_type5  lw  \
# 0                   96        13        13        10         8         9   2
# 1                   97        13        13        10         8         9   2
# 2                   80        13        13        10         8         9   2
# 3                   87        13        13        10         8         9   2
# 4                   71         8         8         4         1         1   2
#
#    qc  mosq_pred  mosq_previous  case
# 0   0        196              0     0
# 1   0        110              0     0
# 2   0        162              0     0
# 3   0         85              0     0
# 4   0         68              0     0

# %%
X_test = data_test.select_dtypes(exclude=['object']).drop(columns = ['case'])
y_test = data_test['case']

scaler = MinMaxScaler()
imputer = KNNImputer()

X_test = scaler.fit_transform(X_test)
X_test = imputer.fit_transform(X_test)

results_test = inference_lin_model(model, data_test, X_test, y_test)

# %%
results_test.drop(columns='case', inplace= True)
results_test
# Out:
#            x         y               lau1  day  month  year     score
# 0   23.36970  38.14150  μανδρας ειδυλλιας   16      5  2023  0.999906
# 1   23.49864  37.73843            αιγινας   16      5  2023  0.999666
# 2   23.26333  38.03007           μεγαρεων   16      5  2023  0.999216
# 3   23.78661  38.25918             ωρωπου   16      5  2023  0.998709
# 4   23.95676  38.02027  ραφηνας πικερμιου   16      5  2023  0.998331
# ..       ...       ...                ...  ...    ...   ...       ...
# 61  23.80511  37.99143   παπαγου χολαργου   16      5  2023  0.601696
# 62  23.34009  37.69503         αγκιστριου   16      5  2023  0.561954
# 63  23.43348  37.33221              υδρας   16      5  2023  0.154287
# 64  23.79175  37.96013        καισαριανης   16      5  2023  0.017713
# 65  22.98514  36.25037            κυθηρων   16      5  2023  0.000398
#
# [66 rows x 7 columns]

# %%
bins_path = f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Bins_{YEAR}.csv'

bins = []

with open(bins_path, mode='r', newline='') as file:
    reader = csv.reader(file)
    for row in reader:
        bins.extend(map(float, row))

print(bins)
# Out:
# [0.0, 0.0551293142597989, 0.309017870770514, 0.5848636387272795, 0.864260171276974, 0.9864932650737608, 1.0]

# %%
results_test['risk_class'] = pd.cut(results_test['score'], bins=bins, labels=False, include_lowest=True)
results_test
# Out:
#            x         y               lau1  day  month  year     score  \
# 0   23.36970  38.14150  μανδρας ειδυλλιας   16      5  2023  0.999906
# 1   23.49864  37.73843            αιγινας   16      5  2023  0.999666
# 2   23.26333  38.03007           μεγαρεων   16      5  2023  0.999216
# 3   23.78661  38.25918             ωρωπου   16      5  2023  0.998709
# 4   23.95676  38.02027  ραφηνας πικερμιου   16      5  2023  0.998331
# ..       ...       ...                ...  ...    ...   ...       ...
# 61  23.80511  37.99143   παπαγου χολαργου   16      5  2023  0.601696
# 62  23.34009  37.69503         αγκιστριου   16      5  2023  0.561954
# 63  23.43348  37.33221              υδρας   16      5  2023  0.154287
# 64  23.79175  37.96013        καισαριανης   16      5  2023  0.017713
# 65  22.98514  36.25037            κυθηρων   16      5  2023  0.000398
#
#     risk_class
# 0            5
# 1            5
# 2            5
# 3            5
# 4            5
# ..         ...
# 61           3
# 62           2
# 63           1
# 64           0
# 65           0
#
# [66 rows x 8 columns]

# %%
results_test.to_csv(f"../../data/{NUTS2}/results/{NUTS0}_{NUTS2}_Results_{YEAR}-{MONTH}-{PERIOD}_(new).csv", encoding = enc, index = False)

# %%
##TODO Visualisation of results
