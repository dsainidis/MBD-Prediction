# %%
import numpy as np
import pandas as pd
import random
from sklearn.linear_model import LogisticRegression
import sys

sys.path.insert(0, "../../../Modules")

pd.set_option('display.max_columns', None)
random.seed(0)
np.random.seed(0)

from utils import *

# %%
NUTS0 = 'GR'
NUTS2 = 'CMacedonia'

# %%
f = open(f"../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_2010-2021_Cases_Dates.txt", "r")
print(f.read())
# Out:
# months: 6, 7, 8, 9, 10,
# years: 2010, 2011, 2012, 2013, 2018, 2019, 2020, 2021,

# %%
f = open(f"../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_2022_Cases_Dates.txt", "r")
print(f.read())
# Out:
# months: 7, 8, 9, 10, 11,
# years: 2022,

# %%
r_u = 0.05
near_u = 0.25
smote = 1
scaler = 'minmax'
#years_to_remove = [year for year in range(2012, 2018)]
years_to_remove = []
path_train = f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Dataset_2010_2021.csv'
path_test = f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Dataset_2022.csv'

# %%
dataset_train = read_data(path_train, exclude_years = years_to_remove)
dataset_train.head()
# Out:
#           x         y dt_placement                 nuts2  \
# 0  22.48398  40.64468   2010-01-01  κεντρικης μακεδονιας
# 1  21.94079  40.97703   2010-01-01  κεντρικης μακεδονιας
# 2  22.89198  40.65603   2010-01-01  κεντρικης μακεδονιας
# 3  23.98253  40.91510   2010-01-01  κεντρικης μακεδονιας
# 4  23.69108  40.49593   2010-01-01  κεντρικης μακεδονιας
#
#                     lau1  day  month  week  year   day_sin  day_cos  \
# 0           αλεξανδρειας    1      1    53  2010  0.201299  0.97953
# 1               αλμωπιας    1      1    53  2010  0.201299  0.97953
# 2  αμπελοκηπων μενεμενης    1      1    53  2010  0.201299  0.97953
# 3              αμφιπολης    1      1    53  2010  0.201299  0.97953
# 4             αριστοτελη    1      1    53  2010  0.201299  0.97953
#
#    month_sin  month_cos      week_sin  week_cos   area  population  \
# 0        0.5   0.866025 -2.449294e-16       1.0  478.8     38293.0
# 1        0.5   0.866025 -2.449294e-16       1.0  985.8     24924.0
# 2        0.5   0.866025 -2.449294e-16       1.0    9.8     49674.0
# 3        0.5   0.866025 -2.449294e-16       1.0  411.8      7169.0
# 4        0.5   0.866025 -2.449294e-16       1.0  747.0     16994.0
#
#    population_density  eq_distance      ndvi      ndmi      ndwi      ndbi  \
# 0                86.8     46.44911       NaN       NaN       NaN       NaN
# 1                28.0     46.48134       NaN       NaN       NaN       NaN
# 2              5319.1     46.65786       NaN       NaN       NaN       NaN
# 3                22.3     47.42581       NaN       NaN       NaN       NaN
# 4                24.5     46.91682  0.036921  0.159004  0.193601 -0.159004
#
#    ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  \
# 0        NaN        NaN        NaN        NaN       NaN       NaN       NaN
# 1        NaN        NaN        NaN        NaN       NaN       NaN       NaN
# 2        NaN        NaN        NaN        NaN       NaN       NaN       NaN
# 3        NaN        NaN        NaN        NaN       NaN       NaN       NaN
# 4   0.036921   0.159004   0.193601  -0.159004       0.0       0.0       0.0
#
#    ndbi_std        lst    lst_day  lst_night  lst_jan_day_mean  \
# 0       NaN   9.390000  11.935000      6.845          7.618333
# 1       NaN   8.657273  11.324545      5.990          4.240266
# 2       NaN  11.180000  13.470000      8.890         12.730000
# 3       NaN  10.742500  13.120000      8.365          8.059333
# 4       0.0  11.447500  15.240000      7.655          9.412740
#
#    lst_jan_night_mean  lst_feb_day_mean  lst_feb_night_mean  lst_mar_day_mean  \
# 0            3.670476          9.961333            1.982765         18.738689
# 1            1.734176          4.199935            1.072630         11.344401
# 2            5.510000          9.853333            3.612000         18.272222
# 3            3.832476          9.231646            1.955639         14.550773
# 4            4.925685          8.219720            2.711017         15.334974
#
#    lst_mar_night_mean  lst_apr_day_mean  lst_apr_night_mean  \
# 0            4.318686         29.464560            9.289931
# 1            2.127124         18.823986            6.621377
# 2            6.046667         26.770000           11.750000
# 3            3.470297         20.603567            8.292500
# 4            3.402690         18.882057            7.497680
#
#    acc_rainfall_1week  acc_rainfall_2week  acc_rainfall_jan  \
# 0            0.015560            0.015560          0.015560
# 1            0.248551            0.248551          0.248551
# 2            0.000000            0.000000          0.000000
# 3            0.055994            0.055994          0.055994
# 4            1.750566            1.750566          1.750566
#
#    distance_to_coast  distance_to_river  slope_mean_1km  aspect_mean_200m  \
# 0       21798.191901         561.876983               3        148.634810
# 1       21799.947368         819.637594              34         54.056037
# 2        1013.723139        1259.926671               2        166.963790
# 3       16270.860936          21.768793              12        152.028440
# 4       11468.297401        1749.385768              22        273.587292
#
#    elevation_mean_1km  hillshade_mean_1km  fs_area_1km  flow_accu_200m  \
# 0            2.247180          180.067365          0.0        5.738407
# 1          965.390539          175.271364          0.0        1.000000
# 2            4.655965          180.457193          0.0       24.343007
# 3          529.676707          197.614059          0.0      116.778232
# 4          768.043224          181.562024          0.0        1.033661
#
#    lc_prop1  lc_prop1_assessment  lc_prop2  lc_prop2_assessment  lc_prop3  \
# 0        31                   99        36                 99.0        30
# 1        14                   99        10                 99.0        10
# 2        32                   97         9                 99.0        30
# 3        22                   74        20                 74.0        20
# 4        14                   99        10                 99.0        10
#
#    lc_prop3_assessment  lc_type1  lc_type2  lc_type3  lc_type4  lc_type5  lw  \
# 0                   99        12        12         1         6         7   2
# 1                   99         4         4         6         4         4   2
# 2                   97        13        13        10         8         9   2
# 3                   74         9         9         4         1         1   2
# 4                   99         4         4         6         4         4   2
#
#    qc  mosq_pred  mosq_previous  case
# 0   0          5              0     0
# 1   0          1              0     0
# 2   0          7              0     0
# 3   0         20              0     0
# 4   0          4              0     0

# %%
dataset_test = read_data(path_test, exclude_years = years_to_remove)
dataset_test.head()
# Out:
#           x         y dt_placement                 nuts2  \
# 0  22.48398  40.64468   2022-01-01  κεντρικης μακεδονιας
# 1  21.94079  40.97703   2022-01-01  κεντρικης μακεδονιας
# 2  22.89198  40.65603   2022-01-01  κεντρικης μακεδονιας
# 3  23.98253  40.91510   2022-01-01  κεντρικης μακεδονιας
# 4  23.69108  40.49593   2022-01-01  κεντρικης μακεδονιας
#
#                     lau1  day  month  week  year   day_sin  day_cos  \
# 0           αλεξανδρειας    1      1    52  2022  0.201299  0.97953
# 1               αλμωπιας    1      1    52  2022  0.201299  0.97953
# 2  αμπελοκηπων μενεμενης    1      1    52  2022  0.201299  0.97953
# 3              αμφιπολης    1      1    52  2022  0.201299  0.97953
# 4             αριστοτελη    1      1    52  2022  0.201299  0.97953
#
#    month_sin  month_cos  week_sin  week_cos   area  population  \
# 0        0.5   0.866025 -0.118273  0.992981  478.8     38293.0
# 1        0.5   0.866025 -0.118273  0.992981  985.8     24924.0
# 2        0.5   0.866025 -0.118273  0.992981    9.8     49674.0
# 3        0.5   0.866025 -0.118273  0.992981  411.8      7169.0
# 4        0.5   0.866025 -0.118273  0.992981  747.0     16994.0
#
#    population_density  eq_distance  ndvi  ndmi  ndwi  ndbi  ndvi_mean  \
# 0                86.8     46.44911   NaN   NaN   NaN   NaN        NaN
# 1                28.0     46.48134   NaN   NaN   NaN   NaN        NaN
# 2              5319.1     46.65786   NaN   NaN   NaN   NaN        NaN
# 3                22.3     47.42581   NaN   NaN   NaN   NaN        NaN
# 4                24.5     46.91682   NaN   NaN   NaN   NaN        NaN
#
#    ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  \
# 0        NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 1        NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 2        NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 3        NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 4        NaN        NaN        NaN       NaN       NaN       NaN       NaN
#
#         lst    lst_day  lst_night  lst_jan_day_mean  lst_jan_night_mean  \
# 0       NaN        NaN   7.450000          8.126419           -1.340303
# 1  9.810778  12.236000   7.385556          5.156188           -0.429920
# 2       NaN        NaN   9.770000          8.206667            1.223333
# 3       NaN        NaN   5.935000          5.506350           -0.849211
# 4  8.014583   9.186667   6.842500          5.626176            0.027273
#
#    lst_feb_day_mean  lst_feb_night_mean  lst_mar_day_mean  lst_mar_night_mean  \
# 0         16.216012            1.011667         18.020179            1.565813
# 1          9.002046            1.203846          8.268402            0.655058
# 2         14.106000            3.702000         17.271538            2.883846
# 3         10.168715            1.184231         13.528745            0.333718
# 4          8.827055            1.857362         12.089767            0.979534
#
#    lst_apr_day_mean  lst_apr_night_mean  acc_rainfall_1week  \
# 0         32.641755            8.896456            0.113685
# 1         20.890796            6.749332            2.557299
# 2         26.801250            9.896667            0.000000
# 3         22.552471            8.162000            0.417504
# 4         20.756913            8.392523            0.000000
#
#    acc_rainfall_2week  acc_rainfall_jan  distance_to_coast  distance_to_river  \
# 0            0.113685          0.113685       21798.191901         561.876983
# 1            2.557299          2.557299       21799.947368         819.637594
# 2            0.000000          0.000000        1013.723139        1259.926671
# 3            0.417504          0.417504       16270.860936          21.768793
# 4            0.000000          0.000000       11468.297401        1749.385768
#
#    slope_mean_1km  aspect_mean_200m  elevation_mean_1km  hillshade_mean_1km  \
# 0               3        148.634810            2.247180          180.067365
# 1              34         54.056037          965.390539          175.271364
# 2               2        166.963790            4.655965          180.457193
# 3              12        152.028440          529.676707          197.614059
# 4              22        273.587292          768.043224          181.562024
#
#    fs_area_1km  flow_accu_200m  lc_prop1  lc_prop1_assessment  lc_prop2  \
# 0          0.0        5.738407        31                   99        36
# 1          0.0        1.000000        14                   99        10
# 2          0.0       24.343007        32                   97         9
# 3          0.0      116.778232        22                   79        20
# 4          0.0        1.033661        14                   99        10
#
#    lc_prop2_assessment  lc_prop3  lc_prop3_assessment  lc_type1  lc_type2  \
# 0                 99.0        30                   99        12        12
# 1                 99.0        10                   99         4         4
# 2                 99.0        30                   97        13        13
# 3                 79.0        20                   79         9         9
# 4                 99.0        10                   99         4         4
#
#    lc_type3  lc_type4  lc_type5  lw  qc  mosq_pred  mosq_previous  case
# 0         1         6         7   2   0         26              0     0
# 1         6         4         4   2   0          1              0     0
# 2        10         8         9   2   0         26              0     0
# 3         4         1         1   2   0         26              0     0
# 4         6         4         4   2   0          1              0     0

# %%
#Check months

dataset_train = dataset_train.query('month >= 6 & month <= 11')
dataset_train.reset_index(inplace=True, drop=True)

# %%
dataset_train
# Out:
#              x         y dt_placement                 nuts2  \
# 0     22.48398  40.64468   2010-06-01  κεντρικης μακεδονιας
# 1     21.94079  40.97703   2010-06-01  κεντρικης μακεδονιας
# 2     22.89198  40.65603   2010-06-01  κεντρικης μακεδονιας
# 3     23.98253  40.91510   2010-06-01  κεντρικης μακεδονιας
# 4     23.69108  40.49593   2010-06-01  κεντρικης μακεδονιας
# ...        ...       ...          ...                   ...
# 5763  22.14670  40.82294   2021-08-16  κεντρικης μακεδονιας
# 5764  22.41285  40.81412   2021-08-01  κεντρικης μακεδονιας
# 5765  22.15177  40.44520   2021-08-16  κεντρικης μακεδονιας
# 5766  22.41285  40.81412   2021-08-16  κεντρικης μακεδονιας
# 5767  22.14670  40.82294   2021-08-16  κεντρικης μακεδονιας
#
#                        lau1  day  month  week  year   day_sin   day_cos  \
# 0              αλεξανδρειας    1      6    22  2010  0.201299  0.979530
# 1                  αλμωπιας    1      6    22  2010  0.201299  0.979530
# 2     αμπελοκηπων μενεμενης    1      6    22  2010  0.201299  0.979530
# 3                 αμφιπολης    1      6    22  2010  0.201299  0.979530
# 4                αριστοτελη    1      6    22  2010  0.201299  0.979530
# ...                     ...  ...    ...   ...   ...       ...       ...
# 5763                σκυδρας   16      8    33  2021 -0.101168 -0.994869
# 5764                 πελλας    1      8    30  2021  0.201299  0.979530
# 5765                βεροιας   16      8    33  2021 -0.101168 -0.994869
# 5766                 πελλας   16      8    33  2021 -0.101168 -0.994869
# 5767                σκυδρας   16      8    33  2021 -0.101168 -0.994869
#
#          month_sin  month_cos  week_sin  week_cos   area  population  \
# 0     1.224647e-16       -1.0  0.508531 -0.861044  478.8     38293.0
# 1     1.224647e-16       -1.0  0.508531 -0.861044  985.8     24924.0
# 2     1.224647e-16       -1.0  0.508531 -0.861044    9.8     49674.0
# 3     1.224647e-16       -1.0  0.508531 -0.861044  411.8      7169.0
# 4     1.224647e-16       -1.0  0.508531 -0.861044  747.0     16994.0
# ...            ...        ...       ...       ...    ...         ...
# 5763 -8.660254e-01       -0.5 -0.696551 -0.717507  239.5     18080.0
# 5764 -8.660254e-01       -0.5 -0.403123 -0.915146  669.2     56918.0
# 5765 -8.660254e-01       -0.5 -0.696551 -0.717507  796.5     62064.0
# 5766 -8.660254e-01       -0.5 -0.696551 -0.717507  669.2     56918.0
# 5767 -8.660254e-01       -0.5 -0.696551 -0.717507  239.5     18080.0
#
#       population_density  eq_distance      ndvi      ndmi      ndwi      ndbi  \
# 0                   86.8     46.44911  0.237090 -0.048711 -0.317377  0.048711
# 1                   28.0     46.48134  0.610494  0.297777 -0.269769 -0.297777
# 2                 5319.1     46.65786  0.158598 -0.002042 -0.195420  0.002042
# 3                   22.3     47.42581  0.600695  0.348246 -0.219345 -0.348246
# 4                   24.5     46.91682  0.517065  0.247244 -0.249138 -0.247244
# ...                  ...          ...       ...       ...       ...       ...
# 5763                84.3     46.44339  0.445122  0.014416 -0.427180 -0.014416
# 5764                94.3     46.56316  0.428876  0.049528 -0.421793 -0.049528
# 5765                83.5     46.11415  0.607984  0.180537 -0.521345 -0.180537
# 5766                94.3     46.56316  0.409942  0.025964 -0.413967 -0.025964
# 5767                84.3     46.44339  0.445122  0.014416 -0.427180 -0.014416
#
#       ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  \
# 0      0.233606  -0.039714  -0.304677   0.039714  0.064241  0.055555
# 1      0.589813   0.268988  -0.282681  -0.268988  0.054153  0.046797
# 2      0.161290  -0.000149  -0.195554   0.000149  0.079131  0.039658
# 3      0.564287   0.283836  -0.257383  -0.283836  0.049732  0.050856
# 4      0.548352   0.286086  -0.228926  -0.286086  0.042899  0.042628
# ...         ...        ...        ...        ...       ...       ...
# 5763   0.443690   0.017735  -0.421358  -0.017735  0.118285  0.115395
# 5764   0.424337   0.039825  -0.417760  -0.039825  0.086261  0.075733
# 5765   0.553707   0.143929  -0.486465  -0.143929  0.110443  0.086152
# 5766   0.406070   0.019722  -0.408867  -0.019722  0.089963  0.080993
# 5767   0.443690   0.017735  -0.421358  -0.017735  0.118285  0.115395
#
#       ndwi_std  ndbi_std        lst    lst_day  lst_night  lst_jan_day_mean  \
# 0     0.021262  0.055555  27.490000  38.045000  16.935000          7.618333
# 1     0.051947  0.046797  19.087273  24.759091  13.415455          4.240266
# 2     0.030081  0.039658  26.500000  35.950000  17.050000         12.730000
# 3     0.027357  0.050856  24.495000  30.690000  18.300000          8.059333
# 4     0.027381  0.042628  19.367500  24.000000  14.735000          9.412740
# ...        ...       ...        ...        ...        ...               ...
# 5763  0.067481  0.115395  30.280000  37.640000  22.920000          8.027348
# 5764  0.052849  0.075733  28.066000  34.806000  21.326000          8.274332
# 5765  0.076162  0.086152  24.965714  30.210000  19.721429          3.536070
# 5766  0.054664  0.080993  31.210000  39.146000  23.274000          8.274332
# 5767  0.067481  0.115395  30.280000  37.640000  22.920000          8.027348
#
#       lst_jan_night_mean  lst_feb_day_mean  lst_feb_night_mean  \
# 0               3.670476          9.961333            1.982765
# 1               1.734176          4.199935            1.072630
# 2               5.510000          9.853333            3.612000
# 3               3.832476          9.231646            1.955639
# 4               4.925685          8.219720            2.711017
# ...                  ...               ...                 ...
# 5763           -1.694000         16.188258            3.720184
# 5764           -0.882878         15.858857            4.070955
# 5765            0.463000          8.306008            3.348285
# 5766           -0.882878         15.858857            4.070955
# 5767           -1.694000         16.188258            3.720184
#
#       lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  \
# 0            18.738689            4.318686         29.464560
# 1            11.344401            2.127124         18.823986
# 2            18.272222            6.046667         26.770000
# 3            14.550773            3.470297         20.603567
# 4            15.334974            3.402690         18.882057
# ...                ...                 ...               ...
# 5763         18.653647            3.363529         23.454958
# 5764         20.371221            3.582500         25.752451
# 5765         12.269446            1.182928         18.425658
# 5766         20.371221            3.582500         25.752451
# 5767         18.653647            3.363529         23.454958
#
#       lst_apr_night_mean  acc_rainfall_1week  acc_rainfall_2week  \
# 0               9.289931           27.661434           69.883681
# 1               6.621377           19.182475           53.285836
# 2              11.750000           60.840037           99.001511
# 3               8.292500           29.119374           48.335329
# 4               7.497680           27.828753           56.447650
# ...                  ...                 ...                 ...
# 5763            6.352353            4.010308           12.030641
# 5764            6.380588            0.456408           12.378124
# 5765            4.826882            2.535976            2.636255
# 5766            6.380588           14.941811           15.814512
# 5767            6.352353            4.010308           12.030641
#
#       acc_rainfall_jan  distance_to_coast  distance_to_river  slope_mean_1km  \
# 0           634.525996       21798.191901         561.876983               3
# 1           708.081877       21799.947368         819.637594              34
# 2           625.519261        1013.723139        1259.926671               2
# 3           661.806941       16270.860936          21.768793              12
# 4           608.274993       11468.297401        1749.385768              22
# ...                ...                ...                ...             ...
# 5763        692.442186       20467.087760        2556.132830               4
# 5764        667.661598       18812.025826         788.419376               5
# 5765        736.955619        8361.853508        1056.980614               8
# 5766        683.476109       18812.025826         788.419376               5
# 5767        692.442186       20467.087760        2556.132830               4
#
#       aspect_mean_200m  elevation_mean_1km  hillshade_mean_1km  fs_area_1km  \
# 0           148.634810            2.247180          180.067365          0.0
# 1            54.056037          965.390539          175.271364          0.0
# 2           166.963790            4.655965          180.457193          0.0
# 3           152.028440          529.676707          197.614059          0.0
# 4           273.587292          768.043224          181.562024          0.0
# ...                ...                 ...                 ...          ...
# 5763        227.370939          344.084297          191.478748          0.0
# 5764        141.814646          171.228187          175.809127          0.0
# 5765        126.512756          590.387395          156.610698          0.0
# 5766        141.814646          171.228187          175.809127          0.0
# 5767        227.370939          344.084297          191.478748          0.0
#
#       flow_accu_200m  lc_prop1  lc_prop1_assessment  lc_prop2  \
# 0           5.738407        31                   99        36
# 1           1.000000        14                   99        10
# 2          24.343007        32                   97         9
# 3         116.778232        22                   74        20
# 4           1.033661        14                   99        10
# ...              ...       ...                  ...       ...
# 5763        1.165700        22                   79        20
# 5764        1.000000        31                   98        36
# 5765        1.926913        15                   86        10
# 5766        1.000000        31                   98        36
# 5767        1.165700        22                   79        20
#
#       lc_prop2_assessment  lc_prop3  lc_prop3_assessment  lc_type1  lc_type2  \
# 0                    99.0        30                   99        12        12
# 1                    99.0        10                   99         4         4
# 2                    99.0        30                   97        13        13
# 3                    74.0        20                   74         9         9
# 4                    99.0        10                   99         4         4
# ...                   ...       ...                  ...       ...       ...
# 5763                 79.0        20                   79         9         9
# 5764                 98.0        30                   98        12        12
# 5765                 90.0        10                   90         5         5
# 5766                 98.0        30                   98        12        12
# 5767                 79.0        20                   79         9         9
#
#       lc_type3  lc_type4  lc_type5  lw  qc  mosq_pred  mosq_previous  case
# 0            1         6         7   2   0          5             10     0
# 1            6         4         4   2   0          1              2     0
# 2           10         8         9   2   0          7             14     0
# 3            4         1         1   2   0         20             40     0
# 4            6         4         4   2   0          4              8     0
# ...        ...       ...       ...  ..  ..        ...            ...   ...
# 5763         4         4         4   2   0          4              8     1
# 5764         3         5         8   2   0          4              8     1
# 5765         6         4         4   2   0          2              4     1
# 5766         3         5         8   2   0          4              8     1
# 5767         4         4         4   2   0          4              8     1
#
# [5768 rows x 69 columns]

# %%
#Check months

dataset_test = dataset_test.query('month >= 6 & month <= 11')
dataset_test.reset_index(inplace=True, drop=True)

# %%
dataset_test
# Out:
#             x         y dt_placement                 nuts2  \
# 0    22.48398  40.64468   2022-06-01  κεντρικης μακεδονιας
# 1    21.94079  40.97703   2022-06-01  κεντρικης μακεδονιας
# 2    22.89198  40.65603   2022-06-01  κεντρικης μακεδονιας
# 3    23.98253  40.91510   2022-06-01  κεντρικης μακεδονιας
# 4    23.69108  40.49593   2022-06-01  κεντρικης μακεδονιας
# ..        ...       ...          ...                   ...
# 493  22.48398  40.64468   2022-08-16  κεντρικης μακεδονιας
# 494  22.15177  40.44520   2022-08-16  κεντρικης μακεδονιας
# 495  22.95369  40.62334   2022-08-16  κεντρικης μακεδονιας
# 496  23.24414  40.32110   2022-08-16  κεντρικης μακεδονιας
# 497  23.05120  40.60697   2022-08-16  κεντρικης μακεδονιας
#
#                       lau1  day  month  week  year   day_sin   day_cos  \
# 0             αλεξανδρειας    1      6    22  2022  0.201299  0.979530
# 1                 αλμωπιας    1      6    22  2022  0.201299  0.979530
# 2    αμπελοκηπων μενεμενης    1      6    22  2022  0.201299  0.979530
# 3                αμφιπολης    1      6    22  2022  0.201299  0.979530
# 4               αριστοτελη    1      6    22  2022  0.201299  0.979530
# ..                     ...  ...    ...   ...   ...       ...       ...
# 493           αλεξανδρειας   16      8    33  2022 -0.101168 -0.994869
# 494                βεροιας   16      8    33  2022 -0.101168 -0.994869
# 495           θεσσαλονικης   16      8    33  2022 -0.101168 -0.994869
# 496       νεας προποντιδας   16      8    33  2022 -0.101168 -0.994869
# 497       πυλαιας χορτιατη   16      8    33  2022 -0.101168 -0.994869
#
#         month_sin  month_cos  week_sin  week_cos   area  population  \
# 0    1.224647e-16       -1.0  0.508531 -0.861044  478.8     38293.0
# 1    1.224647e-16       -1.0  0.508531 -0.861044  985.8     24924.0
# 2    1.224647e-16       -1.0  0.508531 -0.861044    9.8     49674.0
# 3    1.224647e-16       -1.0  0.508531 -0.861044  411.8      7169.0
# 4    1.224647e-16       -1.0  0.508531 -0.861044  747.0     16994.0
# ..            ...        ...       ...       ...    ...         ...
# 493 -8.660254e-01       -0.5 -0.696551 -0.717507  478.8     38293.0
# 494 -8.660254e-01       -0.5 -0.696551 -0.717507  796.5     62064.0
# 495 -8.660254e-01       -0.5 -0.696551 -0.717507   19.3    317778.0
# 496 -8.660254e-01       -0.5 -0.696551 -0.717507  372.3     34391.0
# 497 -8.660254e-01       -0.5 -0.696551 -0.717507  155.6     72223.0
#
#      population_density  eq_distance      ndvi      ndmi      ndwi      ndbi  \
# 0                  86.8     46.44911  0.203561  0.003898 -0.207792 -0.003898
# 1                  28.0     46.48134  0.619276  0.251041 -0.511561 -0.251041
# 2                5319.1     46.65786  0.098917 -0.022971 -0.126924  0.022971
# 3                  22.3     47.42581  0.476810  0.181223 -0.427585 -0.181223
# 4                  24.5     46.91682  0.692618  0.339332 -0.580010 -0.339332
# ..                  ...          ...       ...       ...       ...       ...
# 493                86.8     46.44911  0.694571  0.353325 -0.589602 -0.353325
# 494                83.5     46.11415  0.626029  0.198500 -0.535367 -0.198500
# 495             16848.8     46.65970  0.192811 -0.006628 -0.214006  0.006628
# 496                98.0     46.54118  0.323303 -0.028801 -0.362826  0.028801
# 497               450.6     46.69351  0.383580  0.040619 -0.369631 -0.040619
#
#      ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  \
# 0     0.192471  -0.005826  -0.202880   0.005826  0.044951  0.038408  0.034214
# 1     0.621279   0.252002  -0.514743  -0.252002  0.051984  0.044962  0.040620
# 2     0.130002  -0.019382  -0.158113   0.019382  0.048773  0.022557  0.040199
# 3     0.475048   0.176300  -0.423468  -0.176300  0.061094  0.069950  0.033972
# 4     0.681440   0.327785  -0.573466  -0.327785  0.040490  0.045362  0.027481
# ..         ...        ...        ...        ...       ...       ...       ...
# 493   0.685882   0.343081  -0.584848  -0.343081  0.043877  0.051278  0.035686
# 494   0.616168   0.191642  -0.529950  -0.191642  0.075760  0.067731  0.054042
# 495   0.082588   0.015971  -0.068460  -0.015971  0.118560  0.130964  0.205887
# 496   0.318196  -0.038290  -0.363848   0.038290  0.050504  0.034735  0.033718
# 497   0.395833   0.053213  -0.381372  -0.053213  0.067984  0.058193  0.039231
#
#      ndbi_std        lst    lst_day  lst_night  lst_jan_day_mean  \
# 0    0.038408  29.272500  38.310000  20.235000          8.126419
# 1    0.044962  20.111818  23.310000  16.913636          5.156188
# 2    0.022557  29.500000  36.550000  22.450000          8.206667
# 3    0.069950  23.105000  28.415000  17.795000          5.506350
# 4    0.045362  21.703750  26.225000  17.182500          5.626176
# ..        ...        ...        ...        ...               ...
# 493  0.051278  25.332500  31.340000  19.325000          8.126419
# 494  0.067731  23.221429  30.087143  16.355714          3.678481
# 495  0.130964        NaN        NaN        NaN               NaN
# 496  0.034735  29.003333  38.143333  19.863333         10.509905
# 497  0.058193  27.405000  34.790000  20.020000          6.053960
#
#      lst_jan_night_mean  lst_feb_day_mean  lst_feb_night_mean  \
# 0             -1.340303         16.216012            1.011667
# 1             -0.429920          9.002046            1.203846
# 2              1.223333         14.106000            3.702000
# 3             -0.849211         10.168715            1.184231
# 4              0.027273          8.827055            1.857362
# ..                  ...               ...                 ...
# 493           -1.340303         16.216012            1.011667
# 494            0.405016          6.749489            2.093469
# 495                 NaN               NaN                 NaN
# 496            0.591280         14.209359            2.818828
# 497           -0.244618         11.039295            2.596474
#
#      lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  \
# 0           18.020179            1.565813         32.641755
# 1            8.268402            0.655058         20.890796
# 2           17.271538            2.883846         26.801250
# 3           13.528745            0.333718         22.552471
# 4           12.089767            0.979534         20.756913
# ..                ...                 ...               ...
# 493         18.020179            1.565813         32.641755
# 494          6.703573           -0.614043         20.082834
# 495               NaN                 NaN               NaN
# 496         16.059402            1.388444         25.020417
# 497         13.741231            1.628667         22.957647
#
#      lst_apr_night_mean  acc_rainfall_1week  acc_rainfall_2week  \
# 0              8.896456            7.430859           60.492267
# 1              6.749332           32.516852           41.760239
# 2              9.896667            2.566023           60.273106
# 3              8.162000          135.776673          137.128588
# 4              8.392523            7.843521            9.150648
# ..                  ...                 ...                 ...
# 493            8.896456           33.114033           35.279590
# 494            7.265003           39.399950           40.288825
# 495                 NaN           10.839940           19.326230
# 496            8.645154           33.442790           34.047510
# 497            9.294667           28.918219           32.245201
#
#      acc_rainfall_jan  distance_to_coast  distance_to_river  slope_mean_1km  \
# 0          339.782435       21798.191901         561.876983               3
# 1          468.251021       21799.947368         819.637594              34
# 2          469.045192        1013.723139        1259.926671               2
# 3          490.154914       16270.860936          21.768793              12
# 4          585.233898       11468.297401        1749.385768              22
# ..                ...                ...                ...             ...
# 493        701.852196       21798.191901         561.876983               3
# 494        783.684469        8361.853508        1056.980614               8
# 495        849.966242         239.472007        2110.018302               8
# 496        972.080135        7667.944000         619.758246               4
# 497        855.411301        6252.575607        2993.526388              10
#
#      aspect_mean_200m  elevation_mean_1km  hillshade_mean_1km  fs_area_1km  \
# 0          148.634810            2.247180          180.067365     0.000000
# 1           54.056037          965.390539          175.271364     0.000000
# 2          166.963790            4.655965          180.457193     0.000000
# 3          152.028440          529.676707          197.614059     0.000000
# 4          273.587292          768.043224          181.562024     0.000000
# ..                ...                 ...                 ...          ...
# 493        148.634810            2.247180          180.067365     0.000000
# 494        126.512756          590.387395          156.610698     0.000000
# 495        175.716890           17.195550          184.189975     0.828767
# 496        200.754118           84.513525          180.292620     0.000000
# 497        174.615055          508.500208          183.388120     0.000000
#
#      flow_accu_200m  lc_prop1  lc_prop1_assessment  lc_prop2  \
# 0          5.738407        31                   99        36
# 1          1.000000        14                   99        10
# 2         24.343007        32                   97         9
# 3        116.778232        22                   79        20
# 4          1.033661        14                   99        10
# ..              ...       ...                  ...       ...
# 493        5.738407        31                   99        36
# 494        1.926913        15                   86        10
# 495       28.165350        32                   96         9
# 496        1.588520        31                   96        36
# 497        3.748108        31                   86         9
#
#      lc_prop2_assessment  lc_prop3  lc_prop3_assessment  lc_type1  lc_type2  \
# 0                   99.0        30                   99        12        12
# 1                   99.0        10                   99         4         4
# 2                   99.0        30                   97        13        13
# 3                   79.0        20                   79         9         9
# 4                   99.0        10                   99         4         4
# ..                   ...       ...                  ...       ...       ...
# 493                 99.0        30                   99        12        12
# 494                 90.0        10                   90         5         5
# 495                 97.0        30                   96        13        13
# 496                 94.0        30                   96        12        12
# 497                  NaN        30                   86        13        13
#
#      lc_type3  lc_type4  lc_type5  lw  qc  mosq_pred  mosq_previous  case
# 0           1         6         7   2   0         26             52     0
# 1           6         4         4   2   0          1              2     0
# 2          10         8         9   2   0         26             52     0
# 3           4         1         1   2   0         26             52     0
# 4           6         4         4   2   0          1              2     0
# ..        ...       ...       ...  ..  ..        ...            ...   ...
# 493         1         6         7   2   0         26             52     1
# 494         6         4         4   2   0         14             28     1
# 495        10         8         9   2   0          1              2     1
# 496         3         5         8   2   0          1              2     1
# 497        10         8         9   2   9         26             52     1
#
# [498 rows x 69 columns]

# %%
dataset_train['lau1'].unique().shape
# Out:
# (38,)

# %%
dataset_test['lau1'].unique().shape
# Out:
# (38,)

# %%
dsc = dataframe_describe(dataset_train)
dsc.head(15)
# Out:
#     year non-case case total percentage
# 0   2010      367  250   617     10.70%
# 1   2011      432   31   463      8.03%
# 2   2012      437   20   457      7.92%
# 3   2013      439   21   460      7.98%
# 4   2014      456    0   456      7.91%
# 5   2015      456    0   456      7.91%
# 6   2016      456    0   456      7.91%
# 7   2017      456    0   456      7.91%
# 8   2018      387  117   504      8.74%
# 9   2019      420   53   473      8.20%
# 10  2020      399   93   492      8.53%
# 11  2021      431   47   478      8.29%

# %%
dsc = dataframe_describe(dataset_test)
dsc.head(15)
# Out:
#    year non-case case total percentage
# 0  2022      350  148   498    100.00%

# %%
plot_imbalance(dataset_train)

# %%
plot_imbalance(dataset_test)

# %%
coefficients = []
results_train = pd.DataFrame()
results_test = pd.DataFrame()
feature_names = dataset_train.select_dtypes(exclude=['object']).drop(columns = ['case']).columns

# %%
data_train = dataset_train
data_test = dataset_test
    
data_train.reset_index(inplace = True, drop = True)
data_test.reset_index(inplace = True, drop = True)
    
X_train = data_train.select_dtypes(exclude=['object']).drop(columns = ['case'])
y_train = data_train['case']
X_test = data_test.select_dtypes(exclude=['object']).drop(columns = ['case'])
y_test = data_test['case']
    
X_train, X_test, y_train, y_test, X_train_df = transform_data(X_train, X_test, y_train, y_test, r_u, near_u, smote, scaler_key=scaler)
    
w0,w1 = calculate_weights(y_train)

model = LogisticRegression(max_iter = 1000, class_weight = {0.0: w0, 1.0:w1}, n_jobs = -1, random_state = 0)
    
train, test, coef = train_and_predict(model, X_train_df, data_test, X_train, y_train, X_test, y_test)
    
results_train = results_train.append(train, ignore_index = True)
results_test = results_test.append(test, ignore_index = True)
coefficients.append(coef)
    
print(f"Year: {test['year'].iloc[0]} || w0:{w0}, w1:{w1} || ##")
# Out:
# Year: 2022 || w0:1, w1:4 || ##

# %%
#plot_feature_importance(coefficients, feature_names, top = 15, figure_size = (8, 4))

# %%
#plot_trend_curve(results_test, list(dsc['case']))

# %%
plot_probability_curve(results_test)

# %%
plot_roc_curve(results_test)

# %%
plot_pr_curve(results_test, plot_fbeta=True)

# %%
operational, cumulative, avg, weighted = evaluate_operational(results_test, k = 20, prob_threshold = -1)
print(f'Average: {avg*100:.2f}%\nWeighted Average: {weighted*100:.2f}%')
# Out:
# Average: 67.33%
# Weighted Average: 67.33%

# %%
operational
# Out:
#    Prediction Date  Infected  Discovered  Out of Percentage  percentage
# 0       01/06/2022         0           0       0        NaN         NaN
# 1       16/06/2022         0           0       0        NaN         NaN
# 2       01/07/2022         1           0       1     0.00 %      0.0000
# 3       16/07/2022         8           5       8    62.50 %      0.6250
# 4       01/08/2022        16           7      16    43.75 %      0.4375
# 5       16/08/2022        40          17      20    85.00 %      0.8500
# 6       01/09/2022        38          17      20    85.00 %      0.8500
# 7       16/09/2022        29          15      20    75.00 %      0.7500
# 8       01/10/2022        13           5      13    38.46 %      0.3846
# 9       16/10/2022         2           2       2   100.00 %      1.0000
# 10      01/11/2022         0           0       0        NaN         NaN
# 11      16/11/2022         1           0       1     0.00 %      0.0000

# %%
cumulative
# Out:
#    Year  Infected  Discovered  Out Of Percentage  percentage
# 0  2022       148          68     101    67.33 %      0.6733

# %%
#report_train, report_test = classification_report(results_train, results_test, threshold = 0.1, beta = 4)

# %%
#report_test.head(15)

# %%
#plot_feature_importance(coefficients, feature_names,  x_label = 'Model Weights', top = 15, figure_size = (8, 5))

# %%
results_test
# Out:
#             x         y  municipality  day  month  year  case  probability
# 0    22.15177  40.44520       βεροιας    1      8  2022     1     0.976670
# 1    22.15177  40.44520       βεροιας    1      8  2022     1     0.976670
# 2    22.33660  40.28529     κατερινης    1      8  2022     0     0.973615
# 3    22.14670  40.82294       σκυδρας    1      8  2022     0     0.973188
# 4    22.95369  40.62334  θεσσαλονικης   16      8  2022     1     0.972422
# ..        ...       ...           ...  ...    ...   ...   ...          ...
# 493  23.98253  40.91510     αμφιπολης   16     11  2022     0     0.000148
# 494  23.38609  40.07252    κασσανδρας   16     11  2022     0     0.000139
# 495  23.69108  40.49593    αριστοτελη   16     11  2022     0     0.000139
# 496  22.47713  40.13156  διου ολυμπου   16     11  2022     0     0.000061
# 497  23.82811  40.11026      σιθωνιας   16     11  2022     0     0.000043
#
# [498 rows x 8 columns]
