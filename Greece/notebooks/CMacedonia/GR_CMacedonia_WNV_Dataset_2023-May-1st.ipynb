# %% [markdown]
# ## Merges all the availble information into a **Final Dataset** to be used for modeling ##

# %%
import pandas as pd
import datetime
import math
import numpy as np
import missingno
import json
from statistics import mean
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
import sys

sys.path.insert(0, "../../../Modules")

from preprocessing_utils import *


enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 10
# Out:
# c:\Users\dimit\AppData\Local\Programs\Python\Python39\lib\site-packages\geopandas\_compat.py:112: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
NUTS0 = 'GR'
NUTS2 = 'CMacedonia'
NUTS2_EL = 'κεντρικης μακεδονιας'

# %%
timeline_file = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Timeline_2023-May-1st_filled.csv', encoding=enc)
#wnv_file = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Timeline_2022.csv', encoding=enc)

# %%
timeline_file.head()
# Out:
#            lau1                region         x         y dt_placement  year  \
# 0  αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2023-05-01  2023
# 1  αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2023-05-01  2023
# 2  αλεξανδρειας  κεντρικης μακεδονιας  22.48988  40.62222   2023-05-01  2023
# 3  αλεξανδρειας  κεντρικης μακεδονιας  22.58432  40.62222   2023-05-01  2023
# 4      αλμωπιας  κεντρικης μακεδονιας  22.06171  40.94926   2023-05-01  2023
#
#    month indices_image_date  indices_lat  indices_lon  ndvi_new  ndmi_new  \
# 0      5         2023-04-30    40.659996    22.397246  0.189948 -0.054951
# 1      5         2023-04-30    40.677962    22.464619  0.110222 -0.165351
# 2      5         2023-04-30    40.624063    22.491569  0.253299 -0.038819
# 3      5         2023-04-30    40.624063    22.585892  0.127131 -0.143169
# 4      5         2023-04-30    40.947456    22.060378  0.533898  0.172414
#
#    ndwi_new  ndbi_new  ndvi_mean_new  ndmi_mean_new  ndwi_mean_new  \
# 0 -0.195018  0.054951       0.203597      -0.056477      -0.208414
# 1 -0.172650  0.165351       0.163025      -0.120348      -0.203631
# 2 -0.281858  0.038819       0.217262      -0.067217      -0.254128
# 3 -0.200613  0.143169       0.139141      -0.115394      -0.199779
# 4 -0.460370 -0.172414       0.591643       0.225081      -0.504579
#
#    ndbi_mean_new  ndvi_std_new  ndmi_std_new  ndwi_std_new  ndbi_std_new  \
# 0       0.056477      0.090037      0.067204      0.074951      0.067204
# 1       0.120348      0.060902      0.038216      0.052802      0.038216
# 2       0.067217      0.043139      0.036751      0.030546      0.036751
# 3       0.115394      0.032065      0.022881      0.030471      0.022881
# 4      -0.225081      0.030718      0.025556      0.022824      0.025556
#
#   lst_image_date    lst_lat    lst_lon  lst_day_new  lst_night_new  \
# 0     2023-05-01  40.659996  22.397246      15255.0        14332.0
# 1     2023-05-01  40.677962  22.464619      15351.0        14260.0
# 2     2023-05-01  40.624063  22.491569      15195.0        14244.0
# 3     2023-05-01  40.624063  22.585892      15265.0        14215.0
# 4     2023-05-01  40.947456  22.060378      14754.0        14171.0
#
#    monthly_lst_lat  monthly_lst_lon  lst_jan_day_mean_new  \
# 0        40.659996        22.397246          14284.083333
# 1        40.677962        22.464619          14206.000000
# 2        40.624063        22.491569          14209.272727
# 3        40.624063        22.585892          14237.400000
# 4        40.947456        22.060378          14194.545455
#
#    lst_jan_night_mean_new  lst_feb_day_mean_new  lst_feb_night_mean_new  \
# 0            13749.166667          14328.421053            13656.411765
# 1            13746.000000          14233.200000            13688.333333
# 2            13756.307692          14227.071429            13700.500000
# 3            13747.285714          14266.846154            13678.000000
# 4            13704.333333          14252.187500            13625.400000
#
#    lst_mar_day_mean_new  lst_mar_night_mean_new  lst_apr_day_mean_new  \
# 0          14754.941176            13922.545455          15018.466667
# 1          14793.333333            13936.333333          14919.181818
# 2          14700.312500            13925.571429          14910.545455
# 3          14819.857143            13907.357143          14836.600000
# 4          14610.384615            13888.777778          14649.111111
#
#    lst_apr_night_mean_new indices_image_date.1  indices_lat.1  indices_lon.1  \
# 0            14063.166667           2023-05-01      40.650186      22.350102
# 1            14048.272727           2023-05-01      40.650186      22.450103
# 2            14055.000000           2023-05-01      40.650186      22.450103
# 3            14043.111111           2023-05-01      40.650186      22.550103
# 4            14073.500000           2023-05-01      40.950187      22.050101
#
#    acc_rainfall_jan_new dt_placement_minus_7 dt_placement_minus_14  \
# 0             49.232035           2023-04-24            2023-04-17
# 1             56.700632           2023-04-24            2023-04-17
# 2             56.700632           2023-04-24            2023-04-17
# 3             56.552685           2023-04-24            2023-04-17
# 4            122.900567           2023-04-24            2023-04-17
#
#   dt_placement_minus_7_avail dt_placement_minus_14_avail  \
# 0                 2023-04-24                  2023-04-17
# 1                 2023-04-24                  2023-04-17
# 2                 2023-04-24                  2023-04-17
# 3                 2023-04-24                  2023-04-17
# 4                 2023-04-24                  2023-04-17
#
#    acc_rainfall_1week_new  acc_rainfall_2week_new
# 0                0.494345                5.837251
# 1                0.504019                3.901367
# 2                0.504019                3.901367
# 3                2.602183                4.216068
# 4                1.398249                7.034094

# %%
#wnv_file.head()

# %%
timeline_file.rename(columns={"region": "nuts2"}, inplace=True)

# %%
timeline_file = timeline_file.rename(columns=lambda x: re.sub('_new', '', x))

# %%
timeline_file.drop(columns=['indices_image_date', 'indices_lat', 'indices_lon' , 'lst_image_date', 'lst_lat','lst_lon' ,'monthly_lst_lat', 'monthly_lst_lon', 
                         'indices_image_date.1', 'indices_lat.1', 'indices_lon.1', 'dt_placement_minus_7', 'dt_placement_minus_14', 'dt_placement_minus_7_avail',
                         'dt_placement_minus_14_avail'], inplace = True)

# %%
timeline_file.head(5)
# Out:
#            lau1                 nuts2         x         y dt_placement  year  \
# 0  αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2023-05-01  2023
# 1  αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2023-05-01  2023
# 2  αλεξανδρειας  κεντρικης μακεδονιας  22.48988  40.62222   2023-05-01  2023
# 3  αλεξανδρειας  κεντρικης μακεδονιας  22.58432  40.62222   2023-05-01  2023
# 4      αλμωπιας  κεντρικης μακεδονιας  22.06171  40.94926   2023-05-01  2023
#
#    month      ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  \
# 0      5  0.189948 -0.054951 -0.195018  0.054951   0.203597  -0.056477
# 1      5  0.110222 -0.165351 -0.172650  0.165351   0.163025  -0.120348
# 2      5  0.253299 -0.038819 -0.281858  0.038819   0.217262  -0.067217
# 3      5  0.127131 -0.143169 -0.200613  0.143169   0.139141  -0.115394
# 4      5  0.533898  0.172414 -0.460370 -0.172414   0.591643   0.225081
#
#    ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  \
# 0  -0.208414   0.056477  0.090037  0.067204  0.074951  0.067204  15255.0
# 1  -0.203631   0.120348  0.060902  0.038216  0.052802  0.038216  15351.0
# 2  -0.254128   0.067217  0.043139  0.036751  0.030546  0.036751  15195.0
# 3  -0.199779   0.115394  0.032065  0.022881  0.030471  0.022881  15265.0
# 4  -0.504579  -0.225081  0.030718  0.025556  0.022824  0.025556  14754.0
#
#    lst_night  lst_jan_day_mean  lst_jan_night_mean  lst_feb_day_mean  \
# 0    14332.0      14284.083333        13749.166667      14328.421053
# 1    14260.0      14206.000000        13746.000000      14233.200000
# 2    14244.0      14209.272727        13756.307692      14227.071429
# 3    14215.0      14237.400000        13747.285714      14266.846154
# 4    14171.0      14194.545455        13704.333333      14252.187500
#
#    lst_feb_night_mean  lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  \
# 0        13656.411765      14754.941176        13922.545455      15018.466667
# 1        13688.333333      14793.333333        13936.333333      14919.181818
# 2        13700.500000      14700.312500        13925.571429      14910.545455
# 3        13678.000000      14819.857143        13907.357143      14836.600000
# 4        13625.400000      14610.384615        13888.777778      14649.111111
#
#    lst_apr_night_mean  acc_rainfall_jan  acc_rainfall_1week  \
# 0        14063.166667         49.232035            0.494345
# 1        14048.272727         56.700632            0.504019
# 2        14055.000000         56.700632            0.504019
# 3        14043.111111         56.552685            2.602183
# 4        14073.500000        122.900567            1.398249
#
#    acc_rainfall_2week
# 0            5.837251
# 1            3.901367
# 2            3.901367
# 3            4.216068
# 4            7.034094

# %%
#wnv_file.head(5)

# %%
# ## Find if there are lau1 units in the epidemiological file and are not contained in the spatiotemporal file.

# names_from_wnv_file = wnv_file["lau1"].drop_duplicates().sort_values().tolist()
# names_from_shapefile = timeline_file["lau1"].drop_duplicates().sort_values().tolist()
# diff = []

# for element in names_from_wnv_file:
#     if element not in names_from_shapefile:
#         diff.append(element)
        

# print(f"{diff}\n\nLength: {len(diff)}")

# %%
#wnv_file['lau1'] = wnv_file['lau1'].apply(lambda x : x.replace('ηρωικης πολεως ναουσας','ναουσας'))

# %%
# ## Check again

# names_from_wnv_file = wnv_file["lau1"].drop_duplicates().sort_values().tolist()
# names_from_shapefile = timeline_file["lau1"].drop_duplicates().sort_values().tolist()
# diff = []

# for element in names_from_wnv_file:
#     if element not in names_from_shapefile:
#         diff.append(element)
        

# print(f"{diff}\n\nLength: {len(diff)}")

# %%
# merged = timeline_file.merge(wnv_file, how='left', on=['dt_placement', 'lau1', 'nuts2'] )
merged = timeline_file

# %%
# merged

# %%
# merged = fillna(merged,{'case': 0})
merged['case'] = 0

# %%
merged['case'].value_counts()
# Out:
# 0    180
# Name: case, dtype: int64

# %%
grouped = merged.groupby(['dt_placement', 'lau1', 'nuts2'], as_index = False)

# %%
dataset = grouped.mean()

# %%
dataset
# Out:
#    dt_placement                   lau1                 nuts2          x  \
# 0    2023-05-01           αλεξανδρειας  κεντρικης μακεδονιας  22.483978
st_jan_night_mean  lst_feb_day_mean  lst_feb_night_mean  \
# 0         13749.690018      14263.884659        13680.811275
# 1         13785.095521      14049.086598        13664.427816
# 2         13837.333333      14251.000000        13783.769231
# 3         13814.041667      14088.281801        13681.627828
# 4         13812.444494      14125.501096        13755.012945
# ..                 ...               ...                 ...
# 33        13928.119167      14169.179722        13820.954622
# 34        13762.496392      14075.517520        13650.563882
# 35        13783.600000      14270.706478        13677.631250
# 36        13836.255556      14236.866300        13751.761905
# 37        13808.191667      14134.076923        13721.935714
#
#     lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  \
# 0       14767.111038        13922.951840      14921.198485
# 1       14324.249349        13852.660376      14396.198124
# 2       14595.538462        13913.571429      14852.400000
# 3       14417.454762        13891.251136      14631.001389
# 4       14425.097837        13869.602156      14508.115950
# ..               ...                 ...               ...
# 33      14426.578611        13938.588462      14594.725524
# 34      14416.621580        13838.663532      14529.864895
# 35      14585.793956        13929.577778      14705.887500
# 36      14546.523148        13945.631235      14648.490028
# 37      14482.508333        13900.631818      14589.181818
#
#     lst_apr_night_mean  acc_rainfall_jan  acc_rainfall_1week  \
# 0         14052.387626         54.796496            1.026141
# 1         13956.128788        172.360332            7.549537
# 2         14251.000000        129.586469            8.539829
# 3         13987.837500         73.469888           12.292893
# 4         14004.449082        161.783456           13.509865
# ..                 ...               ...                 ...
# 33        14073.681352        236.853557            4.614431
# 34        13943.706149         93.955123            1.329351
# 35        14133.433333         83.907471            0.088485
# 36        14101.385185         88.739159            7.164589
# 37        14064.000000        115.115193            3.496156
#
#     acc_rainfall_2week  case
# 0             4.464013   0.0
# 1            31.277387   0.0
# 2            24.316921   0.0
# 3            36.676132   0.0
# 4            88.392827   0.0
# ..                 ...   ...
# 33           66.477034   0.0
# 34           31.294012   0.0
# 35            2.320277   0.0
# 36           23.481618   0.0
# 37           33.069661   0.0
#
# [38 rows x 33 columns]

# %%
dataset = dataset.astype({'case': 'int'})

# %%
dataset['dt_placement'] = pd.to_datetime(dataset['dt_placement'])

# %%
dataset['x'] = dataset['x'].apply(lambda x : round(x,5))
dataset['y'] = dataset['y'].apply(lambda x : round(x,5))
dataset['day'] = dataset['dt_placement'].apply(lambda x : x.day)
dataset['month'] = dataset['dt_placement'].apply(lambda x : x.month)
dataset['year'] = dataset['dt_placement'].apply(lambda x : x.year)
dataset['week'] = dataset.apply(lambda row: datetime.date(int(row['year']), int(row['month']), int(row['day'])).isocalendar().week, axis=1)

# %%
lau1_map = lau1_mapping(dataset, 0, 0)

# %%
dataset = encode_cyclical(dataset, 'day', 31)
dataset = encode_cyclical(dataset, 'month', 12)
dataset = encode_cyclical(dataset, 'week', 53)

# %%
dataset
# Out:
#    dt_placement                   lau1                 nuts2         x  \
# 0    2023-05-01           αλεξανδρειας  κεντρικης μακεδονιας  22.48398
# 1    2023-05-01               αλμωπιας  κεντρικης μακεδονιας  21.94079
# 2    2023-05-01  αμπελοκηπων μενεμενης  κεντρικης μακεδονιας  22.89198
#     lst_feb_day_mean  lst_feb_night_mean  lst_mar_day_mean  \
# 0       14263.884659        13680.811275      14767.111038
# 1       14049.086598        13664.427816      14324.249349
# 2       14251.000000        13783.769231      14595.538462
# 3       14088.281801        13681.627828      14417.454762
# 4       14125.501096        13755.012945      14425.097837
# ..               ...                 ...               ...
# 33      14169.179722        13820.954622      14426.578611
# 34      14075.517520        13650.563882      14416.621580
# 35      14270.706478        13677.631250      14585.793956
# 36      14236.866300        13751.761905      14546.523148
# 37      14134.076923        13721.935714      14482.508333
#
#     lst_mar_night_mean  lst_apr_day_mean  lst_apr_night_mean  \
# 0         13922.951840      14921.198485        14052.387626
# 1         13852.660376      14396.198124        13956.128788
# 2         13913.571429      14852.400000        14251.000000
# 3         13891.251136      14631.001389        13987.837500
# 4         13869.602156      14508.115950        14004.449082
# ..                 ...               ...                 ...
# 33        13938.588462      14594.725524        14073.681352
# 34        13838.663532      14529.864895        13943.706149
# 35        13929.577778      14705.887500        14133.433333
# 36        13945.631235      14648.490028        14101.385185
# 37        13900.631818      14589.181818        14064.000000
#
#     acc_rainfall_jan  acc_rainfall_1week  acc_rainfall_2week  case  day  week  \
# 0          54.796496            1.026141            4.464013     0    1    18
# 1         172.360332            7.549537           31.277387     0    1    18
# 2         129.586469            8.539829           24.316921     0    1    18
# 3          73.469888           12.292893           36.676132     0    1    18
# 4         161.783456           13.509865           88.392827     0    1    18
# ..               ...                 ...                 ...   ...  ...   ...
# 33        236.853557            4.614431           66.477034     0    1    18
# 34         93.955123            1.329351           31.294012     0    1    18
# 35         83.907471            0.088485            2.320277     0    1    18
# 36         88.739159            7.164589           23.481618     0    1    18
# 37        115.115193            3.496156           33.069661     0    1    18
#
#     eq_distance   day_sin  day_cos  month_sin  month_cos  week_sin  week_cos
# 0      46.44911  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# 1      46.48134  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# 2      46.65786  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# 3      47.42581  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# 4      46.91682  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# ..          ...       ...      ...        ...        ...       ...       ...
# 33     46.65417  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# 34     47.47426  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# 35     46.44339  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# 36     46.66036  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# 37     46.78258  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
#
# [38 rows x 42 columns]

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
df_demographics = pd.read_csv(f'../../data/{NUTS0}_WEB_Demographics_Processed.csv', encoding = enc)

# %%
df_demographics
# Out:
#                  lau1                             nuts2                 nuts3  \
# 0             αβδηρων  ανατολικης μακεδονιας και θρακης                ξανθης
# 1         αγαθονησιου                    νοτιου αιγαιου              καλυμνου
# 2               αγιας                         θεσσαλιας               λαρισας
# 3      αγιας βαρβαρας                           αττικης  δυτικου τομεα αθηνων
# 4    αγιας παρασκευης                           αττικης  βορειου τομεα αθηνων
# ..                ...                               ...                   ...
# 327            χανιων                            κρητης                χανιων
# 328        χερσονησου                            κρητης             ηρακλειου
# 329              χιου                   βορειου αιγαιου                  χιου
# 330      ωραιοκαστρου              κεντρικης μακεδονιας          θεσσαλονικης
# 331            ωρωπου                           αττικης    ανατολικης αττικης
#
#       area  population_density  population
# 0    352.0                54.0     17860.0
# 1     14.5                12.8       203.0
# 2    661.8                17.3     10705.0
# 3      2.4             10925.9     26759.0
# 4      7.9              7557.5     62157.0
# ..     ...                 ...         ...
# 327  351.3               309.3    110646.0
# 328  272.2                98.2     27229.0
# 329  842.3                61.0     50483.0
# 330  217.9               175.8     40114.0
# 331  338.2                99.8     33977.0
#
# [332 rows x 6 columns]

# %%
df_demographics_nuts2 = df_demographics.query(f"nuts2 == '{NUTS2_EL}'").copy()

# %%
df_demographics_nuts2.drop(columns=['nuts2', 'nuts3'], inplace=True)
df_demographics_nuts2.reset_index(inplace=True, drop=True)

# %%
df_demographics_nuts2
# Out:
#                      lau1    area  population_density  population
# 0            αλεξανδρειας   478.8                86.8     38293.0
# 1                αλμωπιας   985.8                28.0     24924.0
# 2   αμπελοκηπων μενεμενης     9.8              5319.1     49674.0
# 3               αμφιπολης   411.8                22.3      7169.0
# 4              αριστοτελη   747.0                24.5     16994.0
# ..                    ...     ...                 ...         ...
# 33               σιθωνιας   516.8                24.0     11631.0
# 34               σιντικης  1103.4                20.1     18532.0
# 35                σκυδρας   239.5                84.3     18080.0
# 36             χαλκηδονος   391.5                86.0     29951.0
# 37           ωραιοκαστρου   217.9               175.8     40114.0
#
# [38 rows x 4 columns]

# %%
names_from_merged = dataset["lau1"].drop_duplicates().sort_values().tolist()
names_from_demographics = df_demographics_nuts2["lau1"].drop_duplicates().sort_values().tolist()
diff = []

for element in names_from_merged:
    if element not in names_from_demographics:
        diff.append(element)
        

print(f"{diff}\n\nLength: {len(diff)}")
# Out:
# ['ναουσας']
#
# Length: 1

# %%
df_demographics_nuts2['lau1'] = df_demographics_nuts2['lau1'].apply(lambda x : x.replace('ηρωικης πολεως ναουσας','ναουσας'))

# %%
names_from_merged = dataset["lau1"].drop_duplicates().sort_values().tolist()
names_from_demographics = df_demographics_nuts2["lau1"].drop_duplicates().sort_values().tolist()
diff = []

for element in names_from_merged:
    if element not in names_from_demographics:
        diff.append(element)
        

print(f"{diff}\n\nLength: {len(diff)}")
# Out:
# []
#
# Length: 0

# %%
dataset = pd.merge(dataset, df_demographics_nuts2,  how='left', on=['lau1'])

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
missing = describe_dataframe(dataset)

# %%
dataset
# Out:
#    dt_placement                   lau1                 nuts2         x  \
# 0    2023-05-01           αλεξανδρειας  κεντρικης μακεδονιας  22.48398
# 1    2023-05-01               αλμωπιας  κεντρικης μακεδονιας  21.94079
# 2    2023-05-01  αμπελοκηπων μενεμενης  κεντρικης μακεδονιας  22.89198
# 3    2023-05-01              αμφιπολης  κεντρικης μακεδονιας  23.98253
# 4    2023-05-01             αριστοτελη  κεντρικης μακεδονιας  23.69108
# ..          ...                    ...                   ...       ...
# 33   2023-05-01               σιθωνιας  κεντρικης μακεδονιας  23.82811
# 34   2023-05-01               σιντικης  κεντρικης μακεδονιας  23.38806
# 35   2023-05-01                σκυδρας  κεντρικης μακεδονιας  22.14670
# 36   2023-05-01             χαλκηδονος  κεντρικης μακεδονιας  22.72302
# 37   2023-05-01           ωραιοκαστρου  κεντρικης μακεδονιας  22.94073
#
#            y  year  month      ndvi      ndmi      ndwi      ndbi  ndvi_mean  \
# 0   40.64468  2023      5  0.170150 -0.100573 -0.212535  0.100573   0.180756
st_mar_night_mean  lst_apr_day_mean  lst_apr_night_mean  \
# 0         13922.951840      14921.198485        14052.387626
# 1         13852.660376      14396.198124        13956.128788
# 2         13913.571429      14852.400000        14251.000000
# 3         13891.251136      14631.001389        13987.837500
# 4         13869.602156      14508.115950        14004.449082
# ..                 ...               ...                 ...
# 33        13938.588462      14594.725524        14073.681352
# 34        13838.663532      14529.864895        13943.706149
# 35        13929.577778      14705.887500        14133.433333
# 36        13945.631235      14648.490028        14101.385185
# 37        13900.631818      14589.181818        14064.000000
#
#     acc_rainfall_jan  acc_rainfall_1week  acc_rainfall_2week  case  day  week  \
# 0          54.796496            1.026141            4.464013     0    1    18
# 1         172.360332            7.549537           31.277387     0    1    18
# 2         129.586469            8.539829           24.316921     0    1    18
# 3          73.469888           12.292893           36.676132     0    1    18
# 4         161.783456           13.509865           88.392827     0    1    18
# ..               ...                 ...                 ...   ...  ...   ...
# 33        236.853557            4.614431           66.477034     0    1    18
# 34         93.955123            1.329351           31.294012     0    1    18
# 35         83.907471            0.088485            2.320277     0    1    18
# 36         88.739159            7.164589           23.481618     0    1    18
# 37        115.115193            3.496156           33.069661     0    1    18
#
#     eq_distance   day_sin  day_cos  month_sin  month_cos  week_sin  week_cos  \
# 0      46.44911  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# 1      46.48134  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# 2      46.65786  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# 3      47.42581  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# 4      46.91682  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# ..          ...       ...      ...        ...        ...       ...       ...
# 33     46.65417  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# 34     47.47426  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# 35     46.44339  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# 36     46.66036  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
# 37     46.78258  0.201299  0.97953        0.5  -0.866025  0.845596 -0.533823
#
#       area  population_density  population
# 0    478.8                86.8     38293.0
# 1    985.8                28.0     24924.0
# 2      9.8              5319.1     49674.0
# 3    411.8                22.3      7169.0
# 4    747.0                24.5     16994.0
# ..     ...                 ...         ...
# 33   516.8                24.0     11631.0
# 34  1103.4                20.1     18532.0
# 35   239.5                84.3     18080.0
# 36   391.5                86.0     29951.0
# 37   217.9               175.8     40114.0
#
# [38 rows x 45 columns]

# %%
df_mosquitoes = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Culex_Predictions_2023-May-1st.csv', encoding = enc)
df_mosquitoes
# Out:
#             x          y dt_placement  mosq_pred
# 0   22.483978  40.644680   2023-05-01        202
# 1   21.940791  40.977027   2023-05-01         40
# 2   22.891980  40.656030   2023-05-01        161
# 3   23.982527  40.915103   2023-05-01        186
# 4   23.691080  40.495934   2023-05-01         54
# ..        ...        ...          ...        ...
# 33  23.828106  40.110264   2023-05-01         48
# 34  23.388058  41.313484   2023-05-01        115
# 35  22.146700  40.822940   2023-05-01         37
# 36  22.723020  40.753567   2023-05-01         55
# 37  22.940730  40.771710   2023-05-01         51
#
# [38 rows x 4 columns]

# %%
df_mosquitoes['dt_placement'] = pd.to_datetime(dataset['dt_placement'])
df_mosquitoes['x'] = df_mosquitoes['x'].apply(lambda x : round(x,5))
df_mosquitoes['y'] = df_mosquitoes['y'].apply(lambda x : round(x,5))

# %%
distances, indicies = calculate_nearest_topological(dataset, df_mosquitoes)

# %%
print(f'Min distance: {min(distances)}')
print(f'Max distance: {max(distances)}')
# Out:
# Min distance: 0.0
# Max distance: 0.0011119492658909769

# %%
df_mosq = pd.DataFrame(columns=df_mosquitoes.columns)

# %%
for index in indicies:
    df_mosq = df_mosq.append(df_mosquitoes.iloc[[index]])

df_mosq.drop(columns=['x', 'y', 'dt_placement'], inplace = True)
df_mosq.reset_index(drop=True, inplace=True)

# %%
dataset = pd.concat([dataset, df_mosq], axis=1, join = 'outer')

# %%
dataset.head()
# Out:
#   dt_placement                   lau1                 nuts2         x  \
# 0   2023-05-01           αλεξανδρειας  κεντρικης μακεδονιας  22.48398
# 1   2023-05-01               αλμωπιας  κεντρικης μακεδονιας  21.94079
# 2   2023-05-01  αμπελοκηπων μενεμενης  κεντρικης μακεδονιας  22.89198
# 3   2023-05-01              αμφιπολης  κεντρικης μακεδονιας  23.98253
# 4   2023-05-01             αριστοτελη  κεντρικης μακεδονιας  23.69108
#
#           y  year  month      ndvi      ndmi      ndwi      ndbi  ndvi_mean  \
# 0  40.64468  2023      5  0.170150 -0.100573 -0.212535  0.100573   0.180756
# 1  40.97703  2023      5  0.522353  0.123491 -0.447140 -0.123491   0.529450
# 2  40.65603  2023      5  0.157606  0.030411 -0.169270 -0.030411   0.198656
# 3  40.91510  2023      5  0.301201  0.177338 -0.259019 -0.177338   0.378091
# 4  40.49593  2023      5  0.626137  0.251029 -0.497413 -0.251029   0.615676
#
#    ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  \
# 0  -0.089859  -0.216488   0.089859  0.056536  0.041263  0.047193  0.041263
# 1   0.124210  -0.459599  -0.124210  0.054125  0.054755  0.030793  0.054755
# 2   0.031271  -0.205202  -0.031271  0.092685  0.059763  0.069722  0.059763
# 3   0.212700  -0.314783  -0.212700  0.060114  0.092679  0.062196  0.092679
# 4   0.248771  -0.488425  -0.248771  0.060201  0.055246  0.041223  0.055246
#
#         lst_day     lst_night  lst_jan_day_mean  lst_jan_night_mean  \
# 0  15266.500000  14262.750000      14234.189015        13749.690018
# 1  14510.727273  13972.181818      14057.777305        13785.095521
# 2  15051.000000  14251.000000      14276.571429        13837.333333
# 3  14701.250000  14108.500000      14168.974242        13814.041667
# 4  14574.250000  14108.125000      14191.401297        13812.444494
#
#    lst_feb_day_mean  lst_feb_night_mean  lst_mar_day_mean  lst_mar_night_mean  \
# 0      14263.884659        13680.811275      14767.111038        13922.951840
# 1      14049.086598        13664.427816      14324.249349        13852.660376
# 2      14251.000000        13783.769231      14595.538462        13913.571429
# 3      14088.281801        13681.627828      14417.454762        13891.251136
# 4      14125.501096        13755.012945      14425.097837        13869.602156
#
#    lst_apr_day_mean  lst_apr_night_mean  acc_rainfall_jan  acc_rainfall_1week  \
# 0      14921.198485        14052.387626         54.796496            1.026141
# 1      14396.198124        13956.128788        172.360332            7.549537
# 2      14852.400000        14251.000000        129.586469            8.539829
# 3      14631.001389        13987.837500         73.469888           12.292893
# 4      14508.115950        14004.449082        161.783456           13.509865
#
#    acc_rainfall_2week  case  day  week  eq_distance   day_sin  day_cos  \
# 0            4.464013     0    1    18     46.44911  0.201299  0.97953
# 1           31.277387     0    1    18     46.48134  0.201299  0.97953
# 2           24.316921     0    1    18     46.65786  0.201299  0.97953
# 3           36.676132     0    1    18     47.42581  0.201299  0.97953
# 4           88.392827     0    1    18     46.91682  0.201299  0.97953
#
#    month_sin  month_cos  week_sin  week_cos   area  population_density  \
# 0        0.5  -0.866025  0.845596 -0.533823  478.8                86.8
# 1        0.5  -0.866025  0.845596 -0.533823  985.8                28.0
# 2        0.5  -0.866025  0.845596 -0.533823    9.8              5319.1
# 3        0.5  -0.866025  0.845596 -0.533823  411.8                22.3
# 4        0.5  -0.866025  0.845596 -0.533823  747.0                24.5
#
#    population mosq_pred
# 0     38293.0       202
# 1     24924.0        40
# 2     49674.0       161
# 3      7169.0       186
# 4     16994.0        54

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
dataset.reset_index(inplace=True, drop=True)

# %%
dataset = calculate_mosq_previous(dataset)

# %%
dataset = convert_temperature(dataset)

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
dataset['case'].value_counts()
# Out:
# 0    38
# Name: case, dtype: int64

# %%
dataset = dataset.astype({'mosq_pred' : 'int', 'mosq_previous' : 'int'})

# %%
dataset = convert_multiple_cases(dataset)

# %%
dataset['case'].value_counts()
# Out:
# 0    38
# Name: case, dtype: int64

# %%
cols = dataset.columns

# %%
cols
# Out:
# Index(['dt_placement', 'lau1', 'nuts2', 'x', 'y', 'year', 'month', 'ndvi',
#        'ndmi', 'ndwi', 'ndbi', 'ndvi_mean', 'ndmi_mean', 'ndwi_mean',
#        'ndbi_mean', 'ndvi_std', 'ndmi_std', 'ndwi_std', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_day_mean', 'lst_jan_night_mean',
#        'lst_feb_day_mean', 'lst_feb_night_mean', 'lst_mar_day_mean',
#        'lst_mar_night_mean', 'lst_apr_day_mean', 'lst_apr_night_mean',
#        'acc_rainfall_jan', 'acc_rainfall_1week', 'acc_rainfall_2week', 'case',
#        'day', 'week', 'eq_distance', 'day_sin', 'day_cos', 'month_sin',
#        'month_cos', 'week_sin', 'week_cos', 'area', 'population_density',
#        'population', 'mosq_pred', 'mosq_previous', 'lst'],
#       dtype='object')

# %%
len(cols)
# Out:
# 48

# %%
# check columns

# %%
final_columns = ['x', 'y', 'dt_placement', 'nuts2', 'lau1', 'day', 
                 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 
                 'month_cos', 'week_sin', 'week_cos', 'area', 'population',
                 'population_density', 'eq_distance', 'ndvi', 'ndmi', 'ndwi', 'ndbi', 
                 'ndvi_mean', 'ndmi_mean', 'ndwi_mean', 'ndbi_mean', 
                 'ndvi_std', 'ndmi_std', 'ndwi_std', 'ndbi_std', 'lst',
                 'lst_day', 'lst_night','lst_jan_day_mean', 'lst_jan_night_mean', 
                 'lst_feb_day_mean','lst_feb_night_mean', 'lst_mar_day_mean', 
                 'lst_mar_night_mean', 'lst_apr_day_mean', 'lst_apr_night_mean',
                 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan',
                 'mosq_pred', 'mosq_previous', 'case']

# %%
len(final_columns)
# Out:
# 48

# %%
dataset_final = dataset[final_columns].copy()

# %%
dataset_final
# Out:
#            x         y dt_placement                 nuts2  \
# 0   22.48398  40.64468   2023-05-01  κεντρικης μακεδονιας
# 1   21.94079  40.97703   2023-05-01  κεντρικης μακεδονιας
# 2   22.89198  40.65603   2023-05-01  κεντρικης μακεδονιας
# 3   23.98253  40.91510   2023-05-01  κεντρικης μακεδονιας
# 4   23.69108  40.49593   2023-05-01  κεντρικης μακεδονιας
# ..       ...       ...          ...                   ...
# 33  23.82811  40.11026   2023-05-01  κεντρικης μακεδονιας
# 34  23.38806  41.31348   2023-05-01  κεντρικης μακεδονιας
# 35  22.14670  40.82294   2023-05-01  κεντρικης μακεδονιας
# 36  22.72302  40.75357   2023-05-01  κεντρικης μακεδονιας
# 37  22.94073  40.77171   2023-05-01  κεντρικης μακεδονιας
#
#                      lau1  day  month  week  year   day_sin  day_cos  \
# 0            αλεξανδρειας    1      5    18  2023  0.201299  0.97953
# 1                αλμωπιας    1      5    18  2023  0.201299  0.97953
# 2   αμπελοκηπων μενεμενης    1      5    18  2023  0.201299  0.97953
# 3               αμφιπολης    1      5    18  2023  0.201299  0.97953
# 4              αριστοτελη    1      5    18  2023  0.201299  0.97953
# ..                    ...  ...    ...   ...   ...       ...      ...
# 33               σιθωνιας    1      5    18  2023  0.201299  0.97953
# 34               σιντικης    1      5    18  2023  0.201299  0.97953
# 35                σκυδρας    1      5    18  2023  0.201299  0.97953
# 36             χαλκηδονος    1      5    18  2023  0.201299  0.97953
# 37           ωραιοκαστρου    1      5    18  2023  0.201299  0.97953
#
#     month_sin  month_cos  week_sin  week_cos    area  population  \
# 0         0.5  -0.866025  0.845596 -0.533823   478.8     38293.0
# 1         0.5  -0.866025  0.845596 -0.533823   985.8     24924.0
# 2         0.5  -0.866025  0.845596 -0.533823     9.8     49674.0
# 3         0.5  -0.866025  0.845596 -0.533823   411.8      7169.0
# 4         0.5  -0.866025  0.845596 -0.533823   747.0     16994.0
# ..        ...        ...       ...       ...     ...         ...
# 33        0.5  -0.866025  0.845596 -0.533823   516.8     11631.0
# 34        0.5  -0.866025  0.845596 -0.533823  1103.4     18532.0
# 35        0.5  -0.866025  0.845596 -0.533823   239.5     18080.0
# 36        0.5  -0.866025  0.845596 -0.533823   391.5     29951.0
# 37        0.5  -0.866025  0.845596 -0.533823   217.9     40114.0
#
#     population_density  eq_distance      ndvi      ndmi      ndwi      ndbi  \
# 0                 86.8     46.44911  0.170150 -0.100573 -0.212535  0.100573
# 1                 28.0     46.48134  0.522353  0.123491 -0.447140 -0.123491
# 2               5319.1     46.65786  0.157606  0.030411 -0.169270 -0.030411
# 3                 22.3     47.42581  0.301201  0.177338 -0.259019 -0.177338
# 4                 24.5     46.91682  0.626137  0.251029 -0.497413 -0.251029
# ..                 ...          ...       ...       ...       ...       ...
# 33                24.0     46.65417  0.531072  0.159175 -0.434785 -0.159175
# 34                20.1     47.47426  0.459837  0.137113 -0.378182 -0.137113
# 35                84.3     46.44339  0.628047  0.212817 -0.529299 -0.212817
# 36                86.0     46.66036  0.602195  0.296350 -0.516477 -0.296350
# 37               175.8     46.78258  0.594064  0.259297 -0.479018 -0.259297
#
#     ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  \
# 0    0.180756  -0.089859  -0.216488   0.089859  0.056536  0.041263  0.047193
# 1    0.529450   0.124210  -0.459599  -0.124210  0.054125  0.054755  0.030793
# 2    0.198656   0.031271  -0.205202  -0.031271  0.092685  0.059763  0.069722
# 3    0.378091   0.212700  -0.314783  -0.212700  0.060114  0.092679  0.062196
# 4    0.615676   0.248771  -0.488425  -0.248771  0.060201  0.055246  0.041223
# ..        ...        ...        ...        ...       ...       ...       ...
# 33   0.499631   0.147047  -0.416359  -0.147047  0.032837  0.042631  0.016784
# 34   0.461733   0.131896  -0.387717  -0.131896  0.062271  0.065290  0.054461
# 35   0.638043   0.233769  -0.531265  -0.233769  0.047432  0.038162  0.026900
# 36   0.518183   0.249549  -0.446706  -0.249549  0.108254  0.108705  0.088494
# 37   0.573795   0.234820  -0.476220  -0.234820  0.040529  0.046550  0.020014
#
#     ndbi_std        lst    lst_day  lst_night  lst_jan_day_mean  \
# 0   0.041263  22.142500  32.180000  12.105000         11.533780
# 1   0.054755  11.679091  17.064545   6.293636          8.005546
# 2   0.059763  19.870000  27.870000  11.870000         12.381429
# 3   0.092679  14.947500  20.875000   9.020000         10.229485
# 4   0.055246  13.673750  18.335000   9.012500         10.678026
# ..       ...        ...        ...        ...               ...
# 33  0.042631  15.936000  20.098000  11.774000         12.848600
# 34  0.065290  14.909091  21.364545   8.453636         10.684245
# 35  0.038162  15.765000  19.780000  11.750000         11.476154
# 36  0.108705  18.773333  26.290000  11.256667         11.998909
# 37  0.046550  16.180000  21.000000  11.360000         10.774167
#
#     lst_jan_night_mean  lst_feb_day_mean  lst_feb_night_mean  \
# 0             1.843800         12.127693            0.466225
# 1             2.551910          7.831732            0.138556
# 2             3.596667         11.870000            2.525385
# 3             3.130833          8.615636            0.482557
# 4             3.098890          9.360022            1.950259
# ..                 ...               ...                 ...
# 33            5.412383         10.233594            3.269092
# 34            2.099928          8.360350           -0.138722
# 35            2.522000         12.264130            0.402625
# 36            3.575111         11.587326            1.885238
# 37            3.013833          9.531538            1.288714
#
#     lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  \
# 0          22.192221            5.309037         25.273970
# 1          13.334987            3.903208         14.773962
# 2          18.760769            5.121429         23.898000
# 3          15.199095            4.675023         19.470028
# 4          15.351957            4.242043         17.012319
# ..               ...                 ...               ...
# 33         15.381572            5.621769         18.744510
# 34         15.182432            3.623271         17.447298
# 35         18.565879            5.441556         20.967750
# 36         17.780463            5.762625         19.819801
# 37         16.500167            4.862636         18.633636
#
#     lst_apr_night_mean  acc_rainfall_1week  acc_rainfall_2week  \
# 0             7.897753            1.026141            4.464013
# 1             5.972576            7.549537           31.277387
# 2            11.870000            8.539829           24.316921
# 3             6.606750           12.292893           36.676132
# 4             6.938982           13.509865           88.392827
# ..                 ...                 ...                 ...
# 33            8.323627            4.614431           66.477034
# 34            5.724123            1.329351           31.294012
# 35            9.518667            0.088485            2.320277
# 36            8.877704            7.164589           23.481618
# 37            8.130000            3.496156           33.069661
#
#     acc_rainfall_jan  mosq_pred  mosq_previous  case
# 0          54.796496        202              0     0
# 1         172.360332         40              0     0
# 2         129.586469        161              0     0
# 3          73.469888        186              0     0
# 4         161.783456         54              0     0
# ..               ...        ...            ...   ...
# 33        236.853557         48              0     0
# 34         93.955123        115              0     0
# 35         83.907471         37              0     0
# 36         88.739159         55              0     0
# 37        115.115193         51              0     0
#
# [38 rows x 48 columns]

# %%
dataset_final.to_csv(f"../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Dataset_2023-May-1st.csv", encoding = enc, index = False)
