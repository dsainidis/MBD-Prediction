# %%
import pandas as pd
import datetime
import math
import numpy as np
import missingno
import json
from statistics import mean
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
import sys

sys.path.insert(0, "../../../Mamoth Modules")
sys.path.insert(0, "../../../Modules")

from preprocessing_utils import *

from Preprocessing_Module import read_data, select_columns, reshape_dataset
from Initializer_Module import initializer
from Neural_Network_Module import Dataset, transformations, FeedforwardNeuralNetModel, train_nn, give_predictions
from Model_Validation_Module import validation_plots, metrics

enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 10
# Out:
# c:\Users\dimit\AppData\Local\Programs\Python\Python39\lib\site-packages\geopandas\_compat.py:112: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %%
NUTS0 = 'GR'
NUTS2 = 'CMacedonia'
NUTS2_EL = 'κεντρικης μακεδονιας'

# %%
dataset = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Timeline_Biweekly_2010-2021_filled.csv', encoding=enc)

# %%
dataset.head()
# Out:
#            lau1                region         x         y dt_placement  year  \
# 0  αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2010-01-01  2010
# 1  αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2010-01-16  2010
# 2  αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2010-01-01  2010
# 3  αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2010-01-16  2010
# 4  αλεξανδρειας  κεντρικης μακεδονιας  22.48988  40.62222   2010-01-01  2010
#
#    month indices_image_date  indices_lat  indices_lon  ndvi_new  ndmi_new  \
# 0      1         2009-12-07    40.659996    22.397246       NaN       NaN
# 1      1         2009-12-07    40.659996    22.397246       NaN       NaN
# 2      1         2009-12-07    40.677962    22.464619       NaN       NaN
# 3      1         2009-12-07    40.677962    22.464619       NaN       NaN
# 4      1         2009-12-07    40.624063    22.491569       NaN       NaN
#
#    ndwi_new  ndbi_new  ndvi_mean_new  ndmi_mean_new  ndwi_mean_new  \
# 0       NaN       NaN            NaN            NaN            NaN
# 1       NaN       NaN            NaN            NaN            NaN
# 2       NaN       NaN            NaN            NaN            NaN
# 3       NaN       NaN            NaN            NaN            NaN
# 4       NaN       NaN            NaN            NaN            NaN
#
#    ndbi_mean_new  ndvi_std_new  ndmi_std_new  ndwi_std_new  ndbi_std_new  \
# 0            NaN           NaN           NaN           NaN           NaN
# 1            NaN           NaN           NaN           NaN           NaN
# 2            NaN           NaN           NaN           NaN           NaN
# 3            NaN           NaN           NaN           NaN           NaN
# 4            NaN           NaN           NaN           NaN           NaN
#
#   lst_image_date    lst_lat    lst_lon  lst_day_new  lst_night_new  \
# 0     2010-01-01  40.659996  22.397246      14192.0        14017.0
# 1     2010-01-16  40.659996  22.397246      14129.0        13839.0
# 2     2010-01-01  40.677962  22.464619      14251.0        13995.0
# 3     2010-01-16  40.677962  22.464619      14188.0        13820.0
# 4     2010-01-01  40.624063  22.491569      14239.0        14024.0
#
#    monthly_lst_lat  monthly_lst_lon  lst_jan_day_mean_new  \
# 0        40.659996        22.397246          14034.000000
# 1        40.659996        22.397246          14034.000000
# 2        40.677962        22.464619          13991.166667
# 3        40.677962        22.464619          13991.166667
# 4        40.624063        22.491569          14020.000000
#
#    lst_jan_night_mean_new  lst_feb_day_mean_new  lst_feb_night_mean_new  \
# 0            13884.285714          14232.000000            13736.916667
# 1            13884.285714          14232.000000            13736.916667
# 2            13808.142857          14132.333333            13747.000000
# 3            13808.142857          14132.333333            13747.000000
# 4            13876.500000          14157.333333            13762.727273
#
#    lst_mar_day_mean_new  lst_mar_night_mean_new  lst_apr_day_mean_new  \
# 0          14665.866667            13888.352941          15154.230769
# 1          14665.866667            13888.352941          15154.230769
# 2          14621.000000            13863.266667          15156.538462
# 3          14621.000000            13863.266667          15156.538462
# 4          14546.416667            13868.470588          15075.142857
#
#    lst_apr_night_mean_new indices_image_date.1  indices_lat.1  indices_lon.1  \
# 0            14149.636364           2010-01-01      40.650186      22.350102
# 1            14149.636364           2010-01-16      40.650186      22.350102
# 2            14108.230769           2010-01-01      40.650186      22.450103
# 3            14108.230769           2010-01-16      40.650186      22.450103
# 4            14133.833333           2010-01-01      40.650186      22.450103
#
#    acc_rainfall_jan_new dt_placement_minus_7 dt_placement_minus_14  \
# 0              0.019869           2009-12-25            2009-12-18
# 1             21.994516           2010-01-09            2010-01-02
# 2              0.021185           2009-12-25            2009-12-18
# 3             19.148625           2010-01-09            2010-01-02
# 4              0.021185           2009-12-25            2009-12-18
#
#   dt_placement_minus_7_avail dt_placement_minus_14_avail  \
# 0                 2010-12-16                  2010-12-16
# 1                 2010-01-09                  2010-01-02
# 2                 2010-12-16                  2010-12-16
# 3                 2010-01-09                  2010-01-02
# 4                 2010-12-16                  2010-12-16
#
#    acc_rainfall_1week_new  acc_rainfall_2week_new
# 0                0.019869                0.019869
# 1                1.172702               21.024027
# 2                0.021185                0.021185
# 3                1.418397               18.804765
# 4                0.021185                0.021185

# %%
dataset.rename(columns={"region": "nuts2"}, inplace=True)

# %%
dataset = dataset.rename(columns=lambda x: re.sub('_new', '', x))

# %%
dataset.drop(columns=['indices_image_date', 'indices_lat', 'indices_lon' , 'lst_image_date', 'lst_lat','lst_lon' ,'monthly_lst_lat', 'monthly_lst_lon', 
                         'indices_image_date.1', 'indices_lat.1', 'indices_lon.1', 'dt_placement_minus_7', 'dt_placement_minus_14', 'dt_placement_minus_7_avail',
                         'dt_placement_minus_14_avail'], inplace = True)

# %%
dataset.head(5)
# Out:
#            lau1                 nuts2         x         y dt_placement  year  \
# 0  αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2010-01-01  2010
# 1  αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2010-01-16  2010
# 2  αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2010-01-01  2010
# 3  αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2010-01-16  2010
# 4  αλεξανδρειας  κεντρικης μακεδονιας  22.48988  40.62222   2010-01-01  2010
#
#    month  ndvi  ndmi  ndwi  ndbi  ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  \
# 0      1   NaN   NaN   NaN   NaN        NaN        NaN        NaN        NaN
# 1      1   NaN   NaN   NaN   NaN        NaN        NaN        NaN        NaN
# 2      1   NaN   NaN   NaN   NaN        NaN        NaN        NaN        NaN
# 3      1   NaN   NaN   NaN   NaN        NaN        NaN        NaN        NaN
# 4      1   NaN   NaN   NaN   NaN        NaN        NaN        NaN        NaN
#
#    ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  lst_night  \
# 0       NaN       NaN       NaN       NaN  14192.0    14017.0
# 1       NaN       NaN       NaN       NaN  14129.0    13839.0
# 2       NaN       NaN       NaN       NaN  14251.0    13995.0
# 3       NaN       NaN       NaN       NaN  14188.0    13820.0
# 4       NaN       NaN       NaN       NaN  14239.0    14024.0
#
#    lst_jan_day_mean  lst_jan_night_mean  lst_feb_day_mean  lst_feb_night_mean  \
# 0      14034.000000        13884.285714      14232.000000        13736.916667
# 1      14034.000000        13884.285714      14232.000000        13736.916667
# 2      13991.166667        13808.142857      14132.333333        13747.000000
# 3      13991.166667        13808.142857      14132.333333        13747.000000
# 4      14020.000000        13876.500000      14157.333333        13762.727273
#
#    lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  lst_apr_night_mean  \
# 0      14665.866667        13888.352941      15154.230769        14149.636364
# 1      14665.866667        13888.352941      15154.230769        14149.636364
# 2      14621.000000        13863.266667      15156.538462        14108.230769
# 3      14621.000000        13863.266667      15156.538462        14108.230769
# 4      14546.416667        13868.470588      15075.142857        14133.833333
#
#    acc_rainfall_jan  acc_rainfall_1week  acc_rainfall_2week
# 0          0.019869            0.019869            0.019869
# 1         21.994516            1.172702           21.024027
# 2          0.021185            0.021185            0.021185
# 3         19.148625            1.418397           18.804765
# 4          0.021185            0.021185            0.021185

# %%
grouped = dataset.groupby(['dt_placement', 'lau1', 'nuts2'], as_index = False)
dataset = grouped.mean()
dataset
# Out:
#       dt_placement                   lau1                 nuts2          x  \
# 0       2010-01-01           αλεξανδρειας  κεντρικης μακεδονιας  22.483978
# 1       2010-01-01               αλμωπιας  κεντρικης μακεδονιας  21.940791
# 2       2010-01-01  αμπελοκηπων μενεμενης  κεντρικης μακεδονιας  22.891980
# 3       2010-01-01              αμφιπολης  κεντρικης μακεδονιας  23.982527
# 4       2010-01-01             αριστοτελη  κεντρικης μακεδονιας  23.691080
# ...            ...                    ...                   ...        ...
# 10939   2021-12-16               σιθωνιας  κεντρικης μακεδονιας  23.828106
# 10940   2021-12-16               σιντικης  κεντρικης μακεδονιας  23.388058
# 10941   2021-12-16                σκυδρας  κεντρικης μακεδονιας  22.146700
# 10942   2021-12-16             χαλκηδονος  κεντρικης μακεδονιας  22.723020
# 10943   2021-12-16           ωραιοκαστρου  κεντρικης μακεδονιας  22.940730
#
#                y    year  month      ndvi      ndmi      ndwi      ndbi  \
# 0      40.644680  2010.0    1.0       NaN       NaN       NaN       NaN
# 1      40.977027  2010.0    1.0       NaN       NaN       NaN       NaN
# 2      40.656030  2010.0    1.0       NaN       NaN       NaN       NaN
# 3      40.915102  2010.0    1.0       NaN       NaN       NaN       NaN
# 4      40.495934  2010.0    1.0  0.036921  0.159004  0.193601 -0.159004
# ...          ...     ...    ...       ...       ...       ...       ...
# 10939  40.110264  2021.0   12.0  0.533019  0.216610 -0.406977 -0.216610
# 10940  41.313484  2021.0   12.0  0.126568 -0.005089 -0.091934  0.005089
# 10941  40.822940  2021.0   12.0  0.424823  0.260152 -0.272072 -0.260152
# 10942  40.753567  2021.0   12.0  0.255928 -0.052975 -0.231818  0.052975
# 10943  40.771710  2021.0   12.0  0.489202  0.143697 -0.379266 -0.143697
#
#        ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  \
# 0            NaN        NaN        NaN        NaN       NaN       NaN
# 1            NaN        NaN        NaN        NaN       NaN       NaN
# 2            NaN        NaN        NaN        NaN       NaN       NaN
# 3            NaN        NaN        NaN        NaN       NaN       NaN
# 4       0.036921   0.159004   0.193601  -0.159004  0.000000  0.000000
# ...          ...        ...        ...        ...       ...       ...
# 10939   0.525750   0.209897  -0.401147  -0.209897  0.039324  0.061157
# 10940   0.122184   0.074416  -0.090676  -0.074416  0.027041  0.050254
# 10941   0.423505   0.247285  -0.273696  -0.247285  0.023733  0.043566
# 10942   0.276006  -0.030417  -0.240922   0.030417  0.059156  0.056067
# 10943   0.391442   0.050392  -0.320558  -0.050392  0.089553  0.062114
#
#        ndwi_std  ndbi_std       lst_day  lst_night  lst_jan_day_mean  \
# 0           NaN       NaN  14254.250000   13999.75      14038.416667
# 1           NaN       NaN  14223.727273   13957.00      13869.513312
# 2           NaN       NaN  14331.000000   14102.00      14294.000000
# 3           NaN       NaN  14313.500000   14075.75      14060.466667
# 4      0.000000  0.000000  14419.500000   14040.25      14128.136995
# ...         ...       ...           ...        ...               ...
# 10939  0.034067  0.061157           NaN        NaN      14131.712105
# 10940  0.035247  0.050254           NaN        NaN      13895.539899
# 10941  0.046055  0.043566           NaN        NaN      14058.867424
# 10942  0.041252  0.056067           NaN        NaN      14117.840476
# 10943  0.058832  0.062114           NaN        NaN      13997.121212
#
#        lst_jan_night_mean  lst_feb_day_mean  lst_feb_night_mean  \
# 0            13841.023810      14155.566667        13756.638258
# 1            13744.208815      13867.496753        13711.131484
# 2            13933.000000      14150.166667        13838.100000
# 3            13849.123810      14119.082323        13755.281926
# 4            13903.784226      14068.485978        13793.050847
# ...                   ...               ...                 ...
# 10939        13798.223434      14309.703516        13947.082353
# 10940        13525.684019      14245.385339        13792.929034
# 10941        13572.800000      14466.912879        13843.509211
# 10942        13553.251852      14456.092308        13851.944444
# 10943        13640.071429      14316.700000        13877.980556
#
#        lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  \
# 0          14594.434470        13873.434314      15130.728022
# 1          14224.720029        13763.856185      14598.699282
# 2          14571.111111        13959.833333      14996.000000
# 3          14385.038636        13831.014839      14687.678342
# 4          14424.248689        13827.634516      14601.602841
# ...                 ...                 ...               ...
# 10939      14391.596265        13919.650000      14628.870760
# 10940      14454.229025        13724.788455      14684.146065
# 10941      14590.182353        13825.676471      14830.247917
# 10942      14692.609280        13852.974401      14831.047863
# 10943      14501.561538        13819.107143      14787.000000
#
#        lst_apr_night_mean  acc_rainfall_jan  acc_rainfall_1week  \
# 0            14121.996545          0.015560            0.015560
# 1            13988.568853          0.248551            0.248551
# 2            14245.000000          0.000000            0.000000
# 3            14072.125000          0.055994            0.055994
# 4            14032.383996          1.750566            1.750566
# ...                   ...               ...                 ...
# 10939        14012.311944       2180.544076           75.411011
# 10940        13885.721902       1562.784564          141.524710
# 10941        13975.117647        997.526490           56.599638
# 10942        14012.847619       1117.097203           59.682183
# 10943        13975.461538       1283.646776           62.627688
#
#        acc_rainfall_2week
# 0                0.015560
# 1                0.248551
# 2                0.000000
# 3                0.055994
# 4                1.750566
# ...                   ...
# 10939          161.899452
# 10940          215.682589
# 10941           67.029917
# 10942           90.624163
# 10943          122.578538
#
# [10944 rows x 32 columns]

# %%
dataset['dt_placement'] = pd.to_datetime(dataset['dt_placement'])

# %%
dataset['day'] = dataset['dt_placement'].apply(lambda x : x.day)
dataset['week'] = dataset.apply(lambda row: datetime.date(int(row['year']), int(row['month']), int(row['day'])).isocalendar().week, axis=1)

# %%
dataset = encode_cyclical(dataset, 'day', 31)
dataset = encode_cyclical(dataset, 'month', 12)
dataset = encode_cyclical(dataset, 'week', 53)

# %%
mosquito_data = read_data(f'../../data/{NUTS0}_MSQ_culex_2011-2022_processed.csv')
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
mosquito_data.nuts2.unique()
# Out:
# array(['CENTRAL MACEDONIA', 'THESSALY', 'CRETE', 'WESTERN GREECE'],
#       dtype=object)

# %%
mosquito_data_nuts2 = mosquito_data.query("nuts2 == 'CENTRAL MACEDONIA'").copy()
mosquito_data_nuts2.reset_index(inplace = True, drop = True)

# %%
mosq_columns = mosquito_data_nuts2.columns
mosq_columns
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
                'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
                'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
                'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
                'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
                'acc_rainfall_jan', 'mosq_now']

mosquito_data_nuts2 = select_columns(mosquito_data_nuts2, columns_to_keep, columns_to_keep)

mosquito_data_nuts2 = reshape_dataset(mosquito_data_nuts2,['x','y','dt_placement'])

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()
# Out:
# c:\Users\dimit\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#quantile might change based on sns plots
mosq_quantilie = mosquito_data_nuts2['mosq_now'].quantile(0.90)

mosquito_data_nuts2['mosq_now'][mosquito_data_nuts2['mosq_now'] > mosq_quantilie] = mosq_quantilie+1
# Out:
# C:\Users\dimit\AppData\Local\Temp/ipykernel_8980/187358562.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mosquito_data_nuts2['mosq_now'][mosquito_data_nuts2['mosq_now'] > mosq_quantilie] = mosq_quantilie+1

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()
# Out:
# c:\Users\dimit\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <AxesSubplot:>

# %%
imputer = KNNImputer()

features_for_impute = ['x', 'y', 'day', 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 
                        'lst_day', 'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean', 'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan']

mosquito_data_sub = mosquito_data_nuts2[features_for_impute]

imputed_data = pd.DataFrame(imputer.fit_transform(mosquito_data_sub), columns = mosquito_data_sub.columns)

# %%
imputed_columns = ['ndvi','ndmi', 'ndwi', 'ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std', 'ndmi_std','ndwi_std','ndbi_std',
                   'lst_day','lst_night','lst_jan_mean','lst_feb_mean','lst_mar_mean','lst_apr_mean']

mosquito_data_nuts2[imputed_columns] = imputed_data[imputed_columns]

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <AxesSubplot:>

# %%
step = 15
only_env = True
case_title = 'NN mosq regression'
exp = False
date_col = 'dt_placement'
model_type = 'mosquito_regression'
transform_target = True
augment = True

# %%
mosquito_data_nuts2 = initializer(mosquito_data_nuts2,2,10,25,step,[date_col], env=only_env, date_column = date_col, mosq_column='mosq_now')
# Out:
# Bounds: [  0.  85. 755.]
# c:\Users\dimit\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.25, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

model = FeedforwardNeuralNetModel(num_features=len(train_X[0]), num_class=1, hidden_layers = [264,128,128,64], dropout=0.2, model_type=model_type, transform = transform_target)

# %%
train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)
# Out:
# Epoch 001: | Train Loss: 20.23446 | Val Loss: 23.62586 | Train Acc: 2.763| Val Acc: 2.482
# Epoch 002: | Train Loss: 18.32360 | Val Loss: 25.25307 | Train Acc: 2.187| Val Acc: 2.092
# Epoch 003: | Train Loss: 18.51816 | Val Loss: 25.71894 | Train Acc: 2.255| Val Acc: 2.119
# Epoch 004: | Train Loss: 18.36262 | Val Loss: 25.09647 | Train Acc: 2.207| Val Acc: 2.053
# Epoch 005: | Train Loss: 18.15464 | Val Loss: 23.64172 | Train Acc: 2.158| Val Acc: 2.034
# Epoch 006: | Train Loss: 17.66086 | Val Loss: 23.85744 | Train Acc: 2.072| Val Acc: 1.975
# Epoch 007: | Train Loss: 17.64949 | Val Loss: 23.49626 | Train Acc: 2.086| Val Acc: 2.052
# Epoch 008: | Train Loss: 17.30246 | Val Loss: 23.49417 | Train Acc: 2.027| Val Acc: 2.014
# Epoch 009: | Train Loss: 17.15583 | Val Loss: 23.20933 | Train Acc: 2.012| Val Acc: 2.028
# Epoch 010: | Train Loss: 16.75365 | Val Loss: 23.84811 | Train Acc: 1.981| Val Acc: 2.038
# Epoch 011: | Train Loss: 16.91002 | Val Loss: 23.72694 | Train Acc: 2.000| Val Acc: 2.049
# Epoch 012: | Train Loss: 16.58676 | Val Loss: 23.95389 | Train Acc: 1.954| Val Acc: 2.046
# Epoch 013: | Train Loss: 16.41253 | Val Loss: 23.72307 | Train Acc: 1.951| Val Acc: 2.063
# Epoch 014: | Train Loss: 16.39016 | Val Loss: 23.78787 | Train Acc: 1.976| Val Acc: 2.132
# Epoch 015: | Train Loss: 16.25304 | Val Loss: 23.91165 | Train Acc: 1.956| Val Acc: 2.082
# Epoch 016: | Train Loss: 16.21099 | Val Loss: 24.04166 | Train Acc: 1.933| Val Acc: 2.024
# Epoch 017: | Train Loss: 16.00906 | Val Loss: 24.02652 | Train Acc: 1.935| Val Acc: 2.023
# Epoch 128: | Train Loss: 11.89768 | Val Loss: 24.77658 | Train Acc: 1.325| Val Acc: 1.956
# Epoch 129: | Train Loss: 11.90264 | Val Loss: 24.61124 | Train Acc: 1.331| Val Acc: 1.934
# Epoch 130: | Train Loss: 11.95165 | Val Loss: 24.80259 | Train Acc: 1.337| Val Acc: 1.937
# Epoch 131: | Train Loss: 12.03882 | Val Loss: 24.77136 | Train Acc: 1.349| Val Acc: 1.957
# Epoch 132: | Train Loss: 12.10816 | Val Loss: 24.60866 | Train Acc: 1.349| Val Acc: 1.966
# Epoch 133: | Train Loss: 11.97309 | Val Loss: 24.63633 | Train Acc: 1.342| Val Acc: 1.956
# Epoch 134: | Train Loss: 12.03351 | Val Loss: 24.77130 | Train Acc: 1.337| Val Acc: 1.925
# Epoch 135: | Train Loss: 11.88441 | Val Loss: 24.70089 | Train Acc: 1.324| Val Acc: 1.941
# Epoch 136: | Train Loss: 11.89011 | Val Loss: 24.09559 | Train Acc: 1.328| Val Acc: 1.905
# Epoch 137: | Train Loss: 11.88608 | Val Loss: 24.69175 | Train Acc: 1.320| Val Acc: 1.921
# Epoch 138: | Train Loss: 12.01686 | Val Loss: 24.34573 | Train Acc: 1.333| Val Acc: 1.919
# Epoch 139: | Train Loss: 11.95529 | Val Loss: 24.60845 | Train Acc: 1.335| Val Acc: 1.976
# Epoch 140: | Train Loss: 11.94873 | Val Loss: 24.61413 | Train Acc: 1.340| Val Acc: 1.938
# Epoch 141: | Train Loss: 11.95651 | Val Loss: 24.68838 | Train Acc: 1.323| Val Acc: 1.917
# Epoch 142: | Train Loss: 11.97478 | Val Loss: 24.23820 | Train Acc: 1.330| Val Acc: 1.957
# Epoch 143: | Train Loss: 11.93318 | Val Loss: 24.13999 | Train Acc: 1.338| Val Acc: 1.885
# Epoch 144: | Train Loss: 12.04656 | Val Loss: 24.27267 | Train Acc: 1.339| Val Acc: 1.919
# Epoch 145: | Train Loss: 12.02262 | Val Loss: 24.64590 | Train Acc: 1.350| Val Acc: 1.935
# Epoch 146: | Train Loss: 11.92468 | Val Loss: 24.67480 | Train Acc: 1.329| Val Acc: 1.947
# Epoch 147: | Train Loss: 11.93368 | Val Loss: 24.21740 | Train Acc: 1.316| Val Acc: 1.891
# Epoch 148: | Train Loss: 12.12239 | Val Loss: 24.79456 | Train Acc: 1.353| Val Acc: 1.987
# Epoch 149: | Train Loss: 12.07410 | Val Loss: 24.06141 | Train Acc: 1.367| Val Acc: 1.886
# Epoch 150: | Train Loss: 12.04220 | Val Loss: 25.20369 | Train Acc: 1.332| Val Acc: 2.003

# %%
metrics(train, test, threshold=30)
# Out:
# MAE on train set:  139.43201189435
# min prediction: 1
# max prediction: 1309
#
# MAE on test set:  166.1642902427648
# Error ⩽ 30: 17.85 %
# min prediction: 1
# max prediction: 1402

# %%
validation_plots(test,model_type)

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.000001, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

# Epoch 138: | Train Loss: 11.98456 | Val Loss: 2.19658 | Train Acc: 1.302| Val Acc: 1.633
# Epoch 139: | Train Loss: 12.03979 | Val Loss: 2.85839 | Train Acc: 1.296| Val Acc: 1.633
# Epoch 140: | Train Loss: 11.96204 | Val Loss: 2.46227 | Train Acc: 1.314| Val Acc: 1.633
# Epoch 141: | Train Loss: 12.01901 | Val Loss: 2.35316 | Train Acc: 1.318| Val Acc: 1.633
# Epoch 142: | Train Loss: 11.94450 | Val Loss: 3.40836 | Train Acc: 1.293| Val Acc: 1.633
# Epoch 143: | Train Loss: 11.94578 | Val Loss: 3.21887 | Train Acc: 1.290| Val Acc: 1.633
# Epoch 144: | Train Loss: 11.97187 | Val Loss: 3.69986 | Train Acc: 1.309| Val Acc: 1.633
# Epoch 145: | Train Loss: 11.96161 | Val Loss: 3.22842 | Train Acc: 1.311| Val Acc: 1.633
# Epoch 146: | Train Loss: 12.04505 | Val Loss: 4.93090 | Train Acc: 1.314| Val Acc: 2.633
# Epoch 147: | Train Loss: 11.91300 | Val Loss: 5.58727 | Train Acc: 1.293| Val Acc: 2.633
# Epoch 148: | Train Loss: 11.86332 | Val Loss: 4.93172 | Train Acc: 1.301| Val Acc: 2.633
# Epoch 149: | Train Loss: 11.96798 | Val Loss: 4.68796 | Train Acc: 1.305| Val Acc: 2.633
# Epoch 150: | Train Loss: 12.00321 | Val Loss: 4.07665 | Train Acc: 1.317| Val Acc: 1.633

# %%
dataset_mamoth = dataset_mamoth_preparation(dataset, columns_to_keep)

# %%
mosqutio_predictions = dataset_mamoth[['x', 'y', 'dt_placement']].copy()

# %%
dataset_mamoth.drop(columns=['dt_placement'], inplace=True)

# %%
dataset_mamoth_sub = dataset_mamoth[features_for_impute]

# %%
mamoth_imputed = pd.DataFrame(imputer.transform(dataset_mamoth_sub), columns = dataset_mamoth_sub.columns)

# %%
dataset_mamoth[features_for_impute] = mamoth_imputed[features_for_impute]

# %%
missingno.matrix(dataset_mamoth)
# Out:
# <AxesSubplot:>

# %%
dataset_mamoth_X, dataset_mamoth_y = dataset_mamoth.iloc[:,:-1], dataset_mamoth.iloc[:,-1]

dataset_mamoth_X = scaler.transform(dataset_mamoth_X)

# %%
dataset_mamoth = Dataset(dataset_mamoth_X, dataset_mamoth_y, model_type=model_type, transform = transform_target)

# %%
predictions = give_predictions(model, dataset_mamoth)

# %%
mosqutio_predictions['mosq_pred'] = predictions

# %%
mosqutio_predictions
# Out:
#                x          y dt_placement  mosq_pred
# 0      22.483978  40.644680   2010-01-01          5
# 1      21.940791  40.977027   2010-01-01          2
# 2      22.891980  40.656030   2010-01-01          7
# 3      23.982527  40.915102   2010-01-01          1
# 4      23.691080  40.495934   2010-01-01          4
# ...          ...        ...          ...        ...
# 10939  23.828106  40.110264   2021-12-16          2
# 10940  23.388058  41.313484   2021-12-16          1
# 10941  22.146700  40.822940   2021-12-16          1
# 10942  22.723020  40.753567   2021-12-16          1
# 10943  22.940730  40.771710   2021-12-16          1
#
# [10944 rows x 4 columns]

# %%
mosqutio_predictions.to_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Culex_Predictions_2010-2021.csv', index = False)
