# %% [markdown]
# ## Merges all the availble information into a **Final Dataset** to be used for modeling ##

# %%
import pandas as pd
import datetime
import math
import numpy as np
import missingno
import json
from statistics import mean
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
import sys

sys.path.insert(0, "../../../Modules")

from preprocessing_utils import *


enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 10
# Out:
# c:\Users\dimit\AppData\Local\Programs\Python\Python39\lib\site-packages\geopandas\_compat.py:112: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %%
NUTS0 = 'GR'
NUTS2 = 'CMacedonia'
NUTS2_EL = 'κεντρικης μακεδονιας'

# %%
timeline_file = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Timeline_Biweekly_2010-2021_filled.csv', encoding=enc)
wnv_file = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Cases_2010-2021.csv', encoding=enc)

# %%
timeline_file.head()
# Out:
#            lau1                region         x         y dt_placement  year  \
# 0  αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2010-01-01  2010
# 1  αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2010-01-16  2010
# 2  αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2010-01-01  2010
# 3  αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2010-01-16  2010
# 4  αλεξανδρειας  κεντρικης μακεδονιας  22.48988  40.62222   2010-01-01  2010
#
#    month indices_image_date  indices_lat  indices_lon  ndvi_new  ndmi_new  \
# 0      1         2009-12-07    40.659996    22.397246       NaN       NaN
# 1      1         2009-12-07    40.659996    22.397246       NaN       NaN
# 2      1         2009-12-07    40.677962    22.464619       NaN       NaN
# 3      1         2009-12-07    40.677962    22.464619       NaN       NaN
# 4      1         2009-12-07    40.624063    22.491569       NaN       NaN
#
#    ndwi_new  ndbi_new  ndvi_mean_new  ndmi_mean_new  ndwi_mean_new  \
# 0       NaN       NaN            NaN            NaN            NaN
# 1       NaN       NaN            NaN            NaN            NaN
# 2       NaN       NaN            NaN            NaN            NaN
# 3       NaN       NaN            NaN            NaN            NaN
# 4       NaN       NaN            NaN            NaN            NaN
#
#    ndbi_mean_new  ndvi_std_new  ndmi_std_new  ndwi_std_new  ndbi_std_new  \
# 0            NaN           NaN           NaN           NaN           NaN
# 1            NaN           NaN           NaN           NaN           NaN
# 2            NaN           NaN           NaN           NaN           NaN
# 3            NaN           NaN           NaN           NaN           NaN
# 4            NaN           NaN           NaN           NaN           NaN
#
#   lst_image_date    lst_lat    lst_lon  lst_day_new  lst_night_new  \
# 0     2010-01-01  40.659996  22.397246      14192.0        14017.0
# 1     2010-01-16  40.659996  22.397246      14129.0        13839.0
# 2     2010-01-01  40.677962  22.464619      14251.0        13995.0
# 3     2010-01-16  40.677962  22.464619      14188.0        13820.0
# 4     2010-01-01  40.624063  22.491569      14239.0        14024.0
#
#    monthly_lst_lat  monthly_lst_lon  lst_jan_day_mean_new  \
# 0        40.659996        22.397246          14034.000000
# 1        40.659996        22.397246          14034.000000
# 2        40.677962        22.464619          13991.166667
# 3        40.677962        22.464619          13991.166667
# 4        40.624063        22.491569          14020.000000
#
#    lst_jan_night_mean_new  lst_feb_day_mean_new  lst_feb_night_mean_new  \
# 0            13884.285714          14232.000000            13736.916667
# 1            13884.285714          14232.000000            13736.916667
# 2            13808.142857          14132.333333            13747.000000
# 3            13808.142857          14132.333333            13747.000000
# 4            13876.500000          14157.333333            13762.727273
#
#    lst_mar_day_mean_new  lst_mar_night_mean_new  lst_apr_day_mean_new  \
# 0          14665.866667            13888.352941          15154.230769
# 1          14665.866667            13888.352941          15154.230769
# 2          14621.000000            13863.266667          15156.538462
# 3          14621.000000            13863.266667          15156.538462
# 4          14546.416667            13868.470588          15075.142857
#
#    lst_apr_night_mean_new indices_image_date.1  indices_lat.1  indices_lon.1  \
# 0            14149.636364           2010-01-01      40.650186      22.350102
# 1            14149.636364           2010-01-16      40.650186      22.350102
# 2            14108.230769           2010-01-01      40.650186      22.450103
# 3            14108.230769           2010-01-16      40.650186      22.450103
# 4            14133.833333           2010-01-01      40.650186      22.450103
#
#    acc_rainfall_jan_new dt_placement_minus_7 dt_placement_minus_14  \
# 0              0.019869           2009-12-25            2009-12-18
# 1             21.994516           2010-01-09            2010-01-02
# 2              0.021185           2009-12-25            2009-12-18
# 3             19.148625           2010-01-09            2010-01-02
# 4              0.021185           2009-12-25            2009-12-18
#
#   dt_placement_minus_7_avail dt_placement_minus_14_avail  \
# 0                 2010-12-16                  2010-12-16
# 1                 2010-01-09                  2010-01-02
# 2                 2010-12-16                  2010-12-16
# 3                 2010-01-09                  2010-01-02
# 4                 2010-12-16                  2010-12-16
#
#    acc_rainfall_1week_new  acc_rainfall_2week_new
# 0                0.019869                0.019869
# 1                1.172702               21.024027
# 2                0.021185                0.021185
# 3                1.418397               18.804765
# 4                0.021185                0.021185

# %%
wnv_file.head()
# Out:
#            lau1                 nuts2 dt_placement  case
# 0  αλεξανδρειας  κεντρικης μακεδονιας   2010-06-01     0
# 1  αλεξανδρειας  κεντρικης μακεδονιας   2010-06-16     0
# 2  αλεξανδρειας  κεντρικης μακεδονιας   2010-07-01     0
# 3  αλεξανδρειας  κεντρικης μακεδονιας   2010-07-16     2
# 4  αλεξανδρειας  κεντρικης μακεδονιας   2010-08-01    11

# %%
timeline_file.rename(columns={"region": "nuts2"}, inplace=True)

# %%
timeline_file = timeline_file.rename(columns=lambda x: re.sub('_new', '', x))

# %%
timeline_file.drop(columns=['indices_image_date', 'indices_lat', 'indices_lon' , 'lst_image_date', 'lst_lat','lst_lon' ,'monthly_lst_lat', 'monthly_lst_lon', 
                         'indices_image_date.1', 'indices_lat.1', 'indices_lon.1', 'dt_placement_minus_7', 'dt_placement_minus_14', 'dt_placement_minus_7_avail',
                         'dt_placement_minus_14_avail'], inplace = True)

# %%
timeline_file.head(5)
# Out:
#            lau1                 nuts2         x         y dt_placement  year  \
# 0  αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2010-01-01  2010
# 1  αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2010-01-16  2010
# 2  αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2010-01-01  2010
# 3  αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2010-01-16  2010
# 4  αλεξανδρειας  κεντρικης μακεδονιας  22.48988  40.62222   2010-01-01  2010
#
#    month  ndvi  ndmi  ndwi  ndbi  ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  \
# 0      1   NaN   NaN   NaN   NaN        NaN        NaN        NaN        NaN
# 1      1   NaN   NaN   NaN   NaN        NaN        NaN        NaN        NaN
# 2      1   NaN   NaN   NaN   NaN        NaN        NaN        NaN        NaN
# 3      1   NaN   NaN   NaN   NaN        NaN        NaN        NaN        NaN
# 4      1   NaN   NaN   NaN   NaN        NaN        NaN        NaN        NaN
#
#    ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  lst_night  \
# 0       NaN       NaN       NaN       NaN  14192.0    14017.0
# 1       NaN       NaN       NaN       NaN  14129.0    13839.0
# 2       NaN       NaN       NaN       NaN  14251.0    13995.0
# 3       NaN       NaN       NaN       NaN  14188.0    13820.0
# 4       NaN       NaN       NaN       NaN  14239.0    14024.0
#
#    lst_jan_day_mean  lst_jan_night_mean  lst_feb_day_mean  lst_feb_night_mean  \
# 0      14034.000000        13884.285714      14232.000000        13736.916667
# 1      14034.000000        13884.285714      14232.000000        13736.916667
# 2      13991.166667        13808.142857      14132.333333        13747.000000
# 3      13991.166667        13808.142857      14132.333333        13747.000000
# 4      14020.000000        13876.500000      14157.333333        13762.727273
#
#    lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  lst_apr_night_mean  \
# 0      14665.866667        13888.352941      15154.230769        14149.636364
# 1      14665.866667        13888.352941      15154.230769        14149.636364
# 2      14621.000000        13863.266667      15156.538462        14108.230769
# 3      14621.000000        13863.266667      15156.538462        14108.230769
# 4      14546.416667        13868.470588      15075.142857        14133.833333
#
#    acc_rainfall_jan  acc_rainfall_1week  acc_rainfall_2week
# 0          0.019869            0.019869            0.019869
# 1         21.994516            1.172702           21.024027
# 2          0.021185            0.021185            0.021185
# 3         19.148625            1.418397           18.804765
# 4          0.021185            0.021185            0.021185

# %%
wnv_file.head(5)
# Out:
#            lau1                 nuts2 dt_placement  case
# 0  αλεξανδρειας  κεντρικης μακεδονιας   2010-06-01     0
# 1  αλεξανδρειας  κεντρικης μακεδονιας   2010-06-16     0
# 2  αλεξανδρειας  κεντρικης μακεδονιας   2010-07-01     0
# 3  αλεξανδρειας  κεντρικης μακεδονιας   2010-07-16     2
# 4  αλεξανδρειας  κεντρικης μακεδονιας   2010-08-01    11

# %%
## Find if there are lau1 units in the epidemiological file and are not contained in the spatiotemporal file.

names_from_wnv_file = wnv_file["lau1"].drop_duplicates().sort_values().tolist()
names_from_timeline = timeline_file["lau1"].drop_duplicates().sort_values().tolist()
diff = []

for element in names_from_wnv_file:
    if element not in names_from_timeline:
        diff.append(element)
        

print(f"{diff}\n\nLength: {len(diff)}")
# Out:
# ['ηρωικης πολης ναουσας']
#
# Length: 1

# %%
wnv_file['lau1'] = wnv_file['lau1'].apply(lambda x : x.replace('ηρωικης πολης ναουσας','ναουσας'))

# %%
## Check again

names_from_wnv_file = wnv_file["lau1"].drop_duplicates().sort_values().tolist()
names_from_timeline = timeline_file["lau1"].drop_duplicates().sort_values().tolist()
diff = []

for element in names_from_wnv_file:
    if element not in names_from_timeline:
        diff.append(element)
        

print(f"{diff}\n\nLength: {len(diff)}")
# Out:
# []
#
# Length: 0

# %%
merged = timeline_file.merge(wnv_file, how='left', on=['dt_placement', 'lau1', 'nuts2'] )

# %%
merged
# Out:
#                lau1                 nuts2         x         y dt_placement  \
# 0      αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2010-01-01
# 1      αλεξανδρειας  κεντρικης μακεδονιας  22.39544  40.65816   2010-01-16
# 2      αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2010-01-01
# 3      αλεξανδρειας  κεντρικης μακεδονιας  22.46627  40.67612   2010-01-16
# 4      αλεξανδρειας  κεντρικης μακεδονιας  22.48988  40.62222   2010-01-01
# ...             ...                   ...       ...       ...          ...
# 51835    χαλκηδονος  κεντρικης μακεδονιας  22.73880  40.73560   2021-12-16
# 51836  ωραιοκαστρου  κεντρικης μακεδονιας  22.94073  40.74476   2021-12-01
# 51837  ωραιοκαστρου  κεντρικης μακεδονιας  22.94073  40.74476   2021-12-16
# 51838  ωραιοκαστρου  κεντρικης μακεδονιας  22.94073  40.79866   2021-12-01
# 51839  ωραιοκαστρου  κεντρικης μακεδονιας  22.94073  40.79866   2021-12-16
#
#        year  month      ndvi      ndmi      ndwi      ndbi  ndvi_mean  \
# 0      2010      1       NaN       NaN       NaN       NaN        NaN
# 1      2010      1       NaN       NaN       NaN       NaN        NaN
# 2      2010      1       NaN       NaN       NaN       NaN        NaN
# 3      2010      1       NaN       NaN       NaN       NaN        NaN
# 4      2010      1       NaN       NaN       NaN       NaN        NaN
# ...     ...    ...       ...       ...       ...       ...        ...
# 51835  2021     12  0.251805 -0.073830 -0.213668  0.073830   0.285509
# 51836  2021     12  0.586417  0.234927 -0.449285 -0.234927   0.449600
# 51837  2021     12  0.586417  0.234927 -0.449285 -0.234927   0.449600
# 51838  2021     12  0.391987  0.052467 -0.309246 -0.052467   0.333284
# 51839  2021     12  0.391987  0.052467 -0.309246 -0.052467   0.333284
#
#        ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  \
# 0            NaN        NaN        NaN       NaN       NaN       NaN
# 1            NaN        NaN        NaN       NaN       NaN       NaN
# 2            NaN        NaN        NaN       NaN       NaN       NaN
# 3            NaN        NaN        NaN       NaN       NaN       NaN
# 4            NaN        NaN        NaN       NaN       NaN       NaN
# ...          ...        ...        ...       ...       ...       ...
# 51835  -0.033475  -0.240839   0.033475  0.049812  0.042605  0.035642
# 51836   0.105007  -0.355143  -0.105007  0.078153  0.070156  0.061729
# 51837   0.105007  -0.355143  -0.105007  0.078153  0.070156  0.061729
# 51838  -0.004223  -0.285973   0.004223  0.100953  0.054073  0.055935
# 51839  -0.004223  -0.285973   0.004223  0.100953  0.054073  0.055935
#
#        ndbi_std  lst_day  lst_night  lst_jan_day_mean  lst_jan_night_mean  \
# 0           NaN  14192.0    14017.0      14034.000000        13884.285714
# 1           NaN  14129.0    13839.0      14034.000000        13884.285714
# 2           NaN  14251.0    13995.0      13991.166667        13808.142857
# 3           NaN  14188.0    13820.0      13991.166667        13808.142857
# 4           NaN  14239.0    14024.0      14020.000000        13876.500000
# ...         ...      ...        ...               ...                 ...
# 51835  0.042605      NaN        NaN      14123.750000        13539.555556
# 51836  0.070156      NaN        NaN      14048.333333        13653.142857
# 51837  0.070156      NaN        NaN      14048.333333        13653.142857
# 51838  0.054073      NaN        NaN      13945.909091        13627.000000
# 51839  0.054073      NaN        NaN      13945.909091        13627.000000
#
#        lst_feb_day_mean  lst_feb_night_mean  lst_mar_day_mean  \
# 0          14232.000000        13736.916667      14665.866667
# 1          14232.000000        13736.916667      14665.866667
# 2          14132.333333        13747.000000      14621.000000
# 3          14132.333333        13747.000000      14621.000000
# 4          14157.333333        13762.727273      14546.416667
# ...                 ...                 ...               ...
# 51835      14496.076923        13847.111111      14702.923077
# 51836      14364.266667        13877.850000      14443.200000
# 51837      14364.266667        13877.850000      14443.200000
# 51838      14269.133333        13878.111111      14559.923077
# 51839      14269.133333        13878.111111      14559.923077
#
#        lst_mar_night_mean  lst_apr_day_mean  lst_apr_night_mean  \
# 0            13888.352941      15154.230769        14149.636364
# 1            13888.352941      15154.230769        14149.636364
# 2            13863.266667      15156.538462        14108.230769
# 3            13863.266667      15156.538462        14108.230769
# 4            13868.470588      15075.142857        14133.833333
# ...                   ...               ...                 ...
# 51835        13852.117647      14842.076923        14030.071429
# 51836        13843.214286      14749.466667        13954.000000
# 51837        13843.214286      14749.466667        13954.000000
# 51838        13795.000000      14824.533333        13996.923077
# 51839        13795.000000      14824.533333        13996.923077
#
#        acc_rainfall_jan  acc_rainfall_1week  acc_rainfall_2week  case
# 0              0.019869            0.019869            0.019869   NaN
# 1             21.994516            1.172702           21.024027   NaN
# 2              0.021185            0.021185            0.021185   NaN
# 3             19.148625            1.418397           18.804765   NaN
# 4              0.021185            0.021185            0.021185   NaN
# ...                 ...                 ...                 ...   ...
# 51835       1117.097203           59.682183           90.624163   NaN
# 51836       1161.068238           11.701603           42.697279   NaN
# 51837       1283.646776           62.627688          122.578538   NaN
# 51838       1161.068238           11.701603           42.697279   NaN
# 51839       1283.646776           62.627688          122.578538   NaN
#
# [51840 rows x 33 columns]

# %%
merged = fillna(merged,{'case': 0})

# %%
merged['case'].value_counts()
# Out:
# 0.0     50324
# 1.0       901
# 2.0       306
# 3.0       118
# 4.0        82
#         ...
# 8.0        10
# 18.0        5
# 12.0        5
# 9.0         5
# 11.0        4
# Name: case, Length: 13, dtype: int64

# %%
grouped = merged.groupby(['dt_placement', 'lau1', 'nuts2'], as_index = False)

# %%
dataset = grouped.mean()

# %%
dataset
# Out:
#       dt_placement                   lau1                 nuts2          x  \
# 0       2010-01-01           αλεξανδρειας  κεντρικης μακεδονιας  22.483978
# 1       2010-01-01               αλμωπιας  κεντρικης μακεδονιας  21.940791
# 2       2010-01-01  αμπελοκηπων μενεμενης  κεντρικης μακεδονιας  22.891980
# 3       2010-01-01              αμφιπολης  κεντρικης μακεδονιας  23.982527
# 4       2010-01-01             αριστοτελη  κεντρικης μακεδονιας  23.691080
# ...            ...                    ...                   ...        ...
# 10939   2021-12-16               σιθωνιας  κεντρικης μακεδονιας  23.828106
# 10940   2021-12-16               σιντικης  κεντρικης μακεδονιας  23.388058
# 10941   2021-12-16                σκυδρας  κεντρικης μακεδονιας  22.146700
# 10942   2021-12-16             χαλκηδονος  κεντρικης μακεδονιας  22.723020
# 10943   2021-12-16           ωραιοκαστρου  κεντρικης μακεδονιας  22.940730
#
#                y    year  month      ndvi      ndmi      ndwi      ndbi  \
# 0      40.644680  2010.0    1.0       NaN       NaN       NaN       NaN
# 1      40.977027  2010.0    1.0       NaN       NaN       NaN       NaN
# 2      40.656030  2010.0    1.0       NaN       NaN       NaN       NaN
# 3      40.915102  2010.0    1.0       NaN       NaN       NaN       NaN
# 4      40.495934  2010.0    1.0  0.036921  0.159004  0.193601 -0.159004
# ...          ...     ...    ...       ...       ...       ...       ...
# 10939  40.110264  2021.0   12.0  0.533019  0.216610 -0.406977 -0.216610
# 10940  41.313484  2021.0   12.0  0.126568 -0.005089 -0.091934  0.005089
# 10941  40.822940  2021.0   12.0  0.424823  0.260152 -0.272072 -0.260152
# 10942  40.753567  2021.0   12.0  0.255928 -0.052975 -0.231818  0.052975
# 10943  40.771710  2021.0   12.0  0.489202  0.143697 -0.379266 -0.143697
#
#        ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  \
# 0            NaN        NaN        NaN        NaN       NaN       NaN
# 1            NaN        NaN        NaN        NaN       NaN       NaN
# 2            NaN        NaN        NaN        NaN       NaN       NaN
# 3            NaN        NaN        NaN        NaN       NaN       NaN
# 4       0.036921   0.159004   0.193601  -0.159004  0.000000  0.000000
# ...          ...        ...        ...        ...       ...       ...
# 10939   0.525750   0.209897  -0.401147  -0.209897  0.039324  0.061157
# 10940   0.122184   0.074416  -0.090676  -0.074416  0.027041  0.050254
# 10941   0.423505   0.247285  -0.273696  -0.247285  0.023733  0.043566
# 10942   0.276006  -0.030417  -0.240922   0.030417  0.059156  0.056067
# 10943   0.391442   0.050392  -0.320558  -0.050392  0.089553  0.062114
#
#        ndwi_std  ndbi_std       lst_day  lst_night  lst_jan_day_mean  \
# 0           NaN       NaN  14254.250000   13999.75      14038.416667
# 1           NaN       NaN  14223.727273   13957.00      13869.513312
# 2           NaN       NaN  14331.000000   14102.00      14294.000000
# 3           NaN       NaN  14313.500000   14075.75      14060.466667
# 4      0.000000  0.000000  14419.500000   14040.25      14128.136995
# ...         ...       ...           ...        ...               ...
# 10939  0.034067  0.061157           NaN        NaN      14131.712105
# 10940  0.035247  0.050254           NaN        NaN      13895.539899
# 10941  0.046055  0.043566           NaN        NaN      14058.867424
# 10942  0.041252  0.056067           NaN        NaN      14117.840476
# 10943  0.058832  0.062114           NaN        NaN      13997.121212
#
#        lst_jan_night_mean  lst_feb_day_mean  lst_feb_night_mean  \
# 0            13841.023810      14155.566667        13756.638258
# 1            13744.208815      13867.496753        13711.131484
# 2            13933.000000      14150.166667        13838.100000
# 3            13849.123810      14119.082323        13755.281926
# 4            13903.784226      14068.485978        13793.050847
# ...                   ...               ...                 ...
# 10939        13798.223434      14309.703516        13947.082353
# 10940        13525.684019      14245.385339        13792.929034
# 10941        13572.800000      14466.912879        13843.509211
# 10942        13553.251852      14456.092308        13851.944444
# 10943        13640.071429      14316.700000        13877.980556
#
#        lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  \
# 0          14594.434470        13873.434314      15130.728022
# 1          14224.720029        13763.856185      14598.699282
# 2          14571.111111        13959.833333      14996.000000
# 3          14385.038636        13831.014839      14687.678342
# 4          14424.248689        13827.634516      14601.602841
# ...                 ...                 ...               ...
# 10939      14391.596265        13919.650000      14628.870760
# 10940      14454.229025        13724.788455      14684.146065
# 10941      14590.182353        13825.676471      14830.247917
# 10942      14692.609280        13852.974401      14831.047863
# 10943      14501.561538        13819.107143      14787.000000
#
#        lst_apr_night_mean  acc_rainfall_jan  acc_rainfall_1week  \
# 0            14121.996545          0.015560            0.015560
# 1            13988.568853          0.248551            0.248551
# 2            14245.000000          0.000000            0.000000
# 3            14072.125000          0.055994            0.055994
# 4            14032.383996          1.750566            1.750566
# ...                   ...               ...                 ...
# 10939        14012.311944       2180.544076           75.411011
# 10940        13885.721902       1562.784564          141.524710
# 10941        13975.117647        997.526490           56.599638
# 10942        14012.847619       1117.097203           59.682183
# 10943        13975.461538       1283.646776           62.627688
#
#        acc_rainfall_2week  case
# 0                0.015560   0.0
# 1                0.248551   0.0
# 2                0.000000   0.0
# 3                0.055994   0.0
# 4                1.750566   0.0
# ...                   ...   ...
# 10939          161.899452   0.0
# 10940          215.682589   0.0
# 10941           67.029917   0.0
# 10942           90.624163   0.0
# 10943          122.578538   0.0
#
# [10944 rows x 33 columns]

# %%
dataset = dataset.astype({'case': 'int'})

# %%
dataset['dt_placement'] = pd.to_datetime(dataset['dt_placement'])

# %%
dataset['x'] = dataset['x'].apply(lambda x : round(x,5))
dataset['y'] = dataset['y'].apply(lambda x : round(x,5))
dataset['day'] = dataset['dt_placement'].apply(lambda x : x.day)
dataset['month'] = dataset['dt_placement'].apply(lambda x : x.month)
dataset['year'] = dataset['dt_placement'].apply(lambda x : x.year)
dataset['week'] = dataset.apply(lambda row: datetime.date(int(row['year']), int(row['month']), int(row['day'])).isocalendar().week, axis=1)

# %%
lau1_map = lau1_mapping(dataset, 0, 0)

# %%
dataset = encode_cyclical(dataset, 'day', 31)
dataset = encode_cyclical(dataset, 'month', 12)
dataset = encode_cyclical(dataset, 'week', 53)

# %%
dataset
# Out:
#       dt_placement                   lau1                 nuts2         x  \
# 0       2010-01-01           αλεξανδρειας  κεντρικης μακεδονιας  22.48398
# 1       2010-01-01               αλμωπιας  κεντρικης μακεδονιας  21.94079
# 2       2010-01-01  αμπελοκηπων μενεμενης  κεντρικης μακεδονιας  22.89198
# 3       2010-01-01              αμφιπολης  κεντρικης μακεδονιας  23.98253
# 4       2010-01-01             αριστοτελη  κεντρικης μακεδονιας  23.69108
# ...            ...                    ...                   ...       ...
# 10939   2021-12-16               σιθωνιας  κεντρικης μακεδονιας  23.82811
# 10940   2021-12-16               σιντικης  κεντρικης μακεδονιας  23.38806
# 10941   2021-12-16                σκυδρας  κεντρικης μακεδονιας  22.14670
# 10942   2021-12-16             χαλκηδονος  κεντρικης μακεδονιας  22.72302
# 10943   2021-12-16           ωραιοκαστρου  κεντρικης μακεδονιας  22.94073
#
#               y  year  month      ndvi      ndmi      ndwi      ndbi  \
# 0      40.64468  2010      1       NaN       NaN       NaN       NaN
# 1      40.97703  2010      1       NaN       NaN       NaN       NaN
# 2      40.65603  2010      1       NaN       NaN       NaN       NaN
# 3      40.91510  2010      1       NaN       NaN       NaN       NaN
# 4      40.49593  2010      1  0.036921  0.159004  0.193601 -0.159004
# ...         ...   ...    ...       ...       ...       ...       ...
# 10939  40.11026  2021     12  0.533019  0.216610 -0.406977 -0.216610
# 10940  41.31348  2021     12  0.126568 -0.005089 -0.091934  0.005089
# 10941  40.82294  2021     12  0.424823  0.260152 -0.272072 -0.260152
# 10942  40.75357  2021     12  0.255928 -0.052975 -0.231818  0.052975
# 10943  40.77171  2021     12  0.489202  0.143697 -0.379266 -0.143697
#
#        ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  \
# 0            NaN        NaN        NaN        NaN       NaN       NaN
# 1            NaN        NaN        NaN        NaN       NaN       NaN
# 2            NaN        NaN        NaN        NaN       NaN       NaN
# 3            NaN        NaN        NaN        NaN       NaN       NaN
# 4       0.036921   0.159004   0.193601  -0.159004  0.000000  0.000000
# ...          ...        ...        ...        ...       ...       ...
# 10939   0.525750   0.209897  -0.401147  -0.209897  0.039324  0.061157
# 10940   0.122184   0.074416  -0.090676  -0.074416  0.027041  0.050254
# 10941   0.423505   0.247285  -0.273696  -0.247285  0.023733  0.043566
# 10942   0.276006  -0.030417  -0.240922   0.030417  0.059156  0.056067
# 10943   0.391442   0.050392  -0.320558  -0.050392  0.089553  0.062114
#
#        ndwi_std  ndbi_std       lst_day  lst_night  lst_jan_day_mean  \
# 0           NaN       NaN  14254.250000   13999.75      14038.416667
# 1           NaN       NaN  14223.727273   13957.00      13869.513312
# 2           NaN       NaN  14331.000000   14102.00      14294.000000
# 3           NaN       NaN  14313.500000   14075.75      14060.466667
# 4      0.000000  0.000000  14419.500000   14040.25      14128.136995
# ...         ...       ...           ...        ...               ...
# 10939  0.034067  0.061157           NaN        NaN      14131.712105
# 10940  0.035247  0.050254           NaN        NaN      13895.539899
# 10941  0.046055  0.043566           NaN        NaN      14058.867424
# 10942  0.041252  0.056067           NaN        NaN      14117.840476
# 10943  0.058832  0.062114           NaN        NaN      13997.121212
#
#        lst_jan_night_mean  lst_feb_day_mean  lst_feb_night_mean  \
# 0            13841.023810      14155.566667        13756.638258
# 1            13744.208815      13867.496753        13711.131484
# 2            13933.000000      14150.166667        13838.100000
# 3            13849.123810      14119.082323        13755.281926
# 4            13903.784226      14068.485978        13793.050847
# ...                   ...               ...                 ...
# 10939        13798.223434      14309.703516        13947.082353
# 10940        13525.684019      14245.385339        13792.929034
# 10941        13572.800000      14466.912879        13843.509211
# 10942        13553.251852      14456.092308        13851.944444
# 10943        13640.071429      14316.700000        13877.980556
#
#        lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  \
# 0          14594.434470        13873.434314      15130.728022
# 1          14224.720029        13763.856185      14598.699282
# 2          14571.111111        13959.833333      14996.000000
# 3          14385.038636        13831.014839      14687.678342
# 4          14424.248689        13827.634516      14601.602841
# ...                 ...                 ...               ...
# 10939      14391.596265        13919.650000      14628.870760
# 10940      14454.229025        13724.788455      14684.146065
# 10941      14590.182353        13825.676471      14830.247917
# 10942      14692.609280        13852.974401      14831.047863
# 10943      14501.561538        13819.107143      14787.000000
#
#        lst_apr_night_mean  acc_rainfall_jan  acc_rainfall_1week  \
# 0            14121.996545          0.015560            0.015560
# 1            13988.568853          0.248551            0.248551
# 2            14245.000000          0.000000            0.000000
# 3            14072.125000          0.055994            0.055994
# 4            14032.383996          1.750566            1.750566
# ...                   ...               ...                 ...
# 10939        14012.311944       2180.544076           75.411011
# 10940        13885.721902       1562.784564          141.524710
# 10941        13975.117647        997.526490           56.599638
# 10942        14012.847619       1117.097203           59.682183
# 10943        13975.461538       1283.646776           62.627688
#
#        acc_rainfall_2week  case  day  week  eq_distance   day_sin   day_cos  \
# 0                0.015560     0    1    53     46.44911  0.201299  0.979530
# 1                0.248551     0    1    53     46.48134  0.201299  0.979530
# 2                0.000000     0    1    53     46.65786  0.201299  0.979530
# 3                0.055994     0    1    53     47.42581  0.201299  0.979530
# 4                1.750566     0    1    53     46.91682  0.201299  0.979530
# ...                   ...   ...  ...   ...          ...       ...       ...
# 10939          161.899452     0   16    50     46.65417 -0.101168 -0.994869
# 10940          215.682589     0   16    50     47.47426 -0.101168 -0.994869
# 10941           67.029917     0   16    50     46.44339 -0.101168 -0.994869
# 10942           90.624163     0   16    50     46.66036 -0.101168 -0.994869
# 10943          122.578538     0   16    50     46.78258 -0.101168 -0.994869
#
#           month_sin  month_cos      week_sin  week_cos
# 0      5.000000e-01   0.866025 -2.449294e-16   1.00000
# 1      5.000000e-01   0.866025 -2.449294e-16   1.00000
# 2      5.000000e-01   0.866025 -2.449294e-16   1.00000
# 3      5.000000e-01   0.866025 -2.449294e-16   1.00000
# 4      5.000000e-01   0.866025 -2.449294e-16   1.00000
# ...             ...        ...           ...       ...
# 10939 -2.449294e-16   1.000000 -3.482016e-01   0.93742
# 10940 -2.449294e-16   1.000000 -3.482016e-01   0.93742
# 10941 -2.449294e-16   1.000000 -3.482016e-01   0.93742
# 10942 -2.449294e-16   1.000000 -3.482016e-01   0.93742
# 10943 -2.449294e-16   1.000000 -3.482016e-01   0.93742
#
# [10944 rows x 42 columns]

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
df_demographics = pd.read_csv(f'../../data/{NUTS0}_WEB_Demographics_Processed.csv', encoding = enc)

# %%
df_demographics
# Out:
#                  lau1                             nuts2                 nuts3  \
# 0             αβδηρων  ανατολικης μακεδονιας και θρακης                ξανθης
# 1         αγαθονησιου                    νοτιου αιγαιου              καλυμνου
# 2               αγιας                         θεσσαλιας               λαρισας
# 3      αγιας βαρβαρας                           αττικης  δυτικου τομεα αθηνων
# 4    αγιας παρασκευης                           αττικης  βορειου τομεα αθηνων
# ..                ...                               ...                   ...
# 327            χανιων                            κρητης                χανιων
# 328        χερσονησου                            κρητης             ηρακλειου
# 329              χιου                   βορειου αιγαιου                  χιου
# 330      ωραιοκαστρου              κεντρικης μακεδονιας          θεσσαλονικης
# 331            ωρωπου                           αττικης    ανατολικης αττικης
#
#       area  population_density  population
# 0    352.0                54.0     17860.0
# 1     14.5                12.8       203.0
# 2    661.8                17.3     10705.0
# 3      2.4             10925.9     26759.0
# 4      7.9              7557.5     62157.0
# ..     ...                 ...         ...
# 327  351.3               309.3    110646.0
# 328  272.2                98.2     27229.0
# 329  842.3                61.0     50483.0
# 330  217.9               175.8     40114.0
# 331  338.2                99.8     33977.0
#
# [332 rows x 6 columns]

# %%
df_demographics_nuts2 = df_demographics.query(f"nuts2 == '{NUTS2_EL}'").copy()

# %%
df_demographics_nuts2.drop(columns=['nuts2', 'nuts3'], inplace=True)
df_demographics_nuts2.reset_index(inplace=True, drop=True)

# %%
df_demographics_nuts2
# Out:
#                      lau1    area  population_density  population
# 0            αλεξανδρειας   478.8                86.8     38293.0
# 1                αλμωπιας   985.8                28.0     24924.0
# 2   αμπελοκηπων μενεμενης     9.8              5319.1     49674.0
# 3               αμφιπολης   411.8                22.3      7169.0
# 4              αριστοτελη   747.0                24.5     16994.0
# ..                    ...     ...                 ...         ...
# 33               σιθωνιας   516.8                24.0     11631.0
# 34               σιντικης  1103.4                20.1     18532.0
# 35                σκυδρας   239.5                84.3     18080.0
# 36             χαλκηδονος   391.5                86.0     29951.0
# 37           ωραιοκαστρου   217.9               175.8     40114.0
#
# [38 rows x 4 columns]

# %%
names_from_merged = dataset["lau1"].drop_duplicates().sort_values().tolist()
names_from_demographics = df_demographics_nuts2["lau1"].drop_duplicates().sort_values().tolist()
diff = []

for element in names_from_merged:
    if element not in names_from_demographics:
        diff.append(element)
        

print(f"{diff}\n\nLength: {len(diff)}")
# Out:
# ['ναουσας']
#
# Length: 1

# %%
df_demographics_nuts2['lau1'] = df_demographics_nuts2['lau1'].apply(lambda x : x.replace('ηρωικης πολεως ναουσας','ναουσας'))

# %%
names_from_merged = dataset["lau1"].drop_duplicates().sort_values().tolist()
names_from_demographics = df_demographics_nuts2["lau1"].drop_duplicates().sort_values().tolist()
diff = []

for element in names_from_merged:
    if element not in names_from_demographics:
        diff.append(element)
        

print(f"{diff}\n\nLength: {len(diff)}")
# Out:
# []
#
# Length: 0

# %%
dataset = pd.merge(dataset, df_demographics_nuts2,  how='left', on=['lau1'])

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
missing = describe_dataframe(dataset)

# %%
dataset
# Out:
#       dt_placement                   lau1                 nuts2         x  \
# 0       2010-01-01           αλεξανδρειας  κεντρικης μακεδονιας  22.48398
# 1       2010-01-01               αλμωπιας  κεντρικης μακεδονιας  21.94079
# 2       2010-01-01  αμπελοκηπων μενεμενης  κεντρικης μακεδονιας  22.89198
# 3       2010-01-01              αμφιπολης  κεντρικης μακεδονιας  23.98253
# 4       2010-01-01             αριστοτελη  κεντρικης μακεδονιας  23.69108
# ...            ...                    ...                   ...       ...
# 10939   2021-12-16               σιθωνιας  κεντρικης μακεδονιας  23.82811
# 10940   2021-12-16               σιντικης  κεντρικης μακεδονιας  23.38806
# 10941   2021-12-16                σκυδρας  κεντρικης μακεδονιας  22.14670
# 10942   2021-12-16             χαλκηδονος  κεντρικης μακεδονιας  22.72302
# 10943   2021-12-16           ωραιοκαστρου  κεντρικης μακεδονιας  22.94073
#
#               y  year  month      ndvi      ndmi      ndwi      ndbi  \
# 0      40.64468  2010      1       NaN       NaN       NaN       NaN
# 1      40.97703  2010      1       NaN       NaN       NaN       NaN
# 2      40.65603  2010      1       NaN       NaN       NaN       NaN
# 3      40.91510  2010      1       NaN       NaN       NaN       NaN
# 4      40.49593  2010      1  0.036921  0.159004  0.193601 -0.159004
# ...         ...   ...    ...       ...       ...       ...       ...
# 10939  40.11026  2021     12  0.533019  0.216610 -0.406977 -0.216610
# 10940  41.31348  2021     12  0.126568 -0.005089 -0.091934  0.005089
# 10941  40.82294  2021     12  0.424823  0.260152 -0.272072 -0.260152
# 10942  40.75357  2021     12  0.255928 -0.052975 -0.231818  0.052975
# 10943  40.77171  2021     12  0.489202  0.143697 -0.379266 -0.143697
#
#        ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  \
# 0            NaN        NaN        NaN        NaN       NaN       NaN
# 1            NaN        NaN        NaN        NaN       NaN       NaN
# 2            NaN        NaN        NaN        NaN       NaN       NaN
# 3            NaN        NaN        NaN        NaN       NaN       NaN
# 4       0.036921   0.159004   0.193601  -0.159004  0.000000  0.000000
# ...          ...        ...        ...        ...       ...       ...
# 10939   0.525750   0.209897  -0.401147  -0.209897  0.039324  0.061157
# 10940   0.122184   0.074416  -0.090676  -0.074416  0.027041  0.050254
# 10941   0.423505   0.247285  -0.273696  -0.247285  0.023733  0.043566
# 10942   0.276006  -0.030417  -0.240922   0.030417  0.059156  0.056067
# 10943   0.391442   0.050392  -0.320558  -0.050392  0.089553  0.062114
#
#        ndwi_std  ndbi_std       lst_day  lst_night  lst_jan_day_mean  \
# 0           NaN       NaN  14254.250000   13999.75      14038.416667
# 1           NaN       NaN  14223.727273   13957.00      13869.513312
# 2           NaN       NaN  14331.000000   14102.00      14294.000000
# 3           NaN       NaN  14313.500000   14075.75      14060.466667
# 4      0.000000  0.000000  14419.500000   14040.25      14128.136995
# ...         ...       ...           ...        ...               ...
# 10939  0.034067  0.061157           NaN        NaN      14131.712105
# 10940  0.035247  0.050254           NaN        NaN      13895.539899
# 10941  0.046055  0.043566           NaN        NaN      14058.867424
# 10942  0.041252  0.056067           NaN        NaN      14117.840476
# 10943  0.058832  0.062114           NaN        NaN      13997.121212
#
#        lst_jan_night_mean  lst_feb_day_mean  lst_feb_night_mean  \
# 0            13841.023810      14155.566667        13756.638258
# 1            13744.208815      13867.496753        13711.131484
# 2            13933.000000      14150.166667        13838.100000
# 3            13849.123810      14119.082323        13755.281926
# 4            13903.784226      14068.485978        13793.050847
# ...                   ...               ...                 ...
# 10939        13798.223434      14309.703516        13947.082353
# 10940        13525.684019      14245.385339        13792.929034
# 10941        13572.800000      14466.912879        13843.509211
# 10942        13553.251852      14456.092308        13851.944444
# 10943        13640.071429      14316.700000        13877.980556
#
#        lst_mar_day_mean  lst_mar_night_mean  lst_apr_day_mean  \
# 0          14594.434470        13873.434314      15130.728022
# 1          14224.720029        13763.856185      14598.699282
# 2          14571.111111        13959.833333      14996.000000
# 3          14385.038636        13831.014839      14687.678342
# 4          14424.248689        13827.634516      14601.602841
# ...                 ...                 ...               ...
# 10939      14391.596265        13919.650000      14628.870760
# 10940      14454.229025        13724.788455      14684.146065
# 10941      14590.182353        13825.676471      14830.247917
# 10942      14692.609280        13852.974401      14831.047863
# 10943      14501.561538        13819.107143      14787.000000
#
#        lst_apr_night_mean  acc_rainfall_jan  acc_rainfall_1week  \
# 0            14121.996545          0.015560            0.015560
# 1            13988.568853          0.248551            0.248551
# 2            14245.000000          0.000000            0.000000
# 3            14072.125000          0.055994            0.055994
# 4            14032.383996          1.750566            1.750566
# ...                   ...               ...                 ...
# 10939        14012.311944       2180.544076           75.411011
# 10940        13885.721902       1562.784564          141.524710
# 10941        13975.117647        997.526490           56.599638
# 10942        14012.847619       1117.097203           59.682183
# 10943        13975.461538       1283.646776           62.627688
#
#        acc_rainfall_2week  case  day  week  eq_distance   day_sin   day_cos  \
# 0                0.015560     0    1    53     46.44911  0.201299  0.979530
# 1                0.248551     0    1    53     46.48134  0.201299  0.979530
# 2                0.000000     0    1    53     46.65786  0.201299  0.979530
# 3                0.055994     0    1    53     47.42581  0.201299  0.979530
# 4                1.750566     0    1    53     46.91682  0.201299  0.979530
# ...                   ...   ...  ...   ...          ...       ...       ...
# 10939          161.899452     0   16    50     46.65417 -0.101168 -0.994869
# 10940          215.682589     0   16    50     47.47426 -0.101168 -0.994869
# 10941           67.029917     0   16    50     46.44339 -0.101168 -0.994869
# 10942           90.624163     0   16    50     46.66036 -0.101168 -0.994869
# 10943          122.578538     0   16    50     46.78258 -0.101168 -0.994869
#
#           month_sin  month_cos      week_sin  week_cos    area  \
# 0      5.000000e-01   0.866025 -2.449294e-16   1.00000   478.8
# 1      5.000000e-01   0.866025 -2.449294e-16   1.00000   985.8
# 2      5.000000e-01   0.866025 -2.449294e-16   1.00000     9.8
# 3      5.000000e-01   0.866025 -2.449294e-16   1.00000   411.8
# 4      5.000000e-01   0.866025 -2.449294e-16   1.00000   747.0
# ...             ...        ...           ...       ...     ...
# 10939 -2.449294e-16   1.000000 -3.482016e-01   0.93742   516.8
# 10940 -2.449294e-16   1.000000 -3.482016e-01   0.93742  1103.4
# 10941 -2.449294e-16   1.000000 -3.482016e-01   0.93742   239.5
# 10942 -2.449294e-16   1.000000 -3.482016e-01   0.93742   391.5
# 10943 -2.449294e-16   1.000000 -3.482016e-01   0.93742   217.9
#
#        population_density  population
# 0                    86.8     38293.0
# 1                    28.0     24924.0
# 2                  5319.1     49674.0
# 3                    22.3      7169.0
# 4                    24.5     16994.0
# ...                   ...         ...
# 10939                24.0     11631.0
# 10940                20.1     18532.0
# 10941                84.3     18080.0
# 10942                86.0     29951.0
# 10943               175.8     40114.0
#
# [10944 rows x 45 columns]

# %%
df_mosquitoes = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Culex_Predictions_2010-2021.csv', encoding = enc)
df_mosquitoes
# Out:
#                x          y dt_placement  mosq_pred
# 0      22.483978  40.644680   2010-01-01          5
# 1      21.940791  40.977027   2010-01-01          2
# 2      22.891980  40.656030   2010-01-01          7
# 3      23.982527  40.915103   2010-01-01          1
# 4      23.691080  40.495934   2010-01-01          4
# ...          ...        ...          ...        ...
# 10939  23.828106  40.110264   2021-12-16          2
# 10940  23.388058  41.313484   2021-12-16          1
# 10941  22.146700  40.822940   2021-12-16          1
# 10942  22.723020  40.753567   2021-12-16          1
# 10943  22.940730  40.771710   2021-12-16          1
#
# [10944 rows x 4 columns]

# %%
df_mosquitoes['dt_placement'] = pd.to_datetime(dataset['dt_placement'])
df_mosquitoes['x'] = df_mosquitoes['x'].apply(lambda x : round(x,5))
df_mosquitoes['y'] = df_mosquitoes['y'].apply(lambda x : round(x,5))

# %%
distances, indicies = calculate_nearest_topological(dataset, df_mosquitoes)

# %%
print(f'Min distance: {min(distances)}')
print(f'Max distance: {max(distances)}')
# Out:
# Min distance: 0.0
# Max distance: 0.0011119492658909769

# %%
df_mosq = pd.DataFrame(columns=df_mosquitoes.columns)

# %%
for index in indicies:
    df_mosq = df_mosq.append(df_mosquitoes.iloc[[index]])

df_mosq.drop(columns=['x', 'y', 'dt_placement'], inplace = True)
df_mosq.reset_index(drop=True, inplace=True)

# %%
dataset = pd.concat([dataset, df_mosq], axis=1, join = 'outer')

# %%
dataset.head()
# Out:
#   dt_placement                   lau1                 nuts2         x  \
# 0   2010-01-01           αλεξανδρειας  κεντρικης μακεδονιας  22.48398
# 1   2010-01-01               αλμωπιας  κεντρικης μακεδονιας  21.94079
# 2   2010-01-01  αμπελοκηπων μενεμενης  κεντρικης μακεδονιας  22.89198
# 3   2010-01-01              αμφιπολης  κεντρικης μακεδονιας  23.98253
# 4   2010-01-01             αριστοτελη  κεντρικης μακεδονιας  23.69108
#
#           y  year  month      ndvi      ndmi      ndwi      ndbi  ndvi_mean  \
# 0  40.64468  2010      1       NaN       NaN       NaN       NaN        NaN
# 1  40.97703  2010      1       NaN       NaN       NaN       NaN        NaN
# 2  40.65603  2010      1       NaN       NaN       NaN       NaN        NaN
# 3  40.91510  2010      1       NaN       NaN       NaN       NaN        NaN
# 4  40.49593  2010      1  0.036921  0.159004  0.193601 -0.159004   0.036921
#
#    ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  \
# 0        NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 1        NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 2        NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 3        NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 4   0.159004   0.193601  -0.159004       0.0       0.0       0.0       0.0
#
#         lst_day  lst_night  lst_jan_day_mean  lst_jan_night_mean  \
# 0  14254.250000   13999.75      14038.416667        13841.023810
# 1  14223.727273   13957.00      13869.513312        13744.208815
# 2  14331.000000   14102.00      14294.000000        13933.000000
# 3  14313.500000   14075.75      14060.466667        13849.123810
# 4  14419.500000   14040.25      14128.136995        13903.784226
#
#    lst_feb_day_mean  lst_feb_night_mean  lst_mar_day_mean  lst_mar_night_mean  \
# 0      14155.566667        13756.638258      14594.434470        13873.434314
# 1      13867.496753        13711.131484      14224.720029        13763.856185
# 2      14150.166667        13838.100000      14571.111111        13959.833333
# 3      14119.082323        13755.281926      14385.038636        13831.014839
# 4      14068.485978        13793.050847      14424.248689        13827.634516
#
#    lst_apr_day_mean  lst_apr_night_mean  acc_rainfall_jan  acc_rainfall_1week  \
# 0      15130.728022        14121.996545          0.015560            0.015560
# 1      14598.699282        13988.568853          0.248551            0.248551
# 2      14996.000000        14245.000000          0.000000            0.000000
# 3      14687.678342        14072.125000          0.055994            0.055994
# 4      14601.602841        14032.383996          1.750566            1.750566
#
#    acc_rainfall_2week  case  day  week  eq_distance   day_sin  day_cos  \
# 0            0.015560     0    1    53     46.44911  0.201299  0.97953
# 1            0.248551     0    1    53     46.48134  0.201299  0.97953
# 2            0.000000     0    1    53     46.65786  0.201299  0.97953
# 3            0.055994     0    1    53     47.42581  0.201299  0.97953
# 4            1.750566     0    1    53     46.91682  0.201299  0.97953
#
#    month_sin  month_cos      week_sin  week_cos   area  population_density  \
# 0        0.5   0.866025 -2.449294e-16       1.0  478.8                86.8
# 1        0.5   0.866025 -2.449294e-16       1.0  985.8                28.0
# 2        0.5   0.866025 -2.449294e-16       1.0    9.8              5319.1
# 3        0.5   0.866025 -2.449294e-16       1.0  411.8                22.3
# 4        0.5   0.866025 -2.449294e-16       1.0  747.0                24.5
#
#    population mosq_pred
# 0     38293.0         5
# 1     24924.0         1
# 2     49674.0         7
# 3      7169.0        20
# 4     16994.0         4

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
dataset.reset_index(inplace=True, drop=True)

# %%
dataset = calculate_mosq_previous(dataset)

# %%
dataset = convert_temperature(dataset)

# %%
missingno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
dataset['case'].value_counts()
# Out:
# 0     10608
# 1       212
# 2        61
# 3        23
# 4        20
#       ...
# 6         2
# 11        1
# 18        1
# 12        1
# 9         1
# Name: case, Length: 13, dtype: int64

# %%
dataset = dataset.astype({'mosq_pred' : 'int', 'mosq_previous' : 'int'})

# %%
dataset = convert_multiple_cases(dataset)

# %%
dataset['case'].value_counts()
# Out:
# 0    10608
# 1      632
# Name: case, dtype: int64

# %%
cols = dataset.columns

# %%
cols
# Out:
# Index(['dt_placement', 'lau1', 'nuts2', 'x', 'y', 'year', 'month', 'ndvi',
#        'ndmi', 'ndwi', 'ndbi', 'ndvi_mean', 'ndmi_mean', 'ndwi_mean',
#        'ndbi_mean', 'ndvi_std', 'ndmi_std', 'ndwi_std', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_day_mean', 'lst_jan_night_mean',
#        'lst_feb_day_mean', 'lst_feb_night_mean', 'lst_mar_day_mean',
#        'lst_mar_night_mean', 'lst_apr_day_mean', 'lst_apr_night_mean',
#        'acc_rainfall_jan', 'acc_rainfall_1week', 'acc_rainfall_2week', 'case',
#        'day', 'week', 'eq_distance', 'day_sin', 'day_cos', 'month_sin',
#        'month_cos', 'week_sin', 'week_cos', 'area', 'population_density',
#        'population', 'mosq_pred', 'mosq_previous', 'lst'],
#       dtype='object')

# %%
len(cols)
# Out:
# 48

# %%
# check columns

# %%
final_columns = ['x', 'y', 'dt_placement', 'nuts2', 'lau1', 'day', 
                 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 
                 'month_cos', 'week_sin', 'week_cos', 'area', 'population',
                 'population_density', 'eq_distance', 'ndvi', 'ndmi', 'ndwi', 'ndbi', 
                 'ndvi_mean', 'ndmi_mean', 'ndwi_mean', 'ndbi_mean', 
                 'ndvi_std', 'ndmi_std', 'ndwi_std', 'ndbi_std', 'lst',
                 'lst_day', 'lst_night','lst_jan_day_mean', 'lst_jan_night_mean', 
                 'lst_feb_day_mean','lst_feb_night_mean', 'lst_mar_day_mean', 
                 'lst_mar_night_mean', 'lst_apr_day_mean', 'lst_apr_night_mean',
                 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan',
                 'mosq_pred', 'mosq_previous', 'case']

# %%
len(final_columns)
# Out:
# 48

# %%
dataset_final = dataset[final_columns].copy()

# %%
dataset_final
# Out:
#               x         y dt_placement                 nuts2  \
# 0      22.48398  40.64468   2010-01-01  κεντρικης μακεδονιας
# 1      21.94079  40.97703   2010-01-01  κεντρικης μακεδονιας
# 2      22.89198  40.65603   2010-01-01  κεντρικης μακεδονιας
# 3      23.98253  40.91510   2010-01-01  κεντρικης μακεδονιας
# 4      23.69108  40.49593   2010-01-01  κεντρικης μακεδονιας
# ...         ...       ...          ...                   ...
# 11235  22.41285  40.81412   2018-08-16  κεντρικης μακεδονιας
# 11236  22.41285  40.81412   2018-08-16  κεντρικης μακεδονιας
# 11237  22.41285  40.81412   2018-08-16  κεντρικης μακεδονιας
# 11238  22.41285  40.81412   2018-08-16  κεντρικης μακεδονιας
# 11239  22.41285  40.81412   2018-08-16  κεντρικης μακεδονιας
#
#                         lau1  day  month  week  year   day_sin   day_cos  \
# 0               αλεξανδρειας    1      1    53  2010  0.201299  0.979530
# 1                   αλμωπιας    1      1    53  2010  0.201299  0.979530
# 2      αμπελοκηπων μενεμενης    1      1    53  2010  0.201299  0.979530
# 3                  αμφιπολης    1      1    53  2010  0.201299  0.979530
# 4                 αριστοτελη    1      1    53  2010  0.201299  0.979530
# ...                      ...  ...    ...   ...   ...       ...       ...
# 11235                 πελλας   16      8    33  2018 -0.101168 -0.994869
# 11236                 πελλας   16      8    33  2018 -0.101168 -0.994869
# 11237                 πελλας   16      8    33  2018 -0.101168 -0.994869
# 11238                 πελλας   16      8    33  2018 -0.101168 -0.994869
# 11239                 πελλας   16      8    33  2018 -0.101168 -0.994869
#
#        month_sin  month_cos      week_sin  week_cos   area  population  \
# 0       0.500000   0.866025 -2.449294e-16  1.000000  478.8     38293.0
# 1       0.500000   0.866025 -2.449294e-16  1.000000  985.8     24924.0
# 2       0.500000   0.866025 -2.449294e-16  1.000000    9.8     49674.0
# 3       0.500000   0.866025 -2.449294e-16  1.000000  411.8      7169.0
# 4       0.500000   0.866025 -2.449294e-16  1.000000  747.0     16994.0
# ...          ...        ...           ...       ...    ...         ...
# 11235  -0.866025  -0.500000 -6.965510e-01 -0.717507  669.2     56918.0
# 11236  -0.866025  -0.500000 -6.965510e-01 -0.717507  669.2     56918.0
# 11237  -0.866025  -0.500000 -6.965510e-01 -0.717507  669.2     56918.0
# 11238  -0.866025  -0.500000 -6.965510e-01 -0.717507  669.2     56918.0
# 11239  -0.866025  -0.500000 -6.965510e-01 -0.717507  669.2     56918.0
#
#        population_density  eq_distance      ndvi      ndmi      ndwi  \
# 0                    86.8     46.44911       NaN       NaN       NaN
# 1                    28.0     46.48134       NaN       NaN       NaN
# 2                  5319.1     46.65786       NaN       NaN       NaN
# 3                    22.3     47.42581       NaN       NaN       NaN
# 4                    24.5     46.91682  0.036921  0.159004  0.193601
# ...                   ...          ...       ...       ...       ...
# 11235                94.3     46.56316  0.458799  0.094423 -0.417326
# 11236                94.3     46.56316  0.458799  0.094423 -0.417326
# 11237                94.3     46.56316  0.458799  0.094423 -0.417326
# 11238                94.3     46.56316  0.458799  0.094423 -0.417326
# 11239                94.3     46.56316  0.458799  0.094423 -0.417326
#
#            ndbi  ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  \
# 0           NaN        NaN        NaN        NaN        NaN       NaN
# 1           NaN        NaN        NaN        NaN        NaN       NaN
# 2           NaN        NaN        NaN        NaN        NaN       NaN
# 3           NaN        NaN        NaN        NaN        NaN       NaN
# 4     -0.159004   0.036921   0.159004   0.193601  -0.159004  0.000000
# ...         ...        ...        ...        ...        ...       ...
# 11235 -0.094423   0.425498   0.082706  -0.393120  -0.082706  0.108684
# 11236 -0.094423   0.425498   0.082706  -0.393120  -0.082706  0.108684
# 11237 -0.094423   0.425498   0.082706  -0.393120  -0.082706  0.108684
# 11238 -0.094423   0.425498   0.082706  -0.393120  -0.082706  0.108684
# 11239 -0.094423   0.425498   0.082706  -0.393120  -0.082706  0.108684
#
#        ndmi_std  ndwi_std  ndbi_std        lst    lst_day  lst_night  \
# 0           NaN       NaN       NaN   9.390000  11.935000      6.845
# 1           NaN       NaN       NaN   8.657273  11.324545      5.990
# 2           NaN       NaN       NaN  11.180000  13.470000      8.890
# 3           NaN       NaN       NaN  10.742500  13.120000      8.365
# 4      0.000000  0.000000  0.000000  11.447500  15.240000      7.655
# ...         ...       ...       ...        ...        ...        ...
# 11235  0.072249  0.084478  0.072249  27.882000  34.258000     21.506
# 11236  0.072249  0.084478  0.072249  27.882000  34.258000     21.506
# 11237  0.072249  0.084478  0.072249  27.882000  34.258000     21.506
# 11238  0.072249  0.084478  0.072249  27.882000  34.258000     21.506
# 11239  0.072249  0.084478  0.072249  27.882000  34.258000     21.506
#
#        lst_jan_day_mean  lst_jan_night_mean  lst_feb_day_mean  \
# 0              7.618333            3.670476          9.961333
# 1              4.240266            1.734176          4.199935
# 2             12.730000            5.510000          9.853333
# 3              8.059333            3.832476          9.231646
# 4              9.412740            4.925685          8.219720
# ...                 ...                 ...               ...
# 11235         11.166473            0.115267         14.108900
# 11236         11.166473            0.115267         14.108900
# 11237         11.166473            0.115267         14.108900
# 11238         11.166473            0.115267         14.108900
# 11239         11.166473            0.115267         14.108900
#
#        lst_feb_night_mean  lst_mar_day_mean  lst_mar_night_mean  \
# 0                1.982765         18.738689            4.318686
# 1                1.072630         11.344401            2.127124
# 2                3.612000         18.272222            6.046667
# 3                1.955639         14.550773            3.470297
# 4                2.711017         15.334974            3.402690
# ...                   ...               ...                 ...
# 11235            1.406167         20.498747            6.152633
# 11236            1.406167         20.498747            6.152633
# 11237            1.406167         20.498747            6.152633
# 11238            1.406167         20.498747            6.152633
# 11239            1.406167         20.498747            6.152633
#
#        lst_apr_day_mean  lst_apr_night_mean  acc_rainfall_1week  \
# 0             29.464560            9.289931            0.015560
# 1             18.823986            6.621377            0.248551
# 2             26.770000           11.750000            0.000000
# 3             20.603567            8.292500            0.055994
# 4             18.882057            7.497680            1.750566
# ...                 ...                 ...                 ...
# 11235         28.072005           12.348017            0.498782
# 11236         28.072005           12.348017            0.498782
# 11237         28.072005           12.348017            0.498782
# 11238         28.072005           12.348017            0.498782
# 11239         28.072005           12.348017            0.498782
#
#        acc_rainfall_2week  acc_rainfall_jan  mosq_pred  mosq_previous  case
# 0                0.015560          0.015560          5              0     0
# 1                0.248551          0.248551          1              0     0
# 2                0.000000          0.000000          7              0     0
# 3                0.055994          0.055994         20              0     0
# 4                1.750566          1.750566          4              0     0
# ...                   ...               ...        ...            ...   ...
# 11235            9.606998        761.377052          4              8     1
# 11236            9.606998        761.377052          4              8     1
# 11237            9.606998        761.377052          4              8     1
# 11238            9.606998        761.377052          4              8     1
# 11239            9.606998        761.377052          4              8     1
#
# [11240 rows x 48 columns]

# %%
dataset_final.to_csv(f"../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Dataset_2010_2021.csv", encoding = enc, index = False)
