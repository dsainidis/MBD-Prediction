# %%
import pandas as pd
import missingno
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import gaussian_kde
from scipy.integrate import simps
import sys

sys.path.insert(0, "../../Modules")

from utils import *

enc = 'utf-8' 
dec = 'greek8'

# %%
raw_data = pd.read_csv('../data/GR_WNV_cases_2023.csv', encoding = enc)
raw_data.head(5)
# Out:
#    Έτος Ημ/νία έναρξης συμπτωμάτων        Περιφέρεια πιθανής έκθεσης  \
# 0  2023                   18-07-23              Κεντρικής Μακεδονίας
# 1  2023                   25-07-23                         Θεσσαλίας
# 2  2023                   25-07-23  Ανατολικής Μακεδονίας και Θράκης
# 3  2023                   01-08-23  Ανατολικής Μακεδονίας και Θράκης
# 4  2023                   01-08-23                         Θεσσαλίας
#
#   Περιφερειακή ενότητα πιθανής έκθεσης Δήμος πιθανής έκθεσης  \
# 0                               Σερρών             Ηράκλειας
# 1                            Καρδίτσας             Καρδίτσας
# 2                              Καβάλας                Νέστου
# 3                              Καβάλας                Νέστου
# 4                            Καρδίτσας             Καρδίτσας
#
#    Αριθμός ασθενών ΜΕ εκδηλώσεις από το ΚΝΣ  \
# 0                                         1
# 1                                         1
# 2                                         0
# 3                                         1
# 4                                         1
#
#    Αριθμός ασθενών ΧΩΡΙΣ εκδηλώσεις από το ΚΝΣ  Συνολικός αριθμός ασθενών
# 0                                            0                          1
# 1                                            0                          1
# 2                                            1                          1
# 3                                            0                          1
# 4                                            0                          1

# %%
raw_data.shape
# Out:
# (125, 8)

# %%
data = raw_data.set_axis(['year', 'onset of symptoms', 'nuts2', 'nuts3', 'lau1', 'cases_CNS', 'cases_WO_CNS', 'cases'], axis=1, inplace=False)

# %%
data.drop(columns = ['cases_CNS', 'cases_WO_CNS'], inplace = True)
data.head(5)
# Out:
#    year onset of symptoms                             nuts2      nuts3  \
# 0  2023          18-07-23              Κεντρικής Μακεδονίας     Σερρών
# 1  2023          25-07-23                         Θεσσαλίας  Καρδίτσας
# 2  2023          25-07-23  Ανατολικής Μακεδονίας και Θράκης    Καβάλας
# 3  2023          01-08-23  Ανατολικής Μακεδονίας και Θράκης    Καβάλας
# 4  2023          01-08-23                         Θεσσαλίας  Καρδίτσας
#
#         lau1  cases
# 0  Ηράκλειας      1
# 1  Καρδίτσας      1
# 2     Νέστου      1
# 3     Νέστου      1
# 4  Καρδίτσας      1

# %%
df_missign = describe_dataframe(data)

df_missign
# Out:
#               Column  Missing
# 0               year      0.0
# 1  onset of symptoms      0.0
# 2              nuts2      0.0
# 3              nuts3      0.0
# 4               lau1      0.0
# 5              cases      0.0

# %%
data.shape
# Out:
# (125, 6)

# %%
data['onset of symptoms'] = pd.to_datetime(data['onset of symptoms'], dayfirst=True, errors='coerce')

# %%
data
# Out:
#      year onset of symptoms                             nuts2         nuts3  \
# 0    2023        2023-07-18              Κεντρικής Μακεδονίας        Σερρών
# 1    2023        2023-07-25                         Θεσσαλίας     Καρδίτσας
# 2    2023        2023-07-25  Ανατολικής Μακεδονίας και Θράκης       Καβάλας
# 3    2023        2023-08-01  Ανατολικής Μακεδονίας και Θράκης       Καβάλας
# 4    2023        2023-08-01                         Θεσσαλίας     Καρδίτσας
# ..    ...               ...                               ...           ...
# 120  2023        2023-10-17              Κεντρικής Μακεδονίας  Θεσσαλονίκης
# 121  2023        2023-10-17              Κεντρικής Μακεδονίας       Ημαθίας
# 122  2023        2023-10-17                   Δυτικής Ελλάδας        Αχαΐας
# 123  2023        2023-10-17                      Πελοποννήσου     Αργολίδας
# 124  2023        2023-11-07              Κεντρικής Μακεδονίας  Θεσσαλονίκης
#
#                        lau1  cases
# 0                 Ηράκλειας      1
# 1                 Καρδίτσας      1
# 2                    Νέστου      1
# 3                    Νέστου      1
# 4                 Καρδίτσας      1
# ..                      ...    ...
# 120              Καλαμαριάς      1
# 121  Ηρωικής Πόλεως Νάουσας      1
# 122              Αιγιαλείας      1
# 123        Άργους - Μυκηνών      1
# 124            Ωραιοκάστρου      1
#
# [125 rows x 6 columns]

# %%
missingno.matrix(data)
# Out:
# <AxesSubplot:>

# %%
process_greek(data, 'nuts2')
process_greek(data, 'nuts3')
process_greek(data, 'lau1')

# %%
data
# Out:
#      year onset of symptoms                             nuts2         nuts3  \
# 0    2023        2023-07-18              κεντρικης μακεδονιας        σερρων
# 1    2023        2023-07-25                         θεσσαλιας     καρδιτσας
# 2    2023        2023-07-25  ανατολικης μακεδονιας και θρακης       καβαλας
# 3    2023        2023-08-01  ανατολικης μακεδονιας και θρακης       καβαλας
# 4    2023        2023-08-01                         θεσσαλιας     καρδιτσας
# ..    ...               ...                               ...           ...
# 120  2023        2023-10-17              κεντρικης μακεδονιας  θεσσαλονικης
# 121  2023        2023-10-17              κεντρικης μακεδονιας       ημαθιας
# 122  2023        2023-10-17                   δυτικης ελλαδας        αχαιας
# 123  2023        2023-10-17                      πελοποννησου     αργολιδας
# 124  2023        2023-11-07              κεντρικης μακεδονιας  θεσσαλονικης
#
#                        lau1  cases
# 0                 ηρακλειας      1
# 1                 καρδιτσας      1
# 2                    νεστου      1
# 3                    νεστου      1
# 4                 καρδιτσας      1
# ..                      ...    ...
# 120              καλαμαριας      1
# 121  ηρωικης πολεως ναουσας      1
# 122              αιγιαλειας      1
# 123          αργους μυκηνων      1
# 124            ωραιοκαστρου      1
#
# [125 rows x 6 columns]

# %%
data['day'] = data['onset of symptoms'].apply(lambda x : x.day)
data['month'] = data['onset of symptoms'].apply(lambda x : x.month)

# %%
data
# Out:
#      year onset of symptoms                             nuts2         nuts3  \
# 0    2023        2023-07-18              κεντρικης μακεδονιας        σερρων
# 1    2023        2023-07-25                         θεσσαλιας     καρδιτσας
# 2    2023        2023-07-25  ανατολικης μακεδονιας και θρακης       καβαλας
# 3    2023        2023-08-01  ανατολικης μακεδονιας και θρακης       καβαλας
# 4    2023        2023-08-01                         θεσσαλιας     καρδιτσας
# ..    ...               ...                               ...           ...
# 120  2023        2023-10-17              κεντρικης μακεδονιας  θεσσαλονικης
# 121  2023        2023-10-17              κεντρικης μακεδονιας       ημαθιας
# 122  2023        2023-10-17                   δυτικης ελλαδας        αχαιας
# 123  2023        2023-10-17                      πελοποννησου     αργολιδας
# 124  2023        2023-11-07              κεντρικης μακεδονιας  θεσσαλονικης
#
#                        lau1  cases  day  month
# 0                 ηρακλειας      1   18      7
# 1                 καρδιτσας      1   25      7
# 2                    νεστου      1   25      7
# 3                    νεστου      1    1      8
# 4                 καρδιτσας      1    1      8
# ..                      ...    ...  ...    ...
# 120              καλαμαριας      1   17     10
# 121  ηρωικης πολεως ναουσας      1   17     10
# 122              αιγιαλειας      1   17     10
# 123          αργους μυκηνων      1   17     10
# 124            ωραιοκαστρου      1    7     11
#
# [125 rows x 8 columns]

# %%
data = data.reindex(columns=['onset of symptoms', 'year', 'month', 'day', 'nuts2', 'nuts3', 'lau1', 'cases'])

# %%
data
# Out:
#     onset of symptoms  year  month  day                             nuts2  \
# 0          2023-07-18  2023      7   18              κεντρικης μακεδονιας
# 1          2023-07-25  2023      7   25                         θεσσαλιας
# 2          2023-07-25  2023      7   25  ανατολικης μακεδονιας και θρακης
# 3          2023-08-01  2023      8    1  ανατολικης μακεδονιας και θρακης
# 4          2023-08-01  2023      8    1                         θεσσαλιας
# ..                ...   ...    ...  ...                               ...
# 120        2023-10-17  2023     10   17              κεντρικης μακεδονιας
# 121        2023-10-17  2023     10   17              κεντρικης μακεδονιας
# 122        2023-10-17  2023     10   17                   δυτικης ελλαδας
# 123        2023-10-17  2023     10   17                      πελοποννησου
# 124        2023-11-07  2023     11    7              κεντρικης μακεδονιας
#
#             nuts3                    lau1  cases
# 0          σερρων               ηρακλειας      1
# 1       καρδιτσας               καρδιτσας      1
# 2         καβαλας                  νεστου      1
# 3         καβαλας                  νεστου      1
# 4       καρδιτσας               καρδιτσας      1
# ..            ...                     ...    ...
# 120  θεσσαλονικης              καλαμαριας      1
# 121       ημαθιας  ηρωικης πολεως ναουσας      1
# 122        αχαιας              αιγιαλειας      1
# 123     αργολιδας          αργους μυκηνων      1
# 124  θεσσαλονικης            ωραιοκαστρου      1
#
# [125 rows x 8 columns]

# %%
data.to_csv("../data/GR_WNV_cases_2023_processed.csv", encoding = enc, index = False)

# %%
years = 2023
cases = data.cases.sum()

plt.figure(num = None, figsize = (15,8), facecolor='w', edgecolor='b')
#plt.bar(years, cases)
plt.barh(years, cases)

#ax.bar_label(bars)
#y_t = plt.xticks(np.arange(0, max(cases) + 10, step = 50), size = 14)
#x_t = plt.yticks(np.arange(min(years), max(years) + 1, step = 1), size = 14)
x_l  = plt.ylabel('Years', size = 18)
y_l =  plt.xlabel('Cases', size = 18)
title = plt.title('WNV Cases in Greece per Year', size = 22)

plt.text(cases+0.15, years-0.15, str(cases), size = 12)
ax = plt.gca()
ax.xaxis.grid(True)
plt.show()

# %%
nuts2 = data['nuts2'].drop_duplicates().sort_values().tolist()
cases = [data.query(f"nuts2 == '{nuts2_unit}'").cases.sum() for nuts2_unit in nuts2]

cases, nuts2 = zip(*sorted(zip(cases, nuts2)))

plt.figure(num = None, figsize = (14,5), facecolor='w', edgecolor='b')
plt.barh(nuts2, cases)

y_t = plt.xticks(np.arange(0, max(cases) + 100, step = 50), size = 14)
x_t = plt.yticks(nuts2, size = 14)
x_l  = plt.ylabel('NUTS2', size = 18)
y_l =  plt.xlabel('Cases', size = 18)
title = plt.title('WNV Cases in Greece per NUTS2 (2022)', size = 22)
for nuts2, case in zip(nuts2,cases):
    plt.text(case+0.15, nuts2, str(case), size = 14)
ax = plt.gca()
ax.xaxis.grid(True)
plt.show()
