# %%
import pandas as pd
import missingno
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import gaussian_kde
from scipy.integrate import simps
import sys

sys.path.insert(0, "../../Modules")

from utils import *

enc = 'utf-8' 
dec = 'greek8'

# %%
raw_data = pd.read_csv('../data/GR_WNV_cases_2022.csv', encoding = enc)
raw_data.head(5)
# Out:
#    Έτος Ημ/νία έναρξης συμπτωμάτων Περιφέρεια πιθανής έκθεσης  \
# 0  2022                   12-07-22       Κεντρικής Μακεδονίας
# 1  2022                   19-07-22       Κεντρικής Μακεδονίας
# 2  2022                   19-07-22       Κεντρικής Μακεδονίας
# 3  2022                   16-07-22       Κεντρικής Μακεδονίας
# 4  2022                   16-07-22       Κεντρικής Μακεδονίας
#
#   Περιφερειακή ενότητα πιθανής έκθεσης    Δήμος πιθανής έκθεσης  \
# 0                         Θεσσαλονίκης  Αμπελοκήπων - Μενεμένης
# 1                         Θεσσαλονίκης                    Δέλτα
# 2                         Θεσσαλονίκης               Χαλκηδόνος
# 3                         Θεσσαλονίκης                    Δέλτα
# 4                         Θεσσαλονίκης                   Θέρμης
#
#    Αριθμός ασθενών ΜΕ εκδηλώσεις από το ΚΝΣ  \
# 0                                         1
# 1                                         2
# 2                                         1
# 3                                         1
# 4                                         1
#
#    Αριθμός ασθενών ΧΩΡΙΣ εκδηλώσεις από το ΚΝΣ  Συνολικός αριθμός ασθενών
# 0                                            0                          1
# 1                                            0                          2
# 2                                            0                          1
# 3                                            0                          1
# 4                                            0                          1

# %%
raw_data.shape
# Out:
# (177, 8)

# %%
data = raw_data.set_axis(['year', 'onset of symptoms', 'nuts2', 'nuts3', 'lau1', 'cases_CNS', 'cases_WO_CNS', 'cases'], axis=1, inplace=False)

# %%
data.drop(columns = ['cases_CNS', 'cases_WO_CNS'], inplace = True)
data.head(5)
# Out:
#    year onset of symptoms                 nuts2         nuts3  \
# 0  2022          12-07-22  Κεντρικής Μακεδονίας  Θεσσαλονίκης
# 1  2022          19-07-22  Κεντρικής Μακεδονίας  Θεσσαλονίκης
# 2  2022          19-07-22  Κεντρικής Μακεδονίας  Θεσσαλονίκης
# 3  2022          16-07-22  Κεντρικής Μακεδονίας  Θεσσαλονίκης
# 4  2022          16-07-22  Κεντρικής Μακεδονίας  Θεσσαλονίκης
#
#                       lau1  cases
# 0  Αμπελοκήπων - Μενεμένης      1
# 1                    Δέλτα      2
# 2               Χαλκηδόνος      1
# 3                    Δέλτα      1
# 4                   Θέρμης      1

# %%
df_missign = describe_dataframe(data)

df_missign
# Out:
#               Column  Missing
# 0               year      0.0
# 1  onset of symptoms      0.0
# 2              nuts2      0.0
# 3              nuts3      0.0
# 4               lau1      0.0
# 5              cases      0.0

# %%
data.shape
# Out:
# (177, 6)

# %%
data['onset of symptoms'] = pd.to_datetime(data['onset of symptoms'], dayfirst=True, errors='coerce')

# %%
data
# Out:
#      year onset of symptoms                             nuts2         nuts3  \
# 0    2022        2022-07-12              Κεντρικής Μακεδονίας  Θεσσαλονίκης
# 1    2022        2022-07-19              Κεντρικής Μακεδονίας  Θεσσαλονίκης
# 2    2022        2022-07-19              Κεντρικής Μακεδονίας  Θεσσαλονίκης
# 3    2022        2022-07-16              Κεντρικής Μακεδονίας  Θεσσαλονίκης
# 4    2022        2022-07-16              Κεντρικής Μακεδονίας  Θεσσαλονίκης
# ..    ...               ...                               ...           ...
# 172  2022        2022-10-18                         Θεσσαλίας       Λάρισας
# 173  2022        2022-10-18  Ανατολικής Μακεδονίας και Θράκης        Δράμας
# 174  2022        2022-10-18                      Ιονίων Νήσων      Λευκάδας
# 175  2022        2022-10-25              Κεντρικής Μακεδονίας  Θεσσαλονίκης
# 176  2022        2022-11-22              Κεντρικής Μακεδονίας  Θεσσαλονίκης
#
#                         lau1  cases
# 0    Αμπελοκήπων - Μενεμένης      1
# 1                      Δέλτα      2
# 2                 Χαλκηδόνος      1
# 3                      Δέλτα      1
# 4                     Θέρμης      1
# ..                       ...    ...
# 172                Λαρισαίων      1
# 173                   Δράμας      1
# 174                 Λευκάδας      1
# 175      Κορδελιού - Ευόσμου      1
# 176               Καλαμαριάς      1
#
# [177 rows x 6 columns]

# %%
missingno.matrix(data)
# Out:
# <AxesSubplot:>

# %%
process_greek(data, 'nuts2')
process_greek(data, 'nuts3')
process_greek(data, 'lau1')

# %%
data
# Out:
#      year onset of symptoms                             nuts2         nuts3  \
# 0    2022        2022-07-12              κεντρικης μακεδονιας  θεσσαλονικης
# 1    2022        2022-07-19              κεντρικης μακεδονιας  θεσσαλονικης
# 2    2022        2022-07-19              κεντρικης μακεδονιας  θεσσαλονικης
# 3    2022        2022-07-16              κεντρικης μακεδονιας  θεσσαλονικης
# 4    2022        2022-07-16              κεντρικης μακεδονιας  θεσσαλονικης
# ..    ...               ...                               ...           ...
# 172  2022        2022-10-18                         θεσσαλιας       λαρισας
# 173  2022        2022-10-18  ανατολικης μακεδονιας και θρακης        δραμας
# 174  2022        2022-10-18                      ιονιων νησων      λευκαδας
# 175  2022        2022-10-25              κεντρικης μακεδονιας  θεσσαλονικης
# 176  2022        2022-11-22              κεντρικης μακεδονιας  θεσσαλονικης
#
#                       lau1  cases
# 0    αμπελοκηπων μενεμενης      1
# 1                    δελτα      2
# 2               χαλκηδονος      1
# 3                    δελτα      1
# 4                   θερμης      1
# ..                     ...    ...
# 172              λαρισαιων      1
# 173                 δραμας      1
# 174               λευκαδας      1
# 175      κορδελιου ευοσμου      1
# 176             καλαμαριας      1
#
# [177 rows x 6 columns]

# %%
data['day'] = data['onset of symptoms'].apply(lambda x : x.day)
data['month'] = data['onset of symptoms'].apply(lambda x : x.month)

# %%
data
# Out:
#      year onset of symptoms                             nuts2         nuts3  \
# 0    2022        2022-07-12              κεντρικης μακεδονιας  θεσσαλονικης
# 1    2022        2022-07-19              κεντρικης μακεδονιας  θεσσαλονικης
# 2    2022        2022-07-19              κεντρικης μακεδονιας  θεσσαλονικης
# 3    2022        2022-07-16              κεντρικης μακεδονιας  θεσσαλονικης
# 4    2022        2022-07-16              κεντρικης μακεδονιας  θεσσαλονικης
# ..    ...               ...                               ...           ...
# 172  2022        2022-10-18                         θεσσαλιας       λαρισας
# 173  2022        2022-10-18  ανατολικης μακεδονιας και θρακης        δραμας
# 174  2022        2022-10-18                      ιονιων νησων      λευκαδας
# 175  2022        2022-10-25              κεντρικης μακεδονιας  θεσσαλονικης
# 176  2022        2022-11-22              κεντρικης μακεδονιας  θεσσαλονικης
#
#                       lau1  cases  day  month
# 0    αμπελοκηπων μενεμενης      1   12      7
# 1                    δελτα      2   19      7
# 2               χαλκηδονος      1   19      7
# 3                    δελτα      1   16      7
# 4                   θερμης      1   16      7
# ..                     ...    ...  ...    ...
# 172              λαρισαιων      1   18     10
# 173                 δραμας      1   18     10
# 174               λευκαδας      1   18     10
# 175      κορδελιου ευοσμου      1   25     10
# 176             καλαμαριας      1   22     11
#
# [177 rows x 8 columns]

# %%
data = data.reindex(columns=['onset of symptoms', 'year', 'month', 'day', 'nuts2', 'nuts3', 'lau1', 'cases'])

# %%
data
# Out:
#     onset of symptoms  year  month  day                             nuts2  \
# 0          2022-07-12  2022      7   12              κεντρικης μακεδονιας
# 1          2022-07-19  2022      7   19              κεντρικης μακεδονιας
# 2          2022-07-19  2022      7   19              κεντρικης μακεδονιας
# 3          2022-07-16  2022      7   16              κεντρικης μακεδονιας
# 4          2022-07-16  2022      7   16              κεντρικης μακεδονιας
# ..                ...   ...    ...  ...                               ...
# 172        2022-10-18  2022     10   18                         θεσσαλιας
# 173        2022-10-18  2022     10   18  ανατολικης μακεδονιας και θρακης
# 174        2022-10-18  2022     10   18                      ιονιων νησων
# 175        2022-10-25  2022     10   25              κεντρικης μακεδονιας
# 176        2022-11-22  2022     11   22              κεντρικης μακεδονιας
#
#             nuts3                   lau1  cases
# 0    θεσσαλονικης  αμπελοκηπων μενεμενης      1
# 1    θεσσαλονικης                  δελτα      2
# 2    θεσσαλονικης             χαλκηδονος      1
# 3    θεσσαλονικης                  δελτα      1
# 4    θεσσαλονικης                 θερμης      1
# ..            ...                    ...    ...
# 172       λαρισας              λαρισαιων      1
# 173        δραμας                 δραμας      1
# 174      λευκαδας               λευκαδας      1
# 175  θεσσαλονικης      κορδελιου ευοσμου      1
# 176  θεσσαλονικης             καλαμαριας      1
#
# [177 rows x 8 columns]

# %%
data.to_csv("../data/GR_WNV_cases_2022_processed.csv", encoding = enc, index = False)

# %%
years = 2022
cases = data.cases.sum()

plt.figure(num = None, figsize = (15,8), facecolor='w', edgecolor='b')
#plt.bar(years, cases)
plt.barh(years, cases)

#ax.bar_label(bars)
#y_t = plt.xticks(np.arange(0, max(cases) + 10, step = 50), size = 14)
#x_t = plt.yticks(np.arange(min(years), max(years) + 1, step = 1), size = 14)
x_l  = plt.ylabel('Years', size = 18)
y_l =  plt.xlabel('Cases', size = 18)
title = plt.title('WNV Cases in Greece per Year', size = 22)

plt.text(cases+0.15, years-0.15, str(cases), size = 12)
ax = plt.gca()
ax.xaxis.grid(True)
plt.show()

# %%
nuts2 = data['nuts2'].drop_duplicates().sort_values().tolist()
cases = [data.query(f"nuts2 == '{nuts2_unit}'").cases.sum() for nuts2_unit in nuts2]

cases, nuts2 = zip(*sorted(zip(cases, nuts2)))

plt.figure(num = None, figsize = (14,5), facecolor='w', edgecolor='b')
plt.barh(nuts2, cases)

y_t = plt.xticks(np.arange(0, max(cases) + 100, step = 50), size = 14)
x_t = plt.yticks(nuts2, size = 14)
x_l  = plt.ylabel('NUTS2', size = 18)
y_l =  plt.xlabel('Cases', size = 18)
title = plt.title('WNV Cases in Greece per NUTS2 (2022)', size = 22)
for nuts2, case in zip(nuts2,cases):
    plt.text(case+0.15, nuts2, str(case), size = 14)
ax = plt.gca()
ax.xaxis.grid(True)
plt.show()
