# %%
import pandas as pd

enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 10

# %%
NUTS0 = 'GR'
NUTS2 = 'CMacedonia'
NUTS2_EL = 'κεντρικης μακεδονιας'

# %%
data = pd.read_csv(f'data/{NUTS0}_WNV_cases_2022_processed.csv', encoding = enc)
data.head(5)
# Out:
#   onset of symptoms  year  month  day                 nuts2         nuts3  \
# 0        2022-07-12  2022      7   12  κεντρικης μακεδονιας  θεσσαλονικης
# 1        2022-07-19  2022      7   19  κεντρικης μακεδονιας  θεσσαλονικης
# 2        2022-07-19  2022      7   19  κεντρικης μακεδονιας  θεσσαλονικης
# 3        2022-07-16  2022      7   16  κεντρικης μακεδονιας  θεσσαλονικης
# 4        2022-07-16  2022      7   16  κεντρικης μακεδονιας  θεσσαλονικης
#
#                     lau1  cases
# 0  αμπελοκηπων μενεμενης      1
# 1                  δελτα      2
# 2             χαλκηδονος      1
# 3                  δελτα      1
# 4                 θερμης      1

# %%
data.shape
# Out:
# (177, 8)

# %%
df = data[data['nuts2'].isin([NUTS2_EL])].copy()

# %%
df.reset_index(drop = True, inplace = True)

# %%
df
# Out:
#     onset of symptoms  year  month  day                 nuts2         nuts3  \
# 0          2022-07-12  2022      7   12  κεντρικης μακεδονιας  θεσσαλονικης
# 1          2022-07-19  2022      7   19  κεντρικης μακεδονιας  θεσσαλονικης
# 2          2022-07-19  2022      7   19  κεντρικης μακεδονιας  θεσσαλονικης
# 3          2022-07-16  2022      7   16  κεντρικης μακεδονιας  θεσσαλονικης
# 4          2022-07-16  2022      7   16  κεντρικης μακεδονιας  θεσσαλονικης
# ..                ...   ...    ...  ...                   ...           ...
# 143        2022-10-11  2022     10   11  κεντρικης μακεδονιας        πελλας
# 144        2022-10-11  2022     10   11  κεντρικης μακεδονιας       ημαθιας
# 145        2022-10-18  2022     10   18  κεντρικης μακεδονιας  θεσσαλονικης
# 146        2022-10-25  2022     10   25  κεντρικης μακεδονιας  θεσσαλονικης
# 147        2022-11-22  2022     11   22  κεντρικης μακεδονιας  θεσσαλονικης
#
#                       lau1  cases
# 0    αμπελοκηπων μενεμενης      1
# 1                    δελτα      2
# 2               χαλκηδονος      1
# 3                    δελτα      1
# 4                   θερμης      1
# ..                     ...    ...
# 143                 πελλας      1
# 144                βεροιας      1
# 145           θεσσαλονικης      1
# 146      κορδελιου ευοσμου      1
# 147             καλαμαριας      1
#
# [148 rows x 8 columns]

# %%
wnv_lau1_list = df['lau1'].drop_duplicates().sort_values().tolist()

# with open(f'data/{NUTS0}_WNV_{NUTS2}_lau1_processed.txt', 'w', encoding=enc) as f:
#     for item in wnv_lau1_list:
#         f.write("%s\n" % item)
  
print(f"Number of LAU1 Units in {NUTS2} (from cases): {len(wnv_lau1_list)}")
# Out:
# Number of LAU1 Units in CMacedonia (from cases): 34

# %%
df['period'] = df.apply(lambda row: 1 if (row['day']>=1 and row['day']<=15) else 2, axis = 1)
df['dt_placement'] = df.apply(lambda row: f"{row['year']:04}-{row['month']:02}-{1 if row['period'] == 1 else 16:02}", axis = 1)

df['dt_placement']= pd.to_datetime(df['dt_placement'])
#df['case'] = 1

# %%
df
# Out:
#     onset of symptoms  year  month  day                 nuts2         nuts3  \
# 0          2022-07-12  2022      7   12  κεντρικης μακεδονιας  θεσσαλονικης
# 1          2022-07-19  2022      7   19  κεντρικης μακεδονιας  θεσσαλονικης
# 2          2022-07-19  2022      7   19  κεντρικης μακεδονιας  θεσσαλονικης
# 3          2022-07-16  2022      7   16  κεντρικης μακεδονιας  θεσσαλονικης
# 4          2022-07-16  2022      7   16  κεντρικης μακεδονιας  θεσσαλονικης
# ..                ...   ...    ...  ...                   ...           ...
# 143        2022-10-11  2022     10   11  κεντρικης μακεδονιας        πελλας
# 144        2022-10-11  2022     10   11  κεντρικης μακεδονιας       ημαθιας
# 145        2022-10-18  2022     10   18  κεντρικης μακεδονιας  θεσσαλονικης
# 146        2022-10-25  2022     10   25  κεντρικης μακεδονιας  θεσσαλονικης
# 147        2022-11-22  2022     11   22  κεντρικης μακεδονιας  θεσσαλονικης
#
#                       lau1  cases  period dt_placement
# 0    αμπελοκηπων μενεμενης      1       1   2022-07-01
# 1                    δελτα      2       2   2022-07-16
# 2               χαλκηδονος      1       2   2022-07-16
# 3                    δελτα      1       2   2022-07-16
# 4                   θερμης      1       2   2022-07-16
# ..                     ...    ...     ...          ...
# 143                 πελλας      1       1   2022-10-01
# 144                βεροιας      1       1   2022-10-01
# 145           θεσσαλονικης      1       2   2022-10-16
# 146      κορδελιου ευοσμου      1       2   2022-10-16
# 147             καλαμαριας      1       2   2022-11-16
#
# [148 rows x 10 columns]

# %%
df.drop(columns = ['onset of symptoms', 'day', 'nuts3', 'period'], inplace = True)

# %%
df = df[['month', 'year', 'lau1', 'nuts2', 'dt_placement', 'cases']]

# %%
df
# Out:
#      month  year                   lau1                 nuts2 dt_placement  \
# 0        7  2022  αμπελοκηπων μενεμενης  κεντρικης μακεδονιας   2022-07-01
# 1        7  2022                  δελτα  κεντρικης μακεδονιας   2022-07-16
# 2        7  2022             χαλκηδονος  κεντρικης μακεδονιας   2022-07-16
# 3        7  2022                  δελτα  κεντρικης μακεδονιας   2022-07-16
# 4        7  2022                 θερμης  κεντρικης μακεδονιας   2022-07-16
# ..     ...   ...                    ...                   ...          ...
# 143     10  2022                 πελλας  κεντρικης μακεδονιας   2022-10-01
# 144     10  2022                βεροιας  κεντρικης μακεδονιας   2022-10-01
# 145     10  2022           θεσσαλονικης  κεντρικης μακεδονιας   2022-10-16
# 146     10  2022      κορδελιου ευοσμου  κεντρικης μακεδονιας   2022-10-16
# 147     11  2022             καλαμαριας  κεντρικης μακεδονιας   2022-11-16
#
#      cases
# 0        1
# 1        2
# 2        1
# 3        1
# 4        1
# ..     ...
# 143      1
# 144      1
# 145      1
# 146      1
# 147      1
#
# [148 rows x 6 columns]

# %%
case_months = df['month'].drop_duplicates().sort_values().tolist()
case_months
# Out:
# [7, 8, 9, 10, 11]

# %%
case_years = df['year'].drop_duplicates().sort_values().tolist()
case_years
# Out:
# [2022]

# %%
# with open(f'data/{NUTS0}_WNV_{NUTS2}_cases_dates.txt', 'w', encoding=enc) as f:

#     f.write("%s: " % 'months')
#     for item in case_months:
#         f.write("%s, " % item)

#     f.write("\n")

#     f.write("%s: " % 'years')
#     for item in case_years:
#         f.write("%s, " % item)

# %%
## Creating DataFrame to hold negative examples

df_timeline = pd.DataFrame(columns = ['lau1', 'nuts2', 'dt_placement', 'case'])

for municipality in df['lau1'].drop_duplicates().sort_values():
    for month in range (7,12):
        df_timeline = df_timeline.append({'lau1' : municipality, 'nuts2' : NUTS2_EL, 'dt_placement' : f"{2022:04}-{month:02}-{1:02}", 'case' : 0}, ignore_index = True)
        df_timeline = df_timeline.append({'lau1' : municipality, 'nuts2' : NUTS2_EL, 'dt_placement' : f"{2022:04}-{month:02}-{16:02}", 'case' : 0}, ignore_index = True)
            
df_timeline
# Out:
#              lau1                 nuts2 dt_placement case
# 0    αλεξανδρειας  κεντρικης μακεδονιας   2022-07-01    0
# 1    αλεξανδρειας  κεντρικης μακεδονιας   2022-07-16    0
# 2    αλεξανδρειας  κεντρικης μακεδονιας   2022-08-01    0
# 3    αλεξανδρειας  κεντρικης μακεδονιας   2022-08-16    0
# 4    αλεξανδρειας  κεντρικης μακεδονιας   2022-09-01    0
# ..            ...                   ...          ...  ...
# 335  ωραιοκαστρου  κεντρικης μακεδονιας   2022-09-16    0
# 336  ωραιοκαστρου  κεντρικης μακεδονιας   2022-10-01    0
# 337  ωραιοκαστρου  κεντρικης μακεδονιας   2022-10-16    0
# 338  ωραιοκαστρου  κεντρικης μακεδονιας   2022-11-01    0
# 339  ωραιοκαστρου  κεντρικης μακεδονιας   2022-11-16    0
#
# [340 rows x 4 columns]

# %%
df_timeline['dt_placement']= pd.to_datetime(df_timeline['dt_placement'])

# %%
df.reset_index(inplace = True, drop=True)
df_timeline.reset_index(inplace = True, drop=True)

# %%
## Add cases to negative examples DataFrame

#iterrate DataFrame with cases by row
for index, row in df.iterrows():
    #find index at DataFrame with negative examples where location and date matches the DataFrame with cases
    idx = df_timeline.index[(df_timeline['lau1']==row['lau1']) & (df_timeline['dt_placement']==row['dt_placement'])]
    #get the previous case number using index
    previous_case = df_timeline._get_value(idx.values[0], 'case')
    #add 1 (one) to column case
    df_timeline.at[idx.values[0],'case'] = previous_case+1

# %%
df_timeline['case'].value_counts().sort_index()
# Out:
# 0    234
# 1     69
# 2     32
# 3      5
# Name: case, dtype: int64

# %%
df_timeline
# Out:
#              lau1                 nuts2 dt_placement case
# 0    αλεξανδρειας  κεντρικης μακεδονιας   2022-07-01    0
# 1    αλεξανδρειας  κεντρικης μακεδονιας   2022-07-16    0
# 2    αλεξανδρειας  κεντρικης μακεδονιας   2022-08-01    1
# 3    αλεξανδρειας  κεντρικης μακεδονιας   2022-08-16    3
# 4    αλεξανδρειας  κεντρικης μακεδονιας   2022-09-01    2
# ..            ...                   ...          ...  ...
# 335  ωραιοκαστρου  κεντρικης μακεδονιας   2022-09-16    0
# 336  ωραιοκαστρου  κεντρικης μακεδονιας   2022-10-01    0
# 337  ωραιοκαστρου  κεντρικης μακεδονιας   2022-10-16    0
# 338  ωραιοκαστρου  κεντρικης μακεδονιας   2022-11-01    0
# 339  ωραιοκαστρου  κεντρικης μακεδονιας   2022-11-16    0
#
# [340 rows x 4 columns]

# %%
df_timeline.case.sum()
# Out:
# 148

# %%
df_timeline.to_csv(f"data/{NUTS0}_{NUTS2}_WNV_Timeline_2022.csv", encoding = enc, index = False)
