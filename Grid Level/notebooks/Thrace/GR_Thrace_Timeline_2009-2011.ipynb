# %% [markdown]
# ## Creates the **Timeline** for a specific region by using the Grid File and the required dates ##

# %%
import pandas as pd
from datetime import date, timedelta

import random
import geopandas as gpd
import numpy as np

import sys

sys.path.insert(0, "../../../Modules")

from utils import *

enc = 'utf-8'
dec = 'greek8'
random.seed(0)

# %%
NUTS0 = 'GR'
NUTS2 = 'Thrace'

# %%
gr_grid = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_GRID.csv', encoding = enc)
gr_grid
# Out:
#       cell_number NUTS2_ID         x         y
# 0               0     EL51  23.65882  41.33542
# 1               1     EL51  23.65882  41.35339
# 2               2     EL51  23.65882  41.37135
# 3               3     EL51  23.68241  41.33542
# 4               4     EL51  23.68241  41.35339
# ...           ...      ...       ...       ...
# 3261         3261     EL51  26.58397  41.49712
# 3262         3262     EL51  26.60756  41.35339
# 3263         3263     EL51  26.60756  41.37135
# 3264         3264     EL51  26.60756  41.38932
# 3265         3265     EL51  26.60756  41.40729
#
# [3266 rows x 4 columns]

# %%
## start and end date is defined from available epidemiological file

# %%
start = start_dt = date(2021, 1, 1)
end = end_dt = date(2023, 12, 31)
delta = timedelta(days=1)

# %%
dates = []

while start_dt <= end_dt:
    dates.append(start_dt.isoformat())
    start_dt += delta

# %%
print('Dates between', start, 'and', end)
print(dates)
# Out:
# Dates between 2021-01-01 and 2023-12-31
# ['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04', '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08', '2021-01-09', '2021-01-10', '2021-01-11', '2021-01-12', '2021-01-13', '2021-01-14', '2021-01-15', '2021-01-16', '2021-01-17', '2021-01-18', '2021-01-19', '2021-01-20', '2021-01-21', '2021-01-22', '2021-01-23', '2021-01-24', '2021-01-25', '2021-01-26', '2021-01-27', '2021-01-28', '2021-01-29', '2021-01-30', '2021-01-31', '2021-02-01', '2021-02-02', '2021-02-03', '2021-02-04', '2021-02-05', '2021-02-06', '2021-02-07', '2021-02-08', '2021-02-09', '2021-02-10', '2021-02-11', '2021-02-12', '2021-02-13', '2021-02-14', '2021-02-15', '2021-02-16', '2021-02-17', '2021-02-18', '2021-02-19', '2021-02-20', '2021-02-21', '2021-02-22', '2021-02-23', '2021-02-24', '2021-02-25', '2021-02-26', '2021-02-27', '2021-02-28', '2021-03-01', '2021-03-02', '2021-03-03', '2021-03-04', '2021-03-05', '2021-03-06', '2021-03-07', '2021-03-08', '2021-03-09', '2021-03-10', '2021-03-11', '2021-03-12', '2021-03-13', '2021-03-14', '2021-03-15', '2021-03-16', '2021-03-17', '2021-03-18', '2021-03-19', '2021-03-20', '2021-03-21', '2021-03-22', '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26', '2021-03-27', '2021-03-
-09-13', '2021-09-14', '2021-09-15', '2021-09-16', '2021-09-17', '2021-09-18', '2021-09-19', '2021-09-20', '2021-09-21', '2021-09-22', '2021-09-23', '2021-09-24', '2021-09-25', '2021-09-26', '2021-09-27', '2021-09-28', '2021-09-29', '2021-09-30', '2021-10-01', '2021-10-02', '2021-10-03', '2021-10-04', '2021-10-05', '2021-10-06', '2021-10-07', '2021-10-08', '2021-10-09', '2021-10-10', '2021-10-11', '2021-10-12', '2021-10- ...

# %%
len(dates)
# Out:
# 1095

# %%
gr_timeline = pd.DataFrame()

# %%
data = []
for index, row in gr_grid.iterrows():
    for date in dates:
        data.append({'x': row['x'], 
                     'y': row['y'], 
                     'cell_number': row['cell_number'],  
                     'dt_placement': date,
                     'NUTS2_ID': row['NUTS2_ID'],
                     })

gr_timeline = pd.DataFrame(data)

# %%
gr_timeline
# Out:
#                 x         y  cell_number dt_placement NUTS2_ID
# 0        23.65882  41.33542            0   2021-01-01     EL51
# 1        23.65882  41.33542            0   2021-01-02     EL51
# 2        23.65882  41.33542            0   2021-01-03     EL51
# 3        23.65882  41.33542            0   2021-01-04     EL51
# 4        23.65882  41.33542            0   2021-01-05     EL51
# ...           ...       ...          ...          ...      ...
# 3576265  26.60756  41.40729         3265   2023-12-27     EL51
# 3576266  26.60756  41.40729         3265   2023-12-28     EL51
# 3576267  26.60756  41.40729         3265   2023-12-29     EL51
# 3576268  26.60756  41.40729         3265   2023-12-30     EL51
# 3576269  26.60756  41.40729         3265   2023-12-31     EL51
#
# [3576270 rows x 5 columns]

# %%
gr_timeline['dt_placement'] = pd.to_datetime(gr_timeline['dt_placement'])

# %%
gr_timeline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3576270 entries, 0 to 3576269
# Data columns (total 5 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   x             float64
#  1   y             float64
#  2   cell_number   int64
#  3   dt_placement  datetime64[ns]
#  4   NUTS2_ID      object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 136.4+ MB

# %%
gr_timeline.to_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Timeline_GRID_2021-2023.csv', index = False)

# %%
gr_timeline
# Out:
#                 x         y  cell_number dt_placement NUTS2_ID
# 0        23.65882  41.33542            0   2021-01-01     EL51
# 1        23.65882  41.33542            0   2021-01-02     EL51
# 2        23.65882  41.33542            0   2021-01-03     EL51
# 3        23.65882  41.33542            0   2021-01-04     EL51
# 4        23.65882  41.33542            0   2021-01-05     EL51
# ...           ...       ...          ...          ...      ...
# 3576265  26.60756  41.40729         3265   2023-12-27     EL51
# 3576266  26.60756  41.40729         3265   2023-12-28     EL51
# 3576267  26.60756  41.40729         3265   2023-12-29     EL51
# 3576268  26.60756  41.40729         3265   2023-12-30     EL51
# 3576269  26.60756  41.40729         3265   2023-12-31     EL51
#
# [3576270 rows x 5 columns]
