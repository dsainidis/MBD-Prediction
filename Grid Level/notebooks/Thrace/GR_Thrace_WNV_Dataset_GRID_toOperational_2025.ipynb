# %% [markdown]
# ## Add BioVariables to the **Final Dataset** and convert to **Annual** ##

# %%
import pandas as pd
import geopandas as gpd

import missingno

from sklearn.impute import KNNImputer
import sys

sys.path.insert(0, "../../../Modules")

from utils import *


enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 20
#pd.options.display.float_format = lambda x: '%.6f' % x

# %%
NUTS0 = 'GR'
NUTS2 = 'Thrace'
MONTH = 8

# %%
years = range(2024, 2026)

# %%
datasets = []

for year in years:
    df = pd.read_csv(f"../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Dataset_GRID_{year}.csv", encoding=enc)
    print(f'Year: {year} | {df.shape}')
    datasets.append(df)
# Out:
# Year: 2024 | (39192, 102)
# Year: 2025 | (26128, 102)

# %%
# dataset_monthly = pd.read_csv(f"../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Dataset_GRID_2016_2018.csv", encoding = enc)
dataset_monthly = pd.concat(datasets, ignore_index=True, axis = 0)
dataset_monthly
# Out:
#        cell_number dt_placement NUTS1_ID     NUTS1_NAME NUTS2_ID  \
# 0                0      2024-01      EL5  βορεια ελλαδα     EL51
# 1                0      2024-02      EL5  βορεια ελλαδα     EL51
# 2                0      2024-03      EL5  βορεια ελλαδα     EL51
# 3                0      2024-04      EL5  βορεια ελλαδα     EL51
# 4                0      2024-05      EL5  βορεια ελλαδα     EL51
# ...            ...          ...      ...            ...      ...
# 65315         3265      2025-04      EL5  βορεια ελλαδα     EL51
# 65316         3265      2025-05      EL5  βορεια ελλαδα     EL51
# 65317         3265      2025-06      EL5  βορεια ελλαδα     EL51
# 65318         3265      2025-07      EL5  βορεια ελλαδα     EL51
# 65319         3265      2025-08      EL5  βορεια ελλαδα     EL51
#
#                        NUTS2_NAME NUTS3_ID NUTS3_NAME         LAU1_NAME  \
# 0      ανατολικη μακεδονια, θρακη    EL514      δραμα  κατω νευροκοπιου
# 1      ανατολικη μακεδονια, θρακη    EL514      δραμα  κατω νευροκοπιου
# 2      ανατολικη μακεδονια, θρακη    EL514      δραμα  κατω νευροκοπιου
# 3      ανατολικη μακεδονια, θρακη    EL514      δραμα  κατω νευροκοπιου
# 4      ανατολικη μακεδονια, θρακη    EL514      δραμα  κατω νευροκοπιου
# ...                           ...      ...        ...               ...
# 65315  ανατολικη μακεδονια, θρακη    EL511      εβρος      διδυμοτειχου
# 65316  ανατολικη μακεδονια, θρακη    EL511      εβρος      διδυμοτειχου
# 65317  ανατολικη μακεδονια, θρακη    EL511      εβρος      διδυμοτειχου
# 65318  ανατολικη μακεδονια, θρακη    EL511      εβρος      διδυμοτειχου
# 65319  ανατολικη μακεδονια, θρακη    EL511      εβρος      διδυμοτειχου
#
#               x         y  MOUNT_TYPE  URBN_TYPE  COAST_TYPE  year  month  \
# 0      23.65882  41.33542           2          2           2  2024      1
# 1      23.65882  41.33542           2          2           2  2024      2
# 2      23.65882  41.33542           2          2           2  2024      3
# 3      23.65882  41.33542           2          2           2  2024      4
# 4      23.65882  41.33542           2          2           2  2024      5
# ...         ...       ...         ...        ...         ...   ...    ...
# 65315  26.60756  41.40729           4          2           1  2025      4
# 65316  26.60756  41.40729           4          2           1  2025      5
# 65317  26.60756  41.40729           4          2           1  2025      6
# 65318  26.60756  41.40729           4          2           1  2025      7
# 65319  26.60756  41.40729           4          2           1  2025      8
#
#            ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  \
# 0      0.158323  0.215487 -0.000889 -0.215487   0.199381   0.139230
# 1      0.216415  0.135713 -0.141988 -0.135713   0.201202   0.109560
# 2      0.288020  0.020938 -0.269782 -0.020938   0.271464  -0.014406
# 3      0.415067  0.090004 -0.372324 -0.090004   0.404440   0.054322
# 4      0.683583  0.336109 -0.556243 -0.336109   0.697113   0.322002
# ...         ...       ...       ...       ...        ...        ...
# 65315  0.742663  0.462529 -0.283619 -0.462529   0.627130   0.352200
# 65316  0.640442  0.340811 -0.309375 -0.340811   0.589446   0.300426
# 65317  0.381715  0.080804 -0.339803 -0.080804   0.418554   0.105143
# 65318  0.198721 -0.078176 -0.334130  0.078176   0.297327  -0.002982
# 65319       NaN       NaN       NaN       NaN        NaN        NaN
#
#        ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  \
# 0      -0.122525  -0.139230  0.065784  0.085729  0.100493  0.085729
# 1      -0.165407  -0.109560  0.044973  0.057022  0.058943  0.057022
# 2      -0.261725   0.014406  0.040399  0.034564  0.050305  0.034564
# 3      -0.369121  -0.054322  0.032283  0.029452  0.039463  0.029452
# 4      -0.570011  -0.322002  0.037963  0.025647  0.036570  0.025647
# ...          ...        ...       ...       ...       ...       ...
# 65315  -0.265129  -0.352200  0.083782  0.086808  0.024807  0.086808
# 65316  -0.294487  -0.300426  0.104357  0.105354  0.029402  0.105354
# 65317  -0.347862  -0.105143  0.053095  0.058511  0.036080  0.058511
# 65318  -0.369870   0.002982  0.060244  0.052322  0.028728  0.052322
# 65319        NaN        NaN       NaN       NaN       NaN       NaN
#
#        lst_day_mean  lst_night_mean   lst_mean  lst_jan_day_mean  \
# 0          2.144194       -1.550645   0.296774          2.144194
# 1          8.146552        1.583103   4.864828          2.144194
# 2         11.033226        1.028065   6.030645          2.144194
# 3         20.928621        7.520345  14.224483          2.144194
# 4         18.547931        9.786552  14.167241          2.144194
# ...             ...             ...        ...               ...
# 65315     20.703333        7.435217  14.162609          8.861034
# 65316     29.526000       11.434000  20.480000          8.861034
# 65317     32.945200       19.544615  26.283200          8.861034
# 65318     37.454138       23.335517  30.394828          8.861034
# 65319           NaN             NaN        NaN          8.861034
#
#        lst_feb_day_mean  lst_mar_day_mean  lst_apr_day_mean  \
# 0              8.146552         11.033226         20.928621
# 1              8.146552         11.033226         20.928621
# 2              8.146552         11.033226         20.928621
# 3              8.146552         11.033226         20.928621
# 4              8.146552         11.033226         20.928621
# ...                 ...               ...               ...
# 65315          6.318800         16.690000         20.703333
# 65316          6.318800         16.690000         20.703333
# 65317          6.318800         16.690000         20.703333
# 65318          6.318800         16.690000         20.703333
# 65319          6.318800         16.690000         20.703333
#
#        lst_jan_night_mean  lst_feb_night_mean  lst_mar_night_mean  \
# 0               -1.550645            1.583103            1.028065
# 1               -1.550645            1.583103            1.028065
# 2               -1.550645            1.583103            1.028065
# 3               -1.550645            1.583103            1.028065
# 4               -1.550645            1.583103            1.028065
# ...                   ...                 ...                 ...
# 65315            3.355806           -2.536429            3.741034
# 65316            3.355806           -2.536429            3.741034
# 65317            3.355806           -2.536429            3.741034
# 65318            3.355806           -2.536429            3.741034
# 65319            3.355806           -2.536429            3.741034
#
#        lst_apr_night_mean  lst_jan_mean  lst_feb_mean  lst_mar_mean  \
# 0                7.520345      0.296774      4.864828      6.030645
# 1                7.520345      0.296774      4.864828      6.030645
# 2                7.520345      0.296774      4.864828      6.030645
# 3                7.520345      0.296774      4.864828      6.030645
# 4                7.520345      0.296774      4.864828      6.030645
# ...                   ...           ...           ...           ...
# 65315            7.435217      6.108420      1.891186     10.215517
# 65316            7.435217      6.108420      1.891186     10.215517
# 65317            7.435217      6.108420      1.891186     10.215517
# 65318            7.435217      6.108420      1.891186     10.215517
# 65319            7.435217      6.108420      1.891186     10.215517
#
#        lst_apr_mean  rainfall_mean  acc_rainfall_1week  acc_rainfall_2week  \
# 0         14.224483       1.339776            0.272635           13.341247
# 1         14.224483       0.422918            4.489590            4.490472
# 2         14.224483       1.257594           11.542164           12.303511
# 3         14.224483       1.493143            3.880080           44.668190
# 4         14.224483       1.810461            0.000000            1.398306
# ...             ...            ...                 ...                 ...
# 65315     14.069275       1.398020            0.313529            0.313529
# 65316     14.069275       0.049575            0.000000            0.000000
# 65317     14.069275       0.004990            0.144706            0.144706
# 65318     14.069275       0.160784            0.000000            4.984314
# 65319     14.069275       0.000000            0.000000            0.160784
#
#        acc_rainfall_month  acc_rainfall_jan  rainfall_acc  lst_min  lst_max  \
# 0               41.531526         41.533057     41.533057   -7.190    7.430
# 1               12.264610         53.797667     12.264610   -4.870   12.090
# 2               38.158617         92.783077     38.985411   -2.250   22.230
# 3               44.794301        137.577378     44.794301    1.490   24.250
# 4               56.124294        193.701673     56.124294    6.730   22.590
# ...                   ...               ...           ...      ...      ...
# 65315           41.940587        192.024701     41.940587   -0.730   29.130
# 65316            0.297451        192.322152      0.297451    8.050   30.870
# 65317            0.144706        192.466858      0.144706   16.950   38.050
# 65318            4.984314        197.451171      4.984314   19.770   40.250
# 65319            4.984314        197.451171      0.000000   19.874   41.506
#
#        distance_to_coast  distance_to_river  slope_mean_1km  aspect_mean_200m  \
# 0           13573.304209         975.115126               7        273.211376
# 1           13573.304209         975.115126               7        273.211376
# 2           13573.304209         975.115126               7        273.211376
# 3           13573.304209         975.115126               7        273.211376
# 4           13573.304209         975.115126               7        273.211376
# ...                  ...                ...             ...               ...
# 65315        8856.412678         737.727483               2        128.767263
# 65316        8856.412678         737.727483               2        128.767263
# 65317        8856.412678         737.727483               2        128.767263
# 65318        8856.412678         737.727483               2        128.767263
# 65319        8856.412678         737.727483               2        128.767263
#
#        elevation_mean_1km  hillshade_mean_1km  fs_area_1km  flow_accu_200m  \
# 0             1038.457075          164.099283          0.0        4.925067
# 1             1038.457075          164.099283          0.0        4.925067
# 2             1038.457075          164.099283          0.0        4.925067
# 3             1038.457075          164.099283          0.0        4.925067
# 4             1038.457075          164.099283          0.0        4.925067
# ...                   ...                 ...          ...             ...
# 65315           22.108898          179.985394          0.0        1.589066
# 65316           22.108898          179.985394          0.0        1.589066
# 65317           22.108898          179.985394          0.0        1.589066
# 65318           22.108898          179.985394          0.0        1.589066
# 65319           22.108898          179.985394          0.0        1.589066
#
#        lc_prop1  lc_prop1_assessment  lc_prop2  lc_prop2_assessment  lc_prop3  \
# 0            14                 98.0        10                 99.0        10
# 1            14                 98.0        10                 99.0        10
# 2            14                 98.0        10                 99.0        10
# 3            14                 98.0        10                 99.0        10
# 4            14                 98.0        10                 99.0        10
# ...         ...                  ...       ...                  ...       ...
# 65315        31                 99.0        36                 99.0        30
# 65316        31                 99.0        36                 99.0        30
# 65317        31                 99.0        36                 99.0        30
# 65318        31                 99.0        36                 99.0        30
# 65319        31                 99.0        36                 99.0        30
#
#        lc_prop3_assessment  lc_type1  lc_type2  lc_type3  lc_type4  lc_type5  \
# 0                     99.0         4         4         6         4         4
# 1                     99.0         4         4         6         4         4
# 2                     99.0         4         4         6         4         4
# 3                     99.0         4         4         6         4         4
# 4                     99.0         4         4         6         4         4
# ...                    ...       ...       ...       ...       ...       ...
# 65315                 99.0        12        12         3         5         8
# 65316                 99.0        12        12         3         5         8
# 65317                 99.0        12        12         3         5         8
# 65318                 99.0        12        12         3         5         8
# 65319                 99.0        12        12         3         5         8
#
#        lw  qc    bio1  bio2       bio3         bio4  bio5  bio6  bio7  bio8  \
# 0       2   0  11.750  17.5  41.666667   815.893264  35.0  -7.0  42.0  20.5
# 1       2   0  11.750  17.5  41.666667   815.893264  35.0  -7.0  42.0  20.5
# 2       2   0  11.750  17.5  41.666667   815.893264  35.0  -7.0  42.0  20.5
# 3       2   0  11.750  17.5  41.666667   815.893264  35.0  -7.0  42.0  20.5
# 4       2   0  11.750  17.5  41.666667   815.893264  35.0  -7.0  42.0  20.5
# ...    ..  ..     ...   ...        ...          ...   ...   ...   ...   ...
# 65315   2   0  17.625  21.5  45.744681  1044.970950  41.0  -6.0  47.0   9.5
# 65316   2   0  17.625  21.5  45.744681  1044.970950  41.0  -6.0  47.0   9.5
# 65317   2   0  17.625  21.5  45.744681  1044.970950  41.0  -6.0  47.0   9.5
# 65318   2   0  17.625  21.5  45.744681  1044.970950  41.0  -6.0  47.0   9.5
# 65319   2   0  17.625  21.5  45.744681  1044.970950  41.0  -6.0  47.0   9.5
#
#             bio9      bio10     bio11  bio12  bio13  bio14       bio15  bio16  \
# 0       6.000000  22.500000  1.833333  414.0  118.0    0.0   99.073270  178.0
# 1       6.000000  22.500000  1.833333  414.0  118.0    0.0   99.073270  178.0
# 2       6.000000  22.500000  1.833333  414.0  118.0    0.0   99.073270  178.0
# 3       6.000000  22.500000  1.833333  414.0  118.0    0.0   99.073270  178.0
# 4       6.000000  22.500000  1.833333  414.0  118.0    0.0   99.073270  178.0
# ...          ...        ...       ...    ...    ...    ...         ...    ...
# 65315  25.166667  28.833333  7.000000  194.0  130.0    0.0  177.603846  179.0
# 65316  25.166667  28.833333  7.000000  194.0  130.0    0.0  177.603846  179.0
# 65317  25.166667  28.833333  7.000000  194.0  130.0    0.0  177.603846  179.0
# 65318  25.166667  28.833333  7.000000  194.0  130.0    0.0  177.603846  179.0
# 65319  25.166667  28.833333  7.000000  194.0  130.0    0.0  177.603846  179.0
#
#        bio17  bio18  bio19  M_Y_LT15  M_Y15-64  M_Y_GE65  M_TOTAL  F_Y_LT15  \
# 0       45.0  118.0   86.0    5775.0   27304.0    9999.0  43078.0    5348.0
# 1       45.0  118.0   86.0    5775.0   27304.0    9999.0  43078.0    5348.0
# 2       45.0  118.0   86.0    5775.0   27304.0    9999.0  43078.0    5348.0
# 3       45.0  118.0   86.0    5775.0   27304.0    9999.0  43078.0    5348.0
# 4       45.0  118.0   86.0    5775.0   27304.0    9999.0  43078.0    5348.0
# ...      ...    ...    ...       ...       ...       ...      ...       ...
# 65315    4.0    4.0  149.0       NaN       NaN       NaN      NaN       NaN
# 65316    4.0    4.0  149.0       NaN       NaN       NaN      NaN       NaN
# 65317    4.0    4.0  149.0       NaN       NaN       NaN      NaN       NaN
# 65318    4.0    4.0  149.0       NaN       NaN       NaN      NaN       NaN
# 65319    4.0    4.0  149.0       NaN       NaN       NaN      NaN       NaN
#
#        F_Y15-64  F_Y_GE65  F_TOTAL  MIO_EUR  L_TOTAL  UNL_TOTAL
# 0       25915.0   13125.0  44388.0      NaN      NaN        NaN
# 1       25915.0   13125.0  44388.0      NaN      NaN        NaN
# 2       25915.0   13125.0  44388.0      NaN      NaN        NaN
# 3       25915.0   13125.0  44388.0      NaN      NaN        NaN
# 4       25915.0   13125.0  44388.0      NaN      NaN        NaN
# ...         ...       ...      ...      ...      ...        ...
# 65315       NaN       NaN      NaN      NaN      NaN        NaN
# 65316       NaN       NaN      NaN      NaN      NaN        NaN
# 65317       NaN       NaN      NaN      NaN      NaN        NaN
# 65318       NaN       NaN      NaN      NaN      NaN        NaN
# 65319       NaN       NaN      NaN      NaN      NaN        NaN
#
# [65320 rows x 102 columns]

# %%
# dataset_monthly.cases.sum()

# %%
missingno.matrix(dataset_monthly)
# Out:
# <Axes: >

# %%
missing = describe_dataframe(dataset_monthly, remove_zeros=True)
missing
# Out:
#         Column   Missing
# 16        ndvi   33.2563
# 17        ndmi   33.2563
# 18        ndwi   33.2563
# 19        ndbi   33.2563
# 20   ndvi_mean   31.3074
# ..         ...       ...
# 97    F_Y_GE65   40.0000
# 98     F_TOTAL   40.0000
# 99     MIO_EUR  100.0000
# 100    L_TOTAL  100.0000
# 101  UNL_TOTAL  100.0000
#
# [41 rows x 2 columns]

# %%
all_columns = dataset_monthly.columns.to_list()

# %%
len(dataset_monthly.columns)
# Out:
# 102

# %%
desired_order = ['dt_placement','NUTS2_ID','NUTS2_NAME','NUTS3_ID','NUTS3_NAME','LAU1_NAME', 'cell_number', 'x','y','month','year',
 'ndvi','ndmi','ndwi','ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std','ndmi_std','ndwi_std','ndbi_std',
 'lst_day_mean','lst_jan_day_mean','lst_feb_day_mean','lst_mar_day_mean','lst_apr_day_mean',
 'lst_night_mean','lst_jan_night_mean','lst_feb_night_mean','lst_mar_night_mean','lst_apr_night_mean',
 'lst_mean','lst_jan_mean','lst_feb_mean','lst_mar_mean','lst_apr_mean','lst_min','lst_max',
 'rainfall_mean','acc_rainfall_1week','acc_rainfall_2week','acc_rainfall_month','acc_rainfall_jan',
 'bio1','bio2','bio3','bio4','bio5','bio6','bio7','bio8','bio9','bio10','bio11','bio12','bio13','bio14','bio15','bio16','bio17','bio18','bio19',
 'distance_to_coast','distance_to_river','slope_mean_1km','aspect_mean_200m','elevation_mean_1km','hillshade_mean_1km','fs_area_1km','flow_accu_200m',
 'lc_prop1','lc_prop1_assessment','lc_prop2','lc_prop2_assessment','lc_prop3','lc_prop3_assessment','lc_type1','lc_type2','lc_type3','lc_type4','lc_type5','lw','qc',
 'M_Y_LT15','M_Y15-64','M_Y_GE65','M_TOTAL','F_Y_LT15','F_Y15-64','F_Y_GE65','F_TOTAL','MIO_EUR','L_TOTAL','UNL_TOTAL',
 'MOUNT_TYPE', 'URBN_TYPE', 'COAST_TYPE',
 ]

# %%
len(desired_order)
# Out:
# 99

# %%
diff1 = set(desired_order) - set(all_columns)
diff2 = set(all_columns) - set(desired_order)

# Combine the differences
result = list(diff1.union(diff2))

# %%
result
# Out:
# ['rainfall_acc', 'NUTS1_NAME', 'NUTS1_ID']

# %%
dataset_monthly = dataset_monthly[desired_order].copy()

# %%
dataset_monthly
# Out:
#       dt_placement NUTS2_ID                  NUTS2_NAME NUTS3_ID NUTS3_NAME  \
# 0          2024-01     EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα
# 1          2024-02     EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα
# 2          2024-03     EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα
# 3          2024-04     EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα
# 4          2024-05     EL51  ανατολικη μακεδονια, θρακη    EL514      δραμα
# ...            ...      ...                         ...      ...        ...
# 65315      2025-04     EL51  ανατολικη μακεδονια, θρακη    EL511      εβρος
# 65316      2025-05     EL51  ανατολικη μακεδονια, θρακη    EL511      εβρος
# 65317      2025-06     EL51  ανατολικη μακεδονια, θρακη    EL511      εβρος
# 65318      2025-07     EL51  ανατολικη μακεδονια, θρακη    EL511      εβρος
# 65319      2025-08     EL51  ανατολικη μακεδονια, θρακη    EL511      εβρος
#
#               LAU1_NAME  cell_number         x         y  month  year  \
# 0      κατω νευροκοπιου            0  23.65882  41.33542      1  2024
# 1      κατω νευροκοπιου            0  23.65882  41.33542      2  2024
# 2      κατω νευροκοπιου            0  23.65882  41.33542      3  2024
# 3      κατω νευροκοπιου            0  23.65882  41.33542      4  2024
# 4      κατω νευροκοπιου            0  23.65882  41.33542      5  2024
# ...                 ...          ...       ...       ...    ...   ...
# 65315      διδυμοτειχου         3265  26.60756  41.40729      4  2025
# 65316      διδυμοτειχου         3265  26.60756  41.40729      5  2025
# 65317      διδυμοτειχου         3265  26.60756  41.40729      6  2025
# 65318      διδυμοτειχου         3265  26.60756  41.40729      7  2025
# 65319      διδυμοτειχου         3265  26.60756  41.40729      8  2025
#
#            ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  \
# 0      0.158323  0.215487 -0.000889 -0.215487   0.199381   0.139230
# 1      0.216415  0.135713 -0.141988 -0.135713   0.201202   0.109560
# 2      0.288020  0.020938 -0.269782 -0.020938   0.271464  -0.014406
# 3      0.415067  0.090004 -0.372324 -0.090004   0.404440   0.054322
# 4      0.683583  0.336109 -0.556243 -0.336109   0.697113   0.322002
# ...         ...       ...       ...       ...        ...        ...
# 65315  0.742663  0.462529 -0.283619 -0.462529   0.627130   0.352200
# 65316  0.640442  0.340811 -0.309375 -0.340811   0.589446   0.300426
# 65317  0.381715  0.080804 -0.339803 -0.080804   0.418554   0.105143
# 65318  0.198721 -0.078176 -0.334130  0.078176   0.297327  -0.002982
# 65319       NaN       NaN       NaN       NaN        NaN        NaN
#
#        ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  \
# 0      -0.122525  -0.139230  0.065784  0.085729  0.100493  0.085729
# 1      -0.165407  -0.109560  0.044973  0.057022  0.058943  0.057022
# 2      -0.261725   0.014406  0.040399  0.034564  0.050305  0.034564
# 3      -0.369121  -0.054322  0.032283  0.029452  0.039463  0.029452
# 4      -0.570011  -0.322002  0.037963  0.025647  0.036570  0.025647
# ...          ...        ...       ...       ...       ...       ...
# 65315  -0.265129  -0.352200  0.083782  0.086808  0.024807  0.086808
# 65316  -0.294487  -0.300426  0.104357  0.105354  0.029402  0.105354
# 65317  -0.347862  -0.105143  0.053095  0.058511  0.036080  0.058511
# 65318  -0.369870   0.002982  0.060244  0.052322  0.028728  0.052322
# 65319        NaN        NaN       NaN       NaN       NaN       NaN
#
#        lst_day_mean  lst_jan_day_mean  lst_feb_day_mean  lst_mar_day_mean  \
# 0          2.144194          2.144194          8.146552         11.033226
# 1          8.146552          2.144194          8.146552         11.033226
# 2         11.033226          2.144194          8.146552         11.033226
# 3         20.928621          2.144194          8.146552         11.033226
# 4         18.547931          2.144194          8.146552         11.033226
# ...             ...               ...               ...               ...
# 65315     20.703333          8.861034          6.318800         16.690000
# 65316     29.526000          8.861034          6.318800         16.690000
# 65317     32.945200          8.861034          6.318800         16.690000
# 65318     37.454138          8.861034          6.318800         16.690000
# 65319           NaN          8.861034          6.318800         16.690000
#
#        lst_apr_day_mean  lst_night_mean  lst_jan_night_mean  \
# 0             20.928621       -1.550645           -1.550645
# 1             20.928621        1.583103           -1.550645
# 2             20.928621        1.028065           -1.550645
# 3             20.928621        7.520345           -1.550645
# 4             20.928621        9.786552           -1.550645
# ...                 ...             ...                 ...
# 65315         20.703333        7.435217            3.355806
# 65316         20.703333       11.434000            3.355806
# 65317         20.703333       19.544615            3.355806
# 65318         20.703333       23.335517            3.355806
# 65319         20.703333             NaN            3.355806
#
#        lst_feb_night_mean  lst_mar_night_mean  lst_apr_night_mean   lst_mean  \
# 0                1.583103            1.028065            7.520345   0.296774
# 1                1.583103            1.028065            7.520345   4.864828
# 2                1.583103            1.028065            7.520345   6.030645
# 3                1.583103            1.028065            7.520345  14.224483
# 4                1.583103            1.028065            7.520345  14.167241
# ...                   ...                 ...                 ...        ...
# 65315           -2.536429            3.741034            7.435217  14.162609
# 65316           -2.536429            3.741034            7.435217  20.480000
# 65317           -2.536429            3.741034            7.435217  26.283200
# 65318           -2.536429            3.741034            7.435217  30.394828
# 65319           -2.536429            3.741034            7.435217        NaN
#
#        lst_jan_mean  lst_feb_mean  lst_mar_mean  lst_apr_mean  lst_min  \
# 0          0.296774      4.864828      6.030645     14.224483   -7.190
# 1          0.296774      4.864828      6.030645     14.224483   -4.870
# 2          0.296774      4.864828      6.030645     14.224483   -2.250
# 3          0.296774      4.864828      6.030645     14.224483    1.490
# 4          0.296774      4.864828      6.030645     14.224483    6.730
# ...             ...           ...           ...           ...      ...
# 65315      6.108420      1.891186     10.215517     14.069275   -0.730
# 65316      6.108420      1.891186     10.215517     14.069275    8.050
# 65317      6.108420      1.891186     10.215517     14.069275   16.950
# 65318      6.108420      1.891186     10.215517     14.069275   19.770
# 65319      6.108420      1.891186     10.215517     14.069275   19.874
#
#        lst_max  rainfall_mean  acc_rainfall_1week  acc_rainfall_2week  \
# 0        7.430       1.339776            0.272635           13.341247
# 1       12.090       0.422918            4.489590            4.490472
# 2       22.230       1.257594           11.542164           12.303511
# 3       24.250       1.493143            3.880080           44.668190
# 4       22.590       1.810461            0.000000            1.398306
# ...        ...            ...                 ...                 ...
# 65315   29.130       1.398020            0.313529            0.313529
# 65316   30.870       0.049575            0.000000            0.000000
# 65317   38.050       0.004990            0.144706            0.144706
# 65318   40.250       0.160784            0.000000            4.984314
# 65319   41.506       0.000000            0.000000            0.160784
#
#        acc_rainfall_month  acc_rainfall_jan    bio1  bio2       bio3  \
# 0               41.531526         41.533057  11.750  17.5  41.666667
# 1               12.264610         53.797667  11.750  17.5  41.666667
# 2               38.158617         92.783077  11.750  17.5  41.666667
# 3               44.794301        137.577378  11.750  17.5  41.666667
# 4               56.124294        193.701673  11.750  17.5  41.666667
# ...                   ...               ...     ...   ...        ...
# 65315           41.940587        192.024701  17.625  21.5  45.744681
# 65316            0.297451        192.322152  17.625  21.5  45.744681
# 65317            0.144706        192.466858  17.625  21.5  45.744681
# 65318            4.984314        197.451171  17.625  21.5  45.744681
# 65319            4.984314        197.451171  17.625  21.5  45.744681
#
#               bio4  bio5  bio6  bio7  bio8       bio9      bio10     bio11  \
# 0       815.893264  35.0  -7.0  42.0  20.5   6.000000  22.500000  1.833333
# 1       815.893264  35.0  -7.0  42.0  20.5   6.000000  22.500000  1.833333
# 2       815.893264  35.0  -7.0  42.0  20.5   6.000000  22.500000  1.833333
# 3       815.893264  35.0  -7.0  42.0  20.5   6.000000  22.500000  1.833333
# 4       815.893264  35.0  -7.0  42.0  20.5   6.000000  22.500000  1.833333
# ...            ...   ...   ...   ...   ...        ...        ...       ...
# 65315  1044.970950  41.0  -6.0  47.0   9.5  25.166667  28.833333  7.000000
# 65316  1044.970950  41.0  -6.0  47.0   9.5  25.166667  28.833333  7.000000
# 65317  1044.970950  41.0  -6.0  47.0   9.5  25.166667  28.833333  7.000000
# 65318  1044.970950  41.0  -6.0  47.0   9.5  25.166667  28.833333  7.000000
# 65319  1044.970950  41.0  -6.0  47.0   9.5  25.166667  28.833333  7.000000
#
#        bio12  bio13  bio14       bio15  bio16  bio17  bio18  bio19  \
# 0      414.0  118.0    0.0   99.073270  178.0   45.0  118.0   86.0
# 1      414.0  118.0    0.0   99.073270  178.0   45.0  118.0   86.0
# 2      414.0  118.0    0.0   99.073270  178.0   45.0  118.0   86.0
# 3      414.0  118.0    0.0   99.073270  178.0   45.0  118.0   86.0
# 4      414.0  118.0    0.0   99.073270  178.0   45.0  118.0   86.0
# ...      ...    ...    ...         ...    ...    ...    ...    ...
# 65315  194.0  130.0    0.0  177.603846  179.0    4.0    4.0  149.0
# 65316  194.0  130.0    0.0  177.603846  179.0    4.0    4.0  149.0
# 65317  194.0  130.0    0.0  177.603846  179.0    4.0    4.0  149.0
# 65318  194.0  130.0    0.0  177.603846  179.0    4.0    4.0  149.0
# 65319  194.0  130.0    0.0  177.603846  179.0    4.0    4.0  149.0
#
#        distance_to_coast  distance_to_river  slope_mean_1km  aspect_mean_200m  \
# 0           13573.304209         975.115126               7        273.211376
# 1           13573.304209         975.115126               7        273.211376
# 2           13573.304209         975.115126               7        273.211376
# 3           13573.304209         975.115126               7        273.211376
# 4           13573.304209         975.115126               7        273.211376
# ...                  ...                ...             ...               ...
# 65315        8856.412678         737.727483               2        128.767263
# 65316        8856.412678         737.727483               2        128.767263
# 65317        8856.412678         737.727483               2        128.767263
# 65318        8856.412678         737.727483               2        128.767263
# 65319        8856.412678         737.727483               2        128.767263
#
#        elevation_mean_1km  hillshade_mean_1km  fs_area_1km  flow_accu_200m  \
# 0             1038.457075          164.099283          0.0        4.925067
# 1             1038.457075          164.099283          0.0        4.925067
# 2             1038.457075          164.099283          0.0        4.925067
# 3             1038.457075          164.099283          0.0        4.925067
# 4             1038.457075          164.099283          0.0        4.925067
# ...                   ...                 ...          ...             ...
# 65315           22.108898          179.985394          0.0        1.589066
# 65316           22.108898          179.985394          0.0        1.589066
# 65317           22.108898          179.985394          0.0        1.589066
# 65318           22.108898          179.985394          0.0        1.589066
# 65319           22.108898          179.985394          0.0        1.589066
#
#        lc_prop1  lc_prop1_assessment  lc_prop2  lc_prop2_assessment  lc_prop3  \
# 0            14                 98.0        10                 99.0        10
# 1            14                 98.0        10                 99.0        10
# 2            14                 98.0        10                 99.0        10
# 3            14                 98.0        10                 99.0        10
# 4            14                 98.0        10                 99.0        10
# ...         ...                  ...       ...                  ...       ...
# 65315        31                 99.0        36                 99.0        30
# 65316        31                 99.0        36                 99.0        30
# 65317        31                 99.0        36                 99.0        30
# 65318        31                 99.0        36                 99.0        30
# 65319        31                 99.0        36                 99.0        30
#
#        lc_prop3_assessment  lc_type1  lc_type2  lc_type3  lc_type4  lc_type5  \
# 0                     99.0         4         4         6         4         4
# 1                     99.0         4         4         6         4         4
# 2                     99.0         4         4         6         4         4
# 3                     99.0         4         4         6         4         4
# 4                     99.0         4         4         6         4         4
# ...                    ...       ...       ...       ...       ...       ...
# 65315                 99.0        12        12         3         5         8
# 65316                 99.0        12        12         3         5         8
# 65317                 99.0        12        12         3         5         8
# 65318                 99.0        12        12         3         5         8
# 65319                 99.0        12        12         3         5         8
#
#        lw  qc  M_Y_LT15  M_Y15-64  M_Y_GE65  M_TOTAL  F_Y_LT15  F_Y15-64  \
# 0       2   0    5775.0   27304.0    9999.0  43078.0    5348.0   25915.0
# 1       2   0    5775.0   27304.0    9999.0  43078.0    5348.0   25915.0
# 2       2   0    5775.0   27304.0    9999.0  43078.0    5348.0   25915.0
# 3       2   0    5775.0   27304.0    9999.0  43078.0    5348.0   25915.0
# 4       2   0    5775.0   27304.0    9999.0  43078.0    5348.0   25915.0
# ...    ..  ..       ...       ...       ...      ...       ...       ...
# 65315   2   0       NaN       NaN       NaN      NaN       NaN       NaN
# 65316   2   0       NaN       NaN       NaN      NaN       NaN       NaN
# 65317   2   0       NaN       NaN       NaN      NaN       NaN       NaN
# 65318   2   0       NaN       NaN       NaN      NaN       NaN       NaN
# 65319   2   0       NaN       NaN       NaN      NaN       NaN       NaN
#
#        F_Y_GE65  F_TOTAL  MIO_EUR  L_TOTAL  UNL_TOTAL  MOUNT_TYPE  URBN_TYPE  \
# 0       13125.0  44388.0      NaN      NaN        NaN           2          2
# 1       13125.0  44388.0      NaN      NaN        NaN           2          2
# 2       13125.0  44388.0      NaN      NaN        NaN           2          2
# 3       13125.0  44388.0      NaN      NaN        NaN           2          2
# 4       13125.0  44388.0      NaN      NaN        NaN           2          2
# ...         ...      ...      ...      ...        ...         ...        ...
# 65315       NaN      NaN      NaN      NaN        NaN           4          2
# 65316       NaN      NaN      NaN      NaN        NaN           4          2
# 65317       NaN      NaN      NaN      NaN        NaN           4          2
# 65318       NaN      NaN      NaN      NaN        NaN           4          2
# 65319       NaN      NaN      NaN      NaN        NaN           4          2
#
#        COAST_TYPE
# 0               2
# 1               2
# 2               2
# 3               2
# 4               2
# ...           ...
# 65315           1
# 65316           1
# 65317           1
# 65318           1
# 65319           1
#
# [65320 rows x 99 columns]

# %%
years = dataset_monthly.year.unique()
months =  dataset_monthly.month.unique()
cell_codes = dataset_monthly.cell_number.unique()

# %%
months = range(1,MONTH+1)

# %%
data = []

for year in years[1:]:
    for month in months:
        print(f'Year: {year} | Month: {month}')
        for cell in cell_codes:
            df_regional = dataset_monthly.loc[(dataset_monthly['cell_number'] == cell)].copy()
            df_regional.reset_index(drop = True, inplace = True)

            df_prev_year = df_regional.loc[(df_regional['year'] == year-1)].copy()
            if month == 1:
                df_prev_month = df_regional.loc[(df_regional['year'] == year-1) & (df_regional['month'] == 12)].copy()
            else:
                df_prev_month = df_regional.loc[(df_regional['year'] == year) & (df_regional['month'] == month -1)].copy()

            df_curr_year = df_regional.loc[(df_regional['year'] == year) & (df_regional['month'] == month)].copy()
        
            data.append({'cell_number': cell,
                        'nuts2_id': df_curr_year.iloc[0]['NUTS2_ID'],
                        'nuts3_id': df_curr_year.iloc[0]['NUTS3_ID'],
                        'lau1': df_curr_year.iloc[0]['LAU1_NAME'], 
                        'year': year, 
                        'month': month,
                        'x' : df_curr_year.iloc[0]['x'],
                        'y': df_curr_year.iloc[0]['y'],
                        'ndvi': df_prev_month.iloc[0]['ndvi'],
                        'ndmi': df_prev_month.iloc[0]['ndmi'],
                        'ndwi': df_prev_month.iloc[0]['ndwi'],
                        'ndbi': df_prev_month.iloc[0]['ndbi'],
                        'ndvi_mean': df_prev_month.iloc[0]['ndvi_mean'],
                        'ndmi_mean': df_prev_month.iloc[0]['ndmi_mean'],
                        'ndwi_mean': df_prev_month.iloc[0]['ndwi_mean'],
                        'ndbi_mean': df_prev_month.iloc[0]['ndbi_mean'],
                        'ndvi_std': df_prev_month.iloc[0]['ndvi_std'],
                        'ndmi_std': df_prev_month.iloc[0]['ndmi_std'],
                        'ndwi_std': df_prev_month.iloc[0]['ndwi_std'],
                        'ndbi_std': df_prev_month.iloc[0]['ndbi_std'],

                        'lst_day_mean': df_prev_month.iloc[0]['lst_day_mean'],
                        'lst_jan_day_mean': df_curr_year.iloc[0]['lst_jan_day_mean'],
                        'lst_feb_day_mean': df_curr_year.iloc[0]['lst_feb_day_mean'],
                        'lst_mar_day_mean': df_curr_year.iloc[0]['lst_mar_day_mean'],
                        'lst_apr_day_mean': df_curr_year.iloc[0]['lst_apr_day_mean'],

                        'lst_night_mean': df_prev_month.iloc[0]['lst_night_mean'],
                        'lst_jan_night_mean': df_curr_year.iloc[0]['lst_jan_night_mean'],
                        'lst_feb_night_mean': df_curr_year.iloc[0]['lst_feb_night_mean'],
                        'lst_mar_night_mean': df_curr_year.iloc[0]['lst_mar_night_mean'],
                        'lst_apr_night_mean': df_curr_year.iloc[0]['lst_apr_night_mean'],

                        'lst_mean': df_prev_month.iloc[0]['lst_mean'],
                        'lst_jan_mean': df_curr_year.iloc[0]['lst_jan_mean'],
                        'lst_feb_mean': df_curr_year.iloc[0]['lst_feb_mean'],
                        'lst_mar_mean': df_curr_year.iloc[0]['lst_mar_mean'],
                        'lst_apr_mean': df_curr_year.iloc[0]['lst_apr_mean'],

                        'monthly_lst_min': df_prev_month.iloc[0]['lst_min'],
                        'monthly_lst_max': df_prev_month.iloc[0]['lst_max'],

                        'rainfall_mean': df_prev_month.iloc[0]['rainfall_mean'],
                        'acc_rainfall_1week': df_prev_month.iloc[0]['acc_rainfall_1week'],
                        'acc_rainfall_2week': df_prev_month.iloc[0]['acc_rainfall_2week'],
                        'acc_rainfall_month': df_prev_month.iloc[0]['acc_rainfall_month'],
                        'acc_rainfall_jan': df_curr_year.iloc[0]['acc_rainfall_jan'],

                        'bio1': df_prev_year.iloc[0]['bio1'],
                        'bio2': df_prev_year.iloc[0]['bio2'],
                        'bio3': df_prev_year.iloc[0]['bio3'],
                        'bio4': df_prev_year.iloc[0]['bio4'],
                        'bio5': df_prev_year.iloc[0]['bio5'],
                        'bio6': df_prev_year.iloc[0]['bio6'],
                        'bio7': df_prev_year.iloc[0]['bio7'],
                        'bio8': df_prev_year.iloc[0]['bio8'],
                        'bio9': df_prev_year.iloc[0]['bio9'],
                        'bio10': df_prev_year.iloc[0]['bio10'],
                        'bio11': df_prev_year.iloc[0]['bio11'],
                        'bio12': df_prev_year.iloc[0]['bio12'],
                        'bio13': df_prev_year.iloc[0]['bio13'],
                        'bio14': df_prev_year.iloc[0]['bio14'],
                        'bio15': df_prev_year.iloc[0]['bio15'],
                        'bio16': df_prev_year.iloc[0]['bio16'],
                        'bio17': df_prev_year.iloc[0]['bio17'],
                        'bio18': df_prev_year.iloc[0]['bio18'],
                        'bio19': df_prev_year.iloc[0]['bio19'],

                        'lc_prop1': df_curr_year.iloc[0]['lc_prop1'],
                        'lc_prop2': df_curr_year.iloc[0]['lc_prop2'],
                        'lc_prop3': df_curr_year.iloc[0]['lc_prop3'],
                        'lc_type1': df_curr_year.iloc[0]['lc_type1'],
                        'lc_type2': df_curr_year.iloc[0]['lc_type2'],
                        'lc_type3': df_curr_year.iloc[0]['lc_type3'],
                        'lc_type4': df_curr_year.iloc[0]['lc_type4'],
                        'lc_type5': df_curr_year.iloc[0]['lc_type5'],

                        'distance_to_coast': df_curr_year.iloc[0]['distance_to_coast'],
                        'distance_to_river': df_curr_year.iloc[0]['distance_to_river'],
                        'slope_mean_1km': df_curr_year.iloc[0]['slope_mean_1km'],
                        'aspect_mean_200m': df_curr_year.iloc[0]['aspect_mean_200m'],
                        'elevation_mean_1km': df_curr_year.iloc[0]['elevation_mean_1km'],
                        'hillshade_mean_1km': df_curr_year.iloc[0]['hillshade_mean_1km'],
                        'fs_area_1km': df_curr_year.iloc[0]['fs_area_1km'],
                        'flow_accu_200m': df_curr_year.iloc[0]['flow_accu_200m'],

                        'males_lt15': df_prev_year.iloc[0]['M_Y_LT15'],
                        'males_15t64': df_prev_year.iloc[0]['M_Y15-64'],
                        'males_gt65': df_prev_year.iloc[0]['M_Y_GE65'],
                        'males_total': df_prev_year.iloc[0]['M_TOTAL'],
                        'females_lt15': df_prev_year.iloc[0]['F_Y_LT15'],
                        'females_15t64': df_prev_year.iloc[0]['F_Y15-64'],
                        'females_gt65': df_prev_year.iloc[0]['F_Y_GE65'],
                        'females_total': df_prev_year.iloc[0]['F_TOTAL'],
                        'mio_eur': df_prev_year.iloc[0]['MIO_EUR'],
                        'l_total': df_prev_year.iloc[0]['L_TOTAL'],
                        'unl_total': df_prev_year.iloc[0]['UNL_TOTAL'],

                        'mount_type': df_prev_month.iloc[0]['MOUNT_TYPE'],
                        'urbn_type': df_prev_month.iloc[0]['URBN_TYPE'],
                        'coast_type': df_prev_month.iloc[0]['COAST_TYPE'],
                    
                        # 'cases': df_curr_year.iloc[0]['cases'],
                        })
        
dataset_operational = pd.DataFrame(data)
# Out:
# Year: 2025 | Month: 1
# Year: 2025 | Month: 2
# Year: 2025 | Month: 3
# Year: 2025 | Month: 4
# Year: 2025 | Month: 5
# Year: 2025 | Month: 6
# Year: 2025 | Month: 7
# Year: 2025 | Month: 8

# %%
dataset_monthly[(dataset_monthly['cell_number'] == 0) & (dataset_monthly['year'] == 2023)].drop(columns=['NUTS2_ID','NUTS2_NAME','NUTS3_ID','LAU1_NAME'])
# Out:
# Empty DataFrame
# Columns: [dt_placement, NUTS3_NAME, cell_number, x, y, month, year, ndvi, ndmi, ndwi, ndbi, ndvi_mean, ndmi_mean, ndwi_mean, ndbi_mean, ndvi_std, ndmi_std, ndwi_std, ndbi_std, lst_day_mean, lst_jan_day_mean, lst_feb_day_mean, lst_mar_day_mean, lst_apr_day_mean, lst_night_mean, lst_jan_night_mean, lst_feb_night_mean, lst_mar_night_mean, lst_apr_night_mean, lst_mean, lst_jan_mean, lst_feb_mean, lst_mar_mean, lst_apr_mean, lst_min, lst_max, rainfall_mean, acc_rainfall_1week, acc_rainfall_2week, acc_rainfall_month, acc_rainfall_jan, bio1, bio2, bio3, bio4, bio5, bio6, bio7, bio8, bio9, bio10, bio11, bio12, bio13, bio14, bio15, bio16, bio17, bio18, bio19, distance_to_coast, distance_to_river, slope_mean_1km, aspect_mean_200m, elevation_mean_1km, hillshade_mean_1km, fs_area_1km, flow_accu_200m, lc_prop1, lc_prop1_assessment, lc_prop2, lc_prop2_assessment, lc_prop3, lc_prop3_assessment, lc_type1, lc_type2, lc_type3, lc_type4, lc_type5, lw, qc, M_Y_LT15, M_Y15-64, M_Y_GE65, M_TOTAL, F_Y_LT15, F_Y15-64, F_Y_GE65, F_TOTAL, MIO_EUR, L_TOTAL, UNL_TOTAL, MOUNT_TYPE, URBN_TYPE, COAST_TYPE]
# Index: []

# %%
dataset_operational[(dataset_operational['cell_number'] == 0) & (dataset_operational['year'] == 2024)]
# Out:
# Empty DataFrame
# Columns: [cell_number, nuts2_id, nuts3_id, lau1, year, month, x, y, ndvi, ndmi, ndwi, ndbi, ndvi_mean, ndmi_mean, ndwi_mean, ndbi_mean, ndvi_std, ndmi_std, ndwi_std, ndbi_std, lst_day_mean, lst_jan_day_mean, lst_feb_day_mean, lst_mar_day_mean, lst_apr_day_mean, lst_night_mean, lst_jan_night_mean, lst_feb_night_mean, lst_mar_night_mean, lst_apr_night_mean, lst_mean, lst_jan_mean, lst_feb_mean, lst_mar_mean, lst_apr_mean, monthly_lst_min, monthly_lst_max, rainfall_mean, acc_rainfall_1week, acc_rainfall_2week, acc_rainfall_month, acc_rainfall_jan, bio1, bio2, bio3, bio4, bio5, bio6, bio7, bio8, bio9, bio10, bio11, bio12, bio13, bio14, bio15, bio16, bio17, bio18, bio19, lc_prop1, lc_prop2, lc_prop3, lc_type1, lc_type2, lc_type3, lc_type4, lc_type5, distance_to_coast, distance_to_river, slope_mean_1km, aspect_mean_200m, elevation_mean_1km, hillshade_mean_1km, fs_area_1km, flow_accu_200m, males_lt15, males_15t64, males_gt65, males_total, females_lt15, females_15t64, females_gt65, females_total, mio_eur, l_total, unl_total, mount_type, urbn_type, coast_type]
# Index: []

# %%
missingno.matrix(dataset_operational)
# Out:
# <Axes: >

# %%
missing = describe_dataframe(dataset_operational, remove_zeros=True)
missing
# Out:
#           Column   Missing
# 8           ndvi   11.0418
# 9           ndmi   11.0418
# 10          ndwi   11.0418
# 11          ndbi   11.0418
# 12     ndvi_mean    7.8422
# ..           ...       ...
# 33  lst_mar_mean    3.9192
# 34  lst_apr_mean    3.9192
# 85       mio_eur  100.0000
# 86       l_total  100.0000
# 87     unl_total  100.0000
#
# [30 rows x 2 columns]

# %%
# dataset_monthly.cases.sum()

# %%
# dataset_operational.cases.sum()

# %%
years = dataset_operational.year.unique().tolist()

# %%
years
# Out:
# [2025]

# %%
for item in years:
    dataset_operational[dataset_operational.year == item].to_csv(f"../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Dataset_GRID_OP_{item}.csv", encoding = enc, index = False)
