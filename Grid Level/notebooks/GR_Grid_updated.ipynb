# %% [markdown]
# ## Creates the **Grid File** of a specific country at a certain resolution ##

# %%
import pandas as pd

import random
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import euclidean_distances

import sys

sys.path.insert(0, "../../Modules")

from utils import *

enc = 'utf-8'
dec = 'greek8'
random.seed(0)
np.random.seed(0)

pd.set_option('display.max_columns', None)

# %matplotlib inline

# %%
NUTS0 = 'GR'

# %%
greece_nuts3 = gpd.read_file(r"E:\Drive\NOA\Shapefiles\Greece Shapefiles\EL_Whole.shp",  encoding=enc)
greece_lau1 = gpd.read_file(r"E:\Drive\NOA\Shapefiles\Greece Shapefiles\old\el_lau1.shp",  encoding=enc)
greece_grid = gpd.read_file(f"../data/grid_index/grid_index.shp",  encoding=enc)
greece_wnv_cases1 = pd.read_csv('../data/GR_WNV_cases_grid_2010-2021_processed.csv', encoding = enc)
greece_wnv_cases2 = pd.read_csv('../data/GR_WNV_cases_grid_2022-2024_processed.csv', encoding = enc)

greece_wnv_cases = pd.concat([greece_wnv_cases1, greece_wnv_cases2], ignore_index=True)

# %%
greece_nuts3 = greece_nuts3.to_crs(epsg=4326)
greece_lau1 = greece_lau1.to_crs(epsg=4326)
greece_grid = greece_grid.to_crs(epsg=4326)

# %%
greece_lau1.drop(columns=['KWD_YPES'], inplace = True)
greece_lau1.drop(greece_lau1[greece_lau1['NAME'] == 'Άθως'].index, inplace = True)
greece_lau1.rename(columns={"NAME": "LAU1_NAME", "geometry": "lau1_geom"}, inplace = True)
greece_lau1.set_geometry("lau1_geom", inplace = True)
greece_lau1['lau1_centroid'] = greece_lau1['lau1_geom'].centroid
greece_lau1['lau1_rpoint'] = greece_lau1['lau1_geom'].representative_point()
greece_lau1.reset_index(drop=True, inplace=True)

greece_nuts3.rename(columns={"geometry": "nuts3_geom"}, inplace = True)
greece_nuts3.set_geometry("nuts3_geom", inplace = True)

greece_grid.drop(columns=['PageNumber'], inplace=True)
greece_grid['cell_rpoint'] = greece_grid['geometry'].representative_point()
greece_grid = greece_grid.set_axis(['cell_code', 'geometry', 'cell_rpoint'], axis=1)
# Out:
# C:\Users\dimit\AppData\Local\Temp\ipykernel_20648\2459482315.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   greece_lau1['lau1_centroid'] = greece_lau1['lau1_geom'].centroid

# %%
print(f'greece_nuts3 CRS: {greece_nuts3.crs}')
print(f'greece_lau1 CRS: {greece_lau1.crs}')
print(f'greece_index CRS: {greece_grid.crs}')
# Out:
# greece_nuts3 CRS: EPSG:4326
# greece_lau1 CRS: EPSG:4326
# greece_index CRS: EPSG:4326

# %%
greece_nuts3.plot(facecolor="none", edgecolor='grey', figsize=(20, 20), color='orange')
# Out:
# <Axes: >

# %%
ax = greece_lau1.plot(facecolor="none", edgecolor='black', figsize=(20, 20), color='grey')
greece_lau1['lau1_centroid'].plot(markersize=.25, ax=ax, color='yellow')
greece_lau1['lau1_rpoint'].plot(markersize=.25, ax=ax, color='red')
# Out:
# <Axes: >

# %%
greece_grid.plot(facecolor="none", edgecolor='grey', figsize=(20, 20), color='orange')
# Out:
# <Axes: >

# %%
greece_lau1.set_geometry("lau1_rpoint", inplace = True)
greece_nuts3 = greece_nuts3.to_crs(epsg=4326)
greece_lau1 = greece_lau1.to_crs(epsg=4326)

greece_gdf = greece_lau1.sjoin(greece_nuts3, predicate="within", how = "left")
greece_gdf.head()
# Out:
#            LAU1_NAME                                          lau1_geom  \
# 0          Αμυνταίου  POLYGON ((21.70746 40.85172, 21.70955 40.85119...
# 1  Άκτιου - Βόνιτσας  MULTIPOLYGON (((20.79456 38.75371, 20.79456 38...
# 2             Άνδρου  MULTIPOLYGON (((24.95917 37.69039, 24.95897 37...
# 3   Άργους - Μυκηνών  POLYGON ((22.52084 37.83857, 22.52111 37.83829...
# 4            Έδεσσας  POLYGON ((21.99535 40.90380, 21.99562 40.90344...
#
#                lau1_centroid                lau1_rpoint  index_right  \
# 0  POINT (21.63479 40.67528)  POINT (21.67171 40.68676)           30
# 1  POINT (20.95158 38.82289)  POINT (20.93655 38.81891)           41
# 2  POINT (24.84814 37.85801)  POINT (24.86216 37.84094)           11
# 3  POINT (22.62532 37.66339)  POINT (22.62833 37.65584)           49
# 4  POINT (21.92931 40.79799)  POINT (21.93215 40.79303)           24
#
#   CNTR_CODE CNTR_NAME NUTS1_ID            NUTS1_LATN            NUTS1_NAME  \
# 0        EL    Greece      EL5         Voreia Elláda         Βόρεια Ελλάδα
# 1        EL    Greece      EL6       Kentriki Elláda       Κεντρική Ελλάδα
# 2        EL    Greece      EL4  Nisia Aigaiou, Kriti  Νησιά Αιγαίου, Κρήτη
# 3        EL    Greece      EL6       Kentriki Elláda       Κεντρική Ελλάδα
# 4        EL    Greece      EL5         Voreia Elláda         Βόρεια Ελλάδα
#
#   NUTS2_ID          NUTS2_LATN          NUTS2_NAME NUTS3_ID  \
# 0     EL53    Dytiki Makedonia    Δυτική Μακεδονία    EL533
# 1     EL63       Dytiki Elláda       Δυτική Ελλάδα    EL631
# 2     EL42        Notio Aigaio        Νότιο Αιγαίο    EL422
# 3     EL65        Peloponnisos        Πελοπόννησος    EL651
# 4     EL52  Kentriki Makedonia  Κεντρική Μακεδονία    EL524
#
#                                           NUTS3_LATN  \
# 0                                            Florina
# 1                                    Aitoloakarnania
# 2  Andros, Thira, Kea, Milos, Mykonos, Naxos, Par...
# 3                                  Argolida, Arkadia
# 4                                              Pella
#
#                                           NUTS3_NAME  MOUNT_TYPE  URBN_TYPE  \
# 0                                            Φλώρινα         3.0          3
# 1                                    Αιτωλοακαρνανία         2.0          3
# 2  Άνδρος, Θήρα, Κέα, Μήλος, Μύκονος, Νάξος, Πάρο...         2.0          3
# 3                                  Αργολίδα, Αρκαδία         3.0          3
# 4                                              Πέλλα         2.0          3
#
#    COAST_TYPE
# 0           3
# 1           1
# 2           1
# 3           1
# 4           2

# %%
greece_gdf.shape
# Out:
# (325, 19)

# %%
greece_gdf.drop(columns = ['lau1_centroid',	'lau1_rpoint', 'index_right', 'CNTR_CODE', 'CNTR_NAME', 'NUTS1_LATN', 'NUTS2_LATN', 'NUTS3_LATN'], inplace = True)

# %%
greece_gdf.set_geometry('lau1_geom', inplace = True)
greece_grid.set_geometry('cell_rpoint', inplace = True)

# %%
greece_gdf = greece_gdf.to_crs(epsg=4326)
greece_grid = greece_grid.to_crs(epsg=4326)

# %%
greece_grid = greece_grid.sjoin_nearest(greece_gdf, how='left', max_distance=0.01, distance_col='dist')
# Out:
# c:\Users\dimit\Python Virtual Environments\noa_eywa\Lib\site-packages\geopandas\array.py:365: UserWarning: Geometry is in a geographic CRS. Results from 'sjoin_nearest' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   warnings.warn(

# %%
greece_grid.shape
# Out:
# (141365, 15)

# %%
greece_grid_nans = greece_grid[greece_grid['index_right'].isna()].copy()

# %%
greece_grid_nans.set_geometry('geometry', inplace = True)

# %%
greece_grid_nans.shape
# Out:
# (398, 15)

# %%
describe_dataframe(greece_grid)
# Out:
#          Column  Missing
# 0     cell_code   0.0000
# 1      geometry   0.0000
# 2   cell_rpoint   0.0000
# 3   index_right   0.2815
# 4     LAU1_NAME   0.2815
# 5      NUTS1_ID   0.2815
# 6    NUTS1_NAME   0.2815
# 7      NUTS2_ID   0.2815
# 8    NUTS2_NAME   0.2815
# 9      NUTS3_ID   0.2815
# 10   NUTS3_NAME   0.2815
# 11   MOUNT_TYPE   0.2815
# 12    URBN_TYPE   0.2815
# 13   COAST_TYPE   0.2815
# 14         dist   0.2815

# %%
greece_grid.dropna(how='any', inplace = True)

# %%
greece_grid.dist.max()
# Out:
# 0.009998383223710815

# %%
greece_grid.dist.hist(bins = 50)
# Out:
# <Axes: >

# %%
greece_grid.reset_index(drop = True, inplace = True)

# %%
greece_grid.set_geometry('geometry', inplace = True)

# %%
greece_grid.drop(columns = ['cell_rpoint', 'index_right', 'dist'], inplace = True)

# %%
greece_grid['centroid'] = greece_grid['geometry'].centroid
# Out:
# C:\Users\dimit\AppData\Local\Temp\ipykernel_20648\830613437.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   greece_grid['centroid'] = greece_grid['geometry'].centroid

# %%
ax = greece_grid.plot(figsize=(40, 40), color='grey', facecolor = 'silver')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Έβρος'].plot(ax=ax, color='bisque', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Έβρος'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Δράμα'].plot(ax=ax, color='darkorange', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Δράμα'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Ξάνθη'].plot(ax=ax, color='tan', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Ξάνθη'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Σέρρες'].plot(ax=ax, color='ivory', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Σέρρες'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Ροδόπη'].plot(ax=ax, color='lavender', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Ροδόπη'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Κιλκίς'].plot(ax=ax, color='navy', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Κιλκίς'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Θάσος, Καβάλα'].plot(ax=ax, color='slateblue', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Θάσος, Καβάλα'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Πέλλα'].plot(ax=ax, color='plum', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Πέλλα'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Θεσσαλονίκη'].plot(ax=ax, color='cyan', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Θεσσαλονίκη'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Φλώρινα'].plot(ax=ax, color='coral', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Καστοριά'].plot(ax=ax, color='skyblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Ημαθία'].plot(ax=ax, color='crimson', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Ημαθία'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Γρεβενά, Κοζάνη'].plot(ax=ax, color='cadetblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Χαλκιδική'].plot(ax=ax, color='fuchsia', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Χαλκιδική'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Πιερία'].plot(ax=ax, color='lime', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Πιερία'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Ιωάννινα'].plot(ax=ax, color='aquamarine', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Λάρισα'].plot(ax=ax, color='yellow', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Λάρισα'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Λέσβος, Λήμνος'].plot(ax=ax, color='green', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Κέρκυρα'].plot(ax=ax, color='forestgreen', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Καρδίτσα, Τρίκαλα'].plot(ax=ax, color='orange', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Καρδίτσα, Τρίκαλα'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Θεσπρωτία'].plot(ax=ax, color='rosybrown', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Μαγνησία, Σποράδες'].plot(ax=ax, color='tomato', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Μαγνησία, Σποράδες'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Άρτα, Πρέβεζα'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Ευρυτανία'].plot(ax=ax, color='deepskyblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Φθιώτιδα'].plot(ax=ax, color='violet', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Αιτωλοακαρνανία'].plot(ax=ax, color='pink', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Εύβοια'].plot(ax=ax, color='palegreen', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Λευκάδα'].plot(ax=ax, color='gold', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Φωκίδα'].plot(ax=ax, color='brown', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Χίος'].plot(ax=ax, color='lightgrey', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Ιθάκη, Κεφαλληνία'].plot(ax=ax, color='black', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Βοιωτία'].plot(ax=ax, color='khaki', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Αχαΐα'].plot(ax=ax, color='blueviolet', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Ανατολική Αττική'].plot(ax=ax, color='darkolivegreen', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Δυτική Αττική'].plot(ax=ax, color='moccasin', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Ανατολική Αττική'].plot(ax=ax, color='royalblue', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Δυτική Αττική'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Κορινθία'].plot(ax=ax, color='black', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Βόρειος Τομέας Αθηνών'].plot(ax=ax, color='mistyrose', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Δυτικός Τομέας Αθηνών'].plot(ax=ax, color='magenta', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Κεντρικός Τομέας Αθηνών'].plot(ax=ax, color='lawngreen', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Πειραιάς, Νήσοι'].plot(ax=ax, color='teal', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Βόρειος Τομέας Αθηνών'].plot(ax=ax, color='royalblue', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Δυτικός Τομέας Αθηνών'].plot(ax=ax, color='royalblue', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Κεντρικός Τομέας Αθηνών'].plot(ax=ax, color='royalblue', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Πειραιάς, Νήσοι'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Άνδρος, Θήρα, Κέα, Μήλος, Μύκονος, Νάξος, Πάρος, Σύρος, Τήνος'].plot(ax=ax, color='sienna', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Ζάκυνθος'].plot(ax=ax, color='chocolate', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Νότιος Τομέας Αθηνών'].plot(ax=ax, color='darksalmon', facecolor = 'none')
greece_grid[greece_grid['NUTS3_NAME'] == 'Νότιος Τομέας Αθηνών'].plot(ax=ax, color='royalblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Αργολίδα, Αρκαδία'].plot(ax=ax, color='springgreen', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Ικαρία, Σάμος'].plot(ax=ax, color='powderblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Κάλυμνος, Κάρπαθος – Ηρωική Νήσος Κάσος, Κως, Ρόδος'].plot(ax=ax, color='lightcyan', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Λακωνία, Μεσσηνία'].plot(ax=ax, color='turquoise', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Χανιά'].plot(ax=ax, color='aliceblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Λασίθι'].plot(ax=ax, color='steelblue', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Ηράκλειο'].plot(ax=ax, color='hotpink', facecolor = 'none')
# greece_grid[greece_grid['NUTS3_NAME'] == 'Ρέθυμνο'].plot(ax=ax, color='honeydew', facecolor = 'none')
# Out:
# <Axes: >

# %%
greece_grid.head()
# Out:
#   cell_code                                           geometry   LAU1_NAME  \
# 0      A577  POLYGON ((26.16678 41.74822, 26.16708 41.75722...  Ορεστιάδας
# 1      A582  POLYGON ((26.22687 41.74707, 26.22718 41.75607...  Ορεστιάδας
# 2      B575  POLYGON ((26.14244 41.73967, 26.14274 41.74867...  Ορεστιάδας
# 3      B576  POLYGON ((26.15446 41.73945, 26.15476 41.74845...  Ορεστιάδας
# 4      B577  POLYGON ((26.16648 41.73922, 26.16678 41.74822...  Ορεστιάδας
#
#   NUTS1_ID     NUTS1_NAME NUTS2_ID                  NUTS2_NAME NUTS3_ID  \
# 0      EL5  Βόρεια Ελλάδα     EL51  Aνατολική Μακεδονία, Θράκη    EL511
# 1      EL5  Βόρεια Ελλάδα     EL51  Aνατολική Μακεδονία, Θράκη    EL511
# 2      EL5  Βόρεια Ελλάδα     EL51  Aνατολική Μακεδονία, Θράκη    EL511
# 3      EL5  Βόρεια Ελλάδα     EL51  Aνατολική Μακεδονία, Θράκη    EL511
# 4      EL5  Βόρεια Ελλάδα     EL51  Aνατολική Μακεδονία, Θράκη    EL511
#
#   NUTS3_NAME  MOUNT_TYPE  URBN_TYPE  COAST_TYPE                   centroid
# 0      Έβρος         4.0        2.0         1.0  POINT (26.17294 41.75261)
# 1      Έβρος         4.0        2.0         1.0  POINT (26.23304 41.75146)
# 2      Έβρος         4.0        2.0         1.0  POINT (26.14860 41.74406)
# 3      Έβρος         4.0        2.0         1.0  POINT (26.16062 41.74384)
# 4      Έβρος         4.0        2.0         1.0  POINT (26.17264 41.74361)

# %%
df_sub = greece_grid.loc[greece_grid['NUTS2_ID'] == 'EL52'].copy()
df_sub.drop(columns=['centroid'], inplace=True)
df_sub.reset_index(drop=True, inplace=True)

# %%
# df_sub.to_file('../../data_snipets/EL52_eody_grid.shp', encoding = enc)

# %%
infected_cells = greece_wnv_cases.cell_code.unique().tolist()
len(infected_cells)
# Out:
# 1215

# %%
greece_grid
# Out:
#        cell_code                                           geometry  \
# 0           A577  POLYGON ((26.16678 41.74822, 26.16708 41.75722...
# 1           A582  POLYGON ((26.22687 41.74707, 26.22718 41.75607...
# 2           B575  POLYGON ((26.14244 41.73967, 26.14274 41.74867...
# 3           B576  POLYGON ((26.15446 41.73945, 26.15476 41.74845...
# 4           B577  POLYGON ((26.16648 41.73922, 26.16678 41.74822...
# ...          ...                                                ...
# 140962    ACS408  POLYGON ((24.12201 34.81104, 24.12203 34.82006...
# 140963    ACT406  POLYGON ((24.10014 34.80204, 24.10015 34.81106...
# 140964    ACT407  POLYGON ((24.11107 34.80203, 24.11108 34.81105...
# 140965    ACT408  POLYGON ((24.12200 34.80202, 24.12201 34.81104...
# 140966    ACT409  POLYGON ((24.13293 34.80201, 24.13295 34.81103...
#
#          LAU1_NAME NUTS1_ID            NUTS1_NAME NUTS2_ID  \
# 0       Ορεστιάδας      EL5         Βόρεια Ελλάδα     EL51
# 1       Ορεστιάδας      EL5         Βόρεια Ελλάδα     EL51
# 2       Ορεστιάδας      EL5         Βόρεια Ελλάδα     EL51
# 3       Ορεστιάδας      EL5         Βόρεια Ελλάδα     EL51
# 4       Ορεστιάδας      EL5         Βόρεια Ελλάδα     EL51
# ...            ...      ...                   ...      ...
# 140962      Γαύδου      EL4  Νησιά Αιγαίου, Κρήτη     EL43
# 140963      Γαύδου      EL4  Νησιά Αιγαίου, Κρήτη     EL43
# 140964      Γαύδου      EL4  Νησιά Αιγαίου, Κρήτη     EL43
# 140965      Γαύδου      EL4  Νησιά Αιγαίου, Κρήτη     EL43
# 140966      Γαύδου      EL4  Νησιά Αιγαίου, Κρήτη     EL43
#
#                         NUTS2_NAME NUTS3_ID NUTS3_NAME  MOUNT_TYPE  URBN_TYPE  \
# 0       Aνατολική Μακεδονία, Θράκη    EL511      Έβρος         4.0        2.0
# 1       Aνατολική Μακεδονία, Θράκη    EL511      Έβρος         4.0        2.0
# 2       Aνατολική Μακεδονία, Θράκη    EL511      Έβρος         4.0        2.0
# 3       Aνατολική Μακεδονία, Θράκη    EL511      Έβρος         4.0        2.0
# 4       Aνατολική Μακεδονία, Θράκη    EL511      Έβρος         4.0        2.0
# ...                            ...      ...        ...         ...        ...
# 140962                       Κρήτη    EL434      Χανιά         2.0        2.0
# 140963                       Κρήτη    EL434      Χανιά         2.0        2.0
# 140964                       Κρήτη    EL434      Χανιά         2.0        2.0
# 140965                       Κρήτη    EL434      Χανιά         2.0        2.0
# 140966                       Κρήτη    EL434      Χανιά         2.0        2.0
#
#         COAST_TYPE                   centroid
# 0              1.0  POINT (26.17294 41.75261)
# 1              1.0  POINT (26.23304 41.75146)
# 2              1.0  POINT (26.14860 41.74406)
# 3              1.0  POINT (26.16062 41.74384)
# 4              1.0  POINT (26.17264 41.74361)
# ...            ...                        ...
# 140962         1.0  POINT (24.12749 34.81554)
# 140963         1.0  POINT (24.10561 34.80655)
# 140964         1.0  POINT (24.11654 34.80654)
# 140965         1.0  POINT (24.12747 34.80653)
# 140966         1.0  POINT (24.13841 34.80651)
#
# [140967 rows x 13 columns]

# %%
greece_grid['infected'] = 0
greece_grid.loc[greece_grid['cell_code'].isin(infected_cells), ['infected']] = 1

# %%
greece_grid.infected.sum()
# Out:
# 1215

# %%
#ax = greece_grid[greece_grid['infected'] == 0].plot(facecolor="none", edgecolor='grey', figsize=(20, 20), color='blue')
ax = greece_nuts3.plot(facecolor="none", edgecolor='black', figsize=(20, 20), color='none')
greece_grid[greece_grid['infected'] == 1].plot(facecolor="none", edgecolor='red', ax = ax, color='red')
# Out:
# <Axes: >

# %%
# infected_temporary_df = greece_grid[greece_grid['infected'] == 1].copy()
# infected_temporary_df.drop(columns='geometry', inplace=True)
# infected_temporary_df.set_geometry("centroid", inplace=True)
# infected_temporary_df.to_file('../../data_snipets/Greece_Infected_2x2.shp', encoding = 'utf-8')

# %%
infected_gdf = greece_grid[greece_grid['infected'] == 1]
non_infected_gdf = greece_grid[greece_grid['infected'] == 0]

centroids_infected = list(infected_gdf['centroid'].apply(lambda point: (point.x, point.y)))
centroids_non_infected = list(non_infected_gdf['centroid'].apply(lambda point: (point.x, point.y)))

# %%
all_non_infected_list = []

for point in centroids_infected:
    distances_matrix = euclidean_distances(
        np.array(centroids_non_infected),
        np.array(point).reshape(1, -1)
    )

    sorted_indices = np.argsort(distances_matrix, axis=0)
    sorted_non_infected = non_infected_gdf.iloc[sorted_indices[:, 0]]

    top100_noninfected = sorted_non_infected.iloc[:100].sample(2, random_state=1)
    rest_noninfected = sorted_non_infected.iloc[101:].sample(2, random_state=1361)

    all_non_infected_list.append(top100_noninfected)
    all_non_infected_list.append(rest_noninfected)

all_non_infected = pd.concat(all_non_infected_list, ignore_index=True)

# %%
ax = greece_grid[greece_grid['infected'] == 0].plot(facecolor="none", edgecolor='grey', figsize=(20, 20), color='blue')
all_non_infected.plot(facecolor="none", edgecolor='none', ax = ax, color='blue')
infected_gdf.plot(facecolor="none", edgecolor='red', ax = ax, color='red')
# Out:
# <Axes: >

# %%
wnv_grid = pd.concat([all_non_infected, infected_gdf])

# %%
wnv_grid
# Out:
#        cell_code                                           geometry  \
# 0           G588  POLYGON ((26.29705 41.69166, 26.29737 41.70066...
# 1           H588  POLYGON ((26.29673 41.68266, 26.29705 41.69166...
# 2          UE260  POLYGON ((22.46606 36.80280, 22.46588 36.81181...
# 3          NB344  POLYGON ((23.39420 38.47861, 23.39413 38.48762...
# 4           K591  POLYGON ((26.33177 41.65493, 26.33210 41.66393...
# ...          ...                                                ...
# 114715     RI308  POLYGON ((22.99525 37.47547, 22.99513 37.48449...
# 115573     RN287  POLYGON ((22.75854 37.42816, 22.75839 37.43717...
# 133796    AAK447  POLYGON ((24.55205 35.35088, 24.55211 35.35989...
# 134742    AAP469  POLYGON ((24.79372 35.30445, 24.79380 35.31347...
# 136583    AAY433  POLYGON ((24.39735 35.22525, 24.39740 35.23427...
#
#                 LAU1_NAME NUTS1_ID            NUTS1_NAME NUTS2_ID  \
# 0              Ορεστιάδας      EL5         Βόρεια Ελλάδα     EL51
# 1              Ορεστιάδας      EL5         Βόρεια Ελλάδα     EL51
# 2        Ανατολικής Μάνης      EL6       Κεντρική Ελλάδα     EL65
# 3               Χαλκιδέων      EL6       Κεντρική Ελλάδα     EL64
# 4              Ορεστιάδας      EL5         Βόρεια Ελλάδα     EL51
# ...                   ...      ...                   ...      ...
# 114715          Ναυπλιέων      EL6       Κεντρική Ελλάδα     EL65
# 115573  Βόρειας Κυνουρίας      EL6       Κεντρική Ελλάδα     EL65
# 133796           Ρεθύμνης      EL4  Νησιά Αιγαίου, Κρήτη     EL43
# 134742        Μυλοποτάμου      EL4  Νησιά Αιγαίου, Κρήτη     EL43
# 136583    Αγίου Βασιλείου      EL4  Νησιά Αιγαίου, Κρήτη     EL43
#
#                         NUTS2_NAME NUTS3_ID         NUTS3_NAME  MOUNT_TYPE  \
# 0       Aνατολική Μακεδονία, Θράκη    EL511              Έβρος         4.0
# 1       Aνατολική Μακεδονία, Θράκη    EL511              Έβρος         4.0
# 2                     Πελοπόννησος    EL653  Λακωνία, Μεσσηνία         2.0
# 3                    Στερεά Ελλάδα    EL642             Εύβοια         2.0
# 4       Aνατολική Μακεδονία, Θράκη    EL511              Έβρος         4.0
# ...                            ...      ...                ...         ...
# 114715                Πελοπόννησος    EL651  Αργολίδα, Αρκαδία         3.0
# 115573                Πελοπόννησος    EL651  Αργολίδα, Αρκαδία         3.0
# 133796                       Κρήτη    EL433            Ρέθυμνο         3.0
# 134742                       Κρήτη    EL433            Ρέθυμνο         3.0
# 136583                       Κρήτη    EL433            Ρέθυμνο         3.0
#
#         URBN_TYPE  COAST_TYPE                   centroid  infected
# 0             2.0         1.0  POINT (26.30322 41.69603)         0
# 1             2.0         1.0  POINT (26.30290 41.68704)         0
# 2             3.0         1.0  POINT (22.47158 36.80738)         0
# 3             3.0         1.0  POINT (23.39990 38.48314)         0
# 4             2.0         1.0  POINT (26.33794 41.65931)         0
# ...           ...         ...                        ...       ...
# 114715        3.0         1.0  POINT (23.00085 37.48003)         1
# 115573        3.0         1.0  POINT (22.76412 37.43272)         1
# 133796        3.0         1.0  POINT (24.55758 35.35536)         1
# 134742        3.0         1.0  POINT (24.79926 35.30892)         1
# 136583        3.0         1.0  POINT (24.40287 35.22974)         1
#
# [6075 rows x 14 columns]

# %%
process_greek(wnv_grid, 'NUTS1_NAME')
process_greek(wnv_grid, 'NUTS2_NAME')
process_greek(wnv_grid, 'NUTS3_NAME')
process_greek(wnv_grid, 'LAU1_NAME')

# %%
wnv_grid['x'] = wnv_grid['centroid'].apply(lambda point: point.x)
wnv_grid['y'] = wnv_grid['centroid'].apply(lambda point: point.y)

# %%
describe_dataframe(wnv_grid)
# Out:
#         Column  Missing
# 0    cell_code      0.0
# 1     geometry      0.0
# 2    LAU1_NAME      0.0
# 3     NUTS1_ID      0.0
# 4   NUTS1_NAME      0.0
# 5     NUTS2_ID      0.0
# 6   NUTS2_NAME      0.0
# 7     NUTS3_ID      0.0
# 8   NUTS3_NAME      0.0
# 9   MOUNT_TYPE      0.0
# 10   URBN_TYPE      0.0
# 11  COAST_TYPE      0.0
# 12    centroid      0.0
# 13    infected      0.0
# 14           x      0.0
# 15           y      0.0

# %%
wnv_grid.NUTS1_NAME.unique().tolist()
# Out:
# ['βορεια ελλαδα', 'κεντρικη ελλαδα', 'αττικη', 'νησια αιγαιου, κρητη']

# %%
wnv_grid.NUTS2_NAME.unique().tolist()
# Out:
# ['aνατολικη μακεδονια, θρακη',
#  'θεσσαλια',
#  'aττικη',
#  'στερεα ελλαδα',
#  'νοτιο αιγαιο',
#  'δυτικη μακεδονια',
#  'πελοποννησος',
#  'κεντρικη μακεδονια',
#  'ηπειρος',
#  'δυτικη ελλαδα',
#  'βορειο αιγαιο',
#  'ιονια νησια',
#  'κρητη']

# %%
wnv_grid.NUTS3_NAME.unique().tolist()
# Out:
# ['εβρος',
#  'καρδιτσα, τρικαλα',
#  'δυτικη αττικη',
#  'φωκιδα',
#  'ανατολικη αττικη',
#  'καλυμνος, καρπαθος ηρωικη νησος κασος, κως, ροδος',
#  'γρεβενα, κοζανη',
#  'λαρισα',
#  'αργολιδα, αρκαδια',
#  'πειραιας, νησοι',
#  'ανδρος, θηρα, κεα, μηλος, μυκονος, ναξος, παρος, συρος, τηνος',
#  'μαγνησια, σποραδες',
#  'κιλκις',
#  'σερρες',
#  'ευβοια',
#  'ιωαννινα',
#  'βοιωτια',
#  'αρτα, πρεβεζα',
#  'ευρυτανια',
#  'θεσπρωτια',
#  'ροδοπη',
#  'αιτωλοακαρνανια',
#  'φθιωτιδα',
#  'λεσβος, λημνος',
#  'δραμα',
#  'ξανθη',
#  'κορινθια',
#  'ικαρια, σαμος',
#  'καστορια',
#  'φλωρινα',
#  'βορειος τομεας αθηνων',
#  'πελλα',
#  'αχαια',
#  'θασος, καβαλα',
#  'ιθακη, κεφαλληνια',
#  'χιος',
#  'θεσσαλονικη',
#  'κερκυρα',
#  'λευκαδα',
#  'ημαθια',
#  'χαλκιδικη',
#  'πιερια',
#  'ηλεια',
#  'λακωνια, μεσσηνια',
#  'ζακυνθος',
#  'ρεθυμνο',
#  'χανια',
#  'κεντρικος τομεας αθηνων',
#  'δυτικος τομεας αθηνων',
#  'ηρακλειο',
#  'νοτιος τομεας αθηνων']

# %%
wnv_grid['NUTS2_NAME'] = wnv_grid['NUTS2_NAME'].apply(lambda x : x.replace('aνατολικη μακεδονια, θρακη','ανατολικη μακεδονια, θρακη'))
wnv_grid['NUTS2_NAME'] = wnv_grid['NUTS2_NAME'].apply(lambda x : x.replace('aττικη','αττικη'))

# %%
wnv_grid.NUTS2_NAME.unique().tolist()
# Out:
# ['ανατολικη μακεδονια, θρακη',
#  'θεσσαλια',
#  'αττικη',
#  'στερεα ελλαδα',
#  'νοτιο αιγαιο',
#  'δυτικη μακεδονια',
#  'πελοποννησος',
#  'κεντρικη μακεδονια',
#  'ηπειρος',
#  'δυτικη ελλαδα',
#  'βορειο αιγαιο',
#  'ιονια νησια',
#  'κρητη']

# %%
wnv_grid.reset_index(drop= True, inplace = True)

# %%
wnv_grid.shape
# Out:
# (4405, 16)

# %%
columns = ['x', 'y', 'cell_code', 'NUTS1_ID', 'NUTS1_NAME', 'NUTS2_ID', 'NUTS2_NAME', 'NUTS3_ID', 'NUTS3_NAME', 
            'LAU1_NAME', 'MOUNT_TYPE', 'URBN_TYPE', 'COAST_TYPE', 'geometry', 'centroid']

wnv_grid = wnv_grid[columns].copy()

# %%
wnv_grid.sort_values(by=['NUTS1_NAME', 'NUTS2_NAME', 'NUTS3_NAME', 'LAU1_NAME'], inplace = True)

# %%
ax = greece_grid.plot(facecolor="none", edgecolor='grey', figsize=(20, 20), color='grey')
wnv_grid.plot(facecolor="none", edgecolor='none', ax = ax, color='red')
# Out:
# <AxesSubplot:>

# %%
wnv_grid.reset_index(drop= True, inplace = True)

# %%
wnv_grid
# Out:
#               x          y cell_code NUTS1_ID            NUTS1_NAME NUTS2_ID  \
# 0     23.722470  38.078795     OU372      EL3                αττικη     EL30
# 1     23.756376  38.168996     OK375      EL3                αττικη     EL30
# 2     23.767821  38.160007     OL376      EL3                αττικη     EL30
# 3     23.813502  38.151076     OM380      EL3                αττικη     EL30
# 4     23.779398  38.105953     OR377      EL3                αττικη     EL30
# ...         ...        ...       ...      ...                   ...      ...
# 4400  25.072809  37.632604     QR491      EL4  νησια αιγαιου, κρητη     EL42
# 4401  26.401059  36.639748     UV611      EL4  νησια αιγαιου, κρητη     EL42
# 4402  26.130309  36.554768     VF587      EL4  νησια αιγαιου, κρητη     EL42
# 4403  26.718755  37.398899     RO637      EL4  νησια αιγαιου, κρητη     EL42
# 4404  27.860317  36.529297     VD742      EL4  νησια αιγαιου, κρητη     EL42
#
#         NUTS2_NAME NUTS3_ID  \
# 0           αττικη    EL305
# 1           αττικη    EL305
# 2           αττικη    EL305
# 3           αττικη    EL305
# 4           αττικη    EL305
# ...            ...      ...
# 4400  νοτιο αιγαιο    EL422
# 4401  νοτιο αιγαιο    EL421
# 4402  νοτιο αιγαιο    EL421
# 4403  νοτιο αιγαιο    EL421
# 4404  νοτιο αιγαιο    EL421
#
#                                              NUTS3_NAME    LAU1_NAME  \
# 0                                      ανατολικη αττικη      αχαρνων
# 1                                      ανατολικη αττικη      αχαρνων
# 2                                      ανατολικη αττικη      αχαρνων
# 3                                      ανατολικη αττικη      αχαρνων
# 4                                      ανατολικη αττικη      αχαρνων
# ...                                                 ...          ...
# 4400  ανδρος, θηρα, κεα, μηλος, μυκονος, ναξος, παρο...        τηνου
# 4401  καλυμνος, καρπαθος ηρωικη νησος κασος, κως, ροδος  αστυπαλαιας
# 4402  καλυμνος, καρπαθος ηρωικη νησος κασος, κως, ροδος  αστυπαλαιας
# 4403  καλυμνος, καρπαθος ηρωικη νησος κασος, κως, ροδος       πατμου
# 4404  καλυμνος, καρπαθος ηρωικη νησος κασος, κως, ροδος        συμης
#
#       MOUNT_TYPE  URBN_TYPE  COAST_TYPE  \
# 0            2.0        1.0         1.0
# 1            2.0        1.0         1.0
# 2            2.0        1.0         1.0
# 3            2.0        1.0         1.0
# 4            2.0        1.0         1.0
# ...          ...        ...         ...
# 4400         2.0        3.0         1.0
# 4401         2.0        2.0         1.0
# 4402         2.0        2.0         1.0
# 4403         2.0        2.0         1.0
# 4404         2.0        2.0         1.0
#
#                                                geometry  \
# 0     POLYGON ((23.71679 38.07427, 23.71675 38.08329...
# 1     POLYGON ((23.75068 38.16448, 23.75065 38.17349...
# 2     POLYGON ((23.76213 38.15549, 23.76210 38.16450...
# 3     POLYGON ((23.80781 38.14656, 23.80778 38.15557...
# 4     POLYGON ((23.77371 38.10144, 23.77368 38.11045...
# ...                                                 ...
# 4400  POLYGON ((25.06708 37.62815, 25.06721 37.63716...
# 4401  POLYGON ((26.39533 36.63536, 26.39561 36.64436...
# 4402  POLYGON ((26.12460 36.55036, 26.12485 36.55937...
# 4403  POLYGON ((26.71295 37.39453, 26.71327 37.40353...
# 4404  POLYGON ((27.85452 36.52498, 27.85497 36.53397...
#
#                        centroid
# 0     POINT (23.72247 38.07879)
# 1     POINT (23.75638 38.16900)
# 2     POINT (23.76782 38.16001)
# 3     POINT (23.81350 38.15108)
# 4     POINT (23.77940 38.10595)
# ...                         ...
# 4400  POINT (25.07281 37.63260)
# 4401  POINT (26.40106 36.63975)
# 4402  POINT (26.13031 36.55477)
# 4403  POINT (26.71875 37.39890)
# 4404  POINT (27.86032 36.52930)
#
# [4405 rows x 15 columns]

# %%
wnv_grid.to_csv(f'../data/GR_Grid.csv', encoding=enc, index = False)
