# %% [markdown]
# ## Creates the **Timeline** for a specific region by using the Grid File and the required dates ##

# %%
import pandas as pd
from datetime import date, timedelta

import random
import geopandas as gpd
import numpy as np

import sys

sys.path.insert(0, "../../../Modules")

from utils import *

pd.options.display.max_columns = None

enc = 'utf-8'
dec = 'greek8'
random.seed(0)

# %%
NUTS0 = 'GR'
NUTS2 = 'CMacedonia'

# %%
gr_grid = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_GRID.csv', encoding = enc)
gr_grid
# Out:
#       cell_number NUTS2_ID         x         y
# 0               0     EL52  21.76334  40.79806
# 1               1     EL52  21.76334  40.81603
# 2               2     EL52  21.76334  40.83400
# 3               3     EL52  21.76334  40.85196
# 4               4     EL52  21.78676  40.79806
# ...           ...      ...       ...       ...
# 4411         4411     EL52  24.05875  40.99570
# 4412         4412     EL52  24.05875  41.01366
# 4413         4413     EL52  24.08217  40.95976
# 4414         4414     EL52  24.08217  40.97773
# 4415         4415     EL52  24.08217  40.99570
#
# [4416 rows x 4 columns]

# %%
## start and end date is defined from available epidemiological file

# %%
start = start_dt = date(2024, 1, 1)
end = end_dt = date(2024, 5, 1)
delta = timedelta(days=1)

# %%
dates = []

while start_dt <= end_dt:
    dates.append(start_dt.isoformat())
    start_dt += delta

# %%
print('Dates between', start, 'and', end)
print(dates)
# Out:
# Dates between 2024-01-01 and 2024-05-01
# ['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08', '2024-01-09', '2024-01-10', '2024-01-11', '2024-01-12', '2024-01-13', '2024-01-14', '2024-01-15', '2024-01-16', '2024-01-17', '2024-01-18', '2024-01-19', '2024-01-20', '2024-01-21', '2024-01-22', '2024-01-23', '2024-01-24', '2024-01-25', '2024-01-26', '2024-01-27', '2024-01-28', '2024-01-29', '2024-01-30', '2024-01-31', '2024-02-01', '2024-02-02', '2024-02-03', '2024-02-04', '2024-02-05', '2024-02-06', '2024-02-07', '2024-02-08', '2024-02-09', '2024-02-10', '2024-02-11', '2024-02-12', '2024-02-13', '2024-02-14', '2024-02-15', '2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19', '2024-02-20', '2024-02-21', '2024-02-22', '2024-02-23', '2024-02-24', '2024-02-25', '2024-02-26', '2024-02-27', '2024-02-28', '2024-02-29', '2024-03-01', '2024-03-02', '2024-03-03', '2024-03-04', '2024-03-05', '2024-03-06', '2024-03-07', '2024-03-08', '2024-03-09', '2024-03-10', '2024-03-11', '2024-03-12', '2024-03-13', '2024-03-14', '2024-03-15', '2024-03-16', '2024-03-17', '2024-03-18', '2024-03-19', '2024-03-20', '2024-03-21', '2024-03-22', '2024-03-23', '2024-03-24', '2024-03-25', '2024-03-26', '2024-03-27', '2024-03-28', '2024-03-29', '2024-03-30', '2024-03-31', '2024-04-01', '2024-04-02', '2024-04-03', '2024-04-04', '2024-04-05', '2024-04-06', '2024-04-07', '2024-04-08', '2024-04-09', '2024-04-10', '2024-04-11', '2024-04-12', '2024-04-13', '2024-04-14', '2024-04-15', '2024-04-16', '2024-04-17', '2024-04-18', '2024-04-19', '2024-04-20', '2024-04-21', '2024-04-22', '2024-04-23', '2024-04-24', '2024-04-25', '2024-04-26', '2024-04-27', '2024-04-28', '2024-04-29', '2024-04-30', '2024-05-01']

# %%
len(dates)
# Out:
# 122

# %%
gr_timeline = pd.DataFrame()

# %%
data = []
for index, row in gr_grid.iterrows():
    for date in dates:
        data.append({'x': row['x'], 
                     'y': row['y'], 
                     'cell_number': row['cell_number'],  
                     'dt_placement': date,
                     'NUTS2_ID': row['NUTS2_ID'],
                     })

gr_timeline = pd.DataFrame(data)

# %%
gr_timeline
# Out:
#                x         y  cell_number dt_placement NUTS2_ID
# 0       21.76334  40.79806            0   2024-01-01     EL52
# 1       21.76334  40.79806            0   2024-01-02     EL52
# 2       21.76334  40.79806            0   2024-01-03     EL52
# 3       21.76334  40.79806            0   2024-01-04     EL52
# 4       21.76334  40.79806            0   2024-01-05     EL52
# ...          ...       ...          ...          ...      ...
# 538747  24.08217  40.99570         4415   2024-04-27     EL52
# 538748  24.08217  40.99570         4415   2024-04-28     EL52
# 538749  24.08217  40.99570         4415   2024-04-29     EL52
# 538750  24.08217  40.99570         4415   2024-04-30     EL52
# 538751  24.08217  40.99570         4415   2024-05-01     EL52
#
# [538752 rows x 5 columns]

# %%
gr_timeline['dt_placement'] = pd.to_datetime(gr_timeline['dt_placement'])

# %%
gr_timeline['year'] = gr_timeline['dt_placement'].apply(lambda x: x.year)

# %%
gr_timeline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 538752 entries, 0 to 538751
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   x             538752 non-null  float64
#  1   y             538752 non-null  float64
#  2   cell_number   538752 non-null  int64
#  3   dt_placement  538752 non-null  datetime64[ns]
#  4   NUTS2_ID      538752 non-null  object
#  5   year          538752 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(1)
# memory usage: 24.7+ MB

# %%
years = gr_timeline.year.unique().tolist()

# %%
for item in years:
    gr_timeline[gr_timeline.year == item].drop(columns = ['year']).to_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Timeline_GRID_{item}.csv', index = False)

# %%
gr_timeline
# Out:
#                x         y  cell_number dt_placement NUTS2_ID  year
# 0       21.76334  40.79806            0   2024-01-01     EL52  2024
# 1       21.76334  40.79806            0   2024-01-02     EL52  2024
# 2       21.76334  40.79806            0   2024-01-03     EL52  2024
# 3       21.76334  40.79806            0   2024-01-04     EL52  2024
# 4       21.76334  40.79806            0   2024-01-05     EL52  2024
# ...          ...       ...          ...          ...      ...   ...
# 538747  24.08217  40.99570         4415   2024-04-27     EL52  2024
# 538748  24.08217  40.99570         4415   2024-04-28     EL52  2024
# 538749  24.08217  40.99570         4415   2024-04-29     EL52  2024
# 538750  24.08217  40.99570         4415   2024-04-30     EL52  2024
# 538751  24.08217  40.99570         4415   2024-05-01     EL52  2024
#
# [538752 rows x 6 columns]

# %%
filled_file = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Timeline_GRID_2022-2023_filled.csv', encoding = enc)

# %%
years = filled_file.year.unique().tolist()

# %%
years
# Out:
# [2022, 2023]

# %%
for item in years:
    filled_file[filled_file.year == item].to_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Timeline_GRID_{item}_filled.csv', index = False)
