# %% [markdown]
# ## Merges all the availble information into a **Final Dataset** to be used for modeling ##

# %%
import pandas as pd
import datetime
import missingno
import re

from sklearn.impute import KNNImputer
import sys
import rpy2.robjects as robjects
import rpy2.ipython.html
from rpy2.robjects.packages import importr
import pickle
import gc

rpy2.ipython.html.init_printing()

sys.path.insert(0, "../../../Modules")
sys.path.insert(0, "../../../Mamoth")

from utils import *
from Neural_Network_Module import give_predictions, Dataset


enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 100
pd.options.display.float_format = lambda x: '%.6f' % x
# Out:
# c:\Users\dimit\Python Virtual Environments\noa_eywa\Lib\site-packages\rpy2\robjects\packages.py:367: UserWarning: The symbol 'quartz' is not in this R namespace/package.
#   warnings.warn(

# %%
utils = importr('utils')
base = importr('base')
dismo = importr('dismo')
utils.chooseCRANmirror(ind=41)
# Out:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x000002D064272E10> [0]

# %%
NUTS0 = 'GR'
NUTS2 = 'CMacedonia'

# %%
years = range(2024, 2025)

# %%
timelines = []

for year in years:
    df = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Timeline_GRID_{year}_filled_mean_rain_shp.csv', encoding=enc)
    print(f'Year: {year} | {df.shape}')
    timelines.append(df)
# Out:
# Year: 2024 | (808128, 44)

# %%
# timeline_file = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Timeline_GRID_2016-2018_filled.csv', encoding=enc)
# wnv_file = pd.read_csv(f'../../data/{NUTS0}_WNV_cases_GRID_2010-2021.csv', encoding=enc)

timeline_file = pd.concat(timelines, ignore_index=True, axis = 0)

# %%
del df
del timelines

gc.collect()
# Out:
# 270

# %%
timeline_file.head()
# Out:
#           x         y  cell_number dt_placement NUTS1_ID     NUTS1_NAME  \
# 0 21.763340 40.798060            0   2024-01-01      EL5  βορεια ελλαδα
# 1 21.763340 40.798060            0   2024-01-02      EL5  βορεια ελλαδα
# 2 21.763340 40.798060            0   2024-01-03      EL5  βορεια ελλαδα
# 3 21.763340 40.798060            0   2024-01-04      EL5  βορεια ελλαδα
# 4 21.763340 40.798060            0   2024-01-05      EL5  βορεια ελλαδα
#
#   NUTS2_ID          NUTS2_NAME NUTS3_ID NUTS3_NAME LAU1_NAME  year  month  \
# 0     EL52  κεντρικη μακεδονια    EL524      πελλα   εδεσσας  2024      1
# 1     EL52  κεντρικη μακεδονια    EL524      πελλα   εδεσσας  2024      1
# 2     EL52  κεντρικη μακεδονια    EL524      πελλα   εδεσσας  2024      1
# 3     EL52  κεντρικη μακεδονια    EL524      πελλα   εδεσσας  2024      1
# 4     EL52  κεντρικη μακεδονια    EL524      πελλα   εδεσσας  2024      1
#
#       ndvi      ndmi      ndwi     ndbi  ndvi_mean  ndmi_mean  ndwi_mean  \
# 0 0.329513 -0.087897 -0.308622 0.087897   0.321240  -0.084725  -0.298909
# 1 0.329513 -0.087897 -0.308622 0.087897   0.321240  -0.084725  -0.298909
# 2 0.329513 -0.087897 -0.308622 0.087897   0.321240  -0.084725  -0.298909
# 3 0.329513 -0.087897 -0.308622 0.087897   0.321240  -0.084725  -0.298909
# 4 0.329513 -0.087897 -0.308622 0.087897   0.321240  -0.084725  -0.298909
#
#    ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std      lst_day  \
# 0   0.084725  0.024682  0.037362  0.017980  0.037362 13797.000000
# 1   0.084725  0.024682  0.037362  0.017980  0.037362 14001.000000
# 2   0.084725  0.024682  0.037362  0.017980  0.037362 14001.000000
# 3   0.084725  0.024682  0.037362  0.017980  0.037362 14132.000000
# 4   0.084725  0.024682  0.037362  0.017980  0.037362 14132.000000
#
#      lst_night  rainfall  day  lst_day_jan_mean  lst_night_jan_mean  \
# 0 13711.000000  0.004594    1      13979.161290        13704.419355
# 1 13890.000000  3.881401    2      13979.161290        13704.419355
# 2 13905.000000  5.104080    3      13979.161290        13704.419355
# 3 14057.000000  0.035872    4      13979.161290        13704.419355
# 4 14057.000000  0.000000    5      13979.161290        13704.419355
#
#    lst_day_feb_mean  lst_night_feb_mean  lst_day_mar_mean  lst_night_mar_mean  \
# 0      14168.620690        13794.379310      14355.870968        13787.225806
# 1      14168.620690        13794.379310      14355.870968        13787.225806
# 2      14168.620690        13794.379310      14355.870968        13787.225806
# 3      14168.620690        13794.379310      14355.870968        13787.225806
# 4      14168.620690        13794.379310      14355.870968        13787.225806
#
#    lst_day_apr_mean  lst_night_apr_mean  acc_rainfall_1week  \
# 0      14829.360000        14100.120000            0.004594
# 1      14829.360000        14100.120000            3.885995
# 2      14829.360000        14100.120000            8.990075
# 3      14829.360000        14100.120000            9.025947
# 4      14829.360000        14100.120000            9.025947
#
#    acc_rainfall_2week  acc_rainfall_month  acc_rainfall_jan  MOUNT_TYPE  \
# 0            0.004594            0.004594          0.004594    2.000000
# 1            3.885995            3.885995          3.885995    2.000000
# 2            8.990075            8.990075          8.990075    2.000000
# 3            9.025947            9.025947          9.025947    2.000000
# 4            9.025947            9.025947          9.025947    2.000000
#
#    URBN_TYPE  COAST_TYPE
# 0          3           2
# 1          3           2
# 2          3           2
# 3          3           2
# 4          3           2

# %%
timeline_file.shape
# Out:
# (808128, 44)

# %%
# wnv_file.head()

# %%
# wnv_file.shape

# %%
try:
    timeline_file.drop(columns=['Unnamed: 0'], inplace=True)
except KeyError:
    print ("column not found")
# Out:
# column not found

# %%
temprature_cols = timeline_file.filter(regex='^lst_*').columns.tolist()

timeline_file[temprature_cols] = timeline_file[temprature_cols].apply(lambda x : x * 0.02 - 273.15)

# %%
timeline_file.head()
# Out:
#           x         y  cell_number dt_placement NUTS1_ID     NUTS1_NAME  \
# 0 21.763340 40.798060            0   2024-01-01      EL5  βορεια ελλαδα
# 1 21.763340 40.798060            0   2024-01-02      EL5  βορεια ελλαδα
# 2 21.763340 40.798060            0   2024-01-03      EL5  βορεια ελλαδα
# 3 21.763340 40.798060            0   2024-01-04      EL5  βορεια ελλαδα
# 4 21.763340 40.798060            0   2024-01-05      EL5  βορεια ελλαδα
#
#   NUTS2_ID          NUTS2_NAME NUTS3_ID NUTS3_NAME LAU1_NAME  year  month  \
# 0     EL52  κεντρικη μακεδονια    EL524      πελλα   εδεσσας  2024      1
# 1     EL52  κεντρικη μακεδονια    EL524      πελλα   εδεσσας  2024      1
# 2     EL52  κεντρικη μακεδονια    EL524      πελλα   εδεσσας  2024      1
# 3     EL52  κεντρικη μακεδονια    EL524      πελλα   εδεσσας  2024      1
# 4     EL52  κεντρικη μακεδονια    EL524      πελλα   εδεσσας  2024      1
#
#       ndvi      ndmi      ndwi     ndbi  ndvi_mean  ndmi_mean  ndwi_mean  \
# 0 0.329513 -0.087897 -0.308622 0.087897   0.321240  -0.084725  -0.298909
# 1 0.329513 -0.087897 -0.308622 0.087897   0.321240  -0.084725  -0.298909
# 2 0.329513 -0.087897 -0.308622 0.087897   0.321240  -0.084725  -0.298909
# 3 0.329513 -0.087897 -0.308622 0.087897   0.321240  -0.084725  -0.298909
# 4 0.329513 -0.087897 -0.308622 0.087897   0.321240  -0.084725  -0.298909
#
#    ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_day  lst_night  \
# 0   0.084725  0.024682  0.037362  0.017980  0.037362 2.790000   1.070000
# 1   0.084725  0.024682  0.037362  0.017980  0.037362 6.870000   4.650000
# 2   0.084725  0.024682  0.037362  0.017980  0.037362 6.870000   4.950000
# 3   0.084725  0.024682  0.037362  0.017980  0.037362 9.490000   7.990000
# 4   0.084725  0.024682  0.037362  0.017980  0.037362 9.490000   7.990000
#
#    rainfall  day  lst_day_jan_mean  lst_night_jan_mean  lst_day_feb_mean  \
# 0  0.004594    1          6.433226            0.938387         10.222414
# 1  3.881401    2          6.433226            0.938387         10.222414
# 2  5.104080    3          6.433226            0.938387         10.222414
# 3  0.035872    4          6.433226            0.938387         10.222414
# 4  0.000000    5          6.433226            0.938387         10.222414
#
#    lst_night_feb_mean  lst_day_mar_mean  lst_night_mar_mean  lst_day_apr_mean  \
# 0            2.737586         13.967419            2.594516         23.437200
# 1            2.737586         13.967419            2.594516         23.437200
# 2            2.737586         13.967419            2.594516         23.437200
# 3            2.737586         13.967419            2.594516         23.437200
# 4            2.737586         13.967419            2.594516         23.437200
#
#    lst_night_apr_mean  acc_rainfall_1week  acc_rainfall_2week  \
# 0            8.852400            0.004594            0.004594
# 1            8.852400            3.885995            3.885995
# 2            8.852400            8.990075            8.990075
# 3            8.852400            9.025947            9.025947
# 4            8.852400            9.025947            9.025947
#
#    acc_rainfall_month  acc_rainfall_jan  MOUNT_TYPE  URBN_TYPE  COAST_TYPE
# 0            0.004594          0.004594    2.000000          3           2
# 1            3.885995          3.885995    2.000000          3           2
# 2            8.990075          8.990075    2.000000          3           2
# 3            9.025947          9.025947    2.000000          3           2
# 4            9.025947          9.025947    2.000000          3           2

# %%
timeline_file['lst'] = (timeline_file['lst_day'] + timeline_file['lst_night']) / 2
timeline_file['lst_jan_mean'] = (timeline_file['lst_day_jan_mean'] + timeline_file['lst_night_jan_mean'])/2
timeline_file['lst_feb_mean'] = (timeline_file['lst_day_feb_mean'] + timeline_file['lst_night_feb_mean'])/2
timeline_file['lst_mar_mean'] = (timeline_file['lst_day_mar_mean'] + timeline_file['lst_night_mar_mean'])/2
timeline_file['lst_apr_mean'] = (timeline_file['lst_day_apr_mean'] + timeline_file['lst_night_apr_mean'])/2

# %%
timeline_file['dt_placement'] = pd.to_datetime(timeline_file['dt_placement'])
timeline_file['day'] = timeline_file['dt_placement'].apply(lambda x : x.day)
timeline_file['month'] = timeline_file['dt_placement'].apply(lambda x : x.month)
timeline_file['year'] = timeline_file['dt_placement'].apply(lambda x : x.year)

timeline_file = encode_cyclical(timeline_file, 'month', 12)

# %%
timeline_file.rename(columns={"lst_day_jan_mean": "lst_jan_day_mean",
                        "lst_day_feb_mean": "lst_feb_day_mean",
                        "lst_day_mar_mean": "lst_mar_day_mean",
                        "lst_day_apr_mean": "lst_apr_day_mean",
                        "lst_night_jan_mean": "lst_jan_night_mean",
                        "lst_night_feb_mean": "lst_feb_night_mean",
                        "lst_night_mar_mean": "lst_mar_night_mean",
                        "lst_night_apr_mean": "lst_apr_night_mean"}, inplace=True)

# %%
timeline_file
# Out:
#                x         y  cell_number dt_placement NUTS1_ID     NUTS1_NAME  \
# 0      21.763340 40.798060            0   2024-01-01      EL5  βορεια ελλαδα
# 1      21.763340 40.798060            0   2024-01-02      EL5  βορεια ελλαδα
# 2      21.763340 40.798060            0   2024-01-03      EL5  βορεια ελλαδα
# 3      21.763340 40.798060            0   2024-01-04      EL5  βορεια ελλαδα
# 4      21.763340 40.798060            0   2024-01-05      EL5  βορεια ελλαδα
# ...          ...       ...          ...          ...      ...            ...
# 808123 24.082170 40.995700         4415   2024-06-27      EL5  βορεια ελλαδα
# 808124 24.082170 40.995700         4415   2024-06-28      EL5  βορεια ελλαδα
# 808125 24.082170 40.995700         4415   2024-06-29      EL5  βορεια ελλαδα
# 808126 24.082170 40.995700         4415   2024-06-30      EL5  βορεια ελλαδα
# 808127 24.082170 40.995700         4415   2024-07-01      EL5  βορεια ελλαδα
#
#        NUTS2_ID          NUTS2_NAME NUTS3_ID NUTS3_NAME  LAU1_NAME  year  \
# 0          EL52  κεντρικη μακεδονια    EL524      πελλα    εδεσσας  2024
# 1          EL52  κεντρικη μακεδονια    EL524      πελλα    εδεσσας  2024
# 2          EL52  κεντρικη μακεδονια    EL524      πελλα    εδεσσας  2024
# 3          EL52  κεντρικη μακεδονια    EL524      πελλα    εδεσσας  2024
# 4          EL52  κεντρικη μακεδονια    EL524      πελλα    εδεσσας  2024
# ...         ...                 ...      ...        ...        ...   ...
# 808123     EL52  κεντρικη μακεδονια    EL526     σερρες  αμφιπολης  2024
# 808124     EL52  κεντρικη μακεδονια    EL526     σερρες  αμφιπολης  2024
# 808125     EL52  κεντρικη μακεδονια    EL526     σερρες  αμφιπολης  2024
# 808126     EL52  κεντρικη μακεδονια    EL526     σερρες  αμφιπολης  2024
# 808127     EL52  κεντρικη μακεδονια    EL526     σερρες  αμφιπολης  2024
#
#         month     ndvi      ndmi      ndwi     ndbi  ndvi_mean  ndmi_mean  \
# 0           1 0.329513 -0.087897 -0.308622 0.087897   0.321240  -0.084725
# 1           1 0.329513 -0.087897 -0.308622 0.087897   0.321240  -0.084725
# 2           1 0.329513 -0.087897 -0.308622 0.087897   0.321240  -0.084725
# 3           1 0.329513 -0.087897 -0.308622 0.087897   0.321240  -0.084725
# 4           1 0.329513 -0.087897 -0.308622 0.087897   0.321240  -0.084725
# ...       ...      ...       ...       ...      ...        ...        ...
# 808123      6 0.249392 -0.054278 -0.324742 0.054278   0.252126  -0.043821
# 808124      6 0.249392 -0.054278 -0.324742 0.054278   0.252126  -0.043821
# 808125      6 0.249392 -0.054278 -0.324742 0.054278   0.252126  -0.043821
# 808126      6 0.249392 -0.054278 -0.324742 0.054278   0.252126  -0.043821
# 808127      7 0.250723 -0.063707 -0.335736 0.063707   0.257580  -0.048487
#
#         ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std
# 2                 8.990075          8.990075    2.000000          3
# 3                 9.025947          9.025947    2.000000          3
# 4                 9.025947          9.025947    2.000000          3
# ...                    ...               ...         ...        ...
# 808123            0.000000        273.645107    2.000000          3
# 808124            0.000000        273.645107    2.000000          3
# 808125            0.000000        273.645107    2.000000          3
# 808126            0.000000        273.645107    2.000000          3
# 808127            0.000000        273.645107    2.000000          3
#
#         COAST_TYPE       lst  lst_jan_mean  lst_feb_mean  lst_mar_mean  \
# 0                2  1.930000      3.685806      6.480000      8.280968
# 1                2  5.760000      3.685806      6.480000      8.280968
# 2                2  5.910000      3.685806      6.480000      8.280968
# 3                2  8.740000      3.685806      6.480000      8.280968
# 4                2  8.740000      3.685806      6.480000      8.280968
# ...            ...       ...           ...           ...           ...
# 808123           1 29.200000      4.186129      8.352759     11.148710
# 808124           1 28.670000      4.186129      8.352759     11.148710
# 808125           1 31.270000      4.186129      8.352759     11.148710
# 808126           1 29.200000      4.186129      8.352759     11.148710
# 808127           1 32.140000      4.186129      8.352759     11.148710
#
#         lst_apr_mean  month_sin  month_cos
# 0          16.144800   0.500000   0.866025
# 1          16.144800   0.500000   0.866025
# 2          16.144800   0.500000   0.866025
# 3          16.144800   0.500000   0.866025
# 4          16.144800   0.500000   0.866025
# ...              ...        ...        ...
# 808123     18.423600   0.000000  -1.000000
# 808124     18.423600   0.000000  -1.000000
# 808125     18.423600   0.000000  -1.000000
# 808126     18.423600   0.000000  -1.000000
# 808127     18.423600  -0.500000  -0.866025
#
# [808128 rows x 51 columns]

# %%
timeline_file.rename(columns={"dt_placement": "dt_placement_daily"}, inplace=True)
timeline_file['date_string'] = timeline_file['month'].astype(str) + '-' + timeline_file['year'].astype(str)
timeline_file['dt_placement'] = pd.to_datetime(timeline_file['date_string'], format='%m-%Y').dt.to_period('M')
timeline_file.drop(columns=['date_string'], inplace = True)

# %%
gc.collect()
# Out:
# 0

# %%
grouped_by_month = timeline_file.drop(columns=['dt_placement_daily']).groupby(['cell_number','dt_placement','NUTS1_ID','NUTS1_NAME','NUTS2_ID','NUTS2_NAME','NUTS3_ID', 'NUTS3_NAME', 'LAU1_NAME'], as_index = False)

grouped_by_month_mean = grouped_by_month.mean()
grouped_by_month_min = grouped_by_month.min()
grouped_by_month_max = grouped_by_month.max()
grouped_by_month_sum = grouped_by_month.sum()
grouped_by_month_last = grouped_by_month.last()

# %%
del timeline_file
gc.collect()
# Out:
# 0

# %%
grouped_by_month_dataset = pd.concat([grouped_by_month_mean[['cell_number','dt_placement','NUTS1_ID','NUTS1_NAME','NUTS2_ID','NUTS2_NAME','NUTS3_ID','NUTS3_NAME','LAU1_NAME','x','y','MOUNT_TYPE','URBN_TYPE','COAST_TYPE','year','month']], 
                                     grouped_by_month_mean[['ndvi','ndmi','ndwi','ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std','ndmi_std','ndwi_std','ndbi_std']],
                                     grouped_by_month_mean[['lst_day','lst_night','lst']].rename(columns={'lst_day': 'lst_day_mean', 'lst_night': 'lst_night_mean', 'lst': 'lst_mean'}),
                                     grouped_by_month_last[['lst_jan_day_mean','lst_feb_day_mean','lst_mar_day_mean','lst_apr_day_mean', 'lst_jan_night_mean','lst_feb_night_mean','lst_mar_night_mean','lst_apr_night_mean','lst_jan_mean','lst_feb_mean','lst_mar_mean','lst_apr_mean']],
                                     grouped_by_month_mean[['rainfall']].rename(columns={'rainfall':'rainfall_mean'}),
                                     grouped_by_month_last[['acc_rainfall_1week','acc_rainfall_2week','acc_rainfall_month','acc_rainfall_jan']],
                                     grouped_by_month_min[['lst_day','lst_night']].rename(columns={'lst_day':'lst_day_min', 'lst_night': 'lst_night_min'}),
                                     grouped_by_month_max[['lst_day','lst_night']].rename(columns={'lst_day':'lst_day_max', 'lst_night': 'lst_night_max'}),
                                     grouped_by_month_sum[['rainfall']].rename(columns={'rainfall':'rainfall_acc'})], axis=1)

# %%
del grouped_by_month
del grouped_by_month_mean
del grouped_by_month_min
del grouped_by_month_max
del grouped_by_month_sum
del grouped_by_month_last

gc.collect()
# Out:
# 0

# %%
grouped_by_month_dataset.head()
# Out:
#    cell_number dt_placement NUTS1_ID     NUTS1_NAME NUTS2_ID  \
# 0            0      2024-01      EL5  βορεια ελλαδα     EL52
# 1            0      2024-02      EL5  βορεια ελλαδα     EL52
# 2            0      2024-03      EL5  βορεια ελλαδα     EL52
# 3            0      2024-04      EL5  βορεια ελλαδα     EL52
# 4            0      2024-05      EL5  βορεια ελλαδα     EL52
#
#            NUTS2_NAME NUTS3_ID NUTS3_NAME LAU1_NAME         x         y  \
# 0  κεντρικη μακεδονια    EL524      πελλα   εδεσσας 21.763340 40.798060
# 1  κεντρικη μακεδονια    EL524      πελλα   εδεσσας 21.763340 40.798060
# 2  κεντρικη μακεδονια    EL524      πελλα   εδεσσας 21.763340 40.798060
# 3  κεντρικη μακεδονια    EL524      πελλα   εδεσσας 21.763340 40.798060
# 4  κεντρικη μακεδονια    EL524      πελλα   εδεσσας 21.763340 40.798060
#
#    MOUNT_TYPE  URBN_TYPE  COAST_TYPE        year    month     ndvi      ndmi  \
# 0    2.000000   3.000000    2.000000 2024.000000 1.000000 0.267415  0.083574
# 1    2.000000   3.000000    2.000000 2024.000000 2.000000 0.244531  0.146571
# 2    2.000000   3.000000    2.000000 2024.000000 3.000000 0.324030 -0.109920
# 3    2.000000   3.000000    2.000000 2024.000000 4.000000 0.498411  0.043862
# 4    2.000000   3.000000    2.000000 2024.000000 5.000000 0.666505  0.221835
#
#        ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  \
# 0 -0.257810 -0.083574   0.241783   0.021266  -0.224117  -0.021266  0.021016
# 1 -0.258886 -0.146571   0.290309  -0.085296  -0.307094   0.085296  0.023339
# 2 -0.337069  0.109920   0.306936  -0.100461  -0.321696   0.100461  0.025461
# 3 -0.419718 -0.043862   0.471756   0.023727  -0.406067  -0.023727  0.044087
# 4 -0.546680 -0.221835   0.635158   0.202725  -0.527143  -0.202725  0.052198
#
#    ndmi_std  ndwi_std  ndbi_std  lst_day_mean  lst_night_mean  lst_mean  \
# 4            270.610234     7.050000       3.590000    27.530000
# ...                 ...          ...            ...          ...
# 30907        144.095731    12.490000       3.490000    25.150000
# 30908        207.200944    21.990000      -5.730000    30.750000
# 30909        273.645107    20.430000      11.150000    32.910000
# 30910        273.645107    28.330000      17.970000    42.750000
# 30911        273.645107    40.930000      23.350000    40.930000
#
#        lst_night_max  rainfall_acc
# 0           7.990000     45.502681
# 1           7.350000     37.534668
# 2           9.830000     46.540790
# 3          15.190000     70.283258
# 4          15.570000     70.748837
# ...              ...           ...
# 30907      11.490000     74.017514
# 30908      15.810000     63.105214
# 30909      16.190000     66.444162
# 30910      24.330000      0.000000
# 30911      23.350000      0.000000
#
# [30912 rows x 53 columns]

# %%
grouped_by_month_dataset['lst_min'] = grouped_by_month_dataset.apply(lambda row: min(row['lst_day_min'], row['lst_night_min']), axis=1)
grouped_by_month_dataset['lst_max'] = grouped_by_month_dataset.apply(lambda row: max(row['lst_day_max'], row['lst_night_max']), axis=1)

# %%
grouped_by_month_dataset.drop(columns=['lst_day_min', 'lst_night_min', 'lst_day_max', 'lst_night_max'], inplace=True)

# %%
grouped_by_month_dataset[['MOUNT_TYPE','URBN_TYPE','COAST_TYPE','year','month']] = grouped_by_month_dataset[['MOUNT_TYPE','URBN_TYPE','COAST_TYPE','year','month']].astype(int)

# %%
grouped_by_month_dataset
# Out:
#        cell_number dt_placement NUTS1_ID     NUTS1_NAME NUTS2_ID  \
# 0                0      2024-01      EL5  βορεια ελλαδα     EL52
# 1                0      2024-02      EL5  βορεια ελλαδα     EL52
# 2                0      2024-03      EL5  βορεια ελλαδα     EL52
# 3                0      2024-04      EL5  βορεια ελλαδα     EL52
# 4                0      2024-05      EL5  βορεια ελλαδα     EL52
# ...            ...          ...      ...            ...      ...
# 30907         4415      2024-03      EL5  βορεια ελλαδα     EL52
# 30908         4415      2024-04      EL5  βορεια ελλαδα     EL52
# 30909         4415      2024-05      EL5  βορεια ελλαδα     EL52
# 30910         4415      2024-06      EL5  βορεια ελλαδα     EL52
# 30911         4415      2024-07      EL5  βορεια ελλαδα     EL52
#
#                NUTS2_NAME NUTS3_ID NUTS3_NAME  LAU1_NAME         x         y  \
# 0      κεντρικη μακεδονια    EL524      πελλα    εδεσσας 21.763340 40.798060
# 1      κεντρικη μακεδονια    EL524      πελλα    εδεσσας 21.763340 40.798060
# 2      κεντρικη μακεδονια    EL524      πελλα    εδεσσας 21.763340 40.798060
# 3      κεντρικη μακεδονια    EL524      πελλα    εδεσσας 21.763340 40.798060
# 4      κεντρικη μακεδονια    EL524      πελλα    εδεσσας 21.763340 40.798060
# ...                   ...      ...        ...        ...       ...       ...
# 30907  κεντρικη μακεδονια    EL526     σερρες  αμφιπολης 24.082170 40.995700
# 30908  κεντρικη μακεδονια    EL526     σερρες  αμφιπολης 24.082170 40.995700
# 30909  κεντρικη μακεδονια    EL526     σερρες  αμφιπολης 24.082170 40.995700
# 30910  κεντρικη μακεδονια    EL526     σερρες  αμφιπολης 24.082170 40.995700
# 30911  κεντρικη μακεδονια    EL526     σερρες  αμφιπολ
# 30907         25.850000            1.270000            3.378276
# 30908         25.850000            1.270000            3.378276
# 30909         25.850000            1.270000            3.378276
# 30910         25.850000            1.270000            3.378276
# 30911         25.850000            1.270000            3.378276
#
#        lst_mar_night_mean  lst_apr_night_mean  lst_jan_mean  lst_feb_mean  \
# 0                2.594516            8.852400      3.685806      6.480000
# 1                2.594516            8.852400      3.685806      6.480000
# 2                2.594516            8.852400      3.685806      6.480000
# 3                2.594516            8.852400      3.685806      6.480000
# 4                2.594516            8.852400      3.685806      6.480000
# ...                   ...                 ...           ...           ...
# 30907            6.602903           10.997200      4.186129      8.352759
# 30908            6.602903           10.997200      4.186129      8.352759
# 30909            6.602903           10.997200      4.186129      8.352759
# 30910            6.602903           10.997200      4.186129      8.352759
# 30911            6.602903           10.997200      4.186129      8.352759
#
#        lst_mar_mean  lst_apr_mean  rainfall_mean  acc_rainfall_1week  \
# 0          8.280968     16.144800       1.467828            7.611751
# 1          8.280968     16.144800       1.294299           18.881823
# 2          8.280968     16.144800       1.551360           11.947780
# 3          8.280968     16.144800       2.423561            0.703507
# 4          8.280968     16.144800       2.358295            0.697901
# ...             ...           ...            ...                 ...
# 30907     11.148710     18.423600       2.467250            2.274147
# 30908     11.148710     18.423600       2.176042            1.151251
# 30909     11.148710     18.423600       2.214805            0.004186
# 30910     11.148710     18.423600       0.000000            0.000000
# 30911     11.148710     18.423600            NaN            0.000000
#
#        acc_rainfall_2week  acc_rainfall_month  acc_rainfall_jan  rainfall_acc  \
# 0               16.225668           45.498087         45.502681     45.502681
# 1               18.951474           37.534668         83.037349     37.534668
# 2               14.171614           29.937022        129.578139     46.540790
# 3               60.256993           70.283258        199.861397     70.283258
# 4               22.902835           70.748837        270.610234     70.748837
# ...                   ...                 ...               ...           ...
# 30907           13.784076           66.777001        144.095731     74.017514
# 30908           62.060012           63.105214        207.200944     63.105214
# 30909           15.850664           66.444162        273.645107     66.444162
# 30910            0.000000            0.000000        273.645107      0.000000
# 30911            0.000000            0.000000        273.645107      0.000000
#
#         lst_min   lst_max
# 0     -6.610000 12.870000
# 1     -5.290000 14.110000
# 2     -4.570000 24.350000
# 3     -1.550000 29.210000
# 4      3.590000 27.530000
# ...         ...       ...
# 30907  3.490000 25.150000
# 30908 -5.730000 30.750000
# 30909 11.150000 32.910000
# 30910 17.970000 42.750000
# 30911 23.350000 40.930000
#
# [30912 rows x 51 columns]

# %% [markdown]
# ### Add Geomorphological and Land Cover/Use

# %%
dataset_locations = grouped_by_month_dataset[['x', 'y']].drop_duplicates(keep='first')
dataset_locations.reset_index(drop = True, inplace = True)

# %%
dataset_locations_per_year = grouped_by_month_dataset[['x', 'y', 'year']].drop_duplicates(keep='first')
dataset_locations_per_year.reset_index(drop = True, inplace = True)

# %%
dataset_locations
# Out:
#              x         y
# 0    21.763340 40.798060
# 1    21.763340 40.798060
# 2    21.763340 40.816030
# 3    21.763340 40.816030
# 4    21.763340 40.834000
# ...        ...       ...
# 6815 24.082170 40.977730
# 6816 24.082170 40.977730
# 6817 24.082170 40.995700
# 6818 24.082170 40.995700
# 6819 24.082170 40.995700
#
# [6820 rows x 2 columns]

# %%
dataset_locations_per_year
# Out:
#              x         y  year
# 0    21.763340 40.798060  2024
# 1    21.763340 40.798060  2024
# 2    21.763340 40.816030  2024
# 3    21.763340 40.816030  2024
# 4    21.763340 40.834000  2024
# ...        ...       ...   ...
# 6815 24.082170 40.977730  2024
# 6816 24.082170 40.977730  2024
# 6817 24.082170 40.995700  2024
# 6818 24.082170 40.995700  2024
# 6819 24.082170 40.995700  2024
#
# [6820 rows x 3 columns]

# %%
geomorphological = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_GRID_Geomorphological.csv')
geomorphological.columns = geomorphological.columns.str.lower()

# %%
distances, indicies = calculate_nearest_topological(dataset_locations, geomorphological)
print(f'Min distance: {min(distances)}')
print(f'Max distance: {max(distances)}')
# Out:
# Min distance: 0.0
# Max distance: 1.5124900532045132e-12

# %%
df_geo = pd.DataFrame(columns=geomorphological.columns)

for index in indicies:
    df_geo = pd.concat([df_geo, geomorphological.iloc[[index]]], ignore_index=True)

df_geo.drop(columns=['x', 'y'], inplace = True)
df_geo.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\dimit\AppData\Local\Temp\ipykernel_22372\180837051.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_geo = pd.concat([df_geo, geomorphological.iloc[[index]]], ignore_index=True)

# %%
dataset_geo = pd.concat([dataset_locations, df_geo], axis=1, join = 'outer')
dataset_geo
# Out:
#              x         y  distance_to_coast  distance_to_river slope_mean_1km  \
# 0    21.763340 40.798060        1448.145975         456.840006              9
# 1    21.763340 40.798060        1448.145975         456.840006              9
# 2    21.763340 40.816030        2463.154314         575.852541             20
# 3    21.763340 40.816030        2463.154314         575.852541             20
# 4    21.763340 40.834000        3829.512564        2424.332192             15
# ...        ...       ...                ...                ...            ...
# 6815 24.082170 40.977730       22644.595043        1241.501789             12
# 6816 24.082170 40.977730       22644.595043        1241.501789             12
# 6817 24.082170 40.995700       23652.015602          77.289431              6
# 6818 24.082170 40.995700       23652.015602          77.289431              6
# 6819 24.082170 40.995700       23652.015602          77.289431              6
#
#       aspect_mean_200m  elevation_mean_1km  hillshade_mean_1km  fs_area_1km  \
# 0            75.660308          748.319206          158.266121     0.000000
# 1            75.660308          748.319206          158.266121     0.000000
# 2           187.414374          897.449167          168.372446     0.000000
# 3           187.414374          897.449167          168.372446     0.000000
# 4           132.525146         1204.950661          166.684023     0.000000
# ...                ...                 ...                 ...          ...
# 6815        146.332865          305.914835          187.156531     0.000000
# 6816        146.332865          305.914835          187.156531     0.000000
# 6817         67.526103           89.811181          175.312728     0.000000
# 6818         67.526103           89.811181          175.312728     0.000000
# 6819         67.526103           89.811181          175.312728     0.000000
#
#       flow_accu_200m
# 0           1.000000
# 1           1.000000
# 2           3.327142
# 3           3.327142
# 4          12.023969
# ...              ...
# 6815        4.770158
# 6816        4.770158
# 6817       87.702619
# 6818       87.702619
# 6819       87.702619
#
# [6820 rows x 10 columns]

# %%
dataset_geo.dtypes
# Out:
# x                     float64
# y                     float64
# distance_to_coast     float64
# distance_to_river     float64
# slope_mean_1km         object
# aspect_mean_200m      float64
# elevation_mean_1km    float64
# hillshade_mean_1km    float64
# fs_area_1km           float64
# flow_accu_200m        float64
# dtype: object

# %%
dataset_geo['slope_mean_1km'] = pd.to_numeric(dataset_geo['slope_mean_1km'], errors='coerce').astype('int64')

# %%
dataset_geo.dtypes
# Out:
# x                     float64
# y                     float64
# distance_to_coast     float64
# distance_to_river     float64
# slope_mean_1km          int64
# aspect_mean_200m      float64
# elevation_mean_1km    float64
# hillshade_mean_1km    float64
# fs_area_1km           float64
# flow_accu_200m        float64
# dtype: object

# %%
dataset_geo
# Out:
#              x         y  distance_to_coast  distance_to_river  \
# 0    21.763340 40.798060        1448.145975         456.840006
# 1    21.763340 40.798060        1448.145975         456.840006
# 2    21.763340 40.816030        2463.154314         575.852541
# 3    21.763340 40.816030        2463.154314         575.852541
# 4    21.763340 40.834000        3829.512564        2424.332192
# ...        ...       ...                ...                ...
# 6815 24.082170 40.977730       22644.595043        1241.501789
# 6816 24.082170 40.977730       22644.595043        1241.501789
# 6817 24.082170 40.995700       23652.015602          77.289431
# 6818 24.082170 40.995700       23652.015602          77.289431
# 6819 24.082170 40.995700       23652.015602          77.289431
#
#       slope_mean_1km  aspect_mean_200m  elevation_mean_1km  \
# 0                  9         75.660308          748.319206
# 1                  9         75.660308          748.319206
# 2                 20        187.414374          897.449167
# 3                 20        187.414374          897.449167
# 4                 15        132.525146         1204.950661
# ...              ...               ...                 ...
# 6815              12        146.332865          305.914835
# 6816              12        146.332865          305.914835
# 6817               6         67.526103           89.811181
# 6818               6         67.526103           89.811181
# 6819               6         67.526103           89.811181
#
#       hillshade_mean_1km  fs_area_1km  flow_accu_200m
# 0             158.266121     0.000000        1.000000
# 1             158.266121     0.000000        1.000000
# 2             168.372446     0.000000        3.327142
# 3             168.372446     0.000000        3.327142
# 4             166.684023     0.000000       12.023969
# ...                  ...          ...             ...
# 6815          187.156531     0.000000        4.770158
# 6816          187.156531     0.000000        4.770158
# 6817          175.312728     0.000000       87.702619
# 6818          175.312728     0.000000       87.702619
# 6819          175.312728     0.000000       87.702619
#
# [6820 rows x 10 columns]

# %%
landcover = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_GRID_Landcover_2001-2022.csv')
landcover.columns = landcover.columns.str.lower()

# %%
lc_columns = landcover.columns.tolist()
lc_columns = [x.split('_')[0] for x in lc_columns]

lc_columns
lc_years = set()

for i in range(0, len(lc_columns)):
    try:
        lc_years.add(int(lc_columns[i]))
    except ValueError:
        pass

lc_years = list(lc_years)

# %%
dates_ = re.compile(r"[0-9]{4}_[0-9]{2}_[0-9]{2}_")

for year in lc_years:
    frame_name = f'landcover_{year}'
    location_columns = ['x', 'y']
    filtered_columns = [col for col in landcover if col.startswith(f'{year}')]
    columns_to_keep = location_columns + filtered_columns
    locals()[frame_name] = landcover[columns_to_keep].copy()
    locals()[frame_name].insert(2, 'year', int(year))
    locals()[frame_name] = locals()[frame_name].rename(columns=lambda x: re.sub(dates_,'',x))

# %%
data_years = dataset_locations_per_year['year'].unique().tolist()

# %%
for year in data_years:
    frame_name = f'dataset_unique_points_annual_{year}'
    locals()[frame_name] = dataset_locations_per_year.query(f"year == {year}").copy()
    locals()[frame_name].reset_index(drop=True, inplace = True)

# %%
landcover_2024= landcover_2023 = landcover_2022

# %%
for year in data_years:
    data_name = f'dataset_unique_points_annual_{year}'
    lc_name = f'landcover_{year}'
    merged_name = f'dataset_unique_points_annual_part{year}'
    distances, indicies = calculate_nearest_topological(locals()[data_name], locals()[lc_name])
    print(f'Year: {year}\nMin distance: {min(distances)}\nMax distance: {max(distances)}')

    df_lulc = pd.DataFrame()

    for index in indicies:
        df_lulc = pd.concat([df_lulc, locals()[lc_name].iloc[[index]]], ignore_index=True)

    df_lulc.drop(columns=['x', 'y', 'year'], inplace = True)
    df_lulc.reset_index(drop=True, inplace=True)

    locals()[merged_name] = pd.concat([locals()[data_name], df_lulc], axis=1, join = 'outer')
# Out:
# Year: 2024
# Min distance: 0.0
# Max distance: 1.5124900532045132e-12

# %%
dataset_lulc = pd.DataFrame()

for year in data_years:
    merged_name = f'dataset_unique_points_annual_part{year}'
    dataset_lulc = pd.concat([dataset_lulc, locals()[merged_name]], ignore_index=True)

# %%
dataset_lulc
# Out:
#              x         y  year  lc_prop1  lc_prop1_assessment  lc_prop2  \
# 0    21.763340 40.798060  2024        31            80.000000        30
# 1    21.763340 40.798060  2024        31            80.000000        30
# 2    21.763340 40.816030  2024        22            81.000000        20
# 3    21.763340 40.816030  2024        22            81.000000        20
# 4    21.763340 40.834000  2024        31            97.000000        30
# ...        ...       ...   ...       ...                  ...       ...
# 6815 24.082170 40.977730  2024        11            96.000000        10
# 6816 24.082170 40.977730  2024        11            96.000000        10
# 6817 24.082170 40.995700  2024        31            87.000000        36
# 6818 24.082170 40.995700  2024        31            87.000000        36
# 6819 24.082170 40.995700  2024        31            87.000000        36
#
#       lc_prop2_assessment  lc_prop3  lc_prop3_assessment  lc_type1  lc_type2  \
# 0               80.000000        30            80.000000        10        10
# 1               80.000000        30            80.000000        10        10
# 2               81.000000        20            81.000000         9         9
# 3               81.000000        20            81.000000         9         9
# 4               97.000000        30            97.000000        10        10
# ...                   ...       ...                  ...       ...       ...
# 6815            97.000000        10            97.000000         1         1
# 6816            97.000000        10            97.000000         1         1
# 6817            88.000000        30            87.000000        12        12
# 6818            88.000000        30            87.000000        12        12
# 6819            88.000000        30            87.000000        12        12
#
#       lc_type3  lc_type4  lc_type5  lw  qc
# 0            1         6         6   2   0
# 1            1         6         6   2   0
# 2            4         4         4   2   0
# 3            4         4         4   2   0
# 4            1         6         6   2   0
# ...        ...       ...       ...  ..  ..
# 6815         7         1         1   2   0
# 6816         7         1         1   2   0
# 6817         3         5         8   2   0
# 6818         3         5         8   2   0
# 6819         3         5         8   2   0
#
# [6820 rows x 16 columns]

# %%
dataset_lulc.dtypes
# Out:
# x                      float64
# y                      float64
# year                     int32
# lc_prop1                 int64
# lc_prop1_assessment    float64
# lc_prop2                 int64
# lc_prop2_assessment    float64
# lc_prop3                 int64
# lc_prop3_assessment    float64
# lc_type1                 int64
# lc_type2                 int64
# lc_type3                 int64
# lc_type4                 int64
# lc_type5                 int64
# lw                       int64
# qc                       int64
# dtype: object

# %%
grouped_by_month_dataset = pd.merge(grouped_by_month_dataset, dataset_geo, on=['x', 'y'], how='left')

# %%
grouped_by_month_dataset = pd.merge(grouped_by_month_dataset, dataset_lulc, on=['x', 'y', 'year'], how='left')

# %% [markdown]
# ### Add Bio Variables ###

# %%
bio_values_df = grouped_by_month_dataset[['cell_number','year','month','rainfall_acc','lst_min','lst_max']]

# %%
bio_values_df.head(15)
# Out:
#     cell_number  year  month  rainfall_acc   lst_min   lst_max
# 0             0  2024      1     45.502681 -6.610000 12.870000
# 1             0  2024      2     37.534668 -5.290000 14.110000
# 2             0  2024      3     46.540790 -4.570000 24.350000
# 3             0  2024      4     70.283258 -1.550000 29.210000
# 4             0  2024      5     70.748837  3.590000 27.530000
# 5             0  2024      6      0.000000 13.730000 35.310000
# 6             0  2024      7      0.000000 21.270000 35.210000
# 7             1  2024      1     28.755997 -8.450000 11.290000
# 8             1  2024      2     47.363458 -4.890000 14.790000
# 9             1  2024      3     62.101817 -7.870000 24.050000
# 10            1  2024      4     67.969667 -2.510000 29.010000
# 11            1  2024      5     74.292547  3.930000 23.350000
# 12            1  2024      6      0.000000 13.790000 32.450000
# 13            1  2024      7      0.000000 20.150000 32.910000
# 14            2  2024      1     28.755997 -8.470000 10.510000

# %%
# wnv_file.head(5)

# %%
# wnv_file

# %%
grouped_by_month_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30912 entries, 0 to 30911
# Data columns (total 72 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cell_number          30912 non-null  int64
#  1   dt_placement         30912 non-null  period[M]
#  2   NUTS1_ID             30912 non-null  object
#  3   NUTS1_NAME           30912 non-null  object
#  4   NUTS2_ID             30912 non-null  object
#  5   NUTS2_NAME           30912 non-null  object
#  6   NUTS3_ID             30912 non-null  object
#  7   NUTS3_NAME           30912 non-null  object
#  8   LAU1_NAME            30912 non-null  object
#  9   x                    30912 non-null  float64
#  10  y                    30912 non-null  float64
#  11  MOUNT_TYPE           30912 non-null  int32
#  12  URBN_TYPE            30912 non-null  int32
#  13  COAST_TYPE           30912 non-null  int32
#  14  year                 30912 non-null  int32
#  15  month                30912 non-null  int32
#  16  ndvi                 30910 non-null  float64
#  17  ndmi                 30910 non-null  float64
#  18  ndwi                 30910 non-null  float64
#  19  ndbi                 30910 non-null  float64
#  20  ndvi_mean            30912 non-null  float64
#  21  ndmi_mean            30912 non-null  float64
#  22  ndwi_mean            30912 non-null  float64
#  23  ndbi_mean            30912 non-null  float64
#  24  ndvi_std             30912 non-null  float64
#  25  ndmi_std             30912 non-null  float64
#  26  ndwi_std             30912 non-null  float64
#  27  ndbi_std             30912 non-null  float64
#  28  lst_day_mean         30912 non-null  float64
#  29  lst_night_mean       30912 non-null  float64
#  30  lst_mean             30912 non-null  float64
#  31  lst_jan_day_mean     30912 non-null  float64
#  32  lst_feb_day_mean     30912 non-null  float64
#  33  lst_mar_day_mean     30912 non-null  float64
#  34  lst_apr_day_mean     30912 non-null  float64
#  35  lst_jan_night_mean   30912 non-null  float64
#  36  lst_feb_night_mean   30912 non-null  float64
#  37  lst_mar_night_mean   30912 non-null  float64
#  38  lst_apr_night_mean   30912 non-null  float64
#  39  lst_jan_mean         30912 non-null  float64
#  40  lst_feb_mean         30912 non-null  float64
#  41  lst_mar_mean         30912 non-null  float64
#  42  lst_apr_mean         30912 non-null  float64
#  43  rainfall_mean        26496 non-null  float64
#  44  acc_rainfall_1week   30912 non-null  float64
#  45  acc_rainfall_2week   30912 non-null  float64
#  46  acc_rainfall_month   30912 non-null  float64
#  47  acc_rainfall_jan     30912 non-null  float64
#  48  rainfall_acc         30912 non-null  float64
#  49  lst_min              30912 non-null  float64
#  50  lst_max              30912 non-null  float64
#  51  distance_to_coast    30912 non-null  float64
#  52  distance_to_river    30912 non-null  float64
#  53  slope_mean_1km       30912 non-null  int64
#  54  aspect_mean_200m     30912 non-null  float64
#  55  elevation_mean_1km   30912 non-null  float64
#  56  hillshade_mean_1km   30912 non-null  float64
#  57  fs_area_1km          30912 non-null  float64
#  58  flow_accu_200m       30912 non-null  float64
#  59  lc_prop1             30912 non-null  int64
#  60  lc_prop1_assessment  30814 non-null  float64
#  61  lc_prop2             30912 non-null  int64
#  62  lc_prop2_assessment  30415 non-null  float64
#  63  lc_prop3             30912 non-null  int64
#  64  lc_prop3_assessment  30814 non-null  float64
#  65  lc_type1             30912 non-null  int64
#  66  lc_type2             30912 non-null  int64
#  67  lc_type3             30912 non-null  int64
#  68  lc_type4             30912 non-null  int64
#  69  lc_type5             30912 non-null  int64
#  70  lw                   30912 non-null  int64
#  71  qc                   30912 non-null  int64
# dtypes: float64(47), int32(5), int64(12), object(7), period[M](1)
# memory usage: 16.4+ MB

# %%
# wnv_file.info()

# %%
# wnv_file['dt_placement'] = pd.to_datetime(wnv_file['dt_placement'], format='%Y-%m').dt.to_period('M')

# %%
# wnv_file.info()

# %%
# wnv_file

# %%
# wnv_file['cases'].value_counts()

# %%
# wnv_file.cases.sum()

# %%
# merged = grouped_by_month_dataset.merge(wnv_file, how='left', on=['dt_placement', 'cell_code'] )
merged = grouped_by_month_dataset

# %%
merged
# Out:
#        cell_number dt_placement NUTS1_ID     NUTS1_NAME NUTS2_ID  \
# 0                0      2024-01      EL5  βορεια ελλαδα     EL52
# 1                0      2024-02      EL5  βορεια ελλαδα     EL52
# 2                0      2024-03      EL5  βορεια ελλαδα     EL52
# 3                0      2024-04      EL5  βορεια ελλαδα     EL52
# 4                0      2024-05      EL5  βορεια ελλαδα     EL52
# ...            ...          ...      ...            ...      ...
# 30907         4415      2024-03      EL5  βορεια ελλαδα     EL52
# 30908         4415      2024-04      EL5  βορεια ελλαδα     EL52
# 30909         4415      2024-05      EL5  βορεια ελλαδα     EL52
# 30910         4415      2024-06      EL5  βορεια ελλαδα     EL52
# 30911         4415      2024-07      EL5  βορεια ελλαδα     EL52
#
# 1     -5.290000 14.110000        1448.145975         456.840006
# 2     -4.570000 24.350000        1448.145975         456.840006
# 3     -1.550000 29.210000        1448.145975         456.840006
# 4      3.590000 27.530000        1448.145975         456.840006
# ...         ...       ...                ...                ...
# 30907  3.490000 25.150000       23652.015602          77.289431
# 30908 -5.730000 30.750000       23652.015602          77.289431
# 30909 11.150000 32.910000       23652.015602          77.289431
# 30910 17.970000 42.750000       23652.015602          77.289431
# 30911 23.350000 40.930000       23652.015602          77.289431
#
#        slope_mean_1km  aspect_mean_200m  elevation_mean_1km  \
# 0                   9         75.660308          748.319206
# 1                   9         75.660308          748.319206
# 2                   9         75.660308          748.319206
# 3                   9         75.660308          748.319206
# 4                   9         75.660308          748.319206
# ...               ...               ...                 ...
# 30907               6         67.526103           89.811181
# 30908               6         67.526103           89.811181
# 30909               6         67.526103           89.811181
# 30910               6         67.526103           89.811181
# 30911               6         67.526103           89.811181
#
#        hillshade_mean_1km  fs_area_1km  flow_accu_200m  lc_prop1  \
# 0              158.266121     0.000000        1.000000        31
# 1              158.266121     0.000000        1.000000        31
# 2              158.266121     0.000000        1.000000        31
# 3              158.266121     0.000000        1.000000        31
# 4              158.266121     0.000000        1.000000        31
# ...                   ...          ...             ...       ...
# 30907          175.312728     0.000000       87.702619        31
# 30908          175.312728     0.000000       87.702619        31
# 30909          175.312728     0.000000       87.702619        31
# 30910          175.312728     0.000000       87.702619        31
# 30911          175.312728     0.000000       87.702619        31
#
#        lc_prop1_assessment  lc_prop2  lc_prop2_assessment  lc_prop3  \
# 0                80.000000        30            80.000000        30
# 1                80.000000        30            80.000000        30
# 2                80.000000        30            80.000000        30
# 3                80.000000        30            80.000000        30
# 4                80.000000        30            80.000000        30
# ...                    ...       ...                  ...       ...
# 30907            87.000000        36            88.000000        30
# 30908            87.000000        36            88.000000        30
# 30909            87.000000        36            88.000000        30
# 30910            87.000000        36            88.000000        30
# 30911            87.000000        36            88.000000        30
#
#        lc_prop3_assessment  lc_type1  lc_type2  lc_type3  lc_type4  lc_type5  \
# 0                80.000000        10        10         1         6         6
# 1                80.000000        10        10         1         6         6
# 2                80.000000        10        10         1         6         6
# 3                80.000000        10        10         1         6         6
# 4                80.000000        10        10         1         6         6
# ...                    ...       ...       ...       ...       ...       ...
# 30907            87.000000        12        12         3         5         8
# 30908            87.000000        12        12         3         5         8
# 30909            87.000000        12        12         3         5         8
# 30910            87.000000        12        12         3         5         8
# 30911            87.000000        12        12         3         5         8
#
#        lw  qc
# 0       2   0
# 1       2   0
# 2       2   0
# 3       2   0
# 4       2   0
# ...    ..  ..
# 30907   2   0
# 30908   2   0
# 30909   2   0
# 30910   2   0
# 30911   2   0
#
# [30912 rows x 72 columns]

# %%
# merged = fillna(merged,{'cases': 0})

# %%
# merged['cases'].value_counts()

# %%
# merged.cases.sum()

# %%
# merged = merged.astype({'cases': 'int'})

# %%
missingno.matrix(merged)
# Out:
# <Axes: >

# %%
gc.collect()
# Out:
# 0

# %%
imputer = KNNImputer()

knn_imputer_columns = ['x', 'y', 'month', 'year', 'lst_min', 'lst_max']

temp_df = merged[knn_imputer_columns]

imputed_data = pd.DataFrame(imputer.fit_transform(temp_df), columns = temp_df.columns)
imputed_columns = ['lst_min', 'lst_max']

merged[imputed_columns] = imputed_data[imputed_columns]

# %%
missingno.matrix(merged)
# Out:
# <Axes: >

# %%
years = merged.year.unique()
years
# Out:
# array([2024])

# %%
cell_codes_un = merged.cell_number.unique()
cell_codes_un
# Out:
# array([   0,    1,    2, ..., 4413, 4414, 4415], dtype=int64)

# %%
rows = []
for year in years:
    for cell in cell_codes_un:
        filtered_df = merged.loc[(merged['year'] == year) & (merged['cell_number'] == cell)].copy()
        filtered_df.reset_index(drop = True, inplace = True)

        tmin = robjects.IntVector(filtered_df['lst_min'].tolist())
        tmax = robjects.IntVector(filtered_df['lst_max'].tolist())
        prec = robjects.IntVector(filtered_df['rainfall_acc'].tolist())

        bio_vars = list(dismo.biovars(prec, tmin, tmax))

        rows.append({'cell_number': cell, 
                     'year': year, 
                     'bio1': bio_vars[0],
                     'bio2': bio_vars[1],
                     'bio3': bio_vars[2],
                     'bio4': bio_vars[3],
                     'bio5': bio_vars[4],
                     'bio6': bio_vars[5],
                     'bio7': bio_vars[6],
                     'bio8': bio_vars[7],
                     'bio9': bio_vars[8],
                     'bio10': bio_vars[9],
                     'bio11': bio_vars[10],
                     'bio12': bio_vars[11],
                     'bio13': bio_vars[12],
                     'bio14': bio_vars[13],
                     'bio15': bio_vars[14],
                     'bio16': bio_vars[15],
                     'bio17': bio_vars[16],
                     'bio18': bio_vars[17],
                     'bio19': bio_vars[18]})
        
biovars_df = pd.DataFrame(rows)

# %%
biovars_df.head(20)
# Out:
#     cell_number  year      bio1      bio2      bio3        bio4      bio5  \
# 0             0  2024 14.071429 22.142857 54.006969  934.714115 35.000000
# 1             1  2024 12.857143 21.428571 53.571429  890.558947 32.000000
# 2             2  2024 13.000000 20.000000 50.000000  837.655458 32.000000
# 3             3  2024 12.357143 18.142857 51.836735  759.777536 29.000000
# 4             4  2024 14.928571 11.285714 40.306122  777.511292 29.000000
# 5             5  2024 14.214286 22.142857 52.721088  917.813136 34.000000
# 6             6  2024 14.714286 20.285714 48.299320  896.222230 35.000000
# 7             7  2024 12.857143 19.142857 51.737452  730.133712 30.000000
# 8             8  2024 13.857143  8.000000 32.000000  781.938982 27.000000
# 9             9  2024 13.571429  8.571429 32.967033  760.717080 28.000000
# 10           10  2024 13.785714  7.857143 34.161491  735.899191 26.000000
# 11           11  2024 13.500000 10.714286 36.945813  790.042193 27.000000
# 12           12  2024 14.642857 24.714286 53.726708  952.502968 37.000000
# 13           13  2024 15.928571 22.714286 52.823920  920.338964 37.000000
# 14           14  2024 14.642857 20.428571 51.071429  848.387827 34.000000
# 15           15  2024 14.500000 22.714286 51.623377  969.965635 37.000000
# 16           16  2024 14.357143 22.428571 50.974026 1004.039460 37.000000
# 17           17  2024 14.000000 19.714286 49.285714  959.166305 35.000000
# 18           18  2024 12.142857 17.714286 49.206349  896.155811 31.000000
# 19           19  2024 13.142857 20.857143 53.479853  944.596160 33.000000
#
#         bio6      bio7      bio8      bio9     bio10    bio11      bio12  \
# 0  -6.000000 41.000000 13.000000 18.333333 22.333333 5.833333 268.000000
# 18 96.000000 0.000000 84.344421 215.000000 20.000000 60.000000 135.000000
# 19 96.000000 0.000000 84.344421 215.000000 20.000000 60.000000 135.000000

# %%
merged = pd.merge(merged, biovars_df,  how='left', on=['cell_number', 'year'])

# %%
##check if biovars have the same value across all months
merged.loc[(merged['year'] == 2024) & (merged['cell_number'] == 0)]
# Out:
#    cell_number dt_placement NUTS1_ID     NUTS1_NAME NUTS2_ID  \
# 0            0      2024-01      EL5  βορεια ελλαδα     EL52
# 1            0      2024-02      EL5  βορεια ελλαδα     EL52
# 2            0      2024-03      EL5  βορεια ελλαδα     EL52
# 3            0      2024-04      EL5  βορεια ελλαδα     EL52
# 4            0      2024-05      EL5  βορεια ελλαδα     EL52
# 5            0      2024-06      EL5  βορεια ελλαδα     EL52
# 6            0      2024-07      EL5  βορεια ελλαδα     EL52
#
#            NUTS2_NAME NUTS3_ID NUTS3_NAME LAU1_NAME         x         y  \
# 0  κεντρικη μακεδονια    EL524      πελλα   εδεσσας 21.763340 40.798060
# 1  κεντρικη μακεδονια    EL524      πελλα   εδεσσας 21.763340 40.798060
# 2  κεντρικη μακεδονια    EL524      πελλα   εδεσσας 21.763340 40.798060
# 3  κεντρικη μακεδονια    EL524      πελλα   εδεσσας 21.763340 40.798060
# 4  κεντρικη μακεδονια    EL524      πελλα   εδεσσας 21.763340 40.798060
# 5  κεντρικη μακεδονια    EL524      πελλα   εδεσσας 21.763340 40.798060
# 6  κεντρικη μακεδονια    EL524      πελλα   εδεσσας 21.763340 40.798060
#
#    MOUNT_TYPE  URBN_TYPE  COAST_TYPE  year  month     ndvi      ndmi  \
# 0           2          3           2  2024      1 0.267415  0.083574
# 1           2          3           2  2024      2 0.244531  0.146571
# 2           2          3           2  2024      3 0.324030 -0.109920
# 3           2          3           2  2024      4 0.498411  0.043862
# 4           2          3           2  2024      5 0.666505  0.221835
# 5           2          3           2  2024      6 0.643850  0.177403
# 6           2          3           2  2024      7 0.653333  0.161383
#
#        ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  \
# 0 -0.257810 -0.083574   0.241783   0.021266  -0.224117  -0.021266  0.021016
# 1 -0.258886 -0.146571   0.290309  -0.085296  -0.307094   0.085296  0.023339
# 2 -0.337069  0.109920   0.306936  -0.100461  -0.321696   0.100461  0.025461
# 3 -0.419718 -0.043862   0.471756   0.023727  -0.406067  -0.023727  0.044087
# 4 -0.546680 -0.221835   0.635158   0.202725  -0.527143  -0.202725  0.052198
# 5 -0.535152 -0.177403   0.606088   0.153313  -0.512681  -0.153313  0.050366
# 6 -0.546283 -0.161383   0.609354   0.132829  -0.521642  -0.132829  0.059097
#
#    ndmi_std  ndwi_std  ndbi_std  lst_day_mean  lst_night_mean  lst_mean  \
# 0  0.055956  0.024599  0.055956      6.433226        0.938387  3.685806
# 1  0.022974  0.011478  0.022974     10.222414        2.737586  6.480000
# 2  0.024213  0.015288  0.024213     13.967419        2.594516  8.280968
# 3  0.046540  0.023812  0.046540     23.437200        8.852400 16.144800
# 4  0.064876  0.035096  0.064876     19.902143       11.425714 15.663929
c_type1  lc_type2  lc_type3  lc_type4  lc_type5  lw  \
# 0            80.000000        10        10         1         6         6   2
# 1            80.000000        10        10         1         6         6   2
# 2            80.000000        10        10         1         6         6   2
# 3            80.000000        10        10         1         6         6   2
# 4            80.000000        10        10         1         6         6   2
# 5            80.000000        10        10         1         6         6   2
# 6            80.000000        10        10         1         6         6   2
#
#    qc      bio1      bio2      bio3       bio4      bio5      bio6      bio7  \
# 0   0 14.071429 22.142857 54.006969 934.714115 35.000000 -6.000000 41.000000
# 1   0 14.071429 22.142857 54.006969 934.714115 35.000000 -6.000000 41.000000
# 2   0 14.071429 22.142857 54.006969 934.714115 35.000000 -6.000000 41.000000
# 3   0 14.071429 22.142857 54.006969 934.714115 35.000000 -6.000000 41.000000
# 4   0 14.071429 22.142857 54.006969 934.714115 35.000000 -6.000000 41.000000
# 5   0 14.071429 22.142857 54.006969 934.714115 35.000000 -6.000000 41.000000
# 6   0 14.071429 22.142857 54.006969 934.714115 35.000000 -6.000000 41.000000
#
#        bio8      bio9     bio10    bio11      bio12     bio13    bio14  \
# 0 13.000000 18.333333 22.333333 5.833333 268.000000 70.000000 0.000000
# 1 13.000000 18.333333 22.333333 5.833333 268.000000 70.000000 0.000000
# 2 13.000000 18.333333 22.333333 5.833333 268.000000 70.000000 0.000000
# 3 13.000000 18.333333 22.333333 5.833333 268.000000 70.000000 0.000000
# 4 13.000000 18.333333 22.333333 5.833333 268.000000 70.000000 0.000000
# 5 13.000000 18.333333 22.333333 5.833333 268.000000 70.000000 0.000000
# 6 13.000000 18.333333 22.333333 5.833333 268.000000 70.000000 0.000000
#
#       bio15      bio16     bio17     bio18      bio19
# 0 73.843256 186.000000 45.000000 70.000000 128.000000
# 1 73.843256 186.000000 45.000000 70.000000 128.000000
# 2 73.843256 186.000000 45.000000 70.000000 128.000000
# 3 73.843256 186.000000 45.000000 70.000000 128.000000
# 4 73.843256 186.000000 45.000000 70.000000 128.000000
# 5 73.843256 186.000000 45.000000 70.000000 128.000000
# 6 73.843256 186.000000 45.000000 70.000000 128.000000

# %%
df_demographics = pd.read_csv(r'E:\Drive\NOA\MBD-Prediction\NUTS3 Level\Greece\data\GR_EUROSTAT_Demographics_Processed.csv', encoding = enc)

# %%
df_demographics
# Out:
#      NUTS3_CODE  YEAR     M_Y_LT15      M_Y15-64     M_Y_GE65       M_TOTAL  \
# 0         EL301  1991 51138.000000 165030.000000 25941.000000 242109.000000
# 1         EL301  1992 50517.000000 170015.000000 27446.000000 247978.000000
# 2         EL301  1993 49861.000000 173915.000000 28721.000000 252497.000000
# 3         EL301  1994 48815.000000 177441.000000 30222.000000 256478.000000
# 4         EL301  1995 47801.000000 180431.000000 31701.000000 259933.000000
df_economics = pd.read_csv(r'E:\Drive\NOA\MBD-Prediction\NUTS3 Level\Greece\data\GR_EUROSTAT_Economics_Processed.csv', encoding = enc)

# %%
df_economics
# Out:
#      NUTS3_CODE  YEAR      MIO_EUR
# 0         EL301  2000 10002.340000
# 1         EL301  2001 10677.520000
# 2         EL301  2002 12022.340000
# 3         EL301  2003 12784.960000
# 4         EL301  2004 14149.980000
# ...         ...   ...          ...
# 1139      EL653  2017  3112.330000
# 1140      EL653  2018  3111.760000
# 1141      EL653  2019  3149.580000
# 1142      EL653  2020  2795.860000
# 1143      EL653  2021  2991.500000
#
# [1144 rows x 3 columns]

# %%
df_economics.rename(columns={'NUTS3_CODE': 'NUTS3_ID', 'YEAR': 'year'}, inplace=True)

# %%
df_economics
# Out:
#      NUTS3_ID  year      MIO_EUR
# 0       EL301  2000 10002.340000
# 1       EL301  2001 10677.520000
# 2       EL301  2002 12022.340000
# 3       EL301  2003 12784.960000
# 4       EL301  2004 14149.980000
# ...       ...   ...          ...
# 1139    EL653  2017  3112.330000
# 1140    EL653  2018  3111.760000
# 1141    EL653  2019  3149.580000
# 1142    EL653  2020  2795.860000
# 1143    EL653  2021  2991.500000
#
# [1144 rows x 3 columns]

# %%
dataset = pd.merge(dataset, df_economics,  how='left', on=['NUTS3_ID', 'year'])

# %%
missingno.matrix(dataset)
# Out:
# <Axes: >

# %%
df_trade = pd.read_csv(r'E:\Drive\NOA\MBD-Prediction\NUTS3 Level\Greece\data\GR_EUROSTAT_Trade_Processed.csv', encoding = enc)

# %%
df_trade
# Out:
#     NUTS3_CODE  YEAR      L_TOTAL    UNL_TOTAL
# 0        EL111  2008  6704.000000  7125.000000
# 1        EL111  2009  3031.000000  3303.000000
# 2        EL111  2010  2663.000000  2085.000000
# 3        EL111  2011  4163.000000  4212.000000
# 4        EL111  2012  4379.000000  5029.000000
# ..         ...   ...          ...          ...
# 766      EL653  2018  2358.000000  2885.000000
# 767      EL653  2019  2914.000000  3549.000000
# 768      EL653  2020  4572.000000  4962.000000
# 769      EL653  2021  3040.000000  3666.000000
# 770      EL653  2022 11830.000000 12294.000000
#
# [771 rows x 4 columns]

# %%
df_trade.rename(columns={'NUTS3_CODE': 'NUTS3_ID', 'YEAR': 'year'}, inplace=True)

# %%
df_trade
# Out:
#     NUTS3_ID  year      L_TOTAL    UNL_TOTAL
# 0      EL111  2008  6704.000000  7125.000000
# 1      EL111  2009  3031.000000  3303.000000
# 2      EL111  2010  2663.000000  2085.000000
# 3      EL111  2011  4163.000000  4212.000000
# 4      EL111  2012  4379.000000  5029.000000
# ..       ...   ...          ...          ...
# 766    EL653  2018  2358.000000  2885.000000
# 767    EL653  2019  2914.000000  3549.000000
# 768    EL653  2020  4572.000000  4962.000000
# 769    EL653  2021  3040.000000  3666.000000
# 770    EL653  2022 11830.000000 12294.000000
#
# [771 rows x 4 columns]

# %%
dataset = pd.merge(dataset, df_trade,  how='left', on=['NUTS3_ID', 'year'])

# %%
missingno.matrix(dataset)
# Out:
# <Axes: >

# %%
missing = describe_dataframe(dataset, remove_zeros=True)

# %%
missing
# Out:
#                   Column    Missing
# 16                  ndvi   0.006500
# 17                  ndmi   0.006500
# 18                  ndwi   0.006500
# 19                  ndbi   0.006500
# 43         rainfall_mean  14.285700
# 60   lc_prop1_assessment   0.317000
# 62   lc_prop2_assessment   1.607800
# 64   lc_prop3_assessment   0.317000
# 91              M_Y_LT15 100.000000
# 92              M_Y15-64 100.000000
# 93              M_Y_GE65 100.000000
# 94               M_TOTAL 100.000000
# 95              F_Y_LT15 100.000000
# 96              F_Y15-64 100.000000
# 97              F_Y_GE65 100.000000
# 98               F_TOTAL 100.000000
# 99               MIO_EUR 100.000000
# 100              L_TOTAL 100.000000
# 101            UNL_TOTAL 100.000000

# %%
dataset
# Out:
#        cell_number dt_placement NUTS1_ID     NUTS1_NAME NUTS2_ID  \
# 0                0      2024-01      EL5  βορεια ελλαδα     EL52
# 1                0      2024-02      EL5  βορεια ελλαδα     EL52
# 2                0      2024-03      EL5  βορεια ελλαδα     EL52
# 3                0      2024-04      EL5  βορεια ελλαδα     EL52
# 4                0      2024-05      EL5  βορεια ελλαδα     EL52
# ...            ...          ...      ...            ...      ...
# 30907         4415      2024-03      EL5  βορεια ελλαδα     EL52
# 30908         4415      2024-04      EL5  βορεια ελλαδα     EL52
# 30909         4415      2024-05      EL5  βορεια ελλαδα     EL52
# 30910         4415      2024-06      EL5  βορεια ελλαδα     EL52
# 30911         4415      2024-07      EL5  βορεια ελλαδα     EL52
#
#                NUTS2_NAME NUTS3_ID NUTS3_NAME  LAU1_NAME         x         y  \
# 0      κεντρικη μακεδονια    EL524      πελλα    εδεσσας 21.763340 40.798060
# 1      κεντρικη μακεδονια    EL524      πελλα    εδεσσας 21.763340 40.798060
# 2      κεντρικη μακεδονια    EL524      πελλα    εδεσσας 21.763340 40.798060
# 3      κεντρικη μακεδονια    EL524      πελλα    εδεσσας 21.763340 40.798060
# 4      κεντρικη μακεδονια    EL524      πελλα    εδεσσας 21.763340 40.798060
# ...                   ...      ...        ...        ...       ...       ...
# 30907  κεντρικη μακεδονια    EL526     σερρες  αμφιπολης 24.082170 40.995700
# 30908  κεντρικη μακεδονια    EL526     σερρες  αμφιπολης 24.082170 40.995700
# 30909  κεντρικη μακεδονια    EL526     σερρες  αμφιπολης 24.082170 40.995700
# 30910  κεντρικη μακεδονια    EL526     σερρες  αμφιπολης 24.082170 40.995700
# 30911  κεντρικη μακεδονια    EL526     σερρες  αμφιπολης 24.082170 40.995700
#
#        MOUNT_TYPE  URBN_TYPE  COAST_TYPE  year  month     ndvi      ndmi  \
# 0               2          3           2  2024      1 0.267415  0.083574
# 1               2          3           2  2024      2 0.244531  0.146571
# 2               2          3           2  2024      3 0.324030 -0.109920
# 3               2          3           2  2024      4 0.498411  0.043862
# 4               2          3           2  2024      5 0.666505  0.221835
# ...           ...        ...         ...   ...    ...      ...       ...
# 30907           2          3           1  2024      3 0.496196  0.119184
# 30908           2          3           1  2024      4 0.519274  0.157851
# 30909           2          3           1  2024      5 0.454293  0.109279
# 30910           2          3           1  2024      6 0.280659 -0.008379
# 30911           2          3           1  2024      7 0.250723 -0.063707
#
#            ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean
#        lc_prop1_assessment  lc_prop2  lc_prop2_assessment  lc_prop3  \
# 0                80.000000        30            80.000000        30
# 1                80.000000        30            80.000000        30
# 2                80.000000        30            80.000000        30
# 3                80.000000        30            80.000000        30
# 4                80.000000        30            80.000000        30
# ...                    ...       ...                  ...       ...
# 30907            87.000000        36            88.000000        30
# 30908            87.000000        36            88.000000        30
# 30909            87.000000        36            88.000000        30
# 30910            87.000000        36            88.000000        30
# 30911            87.000000        36            88.000000        30
#
#        lc_prop3_assessment  lc_type1  lc_type2  lc_type3  lc_type4  lc_type5  \
# 0                80.000000        10        10         1         6         6
# 1                80.000000        10        10         1         6         6
# 2                80.000000        10        10         1         6         6
# 3                80.000000        10        10         1         6         6
# 4                80.000000        10        10         1         6         6
# ...                    ...       ...       ...       ...       ...       ...
# 30907            87.000000        12        12         3         5         8
# 30908            87.000000        12        12         3         5         8
# 30909            87.000000        12        12         3         5         8
# 30910            87.000000        12        12         3         5         8
# 30911            87.000000        12        12         3         5         8
#
#        lw  qc      bio1      bio2      bio3        bio4      bio5      bio6  \
# 0       2   0 14.071429 22.142857 54.006969  934.714115 35.000000 -6.000000
# 1       2   0 14.071429 22.142857 54.006969  934.714115 35.000000 -6.000000
# 2       2   0 14.071429 22.142857 54.006969  934.714115 35.000000 -6.000000
# 3       2   0 14.071429 22.142857 54.006969  934.714115 35.000000 -6.000000
# 4       2   0 14.071429 22.142857 54.006969  934.714115 35.000000 -6.000000
# ...    ..  ..       ...       ...       ...         ...       ...       ...
# 30907   2   0 16.928571 22.714286 48.328267 1097.128286 42.000000 -5.000000
# 30908   2   0 16.928571 22.714286 48.328267 1097.128286 42.000000 -5.000000
# 30909   2   0 16.928571 22.714286 48.328267 1097.128286 42.000000 -5.000000
# 30910   2   0 16.928571 22.714286 48.328267 1097.128286 42.000000 -5.000000
# 30911   2   0 16.928571 22.714286 48.328267 1097.128286 42.000000 -5.000000
#
#            bio7      bio8      bio9     bio10    bio11      bio12     bio13  \
# 0     41.000000 13.000000 18.333333 22.333333 5.833333 268.000000 70.000000
# 1     41.000000 13.000000 18.333333 22.333333 5.833333 268.000000 70.000000
# 2     41.000000 13.000000 18.333333 22.333333 5.833333 268.000000 70.000000
# 3     41.000000 13.000000 18.333333 22.333333 5.833333 268.000000 70.000000
# 4     41.000000 13.000000 18.333333 22.333333 5.833333 268.000000 70.000000
# ...         ...       ...       ...       ...      ...        ...       ...
# 30907 47.000000 16.000000 21.333333 27.500000 7.833333 272.000000 74.000000
# 30908 47.000000 16.000000 21.333333 27.500000 7.833333 272.000000 74.000000
# 30909 47.000000 16.000000 21.333333 27.500000 7.833333 272.000000 74.000000
# 30910 47.000000 16.000000 21.333333 27.500000 7.833333 272.000000 74.000000
# 30911 47.000000 16.000000 21.333333 27.500000 7.833333 272.000000 74.000000
#
#          bio14     bio15      bio16     bio17     bio18      bio19  M_Y_LT15  \
# 0     0.000000 73.843256 186.000000 45.000000 70.000000 128.000000       NaN
# 1     0.000000 73.843256 186.000000 45.000000 70.000000 128.000000       NaN
# 2     0.000000 73.843256 186.000000 45.000000 70.000000 128.000000       NaN
# 3     0.000000 73.843256 186.000000 45.000000 70.000000 128.000000       NaN
# 4     0.000000 73.843256 186.000000 45.000000 70.000000 128.000000       NaN
# ...        ...       ...        ...       ...       ...        ...       ...
# 30907 0.000000 85.162226 203.000000 60.000000 66.000000 143.000000       NaN
# 30908 0.000000 85.162226 203.000000 60.000000 66.000000 143.000000       NaN
# 30909 0.000000 85.162226 203.000000 60.000000 66.000000 143.000000       NaN
# 30910 0.000000 85.162226 203.000000 60.000000 66.000000 143.000000       NaN
# 30911 0.000000 85.162226 203.000000 60.000000 66.000000 143.000000       NaN
#
#        M_Y15-64  M_Y_GE65  M_TOTAL  F_Y_LT15  F_Y15-64  F_Y_GE65  F_TOTAL  \
# 0           NaN       NaN      NaN       NaN       NaN       NaN      NaN
# 1           NaN       NaN      NaN       NaN       NaN       NaN      NaN
# 2           NaN       NaN      NaN       NaN       NaN       NaN      NaN
# 3           NaN       NaN      NaN       NaN       NaN       NaN      NaN
# 4           NaN       NaN      NaN       NaN       NaN       NaN      NaN
# ...         ...       ...      ...       ...       ...       ...      ...
# 30907       NaN       NaN      NaN       NaN       NaN       NaN      NaN
# 30908       NaN       NaN      NaN       NaN       NaN       NaN      NaN
# 30909       NaN       NaN      NaN       NaN       NaN       NaN      NaN
# 30910       NaN       NaN      NaN       NaN       NaN       NaN      NaN
# 30911       NaN       NaN      NaN       NaN       NaN       NaN      NaN
#
#        MIO_EUR  L_TOTAL  UNL_TOTAL
# 0          NaN      NaN        NaN
# 1          NaN      NaN        NaN
# 2          NaN      NaN        NaN
# 3          NaN      NaN        NaN
# 4          NaN      NaN        NaN
# ...        ...      ...        ...
# 30907      NaN      NaN        NaN
# 30908      NaN      NaN        NaN
# 30909      NaN      NaN        NaN
# 30910      NaN      NaN        NaN
# 30911      NaN      NaN        NaN
#
# [30912 rows x 102 columns]

# %%
dataset.reset_index(inplace=True, drop=True)

# %%
# dataset['cases'].value_counts()

# %%
# dataset['cases'].sum()

# %%
dataset
# Out:
#        cell_number dt_placement NUTS1_ID     NUTS1_NAME NUTS2_ID  \
# 0                0      2024-01      EL5  βορεια ελλαδα     EL52
# 1                0      2024-02      EL5  βορεια ελλαδα     EL52
# 2                0      2024-03      EL5  βορεια ελλαδα     EL52
# 3                0      2024-04      EL5  βορεια ελλαδα     EL52
# 4                0      2024-05      EL5  βορεια ελλαδα     EL52
# ...            ...          ...      ...            ...      ...
# 30907         4415      2024-03      EL5  βορεια ελλαδα     EL52
# 30908         4415      2024-04      EL5  βορεια ελλαδα     EL52
# 30909         4415      2024-05      EL5  βορεια ελλαδα     EL52
# 30910         4415      2024-06      EL5  βορεια ελλαδα     EL52
# 30911         4415      2024-07      EL5  βορεια ελλαδα     EL52
#
#                NUTS2_NAME NUTS3_ID NUTS3_NAME  LAU1_NAME         x         y  \
# 0      κεντρικη μακεδονια    EL524      πελλα    εδεσσας 21.763340 40.798060
# 1      κεντρικη μακεδονια    EL524      πελλα    εδεσσας 21.763340 40.798060
# 2      κεντρικη μακεδονια    EL524      πελλα    εδεσσας 21.763340 40.798060
# 3      κεντρικη μακεδονια    EL524      πελλα    εδεσσας 21.763340 40.798060
# 4      κεντρικη μακεδονια    EL524      πελλα    εδεσσας 21.763340 40.798060
# ...                   ...      ...        ...        ...       ...       ...
# 30907  κεντρικη μακεδονια    EL526     σερρες  αμφιπολης 24.082170 40.995700
# 30908  κεντρικη μακεδονια    EL526     σερρες  αμφιπολης 24.082170 40.995700
# 30909  κεντρικη μακεδονια    EL526     σερρες  αμφιπολ
# 2                   9         75.660308          748.319206
# 3                   9         75.660308          748.319206
# 4                   9         75.660308          748.319206
# ...               ...               ...                 ...
# 30907               6         67.526103           89.811181
# 30908               6         67.526103           89.811181
# 30909               6         67.526103           89.811181
# 30910               6         67.526103           89.811181
# 30911               6         67.526103           89.811181
#
#        hillshade_mean_1km  fs_area_1km  flow_accu_200m  lc_prop1  \
# 0              158.266121     0.000000        1.000000        31
# 1              158.266121     0.000000        1.000000        31
# 2              158.266121     0.000000        1.000000        31
# 3              158.266121     0.000000        1.000000        31
# 4              158.266121     0.000000        1.000000        31
# ...                   ...          ...             ...       ...
# 30907          175.312728     0.000000       87.702619        31
# 30908          175.312728     0.000000       87.702619        31
# 30909          175.312728     0.000000       87.702619        31
# 30910          175.312728     0.000000       87.702619        31
# 30911          175.312728     0.000000       87.702619        31
#
#        lc_prop1_assessment  lc_prop2  lc_prop2_assessment  lc_prop3  \
# 0                80.000000        30            80.000000        30
# 1                80.000000        30            80.000000        30
# 2                80.000000        30            80.000000        30
# 3                80.000000        30            80.000000        30
# 4                80.000000        30            80.000000        30
# ...                    ...       ...                  ...       ...
# 30907            87.000000        36            88.000000        30
# 30908            87.000000        36            88.000000        30
# 30909            87.000000        36            88.000000        30
# 30910            87.000000        36            88.000000        30
# 30911            87.000000        36            88.000000        30
#
#        lc_prop3_assessment  lc_type1  lc_type2  lc_type3  lc_type4  lc_type5  \
# 0                80.000000        10        10         1         6         6
# 1                80.000000        10        10         1         6         6
# 2                80.000000        10        10         1         6         6
# 3                80.000000        10        10         1         6         6
# 4                80.000000        10        10         1         6         6
# ...                    ...       ...       ...       ...       ...       ...
# 30907            87.000000        12        12         3         5         8
# 30908            87.000000        12        12         3         5         8
# 30909            87.000000        12        12         3         5         8
# 30910            87.000000        12        12         3         5         8
# 30911            87.000000        12        12         3         5         8
#
#        lw  qc      bio1      bio2      bio3        bio4      bio5      bio6  \
# 0       2   0 14.071429 22.142857 54.006969  934.714115 35.000000 -6.000000
# 1       2   0 14.071429 22.142857 54.006969  934.714115 35.000000 -6.000000
# 2       2   0 14.071429 22.142857 54.006969  934.714115 35.000000 -6.000000
# 3       2   0 14.071429 22.142857 54.006969  934.714115 35.000000 -6.000000
# 4       2   0 14.071429 22.142857 54.006969  934.714115 35.000000 -6.000000
# ...    ..  ..       ...       ...       ...         ...       ...       ...
# 30907   2   0 16.928571 22.714286 48.328267 1097.128286 42.000000 -5.000000
# 30908   2   0 16.928571 22.714286 48.328267 1097.128286 42.000000 -5.000000
# 30909   2   0 16.928571 22.714286 48.328267 1097.128286 42.000000 -5.000000
# 30910   2   0 16.928571 22.714286 48.328267 1097.128286 42.000000 -5.000000
# 30911   2   0 16.928571 22.714286 48.328267 1097.128286 42.000000 -5.000000
#
#            bio7      bio8      bio9     bio10    bio11      bio12     bio13  \
# 0     41.000000 13.000000 18.333333 22.333333 5.833333 268.000000 70.000000
# 1     41.000000 13.000000 18.333333 22.333333 5.833333 268.000000 70.000000
# 2     41.000000 13.000000 18.333333 22.333333 5.833333 268.000000 70.000000
# 3     41.000000 13.000000 18.333333 22.333333 5.833333 268.000000 70.000000
# 4     41.000000 13.000000 18.333333 22.333333 5.833333 268.000000 70.000000
# ...         ...       ...       ...       ...      ...        ...       ...
# 30907 47.000000 16.000000 21.333333 27.500000 7.833333 272.000000 74.000000
# 30908 47.000000 16.000000 21.333333 27.500000 7.833333 272.000000 74.000000
# 30909 47.000000 16.000000 21.333333 27.500000 7.833333 272.000000 74.000000
# 30910 47.000000 16.000000 21.333333 27.500000 7.833333 272.000000 74.000000
# 30911 47.000000 16.000000 21.333333 27.500000 7.833333 272.000000 74.000000
#
#          bio14     bio15      bio16     bio17     bio18      bio19  M_Y_LT15  \
# 0     0.000000 73.843256 186.000000 45.000000 70.000000 128.000000       NaN
# 1     0.000000 73.843256 186.000000 45.000000 70.000000 128.000000       NaN
# 2     0.000000 73.843256 186.000000 45.000000 70.000000 128.000000       NaN
# 3     0.000000 73.843256 186.000000 45.000000 70.000000 128.000000       NaN
# 4     0.000000 73.843256 186.000000 45.000000 70.000000 128.000000       NaN
# ...        ...       ...        ...       ...       ...        ...       ...
# 30907 0.000000 85.162226 203.000000 60.000000 66.000000 143.000000       NaN
# 30908 0.000000 85.162226 203.000000 60.000000 66.000000 143.000000       NaN
# 30909 0.000000 85.162226 203.000000 60.000000 66.000000 143.000000       NaN
# 30910 0.000000 85.162226 203.000000 60.000000 66.000000 143.000000       NaN
# 30911 0.000000 85.162226 203.000000 60.000000 66.000000 143.000000       NaN
#
#        M_Y15-64  M_Y_GE65  M_TOTAL  F_Y_LT15  F_Y15-64  F_Y_GE65  F_TOTAL  \
# 0           NaN       NaN      NaN       NaN       NaN       NaN      NaN
# 1           NaN       NaN      NaN       NaN       NaN       NaN      NaN
# 2           NaN       NaN      NaN       NaN       NaN       NaN      NaN
# 3           NaN       NaN      NaN       NaN       NaN       NaN      NaN
# 4           NaN       NaN      NaN       NaN       NaN       NaN      NaN
# ...         ...       ...      ...       ...       ...       ...      ...
# 30907       NaN       NaN      NaN       NaN       NaN       NaN      NaN
# 30908       NaN       NaN      NaN       NaN       NaN       NaN      NaN
# 30909       NaN       NaN      NaN       NaN       NaN       NaN      NaN
# 30910       NaN       NaN      NaN       NaN       NaN       NaN      NaN
# 30911       NaN       NaN      NaN       NaN       NaN       NaN      NaN
#
#        MIO_EUR  L_TOTAL  UNL_TOTAL
# 0          NaN      NaN        NaN
# 1          NaN      NaN        NaN
# 2          NaN      NaN        NaN
# 3          NaN      NaN        NaN
# 4          NaN      NaN        NaN
# ...        ...      ...        ...
# 30907      NaN      NaN        NaN
# 30908      NaN      NaN        NaN
# 30909      NaN      NaN        NaN
# 30910      NaN      NaN        NaN
# 30911      NaN      NaN        NaN
#
# [30912 rows x 102 columns]

# %%
cols = dataset.columns

# %%
print(cols)
# Out:
# Index(['cell_number', 'dt_placement', 'NUTS1_ID', 'NUTS1_NAME', 'NUTS2_ID',
#        'NUTS2_NAME', 'NUTS3_ID', 'NUTS3_NAME', 'LAU1_NAME', 'x',
#        ...
#        'M_Y15-64', 'M_Y_GE65', 'M_TOTAL', 'F_Y_LT15', 'F_Y15-64', 'F_Y_GE65',
#        'F_TOTAL', 'MIO_EUR', 'L_TOTAL', 'UNL_TOTAL'],
#       dtype='object', length=102)

# %%
len(cols)
# Out:
# 102

# %%
years = dataset.year.unique().tolist()

# %%
for item in years:
    dataset[dataset.year == item].to_csv(f"../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Dataset_GRID_{item}.csv", encoding = enc, index = False)
