# %% [markdown]
# ## Merges all the availble information into a **Final Dataset** to be used for modeling ##

# %%
import pandas as pd
import datetime
import missingno
import re

from sklearn.impute import KNNImputer
import sys
import rpy2.robjects as robjects
import rpy2.ipython.html
from rpy2.robjects.packages import importr
import pickle
import gc

rpy2.ipython.html.init_printing()

sys.path.insert(0, "../../../Modules")
sys.path.insert(0, "../../../Mamoth")

from utils import *
from Neural_Network_Module import give_predictions, Dataset


enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 100
pd.options.display.float_format = lambda x: '%.6f' % x
# Out:
# c:\Users\dimit\Python Virtual Environments\noa_eywa\Lib\site-packages\rpy2\robjects\packages.py:367: UserWarning: The symbol 'quartz' is not in this R namespace/package.
#   warnings.warn(

# %%
utils = importr('utils')
base = importr('base')
dismo = importr('dismo')
utils.chooseCRANmirror(ind=41)
# Out:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x00000219BD1D8B90> [0]

# %%
NUTS0 = 'GR'
NUTS2 = 'Thessaly'

# %%
years = range(2025, 2026)

# %%
timelines = []

for year in years:
    df = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Timeline_GRID_{year}_filled_mean_rain_shp.csv', encoding=enc)
    print(f'Year: {year} | {df.shape}')
    timelines.append(df)
# Out:
# Year: 2025 | (391798, 44)

# %%
# timeline_file = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Timeline_GRID_2016-2018_filled.csv', encoding=enc)
# wnv_file = pd.read_csv(f'../../data/{NUTS0}_WNV_cases_GRID_2010-2021.csv', encoding=enc)

timeline_file = pd.concat(timelines, ignore_index=True, axis = 0)

# %%
del df
del timelines

gc.collect()
# Out:
# 270

# %%
timeline_file.head()
# Out:
#           x         y  cell_number dt_placement NUTS1_ID       NUTS1_NAME  \
# 0 21.155490 39.679430            0   2025-01-01      EL6  κεντρικη ελλαδα
# 1 21.155490 39.679430            0   2025-01-02      EL6  κεντρικη ελλαδα
# 2 21.155490 39.679430            0   2025-01-03      EL6  κεντρικη ελλαδα
# 3 21.155490 39.679430            0   2025-01-04      EL6  κεντρικη ελλαδα
# 4 21.155490 39.679430            0   2025-01-05      EL6  κεντρικη ελλαδα
#
#   NUTS2_ID NUTS2_NAME NUTS3_ID         NUTS3_NAME   LAU1_NAME  year  month  \
# 0     EL61   θεσσαλια    EL611  καρδιτσα, τρικαλα  καλαμπακας  2025      1
# 1     EL61   θεσσαλια    EL611  καρδιτσα, τρικαλα  καλαμπακας  2025      1
# 2     EL61   θεσσαλια    EL611  καρδιτσα, τρικαλα  καλαμπακας  2025      1
# 3     EL61   θεσσαλια    EL611  καρδιτσα, τρικαλα  καλαμπακας  2025      1
# 4     EL61   θεσσαλια    EL611  καρδιτσα, τρικαλα  καλαμπακας  2025      1
#
#       ndvi     ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  \
# 0      NaN      NaN       NaN       NaN        NaN        NaN        NaN
# 1 0.221706 0.730494 -0.233849 -0.730494   0.229238   0.751678  -0.201818
# 2 0.221706 0.730494 -0.233849 -0.730494   0.229238   0.751678  -0.201818
# 3 0.221706 0.730494 -0.233849 -0.730494   0.229238   0.751678  -0.201818
# 4 0.251864 0.679400 -0.253777 -0.679400   0.246129   0.733201  -0.203320
#
#    ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std      lst_day  \
# 0        NaN       NaN       NaN       NaN       NaN 13677.000000
# 1  -0.751678  0.178024  0.106410  0.121615  0.106410 13540.000000
# 2  -0.751678  0.178024  0.106410  0.121615  0.106410 13540.000000
# 3  -0.751678  0.178024  0.106410  0.121615  0.106410 13540.000000
# 4  -0.733201  0.194451  0.114292  0.131210  0.114292 13611.000000
#
#      lst_night  rainfall  day  lst_day_jan_mean  lst_night_jan_mean  \
# 0          NaN 17.190000    1      13710.032258        13190.866667
# 1 13362.000000  0.000000    2      13710.032258        13190.866667
# 2 13362.000000  0.760000    3      13710.032258        13190.866667
# 3 13362.000000  0.140000    4      13710.032258        13190.866667
# 4 13362.000000  0.000000    5      13710.032258        13190.866667
#
#    lst_day_feb_mean  lst_night_feb_mean  lst_day_mar_mean  lst_night_mar_mean  \
# 0      13550.666667        13191.192308      14115.615385        13694.789474
# 1      13550.666667        13191.192308      14115.615385        13694.789474
# 2      13550.666667        13191.192308      14115.615385        13694.789474
# 3      13550.666667        13191.192308      14115.615385        13694.789474
# 4      13550.666667        13191.192308      14115.615385        13694.789474
#
#    lst_day_apr_mean  lst_night_apr_mean  acc_rainfall_1week  \
# 0      14543.666667        13789.000000           17.190000
# 1      14543.666667        13789.000000           17.190000
# 2      14543.666667        13789.000000           17.950000
# 3      14543.666667        13789.000000           18.090000
# 4      14543.666667        13789.000000           18.090000
#
#    acc_rainfall_2week  acc_rainfall_month  acc_rainfall_jan  MOUNT_TYPE  \
# 0           17.190000           17.190000         17.190000    2.000000
# 1           17.190000           17.190000         17.190000    2.000000
# 2           17.950000           17.950000         17.950000    2.000000
# 3           18.090000           18.090000         18.090000    2.000000
# 4           18.090000           18.090000         18.090000    2.000000
#
#    URBN_TYPE  COAST_TYPE
# 0          3           3
# 1          3           3
# 2          3           3
# 3          3           3
# 4          3           3

# %%
timeline_file.shape
# Out:
# (391798, 44)

# %%
# wnv_file.head()

# %%
# wnv_file.shape

# %%
try:
    timeline_file.drop(columns=['Unnamed: 0'], inplace=True)
except KeyError:
    print ("column not found")
# Out:
# column not found

# %%
temprature_cols = timeline_file.filter(regex='^lst_*').columns.tolist()

timeline_file[temprature_cols] = timeline_file[temprature_cols].apply(lambda x : x * 0.02 - 273.15)

# %%
timeline_file.head()
# Out:
#           x         y  cell_number dt_placement NUTS1_ID       NUTS1_NAME  \
# 0 21.155490 39.679430            0   2025-01-01      EL6  κεντρικη ελλαδα
# 1 21.155490 39.679430            0   2025-01-02      EL6  κεντρικη ελλαδα
# 2 21.155490 39.679430            0   2025-01-03      EL6  κεντρικη ελλαδα
# 3 21.155490 39.679430            0   2025-01-04      EL6  κεντρικη ελλαδα
# 4 21.155490 39.679430            0   2025-01-05      EL6  κεντρικη ελλαδα
#
#   NUTS2_ID NUTS2_NAME NUTS3_ID         NUTS3_NAME   LAU1_NAME  year  month  \
# 0     EL61   θεσσαλια    EL611  καρδιτσα, τρικαλα  καλαμπακας  2025      1
# 1     EL61   θεσσαλια    EL611  καρδιτσα, τρικαλα  καλαμπακας  2025      1
# 2     EL61   θεσσαλια    EL611  καρδιτσα, τρικαλα  καλαμπακας  2025      1
# 3     EL61   θεσσαλια    EL611  καρδιτσα, τρικαλα  καλαμπακας  2025      1
# 4     EL61   θεσσαλια    EL611  καρδιτσα, τρικαλα  καλαμπακας  2025      1
#
#       ndvi     ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  \
# 0      NaN      NaN       NaN       NaN        NaN        NaN        NaN
# 1 0.221706 0.730494 -0.233849 -0.730494   0.229238   0.751678  -0.201818
# 2 0.221706 0.730494 -0.233849 -0.730494   0.229238   0.751678  -0.201818
# 3 0.221706 0.730494 -0.233849 -0.730494   0.229238   0.751678  -0.201818
# 4 0.251864 0.679400 -0.253777 -0.679400   0.246129   0.733201  -0.203320
#
#    ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std   lst_day  lst_night  \
# 0        NaN       NaN       NaN       NaN       NaN  0.390000        NaN
# 1  -0.751678  0.178024  0.106410  0.121615  0.106410 -2.350000  -5.910000
# 2  -0.751678  0.178024  0.106410  0.121615  0.106410 -2.350000  -5.910000
# 3  -0.751678  0.178024  0.106410  0.121615  0.106410 -2.350000  -5.910000
# 4  -0.733201  0.194451  0.114292  0.131210  0.114292 -0.930000  -5.910000
#
#    rainfall  day  lst_day_jan_mean  lst_night_jan_mean  lst_day_feb_mean  \
# 0 17.190000    1          1.050645           -9.332667         -2.136667
# 1  0.000000    2          1.050645           -9.332667         -2.136667
# 2  0.760000    3          1.050645           -9.332667         -2.136667
# 3  0.140000    4          1.050645           -9.332667         -2.136667
# 4  0.000000    5          1.050645           -9.332667         -2.136667
#
#    lst_night_feb_mean  lst_day_mar_mean  lst_night_mar_mean  lst_day_apr_mean  \
# 0           -9.326154          9.162308            0.745789         17.723333
# 1           -9.326154          9.162308            0.745789         17.723333
# 2           -9.326154          9.162308            0.745789         17.723333
# 3           -9.326154          9.162308            0.745789         17.723333
# 4           -9.326154          9.162308            0.745789         17.723333
#
#    lst_night_apr_mean  acc_rainfall_1week  acc_rainfall_2week  \
# 0            2.630000           17.190000           17.190000
# 1            2.630000           17.190000           17.190000
# 2            2.630000           17.950000           17.950000
# 3            2.630000           18.090000           18.090000
# 4            2.630000           18.090000           18.090000
#
#    acc_rainfall_month  acc_rainfall_jan  MOUNT_TYPE  URBN_TYPE  COAST_TYPE
# 0           17.190000         17.190000    2.000000          3           3
# 1           17.190000         17.190000    2.000000          3           3
# 2           17.950000         17.950000    2.000000          3           3
# 3           18.090000         18.090000    2.000000          3           3
# 4           18.090000         18.090000    2.000000          3           3

# %%
timeline_file['lst'] = (timeline_file['lst_day'] + timeline_file['lst_night']) / 2
timeline_file['lst_jan_mean'] = (timeline_file['lst_day_jan_mean'] + timeline_file['lst_night_jan_mean'])/2
timeline_file['lst_feb_mean'] = (timeline_file['lst_day_feb_mean'] + timeline_file['lst_night_feb_mean'])/2
timeline_file['lst_mar_mean'] = (timeline_file['lst_day_mar_mean'] + timeline_file['lst_night_mar_mean'])/2
timeline_file['lst_apr_mean'] = (timeline_file['lst_day_apr_mean'] + timeline_file['lst_night_apr_mean'])/2

# %%
timeline_file['dt_placement'] = pd.to_datetime(timeline_file['dt_placement'])
timeline_file['day'] = timeline_file['dt_placement'].apply(lambda x : x.day)
timeline_file['month'] = timeline_file['dt_placement'].apply(lambda x : x.month)
timeline_file['year'] = timeline_file['dt_placement'].apply(lambda x : x.year)

timeline_file = encode_cyclical(timeline_file, 'month', 12)

# %%
timeline_file.rename(columns={"lst_day_jan_mean": "lst_jan_day_mean",
                        "lst_day_feb_mean": "lst_feb_day_mean",
                        "lst_day_mar_mean": "lst_mar_day_mean",
                        "lst_day_apr_mean": "lst_apr_day_mean",
                        "lst_night_jan_mean": "lst_jan_night_mean",
                        "lst_night_feb_mean": "lst_feb_night_mean",
                        "lst_night_mar_mean": "lst_mar_night_mean",
                        "lst_night_apr_mean": "lst_apr_night_mean"}, inplace=True)

# %%
timeline_file
# Out:
#                x         y  cell_number dt_placement NUTS1_ID  \
# 0      21.155490 39.679430            0   2025-01-01      EL6
# 1      21.155490 39.679430            0   2025-01-02      EL6
# 2      21.155490 39.679430            0   2025-01-03      EL6
# 3      21.155490 39.679430            0   2025-01-04      EL6
# 4      21.155490 39.679430            0   2025-01-05      EL6
# ...          ...       ...          ...          ...      ...
# 391793 24.067210 39.338070         3237   2025-04-27      EL6
# 391794 24.067210 39.338070         3237   2025-04-28      EL6
# 391795 24.067210 39.338070         3237   2025-04-29      EL6
# 391796 24.067210 39.338070         3237   2025-04-30      EL6
# 391797 24.067210 39.338070         3237   2025-05-01      EL6
#
#              NUTS1_NAME NUTS2_ID NUTS2_NAME NUTS3_ID          NUTS3_NAME  \
# 0       κεντρικη ελλαδα     EL61   θεσσαλια    EL611   καρδιτσα, τρικαλα
# 1       κεντρικη ελλαδα     EL61   θεσσαλια    EL611   καρδιτσα, τρικαλα
# 2       κεντρικη ελλαδα     EL61   θεσσαλια    EL611   καρδιτσα, τρικαλα
# 3       κεντρικη ελλαδα     EL61   θεσσαλια    EL611   καρδιτσα, τρικαλα
# 4       κεντρικη ελλαδα     EL61   θεσσαλια    EL611   καρδιτσα, τρικαλα
# ...                 ...      ...        ...      ...                 ...
# 391793  κεντρικη ελλαδα     EL61   θεσσαλια    EL613  μαγνησια, σποραδες
# 391794  κεντρικη ελλαδα     EL61   θεσσαλια    EL613  μαγνησια, σποραδες
# 391795  κεντρικη ελλαδα     EL61   θεσσαλια    EL613  μαγνησια, σποραδες
# 391796  κεντρικη ελλαδα     EL61   θεσσαλια    EL613  μαγνησια, σποραδες
# 391797  κεντρικη ελλαδα     EL61   θεσσαλια    EL613  μαγνησια, σποραδες
#
#          LAU1_NAME  year  month     ndvi     ndmi      ndwi      ndbi  \
# 0       καλαμπακας  2025      1      NaN      NaN       NaN       NaN
# 1       καλαμπακας  2025      1 0.221706 0.730494 -0.233849 -0.730494
# 2       καλαμπακας  2025      1 0.221706 0.730494 -0.233849 -0.730494
# 3       καλαμπακας  2025      1 0.221706 0.730494 -0.233849 -0.730494
# 4       καλαμπακας  2025      1 0.251864 0.679400 -0.253777 -0.679400
# ...            ...   ...    ...      ...      ...       ...       ...
# 391793   αλοννησου  2025      4 0.520411 0.135654 -0.442513 -0.135654
# 391794   αλοννησου  2025      4 0.520411 0.135654 -0.442513 -0.135654
# 391795   αλοννησου  2025      4 0.520411 0.135654 -0.442513 -0.135654
# 391796   αλοννησου  2025      4 0.520411 0.135654 -0.442513 -0.135654
# 391797   αλοννησου  2025      5      NaN      NaN       NaN       NaN
#
#         ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std
# 1                17.190000           17.190000         17.190000    2.000000
# 2                17.950000           17.950000         17.950000    2.000000
# 3                18.090000           18.090000         18.090000    2.000000
# 4                18.090000           18.090000         18.090000    2.000000
# ...                    ...                 ...               ...         ...
# 391793            2.740000           30.429999        228.139995    2.000000
# 391794            2.340000           30.429999        228.139995    2.000000
# 391795            2.340000           30.429999        228.139995    2.000000
# 391796            1.590000           28.819999        228.139995    2.000000
# 391797            1.590000           18.509999        228.139995    2.000000
#
#         URBN_TYPE  COAST_TYPE       lst  lst_jan_mean  lst_feb_mean  \
# 0               3           3       NaN     -4.141011     -5.731410
# 1               3           3 -4.130000     -4.141011     -5.731410
# 2               3           3 -4.130000     -4.141011     -5.731410
# 3               3           3 -4.130000     -4.141011     -5.731410
# 4               3           3 -3.420000     -4.141011     -5.731410
# ...           ...         ...       ...           ...           ...
# 391793          2           1 18.210000     10.466452      7.611429
# 391794          2           1       NaN     10.466452      7.611429
# 391795          2           1       NaN     10.466452      7.611429
# 391796          2           1       NaN     10.466452      7.611429
# 391797          2           1       NaN     10.466452      7.611429
#
#         lst_mar_mean  lst_apr_mean  month_sin  month_cos
# 0           4.954049     10.176667   0.500000   0.866025
# 1           4.954049     10.176667   0.500000   0.866025
# 2           4.954049     10.176667   0.500000   0.866025
# 3           4.954049     10.176667   0.500000   0.866025
# 4           4.954049     10.176667   0.500000   0.866025
# ...              ...           ...        ...        ...
# 391793     12.638387     14.462917   0.866025  -0.500000
# 391794     12.638387     14.462917   0.866025  -0.500000
# 391795     12.638387     14.462917   0.866025  -0.500000
# 391796     12.638387     14.462917   0.866025  -0.500000
# 391797     12.638387     14.462917   0.500000  -0.866025
#
# [391798 rows x 51 columns]

# %%
timeline_file.rename(columns={"dt_placement": "dt_placement_daily"}, inplace=True)
timeline_file['date_string'] = timeline_file['month'].astype(str) + '-' + timeline_file['year'].astype(str)
timeline_file['dt_placement'] = pd.to_datetime(timeline_file['date_string'], format='%m-%Y').dt.to_period('M')
timeline_file.drop(columns=['date_string'], inplace = True)

# %%
gc.collect()
# Out:
# 0

# %%
grouped_by_month = timeline_file.drop(columns=['dt_placement_daily']).groupby(['cell_number','dt_placement','NUTS1_ID','NUTS1_NAME','NUTS2_ID','NUTS2_NAME','NUTS3_ID', 'NUTS3_NAME', 'LAU1_NAME'], as_index = False)

grouped_by_month_mean = grouped_by_month.mean()
grouped_by_month_min = grouped_by_month.min()
grouped_by_month_max = grouped_by_month.max()
grouped_by_month_sum = grouped_by_month.sum()
grouped_by_month_last = grouped_by_month.last()

# %%
del timeline_file
gc.collect()
# Out:
# 0

# %%
grouped_by_month_dataset = pd.concat([grouped_by_month_mean[['cell_number','dt_placement','NUTS1_ID','NUTS1_NAME','NUTS2_ID','NUTS2_NAME','NUTS3_ID','NUTS3_NAME','LAU1_NAME','x','y','MOUNT_TYPE','URBN_TYPE','COAST_TYPE','year','month']], 
                                     grouped_by_month_mean[['ndvi','ndmi','ndwi','ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std','ndmi_std','ndwi_std','ndbi_std']],
                                     grouped_by_month_mean[['lst_day','lst_night','lst']].rename(columns={'lst_day': 'lst_day_mean', 'lst_night': 'lst_night_mean', 'lst': 'lst_mean'}),
                                     grouped_by_month_last[['lst_jan_day_mean','lst_feb_day_mean','lst_mar_day_mean','lst_apr_day_mean', 'lst_jan_night_mean','lst_feb_night_mean','lst_mar_night_mean','lst_apr_night_mean','lst_jan_mean','lst_feb_mean','lst_mar_mean','lst_apr_mean']],
                                     grouped_by_month_mean[['rainfall']].rename(columns={'rainfall':'rainfall_mean'}),
                                     grouped_by_month_last[['acc_rainfall_1week','acc_rainfall_2week','acc_rainfall_month','acc_rainfall_jan']],
                                     grouped_by_month_min[['lst_day','lst_night']].rename(columns={'lst_day':'lst_day_min', 'lst_night': 'lst_night_min'}),
                                     grouped_by_month_max[['lst_day','lst_night']].rename(columns={'lst_day':'lst_day_max', 'lst_night': 'lst_night_max'}),
                                     grouped_by_month_sum[['rainfall']].rename(columns={'rainfall':'rainfall_acc'})], axis=1)

# %%
del grouped_by_month
del grouped_by_month_mean
del grouped_by_month_min
del grouped_by_month_max
del grouped_by_month_sum
del grouped_by_month_last

gc.collect()
# Out:
# 0

# %%
grouped_by_month_dataset.head()
# Out:
#    cell_number dt_placement NUTS1_ID       NUTS1_NAME NUTS2_ID NUTS2_NAME  \
# 0            0      2025-01      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 1            0      2025-02      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 2            0      2025-03      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 3            0      2025-04      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 4            0      2025-05      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
#
#   NUTS3_ID         NUTS3_NAME   LAU1_NAME         x         y  MOUNT_TYPE  \
# 0    EL611  καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430    2.000000
# 1    EL611  καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430    2.000000
# 2    EL611  καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430    2.000000
# 3    EL611  καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430    2.000000
# 4    EL611  καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430    2.000000
#
#    URBN_TYPE  COAST_TYPE        year    month     ndvi     ndmi      ndwi  \
# 0   3.000000    3.000000 2025.000000 1.000000 0.269888 0.628876 -0.208902
# 1   3.000000    3.000000 2025.000000 2.000000 0.366295 0.346762 -0.254671
# 2   3.000000    3.000000 2025.000000 3.000000 0.440482 0.178383 -0.394812
# 3   3.000000    3.000000 2025.000000 4.000000 0.489129 0.187812 -0.396035
# 4   3.000000    3.000000 2025.000000 5.000000      NaN      NaN       NaN
#
#        ndbi  ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  \
# 0 -0.628876   0.254061   0.694518  -0.157651  -0.694518  0.189705  0.113860
# 1 -0.346762   0.261093   0.494400  -0.145091  -0.494400  0.173774  0.130960
# 2 -0.178383   0.378342   0.238523  -0.330627  -0.238523  0.116777  0.120771
# 3 -0.187812   0.455384   0.168838  -0.349366  -0.168838  0.068506  0.113474
# 4       NaN        NaN        NaN        NaN        NaN       NaN       NaN
#
#    ndwi_std  ndbi_std  lst_day_mean  lst_night_mean  lst_mean  \
# 0  0.137274  0.113860      1.050645       -9.332667 -4.130000
# 1  0.128415  0.130960     -2.136667       -9.326154 -5.959583
# 2  0.085898  0.120771      9.162308        0.745789  5.187368
# 3  0.058134  0.113474     17.723333        2.630000 10.283889
# 4       NaN       NaN           NaN             NaN       NaN
#
#    lst_jan_day_mean  lst_feb_day_mean  lst_mar_day_mean  lst_apr_day_mean  \
# 0          1.050645         -2.136667          9.162308         17.723333
# 1          1.050645         -2.136667          9.162308         17.723333
# 2          1.050645         -2.136667          9.162308         17.723333
# 3          1.050645         -2.136667          9.162308         17.723333
# 4          1.050645         -2.136667          9.162308         17.723333
#
#    lst_jan_night_mean  lst_feb_night_mean  lst_mar_night_mean  \
# 0           -9.332667           -9.326154            0.745789
# 1           -9.332667           -9.326154            0.745789
# 2           -9.332667           -9.326154            0.745789
# 3           -9.332667           -9.326154            0.745789
# 4           -9.332667           -9.326154            0.745789
#
#    lst_apr_night_mean  lst_jan_mean  lst_feb_mean  lst_mar_mean  lst_apr_mean  \
# 0            2.630000     -4.141011     -5.731410      4.954049     10.176667
# 1            2.630000     -4.141011     -5.731410      4.954049     10.176667
# 2            2.630000     -4.141011     -5.731410      4.954049     10.176667
# 3            2.630000     -4.141011     -5.731410      4.954049     10.176667
# 4            2.630000     -4.141011     -5.731410      4.954049     10.176667
#
#    rainfall_mean  acc_rainfall_1week  acc_rainfall_2week  acc_rainfall_month  \
# 0       4.081613            5.630000           83.839998          109.339998
# 1       2.577500           49.999999           50.419999           72.279998
# 2       6.183871           82.639999          133.209997          175.539996
# 3       1.931667           25.539999           30.269999           57.949999
# 4            NaN           10.950000           28.849999           56.739999
#
#    acc_rainfall_jan  lst_day_min  lst_night_min  lst_day_max  lst_night_max  \
# 0        126.529998    -2.350000     -13.670000     2.990000       0.450000
# 1        198.699996    -4.150000     -10.630000     1.110000      -3.850000
# 2        390.399991     4.750000      -0.370000    13.170000       3.630000
# 3        448.349990     9.810000      -1.230000    21.150000       6.490000
# 4        448.349990          NaN            NaN          NaN            NaN
#
#    rainfall_acc
# 0    126.529998
# 1     72.169998
# 2    191.699996
# 3     57.949999
# 4      0.000000

# %%
grouped_by_month_dataset
# Out:
#        cell_number dt_placement NUTS1_ID       NUTS1_NAME NUTS2_ID NUTS2_NAME  \
# 0                0      2025-01      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 1                0      2025-02      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 2                0      2025-03      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 3                0      2025-04      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 4                0      2025-05      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# ...            ...          ...      ...              ...      ...        ...
# 16185         3237      2025-01      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16186         3237      2025-02      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16187         3237      2025-03      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16188         3237      2025-04      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16189         3237      2025-05      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
#
#       NUTS3_ID          NUTS3_NAME   LAU1_NAME         x         y  \
# 0        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 1        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 2        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 3        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 4        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# ...        ...                 ...         ...       ...       ...
# 16185    EL613  μαγνησια, σποραδες   αλοννησου 24.067210 39.338070
# 16186    EL613  μαγνησια, σποραδες   αλοννησου 24.067210 39.338070
# 16187    EL613  μαγνησια, σποραδες   αλοννησου 24.067210 39.338070
# 16188    EL613  μαγνησια, σποραδες   αλοννησου 24.067210 39.338070
# 16189    EL613  μαγνησια, σποραδες   αλοννησου 24.067210 39.338070
#
#        MOUNT_TYPE  URBN_TYPE  COAST_TYPE        year    month     ndvi  \
# 0        2.000000   3.000000    3.000000 2025.000000 1.000000 0.269888
# 1        2.000000   3.000000    3.000000 2025.000000 2.000000 0.366295
# 2        2.000000   3.000000    3.000000 2025.000000 3.000000 0.440482
# 16187         15.491935         17.515833            9.188065
# 16188         15.491935         17.515833            9.188065
# 16189         15.491935         17.515833            9.188065
#
#        lst_feb_night_mean  lst_mar_night_mean  lst_apr_night_mean  \
# 0               -9.326154            0.745789            2.630000
# 1               -9.326154            0.745789            2.630000
# 2               -9.326154            0.745789            2.630000
# 3               -9.326154            0.745789            2.630000
# 4               -9.326154            0.745789            2.630000
# ...                   ...                 ...                 ...
# 16185            7.627143            9.784839           11.410000
# 16186            7.627143            9.784839           11.410000
# 16187            7.627143            9.784839           11.410000
# 16188            7.627143            9.784839           11.410000
# 16189            7.627143            9.784839           11.410000
#
#        lst_jan_mean  lst_feb_mean  lst_mar_mean  lst_apr_mean  rainfall_mean  \
# 0         -4.141011     -5.731410      4.954049     10.176667       4.081613
# 1         -4.141011     -5.731410      4.954049     10.176667       2.577500
# 2         -4.141011     -5.731410      4.954049     10.176667       6.183871
# 3         -4.141011     -5.731410      4.954049     10.176667       1.931667
# 4         -4.141011     -5.731410      4.954049     10.176667            NaN
# ...             ...           ...           ...           ...            ...
# 16185     10.466452      7.611429     12.638387     14.462917       0.718710
# 16186     10.466452      7.611429     12.638387     14.462917       2.741786
# 16187     10.466452      7.611429     12.638387     14.462917       3.234516
# 16188     10.466452      7.611429     12.638387     14.462917       0.960667
# 16189     10.466452      7.611429     12.638387     14.462917            NaN
#
#        acc_rainfall_1week  acc_rainfall_2week  acc_rainfall_month  \
# 0                5.630000           83.839998          109.339998
# 1               49.999999           50.419999           72.279998
# 2               82.639999          133.209997          175.539996
# 3               25.539999           30.269999           57.949999
# 4               10.950000           28.849999           56.739999
# ...                   ...                 ...                 ...
# 16185            0.000000            0.300000           22.279999
# 16186           49.249999           56.499999           76.769998
# 16187           15.270000           44.459999          100.269998
# 16188            1.070000            1.590000           28.819999
# 16189            1.070000            1.590000           18.509999
#
#        acc_rainfall_jan  lst_day_min  lst_night_min  lst_day_max  \
# 0            126.529998    -2.350000     -13.670000     2.990000
# 1            198.699996    -4.150000     -10.630000     1.110000
# 2            390.399991     4.750000      -0.370000    13.170000
# 3            448.349990     9.810000      -1.230000    21.150000
# 4            448.349990          NaN            NaN          NaN
# ...                 ...          ...            ...          ...
# 16185         22.279999     3.670000       5.630000    13.830000
# 16186         99.049998     2.530000       6.690000    14.090000
# 16187        199.319995     9.010000       5.950000    21.310000
# 16188        228.139995     9.110000       6.230000    23.070000
# 16189        228.139995          NaN            NaN          NaN
#
#        lst_night_max  rainfall_acc
# 0           0.450000    126.529998
# 1          -3.850000     72.169998
# 2           3.630000    191.699996
# 3           6.490000     57.949999
# 4                NaN      0.000000
# ...              ...           ...
# 16185      11.130000     22.279999
# 16186      10.350000     76.769998
# 16187      12.910000    100.269998
# 16188      14.630000     28.819999
# 16189            NaN      0.000000
#
# [16190 rows x 53 columns]

# %%
grouped_by_month_dataset['lst_min'] = grouped_by_month_dataset.apply(lambda row: min(row['lst_day_min'], row['lst_night_min']), axis=1)
grouped_by_month_dataset['lst_max'] = grouped_by_month_dataset.apply(lambda row: max(row['lst_day_max'], row['lst_night_max']), axis=1)

# %%
grouped_by_month_dataset.drop(columns=['lst_day_min', 'lst_night_min', 'lst_day_max', 'lst_night_max'], inplace=True)

# %%
grouped_by_month_dataset[['MOUNT_TYPE','URBN_TYPE','COAST_TYPE','year','month']] = grouped_by_month_dataset[['MOUNT_TYPE','URBN_TYPE','COAST_TYPE','year','month']].astype(int)

# %%
grouped_by_month_dataset
# Out:
#        cell_number dt_placement NUTS1_ID       NUTS1_NAME NUTS2_ID NUTS2_NAME  \
# 0                0      2025-01      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 1                0      2025-02      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 2                0      2025-03      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 3                0      2025-04      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 4                0      2025-05      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# ...            ...          ...      ...              ...      ...        ...
# 16185         3237      2025-01      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16186         3237      2025-02      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16187         3237      2025-03      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16188         3237      2025-04      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16189         3237      2025-05      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
#
#       NUTS3_ID          NUTS3_NAME   LAU1_NAME         x         y  \
# 0        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 1        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 2        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 3        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 4        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# ...        ...                 ...         ...       ...       ...
# 16185    EL613  μαγνησια, σποραδες   αλοννησου 24.067210 39.338070
# 16186    EL613  μαγνησια, σποραδες   αλοννησου 24.067210 39.338070
# 16187    EL613  μαγνησια, σποραδες   αλοννησου 24.067210 39.338070
# 16188    EL613  μαγνησια, σποραδες   αλοννησου 24.067210 39.338070
# 16189    EL613  μαγνησια, σποραδες   αλοννησου 24.067210 39.338070
#
#        MOUNT_TYPE  URBN_TYPE  COAST_TYPE  year  month     ndvi     ndmi  \
# 0               2          3           3  2025      1 0.269888 0.628876
# 1               2          3           3  2025      2 0.366295 0.346762
# 2               2          3           3  2025      3 0.440482 0.178383
# 3               2          3           3  2025      4 0.489129 0.187812
# 4               2          3           3  2025      5      NaN      NaN
# ...           ...        ...         ...   ...    ...      ...      ...
# 16185           2          2           1  2025      1 0.478596 0.176796
# 16186           2          2           1  2025      2 0.420769 0.147417
# 16187           2          2           1  2025      3 0.379472 0.162680
# 16188           2          2           1  2025      4 0.515194 0.129613
# 16189           2          2           1  2025      5      NaN      NaN
#
#            ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  \
# 0     -0.208902 -0.628876   0.254061   0.694518  -0.157651  -0.694518
# 1     -0.254671 -0.346762   0.261093   0.494400  -0.145091  -0.494400
# 2     -0.394812 -0.178383   0.378342   0.238523  -0.330627  -0.238523
# 3     -0.396035 -0.187812   0.455384   0.168838  -0.349366  -0.168838
# 4           NaN       NaN        NaN        NaN        NaN        NaN
# ...         ...       ...        ...        ...        ...        ...
# 16185 -0.370264 -0.176796   0.337622   0.249621  -0.085516  -0.249621
# 16186 -0.336262 -0.147417   0.330030   0.181059  -0.204898  -0.181059
# 16187 -0.280687 -0.162680   0.348769   0.206283  -0.176531  -0.206283
# 16188 -0.435509 -0.129613   0.448456   0.164979  -0.310998  -0.164979
# 16189       NaN       NaN        NaN        NaN        NaN        NaN
#
#        ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_
# 1               50.419999           72.279998        198.699996     72.169998
# 2              133.209997          175.539996        390.399991    191.699996
# 3               30.269999           57.949999        448.349990     57.949999
# 4               28.849999           56.739999        448.349990      0.000000
# ...                   ...                 ...               ...           ...
# 16185            0.300000           22.279999         22.279999     22.279999
# 16186           56.499999           76.769998         99.049998     76.769998
# 16187           44.459999          100.269998        199.319995    100.269998
# 16188            1.590000           28.819999        228.139995     28.819999
# 16189            1.590000           18.509999        228.139995      0.000000
#
#          lst_min   lst_max
# 0     -13.670000  2.990000
# 1     -10.630000  1.110000
# 2      -0.370000 13.170000
# 3      -1.230000 21.150000
# 4            NaN       NaN
# ...          ...       ...
# 16185   3.670000 13.830000
# 16186   2.530000 14.090000
# 16187   5.950000 21.310000
# 16188   6.230000 23.070000
# 16189        NaN       NaN
#
# [16190 rows x 51 columns]

# %% [markdown]
# ### Add Geomorphological and Land Cover/Use

# %%
dataset_locations = grouped_by_month_dataset[['x', 'y']].drop_duplicates(keep='first')
dataset_locations.reset_index(drop = True, inplace = True)

# %%
dataset_locations_per_year = grouped_by_month_dataset[['x', 'y', 'year']].drop_duplicates(keep='first')
dataset_locations_per_year.reset_index(drop = True, inplace = True)

# %%
dataset_locations
# Out:
#              x         y
# 0    21.155490 39.679430
# 1    21.155490 39.679430
# 2    21.178600 39.625530
# 3    21.178600 39.625530
# 4    21.178600 39.643500
# ...        ...       ...
# 4551 23.905450 39.194330
# 4552 23.905450 39.212300
# 4553 23.905450 39.212300
# 4554 23.928560 39.230270
# 4555 24.067210 39.338070
#
# [4556 rows x 2 columns]

# %%
dataset_locations_per_year
# Out:
#              x         y  year
# 0    21.155490 39.679430  2025
# 1    21.155490 39.679430  2025
# 2    21.178600 39.625530  2025
# 3    21.178600 39.625530  2025
# 4    21.178600 39.643500  2025
# ...        ...       ...   ...
# 4551 23.905450 39.194330  2025
# 4552 23.905450 39.212300  2025
# 4553 23.905450 39.212300  2025
# 4554 23.928560 39.230270  2025
# 4555 24.067210 39.338070  2025
#
# [4556 rows x 3 columns]

# %%
geomorphological = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_GRID_Geomorphological.csv')
geomorphological.columns = geomorphological.columns.str.lower()

# %%
distances, indicies = calculate_nearest_topological(dataset_locations, geomorphological)
print(f'Min distance: {min(distances)}')
print(f'Max distance: {max(distances)}')
# Out:
# Min distance: 5.484765537124604e-06
# Max distance: 0.00044491104150597155

# %%
df_geo = pd.DataFrame(columns=geomorphological.columns)

for index in indicies:
    df_geo = pd.concat([df_geo, geomorphological.iloc[[index]]], ignore_index=True)

df_geo.drop(columns=['x', 'y'], inplace = True)
df_geo.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\dimit\AppData\Local\Temp\ipykernel_174716\180837051.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_geo = pd.concat([df_geo, geomorphological.iloc[[index]]], ignore_index=True)

# %%
dataset_geo = pd.concat([dataset_locations, df_geo], axis=1, join = 'outer')
dataset_geo
# Out:
#              x         y  distance_to_coast  distance_to_river slope_mean_1km  \
# 0    21.155490 39.679430       20057.653131         722.827790             34
# 1    21.155490 39.679430       20057.653131         722.827790             34
# 2    21.178600 39.625530       22359.174513        1561.273622             32
# 3    21.178600 39.625530       22359.174513        1561.273622             32
# 4    21.178600 39.643500       22073.181364         437.397275             16
# ...        ...       ...                ...                ...            ...
# 4551 23.905450 39.194330        1605.267341       48889.605025             12
# 4552 23.905450 39.212300        1130.893787       48888.954874             13
# 4553 23.905450 39.212300        1130.893787       48888.954874             13
# 4554 23.928560 39.230270        1155.267987       50961.680408             14
# 4555 24.067210 39.338070         474.834345       56432.126469             14
#
#       aspect_mean_200m  elevation_mean_1km  hillshade_mean_1km  fs_area_1km  \
# 0           176.440719         1574.522145          141.293561     0.000000
# 1           176.440719         1574.522145          141.293561     0.000000
# 2           254.179204         1681.751389          176.989248     0.000000
# 3           254.179204         1681.751389          176.989248     0.000000
# 4           177.777467         1397.093454          160.244280     0.000000
# ...                ...                 ...                 ...          ...
# 4551        212.128782          260.256967          168.750910     0.000000
# 4552        257.572131          379.420309          185.095132     0.000000
# 4553        257.572131          379.420309          185.095132     0.000000
# 4554        180.778128          269.381324          170.808592     0.000000
# 4555        173.137787           48.760165          180.090346     0.206898
#
#       flow_accu_200m
# 0           2.204379
# 1           2.204379
# 2           3.146997
# 3           3.146997
# 4           6.601146
# ...              ...
# 4551        3.803597
# 4552        1.061765
# 4553        1.061765
# 4554        1.553148
# 4555        8.135650
#
# [4556 rows x 10 columns]

# %%
dataset_geo.dtypes
# Out:
# x                     float64
# y                     float64
# distance_to_coast     float64
# distance_to_river     float64
# slope_mean_1km         object
# aspect_mean_200m      float64
# elevation_mean_1km    float64
# hillshade_mean_1km    float64
# fs_area_1km           float64
# flow_accu_200m        float64
# dtype: object

# %%
dataset_geo['slope_mean_1km'] = pd.to_numeric(dataset_geo['slope_mean_1km'], errors='coerce').astype('int64')

# %%
dataset_geo.dtypes
# Out:
# x                     float64
# y                     float64
# distance_to_coast     float64
# distance_to_river     float64
# slope_mean_1km          int64
# aspect_mean_200m      float64
# elevation_mean_1km    float64
# hillshade_mean_1km    float64
# fs_area_1km           float64
# flow_accu_200m        float64
# dtype: object

# %%
dataset_geo
# Out:
#              x         y  distance_to_coast  distance_to_river  \
# 0    21.155490 39.679430       20057.653131         722.827790
# 1    21.155490 39.679430       20057.653131         722.827790
# 2    21.178600 39.625530       22359.174513        1561.273622
# 3    21.178600 39.625530       22359.174513        1561.273622
# 4    21.178600 39.643500       22073.181364         437.397275
# ...        ...       ...                ...                ...
# 4551 23.905450 39.194330        1605.267341       48889.605025
# 4552 23.905450 39.212300        1130.893787       48888.954874
# 4553 23.905450 39.212300        1130.893787       48888.954874
# 4554 23.928560 39.230270        1155.267987       50961.680408
# 4555 24.067210 39.338070         474.834345       56432.126469
#
#       slope_mean_1km  aspect_mean_200m  elevation_mean_1km  \
# 0                 34        176.440719         1574.522145
# 1                 34        176.440719         1574.522145
# 2                 32        254.179204         1681.751389
# 3                 32        254.179204         1681.751389
# 4                 16        177.777467         1397.093454
# ...              ...               ...                 ...
# 4551              12        212.128782          260.256967
# 4552              13        257.572131          379.420309
# 4553              13        257.572131          379.420309
# 4554              14        180.778128          269.381324
# 4555              14        173.137787           48.760165
#
#       hillshade_mean_1km  fs_area_1km  flow_accu_200m
# 0             141.293561     0.000000        2.204379
# 1             141.293561     0.000000        2.204379
# 2             176.989248     0.000000        3.146997
# 3             176.989248     0.000000        3.146997
# 4             160.244280     0.000000        6.601146
# ...                  ...          ...             ...
# 4551          168.750910     0.000000        3.803597
# 4552          185.095132     0.000000        1.061765
# 4553          185.095132     0.000000        1.061765
# 4554          170.808592     0.000000        1.553148
# 4555          180.090346     0.206898        8.135650
#
# [4556 rows x 10 columns]

# %%
landcover = pd.read_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_GRID_Landcover_2001-2022.csv')
landcover.columns = landcover.columns.str.lower()

# %%
lc_columns = landcover.columns.tolist()
lc_columns = [x.split('_')[0] for x in lc_columns]

lc_columns
lc_years = set()

for i in range(0, len(lc_columns)):
    try:
        lc_years.add(int(lc_columns[i]))
    except ValueError:
        pass

lc_years = list(lc_years)

# %%
dates_ = re.compile(r"[0-9]{4}_[0-9]{2}_[0-9]{2}_")

for year in lc_years:
    frame_name = f'landcover_{year}'
    location_columns = ['x', 'y']
    filtered_columns = [col for col in landcover if col.startswith(f'{year}')]
    columns_to_keep = location_columns + filtered_columns
    locals()[frame_name] = landcover[columns_to_keep].copy()
    locals()[frame_name].insert(2, 'year', int(year))
    locals()[frame_name] = locals()[frame_name].rename(columns=lambda x: re.sub(dates_,'',x))

# %%
data_years = dataset_locations_per_year['year'].unique().tolist()

# %%
for year in data_years:
    frame_name = f'dataset_unique_points_annual_{year}'
    locals()[frame_name] = dataset_locations_per_year.query(f"year == {year}").copy()
    locals()[frame_name].reset_index(drop=True, inplace = True)

# %%
landcover_2025 = landcover_2024 = landcover_2023 = landcover_2022

# %%
for year in data_years:
    data_name = f'dataset_unique_points_annual_{year}'
    lc_name = f'landcover_{year}'
    merged_name = f'dataset_unique_points_annual_part{year}'
    distances, indicies = calculate_nearest_topological(locals()[data_name], locals()[lc_name])
    print(f'Year: {year}\nMin distance: {min(distances)}\nMax distance: {max(distances)}')

    df_lulc = pd.DataFrame()

    for index in indicies:
        df_lulc = pd.concat([df_lulc, locals()[lc_name].iloc[[index]]], ignore_index=True)

    df_lulc.drop(columns=['x', 'y', 'year'], inplace = True)
    df_lulc.reset_index(drop=True, inplace=True)

    locals()[merged_name] = pd.concat([locals()[data_name], df_lulc], axis=1, join = 'outer')
# Out:
# Year: 2025
# Min distance: 5.484765537124604e-06
# Max distance: 0.00044491104150597155

# %%
dataset_lulc = pd.DataFrame()

for year in data_years:
    merged_name = f'dataset_unique_points_annual_part{year}'
    dataset_lulc = pd.concat([dataset_lulc, locals()[merged_name]], ignore_index=True)

# %%
dataset_lulc
# Out:
#              x         y  year  lc_prop1  lc_prop1_assessment  lc_prop2  \
# 0    21.155490 39.679430  2025        31                   97        30
# 1    21.155490 39.679430  2025        31                   97        30
# 2    21.178600 39.625530  2025        31                   98        36
# 3    21.178600 39.625530  2025        31                   98        36
# 4    21.178600 39.643500  2025        21                   81        20
# ...        ...       ...   ...       ...                  ...       ...
# 4551 23.905450 39.194330  2025        21                   82        20
# 4552 23.905450 39.212300  2025        21                   92        20
# 4553 23.905450 39.212300  2025        21                   92        20
# 4554 23.928560 39.230270  2025        21                   78        20
# 4555 24.067210 39.338070  2025        21                   88        20
#
#       lc_prop2_assessment  lc_prop3  lc_prop3_assessment  lc_type1  lc_type2  \
# 0               97.000000        30                   97        10        10
# 1               97.000000        30                   97        10        10
# 2               98.000000        30                   98        12        12
# 3               98.000000        30                   98        12        12
# 4               81.000000        20                   81         8         8
# ...                   ...       ...                  ...       ...       ...
# 4551            82.000000        20                   82         8         8
# 4552            92.000000        20                   92         8         8
# 4553            92.000000        20                   92         8         8
# 4554            78.000000        20                   78         8         8
# 4555            88.000000        20                   88         8         8
#
#       lc_type3  lc_type4  lc_type5  lw  qc
# 0            1         6         6   2   0
# 1            1         6         6   2   0
# 2            1         6         7   2   0
# 3            1         6         7   2   0
# 4            4         1         1   2   0
# ...        ...       ...       ...  ..  ..
# 4551         4         2         2   2   0
# 4552         4         1         1   2   0
# 4553         4         1         1   2   0
# 4554         4         1         1   2   0
# 4555         4         1         1   2   0
#
# [4556 rows x 16 columns]

# %%
dataset_lulc.dtypes
# Out:
# x                      float64
# y                      float64
# year                     int32
# lc_prop1                 int64
# lc_prop1_assessment      int64
# lc_prop2                 int64
# lc_prop2_assessment    float64
# lc_prop3                 int64
# lc_prop3_assessment      int64
# lc_type1                 int64
# lc_type2                 int64
# lc_type3                 int64
# lc_type4                 int64
# lc_type5                 int64
# lw                       int64
# qc                       int64
# dtype: object

# %%
grouped_by_month_dataset = pd.merge(grouped_by_month_dataset, dataset_geo, on=['x', 'y'], how='left')

# %%
grouped_by_month_dataset = pd.merge(grouped_by_month_dataset, dataset_lulc, on=['x', 'y', 'year'], how='left')

# %% [markdown]
# ### Add Bio Variables ###

# %%
bio_values_df = grouped_by_month_dataset[['cell_number','year','month','rainfall_acc','lst_min','lst_max']]

# %%
bio_values_df.head(15)
# Out:
#     cell_number  year  month  rainfall_acc    lst_min   lst_max
# 0             0  2025      1    126.529998 -13.670000  2.990000
# 1             0  2025      2     72.169998 -10.630000  1.110000
# 2             0  2025      3    191.699996  -0.370000 13.170000
# 3             0  2025      4     57.949999  -1.230000 21.150000
# 4             0  2025      5      0.000000        NaN       NaN
# 5             1  2025      1    126.529998  -5.870000  2.370000
# 6             1  2025      2     72.169998  -6.210000 -0.430000
# 7             1  2025      3    191.699996  -1.750000 11.830000
# 8             1  2025      4     57.949999  -0.450000 21.990000
# 9             1  2025      5      0.000000        NaN       NaN
# 10            2  2025      1    126.529998  -5.710000  5.810000
# 11            2  2025      2     72.169998  -1.970000  2.010000
# 12            2  2025      3    191.699996  -1.110000 16.910000
# 13            2  2025      4     57.949999   0.270000 21.010000
# 14            2  2025      5      0.000000        NaN       NaN

# %%
# wnv_file.head(5)

# %%
# wnv_file

# %%
grouped_by_month_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16190 entries, 0 to 16189
# Data columns (total 72 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cell_number          16190 non-null  int64
#  1   dt_placement         16190 non-null  period[M]
#  2   NUTS1_ID             16190 non-null  object
#  3   NUTS1_NAME           16190 non-null  object
#  4   NUTS2_ID             16190 non-null  object
#  5   NUTS2_NAME           16190 non-null  object
#  6   NUTS3_ID             16190 non-null  object
#  7   NUTS3_NAME           16190 non-null  object
#  8   LAU1_NAME            16190 non-null  object
#  9   x                    16190 non-null  float64
#  10  y                    16190 non-null  float64
#  11  MOUNT_TYPE           16190 non-null  int32
#  12  URBN_TYPE            16190 non-null  int32
#  13  COAST_TYPE           16190 non-null  int32
#  14  year                 16190 non-null  int32
#  15  month                16190 non-null  int32
#  16  ndvi                 12852 non-null  float64
#  17  ndmi                 12852 non-null  float64
#  18  ndwi                 12852 non-null  float64
#  19  ndbi                 12852 non-null  float64
#  20  ndvi_mean            12920 non-null  float64
#  21  ndmi_mean            12920 non-null  float64
#  22  ndwi_mean            12920 non-null  float64
#  23  ndbi_mean            12920 non-null  float64
#  24  ndvi_std             12920 non-null  float64
#  25  ndmi_std             12920 non-null  float64
#  26  ndwi_std             12920 non-null  float64
#  27  ndbi_std             12920 non-null  float64
#  28  lst_day_mean         12947 non-null  float64
#  29  lst_night_mean       12948 non-null  float64
#  30  lst_mean             12943 non-null  float64
#  31  lst_jan_day_mean     16190 non-null  float64
#  32  lst_feb_day_mean     16165 non-null  float64
#  33  lst_mar_day_mean     16190 non-null  float64
#  34  lst_apr_day_mean     16190 non-null  float64
#  35  lst_jan_night_mean   16190 non-null  float64
#  36  lst_feb_night_mean   16170 non-null  float64
#  37  lst_mar_night_mean   16190 non-null  float64
#  38  lst_apr_night_mean   16190 non-null  float64
#  39  lst_jan_mean         16190 non-null  float64
#  40  lst_feb_mean         16145 non-null  float64
#  41  lst_mar_mean         16190 non-null  float64
#  42  lst_apr_mean         16190 non-null  float64
#  43  rainfall_mean        12952 non-null  float64
#  44  acc_rainfall_1week   16190 non-null  float64
#  45  acc_rainfall_2week   16190 non-null  float64
#  46  acc_rainfall_month   16190 non-null  float64
#  47  acc_rainfall_jan     16190 non-null  float64
#  48  rainfall_acc         16190 non-null  float64
#  49  lst_min              12947 non-null  float64
#  50  lst_max              12947 non-null  float64
#  51  distance_to_coast    16190 non-null  float64
#  52  distance_to_river    16190 non-null  float64
#  53  slope_mean_1km       16190 non-null  int64
#  54  aspect_mean_200m     16190 non-null  float64
#  55  elevation_mean_1km   16190 non-null  float64
#  56  hillshade_mean_1km   16190 non-null  float64
#  57  fs_area_1km          16190 non-null  float64
#  58  flow_accu_200m       16190 non-null  float64
#  59  lc_prop1             16190 non-null  int64
#  60  lc_prop1_assessment  16190 non-null  int64
#  61  lc_prop2             16190 non-null  int64
#  62  lc_prop2_assessment  16065 non-null  float64
#  63  lc_prop3             16190 non-null  int64
#  64  lc_prop3_assessment  16190 non-null  int64
#  65  lc_type1             16190 non-null  int64
#  66  lc_type2             16190 non-null  int64
#  67  lc_type3             16190 non-null  int64
#  68  lc_type4             16190 non-null  int64
#  69  lc_type5             16190 non-null  int64
#  70  lw                   16190 non-null  int64
#  71  qc                   16190 non-null  int64
# dtypes: float64(45), int32(5), int64(14), object(7), period[M](1)
# memory usage: 8.6+ MB

# %%
# wnv_file.info()

# %%
# wnv_file['dt_placement'] = pd.to_datetime(wnv_file['dt_placement'], format='%Y-%m').dt.to_period('M')

# %%
# wnv_file.info()

# %%
# wnv_file

# %%
# wnv_file['cases'].value_counts()

# %%
# wnv_file.cases.sum()

# %%
# merged = grouped_by_month_dataset.merge(wnv_file, how='left', on=['dt_placement', 'cell_code'] )
merged = grouped_by_month_dataset

# %%
merged
# Out:
#        cell_number dt_placement NUTS1_ID       NUTS1_NAME NUTS2_ID NUTS2_NAME  \
# 0                0      2025-01      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 1                0      2025-02      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 2                0      2025-03      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 3                0      2025-04      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 4                0      2025-05      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# ...            ...          ...      ...              ...      ...        ...
# 16185         3237      2025-01      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16186         3237      2025-02      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16187         3237      2025-03      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16188         3237      2025-04      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16189         3237      2025-05      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
#
#       NUTS3_ID          NUTS3_NAME   LAU1_NAME         x         y  \
# 0        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 1        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 2        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 3        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 4        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# ...        ...                 ...         ...       ...       ...
# 16185    EL613  μαγνησια, σποραδες   αλοννησου 24.067210 39.338070
# 16186    EL613  μαγνησια, σποραδες   αλοννησου 24.067210 39.338070
# 16187    EL613  μαγνησια, σποραδες   αλοννησου 24.067210 39.338070
# 16188    EL613  μαγνησια, σποραδες   αλοννησου 24.067210 39.338070
# 16189    EL613  μαγνησια, σποραδες   αλοννησου 24.067210 39.338070
#
#        MOUNT_TYPE  URBN_TYPE  COAST_TYPE  year  month     ndvi     ndmi  \
# 0               2          3           3  2025      1 0.269888 0.628876
# 1               2          3           3  2025      2 0.366295 0.346762
# 2               2          3           3  2025      3 0.440482 0.178383
# 3               2          3           3  2025      4 0.489129 0.187812
# 4               2          3           3  2025      5      NaN      NaN
# ...           ...        ...         ...   ...    ...      ...      ...
# 16185           2          2           1  2025      1 0.478596 0.176796
# 16186           2          2           1  2025      2 0.420769 0.147417
# 16187           2          2           1  2025      3 0.379472 0.162680
# 16188           2          2           1  2025      4 0.515194 0.129613
# 16189           2          2           1  2025      5      NaN      NaN
#
#            ndwi      ndbi  ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  \
# 0     -0.208902 -0.628876   0.254061   0.694518  -0.157651  -0.694518
# 1     -0.254671 -0.346762   0.261093   0.494400  -0.145091  -0.494400
# 2     -0.394812 -0.178383   0.378342   0.238523  -0.330627  -0.238523
# 3     -0.396035 -0.187812   0.455384   0.168838  -0.349366  -0.168838
# 4           NaN       NaN        NaN        NaN        NaN        NaN
# ...         ...       ...        ...        ...        ...        ...
# 16185 -0.370264 -0.176796   0.337622   0.249621  -0.085516  -0.249621
# 16186 -0.336262 -0.147417   0.330030   0.181059  -0.204898  -0.181059
# 16187 -0.280687 -0.162680   0.348769   0.206283  -0.176531  -0.206283
# 16188 -0.435509 -0.129613   0.448456   0.164979  -0.310998  -0.164979
# 16189       NaN       NaN        NaN        NaN        NaN        NaN
#
#        ndvi_std  ndmi_std  ndwi_std  ndbi_std  lst_
#
#        lw  qc
# 0       2   0
# 1       2   0
# 2       2   0
# 3       2   0
# 4       2   0
# ...    ..  ..
# 16185   2   0
# 16186   2   0
# 16187   2   0
# 16188   2   0
# 16189   2   0
#
# [16190 rows x 72 columns]

# %%
# merged = fillna(merged,{'cases': 0})

# %%
# merged['cases'].value_counts()

# %%
# merged.cases.sum()

# %%
# merged = merged.astype({'cases': 'int'})

# %%
missingno.matrix(merged)
# Out:
# <Axes: >

# %%
gc.collect()
# Out:
# 6

# %%
imputer = KNNImputer()

knn_imputer_columns = ['x', 'y', 'month', 'year', 'lst_min', 'lst_max']

temp_df = merged[knn_imputer_columns]

imputed_data = pd.DataFrame(imputer.fit_transform(temp_df), columns = temp_df.columns)
imputed_columns = ['lst_min', 'lst_max']

merged[imputed_columns] = imputed_data[imputed_columns]

# %%
missingno.matrix(merged)
# Out:
# <Axes: >

# %%
years = merged.year.unique()
years
# Out:
# array([2025])

# %%
cell_codes_un = merged.cell_number.unique()
cell_codes_un
# Out:
# array([   0,    1,    2, ..., 3235, 3236, 3237], dtype=int64)

# %%
rows = []
for year in years:
    for cell in cell_codes_un:
        filtered_df = merged.loc[(merged['year'] == year) & (merged['cell_number'] == cell)].copy()
        filtered_df.reset_index(drop = True, inplace = True)

        tmin = robjects.IntVector(filtered_df['lst_min'].tolist())
        tmax = robjects.IntVector(filtered_df['lst_max'].tolist())
        prec = robjects.IntVector(filtered_df['rainfall_acc'].tolist())

        bio_vars = list(dismo.biovars(prec, tmin, tmax))

        rows.append({'cell_number': cell, 
                     'year': year, 
                     'bio1': bio_vars[0],
                     'bio2': bio_vars[1],
                     'bio3': bio_vars[2],
                     'bio4': bio_vars[3],
                     'bio5': bio_vars[4],
                     'bio6': bio_vars[5],
                     'bio7': bio_vars[6],
                     'bio8': bio_vars[7],
                     'bio9': bio_vars[8],
                     'bio10': bio_vars[9],
                     'bio11': bio_vars[10],
                     'bio12': bio_vars[11],
                     'bio13': bio_vars[12],
                     'bio14': bio_vars[13],
                     'bio15': bio_vars[14],
                     'bio16': bio_vars[15],
                     'bio17': bio_vars[16],
                     'bio18': bio_vars[17],
                     'bio19': bio_vars[18]})
        
biovars_df = pd.DataFrame(rows)

# %%
biovars_df.head(20)
# Out:
#     cell_number  year     bio1      bio2      bio3       bio4      bio5  \
# 0             0  2025 3.400000 16.400000 48.235294 782.943165 21.000000
# 1             1  2025 4.200000 13.200000 48.888889 629.086640 21.000000
# 2             2  2025 5.700000 14.200000 54.615385 510.636857 21.000000
# 3             3  2025 3.700000 15.000000 42.857143 737.054950 22.000000
# 4             4  2025 5.300000 14.200000 52.592593 515.509457 21.000000
# 5             5  2025 4.900000 16.200000 55.862069 631.862327 23.000000
# 6             6  2025 4.000000 14.800000 47.741935 668.954408 21.000000
# 7             7  2025 4.700000 13.400000 51.538462 552.946652 20.000000
# 8             8  2025 5.700000 13.800000 60.000000 481.663783 20.000000
# 9             9  2025 5.200000 13.600000 54.400000 534.555890 21.000000
# 10           10  2025 5.100000 15.400000 57.037037 597.285526 21.000000
# 11           11  2025 5.200000 16.800000 56.000000 593.295879 23.000000
# 12           12  2025 5.600000 16.400000 58.571429 551.588615 22.000000
# 11 174.000000 0.000000 94.805754 279.000000 105.000000 229.000000 279.000000
# 12 166.000000 0.000000 93.122653 272.000000 106.000000 217.000000 272.000000
# 13 158.000000 0.000000 93.063679 270.000000  96.000000 197.000000 270.000000
# 14 158.000000 0.000000 93.063679 270.000000  96.000000 197.000000 270.000000
# 15 158.000000 0.000000 93.063679 270.000000  96.000000 197.000000 270.000000
# 16 158.000000 0.000000 93.063679 270.000000  96.000000 197.000000 270.000000
# 17 158.000000 0.000000 93.063679 270.000000  96.000000 197.000000 270.000000
# 18 174.000000 0.000000 94.805754 279.000000 105.000000 229.000000 279.000000
# 19 174.000000 0.000000 94.805754 279.000000 105.000000 229.000000 279.000000

# %%
merged = pd.merge(merged, biovars_df,  how='left', on=['cell_number', 'year'])

# %%
##check if biovars have the same value across all months
merged.loc[(merged['year'] == 2025) & (merged['cell_number'] == 0)]
# Out:
#    cell_number dt_placement NUTS1_ID       NUTS1_NAME NUTS2_ID NUTS2_NAME  \
# 0            0      2025-01      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 1            0      2025-02      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 2            0      2025-03      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 3            0      2025-04      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 4            0      2025-05      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
#
#   NUTS3_ID         NUTS3_NAME   LAU1_NAME         x         y  MOUNT_TYPE  \
# 0    EL611  καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430           2
# 1    EL611  καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430           2
# 2    EL611  καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430           2
# 3    EL611  καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430           2
# 4    EL611  καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430           2
#
#    URBN_TYPE  COAST_TYPE  year  month     ndvi     ndmi      ndwi      ndbi  \
# 0          3           3  2025      1 0.269888 0.628876 -0.208902 -0.628876
# 1          3           3  2025      2 0.366295 0.346762 -0.254671 -0.346762
# 2          3           3  2025      3 0.440482 0.178383 -0.394812 -0.178383
# 3          3           3  2025      4 0.489129 0.187812 -0.396035 -0.187812
# 4          3           3  2025      5      NaN      NaN       NaN       NaN
#
#    ndvi_mean  ndmi_mean  ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  \
# 0   0.254061   0.694518  -0.157651  -0.694518  0.189705  0.113860  0.137274
# 1   0.261093   0.494400  -0.145091  -0.494400  0.173774  0.130960  0.128415
# 2   0.378342   0.238523  -0.330627  -0.238523  0.116777  0.120771  0.085898
# 3   0.455384   0.168838  -0.349366  -0.168838  0.068506  0.113474  0.058134
# 4        NaN        NaN        NaN        NaN       NaN       NaN       NaN
#
#    ndbi_std  lst_day_mean  lst_night_mean  lst_mean  lst_jan_day_mean  \
# 0  0.113860      1.050645       -9.332667 -4.130000          1.050645
# 1  0.130960     -2.136667       -9.326154 -5.959583          1.050645
# 2  0.120771      9.162308        0.745789  5.187368          1.050645
# 3  0.113474     17.723333        2.630000 10.283889          1.050645
# 4       NaN           NaN             NaN       NaN          1.050645
#
#    lst_feb_day_mean  lst_mar_day_mean  lst_apr_day_mean  lst_jan_night_mean  \
# 0         -2.136667          9.162308         17.723333           -9.332667
# 1         -2.136667          9.162308         17.723333           -9.332667
# 2         -2.136667          9.162308         17.723333           -9.332667
# 3         -2.136667          9.162308         17.723333           -9.332667
# 4         -2.136667          9.162308         17.723333           -9.332667
#
#    lst_feb_night_mean  lst_mar_night_mean  lst_apr_night_mean  lst_jan_mean  \
# 0           -9.326154            0.745789            2.630000     -4.141011
# 1           -9.326154            0.745789            2.630000     -4.141011
# 2           -9.326154            0.745789            2.630000     -4.141011
# 3           -9.326154            0.745789            2.630000     -4.141011
# 4           -9.326154            0.745789            2.630000     -4.141011
#
#    lst_feb_mean  lst_mar_mean  lst_apr_mean  rainfall_mean  \
# 0     -5.731410      4.954049     10.176667       4.081613
# 1     -5.731410      4.954049     10.176667       2.577500
# 2     -5.731410      4.954049     10.176667       6.183871
# 3     -5.731410      4.954049     10.176667       1.931667
# 4     -5.731410      4.954049     10.176667            NaN
#
#    acc_rainfall_1week  acc_rainfall_2week  acc_rainfall_month  \
# 0            5.630000           83.839998          109.339998
# 1           49.999999           50.419999           72.279998
# 2           82.639999          133.209997          175.539996
# 3           25.539999           30.269999           57.949999
# 4           10.950000           28.849999           56.739999
#
#    acc_rainfall_jan  rainfall_acc    lst_min   lst_max  distance_to_coast  \
# 0        126.529998    126.529998 -13.670000  2.990000       20057.653131
# 1        198.699996     72.169998 -10.630000  1.110000       20057.653131
# 2        390.399991    191.699996  -0.370000 13.170000       20057.653131
# 3        448.349990     57.949999  -1.230000 21.150000       20057.653131
# 4        448.349990      0.000000  -0.714000 21.710000       20057.653131
#
#    distance_to_river  slope_mean_1km  aspect_mean_200m  elevation_mean_1km  \
# 0         722.827790              34        176.440719         1574.522145
# 1         722.827790              34        176.440719         1574.522145
# 2         722.827790              34        176.440719         1574.522145
# 3         722.827790              34        176.440719         1574.522145
# 4         722.827790              34        176.440719         1574.522145
#
#    hillshade_mean_1km  fs_area_1km  flow_accu_200m  lc_prop1  \
# 0          141.293561     0.000000        2.204379        31
# 1          141.293561     0.000000        2.204379        31
# 2          141.293561     0.000000        2.204379        31
# 3          141.293561     0.000000        2.204379        31
# 4          141.293561     0.000000        2.204379        31
#
#    lc_prop1_assessment  lc_prop2  lc_prop2_assessment  lc_prop3  \
# 0                   97        30            97.000000        30
# 1                   97        30            97.000000        30
# 2                   97        30            97.000000        30
# 3                   97        30            97.000000        30
# 4                   97        30            97.000000        30
#
#    lc_prop3_assessment  lc_type1  lc_type2  lc_type3  lc_type4  lc_type5  lw  \
# 0                   97        10        10         1         6         6   2
# 1                   97        10        10         1         6         6   2
# 2                   97        10        10         1         6         6   2
# 3                   97        10        10         1         6         6   2
# 4                   97        10        10         1         6         6   2
#
#    qc     bio1      bio2      bio3       bio4      bio5       bio6      bio7  \
# 0   0 3.400000 16.400000 48.235294 782.943165 21.000000 -13.000000 34.000000
# 1   0 3.400000 16.400000 48.235294 782.943165 21.000000 -13.000000 34.000000
# 2   0 3.400000 16.400000 48.235294 782.943165 21.000000 -13.000000 34.000000
# 3   0 3.400000 16.400000 48.235294 782.943165 21.000000 -13.000000 34.000000
# 4   0 3.400000 16.400000 48.235294 782.943165 21.000000 -13.000000 34.000000
#
#        bio8     bio9    bio10     bio11      bio12      bio13    bio14  \
# 0 -1.166667 5.000000 9.000000 -1.166667 446.000000 191.000000 0.000000
# 1 -1.166667 5.000000 9.000000 -1.166667 446.000000 191.000000 0.000000
# 2 -1.166667 5.000000 9.000000 -1.166667 446.000000 191.000000 0.000000
# 1766    EL653  2023 14067.000000  71993.000000 29360.000000 115420.000000
# 1767    EL653  2024 13819.000000  71499.000000 29720.000000 115038.000000
#
#          F_Y_LT15      F_Y15-64     F_Y_GE65       F_TOTAL
# 0    48144.000000 183544.000000 33859.000000 265547.000000
# 1    47283.000000 188320.000000 35622.000000 271225.000000
# 2    46367.000000 192179.000000 37065.000000 275611.000000
# 3    45313.000000 195444.000000 38973.000000 279730.000000
# 4    44292.000000 198519.000000 40741.000000 283552.000000
# ...           ...           ...          ...           ...
# 1763 15854.000000  74339.000000 33180.000000 123373.000000
# 1764 15590.000000  73901.000000 33433.000000 122924.000000
# 1765 13728.000000  67675.000000 32412.000000 113815.000000
# 1766 13393.000000  67069.000000 32564.000000 113026.000000
# 1767 13186.000000  66430.000000 32875.000000 112491.000000
#
# [1768 rows x 10 columns]

# %%
dataset = pd.merge(merged, df_demographics,  how='left', on=['NUTS3_ID', 'year'])

# %%
missingno.matrix(dataset)
# Out:
# <Axes: >

# %%
df_economics = pd.read_csv(r'E:\Drive\NOA\MBD-Prediction\NUTS3 Level\Greece\data\GR_EUROSTAT_Economics_Processed.csv', encoding = enc)

# %%
df_economics
# Out:
#      NUTS3_CODE  YEAR      MIO_EUR
# 0         EL301  2000  9725.080000
# 1         EL301  2001 10452.130000
# 2         EL301  2002 11780.170000
# 3         EL301  2003 12522.310000
# 4         EL301  2004 13769.510000
# ...         ...   ...          ...
# 1191      EL653  2018  3207.990000
# 1192      EL653  2019  3243.040000
# 1193      EL653  2020  2907.590000
# 1194      EL653  2021  3090.650000
# 1195      EL653  2022  3578.890000
#
# [1196 rows x 3 columns]

# %%
df_economics.rename(columns={'NUTS3_CODE': 'NUTS3_ID', 'YEAR': 'year'}, inplace=True)

# %%
df_economics
# Out:
#      NUTS3_ID  year      MIO_EUR
# 0       EL301  2000  9725.080000
# 1       EL301  2001 10452.130000
# 2       EL301  2002 11780.170000
# 3       EL301  2003 12522.310000
# 4       EL301  2004 13769.510000
# ...       ...   ...          ...
# 1191    EL653  2018  3207.990000
# 1192    EL653  2019  3243.040000
# 1193    EL653  2020  2907.590000
# 1194    EL653  2021  3090.650000
# 1195    EL653  2022  3578.890000
#
# [1196 rows x 3 columns]

# %%
dataset = pd.merge(dataset, df_economics,  how='left', on=['NUTS3_ID', 'year'])

# %%
missingno.matrix(dataset)
# Out:
# <Axes: >

# %%
df_trade = pd.read_csv(r'E:\Drive\NOA\MBD-Prediction\NUTS3 Level\Greece\data\GR_EUROSTAT_Trade_Processed.csv', encoding = enc)

# %%
df_trade
# Out:
#     NUTS3_CODE  YEAR      L_TOTAL    UNL_TOTAL
# 0        EL111  2008  6704.000000  7125.000000
# 1        EL111  2009  3031.000000  3303.000000
# 2        EL111  2010  2663.000000  2085.000000
# 3        EL111  2011  4163.000000  4212.000000
# 4        EL111  2012  4379.000000  5029.000000
# ..         ...   ...          ...          ...
# 818      EL653  2019  3278.000000  3737.000000
# 819      EL653  2020  4572.000000  4962.000000
# 820      EL653  2021  3040.000000  3666.000000
# 821      EL653  2022 11830.000000 12294.000000
# 822      EL653  2023  3092.000000  3999.000000
#
# [823 rows x 4 columns]

# %%
df_trade.rename(columns={'NUTS3_CODE': 'NUTS3_ID', 'YEAR': 'year'}, inplace=True)

# %%
df_trade
# Out:
#     NUTS3_ID  year      L_TOTAL    UNL_TOTAL
# 0      EL111  2008  6704.000000  7125.000000
# 1      EL111  2009  3031.000000  3303.000000
# 2      EL111  2010  2663.000000  2085.000000
# 3      EL111  2011  4163.000000  4212.000000
# 4      EL111  2012  4379.000000  5029.000000
# ..       ...   ...          ...          ...
# 818    EL653  2019  3278.000000  3737.000000
# 819    EL653  2020  4572.000000  4962.000000
# 820    EL653  2021  3040.000000  3666.000000
# 821    EL653  2022 11830.000000 12294.000000
# 822    EL653  2023  3092.000000  3999.000000
#
# [823 rows x 4 columns]

# %%
dataset = pd.merge(dataset, df_trade,  how='left', on=['NUTS3_ID', 'year'])

# %%
missingno.matrix(dataset)
# Out:
# <Axes: >

# %%
missing = describe_dataframe(dataset, remove_zeros=True)

# %%
missing
# Out:
#                   Column    Missing
# 16                  ndvi  20.617700
# 17                  ndmi  20.617700
# 18                  ndwi  20.617700
# 19                  ndbi  20.617700
# 20             ndvi_mean  20.197700
# 21             ndmi_mean  20.197700
# 22             ndwi_mean  20.197700
# 23             ndbi_mean  20.197700
# 24              ndvi_std  20.197700
# 25              ndmi_std  20.197700
# 26              ndwi_std  20.197700
# 27              ndbi_std  20.197700
# 28          lst_day_mean  20.030900
# 29        lst_night_mean  20.024700
# 30              lst_mean  20.055600
# 32      lst_feb_day_mean   0.154400
# 36    lst_feb_night_mean   0.123500
# 40          lst_feb_mean   0.277900
# 43         rainfall_mean  20.000000
# 62   lc_prop2_assessment   0.772100
# 91              M_Y_LT15 100.000000
# 92              M_Y15-64 100.000000
# 93              M_Y_GE65 100.000000
# 94               M_TOTAL 100.000000
# 95              F_Y_LT15 100.000000
# 96              F_Y15-64 100.000000
# 97              F_Y_GE65 100.000000
# 98               F_TOTAL 100.000000
# 99               MIO_EUR 100.000000
# 100              L_TOTAL 100.000000
# 101            UNL_TOTAL 100.000000

# %%
dataset
# Out:
#        cell_number dt_placement NUTS1_ID       NUTS1_NAME NUTS2_ID NUTS2_NAME  \
# 0                0      2025-01      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 1                0      2025-02      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 2                0      2025-03      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 3                0      2025-04      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 4                0      2025-05      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# ...            ...          ...      ...              ...      ...        ...
# 16185         3237      2025-01      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16186         3237      2025-02      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16187         3237      2025-03      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16188         3237      2025-04      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16189         3237      2025-05      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
#
#       NUTS3_ID          NUTS3_NAME   LAU1_NAME         x         y  \
# 0        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 1        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 2        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 3        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 4        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679
# 2                  34        176.440719         1574.522145
# 3                  34        176.440719         1574.522145
# 4                  34        176.440719         1574.522145
# ...               ...               ...                 ...
# 16185              14        173.137787           48.760165
# 16186              14        173.137787           48.760165
# 16187              14        173.137787           48.760165
# 16188              14        173.137787           48.760165
# 16189              14        173.137787           48.760165
#
#        hillshade_mean_1km  fs_area_1km  flow_accu_200m  lc_prop1  \
# 0              141.293561     0.000000        2.204379        31
# 1              141.293561     0.000000        2.204379        31
# 2              141.293561     0.000000        2.204379        31
# 3              141.293561     0.000000        2.204379        31
# 4              141.293561     0.000000        2.204379        31
# ...                   ...          ...             ...       ...
# 16185          180.090346     0.206898        8.135650        21
# 16186          180.090346     0.206898        8.135650        21
# 16187          180.090346     0.206898        8.135650        21
# 16188          180.090346     0.206898        8.135650        21
# 16189          180.090346     0.206898        8.135650        21
#
#        lc_prop1_assessment  lc_prop2  lc_prop2_assessment  lc_prop3  \
# 0                       97        30            97.000000        30
# 1                       97        30            97.000000        30
# 2                       97        30            97.000000        30
# 3                       97        30            97.000000        30
# 4                       97        30            97.000000        30
# ...                    ...       ...                  ...       ...
# 16185                   88        20            88.000000        20
# 16186                   88        20            88.000000        20
# 16187                   88        20            88.000000        20
# 16188                   88        20            88.000000        20
# 16189                   88        20            88.000000        20
#
#        lc_prop3_assessment  lc_type1  lc_type2  lc_type3  lc_type4  lc_type5  \
# 0                       97        10        10         1         6         6
# 1                       97        10        10         1         6         6
# 2                       97        10        10         1         6         6
# 3                       97        10        10         1         6         6
# 4                       97        10        10         1         6         6
# ...                    ...       ...       ...       ...       ...       ...
# 16185                   88         8         8         4         1         1
# 16186                   88         8         8         4         1         1
# 16187                   88         8         8         4         1         1
# 16188                   88         8         8         4         1         1
# 16189                   88         8         8         4         1         1
#
#        lw  qc      bio1      bio2      bio3       bio4      bio5       bio6  \
# 0       2   0  3.400000 16.400000 48.235294 782.943165 21.000000 -13.000000
# 1       2   0  3.400000 16.400000 48.235294 782.943165 21.000000 -13.000000
# 2       2   0  3.400000 16.400000 48.235294 782.943165 21.000000 -13.000000
# 3       2   0  3.400000 16.400000 48.235294 782.943165 21.000000 -13.000000
# 4       2   0  3.400000 16.400000 48.235294 782.943165 21.000000 -13.000000
# ...    ..  ..       ...       ...       ...        ...       ...        ...
# 16185   2   0 11.200000 14.400000 68.571429 301.247407 23.000000   2.000000
# 16186   2   0 11.200000 14.400000 68.571429 301.247407 23.000000   2.000000
# 16187   2   0 11.200000 14.400000 68.571429 301.247407 23.000000   2.000000
# 16188   2   0 11.200000 14.400000 68.571429 301.247407 23.000000   2.000000
# 16189   2   0 11.200000 14.400000 68.571429 301.247407 23.000000   2.000000
#
#            bio7      bio8      bio9     bio10     bio11      bio12      bio13  \
# 0     34.000000 -1.166667  5.000000  9.000000 -1.166667 446.000000 191.000000
# 1     34.000000 -1.166667  5.000000  9.000000 -1.166667 446.000000 191.000000
# 2     34.000000 -1.166667  5.000000  9.000000 -1.166667 446.000000 191.000000
# 3     34.000000 -1.166667  5.000000  9.000000 -1.166667 446.000000 191.000000
# 4     34.000000 -1.166667  5.000000  9.000000 -1.166667 446.000000 191.000000
# ...         ...       ...       ...       ...       ...        ...        ...
# 16185 21.000000 11.833333 11.666667 13.333333  9.500000 226.000000 100.000000
# 16186 21.000000 11.833333 11.666667 13.333333  9.500000 226.000000 100.000000
# 16187 21.000000 11.833333 11.666667 13.333333  9.500000 226.000000 100.000000
# 16188 21.000000 11.833333 11.666667 13.333333  9.500000 226.000000 100.000000
# 16189 21.000000 11.833333 11.666667 13.333333  9.500000 226.000000 100.000000
#
#          bio14     bio15      bio16      bio17      bio18      bio19  \
# 0     0.000000 80.342144 389.000000 183.000000 248.000000 389.000000
# 1     0.000000 80.342144 389.000000 183.000000 248.000000 389.000000
# 2     0.000000 80.342144 389.000000 183.000000 248.000000 389.000000
# 3     0.000000 80.342144 389.000000 183.000000 248.000000 389.000000
# 4     0.000000 80.342144 389.000000 183.000000 248.000000 389.000000
# ...        ...       ...        ...        ...        ...        ...
# 16185 0.000000 89.433500 204.000000  50.000000 128.000000  98.000000
# 16186 0.000000 89.433500 204.000000  50.000000 128.000000  98.000000
# 16187 0.000000 89.433500 204.000000  50.000000 128.000000  98.000000
# 16188 0.000000 89.433500 204.000000  50.000000 128.000000  98.000000
# 16189 0.000000 89.433500 204.000000  50.000000 128.000000  98.000000
#
#        M_Y_LT15  M_Y15-64  M_Y_GE65  M_TOTAL  F_Y_LT15  F_Y15-64  F_Y_GE65  \
# 0           NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 3           NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 4           NaN       NaN       NaN      NaN       NaN       NaN       NaN
# ...         ...       ...       ...      ...       ...       ...       ...
# 16185       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 16186       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 16187       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 16188       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 16189       NaN       NaN       NaN      NaN       NaN       NaN       NaN
#
#        F_TOTAL  MIO_EUR  L_TOTAL  UNL_TOTAL
# 0          NaN      NaN      NaN        NaN
# 1          NaN      NaN      NaN        NaN
# 2          NaN      NaN      NaN        NaN
# 3          NaN      NaN      NaN        NaN
# 4          NaN      NaN      NaN        NaN
# ...        ...      ...      ...        ...
# 16185      NaN      NaN      NaN        NaN
# 16186      NaN      NaN      NaN        NaN
# 16187      NaN      NaN      NaN        NaN
# 16188      NaN      NaN      NaN        NaN
# 16189      NaN      NaN      NaN        NaN
#
# [16190 rows x 102 columns]

# %%
dataset.reset_index(inplace=True, drop=True)

# %%
# dataset['cases'].value_counts()

# %%
# dataset['cases'].sum()

# %%
dataset
# Out:
#        cell_number dt_placement NUTS1_ID       NUTS1_NAME NUTS2_ID NUTS2_NAME  \
# 0                0      2025-01      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 1                0      2025-02      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 2                0      2025-03      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 3                0      2025-04      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 4                0      2025-05      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# ...            ...          ...      ...              ...      ...        ...
# 16185         3237      2025-01      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16186         3237      2025-02      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16187         3237      2025-03      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16188         3237      2025-04      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
# 16189         3237      2025-05      EL6  κεντρικη ελλαδα     EL61   θεσσαλια
#
#       NUTS3_ID          NUTS3_NAME   LAU1_NAME         x         y  \
# 0        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 1        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 2        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679430
# 3        EL611   καρδιτσα, τρικαλα  καλαμπακας 21.155490 39.679
# 16189   4.838000 21.826000         474.834345       56432.126469
#
#        slope_mean_1km  aspect_mean_200m  elevation_mean_1km  \
# 0                  34        176.440719         1574.522145
# 1                  34        176.440719         1574.522145
# 2                  34        176.440719         1574.522145
# 3                  34        176.440719         1574.522145
# 4                  34        176.440719         1574.522145
# ...               ...               ...                 ...
# 16185              14        173.137787           48.760165
# 16186              14        173.137787           48.760165
# 16187              14        173.137787           48.760165
# 16188              14        173.137787           48.760165
# 16189              14        173.137787           48.760165
#
#        hillshade_mean_1km  fs_area_1km  flow_accu_200m  lc_prop1  \
# 0              141.293561     0.000000        2.204379        31
# 1              141.293561     0.000000        2.204379        31
# 2              141.293561     0.000000        2.204379        31
# 3              141.293561     0.000000        2.204379        31
# 4              141.293561     0.000000        2.204379        31
# ...                   ...          ...             ...       ...
# 16185          180.090346     0.206898        8.135650        21
# 16186          180.090346     0.206898        8.135650        21
# 16187          180.090346     0.206898        8.135650        21
# 16188          180.090346     0.206898        8.135650        21
# 16189          180.090346     0.206898        8.135650        21
#
#        lc_prop1_assessment  lc_prop2  lc_prop2_assessment  lc_prop3  \
# 0                       97        30            97.000000        30
# 1                       97        30            97.000000        30
# 2                       97        30            97.000000        30
# 3                       97        30            97.000000        30
# 4                       97        30            97.000000        30
# ...                    ...       ...                  ...       ...
# 16185                   88        20            88.000000        20
# 16186                   88        20            88.000000        20
# 16187                   88        20            88.000000        20
# 16188                   88        20            88.000000        20
# 16189                   88        20            88.000000        20
#
#        lc_prop3_assessment  lc_type1  lc_type2  lc_type3  lc_type4  lc_type5  \
# 0                       97        10        10         1         6         6
# 1                       97        10        10         1         6         6
# 2                       97        10        10         1         6         6
# 3                       97        10        10         1         6         6
# 4                       97        10        10         1         6         6
# ...                    ...       ...       ...       ...       ...       ...
# 16185                   88         8         8         4         1         1
# 16186                   88         8         8         4         1         1
# 16187                   88         8         8         4         1         1
# 16188                   88         8         8         4         1         1
# 16189                   88         8         8         4         1         1
#
#        lw  qc      bio1      bio2      bio3       bio4      bio5       bio6  \
# 0       2   0  3.400000 16.400000 48.235294 782.943165 21.000000 -13.000000
# 1       2   0  3.400000 16.400000 48.235294 782.943165 21.000000 -13.000000
# 2       2   0  3.400000 16.400000 48.235294 782.943165 21.000000 -13.000000
# 3       2   0  3.400000 16.400000 48.235294 782.943165 21.000000 -13.000000
# 4       2   0  3.400000 16.400000 48.235294 782.943165 21.000000 -13.000000
# ...    ..  ..       ...       ...       ...        ...       ...        ...
# 16185   2   0 11.200000 14.400000 68.571429 301.247407 23.000000   2.000000
# 16186   2   0 11.200000 14.400000 68.571429 301.247407 23.000000   2.000000
# 16187   2   0 11.200000 14.400000 68.571429 301.247407 23.000000   2.000000
# 16188   2   0 11.200000 14.400000 68.571429 301.247407 23.000000   2.000000
# 16189   2   0 11.200000 14.400000 68.571429 301.247407 23.000000   2.000000
#
#            bio7      bio8      bio9     bio10     bio11      bio12      bio13  \
# 0     34.000000 -1.166667  5.000000  9.000000 -1.166667 446.000000 191.000000
# 1     34.000000 -1.166667  5.000000  9.000000 -1.166667 446.000000 191.000000
# 2     34.000000 -1.166667  5.000000  9.000000 -1.166667 446.000000 191.000000
# 3     34.000000 -1.166667  5.000000  9.000000 -1.166667 446.000000 191.000000
# 4     34.000000 -1.166667  5.000000  9.000000 -1.166667 446.000000 191.000000
# ...         ...       ...       ...       ...       ...        ...        ...
# 16185 21.000000 11.833333 11.666667 13.333333  9.500000 226.000000 100.000000
# 16186 21.000000 11.833333 11.666667 13.333333  9.500000 226.000000 100.000000
# 16187 21.000000 11.833333 11.666667 13.333333  9.500000 226.000000 100.000000
# 16188 21.000000 11.833333 11.666667 13.333333  9.500000 226.000000 100.000000
# 16189 21.000000 11.833333 11.666667 13.333333  9.500000 226.000000 100.000000
#
#          bio14     bio15      bio16      bio17      bio18      bio19  \
# 0     0.000000 80.342144 389.000000 183.000000 248.000000 389.000000
# 1     0.000000 80.342144 389.000000 183.000000 248.000000 389.000000
# 2     0.000000 80.342144 389.000000 183.000000 248.000000 389.000000
# 3     0.000000 80.342144 389.000000 183.000000 248.000000 389.000000
# 4     0.000000 80.342144 389.000000 183.000000 248.000000 389.000000
# ...        ...       ...        ...        ...        ...        ...
# 16185 0.000000 89.433500 204.000000  50.000000 128.000000  98.000000
# 16186 0.000000 89.433500 204.000000  50.000000 128.000000  98.000000
# 16187 0.000000 89.433500 204.000000  50.000000 128.000000  98.000000
# 16188 0.000000 89.433500 204.000000  50.000000 128.000000  98.000000
# 16189 0.000000 89.433500 204.000000  50.000000 128.000000  98.000000
#
#        M_Y_LT15  M_Y15-64  M_Y_GE65  M_TOTAL  F_Y_LT15  F_Y15-64  F_Y_GE65  \
# 0           NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 3           NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 4           NaN       NaN       NaN      NaN       NaN       NaN       NaN
# ...         ...       ...       ...      ...       ...       ...       ...
# 16185       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 16186       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 16187       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 16188       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 16189       NaN       NaN       NaN      NaN       NaN       NaN       NaN
#
#        F_TOTAL  MIO_EUR  L_TOTAL  UNL_TOTAL
# 0          NaN      NaN      NaN        NaN
# 1          NaN      NaN      NaN        NaN
# 2          NaN      NaN      NaN        NaN
# 3          NaN      NaN      NaN        NaN
# 4          NaN      NaN      NaN        NaN
# ...        ...      ...      ...        ...
# 16185      NaN      NaN      NaN        NaN
# 16186      NaN      NaN      NaN        NaN
# 16187      NaN      NaN      NaN        NaN
# 16188      NaN      NaN      NaN        NaN
# 16189      NaN      NaN      NaN        NaN
#
# [16190 rows x 102 columns]

# %%
cols = dataset.columns

# %%
print(cols)
# Out:
# Index(['cell_number', 'dt_placement', 'NUTS1_ID', 'NUTS1_NAME', 'NUTS2_ID',
#        'NUTS2_NAME', 'NUTS3_ID', 'NUTS3_NAME', 'LAU1_NAME', 'x',
#        ...
#        'M_Y15-64', 'M_Y_GE65', 'M_TOTAL', 'F_Y_LT15', 'F_Y15-64', 'F_Y_GE65',
#        'F_TOTAL', 'MIO_EUR', 'L_TOTAL', 'UNL_TOTAL'],
#       dtype='object', length=102)

# %%
len(cols)
# Out:
# 102

# %%
years = dataset.year.unique().tolist()

# %%
for item in years:
    dataset[dataset.year == item].to_csv(f"../../data/{NUTS2}/{NUTS0}_{NUTS2}_WNV_Dataset_GRID_{item}.csv", encoding = enc, index = False)
