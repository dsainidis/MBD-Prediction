# %% [markdown]
# ## Creates the **Grid File** of a specific region by converting the available shapefile into mutliple (X,Y) coordinate pairs to represent each NUTS3 Unit ##

# %%
import pandas as pd

import random
import geopandas as gpd
import numpy as np
import os

import sys

sys.path.insert(0, r"E:\Drive\NOA\MBD-Prediction\Modules")


from utils import process_greek, create_grid

enc = 'utf-8'
dec = 'greek8'
random.seed(0)
np.random.seed(0)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
NUTS0 = 'GR'
NUTS2 = 'Thessaly'
NUTS2_ID = 'EL61'

# %%
greece_nuts3_gdf = gpd.read_file(r"E:\Drive\NOA\MBD-Prediction\Europe NUTS - LAU Shapefiles\Greece\data\EL_NUTS2.shp",  encoding=enc)

# %%
greece_nuts3_gdf.head(5)
# Out:
#   NUTS_ID CNTR_CODE                    NAME_LATN                   NUTS_NAME  \
# 0    EL62        EL                  Ionia Nisia                 Ιόνια Νησιά
# 1    EL63        EL                Dytiki Elláda               Δυτική Ελλάδα
# 2    EL41        EL                Voreio Aigaio               Βόρειο Αιγαίο
# 3    EL42        EL                 Notio Aigaio                Νότιο Αιγαίο
# 4    EL51        EL  Anatoliki Makedonia, Thraki  Aνατολική Μακεδονία, Θράκη
#
#   CNTR_NAME                                           geometry
# 0    Greece  MULTIPOLYGON (((21.11222 38.31611, 21.11426 38...
# 1    Greece  MULTIPOLYGON (((22.37297 38.14222, 22.37737 38...
# 2    Greece  MULTIPOLYGON (((26.95446 37.75858, 26.96711 37...
# 3    Greece  MULTIPOLYGON (((29.63524 36.11068, 29.63181 36...
# 4    Greece  MULTIPOLYGON (((26.35788 41.71110, 26.36917 41...

# %%
print(f'greece_nuts3 CRS: {greece_nuts3_gdf.crs}')
# Out:
# greece_nuts3 CRS: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433],AXIS["Longitude",EAST],AXIS["Latitude",NORTH]]

# %%
greece_nuts3_gdf = greece_nuts3_gdf.to_crs(epsg=4326)

# %%
print(f'greece_nuts3 CRS: {greece_nuts3_gdf.crs}')
# Out:
# greece_nuts3 CRS: EPSG:4326

# %%
greece_nuts3_gdf.head(5)
# Out:
#   NUTS_ID CNTR_CODE                    NAME_LATN                   NUTS_NAME  \
# 0    EL62        EL                  Ionia Nisia                 Ιόνια Νησιά
# 1    EL63        EL                Dytiki Elláda               Δυτική Ελλάδα
# 2    EL41        EL                Voreio Aigaio               Βόρειο Αιγαίο
# 3    EL42        EL                 Notio Aigaio                Νότιο Αιγαίο
# 4    EL51        EL  Anatoliki Makedonia, Thraki  Aνατολική Μακεδονία, Θράκη
#
#   CNTR_NAME                                           geometry
# 0    Greece  MULTIPOLYGON (((21.11222 38.31611, 21.11426 38...
# 1    Greece  MULTIPOLYGON (((22.37297 38.14222, 22.37737 38...
# 2    Greece  MULTIPOLYGON (((26.95446 37.75858, 26.96711 37...
# 3    Greece  MULTIPOLYGON (((29.63524 36.11068, 29.63181 36...
# 4    Greece  MULTIPOLYGON (((26.35788 41.71110, 26.36917 41...

# %%
greece_nuts3_gdf.NUTS_ID.unique()
# Out:
# array(['EL62', 'EL63', 'EL41', 'EL42', 'EL51', 'EL30', 'EL61', 'EL65',
#        'EL43', 'EL52', 'EL64', 'EL54', 'EL53'], dtype=object)

# %%
print(f'Length of greece_nuts3_gdf: {len(greece_nuts3_gdf)}')
# Out:
# Length of greece_nuts3_gdf: 13

# %%
#choose the correct region

nuts2_gdf = greece_nuts3_gdf.loc[greece_nuts3_gdf['NUTS_ID'] == f'{NUTS2_ID}'].copy()
nuts2_gdf.head()
# Out:
#   NUTS_ID CNTR_CODE  NAME_LATN NUTS_NAME CNTR_NAME  \
# 6    EL61        EL  Thessalia  Θεσσαλία    Greece
#
#                                             geometry
# 6  MULTIPOLYGON (((24.32680 39.33398, 24.32475 39...

# %%
print(f'nuts2_gdf CRS: {nuts2_gdf.crs}')
# Out:
# nuts2_gdf CRS: EPSG:4326

# %%
nuts2_gdf.plot(facecolor="none", edgecolor='grey', figsize=(10, 10), color='orange')
# Out:
# <Axes: >

# %%
nuts2_gdf
# Out:
#   NUTS_ID CNTR_CODE  NAME_LATN NUTS_NAME CNTR_NAME  \
# 6    EL61        EL  Thessalia  Θεσσαλία    Greece
#
#                                             geometry
# 6  MULTIPOLYGON (((24.32680 39.33398, 24.32475 39...

# %%
nuts2_gdf.drop(columns=['CNTR_CODE','NAME_LATN','CNTR_NAME'], inplace = True)
nuts2_gdf.reset_index(drop = True, inplace = True)
process_greek(nuts2_gdf, 'NUTS_NAME')

# %%
nuts2_gdf.head(5)
# Out:
#   NUTS_ID NUTS_NAME                                           geometry
# 0    EL61  θεσσαλια  MULTIPOLYGON (((24.32680 39.33398, 24.32475 39...

# %%
nuts2_gdf.plot(facecolor="none", edgecolor='grey', figsize=(15, 10), color='orange')
# Out:
# <Axes: >

# %%
nuts2_gdf.reset_index(inplace=True, drop = True)

# %%
empty_gdf = gpd.GeoDataFrame(columns=['geometry'], geometry='geometry', crs='EPSG:4326')

df_grid = create_grid(empty_gdf, nuts2_gdf, col_municipal='NUTS_ID', dimension=2)
# df_grid_2.to_csv('data/grid_2.csv', index=False)
# # df_grid_2 = pd.read_csv('data/grid_2.csv')
# # df_grid_2['geometry'] = gpd.GeoSeries.from_wkt(df_grid_2['geometry'])
# # df_grid_2 = gpd.GeoDataFrame(df_grid_2, geometry='geometry')

# %%
df_grid.shape
# Out:
# (3238, 5)

# %%
df_grid.head()
# Out:
#                                             geometry  \
# 0  POLYGON ((21.16704 39.67045, 21.16704 39.68842...
# 1  POLYGON ((21.19015 39.61655, 21.19015 39.63452...
# 2  POLYGON ((21.19015 39.63452, 21.19015 39.65248...
# 3  POLYGON ((21.19015 39.65248, 21.19015 39.67045...
# 4  POLYGON ((21.19015 39.67045, 21.19015 39.68842...
#
#                                          centers  NAME         x         y
# 0   POINT (21.155488402451258 39.67943231820849)  EL61  21.15549  39.67943
# 1  POINT (21.178597337418765 39.625532243407854)  EL61  21.17860  39.62553
# 2  POINT (21.178597337418765 39.643498935008054)  EL61  21.17860  39.64350
# 3  POINT (21.178597337418765 39.661465626608276)  EL61  21.17860  39.66147
# 4   POINT (21.178597337418765 39.67943231820849)  EL61  21.17860  39.67943

# %%
df_grid.rename(columns={"NAME": "NUTS2_ID"}, inplace = True)

# %%
ax = nuts2_gdf.plot(figsize=(15, 15), facecolor="none", edgecolor='black', lw=2)
df_grid.plot(facecolor="none", edgecolor='grey', ax=ax, color='orange')
# Out:
# <Axes: >

# %%
nuts2_grid = df_grid.drop(columns=['centers'])

# %%
nuts2_grid['cell_number'] = nuts2_grid.index

# %%
nuts2_grid
# Out:
#                                                geometry NUTS2_ID         x  \
# 0     POLYGON ((21.16704 39.67045, 21.16704 39.68842...     EL61  21.15549
# 1     POLYGON ((21.19015 39.61655, 21.19015 39.63452...     EL61  21.17860
# 2     POLYGON ((21.19015 39.63452, 21.19015 39.65248...     EL61  21.17860
# 3     POLYGON ((21.19015 39.65248, 21.19015 39.67045...     EL61  21.17860
# 4     POLYGON ((21.19015 39.67045, 21.19015 39.68842...     EL61  21.17860
# ...                                                 ...      ...       ...
# 3233  POLYGON ((23.75524 39.09551, 23.75524 39.11348...     EL61  23.74369
# 3234  POLYGON ((23.91701 39.18535, 23.91701 39.20331...     EL61  23.90545
# 3235  POLYGON ((23.91701 39.20331, 23.91701 39.22128...     EL61  23.90545
# 3236  POLYGON ((23.94012 39.22128, 23.94012 39.23925...     EL61  23.92856
# 3237  POLYGON ((24.07877 39.32908, 24.07877 39.34705...     EL61  24.06721
#
#              y  cell_number
# 0     39.67943            0
# 1     39.62553            1
# 2     39.64350            2
# 3     39.66147            3
# 4     39.67943            4
# ...        ...          ...
# 3233  39.10450         3233
# 3234  39.19433         3234
# 3235  39.21230         3235
# 3236  39.23027         3236
# 3237  39.33807         3237
#
# [3238 rows x 5 columns]

# %%
nuts2_grid_points = gpd.GeoDataFrame(nuts2_grid, geometry=gpd.points_from_xy(nuts2_grid.x, nuts2_grid.y))

# %%
nuts2_grid_points
# Out:
#                        geometry NUTS2_ID         x         y  cell_number
# 0     POINT (21.15549 39.67943)     EL61  21.15549  39.67943            0
# 1     POINT (21.17860 39.62553)     EL61  21.17860  39.62553            1
# 2     POINT (21.17860 39.64350)     EL61  21.17860  39.64350            2
# 3     POINT (21.17860 39.66147)     EL61  21.17860  39.66147            3
# 4     POINT (21.17860 39.67943)     EL61  21.17860  39.67943            4
# ...                         ...      ...       ...       ...          ...
# 3233  POINT (23.74369 39.10450)     EL61  23.74369  39.10450         3233
# 3234  POINT (23.90545 39.19433)     EL61  23.90545  39.19433         3234
# 3235  POINT (23.90545 39.21230)     EL61  23.90545  39.21230         3235
# 3236  POINT (23.92856 39.23027)     EL61  23.92856  39.23027         3236
# 3237  POINT (24.06721 39.33807)     EL61  24.06721  39.33807         3237
#
# [3238 rows x 5 columns]

# %%
ax = nuts2_grid_points.plot(markersize=2.5, figsize=(20, 20), color='red')
nuts2_gdf.plot(facecolor="none", edgecolor='black', ax=ax, lw=2)
# Out:
# <Axes: >

# %%
final_grid = nuts2_grid[['cell_number', 'NUTS2_ID', 'x', 'y', 'geometry']]

final_grid.reset_index(drop = True, inplace= True)

# %%
final_grid
# Out:
#       cell_number NUTS2_ID         x         y  \
# 0               0     EL61  21.15549  39.67943
# 1               1     EL61  21.17860  39.62553
# 2               2     EL61  21.17860  39.64350
# 3               3     EL61  21.17860  39.66147
# 4               4     EL61  21.17860  39.67943
# ...           ...      ...       ...       ...
# 3233         3233     EL61  23.74369  39.10450
# 3234         3234     EL61  23.90545  39.19433
# 3235         3235     EL61  23.90545  39.21230
# 3236         3236     EL61  23.92856  39.23027
# 3237         3237     EL61  24.06721  39.33807
#
#                                                geometry
# 0     POLYGON ((21.16704 39.67045, 21.16704 39.68842...
# 1     POLYGON ((21.19015 39.61655, 21.19015 39.63452...
# 2     POLYGON ((21.19015 39.63452, 21.19015 39.65248...
# 3     POLYGON ((21.19015 39.65248, 21.19015 39.67045...
# 4     POLYGON ((21.19015 39.67045, 21.19015 39.68842...
# ...                                                 ...
# 3233  POLYGON ((23.75524 39.09551, 23.75524 39.11348...
# 3234  POLYGON ((23.91701 39.18535, 23.91701 39.20331...
# 3235  POLYGON ((23.91701 39.20331, 23.91701 39.22128...
# 3236  POLYGON ((23.94012 39.22128, 23.94012 39.23925...
# 3237  POLYGON ((24.07877 39.32908, 24.07877 39.34705...
#
# [3238 rows x 5 columns]

# %%
final_grid.drop(columns='geometry')
# Out:
#       cell_number NUTS2_ID         x         y
# 0               0     EL61  21.15549  39.67943
# 1               1     EL61  21.17860  39.62553
# 2               2     EL61  21.17860  39.64350
# 3               3     EL61  21.17860  39.66147
# 4               4     EL61  21.17860  39.67943
# ...           ...      ...       ...       ...
# 3233         3233     EL61  23.74369  39.10450
# 3234         3234     EL61  23.90545  39.19433
# 3235         3235     EL61  23.90545  39.21230
# 3236         3236     EL61  23.92856  39.23027
# 3237         3237     EL61  24.06721  39.33807
#
# [3238 rows x 4 columns]

# %%
final_grid.drop(columns='geometry').to_csv(f'../../data/{NUTS2}/GR_{NUTS2}_GRID.csv', encoding=enc, index = False)

# %%
final_grid.to_file(f'../../data/{NUTS2}/GR_{NUTS2}_GRID.shp', encoding = 'utf-8')
