# %%
import pandas as pd

# %%
df = pd.read_csv('GR_CMacedonia_Predictions_Oct_2025.csv')

# %%
df
# Out:
#          cell_id       lau1  month  year        x        y  risk_score
# 0     EL524-0000    ΕΔΕΣΣΑΣ     10  2025  21.7633  40.7981    0.000209
# 1     EL524-0001    ΕΔΕΣΣΑΣ     10  2025  21.7633  40.8160    0.000102
# 2     EL524-0002    ΕΔΕΣΣΑΣ     10  2025  21.7633  40.8340    0.000141
# 3     EL524-0003    ΕΔΕΣΣΑΣ     10  2025  21.7633  40.8520    0.000085
# 4     EL524-0004    ΕΔΕΣΣΑΣ     10  2025  21.7868  40.7981    0.003823
# ...          ...        ...    ...   ...      ...      ...         ...
# 4411  EL526-4411  ΑΜΦΙΠΟΛΗΣ     10  2025  24.0588  40.9957    0.016251
# 4412  EL526-4412  ΑΜΦΙΠΟΛΗΣ     10  2025  24.0588  41.0137    0.106112
# 4413  EL526-4413  ΑΜΦΙΠΟΛΗΣ     10  2025  24.0822  40.9598    0.000004
# 4414  EL526-4414  ΑΜΦΙΠΟΛΗΣ     10  2025  24.0822  40.9777    0.000871
# 4415  EL526-4415  ΑΜΦΙΠΟΛΗΣ     10  2025  24.0822  40.9957    0.015303
#
# [4416 rows x 7 columns]

# %%
df.risk_score.min()
# Out:
# 0.0

# %%
df.risk_score.max()
# Out:
# 0.326163

# %%
all = len(df)
all
# Out:
# 4416

# %%
count_low = df['risk_score'].between(0, 0.2).sum()
print(count_low)
print(count_low / all *100 )
# Out:
# 4401
# 99.66032608695652

# %%
count_low_med = df['risk_score'].between(0.2, 0.4).sum()
print(count_low_med)
print(count_low_med / all *100 )
# Out:
# 15
# 0.33967391304347827

# %%
count_med = df['risk_score'].between(0.4, 0.6).sum()
print(count_med)
print(count_med / all *100 )
# Out:
# 0
# 0.0

# %%
count_high_med = df['risk_score'].between(0.6, 0.8).sum()
print(count_high_med)
print(count_high_med / all *100 )
# Out:
# 0
# 0.0

# %%
count_high = df['risk_score'].between(0.8, 1).sum()
print(count_high)
print(count_high / all *100 )
# Out:
# 0
# 0.0

# %%
count_low + count_low_med + count_med + count_high_med + count_high == len(df)
# Out:
# True

# %%
count_low + count_low_med + count_med + count_high_med + count_high
# Out:
# 4416

# %%
len(df)
# Out:
# 4416
