# %%
import pandas as pd

# %%
df = pd.read_csv('GR_CMacedonia_Predictions_Jun_2025.csv')

# %%
df
# Out:
#          cell_id       lau1  month  year        x        y  risk_score
# 0     EL524-0000    ΕΔΕΣΣΑΣ      6  2025  21.7633  40.7981    0.000104
# 1     EL524-0001    ΕΔΕΣΣΑΣ      6  2025  21.7633  40.8160    0.000037
# 2     EL524-0002    ΕΔΕΣΣΑΣ      6  2025  21.7633  40.8340    0.000096
# 3     EL524-0003    ΕΔΕΣΣΑΣ      6  2025  21.7633  40.8520    0.000114
# 4     EL524-0004    ΕΔΕΣΣΑΣ      6  2025  21.7868  40.7981    0.000793
# ...          ...        ...    ...   ...      ...      ...         ...
# 4411  EL526-4411  ΑΜΦΙΠΟΛΗΣ      6  2025  24.0588  40.9957    0.000519
# 4412  EL526-4412  ΑΜΦΙΠΟΛΗΣ      6  2025  24.0588  41.0137    0.032527
# 4413  EL526-4413  ΑΜΦΙΠΟΛΗΣ      6  2025  24.0822  40.9598    0.000002
# 4414  EL526-4414  ΑΜΦΙΠΟΛΗΣ      6  2025  24.0822  40.9777    0.000022
# 4415  EL526-4415  ΑΜΦΙΠΟΛΗΣ      6  2025  24.0822  40.9957    0.000208
#
# [4416 rows x 7 columns]

# %%
df.risk_score.min()
# Out:
# 0.0

# %%
df.risk_score.max()
# Out:
# 0.664762

# %%
all = len(df)
all
# Out:
# 4416

# %%
count_low = df['risk_score'].between(0, 0.2).sum()
print(count_low)
print(count_low / all *100 )
# Out:
# 4330
# 98.05253623188406

# %%
count_low_med = df['risk_score'].between(0.2, 0.4).sum()
print(count_low_med)
print(count_low_med / all *100 )
# Out:
# 70
# 1.585144927536232

# %%
count_med = df['risk_score'].between(0.4, 0.6).sum()
print(count_med)
print(count_med / all *100 )
# Out:
# 15
# 0.33967391304347827

# %%
count_high_med = df['risk_score'].between(0.6, 0.8).sum()
print(count_high_med)
print(count_high_med / all *100 )
# Out:
# 1
# 0.022644927536231884

# %%
count_high = df['risk_score'].between(0.8, 0.1).sum()
print(count_high)
print(count_high / all *100 )
# Out:
# 0
# 0.0

# %%
count_low + count_low_med + count_med + count_high_med + count_high == len(df)
# Out:
# True
