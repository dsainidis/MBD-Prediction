# %%
import pandas as pd

# %%
df = pd.read_csv('GR_CMacedonia_Predictions_Jul_2025.csv')

# %%
df
# Out:
#          cell_id       lau1  month  year        x        y  risk_score
# 0     EL524-0000    ΕΔΕΣΣΑΣ      7  2025  21.7633  40.7981    0.001177
# 1     EL524-0001    ΕΔΕΣΣΑΣ      7  2025  21.7633  40.8160    0.000589
# 2     EL524-0002    ΕΔΕΣΣΑΣ      7  2025  21.7633  40.8340    0.000664
# 3     EL524-0003    ΕΔΕΣΣΑΣ      7  2025  21.7633  40.8520    0.000081
# 4     EL524-0004    ΕΔΕΣΣΑΣ      7  2025  21.7868  40.7981    0.011538
# ...          ...        ...    ...   ...      ...      ...         ...
# 4411  EL526-4411  ΑΜΦΙΠΟΛΗΣ      7  2025  24.0588  40.9957    0.294229
# 4412  EL526-4412  ΑΜΦΙΠΟΛΗΣ      7  2025  24.0588  41.0137    0.807647
# 4413  EL526-4413  ΑΜΦΙΠΟΛΗΣ      7  2025  24.0822  40.9598    0.000025
# 4414  EL526-4414  ΑΜΦΙΠΟΛΗΣ      7  2025  24.0822  40.9777    0.001550
# 4415  EL526-4415  ΑΜΦΙΠΟΛΗΣ      7  2025  24.0822  40.9957    0.504060
#
# [4416 rows x 7 columns]

# %%
df.risk_score.min()
# Out:
# 1e-06

# %%
df.risk_score.max()
# Out:
# 0.949224

# %%
all = len(df)
all
# Out:
# 4416

# %%
count_low = df['risk_score'].between(0, 0.2).sum()
print(count_low)
print(count_low / all *100 )
# Out:
# 2620
# 59.32971014492754

# %%
count_low_med = df['risk_score'].between(0.2, 0.4).sum()
print(count_low_med)
print(count_low_med / all *100 )
# Out:
# 602
# 13.632246376811594

# %%
count_med = df['risk_score'].between(0.4, 0.6).sum()
print(count_med)
print(count_med / all *100 )
# Out:
# 646
# 14.628623188405799

# %%
count_high_med = df['risk_score'].between(0.6, 0.8).sum()
print(count_high_med)
print(count_high_med / all *100 )
# Out:
# 471
# 10.665760869565217

# %%
count_high = df['risk_score'].between(0.8, 1).sum()
print(count_high)
print(count_high / all *100 )
# Out:
# 77
# 1.7436594202898552

# %%
count_low + count_low_med + count_med + count_high_med + count_high == len(df)
# Out:
# True

# %%
count_low + count_low_med + count_med + count_high_med + count_high
# Out:
# 4416

# %%
len(df)
# Out:
# 4416
