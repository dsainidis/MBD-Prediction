# %%
import pandas as pd

# %%
df = pd.read_csv('GR_Attica_Predictions_Aug_2025.csv')

# %%
df
# Out:
#         cell_id         lau1  month  year        x        y  risk_score
# 0    EL307-0000      ΚΥΘΗΡΩΝ      8  2025  22.9254  36.2292    0.161000
# 1    EL307-0001      ΚΥΘΗΡΩΝ      8  2025  22.9254  36.3191    0.022488
# 2    EL307-0002      ΚΥΘΗΡΩΝ      8  2025  22.9254  36.3370    0.254400
# 3    EL307-0003      ΚΥΘΗΡΩΝ      8  2025  22.9475  36.1933    0.184461
# 4    EL307-0004      ΚΥΘΗΡΩΝ      8  2025  22.9475  36.2113    0.131143
# ..          ...          ...    ...   ...      ...      ...         ...
# 732  EL305-0732    ΜΑΡΑΘΩΝΟΣ      8  2025  24.0333  38.1876    0.356962
# 733  EL305-0733    ΜΑΡΑΘΩΝΟΣ      8  2025  24.0333  38.2056    0.451907
# 734  EL305-0734  ΛΑΥΡΕΩΤΙΚΗΣ      8  2025  24.0555  37.7564    0.676764
# 735  EL305-0735  ΛΑΥΡΕΩΤΙΚΗΣ      8  2025  24.0555  37.7744    0.259044
# 736  EL305-0736  ΛΑΥΡΕΩΤΙΚΗΣ      8  2025  24.0555  37.7923    0.629915
#
# [737 rows x 7 columns]

# %%
df.risk_score.min()
# Out:
# 0.000652

# %%
df.risk_score.max()
# Out:
# 0.877981

# %%
all = len(df)
all
# Out:
# 737

# %%
count_low = df['risk_score'].between(0, 0.2).sum()
print(count_low)
print(count_low / all *100 )
# Out:
# 358
# 48.575305291723204

# %%
count_low_med = df['risk_score'].between(0.2, 0.4).sum()
print(count_low_med)
print(count_low_med / all *100 )
# Out:
# 173
# 23.473541383989144

# %%
count_med = df['risk_score'].between(0.4, 0.6).sum()
print(count_med)
print(count_med / all *100 )
# Out:
# 142
# 19.26729986431479

# %%
count_high_med = df['risk_score'].between(0.6, 0.8).sum()
print(count_high_med)
print(count_high_med / all *100 )
# Out:
# 60
# 8.14111261872456

# %%
count_high = df['risk_score'].between(0.8, 1).sum()
print(count_high)
print(count_high / all *100 )
# Out:
# 4
# 0.5427408412483039

# %%
count_low + count_low_med + count_med + count_high_med + count_high == len(df)
# Out:
# True
