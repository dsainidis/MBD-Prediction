# %%
import pandas as pd

# %%
df = pd.read_csv('GR_Attica_Predictions_Jun_2025.csv')

# %%
df
# Out:
#         cell_id         lau1  month  year        x        y  risk_score
# 0    EL307-0000      ΚΥΘΗΡΩΝ      6  2025  22.9254  36.2292    0.000669
# 1    EL307-0001      ΚΥΘΗΡΩΝ      6  2025  22.9254  36.3191    0.000254
# 2    EL307-0002      ΚΥΘΗΡΩΝ      6  2025  22.9254  36.3370    0.000480
# 3    EL307-0003      ΚΥΘΗΡΩΝ      6  2025  22.9475  36.1933    0.000229
# 4    EL307-0004      ΚΥΘΗΡΩΝ      6  2025  22.9475  36.2113    0.000323
# ..          ...          ...    ...   ...      ...      ...         ...
# 732  EL305-0732    ΜΑΡΑΘΩΝΟΣ      6  2025  24.0333  38.1876    0.002099
# 733  EL305-0733    ΜΑΡΑΘΩΝΟΣ      6  2025  24.0333  38.2056    0.004322
# 734  EL305-0734  ΛΑΥΡΕΩΤΙΚΗΣ      6  2025  24.0555  37.7564    0.028615
# 735  EL305-0735  ΛΑΥΡΕΩΤΙΚΗΣ      6  2025  24.0555  37.7744    0.032335
# 736  EL305-0736  ΛΑΥΡΕΩΤΙΚΗΣ      6  2025  24.0555  37.7923    0.028672
#
# [737 rows x 7 columns]

# %%
df.risk_score.min()
# Out:
# 8e-06

# %%
df.risk_score.max()
# Out:
# 0.430687

# %%
count_low = df['risk_score'].between(0, 0.2).sum()
count_low
# Out:
# 724

# %%
count_low_med = df['risk_score'].between(0.2, 0.4).sum()
count_low_med
# Out:
# 12

# %%
count_med = df['risk_score'].between(0.4, 0.6).sum()
count_med
# Out:
# 1

# %%
count_high_med = df['risk_score'].between(0.6, 0.8).sum()
count_high_med
# Out:
# 0

# %%
count_high = df['risk_score'].between(0.8, 0.1).sum()
count_high
# Out:
# 0

# %%
count_low + count_low_med + count_med + count_high_med + count_high == len(df)
# Out:
# True
