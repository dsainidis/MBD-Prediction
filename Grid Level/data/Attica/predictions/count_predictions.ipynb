# %%
import pandas as pd

# %%
df = pd.read_csv('GR_Attica_Predictions_Jul_2025.csv')

# %%
df
# Out:
#         cell_id         lau1  month  year        x        y  risk_score
# 0    EL307-0000      ΚΥΘΗΡΩΝ      7  2025  22.9254  36.2292    0.101841
# 1    EL307-0001      ΚΥΘΗΡΩΝ      7  2025  22.9254  36.3191    0.020806
# 2    EL307-0002      ΚΥΘΗΡΩΝ      7  2025  22.9254  36.3370    0.063767
# 3    EL307-0003      ΚΥΘΗΡΩΝ      7  2025  22.9475  36.1933    0.033038
# 4    EL307-0004      ΚΥΘΗΡΩΝ      7  2025  22.9475  36.2113    0.132760
# ..          ...          ...    ...   ...      ...      ...         ...
# 732  EL305-0732    ΜΑΡΑΘΩΝΟΣ      7  2025  24.0333  38.1876    0.348593
# 733  EL305-0733    ΜΑΡΑΘΩΝΟΣ      7  2025  24.0333  38.2056    0.447002
# 734  EL305-0734  ΛΑΥΡΕΩΤΙΚΗΣ      7  2025  24.0555  37.7564    0.696394
# 735  EL305-0735  ΛΑΥΡΕΩΤΙΚΗΣ      7  2025  24.0555  37.7744    0.565131
# 736  EL305-0736  ΛΑΥΡΕΩΤΙΚΗΣ      7  2025  24.0555  37.7923    0.462571
#
# [737 rows x 7 columns]

# %%
df.risk_score.min()
# Out:
# 0.000183

# %%
df.risk_score.max()
# Out:
# 0.902412

# %%
all = len(df)
all
# Out:
# 737

# %%
count_low = df['risk_score'].between(0, 0.2).sum()
print(count_low)
print(count_low / all *100 )
# Out:
# 336
# 45.59023066485753

# %%
count_low_med = df['risk_score'].between(0.2, 0.4).sum()
print(count_low_med)
print(count_low_med / all *100 )
# Out:
# 152
# 20.62415196743555

# %%
count_med = df['risk_score'].between(0.4, 0.6).sum()
print(count_med)
print(count_med / all *100 )
# Out:
# 128
# 17.367706919945725

# %%
count_high_med = df['risk_score'].between(0.6, 0.8).sum()
print(count_high_med)
print(count_high_med / all *100 )
# Out:
# 110
# 14.925373134328357

# %%
count_high = df['risk_score'].between(0.8, 1).sum()
print(count_high)
print(count_high / all *100 )
# Out:
# 11
# 1.4925373134328357

# %%
count_low + count_low_med + count_med + count_high_med + count_high == len(df)
# Out:
# True
