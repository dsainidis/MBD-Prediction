# %%
import pandas as pd

# %%
df = pd.read_csv('GR_Thessaly_Predictions_Aug_2025.csv')

# %%
df
# Out:
#          cell_id        lau1  month  year        x        y  risk_score
# 0     EL611-0000  ΚΑΛΑΜΠΑΚΑΣ      8  2025  21.1555  39.6794    0.002297
# 1     EL611-0001  ΚΑΛΑΜΠΑΚΑΣ      8  2025  21.1786  39.6255    0.001440
# 2     EL611-0002  ΚΑΛΑΜΠΑΚΑΣ      8  2025  21.1786  39.6435    0.014915
# 3     EL611-0003  ΚΑΛΑΜΠΑΚΑΣ      8  2025  21.1786  39.6615    0.002054
# 4     EL611-0004  ΚΑΛΑΜΠΑΚΑΣ      8  2025  21.1786  39.6794    0.019022
# ...          ...         ...    ...   ...      ...      ...         ...
# 3233  EL613-3233    ΣΚΟΠΕΛΟΥ      8  2025  23.7437  39.1045    0.017822
# 3234  EL613-3234   ΑΛΟΝΝΗΣΟΥ      8  2025  23.9054  39.1943    0.076700
# 3235  EL613-3235   ΑΛΟΝΝΗΣΟΥ      8  2025  23.9054  39.2123    0.026933
# 3236  EL613-3236   ΑΛΟΝΝΗΣΟΥ      8  2025  23.9286  39.2303    0.007720
# 3237  EL613-3237   ΑΛΟΝΝΗΣΟΥ      8  2025  24.0672  39.3381    0.435538
#
# [3238 rows x 7 columns]

# %%
df.risk_score.min()
# Out:
# 1e-05

# %%
df.risk_score.max()
# Out:
# 0.929859

# %%
all = len(df)
all
# Out:
# 3238

# %%
count_low = df['risk_score'].between(0, 0.2).sum()
print(count_low)
print(count_low / all *100 )
# Out:
# 1870
# 57.75169857936998

# %%
count_low_med = df['risk_score'].between(0.2, 0.4).sum()
print(count_low_med)
print(count_low_med / all *100 )
# Out:
# 418
# 12.909203211859172

# %%
count_med = df['risk_score'].between(0.4, 0.6).sum()
print(count_med)
print(count_med / all *100 )
# Out:
# 419
# 12.940086473131561

# %%
count_high_med = df['risk_score'].between(0.6, 0.8).sum()
print(count_high_med)
print(count_high_med / all *100 )
# Out:
# 423
# 13.063619518221122

# %%
count_high = df['risk_score'].between(0.8, 1).sum()
print(count_high)
print(count_high / all *100 )
# Out:
# 108
# 3.3353922174181596

# %%
count_low + count_low_med + count_med + count_high_med + count_high == len(df)
# Out:
# True
