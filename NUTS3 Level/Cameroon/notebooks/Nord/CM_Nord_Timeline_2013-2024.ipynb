# %%
import pandas as pd
from datetime import date, timedelta

import random
import geopandas as gpd
import numpy as np

import sys

sys.path.insert(0, "../../utils")

from plots import *
from string_handling import *

enc = 'utf-8' 

random.seed(0)
np.random.seed(0)

pd.set_option('display.max_columns', None)

# %%
cm_nord_grid = pd.read_csv('../../data/Nord/CM_Nord_Grid.csv', encoding=enc)
cm_nord_grid.head()
# Out:
#           x        y  GID0  GID1  GID2      GID3
# 0  12.29306  8.21972  nord  faro  poli  balkossa
# 1  12.29306  8.25566  nord  faro  poli  balkossa
# 2  12.29306  8.29159  nord  faro  poli  balkossa
# 3  12.29306  8.32752  nord  faro  poli  balkossa
# 4  12.29306  8.36346  nord  faro  poli  balkossa

# %%
start = start_dt = date(2013, 1, 1)
end = end_dt = date(2024, 12, 31)
delta = timedelta(days=1)

# %%
dates = []

while start_dt <= end_dt:
    dates.append(start_dt.isoformat())
    start_dt += delta

# %%
print('Dates between', start, 'and', end)
print(dates)
# Out:
# Dates between 2013-01-01 and 2013-12-31
# ['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04', '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08', '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-12', '2013-01-13', '2013-01-14', '2013-01-15', '2013-01-16', '2013-01-17', '2013-01-18', '2013-01-19', '2013-01-20', '2013-01-21', '2013-01-22', '2013-01-23', '2013-01-24', '2013-01-25', '2013-01-26', '2013-01-27', '2013-01-28', '2013-01-29', '2013-01-30', '2013-01-31', '2013-02-01', '2013-02-02', '2013-02-03', '2013-02-04', '2013-02-05', '2013-02-06', '2013-02-07', '2013-02-08', '2013-02-09', '2013-02-10', '2013-02-11', '2013-02-12', '2013-02-13', '2013-02-14', '2013-02-15', '2013-02-16', '2013-02-17', '2013-02-18', '2013-02-19', '2013-02-20', '2013-02-21', '2013-02-22', '2013-02-23', '2013-02-24', '2013-02-25', '2013-02-26', '2013-02-27', '2013-02-28', '2013-03-01', '2013-03-02', '2013-03-03', '2013-03-04', '2013-03-05', '2013-03-06', '2013-03-07', '2013-03-08', '2013-03-09', '2013-03-10', '2013-03-11', '2013-03-12', '2013-03-13', '2013-03-14', '2013-03-15', '2013-03-16', '2013-03-17', '2013-03-18', '2013-03-19', '2013-03-20', '2013-03-21', '2013-03-22', '2013-03-23', '2013-03-24', '2013-03-25', '2013-03-26', '2013-03-27', '2013-03-28', '2013-03-29', '2013-03-30', '2013-03-31', '2013-04-01', '2013-04-02', '2013-04-03', '2013-04-04', '2013-04-05', '2013-04-06', '2013-04-07', '2013-04-08', '2013-04-09', '2013-04-10', '2013-04-11', '2013-04-12', '2013-04-13', '2013-04
# %%
len(dates)
# Out:
# 365

# %%
print(f'Total Rows: {len(dates) * len(cm_nord_grid)}')
# Out:
# Total Rows: 1445035

# %%
cm_timeline = pd.DataFrame()

# %%
data = []
for index, row in cm_nord_grid.iterrows():
    for date in dates:
        data.append({'x': row['x'], 
                     'y': row['y'],
                     'GID0': row['GID0'], 
                     'GID1': row['GID1'],
                     'GID2': row['GID2'], 
                     'GID3': row['GID3'],  
                     'dt_placement': date})

# %%
cm_timeline = pd.DataFrame(data)

# %%
cm_timeline
# Out:
#                 x        y  GID0      GID1     GID2      GID3 dt_placement
# 0        12.29306  8.21972  nord      faro     poli  balkossa   2013-01-01
# 1        12.29306  8.21972  nord      faro     poli  balkossa   2013-01-02
# 2        12.29306  8.21972  nord      faro     poli  balkossa   2013-01-03
# 3        12.29306  8.21972  nord      faro     poli  balkossa   2013-01-04
# 4        12.29306  8.21972  nord      faro     poli  balkossa   2013-01-05
# ...           ...      ...   ...       ...      ...       ...          ...
# 1445030  15.55146  7.75259  nord  mayo-rey  touboro    mafare   2013-12-27
# 1445031  15.55146  7.75259  nord  mayo-rey  touboro    mafare   2013-12-28
# 1445032  15.55146  7.75259  nord  mayo-rey  touboro    mafare   2013-12-29
# 1445033  15.55146  7.75259  nord  mayo-rey  touboro    mafare   2013-12-30
# 1445034  15.55146  7.75259  nord  mayo-rey  touboro    mafare   2013-12-31
#
# [1445035 rows x 7 columns]

# %%
cm_timeline['dt_placement'] = pd.to_datetime(cm_timeline['dt_placement'])
cm_timeline['year'] = cm_timeline['dt_placement'].apply(lambda x: x.year)

# %%
cm_timeline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445035 entries, 0 to 1445034
# Data columns (total 8 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   x             1445035 non-null  float64
#  1   y             1445035 non-null  float64
#  2   GID0          1445035 non-null  object
#  3   GID1          1445035 non-null  object
#  4   GID2          1445035 non-null  object
#  5   GID3          1445035 non-null  object
#  6   dt_placement  1445035 non-null  datetime64[ns]
#  7   year          1445035 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 88.2+ MB

# %%
years = cm_timeline.year.unique().tolist()

# %%
for item in years:
    cm_towrite = cm_timeline[cm_timeline.year == item].drop(columns = ['year'])
    print(f'Year: {item}, Timeline Shape: {cm_towrite.shape}')
    cm_towrite.to_csv(f'../../data/Nord/CM_Nord_Timeline_{item}.csv', index = False)
# Out:
# Year: 2013, Timeline Shape: (1445035, 7)
