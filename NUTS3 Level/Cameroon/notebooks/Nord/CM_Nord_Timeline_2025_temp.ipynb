# %%
import pandas as pd
from datetime import date, timedelta

import random
import geopandas as gpd
import numpy as np

import sys

sys.path.insert(0, "../../utils")

from plots import *
from string_handling import *

enc = 'utf-8' 

random.seed(0)
np.random.seed(0)

pd.set_option('display.max_columns', None)

REGION = 'Nord'

# %%
cm_nord_grid = pd.read_csv(f'../../data/{REGION}/CM_{REGION}_Grid.csv', encoding=enc)
cm_nord_grid.head()
# Out:
#           x        y  GID0  GID1  GID2      GID3
# 0  12.29306  8.21972  nord  faro  poli  balkossa
# 1  12.29306  8.25566  nord  faro  poli  balkossa
# 2  12.29306  8.29159  nord  faro  poli  balkossa
# 3  12.29306  8.32752  nord  faro  poli  balkossa
# 4  12.29306  8.36346  nord  faro  poli  balkossa

# %%
start = start_dt = date(2025, 9, 1)
end = end_dt = date(2025, 10, 31)
delta = timedelta(days=1)

# %%
dates = []

while start_dt <= end_dt:
    dates.append(start_dt.isoformat())
    start_dt += delta

# %%
print('Dates between', start, 'and', end)
print(dates)
# Out:
# Dates between 2025-09-01 and 2025-10-31
# ['2025-09-01', '2025-09-02', '2025-09-03', '2025-09-04', '2025-09-05', '2025-09-06', '2025-09-07', '2025-09-08', '2025-09-09', '2025-09-10', '2025-09-11', '2025-09-12', '2025-09-13', '2025-09-14', '2025-09-15', '2025-09-16', '2025-09-17', '2025-09-18', '2025-09-19', '2025-09-20', '2025-09-21', '2025-09-22', '2025-09-23', '2025-09-24', '2025-09-25', '2025-09-26', '2025-09-27', '2025-09-28', '2025-09-29', '2025-09-30', '2025-10-01', '2025-10-02', '2025-10-03', '2025-10-04', '2025-10-05', '2025-10-06', '2025-10-07', '2025-10-08', '2025-10-09', '2025-10-10', '2025-10-11', '2025-10-12', '2025-10-13', '2025-10-14', '2025-10-15', '2025-10-16', '2025-10-17', '2025-10-18', '2025-10-19', '2025-10-20', '2025-10-21', '2025-10-22', '2025-10-23', '2025-10-24', '2025-10-25', '2025-10-26', '2025-10-27', '2025-10-28', '2025-10-29', '2025-10-30', '2025-10-31']

# %%
len(dates)
# Out:
# 61

# %%
print(f'Total Rows: {len(dates) * len(cm_nord_grid)}')
# Out:
# Total Rows: 241499

# %%
cm_timeline = pd.DataFrame()

# %%
data = []
for index, row in cm_nord_grid.iterrows():
    for date in dates:
        data.append({'x': row['x'], 
                     'y': row['y'],
                     'GID0': row['GID0'], 
                     'GID1': row['GID1'],
                     'GID2': row['GID2'], 
                     'GID3': row['GID3'],  
                     'dt_placement': date})

# %%
cm_timeline = pd.DataFrame(data)

# %%
cm_timeline
# Out:
#                x        y  GID0      GID1     GID2      GID3 dt_placement
# 0       12.29306  8.21972  nord      faro     poli  balkossa   2025-09-01
# 1       12.29306  8.21972  nord      faro     poli  balkossa   2025-09-02
# 2       12.29306  8.21972  nord      faro     poli  balkossa   2025-09-03
# 3       12.29306  8.21972  nord      faro     poli  balkossa   2025-09-04
# 4       12.29306  8.21972  nord      faro     poli  balkossa   2025-09-05
# ...          ...      ...   ...       ...      ...       ...          ...
# 241494  15.55146  7.75259  nord  mayo-rey  touboro    mafare   2025-10-27
# 241495  15.55146  7.75259  nord  mayo-rey  touboro    mafare   2025-10-28
# 241496  15.55146  7.75259  nord  mayo-rey  touboro    mafare   2025-10-29
# 241497  15.55146  7.75259  nord  mayo-rey  touboro    mafare   2025-10-30
# 241498  15.55146  7.75259  nord  mayo-rey  touboro    mafare   2025-10-31
#
# [241499 rows x 7 columns]

# %%
cm_timeline['dt_placement'] = pd.to_datetime(cm_timeline['dt_placement'])
cm_timeline['year'] = cm_timeline['dt_placement'].apply(lambda x: x.year)

# %%
cm_timeline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241499 entries, 0 to 241498
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   x             241499 non-null  float64
#  1   y             241499 non-null  float64
#  2   GID0          241499 non-null  object
#  3   GID1          241499 non-null  object
#  4   GID2          241499 non-null  object
#  5   GID3          241499 non-null  object
#  6   dt_placement  241499 non-null  datetime64[ns]
#  7   year          241499 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 14.7+ MB

# %%
years = cm_timeline.year.unique().tolist()

# %%
years
# Out:
# [2025]

# %%
## change the month here

for item in years:
    cm_towrite = cm_timeline[cm_timeline.year == item].drop(columns = ['year'])
    print(f'Year: {item}, Timeline Shape: {cm_towrite.shape}')
    cm_towrite.to_csv(f'../../data/{REGION}/CM_{REGION}_Timeline_{item}_10.csv', index = False)
# Out:
# Year: 2025, Timeline Shape: (241499, 7)
