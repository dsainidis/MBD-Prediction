# %%
import pandas as pd
import sys

sys.path.insert(0, "../utils")
enc = 'utf-8' 

pd.set_option('display.max_columns', None)

# %%
cases_df = pd.read_csv('../data/CM_MAL_cases_GID2_2015-2024_fixed.csv', encoding=enc)
polygon_ids = pd.read_csv('../data/CM_WEB_Polygons_processed.csv', encoding=enc)

# %%
cases_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
cases_df['location'] = list(zip(cases_df['GID0'], cases_df['GID2'], cases_df['GID3']))

# %%
polygon_ids['location'] = polygon_ids['location'].astype(str)
cases_df['location'] = cases_df['location'].astype(str)

# %%
referenced_cases = pd.merge(cases_df, polygon_ids, on=['location'], how='left')

# %%
referenced_cases.drop(columns=['GID0', 'GID2', 'GID3', 'location', 
                               'Death_UND5', 'Death_OVR5', 'Death_PRGN', 'Death_TOTAL',
                               'Hosp_UND5', 'Hosp_OVR5', 'Hosp_PRGN', 
                               'Sevr_UND5', 'Sevr_OVR5', 'Sevr_PRGN'], inplace = True)

# %%
referenced_cases = referenced_cases[['id', 'dt_placement', 'Case_UND5', 'Case_OVR5', 'Case_PRGN', 'Case_TOTAL', 'Sevr_TOTAL', 'Hosp_TOTAL']].copy()

# %%
referenced_cases.rename(columns={'id': 'polygon_id'}, inplace = True)

# %%
referenced_cases.reset_index(drop=True, inplace=True)

# %%
referenced_cases
# Out:
#        polygon_id dt_placement  Case_UND5  Case_OVR5  Case_PRGN  Case_TOTAL  \
# 0             372      2015-01         49         43          2          94
# 1             310      2015-01          2          5          0           7
# 2             311      2015-01         25         63          3          91
# 3             313      2015-01         16         14          1          31
# 4             312      2015-01         67         38          4         109
# ...           ...          ...        ...        ...        ...         ...
# 50891         127      2024-12         34         25          0          59
# 50892          59      2024-12         51         46         29         126
# 50893          57      2024-12        247        330         79         656
# 50894          62      2024-12        138        197         68         403
# 50895          58      2024-12         46         44         12         102
#
#        Sevr_TOTAL  Hosp_TOTAL
# 0              17          17
# 1               0           0
# 2              83           1
# 3               8           8
# 4              41           3
# ...           ...         ...
# 50891          30          30
# 50892          70          70
# 50893         317         317
# 50894         156         156
# 50895          73          73
#
# [50896 rows x 8 columns]

# %%
referenced_cases.to_csv('../data/CM_MAL_cases_GID2_2015-2024_fixed_georeferenced.csv', encoding=enc, index=False)
