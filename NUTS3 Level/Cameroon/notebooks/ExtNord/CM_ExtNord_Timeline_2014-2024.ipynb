# %%
import pandas as pd
from datetime import date, timedelta

import random
import geopandas as gpd
import numpy as np

import sys

sys.path.insert(0, "../utils")

from plots import *
from string_handling import *

enc = 'utf-8' 

random.seed(0)
np.random.seed(0)

pd.set_option('display.max_columns', None)

# %%
cm_extnord_grid = pd.read_csv('../data/CM_ExtNord_Grid.csv', encoding=enc)
cm_extnord_grid.head()
# Out:
#           x         y          GID0          GID1    GID2      GID3
# 0  13.43483  10.10446  extreme nord  mayo-tsanaga  bourha  maboudji
# 1  13.45125  10.14959  extreme nord  mayo-tsanaga  bourha  boukoula
# 2  13.45125  10.16755  extreme nord  mayo-tsanaga  bourha  boukoula
# 3  13.46950  10.13162  extreme nord  mayo-tsanaga  bourha  boukoula
# 4  13.46950  10.14959  extreme nord  mayo-tsanaga  bourha  boukoula

# %%
start = start_dt = date(2014, 1, 1)
end = end_dt = date(2024, 12, 31)
delta = timedelta(days=1)

# %%
dates = []

while start_dt <= end_dt:
    dates.append(start_dt.isoformat())
    start_dt += delta

# %%
print('Dates between', start, 'and', end)
print(dates)
# Out:
# Dates between 2014-01-01 and 2024-12-31
# ['2014-01-01', '2014-01-02', '2014-01-03', '2014-01-04', '2014-01-05', '2014-01-06', '2014-01-07', '2014-01-08', '2014-01-09', '2014-01-10', '2014-01-11', '2014-01-12', '2014-01-13', '2014-01-14', '2014-01-15', '2014-01-16', '2014-01-17', '2014-01-18', '2014-01-19', '2014-01-20', '2014-01-21', '2014-01-22', '2014-01-23', '2014-01-24', '2014-01-25', '2014-01-26', '2014-01-27', '2014-01-28', '2014-01-29', '2014-01-30', '2014-01-31', '2014-02-01', '2014-02-02', '2014-02-03', '2014-02-04', '2014-02-05', '2014-02-06', '2014-02-07', '2014-02-08', '2014-02-09', '2014-02-10', '2014-02-11', '2014-02-12', '2014-02-13', '2014-02-14', '2014-02-15', '2014-02-16', '2014-02-17', '2014-02-18', '2014-02-19', '2014-02-20', '2014-02-21', '2014-02-22', '2014-02-23', '2014-02-24', '2014-02-25', '2014-02-26', '2014-02-27', '2014-02-28', '2014-03-01', '2014-03-02', '2014-03-03', '2014-03-04', '2014-03-05', '2014-03-06', '2014-03-07', '2014-03-08', '2014-03-09', '2014-03-10', '2014-03-11', '2014-03-12', '2014-03-13', '2014-03-14', '2014-03-15', '2014-03-16', '2014-03-17', '2014-03-18', '2014-03-19', '2014-03-20', '2014-03-21', '2014-03-22', '2014-03-23', '2014-03-24', '2014-03-25', '2014-03-26', '2014-03-27', '2014-03-28', '2014-03-29', '2014-03-30', '2014-03-31', '2014-04-01', '2014-04-02', '2014-04-03', '2014-04-04', '2014-04-05', '2014-04-06', '2014-04-07', '2014-04-08', '2014-04-09', '2014-04-10', '2014-04-11', '2014-04-12', '2014-04-13', '2014-04-14', '2014-04-15', '2014-04-16', '2014-04-17', '2014-04-18', '2014-04-19', '2014-04-20',
print(f'Total Rows: {len(dates) * len(cm_extnord_grid)}')
# Out:
# Total Rows: 8321278

# %%
cm_timeline = pd.DataFrame()

# %%
data = []
for index, row in cm_extnord_grid.iterrows():
    for date in dates:
        data.append({'x': row['x'], 
                     'y': row['y'],
                     'GID0': row['GID0'], 
                     'GID1': row['GID1'],
                     'GID2': row['GID2'], 
                     'GID3': row['GID3'],  
                     'dt_placement': date})

# %%
cm_timeline = pd.DataFrame(data)

# %%
cm_timeline
# Out:
#                 x         y          GID0          GID1    GID2       GID3  \
# 0        13.43483  10.10446  extreme nord  mayo-tsanaga  bourha   maboudji
# 1        13.43483  10.10446  extreme nord  mayo-tsanaga  bourha   maboudji
# 2        13.43483  10.10446  extreme nord  mayo-tsanaga  bourha   maboudji
# 3        13.43483  10.10446  extreme nord  mayo-tsanaga  bourha   maboudji
# 4        13.43483  10.10446  extreme nord  mayo-tsanaga  bourha   maboudji
# ...           ...       ...           ...           ...     ...        ...
# 8321273  15.57371  10.02477  extreme nord    mayo-danay   guere  nouldaina
# 8321274  15.57371  10.02477  extreme nord    mayo-danay   guere  nouldaina
# 8321275  15.57371  10.02477  extreme nord    mayo-danay   guere  nouldaina
# 8321276  15.57371  10.02477  extreme nord    mayo-danay   guere  nouldaina
# 8321277  15.57371  10.02477  extreme nord    mayo-danay   guere  nouldaina
#
#         dt_placement
# 0         2014-01-01
# 1         2014-01-02
# 2         2014-01-03
# 3         2014-01-04
# 4         2014-01-05
# ...              ...
# 8321273   2024-12-27
# 8321274   2024-12-28
# 8321275   2024-12-29
# 8321276   2024-12-30
# 8321277   2024-12-31
#
# [8321278 rows x 7 columns]

# %%
cm_timeline['dt_placement'] = pd.to_datetime(cm_timeline['dt_placement'])
cm_timeline['year'] = cm_timeline['dt_placement'].apply(lambda x: x.year)

# %%
cm_timeline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8321278 entries, 0 to 8321277
# Data columns (total 8 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   x             float64
#  1   y             float64
#  2   GID0          object
#  3   GID1          object
#  4   GID2          object
#  5   GID3          object
#  6   dt_placement  datetime64[ns]
#  7   year          int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 507.9+ MB

# %%
years = cm_timeline.year.unique().tolist()

# %%
for item in years:
    cm_towrite = cm_timeline[cm_timeline.year == item].drop(columns = ['year'])
    print(f'Year: {item}, Timeline Shape: {cm_towrite.shape}')
    cm_towrite.to_csv(f'../data/CM_ExtNord_Timeline_{item}.csv', index = False)
# Out:
# Year: 2014, Timeline Shape: (755915, 7)
# Year: 2015, Timeline Shape: (755915, 7)
# Year: 2016, Timeline Shape: (757986, 7)
# Year: 2017, Timeline Shape: (755915, 7)
# Year: 2018, Timeline Shape: (755915, 7)
# Year: 2019, Timeline Shape: (755915, 7)
# Year: 2020, Timeline Shape: (757986, 7)
# Year: 2021, Timeline Shape: (755915, 7)
# Year: 2022, Timeline Shape: (755915, 7)
# Year: 2023, Timeline Shape: (755915, 7)
# Year: 2024, Timeline Shape: (757986, 7)
