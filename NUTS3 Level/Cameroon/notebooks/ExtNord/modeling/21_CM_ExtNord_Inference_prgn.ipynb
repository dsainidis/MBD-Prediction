# %%
import pandas as pd
from sklearn.model_selection import StratifiedKFold
import numpy as np
import geopandas as gpd
import sys
import pickle
import json

sys.path.insert(0, "../../../utils")

from modules import *

import xgboost as xgb
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.impute import KNNImputer
from Model_Validation_Module import *

enc = 'utf-8'

REGION = 'ExtNord'

ΤARGET = "_prgn"  # "_und5", "_ovr5", "_prgn", "_severe", "_hospitalization" or ""

# %%
target_variable = {"": "Total Malaria Cases",
                   "_und5": "Malaria Cases Under 5 Years",
                   "_ovr5": "Malaria Cases Over 5 Years",
                   "_prgn": "Malaria Cases in Pregnant Women",
                   "_severe": "Total Severe Malaria Cases",
                   "_hospitalization": "Total Malaria Hospitalizations"}

# %%
dataframe = pd.read_csv(f'../../../data/{REGION}/CM_{REGION}_Test_Dataset_2015-2025.csv', encoding=enc)

# %%
dataframe
# Out:
#                GID0          GID1  GID2       GID3          x          y  \
# 0      extreme nord       diamare  bogo     balaza  14.515776  10.786560
# 1      extreme nord       diamare  bogo      balda  14.724237  10.914551
# 2      extreme nord       diamare  bogo       bogo  14.597860  10.743440
# 3      extreme nord       diamare  bogo      borai  14.606980  10.653607
# 4      extreme nord       diamare  bogo  guinggley  14.702740  10.792848
# ...             ...           ...   ...        ...        ...        ...
# 41839  extreme nord  mayo-tsanaga  roua      midre  13.871290  10.791350
# 41840  extreme nord  mayo-tsanaga  roua    ndimche  13.968570  10.827287
# 41841  extreme nord  mayo-tsanaga  roua       roua  13.968570  10.779370
# 41842  extreme nord  mayo-tsanaga  roua    soulede  13.917498  10.736254
# 41843  extreme nord  mayo-tsanaga  roua      zogom  14.005050  10.743440
#
#       dt_prediction  year  month  month_sin  ...  bio10  bio11  bio12  bio13  \
# 0           2015-01  2015      1        0.5  ...  34.33  28.83   1345    483
# 1           2015-01  2015      1        0.5  ...  35.00  29.33   1228    422
# 2           2015-01  2015      1        0.5  ...  34.17  27.33   1324    475
# 3           2015-01  2015      1        0.5  ...  33.83  27.00   1301    476
# 4           2015-01  2015      1        0.5  ...  34.17  28.17   1268    440
# ...             ...   ...    ...        ...  ...    ...    ...    ...    ...
# 41839       2025-12  2025     12        0.0  ...  31.50  25.33   1941    597
# 41840       2025-12  2025     12        0.0  ...  31.83  25.50   1894    590
# 41841       2025-12  2025     12        0.0  ...  33.00  25.83   1968    607
# 41842       2025-12  2025     12        0.0  ...  32.67  25.00   1969    604
# 41843       2025-12  2025     12        0.0  ...  33.67  26.50   1934    569
#
#        bio14   bio15  bio16  bio17  bio18  bio19
# 0          0  143.14   1072      0     85    911
# 1          0  140.46    982      0     91    784
# 2          0  144.61   1070      0     74    701
# 3          0  144.58   1048      0     63    693
# 4          0  142.37   1023      0    180   1023
# ...      ...     ...    ...    ...    ...    ...
# 41839      0  135.39   1464      1     61    158
# 41840      0  136.08   1434      1     56      1
# 41841      0  135.57   1507      1     58      1
# 41842      0  135.14   1498      2     60      2
# 41843      0  133.34   1454      0     71    978
#
# [41844 rows x 76 columns]

# %%
dataframe.sort_values(["dt_prediction", "GID0", "GID1", "GID2", "GID3"], inplace=True)

dataframe['location_full'] = list(zip(dataframe['GID0'], dataframe['GID1'], dataframe['GID2'], dataframe['GID3']))
dataframe['location'] = list(zip(dataframe['GID0'], dataframe['GID2'], dataframe['GID3']))
dataframe.drop(columns=['GID0', 'GID1', 'GID2', 'GID3', 'year', 'month', 'dt_weather_acc', 'year_biovars', 'year_lc'], inplace=True)
dataframe['dt_prediction'] = pd.to_datetime(dataframe['dt_prediction']).dt.to_period('M')

dataframe = dataframe[['location', 'location_full'] + dataframe.columns.to_list()[:-2]]

# %%
rainfall_cols = [col for col in dataframe.columns if 'rainfall' in col]
lst_cols = [col for col in dataframe.columns if 'lst' in col]
bio_cols = [col for col in dataframe.columns if 'bio' in col]
geo_cols = ['distance_to_coast', 'distance_to_river', 'slope_mean_1km', 'aspect_mean_200m', 'elevation_mean_1km', 'hillshade_mean_1km', 'fs_area_1km', 'flow_accu_200m']
geo_cols += [f"{col}_std" for col in geo_cols]

round_cols = [rainfall_cols, lst_cols, bio_cols, geo_cols]
round_factor = [4,2,2,2]

# %%
inference = dataframe[dataframe["dt_prediction"] > pd.Period("2024-09", freq="M")]
inference.reset_index(drop=True, inplace=True)

inference.head()
# Out:
#                           location                             location_full  \
# 0     (extreme nord, bogo, balaza)     (extreme nord, diamare, bogo, balaza)
# 1      (extreme nord, bogo, balda)      (extreme nord, diamare, bogo, balda)
# 2       (extreme nord, bogo, bogo)       (extreme nord, diamare, bogo, bogo)
# 3      (extreme nord, bogo, borai)      (extreme nord, diamare, bogo, borai)
# 4  (extreme nord, bogo, guinggley)  (extreme nord, diamare, bogo, guinggley)
#
#            x          y dt_prediction  month_sin  month_cos      ndvi  \
# 0  14.515776  10.786560       2024-10     -0.866        0.5  0.377319
# 1  14.724237  10.914551       2024-10     -0.866        0.5  0.354336
# 2  14.597860  10.743440       2024-10     -0.866        0.5  0.365004
# 3  14.606980  10.653607       2024-10     -0.866        0.5  0.364578
# 4  14.702740  10.792848       2024-10     -0.866        0.5  0.390559
#
#        ndmi      ndwi  ...  bio10  bio11  bio12  bio13  bio14   bio15  bio16  \
# 0 -0.022331 -0.351487  ...  36.00  28.00   1400    457      0  121.31    944
# 1 -0.084411 -0.340380  ...  36.33  27.67   1373    452      0  123.78    943
# 2 -0.053135 -0.358651  ...  34.83  28.33   1415    464      0  121.63    939
# 3  0.034294 -0.333879  ...  35.00  28.00   1475    464      0  117.63    962
# 4  0.010424 -0.367982  ...  35.33  28.00   1449    475      0  121.57    964
#
#    bio17  bio18  bio19
# 0      0    150    890
# 1      0    131    890
# 2      0    134    924
# 3      0    162    949
# 4      0    135    947
#
# [5 rows x 69 columns]

# %%
with open(f'saved/CM_{REGION}_bin_ranges{ΤARGET}.pkl', 'rb') as f:
    bin_ranges = pickle.load(f)

num_of_classes = len(bin_ranges) - 1
print(f'Number of classes: {num_of_classes}')
# Out:
# Number of classes: 7

# %%
with open(f"saved/CM_{REGION}_rfecv_model{ΤARGET}.pkl", "rb") as f:
    fitted_rfe = pickle.load(f)

with open(f"saved/CM_{REGION}_scaler{ΤARGET}.pkl", "rb") as f:
    fitted_scaler = pickle.load(f)

with open(f"saved/CM_{REGION}_imputer{ΤARGET}.pkl", "rb") as f:
    fitted_imputer = pickle.load(f)

with open(f"saved/CM_{REGION}_xgb_model{ΤARGET}.pkl", "rb") as f:
    fitted_model = pickle.load(f)

# %%
X_test = inference.select_dtypes(exclude=['object', 'period[M]'])
X_test.head()
# Out:
#            x          y  month_sin  month_cos      ndvi      ndmi      ndwi  \
# 0  14.515776  10.786560     -0.866        0.5  0.377319 -0.022331 -0.351487
# 1  14.724237  10.914551     -0.866        0.5  0.354336 -0.084411 -0.340380
# 2  14.597860  10.743440     -0.866        0.5  0.365004 -0.053135 -0.358651
# 3  14.606980  10.653607     -0.866        0.5  0.364578  0.034294 -0.333879
# 4  14.702740  10.792848     -0.866        0.5  0.390559  0.010424 -0.367982
#
#        ndbi  ndvi_mean  ndmi_mean  ...  bio10  bio11  bio12  bio13  bio14  \
# 0  0.022331   0.367593  -0.031104  ...  36.00  28.00   1400    457      0
# 1  0.084411   0.347946  -0.050915  ...  36.33  27.67   1373    452      0
# 2  0.053135   0.368767  -0.033106  ...  34.83  28.33   1415    464      0
# 3 -0.034294   0.384466   0.009838  ...  35.00  28.00   1475    464      0
# 4 -0.010424   0.385293  -0.017150  ...  35.33  28.00   1449    475      0
#
#     bio15  bio16  bio17  bio18  bio19
# 0  121.31    944      0    150    890
# 1  123.78    943      0    131    890
# 2  121.63    939      0    134    924
# 3  117.63    962      0    162    949
# 4  121.57    964      0    135    947
#
# [5 rows x 66 columns]

# %%
X_test_scaled = pd.DataFrame(fitted_scaler.transform(X_test), columns=X_test.columns, index=X_test.index)

# %%
X_test_imputed = pd.DataFrame(fitted_imputer.transform(X_test_scaled), columns=X_test.columns, index=X_test.index)

# %%
X_test_imputed = pd.DataFrame(fitted_scaler.inverse_transform(X_test_imputed), columns=X_test.columns, index=X_test.index)
X_test_imputed = round_columns(X_test_imputed, round_cols, round_factor)

# %%
X_test_rfe = pd.DataFrame(fitted_rfe.transform(X_test_imputed), columns = X_test.columns[fitted_rfe.support_], index=X_test.index)

# %%
y_test_pred = fitted_model.predict(X_test_rfe)

# %%
y_test_pred = np.clip(np.round(y_test_pred), 0, num_of_classes -1).astype(int)

# %%
y_test_pred
# Out:
# array([4, 2, 5, ..., 1, 1, 1])

# %%
results_test = pd.DataFrame({'prediction': y_test_pred})

results_test['dt_prediction'] = inference.loc[results_test.index, 'dt_prediction']
results_test['dt_reference'] = results_test['dt_prediction']+3

results_test.reset_index(drop=True, inplace=True)

# %%
results_test
# Out:
#       prediction dt_prediction dt_reference
# 0              4       2024-10      2025-01
# 1              2       2024-10      2025-01
# 2              5       2024-10      2025-01
# 3              1       2024-10      2025-01
# 4              2       2024-10      2025-01
# ...          ...           ...          ...
# 4750           1       2025-12      2026-03
# 4751           1       2025-12      2026-03
# 4752           1       2025-12      2026-03
# 4753           1       2025-12      2026-03
# 4754           1       2025-12      2026-03
#
# [4755 rows x 3 columns]

# %%
results_df = pd.merge(inference[['location', 'location_full', 'x', 'y']], results_test, left_index=True, right_index=True, how='inner')
results_df['classes_range'] = num_of_classes-1
results_df['target'] = target_variable[ΤARGET]

# %%
polygon_ids = pd.read_csv(f'../../../data/CM_WEB_Polygons_processed.csv', encoding=enc)

polygon_ids['location'] = polygon_ids['location'].astype(str)
results_df['location'] = results_df['location'].astype(str)

# %%
results_df = pd.merge(results_df, polygon_ids, on=['location'], how='left')
results_df.drop(columns=['location'], inplace=True)
results_df.rename(columns={'location_full': 'location', 'id': 'polygon_id'}, inplace=True)
results_df = results_df[['location', 'polygon_id', 'x', 'y', 'target', 'classes_range', 'dt_prediction', 'dt_reference', 'prediction']]

# %%
results_df = results_df[['location', 'polygon_id', 'x', 'y', 'target', 'classes_range', 'dt_prediction', 'dt_reference', 'prediction']]

# %%
results_df
# Out:
#                                          location  polygon_id          x  \
# 0           (extreme nord, diamare, bogo, balaza)         372  14.515776
# 1            (extreme nord, diamare, bogo, balda)         310  14.724237
# 2             (extreme nord, diamare, bogo, bogo)         311  14.597860
# 3            (extreme nord, diamare, bogo, borai)         313  14.606980
# 4        (extreme nord, diamare, bogo, guinggley)         312  14.702740
# ...                                           ...         ...        ...
# 4750    (extreme nord, mayo-tsanaga, roua, midre)         367  13.871290
# 4751  (extreme nord, mayo-tsanaga, roua, ndimche)         428  13.968570
# 4752     (extreme nord, mayo-tsanaga, roua, roua)         411  13.968570
# 4753  (extreme nord, mayo-tsanaga, roua, soulede)         368  13.917498
# 4754    (extreme nord, mayo-tsanaga, roua, zogom)         442  14.005050
#
#               y                           target  classes_range dt_prediction  \
# 0     10.786560  Malaria Cases in Pregnant Women              6       2024-10
# 1     10.914551  Malaria Cases in Pregnant Women              6       2024-10
# 2     10.743440  Malaria Cases in Pregnant Women              6       2024-10
# 3     10.653607  Malaria Cases in Pregnant Women              6       2024-10
# 4     10.792848  Malaria Cases in Pregnant Women              6       2024-10
# ...         ...                              ...            ...           ...
# 4750  10.791350  Malaria Cases in Pregnant Women              6       2025-12
# 4751  10.827287  Malaria Cases in Pregnant Women              6       2025-12
# 4752  10.779370  Malaria Cases in Pregnant Women              6       2025-12
# 4753  10.736254  Malaria Cases in Pregnant Women              6       2025-12
# 4754  10.743440  Malaria Cases in Pregnant Women              6       2025-12
#
#      dt_reference  prediction
# 0         2025-01           4
# 1         2025-01           2
# 2         2025-01           5
# 3         2025-01           1
# 4         2025-01           2
# ...           ...         ...
# 4750      2026-03           1
# 4751      2026-03           1
# 4752      2026-03           1
# 4753      2026-03           1
# 4754      2026-03           1
#
# [4755 rows x 9 columns]

# %%
results_df.prediction.value_counts().sort_index().plot(kind='bar', 
                                                              figsize=(6, 4), 
                                                              title='Predicted Case Bin Distribution', 
                                                              xlabel='Bins', 
                                                              ylabel='Frequency')
# Out:
# <Axes: title={'center': 'Predicted Case Bin Distribution'}, xlabel='Bins', ylabel='Frequency'>

# %%
period = "2026-03"

test_results_to_send = results_df[results_df["dt_reference"] == pd.Period(period, freq="M")]
test_results_to_send.to_csv(f'../../../data/{REGION}/results/CM_{REGION}_Inference_{period}{ΤARGET}.csv', index=False, encoding=enc)

# %%
test_results_to_send.prediction.value_counts().sort_index().plot(kind='bar', 
                                                              figsize=(6, 4), 
                                                              title='Predicted Case Bin Distribution', 
                                                              xlabel='Bins', 
                                                              ylabel='Frequency')
# Out:
# <Axes: title={'center': 'Predicted Case Bin Distribution'}, xlabel='Bins', ylabel='Frequency'>

# %%
shapefile_path = "../../../../../../Shapefiles/Cameroon Shapefiles/new/"
shapefile = gpd.read_file(f"{shapefile_path}web_platform/CM_ExtremeNord_LV3.shp",  encoding=enc)

shapefile['location'] = list(zip(shapefile['GID0'],shapefile['GID1'], shapefile['GID2'], shapefile['GID3']))

# %%
results_shapefile = gpd.GeoDataFrame(pd.merge(test_results_to_send, shapefile[['location', 'geometry']], on='location', how='left'), 
                                            geometry='geometry',
                                            crs=shapefile.crs)

results_shapefile.drop(columns=['location'], inplace=True)
results_shapefile['dt_prediction'] = results_shapefile['dt_prediction'].astype(str)
results_shapefile['dt_reference'] = results_shapefile['dt_reference'].astype(str)

# %%
results_shapefile
# Out:
#      polygon_id          x          y                           target  \
# 0           372  14.515776  10.786560  Malaria Cases in Pregnant Women
# 1           310  14.724237  10.914551  Malaria Cases in Pregnant Women
# 2           311  14.597860  10.743440  Malaria Cases in Pregnant Women
# 3           313  14.606980  10.653607  Malaria Cases in Pregnant Women
# 4           312  14.702740  10.792848  Malaria Cases in Pregnant Women
# ..          ...        ...        ...                              ...
# 312         367  13.871290  10.791350  Malaria Cases in Pregnant Women
# 313         428  13.968570  10.827287  Malaria Cases in Pregnant Women
# 314         411  13.968570  10.779370  Malaria Cases in Pregnant Women
# 315         368  13.917498  10.736254  Malaria Cases in Pregnant Women
# 316         442  14.005050  10.743440  Malaria Cases in Pregnant Women
#
#      classes_range dt_prediction dt_reference  prediction  \
# 0                6       2025-12      2026-03           3
# 1                6       2025-12      2026-03           2
# 2                6       2025-12      2026-03           4
# 3                6       2025-12      2026-03           1
# 4                6       2025-12      2026-03           1
# ..             ...           ...          ...         ...
# 312              6       2025-12      2026-03           1
# 313              6       2025-12      2026-03           1
# 314              6       2025-12      2026-03           1
# 315              6       2025-12      2026-03           1
# 316              6       2025-12      2026-03           1
#
#                                               geometry
# 0    POLYGON ((14.58994 10.92058, 14.59002 10.92043...
# 1    POLYGON ((14.77766 11.04734, 14.77783 11.04683...
# 2    POLYGON ((14.58146 10.69651, 14.58130 10.69653...
# 3    POLYGON ((14.56106 10.62899, 14.56133 10.62981...
# 4    POLYGON ((14.78187 10.88231, 14.78200 10.88230...
# ..                                                 ...
# 312  POLYGON ((13.87545 10.82501, 13.87552 10.82457...
# 313  POLYGON ((13.96314 10.85196, 13.96329 10.85198...
# 314  POLYGON ((14.00134 10.75699, 14.00093 10.75700...
# 315  POLYGON ((13.95906 10.79143, 13.95912 10.79136...
# 316  POLYGON ((14.02364 10.76046, 14.02380 10.76027...
#
# [317 rows x 9 columns]

# %%
results_shapefile.to_file(f'../../../data/{REGION}/results/CM_{REGION}_Inference_TEST{ΤARGET}.shp', index=False, encoding=enc)
# Out:
# C:\Users\dimit\AppData\Local\Temp\ipykernel_10744\12272870.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   results_shapefile.to_file(f'../../../data/{REGION}/results/CM_{REGION}_Inference_TEST{ΤARGET}.shp', index=False, encoding=enc)

# %%
float_column = 'prediction'
cmap = plt.cm.YlOrRd
figure_size = (12,8)
title_size = 18

fig, ax = plt.subplots(figsize=figure_size)

# Plot the geometry column with the colors based on the float column
results_shapefile.plot(ax=ax, column=float_column, cmap=cmap, edgecolor='grey', legend=True, vmin = 0, vmax = results_shapefile.classes_range.iloc[1])
plt.title(f'{target_variable[ΤARGET]} Prediction\nRegion: Cameroon Extreme North\nDate of prediction: {results_shapefile.dt_prediction.iloc[1]}\nDate of reference: {results_shapefile.dt_reference.iloc[1]}', 
          size = title_size)
# plt.show()
# Out:
# Text(0.5, 1.0, 'Malaria Cases in Pregnant Women Prediction\nRegion: Cameroon Extreme North\nDate of prediction: 2025-12\nDate of reference: 2026-03')
