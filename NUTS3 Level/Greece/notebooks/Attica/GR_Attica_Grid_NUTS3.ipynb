# %% [markdown]
# ## Creates the **Grid File** of a specific region by converting the available shapefile into mutliple (X,Y) coordinate pairs to represent each NUTS3 Unit ##

# %%
import pandas as pd

import random
import geopandas as gpd
import numpy as np
import os

import sys

sys.path.insert(0, "../../../../Modules")

from utils import process_greek, create_grid

enc = 'utf-8'
dec = 'greek8'
random.seed(0)
np.random.seed(0)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
NUTS0 = 'GR'
NUTS2 = 'Attica'
NUTS2_ID = 'EL30'

# %%
greece_nuts3_gdf = gpd.read_file(f"../../../../Europe Shapefiles/Greece/data/EL_Whole.shp",  encoding=enc)

# %%
greece_nuts3_gdf.head(5)
# Out:
#   CNTR_CODE CNTR_NAME NUTS1_ID NUTS1_LATN NUTS1_NAME NUTS2_ID NUTS2_LATN  \
# 0        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
# 1        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
# 2        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
# 3        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
# 4        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
#
#   NUTS2_NAME NUTS3_ID                NUTS3_LATN               NUTS3_NAME  \
# 0     Aττική    EL301    Voreios Tomeas Athinon    Βόρειος Τομέας Αθηνών
# 1     Aττική    EL302    Dytikos Tomeas Athinon    Δυτικός Τομέας Αθηνών
# 2     Aττική    EL303  Kentrikos Tomeas Athinon  Κεντρικός Τομέας Αθηνών
# 3     Aττική    EL304     Notios Tomeas Athinon     Νότιος Τομέας Αθηνών
# 4     Aττική    EL305          Anatoliki Attiki         Ανατολική Αττική
#
#    MOUNT_TYPE  URBN_TYPE  COAST_TYPE  \
# 0         4.0          1           2
# 1         4.0          1           1
# 2         4.0          1           2
# 3         4.0          1           1
# 4         2.0          1           1
#
#                                             geometry
# 0  POLYGON ((23.82310 37.97392, 23.80300 37.98545...
# 1  MULTIPOLYGON (((23.72005 38.06296, 23.72884 38...
# 2  POLYGON ((23.82310 37.97392, 23.82185 37.97195...
# 3  POLYGON ((23.80679 37.91784, 23.80240 37.91205...
# 4  MULTIPOLYGON (((24.10518 38.18205, 24.10171 38...

# %%
print(f'greece_nuts3 CRS: {greece_nuts3_gdf.crs}')
# Out:
# greece_nuts3 CRS: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433],AXIS["Longitude",EAST],AXIS["Latitude",NORTH]]

# %%
greece_nuts3_gdf = greece_nuts3_gdf.to_crs(epsg=4326)

# %%
print(f'greece_nuts3 CRS: {greece_nuts3_gdf.crs}')
# Out:
# greece_nuts3 CRS: EPSG:4326

# %%
greece_nuts3_gdf.head(5)
# Out:
#   CNTR_CODE CNTR_NAME NUTS1_ID NUTS1_LATN NUTS1_NAME NUTS2_ID NUTS2_LATN  \
# 0        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
# 1        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
# 2        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
# 3        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
# 4        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
#
#   NUTS2_NAME NUTS3_ID                NUTS3_LATN               NUTS3_NAME  \
# 0     Aττική    EL301    Voreios Tomeas Athinon    Βόρειος Τομέας Αθηνών
# 1     Aττική    EL302    Dytikos Tomeas Athinon    Δυτικός Τομέας Αθηνών
# 2     Aττική    EL303  Kentrikos Tomeas Athinon  Κεντρικός Τομέας Αθηνών
# 3     Aττική    EL304     Notios Tomeas Athinon     Νότιος Τομέας Αθηνών
# 4     Aττική    EL305          Anatoliki Attiki         Ανατολική Αττική
#
#    MOUNT_TYPE  URBN_TYPE  COAST_TYPE  \
# 0         4.0          1           2
# 1         4.0          1           1
# 2         4.0          1           2
# 3         4.0          1           1
# 4         2.0          1           1
#
#                                             geometry
# 0  POLYGON ((23.82310 37.97392, 23.80300 37.98545...
# 1  MULTIPOLYGON (((23.72005 38.06296, 23.72884 38...
# 2  POLYGON ((23.82310 37.97392, 23.82185 37.97195...
# 3  POLYGON ((23.80679 37.91784, 23.80240 37.91205...
# 4  MULTIPOLYGON (((24.10518 38.18205, 24.10171 38...

# %%
greece_nuts3_gdf.NUTS3_ID.unique()
# Out:
# array(['EL301', 'EL302', 'EL303', 'EL304', 'EL305', 'EL306', 'EL307',
#        'EL411', 'EL412', 'EL413', 'EL421', 'EL422', 'EL431', 'EL432',
#        'EL433', 'EL434', 'EL511', 'EL512', 'EL513', 'EL514', 'EL515',
#        'EL521', 'EL522', 'EL523', 'EL524', 'EL525', 'EL526', 'EL527',
#        'EL531', 'EL532', 'EL533', 'EL541', 'EL542', 'EL543', 'EL611',
#        'EL612', 'EL613', 'EL621', 'EL622', 'EL623', 'EL624', 'EL631',
#        'EL632', 'EL633', 'EL641', 'EL642', 'EL643', 'EL644', 'EL645',
#        'EL651', 'EL652', 'EL653'], dtype=object)

# %%
#choose the correct region

nuts2_gdf = greece_nuts3_gdf.loc[greece_nuts3_gdf['NUTS2_ID'] == f'{NUTS2_ID}'].copy()
nuts2_gdf.head()
# Out:
#   CNTR_CODE CNTR_NAME NUTS1_ID NUTS1_LATN NUTS1_NAME NUTS2_ID NUTS2_LATN  \
# 0        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
# 1        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
# 2        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
# 3        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
# 4        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
#
#   NUTS2_NAME NUTS3_ID                NUTS3_LATN               NUTS3_NAME  \
# 0     Aττική    EL301    Voreios Tomeas Athinon    Βόρειος Τομέας Αθηνών
# 1     Aττική    EL302    Dytikos Tomeas Athinon    Δυτικός Τομέας Αθηνών
# 2     Aττική    EL303  Kentrikos Tomeas Athinon  Κεντρικός Τομέας Αθηνών
# 3     Aττική    EL304     Notios Tomeas Athinon     Νότιος Τομέας Αθηνών
# 4     Aττική    EL305          Anatoliki Attiki         Ανατολική Αττική
#
#    MOUNT_TYPE  URBN_TYPE  COAST_TYPE  \
# 0         4.0          1           2
# 1         4.0          1           1
# 2         4.0          1           2
# 3         4.0          1           1
# 4         2.0          1           1
#
#                                             geometry
# 0  POLYGON ((23.82310 37.97392, 23.80300 37.98545...
# 1  MULTIPOLYGON (((23.72005 38.06296, 23.72884 38...
# 2  POLYGON ((23.82310 37.97392, 23.82185 37.97195...
# 3  POLYGON ((23.80679 37.91784, 23.80240 37.91205...
# 4  MULTIPOLYGON (((24.10518 38.18205, 24.10171 38...

# %%
print(f'nuts2_gdf CRS: {nuts2_gdf.crs}')
# Out:
# nuts2_gdf CRS: EPSG:4326

# %%
nuts2_gdf.plot(facecolor="none", edgecolor='grey', figsize=(15, 10), color='orange')
# Out:
# <Axes: >

# %%
nuts2_gdf.NUTS3_NAME.unique()
# Out:
# array(['Βόρειος Τομέας Αθηνών', 'Δυτικός Τομέας Αθηνών',
#        'Κεντρικός Τομέας Αθηνών', 'Νότιος Τομέας Αθηνών',
#        'Ανατολική Αττική', 'Δυτική Αττική', 'Πειραιάς, Νήσοι'],
#       dtype=object)

# %%
nuts2_gdf.drop(columns=['CNTR_CODE','CNTR_NAME','NUTS1_ID','NUTS1_LATN','NUTS1_NAME','NUTS2_LATN','NUTS3_LATN',
                        'MOUNT_TYPE','URBN_TYPE','COAST_TYPE'], inplace = True)
nuts2_gdf.reset_index(drop = True, inplace = True)
process_greek(nuts2_gdf, 'NUTS3_NAME')
process_greek(nuts2_gdf, 'NUTS2_NAME')

# %%
nuts2_gdf.head(5)
# Out:
#   NUTS2_ID NUTS2_NAME NUTS3_ID               NUTS3_NAME  \
# 0     EL30     αττικη    EL301    βορειος τομεας αθηνων
# 1     EL30     αττικη    EL302    δυτικος τομεας αθηνων
# 2     EL30     αττικη    EL303  κεντρικος τομεας αθηνων
# 3     EL30     αττικη    EL304     νοτιος τομεας αθηνων
# 4     EL30     αττικη    EL305         ανατολικη αττικη
#
#                                             geometry
# 0  POLYGON ((23.82310 37.97392, 23.80300 37.98545...
# 1  MULTIPOLYGON (((23.72005 38.06296, 23.72884 38...
# 2  POLYGON ((23.82310 37.97392, 23.82185 37.97195...
# 3  POLYGON ((23.80679 37.91784, 23.80240 37.91205...
# 4  MULTIPOLYGON (((24.10518 38.18205, 24.10171 38...

# %%
nuts2_gdf.plot(facecolor="none", edgecolor='grey', figsize=(15, 10), color='orange')
# Out:
# <Axes: >

# %%
nuts3_units = nuts2_gdf['NUTS3_NAME'].unique().tolist()

if not os.path.exists(f'../../data/{NUTS2}/'):
    os.makedirs(f'../../data/{NUTS2}/')

with open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_SHP_NUTS3_Units_Processed.txt', 'w', encoding=enc) as f:
    for item in nuts3_units:
        f.write("%s\n" % item)

print(f"Number of NUTS3 Units in {NUTS2} (from shapefile): {len(nuts3_units)}")
# Out:
# Number of NUTS3 Units in Attica (from shapefile): 7

# %%
nuts2_gdf.reset_index(inplace=True, drop = True)

# %%
empty_gdf = gpd.GeoDataFrame(columns=['geometry'], geometry='geometry', crs='EPSG:4326')

df_grid = create_grid(empty_gdf, nuts2_gdf, col_municipal='NUTS3_NAME', dimension=2)

# %%
df_grid.shape
# Out:
# (624, 5)

# %%
df_grid.head()
# Out:
#                                             geometry  \
# 0  POLYGON ((23.78937 38.04579, 23.78937 38.06376...
# 1  POLYGON ((23.81216 38.00986, 23.81216 38.02782...
# 2  POLYGON ((23.81216 38.02782, 23.81216 38.04579...
# 3  POLYGON ((23.81216 38.04579, 23.81216 38.06376...
# 4  POLYGON ((23.81216 38.06376, 23.81216 38.08172...
#
#                                         centers                   NAME  \
# 0  POINT (23.777976934677444 38.05477211220097)  βορειος τομεας αθηνων
# 1  POINT (23.80076889112907 38.018838729000535)  βορειος τομεας αθηνων
# 2  POINT (23.80076889112907 38.036805420600764)  βορειος τομεας αθηνων
# 3   POINT (23.80076889112907 38.05477211220097)  βορειος τομεας αθηνων
# 4   POINT (23.80076889112907 38.07273880380119)  βορειος τομεας αθηνων
#
#           x         y
# 0  23.77798  38.05477
# 1  23.80077  38.01884
# 2  23.80077  38.03681
# 3  23.80077  38.05477
# 4  23.80077  38.07274

# %%
df_grid.rename(columns={"NAME": "NUTS3_NAME"}, inplace = True)

# %%
ax = nuts2_gdf.plot(figsize=(15, 15), facecolor="none", edgecolor='black', lw=2)
df_grid.plot(facecolor="none", edgecolor='grey', ax=ax, color='orange')
# Out:
# <Axes: >

# %%
grid_nuts3 = df_grid['NUTS3_NAME'].unique().tolist()
print(f"Number of NUTS3 Units in Grid: {len(grid_nuts3)}")
# Out:
# Number of NUTS3 Units in Grid: 7

# %%
if (len(nuts3_units) != len(grid_nuts3)):
    delta = [item for item in nuts3_units if item not in grid_nuts3]
    print(delta)

    lost_lau1 = nuts2_gdf[nuts2_gdf['NUTS3_NAME'].isin(delta)]
    lost_lau1["centroid"] = lost_lau1["geometry"].centroid

    add_to_nuts2_grid = pd.DataFrame()
    add_to_nuts2_grid['NUTS3_NAME'] = lost_lau1['NUTS3_NAME']
    add_to_nuts2_grid['geometry'] = lost_lau1['geometry']
    add_to_nuts2_grid['x'] = round(lost_lau1['centroid'].x, 5)
    add_to_nuts2_grid['y'] = round(lost_lau1['centroid'].y, 5)

    lost_lau1.plot(facecolor="none", edgecolor='grey', figsize=(10, 10), color='orange')

# %%
nuts2_grid = df_grid.drop(columns=['centers'])

# %%
nuts2_grid
# Out:
#                                               geometry             NUTS3_NAME  \
# 0    POLYGON ((23.78937 38.04579, 23.78937 38.06376...  βορειος τομεας αθηνων
# 1    POLYGON ((23.81216 38.00986, 23.81216 38.02782...  βορειος τομεας αθηνων
# 2    POLYGON ((23.81216 38.02782, 23.81216 38.04579...  βορειος τομεας αθηνων
# 3    POLYGON ((23.81216 38.04579, 23.81216 38.06376...  βορειος τομεας αθηνων
# 4    POLYGON ((23.81216 38.06376, 23.81216 38.08172...  βορειος τομεας αθηνων
# ..                                                 ...                    ...
# 619  POLYGON ((23.53474 37.92708, 23.53474 37.94505...        πειραιας, νησοι
# 620  POLYGON ((23.60121 37.96301, 23.60121 37.98098...        πειραιας, νησοι
# 621  POLYGON ((23.62337 37.96301, 23.62337 37.98098...        πειραιας, νησοι
# 622  POLYGON ((23.64553 37.96301, 23.64553 37.98098...        πειραιας, νησοι
# 623  POLYGON ((23.66769 37.94505, 23.66769 37.96301...        πειραιας, νησοι
#
#             x         y
# 0    23.77798  38.05477
# 1    23.80077  38.01884
# 2    23.80077  38.03681
# 3    23.80077  38.05477
# 4    23.80077  38.07274
# ..        ...       ...
# 619  23.52366  37.93606
# 620  23.59013  37.97200
# 621  23.61229  37.97200
# 622  23.63445  37.97200
# 623  23.65661  37.95403
#
# [624 rows x 4 columns]

# %%
if (len(nuts3_units) != len(grid_nuts3)):
    nuts2_grid = pd.concat([nuts2_grid, add_to_nuts2_grid], axis=0)

nuts2_grid.reset_index(inplace=True, drop=True)

# %%
nuts2_grid.rename(columns={"geometry": "shape"}, inplace=True)

# %%
nuts2_grid
# Out:
#                                                  shape             NUTS3_NAME  \
# 0    POLYGON ((23.78937 38.04579, 23.78937 38.06376...  βορειος τομεας αθηνων
# 1    POLYGON ((23.81216 38.00986, 23.81216 38.02782...  βορειος τομεας αθηνων
# 2    POLYGON ((23.81216 38.02782, 23.81216 38.04579...  βορειος τομεας αθηνων
# 3    POLYGON ((23.81216 38.04579, 23.81216 38.06376...  βορειος τομεας αθηνων
# 4    POLYGON ((23.81216 38.06376, 23.81216 38.08172...  βορειος τομεας αθηνων
# ..                                                 ...                    ...
# 619  POLYGON ((23.53474 37.92708, 23.53474 37.94505...        πειραιας, νησοι
# 620  POLYGON ((23.60121 37.96301, 23.60121 37.98098...        πειραιας, νησοι
# 621  POLYGON ((23.62337 37.96301, 23.62337 37.98098...        πειραιας, νησοι
# 622  POLYGON ((23.64553 37.96301, 23.64553 37.98098...        πειραιας, νησοι
# 623  POLYGON ((23.66769 37.94505, 23.66769 37.96301...        πειραιας, νησοι
#
#             x         y
# 0    23.77798  38.05477
# 1    23.80077  38.01884
# 2    23.80077  38.03681
# 3    23.80077  38.05477
# 4    23.80077  38.07274
# ..        ...       ...
# 619  23.52366  37.93606
# 620  23.59013  37.97200
# 621  23.61229  37.97200
# 622  23.63445  37.97200
# 623  23.65661  37.95403
#
# [624 rows x 4 columns]

# %%
nuts2_grid_points = gpd.GeoDataFrame(nuts2_grid, geometry=gpd.points_from_xy(nuts2_grid.x, nuts2_grid.y))

# %%
nuts2_grid_points
# Out:
#                                                  shape             NUTS3_NAME  \
# 0    POLYGON ((23.78937 38.04579, 23.78937 38.06376...  βορειος τομεας αθηνων
# 1    POLYGON ((23.81216 38.00986, 23.81216 38.02782...  βορειος τομεας αθηνων
# 2    POLYGON ((23.81216 38.02782, 23.81216 38.04579...  βορειος τομεας αθηνων
# 3    POLYGON ((23.81216 38.04579, 23.81216 38.06376...  βορειος τομεας αθηνων
# 4    POLYGON ((23.81216 38.06376, 23.81216 38.08172...  βορειος τομεας αθηνων
# ..                                                 ...                    ...
# 619  POLYGON ((23.53474 37.92708, 23.53474 37.94505...        πειραιας, νησοι
# 620  POLYGON ((23.60121 37.96301, 23.60121 37.98098...        πειραιας, νησοι
# 621  POLYGON ((23.62337 37.96301, 23.62337 37.98098...        πειραιας, νησοι
# 622  POLYGON ((23.64553 37.96301, 23.64553 37.98098...        πειραιας, νησοι
# 623  POLYGON ((23.66769 37.94505, 23.66769 37.96301...        πειραιας, νησοι
#
#             x         y                   geometry
# 0    23.77798  38.05477  POINT (23.77798 38.05477)
# 1    23.80077  38.01884  POINT (23.80077 38.01884)
# 2    23.80077  38.03681  POINT (23.80077 38.03681)
# 3    23.80077  38.05477  POINT (23.80077 38.05477)
# 4    23.80077  38.07274  POINT (23.80077 38.07274)
# ..        ...       ...                        ...
# 619  23.52366  37.93606  POINT (23.52366 37.93606)
# 620  23.59013  37.97200  POINT (23.59013 37.97200)
# 621  23.61229  37.97200  POINT (23.61229 37.97200)
# 622  23.63445  37.97200  POINT (23.63445 37.97200)
# 623  23.65661  37.95403  POINT (23.65661 37.95403)
#
# [624 rows x 5 columns]

# %%
ax = nuts2_grid_points.plot(markersize=2.5, figsize=(20, 20), color='red')
nuts2_gdf.plot(facecolor="none", edgecolor='black', ax=ax, lw=2)
# Out:
# <Axes: >

# %%
final_grid = pd.merge(nuts2_grid[['NUTS3_NAME', 'x', 'y']], nuts2_gdf[['NUTS2_ID','NUTS2_NAME','NUTS3_ID','NUTS3_NAME']], how='left', on=['NUTS3_NAME']) 
final_grid.sort_values(by=['NUTS3_NAME'], inplace = True)
final_grid = final_grid[['NUTS2_ID', 'NUTS2_NAME', 'NUTS3_ID', 'NUTS3_NAME', 'x', 'y']]

final_grid.reset_index(drop = True, inplace= True)

# %%
final_grid
# Out:
#     NUTS2_ID NUTS2_NAME NUTS3_ID        NUTS3_NAME         x         y
# 0       EL30     αττικη    EL305  ανατολικη αττικη  24.00727  37.83228
# 1       EL30     αττικη    EL305  ανατολικη αττικη  23.91651  37.92212
# 2       EL30     αττικη    EL305  ανατολικη αττικη  23.91651  37.90415
# 3       EL30     αττικη    EL305  ανατολικη αττικη  23.91651  37.88618
# 4       EL30     αττικη    EL305  ανατολικη αττικη  23.91651  37.86822
# ..       ...        ...      ...               ...       ...       ...
# 619     EL30     αττικη    EL307   πειραιας, νησοι  22.99184  36.24719
# 620     EL30     αττικη    EL307   πειραιας, νησοι  22.99184  36.22923
# 621     EL30     αττικη    EL307   πειραιας, νησοι  22.99184  36.21126
# 622     EL30     αττικη    EL307   πειραιας, νησοι  22.99184  36.17533
# 623     EL30     αττικη    EL307   πειραιας, νησοι  23.65661  37.95403
#
# [624 rows x 6 columns]

# %%
final_grid['NUTS2_NAME'] = 'αττικη'

# %%
final_grid
# Out:
#     NUTS2_ID NUTS2_NAME NUTS3_ID        NUTS3_NAME         x         y
# 0       EL30     αττικη    EL305  ανατολικη αττικη  24.00727  37.83228
# 1       EL30     αττικη    EL305  ανατολικη αττικη  23.91651  37.92212
# 2       EL30     αττικη    EL305  ανατολικη αττικη  23.91651  37.90415
# 3       EL30     αττικη    EL305  ανατολικη αττικη  23.91651  37.88618
# 4       EL30     αττικη    EL305  ανατολικη αττικη  23.91651  37.86822
# ..       ...        ...      ...               ...       ...       ...
# 619     EL30     αττικη    EL307   πειραιας, νησοι  22.99184  36.24719
# 620     EL30     αττικη    EL307   πειραιας, νησοι  22.99184  36.22923
# 621     EL30     αττικη    EL307   πειραιας, νησοι  22.99184  36.21126
# 622     EL30     αττικη    EL307   πειραιας, νησοι  22.99184  36.17533
# 623     EL30     αττικη    EL307   πειραιας, νησοι  23.65661  37.95403
#
# [624 rows x 6 columns]

# %%
final_grid.NUTS3_NAME.unique()
# Out:
# array(['ανατολικη αττικη', 'βορειος τομεας αθηνων', 'δυτικη αττικη',
#        'δυτικος τομεας αθηνων', 'κεντρικος τομεας αθηνων',
#        'νοτιος τομεας αθηνων', 'πειραιας, νησοι'], dtype=object)

# %%
final_grid.to_csv(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_Grid_NUTS3.csv', encoding=enc, index = False)
