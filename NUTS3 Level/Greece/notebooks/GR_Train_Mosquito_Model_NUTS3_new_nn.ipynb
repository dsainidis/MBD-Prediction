# %% [markdown]
# ## Produces **Mosquito Predictions** for a specific region using MAMOTH ##

# %%
import pandas as pd
import datetime
import math
import numpy as np
import missingno
import json
from statistics import mean
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
import sys
import pickle

sys.path.insert(0, "../../../Mamoth_new")
sys.path.insert(0, "../../../Modules")

from utils import *

from Preprocessing_Module import read_data, add_topological, add_landcover, merge_new_data, fill_data, select_columns, reshape_dataset, fillna_dataset, remove_nan_features, unused_stations
from Feature_Expansion_Module import feature_expansion
from Initializer_Module import initializer
from XGboost_Model_Module import Xgboost_model
from Neural_Network_Module import FeedforwardNeuralNetModel
from Model_Validation_Module import give_predictions_nn, evaluate_nn, give_predictions_xgboost, evaluate_xgboost, validate_results, merge_predictions

enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 100
pd.options.display.float_format = lambda x: '%.6f' % x

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
NUTS0 = 'GR'

# %%
mosquito_data = read_data(f'../data/{NUTS0}_MSQ_culex_2011-2024_processed.csv')
# Out:
# Index(['nuts2', 'nuts3', 'x', 'y', 'dt_placement', 'month', 'year',
#        'month_sin', 'month_cos', 'ndvi', 'ndmi', 'ndwi', 'ndbi', 'ndvi_mean',
#        'ndmi_mean', 'ndwi_mean', 'ndbi_mean', 'ndvi_std', 'ndmi_std',
#        'ndwi_std', 'ndbi_std', 'lst_day', 'lst_night', 'lst',
#        'lst_jan_day_mean', 'lst_jan_night_mean', 'lst_jan_mean',
#        'lst_feb_day_mean', 'lst_feb_night_mean', 'lst_feb_mean',
#        'lst_mar_day_mean', 'lst_mar_night_mean', 'lst_mar_mean',
#        'lst_apr_day_mean', 'lst_apr_night_mean', 'lst_apr_mean',
#        'acc_rainfall_jan', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'distance_to_coast', 'distance_to_river', 'slope_mean_1km',
#        'aspect_mean_200m', 'elevation_mean_1km', 'hillshade_mean_1km',
#        'fs_area_1km', 'flow_accu_200m', 'lc_type1', 'mosq_now'],
#       dtype='object')

# %%
mosquito_data.nuts2.unique()
# Out:
# array(['EL52', 'EL61', 'EL63', 'EL43', 'EL53', 'EL57'], dtype=object)

# %%
# select region

# %%
mosquito_data.drop(columns=['nuts2', 'nuts3'], inplace=True)

# %%
mosquito_data
# Out:
#               x         y dt_placement  month  year  month_sin  month_cos  \
# 0     22.193720 40.665896   2011-03-29      3  2011   1.000000   0.000000
# 1     22.447874 40.753947   2011-03-28      3  2011   1.000000   0.000000
# 2     22.615797 40.664160   2011-04-05      4  2011   0.866025  -0.500000
# 3     22.547799 40.509188   2011-04-13      4  2011   0.866025  -0.500000
# 4     22.715266 40.669967   2011-04-05      4  2011   0.866025  -0.500000
# ...         ...       ...          ...    ...   ...        ...        ...
# 20072 21.720620 38.225835   2024-09-08      9  2024  -1.000000  -0.000000
# 20073 21.725120 38.225193   2024-09-08      9  2024  -1.000000  -0.000000
# 20074 21.671776 38.163949   2024-09-08      9  2024  -1.000000  -0.000000
# 20075 21.266408 37.841273   2024-09-08      9  2024  -1.000000  -0.000000
# 20076 21.351672 39.377562   2024-09-08      9  2024  -1.000000  -0.000000
#
#            ndvi      ndmi      ndwi      ndbi  ndvi_mean  ndmi_mean
# 20076      1.387769          8.428182            1.640000      5.034091
#
#        lst_mar_day_mean  lst_mar_night_mean  lst_mar_mean  lst_apr_day_mean  \
# 0             19.115714            3.161667     11.138690         24.771667
# 1             20.072500            4.233333     12.152917         28.004667
# 2             18.624286            3.625385     11.124835         28.131333
# 3             18.439231            3.005556     10.722393         25.953333
# 4             18.195000            3.276667     10.735833         26.464118
# ...                 ...                 ...           ...               ...
# 20072               NaN                 NaN           NaN               NaN
# 20073               NaN                 NaN           NaN               NaN
# 20074         14.688947           10.795882     12.742415         21.400000
# 20075         18.441111            8.020000     13.230556         26.620000
# 20076         12.568571            4.852222      8.710397         19.767333
#
#        lst_apr_night_mean  lst_apr_mean  acc_rainfall_jan  acc_rainfall_1week  \
# 0                8.180000     16.475833        203.793588           11.032128
# 1                8.736667     18.370667        180.220247            0.072116
# 2                8.008750     18.070042        231.269478            3.360479
# 3                8.370000     17.161667        224.639889            9.028140
# 4                7.859231     17.161674        222.349577            3.512708
# ...                   ...           ...               ...                 ...
# 20072                 NaN           NaN        604.329986            0.000000
# 20073                 NaN           NaN        604.329986            0.000000
# 20074           14.025000     17.712500        626.229986            0.660000
# 20075           11.171111     18.895556        678.089984           13.809999
# 20076            7.993333     13.880333        897.189983           12.320000
#
#        acc_rainfall_2week  distance_to_coast  distance_to_river  \
# 0               37.117337       21141.266390         883.226446
# 1               37.919265       30069.317203         970.515584
# 2               18.171441       16862.084973        3002.814943
# 3               11.736175        4023.105903         244.900503
# 4               14.843995       10066.399818        2262.772151
# ...                   ...                ...                ...
# 20072           46.869999         168.931756         324.697208
# 20073           46.869999         168.931756         324.697208
# 20074           46.639999        1200.955428        2077.453102
# 20075           65.019998        4312.027104          60.842302
# 20076          109.079999       28025.355559        1166.337954
#
#        slope_mean_1km  aspect_mean_200m  elevation_mean_1km  \
# 0                   3        139.431379           26.465763
# 1                   2        153.716334            7.287204
# 2                   2        175.935701            3.944174
# 3                   1        162.125531            9.677160
# 4                   0        137.033411            3.910004
# ...               ...               ...                 ...
# 20072               2        166.493709            4.461059
# 20073               2        166.493709            4.461059
# 20074              24        237.851418          117.259552
# 20075               2        152.572060            4.257806
# 20076              37         47.645860         1033.281638
#
#        hillshade_mean_1km  fs_area_1km  flow_accu_200m  lc_type1  mosq_now
# 0              179.374424     0.000000        1.000000        12  0.000000
# 1              180.413471     0.000000       17.093175        12 32.000000
# 2              180.097455     0.000000        1.251483         9  8.000000
# 3              179.975337     0.000000      130.702755        12 21.000000
# 4              179.788315     0.000000        5.966853        12  4.000000
# ...                   ...          ...             ...       ...       ...
# 20072          181.900818     0.972635       24.600078        13  1.000000
# 20073          181.900818     0.972635       24.600078        13 29.000000
# 20074          185.594028     0.000000        1.458380        10 36.000000
# 20075          180.662507     0.000000       98.440961        12 14.000000
# 20076          133.882178     0.000000        1.000000        12 21.000000
#
# [20077 rows x 47 columns]

# %%
# mosquito_data_nuts2 = mosquito_data.query(f"nuts2 == '{NUTS2_EL}'").copy()
# mosquito_data_nuts2.reset_index(inplace = True, drop = True)

# %%
# mosq_columns = mosquito_data_nuts2.columns
# mosq_columns

# %%
# columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#                 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#                 'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#                 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#                 'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#                 'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#                 'acc_rainfall_jan', 'mosq_now']

# columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#                 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#                 'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#                 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#                 'lst_night', 'acc_rainfall_1week', 'acc_rainfall_2week',
#                 'acc_rainfall_jan', 'mosq_now']

# mosquito_data_nuts2 = select_columns(mosquito_data_nuts2, columns_to_keep, columns_to_keep)

# mosquito_data_nuts2 = reshape_dataset(mosquito_data_nuts2,['x','y','dt_placement'])

# %%
mosquito_data = reshape_dataset(mosquito_data,['x','y','dt_placement'])

# %%
mosquito_data
# Out:
#               x         y dt_placement  mosq_now  month  year  month_sin  \
# 0     20.772536 38.932006   2024-06-23  7.000000      6  2024   0.000000
# 1     20.772536 38.932006   2024-07-08  3.000000      7  2024  -0.500000
# 2     20.772536 38.932006   2024-07-21  6.000000      7  2024  -0.500000
# 3     20.772536 38.932006   2024-08-04  3.000000      8  2024  -0.866025
# 4     20.772536 38.932006   2024-08-18  6.000000      8  2024  -0.866025
# ...         ...       ...          ...       ...    ...   ...        ...
# 15994 26.104770 35.203951   2018-10-14  0.000000     10  2018  -0.866025
# 15995 26.104770 35.203951   2018-10-28  0.000000     10  2018  -0.866025
# 15996 26.104770 35.203951   2018-11-13  0.000000     11  2018  -0.500000
# 15997 26.104770 35.203951   2018-11-18  0.000000     11  2018  -0.500000
# 15998 26.109237 35.210816   2019-06-19  0.000000      6  2019   0.000000
#
#        month_cos     ndvi      ndmi      ndwi     ndbi  ndvi_mean  ndmi_mean  \
# 0      -1.000000 0.137293 -0.110434 -0.215907 0.110434   0.192877  -0.117798
# 1      -0.866025 0.136116 -0.082246 -0.214591 0.082246   0.175884  -0.106449
# 2      -0.866025 0.213480 -0.007887 -0.276817 0.007887   0.268138  -0.045527
# 3      -0.500000 0.217528 -0.017574 -0.289106 0.017574   0.264545  -0.055466
# 4      -0.500000 0.117635 -0.102342 -0.195899 0.102342   0.146791  -0.135776
# ...          ...      ...       ...       ...      ...        ...        ...
# 15994   0.500000      NaN       NaN       NaN      NaN        NaN        NaN
# 15995   0.500000      NaN       NaN       NaN      NaN        NaN        NaN
# 15996   0.866025      NaN       NaN       NaN      NaN        NaN        NaN
# 15997   0.866025      NaN       NaN       NaN      NaN        NaN        NaN
# 15998  -1.000000      NaN       NaN       NaN      NaN        NaN        NaN
#
#        ndwi_mean  ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std   lst_day  \
# 0      -0.253381   0.117798  0.067813  0.037356  0.044288  0.037356 36.050000
# 1      -0.254290   0.106449  0.070887  0.041583  0.054521  0.041583 34.430000
# 2      -0.366267   0.045527  0.057812  0.033454  0.051669  0.033454 34.430000
# 3      -0.369753   0.055466  0.051267  0.033734  0.049228  0.033734 34.730000
# 4      -0.227748   0.135776  0.055008  0.043494  0.042582  0.043494 30.630000
# 0                0.000000         511.359452        2946.437192
# 1                0.000000         511.359452        2946.437192
# 2                0.000000         511.359452        2946.437192
# 3                0.000000         511.359452        2946.437192
# 4                0.000000         511.359452        2946.437192
# ...                   ...                ...                ...
# 15994            3.009228          42.905148         526.523091
# 15995           16.244287          42.905148         526.523091
# 15996           30.078372          42.905148         526.523091
# 15997          110.316012          42.905148         526.523091
# 15998            2.536395          42.905148         526.523091
#
#        slope_mean_1km  aspect_mean_200m  elevation_mean_1km  \
# 0                   2        145.794331            0.867053
# 1                   2        145.794331            0.867053
# 2                   2        145.794331            0.867053
# 3                   2        145.794331            0.867053
# 4                   2        145.794331            0.867053
# ...               ...               ...                 ...
# 15994               5         89.447569           18.500693
# 15995               5         89.447569           18.500693
# 15996               5         89.447569           18.500693
# 15997               5         89.447569           18.500693
# 15998               5         89.447569           18.500693
#
#        hillshade_mean_1km  fs_area_1km  flow_accu_200m  lc_type1
# 0              180.281098     0.475593        1.065210        13
# 1              180.281098     0.475593        1.065210        13
# 2              180.281098     0.475593        1.065210        13
# 3              180.281098     0.475593        1.065210        13
# 4              180.281098     0.475593        1.065210        13
# ...                   ...          ...             ...       ...
# 15994          174.624011     0.882946        8.670127        13
# 15995          174.624011     0.882946        8.670127        13
# 15996          174.624011     0.882946        8.670127        13
# 15997          174.624011     0.882946        8.670127        13
# 15998          174.624011     0.882946        8.670127        13
#
# [15999 rows x 47 columns]

# %%
#mosquito_data = feature_expansion(mosquito_data, env=True)

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data['mosq_now'])
plt.title('Count Distribution')
plt.show()

# %%
#quantile might change based on sns plots
mosq_quantilie = mosquito_data['mosq_now'].quantile(0.95)

mosquito_data['mosq_now'][mosquito_data['mosq_now'] > mosq_quantilie] = mosq_quantilie+1

plt.figure(figsize=(12,6))
sns.distplot(mosquito_data['mosq_now'])
plt.title('Count Distribution')
plt.show()

# %%
model_type = 'mosquito_regression'
mosquito_data = initializer(mosquito_data, model_type, 10, flag=True)

# %%
mosquito_data
# Out:
#               x         y dt_placement  month  year  month_sin  month_cos  \
# 0     20.772536 38.932006   2024-06-23      6  2024   0.000000  -1.000000
# 1     20.772536 38.932006   2024-07-08      7  2024  -0.500000  -0.866025
# 2     20.772536 38.932006   2024-07-21      7  2024  -0.500000  -0.866025
# 3     20.772536 38.932006   2024-08-04      8  2024  -0.866025  -0.500000
# 4     20.772536 38.932006   2024-08-18      8  2024  -0.866025  -0.500000
# ...         ...       ...          ...    ...   ...        ...        ...
# 15994 26.104770 35.203951   2018-10-14     10  2018  -0.866025   0.500000
# 15995 26.104770 35.203951   2018-10-28     10  2018  -0.866025   0.500000
# 15996 26.104770 35.203951   2018-11-13     11  2018  -0.500000   0.866025
# 15997 26.104770 35.203951   2018-11-18     11  2018  -0.500000   0.866025
# 15998 26.109237 35.210816   2019-06-19      6  2019   0.000000  -1.000000
#
#           ndvi      ndmi      ndwi     ndbi  ndvi_mean  ndmi_mean  ndwi_mean  \
# 0     0.137293 -0.110434 -0.215907 0.110434   0.192877  -0.117798  -0.253381
# 1     0.136116 -0.082246 -0.214591 0.082246   0.175884  -0.106449  -0.254290
# 2     0.213480 -0.007887 -0.276817 0.007887   0.268138  -0.045527  -0.366267
# 3     0.217528 -0.017574 -0.289106 0.017574   0.264545  -0.055466  -0.369753
# 4     0.117635 -0.102342 -0.195899 0.102342   0.146791  -0.135776  -0.227748
# ...        ...       ...       ...      ...        ...        ...        ...
# 15994      NaN       NaN       NaN      NaN        NaN        NaN        NaN
# 15995      NaN       NaN       NaN      NaN        NaN        NaN        NaN
# 15996      NaN       NaN       NaN      NaN        NaN        NaN        NaN
# 15997      NaN       NaN       NaN      NaN        NaN        NaN        NaN
# 15998      NaN       NaN       NaN      NaN        NaN        NaN        NaN
#
#        ndbi_mean  ndvi_std  ndmi_std  ndwi_std  ndbi_std   lst_day  lst_night  \
# 0       0.117798  0.067813  0.037356  0.044288  0.037356 36.050000  23.450000
# 1       0.106449  0.070887  0.041583  0.054521  0.041583 34.430000  24.770000
# 2       0.045527  0.057812  0.033454  0.051669  0.033454 34.430000  27.630000
# 3       0.055466  0.051267  0.033734  0.049228  0.033734 34.730000  25.610000
# 4       0.135776  0.055008  0.043494  0.042582  0.043494 30.630000  26.830000
# ...          ...       ...       ...       ...       ...       ...        ...
# 15994        NaN       NaN       NaN       NaN       NaN 25.190000  18.430000
# 15995        NaN       NaN       NaN       NaN       NaN 25.690000  15.090000
# 15996        NaN       NaN       NaN       NaN       NaN 19.350000   5.130000
# 15997        NaN       NaN       NaN       NaN       NaN 15.650000  10.650000
# 15998        NaN       NaN       NaN       NaN       NaN 34.150000  22.190000
#
#             lst  lst_jan_day_mean  lst_jan_night_mean  lst_jan_mean  \
# 0     29.750000         11.439333            7.011250      9.225292
# 1     29.600000         11.439333            7.011250      9.225292
# 2     31.030000         11.439333            7.011250      9.225292
# 3     30.170000         11.439333            7.011250      9.225292
# 4     28.730000         11.439333            7.011250      9.225292
# ...         ...               ...                 ...           ...
# 15994 21.810000         14.311333            8.223684     11.267509
# 15995 20.390000         14.311333            8.223684     11.267509
# 15996 12.240000         14.311333            8.223684     11.267509
# 15997 13.150000         14.311333            8.223684     11.267509
# 15998 28.170000         13.058889            7.437143     10.248016
#
#        lst_feb_day_mean  lst_feb_night_mean  lst_feb_mean  lst_mar_day_mean  \
# 0             11.695000            7.808333      9.751667         15.768947
# 1             11.695000            7.808333      9.751667         15.768947
# 2             11.695000            7.808333      9.751667         15.768947
# 3             11.695000            7.808333      9.751667         15.768947
# 4             11.695000            7.808333      9.751667         15.768947
# ...                 ...                 ...           ...               ...
# 15994         15.518889            8.602857     12.060873         19.768462
# 15995         15.518889            8.602857     12.060873         19.768462
# 15996         15.518889            8.602857     12.060873         19.768462
# 15997         15.518889            8.602857     12.060873         19.768462
# 15998         14.467778            7.990000     11.228889         18.416667
#
#        lst_mar_night_mean  lst_mar_mean  lst_apr_day_mean  lst_apr_night_mean  \
# 0               10.856667     13.312807         21.840000           13.966923
# 1               10.856667     13.312807         21.840000           13.966923
# 2               10.856667     13.312807         21.840000           13.966923
# 3               10.856667     13.312807         21.840000           13.966923
# 4               10.856667     13.312807         21.713158           13.958571
# ...                   ...           ...               ...                 ...
# 15994           11.120000     15.444231         25.725652           13.505000
# 15995           11.120000     15.444231         25.725652           13.505000
# 15996           11.120000     15.444231         25.725652           13.505000
# 15997           11.120000     15.444231         25.725652           13.505000
# 15998           10.677368     14.547018         20.210000           11.028889
#
#        lst_apr_mean  acc_rainfall_jan  acc_rainfall_1week  acc_rainfall_2week  \
# 0         17.903462        621.993077            0.000000            0.000000
# 1         17.903462        621.993077            0.000000            0.000000
# 2         17.903462        621.993077            0.000000            0.000000
# 3         17.903462        621.993077            0.000000            0.000000
# 4         17.835865        864.309978            0.000000            0.000000
# ...             ...               ...                 ...                 ...
# 15994     19.615326        574.486808            2.518828            3.009228
# 15995     19.615326        590.731095           13.140982           16.244287
# 15996     19.615326        621.499511           29.104984           30.078372
# 15997     19.615326        702.710539           81.233202          110.316012
# 15998     15.619444       1140.272119            1.069812            2.536395
#
#        distance_to_coast  distance_to_river  slope_mean_1km  aspect_mean_200m  \
# 0             511.359452        2946.437192               2        145.794331
# 1             511.359452        2946.437192               2        145.794331
# 2             511.359452        2946.437192               2        145.794331
# 3             511.359452        2946.437192               2        145.794331
# 4             511.359452        2946.437192               2        145.794331
# ...                  ...                ...             ...               ...
# 15994          42.905148         526.523091               5         89.447569
# 15995          42.905148         526.523091               5         89.447569
# 15996          42.905148         526.523091               5         89.447569
# 15997          42.905148         526.523091               5         89.447569
# 15998          42.905148         526.523091               5         89.447569
#
#        elevation_mean_1km  hillshade_mean_1km  fs_area_1km  flow_accu_200m  \
# 0                0.867053          180.281098     0.475593        1.065210
# 1                0.867053          180.281098     0.475593        1.065210
# 2                0.867053          180.281098     0.475593        1.065210
# 3                0.867053          180.281098     0.475593        1.065210
# 4                0.867053          180.281098     0.475593        1.065210
# ...                   ...                 ...          ...             ...
# 15994           18.500693          174.624011     0.882946        8.670127
# 15995           18.500693          174.624011     0.882946        8.670127
# 15996           18.500693          174.624011     0.882946        8.670127
# 15997           18.500693          174.624011     0.882946        8.670127
# 15998           18.500693          174.624011     0.882946        8.670127
#
#        lc_type1  mosq_now
# 0            13  7.000000
# 1            13  3.000000
# 2            13  6.000000
# 3            13  3.000000
# 4            13  6.000000
# ...         ...       ...
# 15994        13  0.000000
# 15995        13  0.000000
# 15996        13  0.000000
# 15997        13  0.000000
# 15998        13  0.000000
#
# [15999 rows x 47 columns]

# %%
mosquito_data.columns.sort_values()
# Out:
# Index(['acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan',
#        'aspect_mean_200m', 'distance_to_coast', 'distance_to_river',
#        'dt_placement', 'elevation_mean_1km', 'flow_accu_200m', 'fs_area_1km',
#        'hillshade_mean_1km', 'lc_type1', 'lst', 'lst_apr_day_mean',
#        'lst_apr_mean', 'lst_apr_night_mean', 'lst_day', 'lst_feb_day_mean',
#        'lst_feb_mean', 'lst_feb_night_mean', 'lst_jan_day_mean',
#        'lst_jan_mean', 'lst_jan_night_mean', 'lst_mar_day_mean',
#        'lst_mar_mean', 'lst_mar_night_mean', 'lst_night', 'month', 'month_cos',
#        'month_sin', 'mosq_now', 'ndbi', 'ndbi_mean', 'ndbi_std', 'ndmi',
#        'ndmi_mean', 'ndmi_std', 'ndvi', 'ndvi_mean', 'ndvi_std', 'ndwi',
#        'ndwi_mean', 'ndwi_std', 'slope_mean_1km', 'x', 'y', 'year'],
#       dtype='object')

# %%
mosquito_data.drop(columns=['x', 'y', 'month', 'year'], inplace=True)

# %%
missingno.matrix(mosquito_data)
# Out:
# <Axes: >

# %%
step = 15
only_env = True
case_title = 'NN mosq regression'
exp = False
date_col = 'dt_placement'
transform_target = True
augment = True
num_class = 1
hidden_layers = [264,128,128,64,32]
learning_rate = 0.001
epochs = 50
batch_size = 128
dropout = 0.2
# set the early stop argument as early_stop = (tolerance, min_delta)
early_stop = None
#set the transformation actions on the data. Options are 'augmentation', 'normalization', 'log', 'scaling'
transformation_list = ['scaling']
#set the data for embeddings e.g. data[['col', 'col2']]
embedded_data = None
#set the boolean for plotting feature importance (!very time consuming!)
fi = False

# %%
data = mosquito_data.copy()

# %%
missingno.matrix(data)
# Out:
# <Axes: >

# %%
imputer = KNNImputer()

features_for_impute = [ 'month_sin', 'month_cos',
                        'ndvi', 'ndmi', 'ndwi', 'ndbi', 
                        'ndvi_mean', 'ndmi_mean', 'ndwi_mean', 'ndbi_mean', 
                        'ndvi_std', 'ndmi_std', 'ndwi_std', 'ndbi_std', 
                        'lst_day', 'lst_night', 'lst',
                        'lst_jan_day_mean', 'lst_jan_night_mean', 'lst_jan_mean',
                        'lst_feb_day_mean', 'lst_feb_night_mean', 'lst_feb_mean',
                        'lst_mar_day_mean', 'lst_mar_night_mean', 'lst_mar_mean',
                        'lst_apr_day_mean', 'lst_apr_night_mean', 'lst_apr_mean',
                        'acc_rainfall_jan', 'acc_rainfall_1week', 'acc_rainfall_2week',
                        'distance_to_coast', 'distance_to_river', 'slope_mean_1km',
                        'aspect_mean_200m', 'elevation_mean_1km', 'hillshade_mean_1km',
                        'fs_area_1km', 'flow_accu_200m', 'lc_type1',]
#                        'null_island_distance', 'vert_distance', 'days_distance', 'summer_days_month']


mosquito_data_sub = mosquito_data[features_for_impute]

imputed_data = pd.DataFrame(imputer.fit_transform(mosquito_data_sub), columns = mosquito_data_sub.columns)


imputed_columns = [ 'ndvi', 'ndmi', 'ndwi', 'ndbi',
                    'ndvi_mean', 'ndmi_mean', 'ndwi_mean', 'ndbi_mean', 
                    'ndvi_std', 'ndmi_std', 'ndwi_std', 'ndbi_std', 
                    'lst_day', 'lst_night', 'lst',
                    'lst_jan_day_mean', 'lst_jan_night_mean', 'lst_jan_mean',
                    'lst_feb_day_mean', 'lst_feb_night_mean', 'lst_feb_mean',
                    'lst_mar_day_mean', 'lst_mar_night_mean', 'lst_mar_mean',
                    'lst_apr_day_mean', 'lst_apr_night_mean', 'lst_apr_mean',
                    'flow_accu_200m']

mosquito_data[imputed_columns] = imputed_data[imputed_columns]

data_env = mosquito_data.copy()

# %%
# data_env = data
# data_env = data_env.dropna().reset_index(drop=True)

# %%
missingno.matrix(data_env)
# Out:
# <Axes: >

# %%
model = FeedforwardNeuralNetModel(num_features=len(data_env.iloc[0,:])-2, num_class=num_class,
                                      hidden_layers = hidden_layers, model_type=model_type,
                                      learning_rate = learning_rate, epochs = epochs, batch_size = batch_size,
                                      dropout = dropout, embedding_data=embedded_data, 
                                      transformation_list=transformation_list, early_stop = early_stop, 
                                      l1_weight=0, l2_weight=0, weights=False)

# %%
fitted_scaler, fitted_model = evaluate_nn(model, data_env, test_size = 0.2, fi = fi)
# Out:
# Epoch 001: | Train Loss: 59695.89857 | Val Loss: 56172.18594 | Train Acc: 124.754| Val Acc: 119.438
# Epoch 002: | Train Loss: 58279.97660 | Val Loss: 54649.59039 | Train Acc: 123.144| Val Acc: 117.681
# Epoch 003: | Train Loss: 56784.86055 | Val Loss: 52947.77852 | Train Acc: 121.407| Val Acc: 115.677
# Epoch 004: | Train Loss: 54994.06271 | Val Loss: 51114.48461 | Train Acc: 119.231| Val Acc: 113.374
# Epoch 005: | Train Loss: 52879.21748 | Val Loss: 48685.65289 | Train Acc: 116.706| Val Acc: 110.177
# Epoch 006: | Train Loss: 50479.12541 | Val Loss: 45968.43313 | Train Acc: 113.692| Val Acc: 106.828
# Epoch 007: | Train Loss: 47709.98820 | Val Loss: 43086.27898 | Train Acc: 110.256| Val Acc: 103.235
# Epoch 008: | Train Loss: 44616.90807 | Val Loss: 39815.85852 | Train Acc: 106.406| Val Acc: 99.277
# Epoch 009: | Train Loss: 40994.65699 | Val Loss: 36325.57945 | Train Acc: 102.284| Val Acc: 94.958
# Epoch 010: | Train Loss: 37244.14118 | Val Loss: 32945.56289 | Train Acc: 97.972| Val Acc: 90.794
# Epoch 011: | Train Loss: 33836.31441 | Val Loss: 29558.09598 | Train Acc: 93.905| Val Acc: 87.474
# Epoch 012: | Train Loss: 30666.89490 | Val Loss: 26937.69008 | Train Acc: 90.498| Val Acc: 85.084
# Epoch 013: | Train Loss: 27737.24848 | Val Loss: 24507.42316 | Train Acc: 87.329| Val Acc: 83.268
# Epoch 014: | Train Loss: 25239.71073 | Val Loss: 23094.52285 | Train Acc: 84.463| Val Acc: 82.207
# Epoch 015: | Train Loss: 23160.77356 | Val Loss: 21892.37406 | Train Acc: 82.488| Val Acc: 81.309
# Epoch 016: | Train Loss: 21772.76503 | Val Loss: 21278.94750 | Train Acc: 81.427| Val Acc: 80.575
# Epoch 042: | Train Loss: 14100.88002 | Val Loss: 20481.62434 | Train Acc: 71.325| Val Acc: 82.810
# Epoch 043: | Train Loss: 14195.79489 | Val Loss: 20660.92758 | Train Acc: 71.095| Val Acc: 83.037
# Epoch 044: | Train Loss: 14240.66556 | Val Loss: 20724.81961 | Train Acc: 70.752| Val Acc: 82.076
# Epoch 045: | Train Loss: 13936.88481 | Val Loss: 20910.79215 | Train Acc: 70.468| Val Acc: 82.434
# Epoch 046: | Train Loss: 13732.03376 | Val Loss: 21036.17500 | Train Acc: 69.823| Val Acc: 82.874
# Epoch 047: | Train Loss: 13768.83713 | Val Loss: 20573.64289 | Train Acc: 70.150| Val Acc: 83.065
# Epoch 048: | Train Loss: 13706.51759 | Val Loss: 20474.04348 | Train Acc: 69.381| Val Acc: 81.266
# Epoch 049: | Train Loss: 13289.51369 | Val Loss: 21051.29527 | Train Acc: 68.833| Val Acc: 82.687
# Epoch 050: | Train Loss: 13489.01901 | Val Loss: 20635.38734 | Train Acc: 69.382| Val Acc: 81.634
# MAE on train set:  61.60650832096257
# min prediction: 1.0
# max prediction: 788.0999999999985
#
# MAE on test set:  81.63218749999993
# Error <= 3: 6.69 %
# min prediction: 2.0
# max prediction: 788.0999999999985

# %%
# mosquito_data_nuts2 = initializer(mosquito_data,2,10,25,step,[date_col], env=only_env, date_column = date_col, mosq_column='mosq_now')

# %%
train_X, train_y, test_X, test_y, scaler = transformations_nn(mosquito_data, model_type = model_type, split = 0.25, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

model = FeedforwardNeuralNetModel(num_features=len(train_X[0]), num_class=1, hidden_layers = hidden_layers, dropout=dropout, model_type=model_type, transform = transform_target)

# %%
train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 100, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = True)

# %%
metrics(train, test, threshold=30)

# %%
validation_plots(test,model_type)

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.000001, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.000001, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)

# %%
pickle.dump(model, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_Mamoth_NN.pt', 'wb'))
pickle.dump(imputer, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_KNN_Imputer.pkl', 'wb'))
pickle.dump(scaler, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_Scaler.pkl', 'wb'))
