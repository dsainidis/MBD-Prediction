# %%
import pandas as pd
import missingno

enc = 'utf-8'

# %%
df_loading = pd.read_csv('../data/GR_EUROSTAT_Trade_Loading_Raw.csv', encoding=enc)
df_loading.head()
# Out:
#   STRUCTURE                STRUCTURE_ID  \
# 0  dataflow  ESTAT:ROAD_GO_NA_RL3G(1.0)
# 1  dataflow  ESTAT:ROAD_GO_NA_RL3G(1.0)
# 2  dataflow  ESTAT:ROAD_GO_NA_RL3G(1.0)
# 3  dataflow  ESTAT:ROAD_GO_NA_RL3G(1.0)
# 4  dataflow  ESTAT:ROAD_GO_NA_RL3G(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency  \
# 0  National road freight transport by region of l...    A         Annual
# 1  National road freight transport by region of l...    A         Annual
# 2  National road freight transport by region of l...    A         Annual
# 3  National road freight transport by region of l...    A         Annual
# 4  National road freight transport by region of l...    A         Annual
#
#   nst07  \
# 0  GT01
# 1  GT01
# 2  GT01
# 3  GT01
# 4  GT01
#
#   Standard goods classification for transport statistics (NST 2007, 20 group)  \
# 0  Products of agriculture, hunting, and forestry...
# 1  Products of agriculture, hunting, and forestry...
# ...

# %%
df_loading.drop(columns=['STRUCTURE', 'STRUCTURE_NAME', 'Time frequency', 'Standard goods classification for transport statistics (NST 2007, 20 group)', 'Unit of measure', 'Geopolitical entity (reporting)', 'Time', 'Observation value', 'Observation status (Flag) V2 structure','CONF_STATUS','Confidentiality status (flag)'], inplace=True)
df_loading.rename(columns={'STRUCTURE_ID': 'DATAFLOW'}, inplace=True)
df_loading
# Out:
#                           DATAFLOW freq  nst07   unit    geo  TIME_PERIOD  \
# 0       ESTAT:ROAD_GO_NA_RL3G(1.0)    A   GT01  THS_T  AT111         2008
# 1       ESTAT:ROAD_GO_NA_RL3G(1.0)    A   GT01  THS_T  AT111         2009
# 2       ESTAT:ROAD_GO_NA_RL3G(1.0)    A   GT01  THS_T  AT111         2010
# 3       ESTAT:ROAD_GO_NA_RL3G(1.0)    A   GT01  THS_T  AT111         2011
# 4       ESTAT:ROAD_GO_NA_RL3G(1.0)    A   GT01  THS_T  AT111         2012
# ...                            ...  ...    ...    ...    ...          ...
# 409818  ESTAT:ROAD_GO_NA_RL3G(1.0)    A  TOTAL  THS_T  UKN15         2020
# 409819  ESTAT:ROAD_GO_NA_RL3G(1.0)    A  TOTAL  THS_T  UKN16         2018
# 409820  ESTAT:ROAD_GO_NA_RL3G(1.0)    A  TOTAL  THS_T  UKN16         2019
# 409821  ESTAT:ROAD_GO_NA_RL3G(1.0)    A  TOTAL  THS_T  UKN16         2020
# 409822  ESTAT:ROAD_GO_NA_RL3G(1.0)    A    UNK  THS_T  ME000         2017
#
#         OBS_VALUE OBS_FLAG
# 0            79.0      NaN
# ...

# %%
df_unloading = pd.read_csv('../data/GR_EUROSTAT_Trade_Unloading_Raw.csv', encoding=enc)
df_unloading.head()
# Out:
#   STRUCTURE                STRUCTURE_ID  \
# 0  dataflow  ESTAT:ROAD_GO_NA_RU3G(1.0)
# 1  dataflow  ESTAT:ROAD_GO_NA_RU3G(1.0)
# 2  dataflow  ESTAT:ROAD_GO_NA_RU3G(1.0)
# 3  dataflow  ESTAT:ROAD_GO_NA_RU3G(1.0)
# 4  dataflow  ESTAT:ROAD_GO_NA_RU3G(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency  \
# 0  National road freight transport by region of u...    A         Annual
# 1  National road freight transport by region of u...    A         Annual
# 2  National road freight transport by region of u...    A         Annual
# 3  National road freight transport by region of u...    A         Annual
# 4  National road freight transport by region of u...    A         Annual
#
#   nst07  \
# 0  GT01
# 1  GT01
# 2  GT01
# 3  GT01
# 4  GT01
#
#   Standard goods classification for transport statistics (NST 2007, 20 group)  \
# 0  Products of agriculture, hunting, and forestry...
# 1  Products of agriculture, hunting, and forestry...
# ...

# %%
df_unloading.drop(columns=['STRUCTURE', 'STRUCTURE_NAME', 'Time frequency', 'Standard goods classification for transport statistics (NST 2007, 20 group)', 'Unit of measure', 'Geopolitical entity (reporting)', 'Time', 'Observation value', 'Observation status (Flag) V2 structure','CONF_STATUS','Confidentiality status (flag)'], inplace=True)
df_unloading.rename(columns={'STRUCTURE_ID': 'DATAFLOW'}, inplace=True)
df_unloading
# Out:
#                           DATAFLOW freq  nst07   unit    geo  TIME_PERIOD  \
# 0       ESTAT:ROAD_GO_NA_RU3G(1.0)    A   GT01  THS_T  AT111         2008
# 1       ESTAT:ROAD_GO_NA_RU3G(1.0)    A   GT01  THS_T  AT111         2009
# 2       ESTAT:ROAD_GO_NA_RU3G(1.0)    A   GT01  THS_T  AT111         2010
# 3       ESTAT:ROAD_GO_NA_RU3G(1.0)    A   GT01  THS_T  AT111         2011
# 4       ESTAT:ROAD_GO_NA_RU3G(1.0)    A   GT01  THS_T  AT111         2012
# ...                            ...  ...    ...    ...    ...          ...
# 420284  ESTAT:ROAD_GO_NA_RU3G(1.0)    A  TOTAL  THS_T  UKN15         2020
# 420285  ESTAT:ROAD_GO_NA_RU3G(1.0)    A  TOTAL  THS_T  UKN16         2018
# 420286  ESTAT:ROAD_GO_NA_RU3G(1.0)    A  TOTAL  THS_T  UKN16         2019
# 420287  ESTAT:ROAD_GO_NA_RU3G(1.0)    A  TOTAL  THS_T  UKN16         2020
# 420288  ESTAT:ROAD_GO_NA_RU3G(1.0)    A    UNK  THS_T  ME000         2017
#
#         OBS_VALUE OBS_FLAG
# 0            59.0      NaN
# ...

# %%
df_loading.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409823 entries, 0 to 409822
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   DATAFLOW     409823 non-null  object
#  1   freq         409823 non-null  object
#  2   nst07        409823 non-null  object
#  3   unit         409823 non-null  object
#  4   geo          409823 non-null  object
#  5   TIME_PERIOD  409823 non-null  int64
#  6   OBS_VALUE    319672 non-null  float64
#  7   OBS_FLAG     90153 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 25.0+ MB

# %%
df_unloading.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420289 entries, 0 to 420288
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   DATAFLOW     420289 non-null  object
#  1   freq         420289 non-null  object
#  2   nst07        420289 non-null  object
#  3   unit         420289 non-null  object
#  4   geo          420289 non-null  object
#  5   TIME_PERIOD  420289 non-null  int64
#  6   OBS_VALUE    331174 non-null  float64
#  7   OBS_FLAG     89118 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 25.7+ MB

# %%
df_loading.DATAFLOW.unique()
# Out:
# array(['ESTAT:ROAD_GO_NA_RL3G(1.0)'], dtype=object)

# %%
df_unloading.DATAFLOW.unique()
# Out:
# array(['ESTAT:ROAD_GO_NA_RU3G(1.0)'], dtype=object)

# %%
df_loading.freq.unique()
# Out:
# array(['A'], dtype=object)

# %%
df_unloading.freq.unique()
# Out:
# array(['A'], dtype=object)

# %%
df_loading.nst07.unique()
# Out:
# array(['GT01', 'GT02', 'GT03', 'GT04', 'GT05', 'GT06', 'GT07', 'GT08',
#        'GT09', 'GT10', 'GT11', 'GT12', 'GT13', 'GT14', 'GT15', 'GT16',
#        'GT17', 'GT18', 'GT19', 'GT20', 'TOTAL', 'UNK'], dtype=object)

# %%
df_unloading.nst07.unique()
# Out:
# array(['GT01', 'GT02', 'GT03', 'GT04', 'GT05', 'GT06', 'GT07', 'GT08',
#        'GT09', 'GT10', 'GT11', 'GT12', 'GT13', 'GT14', 'GT15', 'GT16',
#        'GT17', 'GT18', 'GT19', 'GT20', 'TOTAL', 'UNK'], dtype=object)

# %%
df_loading.unit.unique()
# Out:
# array(['THS_T'], dtype=object)

# %%
df_unloading.unit.unique()
# Out:
# array(['THS_T'], dtype=object)

# %%
df_loading.TIME_PERIOD.unique()
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020, 2021, 2022, 2023, 2024], dtype=int64)

# %%
df_unloading.TIME_PERIOD.unique()
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020, 2021, 2022, 2023, 2024], dtype=int64)

# %%
df_loading_gr = df_loading.query("geo.str.match('EL\d{3}')").copy()

# %%
df_unloading_gr = df_unloading.query("geo.str.match('EL\d{3}')").copy()

# %%
df_loading_gr = df_loading_gr[df_loading_gr.nst07 == 'TOTAL'].copy()

# %%
df_unloading_gr = df_unloading_gr[df_unloading_gr.nst07 == 'TOTAL'].copy()

# %%
df_loading_gr.drop(columns=['DATAFLOW', 'freq', 'nst07', 'unit', 'OBS_FLAG'], inplace=True)

# %%
df_unloading_gr.drop(columns=['DATAFLOW', 'freq', 'nst07', 'unit', 'OBS_FLAG'], inplace=True)

# %%
df_loading_gr.reset_index(drop=True, inplace=True)

# %%
df_unloading_gr.reset_index(drop=True, inplace=True)

# %%
df_loading_gr
# Out:
#        geo  TIME_PERIOD  OBS_VALUE
# 0    EL111         2008     6704.0
# 1    EL111         2009     3031.0
# 2    EL111         2010     2663.0
# 3    EL111         2011     4163.0
# 4    EL111         2012     4379.0
# ..     ...          ...        ...
# 870  EL653         2020     4572.0
# 871  EL653         2021     3040.0
# 872  EL653         2022    11830.0
# 873  EL653         2023     3092.0
# 874  EL653         2024     3357.0
#
# [875 rows x 3 columns]

# %%
df_unloading_gr
# Out:
#        geo  TIME_PERIOD  OBS_VALUE
# 0    EL111         2008     7125.0
# 1    EL111         2009     3303.0
# 2    EL111         2010     2085.0
# 3    EL111         2011     4212.0
# 4    EL111         2012     5029.0
# ..     ...          ...        ...
# 870  EL653         2020     4962.0
# 871  EL653         2021     3666.0
# 872  EL653         2022    12294.0
# 873  EL653         2023     3999.0
# 874  EL653         2024     4032.0
#
# [875 rows x 3 columns]

# %%
df_out_loading = df_loading_gr.rename(columns={"geo": "NUTS3_CODE", "TIME_PERIOD": "YEAR", "OBS_VALUE": "L_TOTAL"}, errors="raise")

# %%
df_out_unloading = df_unloading_gr.rename(columns={"geo": "NUTS3_CODE", "TIME_PERIOD": "YEAR", "OBS_VALUE": "UNL_TOTAL"}, errors="raise")

# %%
missingno.matrix(df_out_loading)
# Out:
# <Axes: >

# %%
missingno.matrix(df_out_unloading)
# Out:
# <Axes: >

# %%
df_out = pd.merge(df_out_loading, df_out_unloading,  how='left', on=['NUTS3_CODE', 'YEAR'])

# %%
missingno.matrix(df_out)
# Out:
# <Axes: >

# %%
nuts3_all = df_out.NUTS3_CODE.unique()

# %%
df_out.to_csv('../data/GR_EUROSTAT_Trade_Processed.csv', index=False)
