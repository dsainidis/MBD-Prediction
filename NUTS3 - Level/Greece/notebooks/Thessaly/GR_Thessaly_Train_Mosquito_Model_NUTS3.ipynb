# %% [markdown]
# ## Produces **Mosquito Predictions** for a specific region using MAMOTH ##

# %%
import pandas as pd
import datetime
import math
import numpy as np
import missingno
import json
from statistics import mean
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
import sys
import pickle

sys.path.insert(0, "../../../../Mamoth")
sys.path.insert(0, "../../../../Modules")

from utils import *

from Preprocessing_Module import read_data, select_columns, reshape_dataset
from Initializer_Module import initializer
from Neural_Network_Module import Dataset, transformations, FeedforwardNeuralNetModel, train_nn, give_predictions
from Model_Validation_Module import validation_plots, metrics

enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 100
pd.options.display.float_format = lambda x: '%.6f' % x

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
NUTS0 = 'GR'
NUTS2 = 'Thessaly'
NUTS2_EL = 'θεσσαλιας'

# %%
mosquito_data = read_data(f'../../data/{NUTS0}_MSQ_culex_2011-2022_processed.csv')
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
mosquito_data.nuts2.unique()
# Out:
# array(['κεντρικης μακεδονιας', 'θεσσαλιας', 'κρητης', 'δυτικης ελλαδας'],
#       dtype=object)

# %%
mosquito_data_nuts2 = mosquito_data.query(f"nuts2 == '{NUTS2_EL}'").copy()
mosquito_data_nuts2.reset_index(inplace = True, drop = True)

# %%
mosq_columns = mosquito_data_nuts2.columns
mosq_columns
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
                'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
                'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
                'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
                'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
                'acc_rainfall_jan', 'mosq_now']

# columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#                 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#                 'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#                 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#                 'lst_night', 'acc_rainfall_1week', 'acc_rainfall_2week',
#                 'acc_rainfall_jan', 'mosq_now']

mosquito_data_nuts2 = select_columns(mosquito_data_nuts2, columns_to_keep, columns_to_keep)

mosquito_data_nuts2 = reshape_dataset(mosquito_data_nuts2,['x','y','dt_placement'])

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()

# %%
#quantile might change based on sns plots
mosq_quantilie = mosquito_data_nuts2['mosq_now'].quantile(0.95)

mosquito_data_nuts2['mosq_now'][mosquito_data_nuts2['mosq_now'] > mosq_quantilie] = mosq_quantilie+1

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <Axes: >

# %%
imputer = KNNImputer()

features_for_impute = ['x', 'y', 'day', 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 
                        'lst_day', 'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean', 'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan']

# features_for_impute = ['x', 'y', 'day', 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#                         'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 
#                         'lst_day', 'lst_night', 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan']

mosquito_data_sub = mosquito_data_nuts2[features_for_impute]

imputed_data = pd.DataFrame(imputer.fit_transform(mosquito_data_sub), columns = mosquito_data_sub.columns)

# %%
# imputed_columns = ['ndvi','ndmi', 'ndwi', 'ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std', 'ndmi_std','ndwi_std','ndbi_std',
#                    'lst_day','lst_night']

imputed_columns = ['ndvi','ndmi', 'ndwi', 'ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std', 'ndmi_std','ndwi_std','ndbi_std',
                   'lst_day','lst_night','lst_jan_mean','lst_feb_mean','lst_mar_mean','lst_apr_mean']

mosquito_data_nuts2[imputed_columns] = imputed_data[imputed_columns]

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <Axes: >

# %%
step = 15
only_env = True
case_title = 'NN mosq regression'
exp = False
date_col = 'dt_placement'
model_type = 'mosquito_regression'
transform_target = True
augment = True

# %%
mosquito_data_nuts2 = initializer(mosquito_data_nuts2,2,10,25,step,[date_col], env=only_env, date_column = date_col, mosq_column='mosq_now')
# Out:
# Bounds: [  0.    16.5  255.15]

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.25, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

model = FeedforwardNeuralNetModel(num_features=len(train_X[0]), num_class=1, hidden_layers = [264,128,128,64], dropout=0.2, model_type=model_type, transform = transform_target)

# %%
train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)
# Out:
# Epoch 001: | Train Loss: 41.79371 | Val Loss: 32.19179 | Train Acc: 4.435| Val Acc: 4.028
# Epoch 002: | Train Loss: 37.32095 | Val Loss: 29.08301 | Train Acc: 3.541| Val Acc: 3.443
# Epoch 003: | Train Loss: 36.04838 | Val Loss: 27.21765 | Train Acc: 3.220| Val Acc: 2.837
# Epoch 004: | Train Loss: 34.90155 | Val Loss: 24.85656 | Train Acc: 2.975| Val Acc: 2.564
# Epoch 005: | Train Loss: 34.23423 | Val Loss: 23.66324 | Train Acc: 2.881| Val Acc: 2.264
# Epoch 006: | Train Loss: 34.20779 | Val Loss: 23.56070 | Train Acc: 2.884| Val Acc: 2.224
# Epoch 007: | Train Loss: 33.67248 | Val Loss: 24.39735 | Train Acc: 2.818| Val Acc: 2.362
# Epoch 008: | Train Loss: 33.28452 | Val Loss: 24.64461 | Train Acc: 2.768| Val Acc: 2.162
# Epoch 009: | Train Loss: 33.03157 | Val Loss: 23.79029 | Train Acc: 2.772| Val Acc: 1.983
# Epoch 010: | Train Loss: 32.95853 | Val Loss: 23.41019 | Train Acc: 2.719| Val Acc: 1.966
# Epoch 011: | Train Loss: 32.70025 | Val Loss: 23.52475 | Train Acc: 2.699| Val Acc: 1.965
# Epoch 012: | Train Loss: 32.63052 | Val Loss: 23.64232 | Train Acc: 2.676| Val Acc: 2.145
# Epoch 013: | Train Loss: 32.87098 | Val Loss: 23.23346 | Train Acc: 2.699| Val Acc: 1.985
# Epoch 014: | Train Loss: 32.47169 | Val Loss: 23.02506 | Train Acc: 2.569| Val Acc: 1.802
# Epoch 015: | Train Loss: 32.46755 | Val Loss: 23.13529 | Train Acc: 2.634| Val Acc: 1.814
# Epoch 016: | Train Loss: 32.31256 | Val Loss: 23.70247 | Train Acc: 2.573| Val Acc: 1.995
# Epoch 017: | Train Loss: 32.11252 | Val Loss: 23.66772 | Train Acc: 2.570| Val Acc: 1.957
# Epoch 018: | Train Loss: 32.13162 | Val Loss: 23.10250 | Train Acc: 2.534| Val Acc: 1.763
# Epoch 019: | Train Loss: 31.93465 | Val Loss: 23.08353 | Train Acc: 2.530| Val Acc: 1.777
# Epoch 020: | Train Loss: 31.75617 | Val Loss: 23.96940 | Train Acc: 2.482| Val Acc: 1.806
# Epoch 021: | Train Loss: 31.79991 | Val Loss: 24.51262 | Train Acc: 2.498| Val Acc: 2.008
# Epoch 022: | Train Loss: 31.81836 | Val Loss: 24.80819 | Train Acc: 2.449| Val Acc: 1.977
# Epoch 023: | Train Loss: 31.82041 | Val Loss: 24.66258 | Train Acc: 2.507| Val Acc: 1.971
# Epoch 024: | Train Loss: 31.60035 | Val Loss: 23.75723 | Train Acc: 2.403| Val Acc: 1.948
# Epoch 025: | Train Loss: 31.71813 | Val Loss: 23.98113 | Train Acc: 2.406| Val Acc: 1.791
# Epoch 026: | Train Loss: 31.47013 | Val Loss: 24.53539 | Train Acc: 2.402| Val Acc: 1.820
# Epoch 027: | Train Loss: 31.88233 | Val Loss: 23.27138 | Train Acc: 2.414| Val Acc: 1.967
# Epoch 028: | Train Loss: 31.26336 | Val Loss: 22.87890 | Train Acc: 2.380| Val Acc: 1.937
# Epoch 029: | Train Loss: 31.80521 | Val Loss: 22.54438 | Train Acc: 2.382| Val Acc: 1.579
# Epoch 030: | Train Loss: 31.24063 | Val Loss: 22.78618 | Train Acc: 2.352| Val Acc: 1.596
# Epoch 031: | Train Loss: 31.21919 | Val Loss: 22.93298 | Train Acc: 2.353| Val Acc: 1.784
# Epoch 032: | Train Loss: 31.17046 | Val Loss: 22.92470 | Train Acc: 2.336| Val Acc: 1.632
# Epoch 033: | Train Loss: 31.28889 | Val Loss: 23.04535 | Train Acc: 2.365| Val Acc: 1.757
# Epoch 034: | Train Loss: 31.37380 | Val Loss: 23.71561 | Train Acc: 2.329| Val Acc: 1.773
# Epoch 035: | Train Loss: 31.75275 | Val Loss: 23.95563 | Train Acc: 2.327| Val Acc: 1.945
# Epoch 036: | Train Loss: 31.07050 | Val Loss: 23.78937 | Train Acc: 2.316| Val Acc: 1.959
# Epoch 037: | Train Loss: 30.97610 | Val Loss: 23.54649 | Train Acc: 2.280| Val Acc: 1.939
# Epoch 038: | Train Loss: 30.93215 | Val Loss: 23.32725 | Train Acc: 2.288| Val Acc: 1.957
# Epoch 039: | Train Loss: 31.13775 | Val Loss: 23.35387 | Train Acc: 2.292| Val Acc: 1.953
# Epoch 040: | Train Loss: 30.81877 | Val Loss: 23.41714 | Train Acc: 2.252| Val Acc: 1.956
# Epoch 041: | Train Loss: 30.96874 | Val Loss: 23.22938 | Train Acc: 2.251| Val Acc: 1.765
# Epoch 042: | Train Loss: 30.86997 | Val Loss: 23.17608 | Train Acc: 2.209| Val Acc: 1.737
# Epoch 043: | Train Loss: 30.97269 | Val Loss: 23.25348 | Train Acc: 2.276| Val Acc: 1.914
# Epoch 044: | Train Loss: 30.97297 | Val Loss: 22.98992 | Train Acc: 2.244| Val Acc: 1.756
# Epoch 045: | Train Loss: 30.94767 | Val Loss: 23.19588 | Train Acc: 2.236| Val Acc: 1.793
# Epoch 046: | Train Loss: 31.08912 | Val Loss: 22.83601 | Train Acc: 2.280| Val Acc: 1.764
# Epoch 047: | Train Loss: 30.98084 | Val Loss: 22.93012 | Train Acc: 2.297| Val Acc: 1.757
# Epoch 048: | Train Loss: 30.73843 | Val Loss: 23.35106 | Train Acc: 2.231| Val Acc: 1.884
# Epoch 049: | Train Loss: 30.87390 | Val Loss: 23.76091 | Train Acc: 2.242| Val Acc: 1.902
# Epoch 050: | Train Loss: 30.57787 | Val Loss: 24.04832 | Train Acc: 2.180| Val Acc: 1.919
# Epoch 051: | Train Loss: 30.67588 | Val Loss: 24.19661 | Train Acc: 2.176| Val Acc: 1.919
# Epoch 052: | Train Loss: 31.17901 | Val Loss: 24.16416 | Train Acc: 2.218| Val Acc: 1.914
# Epoch 053: | Train Loss: 30.79167 | Val Loss: 24.59769 | Train Acc: 2.209| Val Acc: 2.094
# Epoch 054: | Train Loss: 31.02863 | Val Loss: 24.95350 | Train Acc: 2.243| Val Acc: 2.117
# Epoch 055: | Train Loss: 31.04045 | Val Loss: 24.77956 | Train Acc: 2.299| Val Acc: 2.104
# Epoch 056: | Train Loss: 30.72105 | Val Loss: 23.83774 | Train Acc: 2.205| Val Acc: 1.908
# Epoch 057: | Train Loss: 30.74093 | Val Loss: 23.83753 | Train Acc: 2.202| Val Acc: 1.894
# Epoch 058: | Train Loss: 30.67670 | Val Loss: 24.05951 | Train Acc: 2.187| Val Acc: 1.910
# Epoch 059: | Train Loss: 30.69520 | Val Loss: 24.79481 | Train Acc: 2.184| Val Acc: 2.090
# Epoch 060: | Train Loss: 30.82333 | Val Loss: 24.79780 | Train Acc: 2.203| Val Acc: 2.076
# Epoch 061: | Train Loss: 30.54452 | Val Loss: 23.94146 | Train Acc: 2.150| Val Acc: 2.060
# Epoch 062: | Train Loss: 30.91164 | Val Loss: 22.79579 | Train Acc: 2.232| Val Acc: 1.732
# Epoch 063: | Train Loss: 30.74079 | Val Loss: 22.73744 | Train Acc: 2.229| Val Acc: 1.575
# Epoch 064: | Train Loss: 30.89170 | Val Loss: 22.86657 | Train Acc: 2.230| Val Acc: 1.743
# Epoch 065: | Train Loss: 30.68204 | Val Loss: 23.03183 | Train Acc: 2.169| Val Acc: 1.905
# Epoch 066: | Train Loss: 30.66833 | Val Loss: 23.23823 | Train Acc: 2.191| Val Acc: 1.724
# Epoch 067: | Train Loss: 30.51724 | Val Loss: 23.18324 | Train Acc: 2.157| Val Acc: 1.721
# Epoch 068: | Train Loss: 30.54325 | Val Loss: 23.11644 | Train Acc: 2.178| Val Acc: 1.555
# Epoch 069: | Train Loss: 30.56284 | Val Loss: 23.09076 | Train Acc: 2.195| Val Acc: 1.547
# Epoch 070: | Train Loss: 30.68891 | Val Loss: 23.13316 | Train Acc: 2.163| Val Acc: 1.541
# Epoch 071: | Train Loss: 30.57692 | Val Loss: 23.10943 | Train Acc: 2.144| Val Acc: 1.535
# Epoch 072: | Train Loss: 30.39629 | Val Loss: 23.39698 | Train Acc: 2.105| Val Acc: 1.578
# Epoch 073: | Train Loss: 30.66115 | Val Loss: 23.43441 | Train Acc: 2.184| Val Acc: 1.580
# Epoch 074: | Train Loss: 30.62605 | Val Loss: 23.32072 | Train Acc: 2.143| Val Acc: 1.566
# Epoch 075: | Train Loss: 30.36689 | Val Loss: 23.28125 | Train Acc: 2.122| Val Acc: 1.522
# Epoch 076: | Train Loss: 30.42111 | Val Loss: 23.28878 | Train Acc: 2.064| Val Acc: 1.683
# Epoch 077: | Train Loss: 30.37263 | Val Loss: 23.32263 | Train Acc: 2.114| Val Acc: 1.687
# Epoch 078: | Train Loss: 30.44534 | Val Loss: 23.44275 | Train Acc: 2.107| Val Acc: 1.705
# Epoch 079: | Train Loss: 30.82382 | Val Loss: 23.53181 | Train Acc: 2.131| Val Acc: 1.753
# Epoch 080: | Train Loss: 30.45163 | Val Loss: 23.55287 | Train Acc: 2.129| Val Acc: 1.716
# Epoch 081: | Train Loss: 30.43527 | Val Loss: 23.64912 | Train Acc: 2.110| Val Acc: 1.695
# Epoch 082: | Train Loss: 30.44262 | Val Loss: 23.44365 | Train Acc: 2.145| Val Acc: 1.524
# Epoch 083: | Train Loss: 30.34124 | Val Loss: 23.36659 | Train Acc: 2.127| Val Acc: 1.547
# Epoch 084: | Train Loss: 30.34999 | Val Loss: 23.21641 | Train Acc: 2.097| Val Acc: 1.547
# Epoch 085: | Train Loss: 30.28249 | Val Loss: 23.12390 | Train Acc: 2.053| Val Acc: 1.686
# Epoch 086: | Train Loss: 30.50090 | Val Loss: 23.37619 | Train Acc: 2.130| Val Acc: 1.868
# Epoch 087: | Train Loss: 30.35638 | Val Loss: 23.37366 | Train Acc: 2.100| Val Acc: 1.875
# Epoch 088: | Train Loss: 30.19548 | Val Loss: 23.50543 | Train Acc: 2.061| Val Acc: 1.861
# Epoch 089: | Train Loss: 30.43130 | Val Loss: 23.16815 | Train Acc: 2.085| Val Acc: 1.681
# Epoch 090: | Train Loss: 30.30180 | Val Loss: 23.24508 | Train Acc: 2.071| Val Acc: 1.709
# Epoch 091: | Train Loss: 30.42373 | Val Loss: 23.11807 | Train Acc: 2.085| Val Acc: 1.706
# Epoch 092: | Train Loss: 30.42095 | Val Loss: 22.95805 | Train Acc: 2.119| Val Acc: 1.552
# Epoch 093: | Train Loss: 30.40493 | Val Loss: 22.74199 | Train Acc: 2.095| Val Acc: 1.545
# Epoch 094: | Train Loss: 30.54305 | Val Loss: 23.84594 | Train Acc: 2.085| Val Acc: 1.894
# Epoch 095: | Train Loss: 30.65492 | Val Loss: 24.41179 | Train Acc: 2.074| Val Acc: 2.046
# Epoch 096: | Train Loss: 30.41632 | Val Loss: 23.63081 | Train Acc: 2.128| Val Acc: 1.889
# Epoch 097: | Train Loss: 30.27411 | Val Loss: 22.95459 | Train Acc: 2.059| Val Acc: 1.698
# Epoch 098: | Train Loss: 30.51303 | Val Loss: 22.96511 | Train Acc: 2.076| Val Acc: 1.559
# Epoch 099: | Train Loss: 30.29138 | Val Loss: 23.04196 | Train Acc: 2.095| Val Acc: 1.569
# Epoch 100: | Train Loss: 30.25656 | Val Loss: 23.11088 | Train Acc: 2.063| Val Acc: 1.564
# Epoch 101: | Train Loss: 30.29933 | Val Loss: 23.06298 | Train Acc: 2.082| Val Acc: 1.543
# Epoch 102: | Train Loss: 30.28588 | Val Loss: 22.82430 | Train Acc: 2.091| Val Acc: 1.515
# Epoch 103: | Train Loss: 30.18869 | Val Loss: 22.67255 | Train Acc: 2.070| Val Acc: 1.508
# Epoch 104: | Train Loss: 30.40419 | Val Loss: 22.61997 | Train Acc: 2.066| Val Acc: 1.516
# Epoch 105: | Train Loss: 30.07196 | Val Loss: 22.66058 | Train Acc: 2.006| Val Acc: 1.515
# Epoch 106: | Train Loss: 30.16490 | Val Loss: 22.69151 | Train Acc: 2.040| Val Acc: 1.532
# Epoch 107: | Train Loss: 30.16830 | Val Loss: 22.72442 | Train Acc: 2.051| Val Acc: 1.548
# Epoch 108: | Train Loss: 30.13712 | Val Loss: 22.81118 | Train Acc: 2.019| Val Acc: 1.700
# Epoch 109: | Train Loss: 30.12507 | Val Loss: 22.95857 | Train Acc: 2.002| Val Acc: 1.702
# Epoch 110: | Train Loss: 30.09432 | Val Loss: 22.99026 | Train Acc: 2.038| Val Acc: 1.694
# Epoch 111: | Train Loss: 30.08201 | Val Loss: 22.92239 | Train Acc: 2.014| Val Acc: 1.690
# Epoch 112: | Train Loss: 30.25914 | Val Loss: 22.86796 | Train Acc: 2.022| Val Acc: 1.671
# Epoch 113: | Train Loss: 30.12753 | Val Loss: 22.85045 | Train Acc: 2.016| Val Acc: 1.668
# Epoch 114: | Train Loss: 30.02567 | Val Loss: 22.84828 | Train Acc: 1.996| Val Acc: 1.677
# Epoch 115: | Train Loss: 30.08393 | Val Loss: 22.82646 | Train Acc: 2.002| Val Acc: 1.695
# Epoch 116: | Train Loss: 30.10202 | Val Loss: 22.70964 | Train Acc: 1.987| Val Acc: 1.518
# Epoch 117: | Train Loss: 30.02981 | Val Loss: 22.58147 | Train Acc: 1.991| Val Acc: 1.483
# Epoch 118: | Train Loss: 30.08946 | Val Loss: 22.56341 | Train Acc: 2.024| Val Acc: 1.478
# Epoch 119: | Train Loss: 30.01616 | Val Loss: 22.63615 | Train Acc: 1.952| Val Acc: 1.509
# Epoch 120: | Train Loss: 30.10123 | Val Loss: 22.91597 | Train Acc: 1.958| Val Acc: 1.690
# Epoch 121: | Train Loss: 30.07414 | Val Loss: 23.09316 | Train Acc: 1.984| Val Acc: 1.695
# Epoch 122: | Train Loss: 30.13560 | Val Loss: 23.07950 | Train Acc: 2.038| Val Acc: 1.680
# Epoch 123: | Train Loss: 30.09999 | Val Loss: 23.02521 | Train Acc: 2.012| Val Acc: 1.699
# Epoch 124: | Train Loss: 30.13135 | Val Loss: 22.84722 | Train Acc: 2.045| Val Acc: 1.693
# Epoch 125: | Train Loss: 29.98247 | Val Loss: 22.79152 | Train Acc: 1.960| Val Acc: 1.678
# Epoch 126: | Train Loss: 30.08114 | Val Loss: 22.80836 | Train Acc: 1.983| Val Acc: 1.722
# Epoch 127: | Train Loss: 30.04688 | Val Loss: 22.79386 | Train Acc: 1.969| Val Acc: 1.689
# Epoch 128: | Train Loss: 30.05874 | Val Loss: 22.82587 | Train Acc: 1.985| Val Acc: 1.697
# Epoch 129: | Train Loss: 30.03301 | Val Loss: 22.83030 | Train Acc: 1.985| Val Acc: 1.690
# Epoch 130: | Train Loss: 30.04258 | Val Loss: 22.75636 | Train Acc: 1.949| Val Acc: 1.683
# Epoch 131: | Train Loss: 30.01777 | Val Loss: 22.80296 | Train Acc: 1.965| Val Acc: 1.685
# Epoch 132: | Train Loss: 30.02470 | Val Loss: 22.77046 | Train Acc: 1.978| Val Acc: 1.687
# Epoch 133: | Train Loss: 30.06524 | Val Loss: 23.45955 | Train Acc: 1.962| Val Acc: 1.738
# Epoch 134: | Train Loss: 30.37465 | Val Loss: 24.12830 | Train Acc: 2.013| Val Acc: 1.742
# Epoch 135: | Train Loss: 30.15458 | Val Loss: 24.08963 | Train Acc: 2.002| Val Acc: 1.751
# Epoch 136: | Train Loss: 30.29875 | Val Loss: 23.83305 | Train Acc: 2.012| Val Acc: 1.737
# Epoch 137: | Train Loss: 30.18840 | Val Loss: 24.00699 | Train Acc: 2.018| Val Acc: 1.884
# Epoch 138: | Train Loss: 30.12818 | Val Loss: 24.56952 | Train Acc: 2.021| Val Acc: 2.045
# Epoch 139: | Train Loss: 30.02367 | Val Loss: 24.57020 | Train Acc: 1.992| Val Acc: 1.885
# Epoch 140: | Train Loss: 30.05808 | Val Loss: 24.20835 | Train Acc: 2.025| Val Acc: 1.710
# Epoch 141: | Train Loss: 30.18435 | Val Loss: 23.06269 | Train Acc: 1.971| Val Acc: 1.541
# Epoch 142: | Train Loss: 30.43172 | Val Loss: 22.92813 | Train Acc: 2.028| Val Acc: 1.727
# Epoch 143: | Train Loss: 30.14126 | Val Loss: 23.02148 | Train Acc: 2.013| Val Acc: 1.723
# Epoch 144: | Train Loss: 30.16409 | Val Loss: 23.10744 | Train Acc: 1.981| Val Acc: 1.709
# Epoch 145: | Train Loss: 30.26808 | Val Loss: 23.96876 | Train Acc: 1.968| Val Acc: 1.848
# Epoch 146: | Train Loss: 30.19953 | Val Loss: 24.13985 | Train Acc: 2.039| Val Acc: 1.845
# Epoch 147: | Train Loss: 30.09471 | Val Loss: 23.58033 | Train Acc: 1.990| Val Acc: 1.672
# Epoch 148: | Train Loss: 30.04867 | Val Loss: 23.41782 | Train Acc: 1.988| Val Acc: 1.669
# Epoch 149: | Train Loss: 30.06120 | Val Loss: 23.36025 | Train Acc: 2.002| Val Acc: 1.512
# Epoch 150: | Train Loss: 30.19602 | Val Loss: 23.18854 | Train Acc: 1.968| Val Acc: 1.543

# %%
metrics(train, test, threshold=30)
# Out:
# MAE on train set:  29.099267255188252
# min prediction: 1
# max prediction: 231
#
# MAE on test set:  29.637022921464578
# Error ⩽ 30: 76.34 %
# min prediction: 1
# max prediction: 277

# %%
validation_plots(test,model_type)

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.000001, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)
# Out:
# Epoch 001: | Train Loss: 33.79706 | Val Loss: 0.18336 | Train Acc: 2.403| Val Acc: 0.542
# Epoch 002: | Train Loss: 33.00948 | Val Loss: 0.00208 | Train Acc: 2.261| Val Acc: 0.458
# Epoch 003: | Train Loss: 33.04118 | Val Loss: 0.08368 | Train Acc: 2.277| Val Acc: 0.542
# Epoch 004: | Train Loss: 33.03801 | Val Loss: 0.39681 | Train Acc: 2.290| Val Acc: 0.542
# Epoch 005: | Train Loss: 33.12001 | Val Loss: 0.66175 | Train Acc: 2.256| Val Acc: 0.542
# Epoch 006: | Train Loss: 32.69527 | Val Loss: 0.45936 | Train Acc: 2.255| Val Acc: 0.542
# Epoch 007: | Train Loss: 32.51777 | Val Loss: 0.46496 | Train Acc: 2.185| Val Acc: 0.542
# Epoch 008: | Train Loss: 32.53499 | Val Loss: 0.43640 | Train Acc: 2.180| Val Acc: 0.542
# Epoch 009: | Train Loss: 32.47813 | Val Loss: 0.33769 | Train Acc: 2.169| Val Acc: 0.542
# Epoch 010: | Train Loss: 32.45824 | Val Loss: 0.58835 | Train Acc: 2.190| Val Acc: 0.542
# Epoch 011: | Train Loss: 32.31352 | Val Loss: 0.46049 | Train Acc: 2.165| Val Acc: 0.542
# Epoch 012: | Train Loss: 32.26534 | Val Loss: 0.13487 | Train Acc: 2.182| Val Acc: 0.542
# Epoch 013: | Train Loss: 32.17328 | Val Loss: 0.01642 | Train Acc: 2.115| Val Acc: 0.542
# Epoch 014: | Train Loss: 32.41954 | Val Loss: 0.15039 | Train Acc: 2.132| Val Acc: 0.542
# Epoch 015: | Train Loss: 32.44960 | Val Loss: 0.47928 | Train Acc: 2.146| Val Acc: 0.542
# Epoch 016: | Train Loss: 32.43543 | Val Loss: 0.18965 | Train Acc: 2.174| Val Acc: 0.542
# Epoch 017: | Train Loss: 32.35623 | Val Loss: 0.02568 | Train Acc: 2.181| Val Acc: 0.542
# Epoch 018: | Train Loss: 32.22630 | Val Loss: 0.05099 | Train Acc: 2.148| Val Acc: 0.542
# Epoch 019: | Train Loss: 32.44024 | Val Loss: 0.44431 | Train Acc: 2.140| Val Acc: 0.542
# Epoch 020: | Train Loss: 32.23719 | Val Loss: 0.63774 | Train Acc: 2.122| Val Acc: 0.542
# Epoch 021: | Train Loss: 32.17394 | Val Loss: 0.39074 | Train Acc: 2.116| Val Acc: 0.542
# Epoch 022: | Train Loss: 32.26575 | Val Loss: 0.18368 | Train Acc: 2.143| Val Acc: 0.542
# Epoch 023: | Train Loss: 32.22853 | Val Loss: 0.14506 | Train Acc: 2.136| Val Acc: 0.542
# Epoch 024: | Train Loss: 32.24907 | Val Loss: 0.19743 | Train Acc: 2.163| Val Acc: 0.542
# Epoch 025: | Train Loss: 32.15717 | Val Loss: 0.43089 | Train Acc: 2.112| Val Acc: 0.542
# Epoch 026: | Train Loss: 32.17206 | Val Loss: 0.34397 | Train Acc: 2.087| Val Acc: 0.542
# Epoch 027: | Train Loss: 32.16161 | Val Loss: 0.23634 | Train Acc: 2.140| Val Acc: 0.542
# Epoch 028: | Train Loss: 32.25182 | Val Loss: 0.58770 | Train Acc: 2.106| Val Acc: 0.542
# Epoch 029: | Train Loss: 32.10165 | Val Loss: 0.46958 | Train Acc: 2.106| Val Acc: 0.542
# Epoch 030: | Train Loss: 32.10035 | Val Loss: 0.02303 | Train Acc: 2.085| Val Acc: 0.542
# Epoch 031: | Train Loss: 32.14704 | Val Loss: 0.02683 | Train Acc: 2.093| Val Acc: 0.542
# Epoch 032: | Train Loss: 32.23525 | Val Loss: 0.61219 | Train Acc: 2.116| Val Acc: 0.542
# Epoch 033: | Train Loss: 32.09110 | Val Loss: 0.30580 | Train Acc: 2.070| Val Acc: 0.542
# Epoch 034: | Train Loss: 32.10185 | Val Loss: 0.08838 | Train Acc: 2.104| Val Acc: 0.542
# Epoch 035: | Train Loss: 32.25706 | Val Loss: 0.02004 | Train Acc: 2.077| Val Acc: 0.542
# Epoch 036: | Train Loss: 32.41085 | Val Loss: 0.02440 | Train Acc: 2.100| Val Acc: 0.542
# Epoch 037: | Train Loss: 32.12250 | Val Loss: 0.06372 | Train Acc: 2.113| Val Acc: 0.542
# Epoch 038: | Train Loss: 32.22613 | Val Loss: 0.00273 | Train Acc: 2.111| Val Acc: 0.542
# Epoch 039: | Train Loss: 32.13384 | Val Loss: 0.02583 | Train Acc: 2.097| Val Acc: 0.542
# Epoch 040: | Train Loss: 32.06957 | Val Loss: 0.19464 | Train Acc: 2.072| Val Acc: 0.542
# Epoch 041: | Train Loss: 32.01024 | Val Loss: 0.29527 | Train Acc: 2.066| Val Acc: 0.542
# Epoch 042: | Train Loss: 32.11902 | Val Loss: 0.35109 | Train Acc: 2.093| Val Acc: 0.542
# Epoch 043: | Train Loss: 32.07855 | Val Loss: 0.31696 | Train Acc: 2.079| Val Acc: 0.542
# Epoch 044: | Train Loss: 32.01976 | Val Loss: 0.21393 | Train Acc: 2.065| Val Acc: 0.542
# Epoch 045: | Train Loss: 31.96864 | Val Loss: 0.05071 | Train Acc: 2.035| Val Acc: 0.542
# Epoch 046: | Train Loss: 32.01397 | Val Loss: 0.02930 | Train Acc: 2.080| Val Acc: 0.542
# Epoch 047: | Train Loss: 31.94584 | Val Loss: 0.18649 | Train Acc: 2.054| Val Acc: 0.542
# Epoch 048: | Train Loss: 31.94852 | Val Loss: 0.31188 | Train Acc: 2.030| Val Acc: 0.542
# Epoch 049: | Train Loss: 32.07352 | Val Loss: 0.19587 | Train Acc: 2.081| Val Acc: 0.542
# Epoch 050: | Train Loss: 31.92878 | Val Loss: 0.08894 | Train Acc: 2.056| Val Acc: 0.542
# Epoch 051: | Train Loss: 32.04706 | Val Loss: 0.26311 | Train Acc: 2.067| Val Acc: 0.542
# Epoch 052: | Train Loss: 31.99747 | Val Loss: 0.27044 | Train Acc: 2.051| Val Acc: 0.542
# Epoch 053: | Train Loss: 32.05887 | Val Loss: 0.03512 | Train Acc: 2.078| Val Acc: 0.542
# Epoch 054: | Train Loss: 32.10279 | Val Loss: 0.06859 | Train Acc: 2.054| Val Acc: 0.542
# Epoch 055: | Train Loss: 32.15788 | Val Loss: 0.11275 | Train Acc: 2.053| Val Acc: 0.542
# Epoch 056: | Train Loss: 32.14664 | Val Loss: 0.32521 | Train Acc: 2.073| Val Acc: 0.542
# Epoch 057: | Train Loss: 31.96351 | Val Loss: 0.28377 | Train Acc: 2.050| Val Acc: 0.542
# Epoch 058: | Train Loss: 31.93510 | Val Loss: 0.13498 | Train Acc: 2.019| Val Acc: 0.542
# Epoch 059: | Train Loss: 32.00653 | Val Loss: 0.07449 | Train Acc: 2.040| Val Acc: 0.542
# Epoch 060: | Train Loss: 32.08784 | Val Loss: 0.09521 | Train Acc: 2.063| Val Acc: 0.542
# Epoch 061: | Train Loss: 31.97495 | Val Loss: 0.17404 | Train Acc: 2.043| Val Acc: 0.542
# Epoch 062: | Train Loss: 31.93173 | Val Loss: 0.32939 | Train Acc: 2.034| Val Acc: 0.542
# Epoch 063: | Train Loss: 31.96331 | Val Loss: 0.26662 | Train Acc: 2.052| Val Acc: 0.542
# Epoch 064: | Train Loss: 31.92752 | Val Loss: 0.23459 | Train Acc: 2.034| Val Acc: 0.542
# Epoch 065: | Train Loss: 31.88795 | Val Loss: 0.21846 | Train Acc: 2.021| Val Acc: 0.542
# Epoch 066: | Train Loss: 31.94208 | Val Loss: 0.27365 | Train Acc: 2.011| Val Acc: 0.542
# Epoch 067: | Train Loss: 31.87162 | Val Loss: 0.22608 | Train Acc: 2.012| Val Acc: 0.542
# Epoch 068: | Train Loss: 31.84677 | Val Loss: 0.18812 | Train Acc: 1.984| Val Acc: 0.542
# Epoch 069: | Train Loss: 32.01408 | Val Loss: 0.24702 | Train Acc: 2.017| Val Acc: 0.542
# Epoch 070: | Train Loss: 31.93766 | Val Loss: 0.54733 | Train Acc: 2.030| Val Acc: 0.542
# Epoch 071: | Train Loss: 31.98347 | Val Loss: 0.71416 | Train Acc: 2.064| Val Acc: 0.542
# Epoch 072: | Train Loss: 31.97956 | Val Loss: 0.52574 | Train Acc: 2.045| Val Acc: 0.542
# Epoch 073: | Train Loss: 31.90961 | Val Loss: 0.22275 | Train Acc: 2.003| Val Acc: 0.542
# Epoch 074: | Train Loss: 32.03528 | Val Loss: 0.16578 | Train Acc: 2.026| Val Acc: 0.542
# Epoch 075: | Train Loss: 31.92998 | Val Loss: 0.24018 | Train Acc: 2.009| Val Acc: 0.542
# Epoch 076: | Train Loss: 31.91884 | Val Loss: 0.18004 | Train Acc: 2.016| Val Acc: 0.542
# Epoch 077: | Train Loss: 31.79616 | Val Loss: 0.41706 | Train Acc: 1.979| Val Acc: 0.542
# Epoch 078: | Train Loss: 31.78929 | Val Loss: 0.49827 | Train Acc: 1.994| Val Acc: 0.542
# Epoch 079: | Train Loss: 31.89665 | Val Loss: 0.36082 | Train Acc: 2.010| Val Acc: 0.542
# Epoch 080: | Train Loss: 31.91578 | Val Loss: 0.57663 | Train Acc: 2.025| Val Acc: 0.542
# Epoch 081: | Train Loss: 31.83339 | Val Loss: 0.49293 | Train Acc: 2.009| Val Acc: 0.542
# Epoch 082: | Train Loss: 31.89503 | Val Loss: 0.26140 | Train Acc: 1.990| Val Acc: 0.542
# Epoch 083: | Train Loss: 31.94749 | Val Loss: 0.06276 | Train Acc: 1.987| Val Acc: 0.542
# Epoch 084: | Train Loss: 31.78865 | Val Loss: 0.08337 | Train Acc: 1.990| Val Acc: 0.542
# Epoch 085: | Train Loss: 32.15482 | Val Loss: 0.43234 | Train Acc: 2.037| Val Acc: 0.542
# Epoch 086: | Train Loss: 32.01582 | Val Loss: 0.54986 | Train Acc: 2.009| Val Acc: 0.542
# Epoch 087: | Train Loss: 32.09685 | Val Loss: 0.07665 | Train Acc: 2.081| Val Acc: 0.542
# Epoch 088: | Train Loss: 31.80939 | Val Loss: 0.00036 | Train Acc: 2.004| Val Acc: 0.458
# Epoch 089: | Train Loss: 31.90067 | Val Loss: 0.26141 | Train Acc: 2.023| Val Acc: 0.542
# Epoch 090: | Train Loss: 31.92271 | Val Loss: 0.34007 | Train Acc: 2.050| Val Acc: 0.542
# Epoch 091: | Train Loss: 32.00969 | Val Loss: 0.19060 | Train Acc: 2.014| Val Acc: 0.542
# Epoch 092: | Train Loss: 31.74160 | Val Loss: 0.18515 | Train Acc: 1.970| Val Acc: 0.542
# Epoch 093: | Train Loss: 31.75003 | Val Loss: 0.32038 | Train Acc: 1.991| Val Acc: 0.542
# Epoch 094: | Train Loss: 31.74887 | Val Loss: 0.29207 | Train Acc: 1.993| Val Acc: 0.542
# Epoch 095: | Train Loss: 31.96116 | Val Loss: 0.14946 | Train Acc: 1.997| Val Acc: 0.542
# Epoch 096: | Train Loss: 31.75584 | Val Loss: 0.16785 | Train Acc: 1.959| Val Acc: 0.542
# Epoch 097: | Train Loss: 31.86890 | Val Loss: 0.29903 | Train Acc: 1.984| Val Acc: 0.542
# Epoch 098: | Train Loss: 31.81048 | Val Loss: 0.50472 | Train Acc: 1.990| Val Acc: 0.542
# Epoch 099: | Train Loss: 31.79808 | Val Loss: 0.39827 | Train Acc: 1.974| Val Acc: 0.542
# Epoch 100: | Train Loss: 31.93077 | Val Loss: 0.17768 | Train Acc: 2.012| Val Acc: 0.542
# Epoch 101: | Train Loss: 31.93472 | Val Loss: 0.19730 | Train Acc: 2.025| Val Acc: 0.542
# Epoch 102: | Train Loss: 31.82468 | Val Loss: 0.20544 | Train Acc: 1.999| Val Acc: 0.542
# Epoch 103: | Train Loss: 31.87718 | Val Loss: 0.27555 | Train Acc: 1.994| Val Acc: 0.542
# Epoch 104: | Train Loss: 31.94517 | Val Loss: 0.14749 | Train Acc: 2.014| Val Acc: 0.542
# Epoch 105: | Train Loss: 31.96815 | Val Loss: 0.29389 | Train Acc: 2.035| Val Acc: 0.542
# Epoch 106: | Train Loss: 32.02520 | Val Loss: 0.46671 | Train Acc: 2.027| Val Acc: 0.542
# Epoch 107: | Train Loss: 31.95285 | Val Loss: 0.39982 | Train Acc: 2.036| Val Acc: 0.542
# Epoch 108: | Train Loss: 31.87792 | Val Loss: 0.19255 | Train Acc: 2.024| Val Acc: 0.542
# Epoch 109: | Train Loss: 31.89822 | Val Loss: 0.18436 | Train Acc: 2.019| Val Acc: 0.542
# Epoch 110: | Train Loss: 31.84371 | Val Loss: 0.67600 | Train Acc: 1.974| Val Acc: 0.542
# Epoch 111: | Train Loss: 31.73536 | Val Loss: 0.83710 | Train Acc: 1.960| Val Acc: 0.542
# Epoch 112: | Train Loss: 31.90018 | Val Loss: 0.88080 | Train Acc: 2.032| Val Acc: 0.542
# Epoch 113: | Train Loss: 31.77584 | Val Loss: 0.88164 | Train Acc: 1.986| Val Acc: 0.542
# Epoch 114: | Train Loss: 31.75473 | Val Loss: 0.31516 | Train Acc: 1.977| Val Acc: 0.542
# Epoch 115: | Train Loss: 31.73691 | Val Loss: 0.22769 | Train Acc: 1.957| Val Acc: 0.542
# Epoch 116: | Train Loss: 31.72840 | Val Loss: 0.52137 | Train Acc: 1.974| Val Acc: 0.542
# Epoch 117: | Train Loss: 31.71809 | Val Loss: 0.71024 | Train Acc: 1.967| Val Acc: 0.542
# Epoch 118: | Train Loss: 31.75899 | Val Loss: 0.61383 | Train Acc: 1.988| Val Acc: 0.542
# Epoch 119: | Train Loss: 31.68937 | Val Loss: 0.23847 | Train Acc: 1.936| Val Acc: 0.542
# Epoch 120: | Train Loss: 31.75728 | Val Loss: 0.38734 | Train Acc: 1.988| Val Acc: 0.542
# Epoch 121: | Train Loss: 31.81688 | Val Loss: 0.63556 | Train Acc: 1.973| Val Acc: 0.542
# Epoch 122: | Train Loss: 31.83906 | Val Loss: 0.30825 | Train Acc: 1.968| Val Acc: 0.542
# Epoch 123: | Train Loss: 31.85457 | Val Loss: 0.16949 | Train Acc: 1.995| Val Acc: 0.542
# Epoch 124: | Train Loss: 31.81425 | Val Loss: 0.19570 | Train Acc: 1.971| Val Acc: 0.542
# Epoch 125: | Train Loss: 31.75046 | Val Loss: 0.24418 | Train Acc: 1.955| Val Acc: 0.542
# Epoch 126: | Train Loss: 31.79226 | Val Loss: 0.26312 | Train Acc: 1.963| Val Acc: 0.542
# Epoch 127: | Train Loss: 31.73316 | Val Loss: 0.32776 | Train Acc: 1.954| Val Acc: 0.542
# Epoch 128: | Train Loss: 31.74026 | Val Loss: 0.31270 | Train Acc: 1.954| Val Acc: 0.542
# Epoch 129: | Train Loss: 31.71360 | Val Loss: 0.32181 | Train Acc: 1.946| Val Acc: 0.542
# Epoch 130: | Train Loss: 31.68804 | Val Loss: 0.36407 | Train Acc: 1.941| Val Acc: 0.542
# Epoch 131: | Train Loss: 31.71295 | Val Loss: 0.24772 | Train Acc: 1.948| Val Acc: 0.542
# Epoch 132: | Train Loss: 31.71134 | Val Loss: 0.18928 | Train Acc: 1.936| Val Acc: 0.542
# Epoch 133: | Train Loss: 31.69031 | Val Loss: 0.45236 | Train Acc: 1.957| Val Acc: 0.542
# Epoch 134: | Train Loss: 31.65436 | Val Loss: 0.46258 | Train Acc: 1.923| Val Acc: 0.542
# Epoch 135: | Train Loss: 31.65488 | Val Loss: 0.48112 | Train Acc: 1.908| Val Acc: 0.542
# Epoch 136: | Train Loss: 31.66000 | Val Loss: 0.32883 | Train Acc: 1.925| Val Acc: 0.542
# Epoch 137: | Train Loss: 31.66194 | Val Loss: 0.25491 | Train Acc: 1.907| Val Acc: 0.542
# Epoch 138: | Train Loss: 31.70955 | Val Loss: 0.20965 | Train Acc: 1.942| Val Acc: 0.542
# Epoch 139: | Train Loss: 31.66290 | Val Loss: 0.18365 | Train Acc: 1.926| Val Acc: 0.542
# Epoch 140: | Train Loss: 31.77479 | Val Loss: 0.62560 | Train Acc: 1.927| Val Acc: 0.542
# Epoch 141: | Train Loss: 31.76224 | Val Loss: 0.73587 | Train Acc: 1.983| Val Acc: 0.542
# Epoch 142: | Train Loss: 31.69523 | Val Loss: 0.20528 | Train Acc: 1.951| Val Acc: 0.542
# Epoch 143: | Train Loss: 31.76045 | Val Loss: 0.40533 | Train Acc: 1.956| Val Acc: 0.542
# Epoch 144: | Train Loss: 31.67914 | Val Loss: 0.98250 | Train Acc: 1.953| Val Acc: 0.542
# Epoch 145: | Train Loss: 31.69120 | Val Loss: 0.87050 | Train Acc: 1.951| Val Acc: 0.542
# Epoch 146: | Train Loss: 31.64678 | Val Loss: 0.93223 | Train Acc: 1.929| Val Acc: 0.542
# Epoch 147: | Train Loss: 31.62641 | Val Loss: 0.58356 | Train Acc: 1.937| Val Acc: 0.542
# Epoch 148: | Train Loss: 31.63099 | Val Loss: 0.32548 | Train Acc: 1.913| Val Acc: 0.542
# Epoch 149: | Train Loss: 31.67772 | Val Loss: 0.57639 | Train Acc: 1.947| Val Acc: 0.542
# Epoch 150: | Train Loss: 31.62898 | Val Loss: 0.57075 | Train Acc: 1.903| Val Acc: 0.542

# %%
pickle.dump(model, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_Mamoth_NN.pt', 'wb'))
pickle.dump(imputer, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_KNN_Imputer.pkl', 'wb'))
pickle.dump(scaler, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_Scaler.pkl', 'wb'))
