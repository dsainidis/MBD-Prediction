# %% [markdown]
# ## Produces **Mosquito Predictions** for a specific region using MAMOTH ##

# %%
import pandas as pd
import datetime
import math
import numpy as np
import missingno
import json
from statistics import mean
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
import sys
import pickle

sys.path.insert(0, "../../../../Mamoth")
sys.path.insert(0, "../../../../Modules")

from utils import *

from Preprocessing_Module import read_data, select_columns, reshape_dataset
from Initializer_Module import initializer
from Neural_Network_Module import Dataset, transformations, FeedforwardNeuralNetModel, train_nn, give_predictions
from Model_Validation_Module import validation_plots, metrics

enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 100
pd.options.display.float_format = lambda x: '%.6f' % x

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
NUTS0 = 'GR'
NUTS2 = 'Peloponnese'
NUTS2_EL = 'κεντρικης μακεδονιας'

# %%
mosquito_data = read_data(f'../../data/{NUTS0}_MSQ_culex_2011-2022_processed.csv')
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
mosquito_data.nuts2.unique()
# Out:
# array(['κεντρικης μακεδονιας', 'θεσσαλιας', 'κρητης', 'δυτικης ελλαδας'],
#       dtype=object)

# %%
mosquito_data_nuts2 = mosquito_data.query(f"nuts2 == '{NUTS2_EL}'").copy()
mosquito_data_nuts2.reset_index(inplace = True, drop = True)

# %%
mosq_columns = mosquito_data_nuts2.columns
mosq_columns
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
                'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
                'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
                'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
                'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
                'acc_rainfall_jan', 'mosq_now']

# columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#                 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#                 'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#                 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#                 'lst_night', 'acc_rainfall_1week', 'acc_rainfall_2week',
#                 'acc_rainfall_jan', 'mosq_now']

mosquito_data_nuts2 = select_columns(mosquito_data_nuts2, columns_to_keep, columns_to_keep)

mosquito_data_nuts2 = reshape_dataset(mosquito_data_nuts2,['x','y','dt_placement'])

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()

# %%
#quantile might change based on sns plots
mosq_quantilie = mosquito_data_nuts2['mosq_now'].quantile(0.90)

mosquito_data_nuts2['mosq_now'][mosquito_data_nuts2['mosq_now'] > mosq_quantilie] = mosq_quantilie+1

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <Axes: >

# %%
imputer = KNNImputer()

features_for_impute = ['x', 'y', 'day', 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 
                        'lst_day', 'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean', 'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan']

# features_for_impute = ['x', 'y', 'day', 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#                         'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 
#                         'lst_day', 'lst_night', 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan']

mosquito_data_sub = mosquito_data_nuts2[features_for_impute]

imputed_data = pd.DataFrame(imputer.fit_transform(mosquito_data_sub), columns = mosquito_data_sub.columns)

# %%
# imputed_columns = ['ndvi','ndmi', 'ndwi', 'ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std', 'ndmi_std','ndwi_std','ndbi_std',
#                    'lst_day','lst_night']

imputed_columns = ['ndvi','ndmi', 'ndwi', 'ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std', 'ndmi_std','ndwi_std','ndbi_std',
                   'lst_day','lst_night','lst_jan_mean','lst_feb_mean','lst_mar_mean','lst_apr_mean']

mosquito_data_nuts2[imputed_columns] = imputed_data[imputed_columns]

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <Axes: >

# %%
step = 15
only_env = True
case_title = 'NN mosq regression'
exp = False
date_col = 'dt_placement'
model_type = 'mosquito_regression'
transform_target = True
augment = True

# %%
mosquito_data_nuts2 = initializer(mosquito_data_nuts2,2,10,25,step,[date_col], env=only_env, date_column = date_col, mosq_column='mosq_now')
# Out:
# Bounds: [  0.  85. 755.]

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.25, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

model = FeedforwardNeuralNetModel(num_features=len(train_X[0]), num_class=1, hidden_layers = [264,128,128,64], dropout=0.2, model_type=model_type, transform = transform_target)

# %%
train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)
# Out:
# Epoch 001: | Train Loss: 19.17323 | Val Loss: 23.04008 | Train Acc: 2.598| Val Acc: 1.947
# Epoch 002: | Train Loss: 18.47620 | Val Loss: 26.32344 | Train Acc: 2.241| Val Acc: 2.109
# Epoch 003: | Train Loss: 18.30026 | Val Loss: 25.73432 | Train Acc: 2.200| Val Acc: 2.085
# Epoch 004: | Train Loss: 17.85110 | Val Loss: 25.19471 | Train Acc: 2.123| Val Acc: 2.045
# Epoch 005: | Train Loss: 17.60416 | Val Loss: 24.82808 | Train Acc: 2.109| Val Acc: 2.017
# Epoch 006: | Train Loss: 17.44678 | Val Loss: 24.65186 | Train Acc: 2.073| Val Acc: 2.028
# Epoch 007: | Train Loss: 17.30000 | Val Loss: 24.52432 | Train Acc: 2.050| Val Acc: 2.021
# Epoch 008: | Train Loss: 17.13360 | Val Loss: 24.35868 | Train Acc: 2.040| Val Acc: 2.022
# Epoch 009: | Train Loss: 16.86343 | Val Loss: 24.66595 | Train Acc: 2.014| Val Acc: 2.055
# Epoch 010: | Train Loss: 16.63838 | Val Loss: 25.05896 | Train Acc: 1.984| Val Acc: 2.119
# Epoch 011: | Train Loss: 16.53359 | Val Loss: 24.56486 | Train Acc: 1.983| Val Acc: 2.059
# Epoch 012: | Train Loss: 16.27995 | Val Loss: 25.03051 | Train Acc: 1.967| Val Acc: 2.112
# Epoch 013: | Train Loss: 16.16961 | Val Loss: 25.43057 | Train Acc: 1.964| Val Acc: 2.147
# Epoch 014: | Train Loss: 16.23869 | Val Loss: 24.44791 | Train Acc: 1.966| Val Acc: 2.095
# Epoch 015: | Train Loss: 15.92086 | Val Loss: 25.69317 | Train Acc: 1.929| Val Acc: 2.221
# Epoch 016: | Train Loss: 15.96571 | Val Loss: 25.60783 | Train Acc: 1.950| Val Acc: 2.204
# Epoch 017: | Train Loss: 15.84674 | Val Loss: 25.38581 | Train Acc: 1.940| Val Acc: 2.204
# Epoch 018: | Train Loss: 15.59737 | Val Loss: 25.26473 | Train Acc: 1.922| Val Acc: 2.210
# Epoch 019: | Train Loss: 15.48500 | Val Loss: 25.93274 | Train Acc: 1.888| Val Acc: 2.268
# Epoch 020: | Train Loss: 15.33513 | Val Loss: 26.28061 | Train Acc: 1.879| Val Acc: 2.285
# Epoch 021: | Train Loss: 15.30420 | Val Loss: 25.81832 | Train Acc: 1.862| Val Acc: 2.255
# Epoch 022: | Train Loss: 15.09812 | Val Loss: 26.23825 | Train Acc: 1.842| Val Acc: 2.293
# Epoch 023: | Train Loss: 15.01716 | Val Loss: 26.57688 | Train Acc: 1.831| Val Acc: 2.346
# Epoch 024: | Train Loss: 14.80879 | Val Loss: 26.48201 | Train Acc: 1.814| Val Acc: 2.319
# Epoch 025: | Train Loss: 14.83655 | Val Loss: 26.56500 | Train Acc: 1.831| Val Acc: 2.312
# Epoch 026: | Train Loss: 14.74933 | Val Loss: 26.54140 | Train Acc: 1.827| Val Acc: 2.334
# Epoch 027: | Train Loss: 14.43286 | Val Loss: 27.23990 | Train Acc: 1.786| Val Acc: 2.360
# Epoch 028: | Train Loss: 14.32813 | Val Loss: 26.76934 | Train Acc: 1.774| Val Acc: 2.346
# Epoch 029: | Train Loss: 14.18760 | Val Loss: 26.36708 | Train Acc: 1.734| Val Acc: 2.292
# Epoch 030: | Train Loss: 14.20312 | Val Loss: 26.49282 | Train Acc: 1.737| Val Acc: 2.314
# Epoch 031: | Train Loss: 14.24411 | Val Loss: 26.71928 | Train Acc: 1.758| Val Acc: 2.329
# Epoch 032: | Train Loss: 14.00750 | Val Loss: 27.82646 | Train Acc: 1.710| Val Acc: 2.454
# Epoch 033: | Train Loss: 13.76416 | Val Loss: 27.19329 | Train Acc: 1.684| Val Acc: 2.354
# Epoch 034: | Train Loss: 14.04764 | Val Loss: 26.52193 | Train Acc: 1.722| Val Acc: 2.331
# Epoch 035: | Train Loss: 13.66689 | Val Loss: 26.57637 | Train Acc: 1.686| Val Acc: 2.312
# Epoch 036: | Train Loss: 13.39947 | Val Loss: 27.76971 | Train Acc: 1.647| Val Acc: 2.392
# Epoch 037: | Train Loss: 13.62475 | Val Loss: 27.13888 | Train Acc: 1.653| Val Acc: 2.307
# Epoch 038: | Train Loss: 13.62106 | Val Loss: 26.90581 | Train Acc: 1.657| Val Acc: 2.330
# Epoch 039: | Train Loss: 13.36506 | Val Loss: 27.07433 | Train Acc: 1.629| Val Acc: 2.346
# Epoch 040: | Train Loss: 13.41063 | Val Loss: 26.97261 | Train Acc: 1.635| Val Acc: 2.363
# Epoch 041: | Train Loss: 13.31871 | Val Loss: 27.77168 | Train Acc: 1.621| Val Acc: 2.423
# Epoch 042: | Train Loss: 13.29328 | Val Loss: 25.55058 | Train Acc: 1.599| Val Acc: 2.209
# Epoch 043: | Train Loss: 13.18598 | Val Loss: 26.47829 | Train Acc: 1.586| Val Acc: 2.254
# Epoch 044: | Train Loss: 13.19661 | Val Loss: 26.36748 | Train Acc: 1.587| Val Acc: 2.236
# Epoch 045: | Train Loss: 12.99229 | Val Loss: 26.44291 | Train Acc: 1.570| Val Acc: 2.285
# Epoch 046: | Train Loss: 13.07708 | Val Loss: 26.67462 | Train Acc: 1.575| Val Acc: 2.263
# Epoch 047: | Train Loss: 12.95825 | Val Loss: 26.88116 | Train Acc: 1.557| Val Acc: 2.309
# Epoch 048: | Train Loss: 13.10822 | Val Loss: 26.77389 | Train Acc: 1.583| Val Acc: 2.267
# Epoch 049: | Train Loss: 12.86460 | Val Loss: 26.79697 | Train Acc: 1.539| Val Acc: 2.294
# Epoch 050: | Train Loss: 12.76400 | Val Loss: 26.77190 | Train Acc: 1.532| Val Acc: 2.288
# Epoch 051: | Train Loss: 12.84892 | Val Loss: 26.76158 | Train Acc: 1.553| Val Acc: 2.268
# Epoch 052: | Train Loss: 12.87164 | Val Loss: 26.87341 | Train Acc: 1.542| Val Acc: 2.276
# Epoch 053: | Train Loss: 12.73726 | Val Loss: 26.19991 | Train Acc: 1.537| Val Acc: 2.229
# Epoch 054: | Train Loss: 12.84690 | Val Loss: 26.42917 | Train Acc: 1.546| Val Acc: 2.266
# Epoch 055: | Train Loss: 12.77882 | Val Loss: 26.55373 | Train Acc: 1.519| Val Acc: 2.245
# Epoch 056: | Train Loss: 12.78838 | Val Loss: 26.40825 | Train Acc: 1.538| Val Acc: 2.208
# Epoch 057: | Train Loss: 12.75808 | Val Loss: 26.68906 | Train Acc: 1.524| Val Acc: 2.268
# Epoch 058: | Train Loss: 12.74807 | Val Loss: 27.76453 | Train Acc: 1.524| Val Acc: 2.369
# Epoch 059: | Train Loss: 12.65777 | Val Loss: 27.21582 | Train Acc: 1.511| Val Acc: 2.319
# Epoch 060: | Train Loss: 12.59142 | Val Loss: 27.11410 | Train Acc: 1.500| Val Acc: 2.281
# Epoch 061: | Train Loss: 12.64126 | Val Loss: 26.74422 | Train Acc: 1.505| Val Acc: 2.224
# Epoch 062: | Train Loss: 12.61039 | Val Loss: 26.85672 | Train Acc: 1.499| Val Acc: 2.262
# Epoch 063: | Train Loss: 12.51861 | Val Loss: 26.48820 | Train Acc: 1.494| Val Acc: 2.223
# Epoch 064: | Train Loss: 12.57086 | Val Loss: 26.44523 | Train Acc: 1.495| Val Acc: 2.240
# Epoch 065: | Train Loss: 12.51181 | Val Loss: 25.71577 | Train Acc: 1.472| Val Acc: 2.112
# Epoch 066: | Train Loss: 12.46257 | Val Loss: 25.54813 | Train Acc: 1.466| Val Acc: 2.070
# Epoch 067: | Train Loss: 12.44658 | Val Loss: 25.60549 | Train Acc: 1.463| Val Acc: 2.124
# Epoch 068: | Train Loss: 12.54544 | Val Loss: 27.04252 | Train Acc: 1.486| Val Acc: 2.297
# Epoch 069: | Train Loss: 12.57824 | Val Loss: 26.10055 | Train Acc: 1.481| Val Acc: 2.189
# Epoch 070: | Train Loss: 12.54412 | Val Loss: 25.98833 | Train Acc: 1.479| Val Acc: 2.188
# Epoch 071: | Train Loss: 12.38591 | Val Loss: 26.58101 | Train Acc: 1.453| Val Acc: 2.199
# Epoch 072: | Train Loss: 12.47871 | Val Loss: 26.11158 | Train Acc: 1.462| Val Acc: 2.127
# Epoch 073: | Train Loss: 12.40132 | Val Loss: 25.32873 | Train Acc: 1.463| Val Acc: 2.088
# Epoch 074: | Train Loss: 12.43075 | Val Loss: 26.15199 | Train Acc: 1.453| Val Acc: 2.157
# Epoch 075: | Train Loss: 12.40190 | Val Loss: 26.37174 | Train Acc: 1.448| Val Acc: 2.175
# Epoch 076: | Train Loss: 12.36295 | Val Loss: 25.34608 | Train Acc: 1.438| Val Acc: 2.050
# Epoch 077: | Train Loss: 12.48435 | Val Loss: 26.01858 | Train Acc: 1.455| Val Acc: 2.161
# Epoch 078: | Train Loss: 12.30753 | Val Loss: 25.91476 | Train Acc: 1.440| Val Acc: 2.126
# Epoch 079: | Train Loss: 12.32486 | Val Loss: 25.60279 | Train Acc: 1.419| Val Acc: 2.119
# Epoch 080: | Train Loss: 12.27278 | Val Loss: 25.65830 | Train Acc: 1.432| Val Acc: 2.116
# Epoch 081: | Train Loss: 12.29179 | Val Loss: 25.99017 | Train Acc: 1.426| Val Acc: 2.125
# Epoch 082: | Train Loss: 12.26923 | Val Loss: 25.05477 | Train Acc: 1.428| Val Acc: 2.049
# Epoch 083: | Train Loss: 12.16204 | Val Loss: 25.01505 | Train Acc: 1.423| Val Acc: 2.039
# Epoch 084: | Train Loss: 12.21277 | Val Loss: 25.66136 | Train Acc: 1.419| Val Acc: 2.156
# Epoch 085: | Train Loss: 12.15234 | Val Loss: 25.85457 | Train Acc: 1.409| Val Acc: 2.098
# Epoch 086: | Train Loss: 12.15712 | Val Loss: 25.69418 | Train Acc: 1.403| Val Acc: 2.092
# Epoch 087: | Train Loss: 12.20183 | Val Loss: 25.52196 | Train Acc: 1.403| Val Acc: 2.121
# Epoch 088: | Train Loss: 12.21779 | Val Loss: 25.66632 | Train Acc: 1.415| Val Acc: 2.120
# Epoch 089: | Train Loss: 12.33509 | Val Loss: 25.56613 | Train Acc: 1.439| Val Acc: 2.121
# Epoch 090: | Train Loss: 12.21280 | Val Loss: 25.59676 | Train Acc: 1.404| Val Acc: 2.101
# Epoch 091: | Train Loss: 12.29035 | Val Loss: 25.43966 | Train Acc: 1.411| Val Acc: 2.089
# Epoch 092: | Train Loss: 12.25127 | Val Loss: 26.13395 | Train Acc: 1.422| Val Acc: 2.171
# Epoch 093: | Train Loss: 12.15429 | Val Loss: 26.04006 | Train Acc: 1.401| Val Acc: 2.165
# Epoch 094: | Train Loss: 12.10142 | Val Loss: 26.25108 | Train Acc: 1.402| Val Acc: 2.160
# Epoch 095: | Train Loss: 12.26936 | Val Loss: 25.73417 | Train Acc: 1.422| Val Acc: 2.109
# Epoch 096: | Train Loss: 12.20033 | Val Loss: 26.17575 | Train Acc: 1.398| Val Acc: 2.190
# Epoch 097: | Train Loss: 12.01922 | Val Loss: 25.44317 | Train Acc: 1.374| Val Acc: 2.089
# Epoch 098: | Train Loss: 12.10795 | Val Loss: 25.71641 | Train Acc: 1.377| Val Acc: 2.122
# Epoch 099: | Train Loss: 12.02660 | Val Loss: 25.91103 | Train Acc: 1.372| Val Acc: 2.140
# Epoch 100: | Train Loss: 12.06439 | Val Loss: 24.85264 | Train Acc: 1.385| Val Acc: 2.024
# Epoch 101: | Train Loss: 12.03656 | Val Loss: 25.30298 | Train Acc: 1.363| Val Acc: 2.095
# Epoch 102: | Train Loss: 12.02734 | Val Loss: 25.16700 | Train Acc: 1.372| Val Acc: 2.074
# Epoch 103: | Train Loss: 12.04003 | Val Loss: 25.80550 | Train Acc: 1.378| Val Acc: 2.133
# Epoch 104: | Train Loss: 12.01242 | Val Loss: 25.17374 | Train Acc: 1.381| Val Acc: 2.060
# Epoch 105: | Train Loss: 12.11844 | Val Loss: 25.30567 | Train Acc: 1.380| Val Acc: 2.048
# Epoch 106: | Train Loss: 12.13704 | Val Loss: 25.30803 | Train Acc: 1.384| Val Acc: 2.085
# Epoch 107: | Train Loss: 12.11088 | Val Loss: 25.08827 | Train Acc: 1.385| Val Acc: 2.045
# Epoch 108: | Train Loss: 12.15458 | Val Loss: 25.04379 | Train Acc: 1.391| Val Acc: 2.010
# Epoch 109: | Train Loss: 12.05306 | Val Loss: 24.93207 | Train Acc: 1.378| Val Acc: 1.993
# Epoch 110: | Train Loss: 12.14116 | Val Loss: 24.82340 | Train Acc: 1.374| Val Acc: 2.031
# Epoch 111: | Train Loss: 12.16729 | Val Loss: 24.66873 | Train Acc: 1.390| Val Acc: 1.972
# Epoch 112: | Train Loss: 12.02029 | Val Loss: 25.09659 | Train Acc: 1.347| Val Acc: 2.040
# Epoch 113: | Train Loss: 12.07045 | Val Loss: 24.71644 | Train Acc: 1.359| Val Acc: 1.986
# Epoch 114: | Train Loss: 12.13277 | Val Loss: 24.67812 | Train Acc: 1.370| Val Acc: 2.023
# Epoch 115: | Train Loss: 12.18839 | Val Loss: 25.38655 | Train Acc: 1.385| Val Acc: 2.094
# Epoch 116: | Train Loss: 12.07831 | Val Loss: 25.12715 | Train Acc: 1.368| Val Acc: 2.022
# Epoch 117: | Train Loss: 11.95559 | Val Loss: 25.47009 | Train Acc: 1.361| Val Acc: 2.079
# Epoch 118: | Train Loss: 11.96577 | Val Loss: 24.98683 | Train Acc: 1.347| Val Acc: 1.998
# Epoch 119: | Train Loss: 12.02666 | Val Loss: 25.01409 | Train Acc: 1.361| Val Acc: 2.049
# Epoch 120: | Train Loss: 11.90402 | Val Loss: 24.93404 | Train Acc: 1.324| Val Acc: 2.026
# Epoch 121: | Train Loss: 11.97916 | Val Loss: 24.98681 | Train Acc: 1.350| Val Acc: 2.061
# Epoch 122: | Train Loss: 11.93575 | Val Loss: 25.36882 | Train Acc: 1.354| Val Acc: 2.023
# Epoch 123: | Train Loss: 11.94166 | Val Loss: 24.91394 | Train Acc: 1.332| Val Acc: 2.083
# Epoch 124: | Train Loss: 11.91512 | Val Loss: 24.66021 | Train Acc: 1.342| Val Acc: 1.991
# Epoch 125: | Train Loss: 11.91925 | Val Loss: 24.72007 | Train Acc: 1.333| Val Acc: 2.016
# Epoch 126: | Train Loss: 11.91977 | Val Loss: 24.74072 | Train Acc: 1.324| Val Acc: 2.013
# Epoch 127: | Train Loss: 11.87313 | Val Loss: 24.93604 | Train Acc: 1.337| Val Acc: 2.032
# Epoch 128: | Train Loss: 12.00577 | Val Loss: 24.90758 | Train Acc: 1.346| Val Acc: 2.050
# Epoch 129: | Train Loss: 11.84954 | Val Loss: 24.49140 | Train Acc: 1.317| Val Acc: 1.963
# Epoch 130: | Train Loss: 11.90920 | Val Loss: 24.65722 | Train Acc: 1.328| Val Acc: 2.022
# Epoch 131: | Train Loss: 11.95314 | Val Loss: 24.69891 | Train Acc: 1.336| Val Acc: 1.957
# Epoch 132: | Train Loss: 11.97426 | Val Loss: 25.41690 | Train Acc: 1.330| Val Acc: 2.061
# Epoch 133: | Train Loss: 11.98782 | Val Loss: 25.49419 | Train Acc: 1.360| Val Acc: 2.082
# Epoch 134: | Train Loss: 11.92778 | Val Loss: 25.35204 | Train Acc: 1.332| Val Acc: 2.054
# Epoch 135: | Train Loss: 12.02863 | Val Loss: 25.30508 | Train Acc: 1.351| Val Acc: 2.069
# Epoch 136: | Train Loss: 12.01691 | Val Loss: 25.25876 | Train Acc: 1.344| Val Acc: 2.116
# Epoch 137: | Train Loss: 11.97825 | Val Loss: 25.15402 | Train Acc: 1.346| Val Acc: 2.049
# Epoch 138: | Train Loss: 11.92353 | Val Loss: 25.42873 | Train Acc: 1.340| Val Acc: 2.073
# Epoch 139: | Train Loss: 11.93676 | Val Loss: 24.82628 | Train Acc: 1.330| Val Acc: 1.983
# Epoch 140: | Train Loss: 11.87629 | Val Loss: 25.02559 | Train Acc: 1.335| Val Acc: 2.025
# Epoch 141: | Train Loss: 12.05663 | Val Loss: 24.90080 | Train Acc: 1.346| Val Acc: 2.055
# Epoch 142: | Train Loss: 12.10803 | Val Loss: 25.41272 | Train Acc: 1.352| Val Acc: 2.063
# Epoch 143: | Train Loss: 11.88242 | Val Loss: 25.03829 | Train Acc: 1.320| Val Acc: 2.031
# Epoch 144: | Train Loss: 11.88576 | Val Loss: 25.31799 | Train Acc: 1.330| Val Acc: 2.051
# Epoch 145: | Train Loss: 11.85851 | Val Loss: 24.81243 | Train Acc: 1.311| Val Acc: 2.005
# Epoch 146: | Train Loss: 11.89095 | Val Loss: 25.41470 | Train Acc: 1.323| Val Acc: 2.057
# Epoch 147: | Train Loss: 11.91949 | Val Loss: 24.56816 | Train Acc: 1.325| Val Acc: 1.947
# Epoch 148: | Train Loss: 11.84095 | Val Loss: 25.12106 | Train Acc: 1.320| Val Acc: 2.037
# Epoch 149: | Train Loss: 11.77268 | Val Loss: 24.91771 | Train Acc: 1.296| Val Acc: 1.981
# Epoch 150: | Train Loss: 11.71348 | Val Loss: 24.84685 | Train Acc: 1.293| Val Acc: 1.989

# %%
metrics(train, test, threshold=30)
# Out:
# MAE on train set:  136.7476607174743
# min prediction: 1
# max prediction: 1763
#
# MAE on test set:  163.0336758153777
# Error ⩽ 30: 16.96 %
# min prediction: 1
# max prediction: 1534

# %%
validation_plots(test,model_type)

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.000001, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)
# Out:
# Epoch 001: | Train Loss: 13.45704 | Val Loss: 3.08771 | Train Acc: 1.555| Val Acc: 1.633
# Epoch 002: | Train Loss: 13.48788 | Val Loss: 3.86079 | Train Acc: 1.534| Val Acc: 1.633
# Epoch 003: | Train Loss: 13.35306 | Val Loss: 4.06715 | Train Acc: 1.533| Val Acc: 1.633
# Epoch 004: | Train Loss: 13.23595 | Val Loss: 3.87462 | Train Acc: 1.503| Val Acc: 1.633
# Epoch 005: | Train Loss: 13.31440 | Val Loss: 5.00442 | Train Acc: 1.516| Val Acc: 2.633
# Epoch 006: | Train Loss: 13.06607 | Val Loss: 4.39366 | Train Acc: 1.478| Val Acc: 1.633
# Epoch 007: | Train Loss: 12.89381 | Val Loss: 3.52145 | Train Acc: 1.458| Val Acc: 1.633
# Epoch 008: | Train Loss: 12.96083 | Val Loss: 3.93702 | Train Acc: 1.456| Val Acc: 1.633
# Epoch 009: | Train Loss: 13.00305 | Val Loss: 4.12220 | Train Acc: 1.470| Val Acc: 1.633
# Epoch 010: | Train Loss: 12.91258 | Val Loss: 3.97275 | Train Acc: 1.458| Val Acc: 1.633
# Epoch 011: | Train Loss: 12.77928 | Val Loss: 4.30249 | Train Acc: 1.442| Val Acc: 1.633
# Epoch 012: | Train Loss: 12.80504 | Val Loss: 3.89468 | Train Acc: 1.428| Val Acc: 1.633
# Epoch 013: | Train Loss: 12.78702 | Val Loss: 5.46312 | Train Acc: 1.447| Val Acc: 2.633
# Epoch 014: | Train Loss: 12.83407 | Val Loss: 3.59652 | Train Acc: 1.433| Val Acc: 1.633
# Epoch 015: | Train Loss: 12.69985 | Val Loss: 4.71948 | Train Acc: 1.422| Val Acc: 2.633
# Epoch 016: | Train Loss: 12.71814 | Val Loss: 3.26183 | Train Acc: 1.432| Val Acc: 1.633
# Epoch 017: | Train Loss: 12.75029 | Val Loss: 4.05856 | Train Acc: 1.432| Val Acc: 1.633
# Epoch 018: | Train Loss: 12.80488 | Val Loss: 3.45682 | Train Acc: 1.441| Val Acc: 1.633
# Epoch 019: | Train Loss: 12.85485 | Val Loss: 3.48255 | Train Acc: 1.429| Val Acc: 1.633
# Epoch 020: | Train Loss: 12.71953 | Val Loss: 3.04803 | Train Acc: 1.428| Val Acc: 1.633
# Epoch 021: | Train Loss: 12.68148 | Val Loss: 3.72125 | Train Acc: 1.425| Val Acc: 1.633
# Epoch 022: | Train Loss: 12.66718 | Val Loss: 3.86201 | Train Acc: 1.433| Val Acc: 1.633
# Epoch 023: | Train Loss: 12.65603 | Val Loss: 4.31283 | Train Acc: 1.422| Val Acc: 1.633
# Epoch 024: | Train Loss: 12.57196 | Val Loss: 3.85637 | Train Acc: 1.411| Val Acc: 1.633
# Epoch 025: | Train Loss: 12.64670 | Val Loss: 3.42763 | Train Acc: 1.414| Val Acc: 1.633
# Epoch 026: | Train Loss: 12.92195 | Val Loss: 5.86369 | Train Acc: 1.462| Val Acc: 2.633
# Epoch 027: | Train Loss: 13.00736 | Val Loss: 4.93836 | Train Acc: 1.460| Val Acc: 2.633
# Epoch 028: | Train Loss: 12.84723 | Val Loss: 4.14289 | Train Acc: 1.455| Val Acc: 1.633
# Epoch 029: | Train Loss: 12.60333 | Val Loss: 4.12035 | Train Acc: 1.428| Val Acc: 1.633
# Epoch 030: | Train Loss: 12.67108 | Val Loss: 4.15922 | Train Acc: 1.419| Val Acc: 1.633
# Epoch 031: | Train Loss: 12.47703 | Val Loss: 4.81780 | Train Acc: 1.400| Val Acc: 2.633
# Epoch 032: | Train Loss: 12.57894 | Val Loss: 4.41170 | Train Acc: 1.407| Val Acc: 1.633
# Epoch 033: | Train Loss: 12.66492 | Val Loss: 4.76300 | Train Acc: 1.414| Val Acc: 2.633
# Epoch 034: | Train Loss: 12.53756 | Val Loss: 4.30455 | Train Acc: 1.421| Val Acc: 1.633
# Epoch 035: | Train Loss: 12.41938 | Val Loss: 4.09164 | Train Acc: 1.392| Val Acc: 1.633
# Epoch 036: | Train Loss: 12.47151 | Val Loss: 3.30861 | Train Acc: 1.389| Val Acc: 1.633
# Epoch 037: | Train Loss: 12.57372 | Val Loss: 3.75827 | Train Acc: 1.408| Val Acc: 1.633
# Epoch 038: | Train Loss: 12.48509 | Val Loss: 3.80203 | Train Acc: 1.393| Val Acc: 1.633
# Epoch 039: | Train Loss: 12.38317 | Val Loss: 3.41804 | Train Acc: 1.396| Val Acc: 1.633
# Epoch 040: | Train Loss: 12.52758 | Val Loss: 4.12968 | Train Acc: 1.421| Val Acc: 1.633
# Epoch 041: | Train Loss: 12.51896 | Val Loss: 4.55398 | Train Acc: 1.406| Val Acc: 2.633
# Epoch 042: | Train Loss: 12.52009 | Val Loss: 3.34395 | Train Acc: 1.422| Val Acc: 1.633
# Epoch 043: | Train Loss: 12.60838 | Val Loss: 3.95748 | Train Acc: 1.400| Val Acc: 1.633
# Epoch 044: | Train Loss: 12.22554 | Val Loss: 4.00855 | Train Acc: 1.381| Val Acc: 1.633
# Epoch 045: | Train Loss: 12.46804 | Val Loss: 5.05153 | Train Acc: 1.415| Val Acc: 2.633
# Epoch 046: | Train Loss: 12.41242 | Val Loss: 4.23626 | Train Acc: 1.395| Val Acc: 1.633
# Epoch 047: | Train Loss: 12.32935 | Val Loss: 3.05843 | Train Acc: 1.389| Val Acc: 1.633
# Epoch 048: | Train Loss: 12.22726 | Val Loss: 2.88019 | Train Acc: 1.374| Val Acc: 1.633
# Epoch 049: | Train Loss: 12.32449 | Val Loss: 4.11487 | Train Acc: 1.386| Val Acc: 1.633
# Epoch 050: | Train Loss: 12.24439 | Val Loss: 4.36304 | Train Acc: 1.388| Val Acc: 1.633
# Epoch 051: | Train Loss: 12.13691 | Val Loss: 4.79139 | Train Acc: 1.361| Val Acc: 2.633
# Epoch 052: | Train Loss: 12.34109 | Val Loss: 5.06507 | Train Acc: 1.375| Val Acc: 2.633
# Epoch 053: | Train Loss: 12.15593 | Val Loss: 4.90095 | Train Acc: 1.350| Val Acc: 2.633
# Epoch 054: | Train Loss: 12.31488 | Val Loss: 5.37426 | Train Acc: 1.366| Val Acc: 2.633
# Epoch 055: | Train Loss: 12.17810 | Val Loss: 4.66933 | Train Acc: 1.368| Val Acc: 2.633
# Epoch 056: | Train Loss: 12.14010 | Val Loss: 3.11838 | Train Acc: 1.358| Val Acc: 1.633
# Epoch 057: | Train Loss: 12.22689 | Val Loss: 3.50796 | Train Acc: 1.369| Val Acc: 1.633
# Epoch 058: | Train Loss: 12.12197 | Val Loss: 4.18982 | Train Acc: 1.366| Val Acc: 1.633
# Epoch 059: | Train Loss: 12.18010 | Val Loss: 6.45520 | Train Acc: 1.360| Val Acc: 2.633
# Epoch 060: | Train Loss: 12.20583 | Val Loss: 4.28253 | Train Acc: 1.359| Val Acc: 1.633
# Epoch 061: | Train Loss: 12.15488 | Val Loss: 4.51070 | Train Acc: 1.356| Val Acc: 1.633
# Epoch 062: | Train Loss: 12.15505 | Val Loss: 5.18710 | Train Acc: 1.357| Val Acc: 2.633
# Epoch 063: | Train Loss: 12.17059 | Val Loss: 5.66584 | Train Acc: 1.349| Val Acc: 2.633
# Epoch 064: | Train Loss: 12.13077 | Val Loss: 5.52547 | Train Acc: 1.357| Val Acc: 2.633
# Epoch 065: | Train Loss: 12.08751 | Val Loss: 4.20261 | Train Acc: 1.361| Val Acc: 1.633
# Epoch 066: | Train Loss: 12.28872 | Val Loss: 5.87908 | Train Acc: 1.362| Val Acc: 2.633
# Epoch 067: | Train Loss: 12.15915 | Val Loss: 5.59568 | Train Acc: 1.360| Val Acc: 2.633
# Epoch 068: | Train Loss: 12.27338 | Val Loss: 4.35068 | Train Acc: 1.374| Val Acc: 1.633
# Epoch 069: | Train Loss: 12.17798 | Val Loss: 3.63980 | Train Acc: 1.356| Val Acc: 1.633
# Epoch 070: | Train Loss: 12.17195 | Val Loss: 3.70793 | Train Acc: 1.369| Val Acc: 1.633
# Epoch 071: | Train Loss: 12.20582 | Val Loss: 5.03857 | Train Acc: 1.354| Val Acc: 2.633
# Epoch 072: | Train Loss: 12.12042 | Val Loss: 3.26951 | Train Acc: 1.351| Val Acc: 1.633
# Epoch 073: | Train Loss: 12.04619 | Val Loss: 3.47668 | Train Acc: 1.342| Val Acc: 1.633
# Epoch 074: | Train Loss: 12.08728 | Val Loss: 2.76751 | Train Acc: 1.344| Val Acc: 1.633
# Epoch 075: | Train Loss: 12.29516 | Val Loss: 2.56784 | Train Acc: 1.356| Val Acc: 1.633
# Epoch 076: | Train Loss: 12.23601 | Val Loss: 2.13653 | Train Acc: 1.369| Val Acc: 1.633
# Epoch 077: | Train Loss: 12.15980 | Val Loss: 3.63281 | Train Acc: 1.334| Val Acc: 1.633
# Epoch 078: | Train Loss: 12.06040 | Val Loss: 2.55003 | Train Acc: 1.339| Val Acc: 1.633
# Epoch 079: | Train Loss: 12.29156 | Val Loss: 2.72779 | Train Acc: 1.366| Val Acc: 1.633
# Epoch 080: | Train Loss: 12.16488 | Val Loss: 2.18994 | Train Acc: 1.348| Val Acc: 1.633
# Epoch 081: | Train Loss: 12.11364 | Val Loss: 2.93704 | Train Acc: 1.342| Val Acc: 1.633
# Epoch 082: | Train Loss: 12.34539 | Val Loss: 3.59596 | Train Acc: 1.375| Val Acc: 1.633
# Epoch 083: | Train Loss: 12.25776 | Val Loss: 2.33075 | Train Acc: 1.367| Val Acc: 1.633
# Epoch 084: | Train Loss: 12.14804 | Val Loss: 2.78324 | Train Acc: 1.360| Val Acc: 1.633
# Epoch 085: | Train Loss: 12.20825 | Val Loss: 2.99344 | Train Acc: 1.361| Val Acc: 1.633
# Epoch 086: | Train Loss: 12.12889 | Val Loss: 2.95378 | Train Acc: 1.349| Val Acc: 1.633
# Epoch 087: | Train Loss: 12.05915 | Val Loss: 4.25698 | Train Acc: 1.344| Val Acc: 1.633
# Epoch 088: | Train Loss: 12.05287 | Val Loss: 4.54566 | Train Acc: 1.335| Val Acc: 1.633
# Epoch 089: | Train Loss: 12.16779 | Val Loss: 2.69805 | Train Acc: 1.343| Val Acc: 1.633
# Epoch 090: | Train Loss: 12.03406 | Val Loss: 2.73223 | Train Acc: 1.335| Val Acc: 1.633
# Epoch 091: | Train Loss: 12.05483 | Val Loss: 2.38873 | Train Acc: 1.333| Val Acc: 1.633
# Epoch 092: | Train Loss: 12.09124 | Val Loss: 3.22078 | Train Acc: 1.326| Val Acc: 1.633
# Epoch 093: | Train Loss: 12.12865 | Val Loss: 3.41053 | Train Acc: 1.335| Val Acc: 1.633
# Epoch 094: | Train Loss: 12.03199 | Val Loss: 2.40331 | Train Acc: 1.325| Val Acc: 1.633
# Epoch 095: | Train Loss: 12.00705 | Val Loss: 2.95892 | Train Acc: 1.319| Val Acc: 1.633
# Epoch 096: | Train Loss: 12.08061 | Val Loss: 3.48608 | Train Acc: 1.328| Val Acc: 1.633
# Epoch 097: | Train Loss: 11.91673 | Val Loss: 3.83738 | Train Acc: 1.318| Val Acc: 1.633
# Epoch 098: | Train Loss: 12.08181 | Val Loss: 3.15784 | Train Acc: 1.328| Val Acc: 1.633
# Epoch 099: | Train Loss: 12.03355 | Val Loss: 2.03832 | Train Acc: 1.333| Val Acc: 1.633
# Epoch 100: | Train Loss: 12.08280 | Val Loss: 2.52268 | Train Acc: 1.330| Val Acc: 1.633
# Epoch 101: | Train Loss: 12.17564 | Val Loss: 2.56980 | Train Acc: 1.327| Val Acc: 1.633
# Epoch 102: | Train Loss: 12.08940 | Val Loss: 2.42315 | Train Acc: 1.339| Val Acc: 1.633
# Epoch 103: | Train Loss: 12.18826 | Val Loss: 3.64768 | Train Acc: 1.348| Val Acc: 1.633
# Epoch 104: | Train Loss: 12.09199 | Val Loss: 2.09650 | Train Acc: 1.354| Val Acc: 1.633
# Epoch 105: | Train Loss: 12.17696 | Val Loss: 2.63739 | Train Acc: 1.341| Val Acc: 1.633
# Epoch 106: | Train Loss: 11.95189 | Val Loss: 2.94661 | Train Acc: 1.318| Val Acc: 1.633
# Epoch 107: | Train Loss: 12.13334 | Val Loss: 2.00997 | Train Acc: 1.318| Val Acc: 1.633
# Epoch 108: | Train Loss: 12.02888 | Val Loss: 2.19975 | Train Acc: 1.328| Val Acc: 1.633
# Epoch 109: | Train Loss: 11.99747 | Val Loss: 2.25350 | Train Acc: 1.315| Val Acc: 1.633
# Epoch 110: | Train Loss: 11.99089 | Val Loss: 2.59454 | Train Acc: 1.311| Val Acc: 1.633
# Epoch 111: | Train Loss: 11.99463 | Val Loss: 3.74436 | Train Acc: 1.315| Val Acc: 1.633
# Epoch 112: | Train Loss: 11.99708 | Val Loss: 3.17027 | Train Acc: 1.325| Val Acc: 1.633
# Epoch 113: | Train Loss: 12.04894 | Val Loss: 3.88187 | Train Acc: 1.334| Val Acc: 1.633
# Epoch 114: | Train Loss: 12.01303 | Val Loss: 2.15948 | Train Acc: 1.319| Val Acc: 1.633
# Epoch 115: | Train Loss: 11.97115 | Val Loss: 2.20083 | Train Acc: 1.313| Val Acc: 1.633
# Epoch 116: | Train Loss: 11.90067 | Val Loss: 2.24595 | Train Acc: 1.305| Val Acc: 1.633
# Epoch 117: | Train Loss: 12.03807 | Val Loss: 3.59165 | Train Acc: 1.319| Val Acc: 1.633
# Epoch 118: | Train Loss: 12.17544 | Val Loss: 3.35222 | Train Acc: 1.330| Val Acc: 1.633
# Epoch 119: | Train Loss: 12.03620 | Val Loss: 2.19272 | Train Acc: 1.309| Val Acc: 1.633
# Epoch 120: | Train Loss: 11.94494 | Val Loss: 2.46115 | Train Acc: 1.306| Val Acc: 1.633
# Epoch 121: | Train Loss: 12.10113 | Val Loss: 3.14957 | Train Acc: 1.324| Val Acc: 1.633
# Epoch 122: | Train Loss: 12.12227 | Val Loss: 2.25728 | Train Acc: 1.340| Val Acc: 1.633
# Epoch 123: | Train Loss: 12.02688 | Val Loss: 1.72160 | Train Acc: 1.324| Val Acc: 1.633
# Epoch 124: | Train Loss: 11.90254 | Val Loss: 1.28985 | Train Acc: 1.288| Val Acc: 1.633
# Epoch 125: | Train Loss: 11.95912 | Val Loss: 1.44779 | Train Acc: 1.298| Val Acc: 1.633
# Epoch 126: | Train Loss: 12.09326 | Val Loss: 2.52240 | Train Acc: 1.329| Val Acc: 1.633
# Epoch 127: | Train Loss: 12.05867 | Val Loss: 0.94411 | Train Acc: 1.326| Val Acc: 0.633
# Epoch 128: | Train Loss: 12.06445 | Val Loss: 1.85630 | Train Acc: 1.336| Val Acc: 1.633
# Epoch 129: | Train Loss: 12.10091 | Val Loss: 4.27562 | Train Acc: 1.318| Val Acc: 1.633
# Epoch 130: | Train Loss: 11.96653 | Val Loss: 2.86137 | Train Acc: 1.314| Val Acc: 1.633
# Epoch 131: | Train Loss: 12.01156 | Val Loss: 2.36904 | Train Acc: 1.313| Val Acc: 1.633
# Epoch 132: | Train Loss: 12.06975 | Val Loss: 2.46502 | Train Acc: 1.324| Val Acc: 1.633
# Epoch 133: | Train Loss: 12.08955 | Val Loss: 2.00211 | Train Acc: 1.314| Val Acc: 1.633
# Epoch 134: | Train Loss: 12.06383 | Val Loss: 2.42183 | Train Acc: 1.339| Val Acc: 1.633
# Epoch 135: | Train Loss: 12.07367 | Val Loss: 1.33803 | Train Acc: 1.332| Val Acc: 1.633
# Epoch 136: | Train Loss: 12.11663 | Val Loss: 2.36722 | Train Acc: 1.322| Val Acc: 1.633
# Epoch 137: | Train Loss: 12.01169 | Val Loss: 1.23037 | Train Acc: 1.318| Val Acc: 0.633
# Epoch 138: | Train Loss: 12.00843 | Val Loss: 2.83402 | Train Acc: 1.320| Val Acc: 1.633
# Epoch 139: | Train Loss: 11.99539 | Val Loss: 4.73070 | Train Acc: 1.305| Val Acc: 2.633
# Epoch 140: | Train Loss: 12.00129 | Val Loss: 3.10671 | Train Acc: 1.309| Val Acc: 1.633
# Epoch 141: | Train Loss: 11.97276 | Val Loss: 2.69514 | Train Acc: 1.316| Val Acc: 1.633
# Epoch 142: | Train Loss: 12.02713 | Val Loss: 1.35460 | Train Acc: 1.319| Val Acc: 1.633
# Epoch 143: | Train Loss: 11.99594 | Val Loss: 2.25583 | Train Acc: 1.306| Val Acc: 1.633
# Epoch 144: | Train Loss: 12.02482 | Val Loss: 1.66950 | Train Acc: 1.319| Val Acc: 1.633
# Epoch 145: | Train Loss: 12.00177 | Val Loss: 2.37668 | Train Acc: 1.311| Val Acc: 1.633
# Epoch 146: | Train Loss: 12.04234 | Val Loss: 2.66173 | Train Acc: 1.317| Val Acc: 1.633
# Epoch 147: | Train Loss: 12.03323 | Val Loss: 3.81144 | Train Acc: 1.313| Val Acc: 1.633
# Epoch 148: | Train Loss: 12.01861 | Val Loss: 3.07738 | Train Acc: 1.316| Val Acc: 1.633
# Epoch 149: | Train Loss: 11.95270 | Val Loss: 3.45380 | Train Acc: 1.307| Val Acc: 1.633
# Epoch 150: | Train Loss: 11.92932 | Val Loss: 5.00159 | Train Acc: 1.306| Val Acc: 2.633

# %%
pickle.dump(model, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_Mamoth_NN.pt', 'wb'))
pickle.dump(imputer, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_KNN_Imputer.pkl', 'wb'))
pickle.dump(scaler, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_Scaler.pkl', 'wb'))
