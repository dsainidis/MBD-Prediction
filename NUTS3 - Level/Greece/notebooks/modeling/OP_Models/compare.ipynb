# %%
attica = ['monthly_lst_min', 'lst_day_mean', 'rainfall_mean', 'bio19',
       'lst_night_mean', 'bio16', 'acc_rainfall_1week', 'acc_rainfall_jan',
       'bio18', 'ndwi', 'bio12', 'month_cos', 'bio11', 'males_15t64', 'bio3',
       'bio8', 'males_total', 'lst_feb_night_mean', 'monthly_lst_max',
       'ndwi_mean']

# %%
cmacedonia = ['lst_night_mean', 'month_sin', 'mosq_pred_acc', 'mio_eur',
       'monthly_lst_min', 'lst_feb_day_mean', 'ndvi_std', 'monthly_lst_max',
       'bio8', 'bio17', 'bio9', 'lst_feb_mean', 'acc_rainfall_1week',
       'acc_rainfall_2week', 'ndwi', 'bio14', 'bio15', 'lst_apr_mean', 'ndvi',
       'flow_accu_200m']

# %%
thrace = ['monthly_lst_max', 'monthly_lst_min', 'lst_mar_night_mean', 'ndmi',
       'lst_night_mean', 'ndwi_std', 'month_sin', 'ndmi_mean', 'bio9', 'ndwi',
       'bio4', 'males_lt15', 'bio17', 'lst_feb_day_mean', 'unl_total', 'ndvi',
       'lst_feb_mean', 'acc_rainfall_1week', 'bio8', 'bio1']

# %%
thessaly = ['lst_night_mean', 'lst_feb_night_mean', 'bio13', 'acc_rainfall_2week',
       'males_15t64', 'acc_rainfall_month', 'monthly_lst_max', 'mosq_pred_acc',
       'ndwi', 'lst_feb_day_mean', 'ndmi_std', 'bio1', 'acc_rainfall_jan',
       'bio14', 'monthly_lst_min', 'bio10', 'mosq_pred_mean', 'bio15', 'bio18',
       'bio9']

# %%
attica_cm = [item for item in attica if item in cmacedonia]
attica_cm
# Out:
# ['monthly_lst_min',
#  'lst_night_mean',
#  'acc_rainfall_1week',
#  'ndwi',
#  'bio8',
#  'monthly_lst_max']

# %%
attica_thrace = [item for item in attica if item in thrace]
attica_thrace
# Out:
# ['monthly_lst_min',
#  'lst_night_mean',
#  'acc_rainfall_1week',
#  'ndwi',
#  'bio8',
#  'monthly_lst_max']

# %%
attica_thessaly = [item for item in attica if item in thessaly]
attica_thessaly
# Out:
# ['monthly_lst_min',
#  'lst_night_mean',
#  'acc_rainfall_jan',
#  'bio18',
#  'ndwi',
#  'males_15t64',
#  'lst_feb_night_mean',
#  'monthly_lst_max']

# %%
cm_thrace = [item for item in cmacedonia if item in thrace]
cm_thrace
# Out:
# ['lst_night_mean',
#  'month_sin',
#  'monthly_lst_min',
#  'lst_feb_day_mean',
#  'monthly_lst_max',
#  'bio8',
#  'bio17',
#  'bio9',
#  'lst_feb_mean',
#  'acc_rainfall_1week',
#  'ndwi',
#  'ndvi']

# %%
cm_thessaly = [item for item in cmacedonia if item in thessaly]
cm_thessaly
# Out:
# ['lst_night_mean',
#  'mosq_pred_acc',
#  'monthly_lst_min',
#  'lst_feb_day_mean',
#  'monthly_lst_max',
#  'bio9',
#  'acc_rainfall_2week',
#  'ndwi',
#  'bio14',
#  'bio15']

# %%
thrace_thessaly = [item for item in thrace if item in thessaly]
thrace_thessaly
# Out:
# ['monthly_lst_max',
#  'monthly_lst_min',
#  'lst_night_mean',
#  'bio9',
#  'ndwi',
#  'lst_feb_day_mean',
#  'bio1']

# %%
thrace_thessaly = [item for item in thessaly if item in thrace]
thrace_thessaly
# Out:
# ['lst_night_mean',
#  'monthly_lst_max',
#  'ndwi',
#  'lst_feb_day_mean',
#  'bio1',
#  'monthly_lst_min',
#  'bio9']
