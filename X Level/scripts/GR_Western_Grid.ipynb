# %%
import pandas as pd

import random
import geopandas as gpd
import numpy as np
import os

import sys

sys.path.insert(0, "../../Modules")

from utils import process_greek, create_grid

enc = 'utf-8'
dec = 'greek8'
random.seed(0)
np.random.seed(0)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
NUTS0 = 'GR'
NUTS2 = 'Western'
NUTS2_ID = 'EL63'
NUTS1_COLNAME = 'NUTS1_ID'
NUTS2_COLNAME = 'NUTS2_ID'

# %%
shapefile_gdf = gpd.read_file(f"../../Europe Shapefiles/Greece/data/EL_Whole.shp",  encoding=enc)

# %%
shapefile_gdf.head()
# Out:
#   CNTR_CODE CNTR_NAME NUTS1_ID NUTS1_LATN NUTS1_NAME NUTS2_ID NUTS2_LATN  \
# 0        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
# 1        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
# 2        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
# 3        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
# 4        EL    Greece      EL3     Attiki     Αττική     EL30     Attiki
#
#   NUTS2_NAME NUTS3_ID                NUTS3_LATN               NUTS3_NAME  \
# 0     Aττική    EL301    Voreios Tomeas Athinon    Βόρειος Τομέας Αθηνών
# 1     Aττική    EL302    Dytikos Tomeas Athinon    Δυτικός Τομέας Αθηνών
# 2     Aττική    EL303  Kentrikos Tomeas Athinon  Κεντρικός Τομέας Αθηνών
# 3     Aττική    EL304     Notios Tomeas Athinon     Νότιος Τομέας Αθηνών
# 4     Aττική    EL305          Anatoliki Attiki         Ανατολική Αττική
#
#    MOUNT_TYPE  URBN_TYPE  COAST_TYPE  \
# 0         4.0          1           2
# 1         4.0          1           1
# 2         4.0          1           2
# 3         4.0          1           1
# 4         2.0          1           1
#
#                                             geometry
# 0  POLYGON ((23.82310 37.97392, 23.80300 37.98545...
# 1  MULTIPOLYGON (((23.72005 38.06296, 23.72884 38...
# 2  POLYGON ((23.82310 37.97392, 23.82185 37.97195...
# 3  POLYGON ((23.80679 37.91784, 23.80240 37.91205...
# 4  MULTIPOLYGON (((24.10518 38.18205, 24.10171 38...

# %%
print(f'shapefile\'s CRS before conversion: {shapefile_gdf.crs}')
shapefile_gdf = shapefile_gdf.to_crs(epsg=4326)
print(f'shapefile\'s CRS after conversion: {shapefile_gdf.crs}')
# Out:
# shapefile's CRS before conversion: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433],AXIS["Longitude",EAST],AXIS["Latitude",NORTH]]
# shapefile's CRS after conversion: EPSG:4326

# %%
shapefile_gdf[NUTS2_COLNAME].unique()
# Out:
# array(['EL30', 'EL41', 'EL42', 'EL43', 'EL51', 'EL52', 'EL53', 'EL54',
#        'EL61', 'EL62', 'EL63', 'EL64', 'EL65'], dtype=object)

# %%
nuts3_gdf = shapefile_gdf.loc[shapefile_gdf[NUTS2_COLNAME] == f'{NUTS2_ID}'].copy()
nuts3_gdf.head()
# Out:
#    CNTR_CODE CNTR_NAME NUTS1_ID       NUTS1_LATN       NUTS1_NAME NUTS2_ID  \
# 41        EL    Greece      EL6  Kentriki Elláda  Κεντρική Ελλάδα     EL63
# 42        EL    Greece      EL6  Kentriki Elláda  Κεντρική Ελλάδα     EL63
# 43        EL    Greece      EL6  Kentriki Elláda  Κεντρική Ελλάδα     EL63
#
#        NUTS2_LATN     NUTS2_NAME NUTS3_ID       NUTS3_LATN       NUTS3_NAME  \
# 41  Dytiki Elláda  Δυτική Ελλάδα    EL631  Aitoloakarnania  Αιτωλοακαρνανία
# 42  Dytiki Elláda  Δυτική Ελλάδα    EL632           Achaia            Αχαΐα
# 43  Dytiki Elláda  Δυτική Ελλάδα    EL633            Ileia            Ηλεία
#
#     MOUNT_TYPE  URBN_TYPE  COAST_TYPE  \
# 41         2.0          3           1
# 42         2.0          2           1
# 43         4.0          3           1
#
#                                              geometry
# 41  MULTIPOLYGON (((21.94600 38.78400, 21.97053 38...
# 42  POLYGON ((22.37297 38.14222, 22.37737 38.13451...
# 43  POLYGON ((21.88974 37.86589, 21.87963 37.86308...

# %%
nuts3_gdf.plot(facecolor="none", edgecolor='grey', figsize=(10, 10), color='orange')
# Out:
# <Axes: >

# %%
nuts2_gdf = nuts3_gdf.dissolve(by = NUTS1_COLNAME, as_index = False)

# %%
nuts2_gdf.plot(facecolor="none", edgecolor='grey', figsize=(10, 10), color='orange')
# Out:
# <Axes: >

# %%
nuts2_gdf = nuts2_gdf[['NUTS2_ID', 'NUTS2_NAME', 'geometry']]
nuts2_gdf.reset_index(inplace=True, drop = True)

# %%
empty_gdf = gpd.GeoDataFrame(columns=['geometry'], geometry='geometry', crs='EPSG:4326')

df_grid = create_grid(empty_gdf, nuts2_gdf, col_municipal=NUTS2_COLNAME, dimension=2)
# df_grid_2.to_csv('data/grid_2.csv', index=False)
# # df_grid_2 = pd.read_csv('data/grid_2.csv')
# # df_grid_2['geometry'] = gpd.GeoSeries.from_wkt(df_grid_2['geometry'])
# # df_grid_2 = gpd.GeoDataFrame(df_grid_2, geometry='geometry')

# %%
df_grid.shape
# Out:
# (2567, 5)

# %%
df_grid.head()
# Out:
#                                             geometry  \
# 0  POLYGON ((20.76333 38.79680, 20.76333 38.81477...
# 1  POLYGON ((20.76333 38.81477, 20.76333 38.83274...
# 2  POLYGON ((20.76333 38.83274, 20.76333 38.85070...
# 3  POLYGON ((20.78594 38.77884, 20.78594 38.79680...
# 4  POLYGON ((20.78594 38.79680, 20.78594 38.81477...
#
#                                          centers NUTS2_ID         x         y
# 0   POINT (20.752030187870567 38.80578598221707)     EL63  20.75203  38.80579
# 1  POINT (20.752030187870567 38.823752673817296)     EL63  20.75203  38.82375
# 2   POINT (20.752030187870567 38.84171936541751)     EL63  20.75203  38.84172
# 3    POINT (20.77463964645095 38.78781929061687)     EL63  20.77464  38.78782
# 4    POINT (20.77463964645095 38.80578598221707)     EL63  20.77464  38.80579

# %%
ax = nuts2_gdf.plot(figsize=(15, 15), facecolor="none", edgecolor='black', lw=2)
df_grid.plot(facecolor="none", edgecolor='grey', ax=ax, color='orange')
# Out:
# <Axes: >

# %%
df_grid.set_geometry('centers', inplace=True)

# %%
gdf_merged = gpd.sjoin(df_grid, nuts3_gdf, how='left', op='within')
gdf_merged.set_geometry('geometry', inplace=True)

# %%
ax = nuts3_gdf.plot(figsize=(15, 15), facecolor="none", edgecolor='black', lw=2)
gdf_merged[gdf_merged['NUTS3_ID'] == 'EL631'].plot(facecolor="none", edgecolor='grey', ax=ax, color='orange')
# Out:
# <Axes: >

# %%
gdf_merged.head()
# Out:
#                                             geometry  \
# 0  POLYGON ((20.76333 38.79680, 20.76333 38.81477...
# 1  POLYGON ((20.76333 38.81477, 20.76333 38.83274...
# 2  POLYGON ((20.76333 38.83274, 20.76333 38.85070...
# 3  POLYGON ((20.78594 38.77884, 20.78594 38.79680...
# 4  POLYGON ((20.78594 38.79680, 20.78594 38.81477...
#
#                      centers NUTS2_ID_left         x         y  index_right  \
# 0  POINT (20.75203 38.80579)          EL63  20.75203  38.80579           41
# 1  POINT (20.75203 38.82375)          EL63  20.75203  38.82375           41
# 2  POINT (20.75203 38.84172)          EL63  20.75203  38.84172           41
# 3  POINT (20.77464 38.78782)          EL63  20.77464  38.78782           41
# 4  POINT (20.77464 38.80579)          EL63  20.77464  38.80579           41
#
#   CNTR_CODE CNTR_NAME NUTS1_ID       NUTS1_LATN       NUTS1_NAME  \
# 0        EL    Greece      EL6  Kentriki Elláda  Κεντρική Ελλάδα
# 1        EL    Greece      EL6  Kentriki Elláda  Κεντρική Ελλάδα
# 2        EL    Greece      EL6  Kentriki Elláda  Κεντρική Ελλάδα
# 3        EL    Greece      EL6  Kentriki Elláda  Κεντρική Ελλάδα
# 4        EL    Greece      EL6  Kentriki Elláda  Κεντρική Ελλάδα
#
#   NUTS2_ID_right     NUTS2_LATN     NUTS2_NAME NUTS3_ID       NUTS3_LATN  \
# 0           EL63  Dytiki Elláda  Δυτική Ελλάδα    EL631  Aitoloakarnania
# 1           EL63  Dytiki Elláda  Δυτική Ελλάδα    EL631  Aitoloakarnania
# 2           EL63  Dytiki Elláda  Δυτική Ελλάδα    EL631  Aitoloakarnania
# 3           EL63  Dytiki Elláda  Δυτική Ελλάδα    EL631  Aitoloakarnania
# 4           EL63  Dytiki Elláda  Δυτική Ελλάδα    EL631  Aitoloakarnania
#
#         NUTS3_NAME  MOUNT_TYPE  URBN_TYPE  COAST_TYPE
# 0  Αιτωλοακαρνανία         2.0          3           1
# 1  Αιτωλοακαρνανία         2.0          3           1
# 2  Αιτωλοακαρνανία         2.0          3           1
# 3  Αιτωλοακαρνανία         2.0          3           1
# 4  Αιτωλοακαρνανία         2.0          3           1

# %%
final_grid = gdf_merged[['NUTS2_ID_left', 'NUTS2_NAME', 'NUTS3_ID', 'NUTS3_NAME', 'x', 'y', 'geometry']]
final_grid.set_geometry('geometry', inplace=True)
final_grid.rename(columns={'NUTS2_ID_left': "NUTS2_ID"}, inplace=True)
final_grid.sort_values(by=['NUTS3_ID', 'x', 'y'], inplace = True)
final_grid.reset_index(drop=True, inplace=True)

# %%
final_grid['cell_code'] = final_grid['NUTS3_ID'] + pd.Series(final_grid.index + 1).apply(lambda x: f"{x:06d}")
process_greek(final_grid, 'NUTS3_NAME')
process_greek(final_grid, 'NUTS2_NAME')

# %%
final_grid = final_grid[['NUTS2_ID', 'NUTS2_NAME', 'NUTS3_ID', 'NUTS3_NAME', 'x', 'y', 'cell_code', 'geometry']]

# %%
final_grid.head()
# Out:
#   NUTS2_ID     NUTS2_NAME NUTS3_ID       NUTS3_NAME         x         y  \
# 0     EL63  δυτικη ελλαδα    EL631  αιτωλοακαρνανια  20.75203  38.80579
# 1     EL63  δυτικη ελλαδα    EL631  αιτωλοακαρνανια  20.75203  38.82375
# 2     EL63  δυτικη ελλαδα    EL631  αιτωλοακαρνανια  20.75203  38.84172
# 3     EL63  δυτικη ελλαδα    EL631  αιτωλοακαρνανια  20.77464  38.78782
# 4     EL63  δυτικη ελλαδα    EL631  αιτωλοακαρνανια  20.77464  38.80579
#
#      cell_code                                           geometry
# 0  EL631000001  POLYGON ((20.76333 38.79680, 20.76333 38.81477...
# 1  EL631000002  POLYGON ((20.76333 38.81477, 20.76333 38.83274...
# 2  EL631000003  POLYGON ((20.76333 38.83274, 20.76333 38.85070...
# 3  EL631000004  POLYGON ((20.78594 38.77884, 20.78594 38.79680...
# 4  EL631000005  POLYGON ((20.78594 38.79680, 20.78594 38.81477...

# %%
final_grid.drop(columns='geometry').to_csv(f'../data/GR_{NUTS2}_Grid.csv', encoding=enc, index = False)
final_grid.to_file(f'../data/GR_{NUTS2}_Grid.shp', encoding = 'utf-8')
