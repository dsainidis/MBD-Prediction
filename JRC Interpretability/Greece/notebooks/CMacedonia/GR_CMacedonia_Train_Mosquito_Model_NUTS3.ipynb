# %% [markdown]
# ## Produces **Mosquito Predictions** for a specific region using MAMOTH ##

# %%
import pandas as pd
import datetime
import math
import numpy as np
import missingno
import json
from statistics import mean
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
import sys
import pickle

sys.path.insert(0, "../../../../Mamoth")
sys.path.insert(0, "../../../../Modules")

from utils import *

from Preprocessing_Module import read_data, select_columns, reshape_dataset
from Initializer_Module import initializer
from Neural_Network_Module import Dataset, transformations, FeedforwardNeuralNetModel, train_nn, give_predictions
from Model_Validation_Module import validation_plots, metrics

enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 100
pd.options.display.float_format = lambda x: '%.6f' % x

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
NUTS0 = 'GR'
NUTS2 = 'CMacedonia'
NUTS2_EL = 'κεντρικης μακεδονιας'

# %%
mosquito_data = read_data(f'../../data/{NUTS0}_MSQ_culex_2011-2022_processed.csv')
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
mosquito_data.nuts2.unique()
# Out:
# array(['κεντρικης μακεδονιας', 'θεσσαλιας', 'κρητης', 'δυτικης ελλαδας'],
#       dtype=object)

# %%
mosquito_data_nuts2 = mosquito_data.query(f"nuts2 == '{NUTS2_EL}'").copy()
mosquito_data_nuts2.reset_index(inplace = True, drop = True)

# %%
mosq_columns = mosquito_data_nuts2.columns
mosq_columns
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
                'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
                'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
                'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
                'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
                'acc_rainfall_jan', 'mosq_now']

# columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#                 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#                 'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#                 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#                 'lst_night', 'acc_rainfall_1week', 'acc_rainfall_2week',
#                 'acc_rainfall_jan', 'mosq_now']

mosquito_data_nuts2 = select_columns(mosquito_data_nuts2, columns_to_keep, columns_to_keep)

mosquito_data_nuts2 = reshape_dataset(mosquito_data_nuts2,['x','y','dt_placement'])

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()

# %%
#quantile might change based on sns plots
mosq_quantilie = mosquito_data_nuts2['mosq_now'].quantile(0.90)

mosquito_data_nuts2['mosq_now'][mosquito_data_nuts2['mosq_now'] > mosq_quantilie] = mosq_quantilie+1

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <AxesSubplot:>

# %%
imputer = KNNImputer()

features_for_impute = ['x', 'y', 'day', 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 
                        'lst_day', 'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean', 'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan']

# features_for_impute = ['x', 'y', 'day', 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#                         'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 
#                         'lst_day', 'lst_night', 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan']

mosquito_data_sub = mosquito_data_nuts2[features_for_impute]

imputed_data = pd.DataFrame(imputer.fit_transform(mosquito_data_sub), columns = mosquito_data_sub.columns)

# %%
# imputed_columns = ['ndvi','ndmi', 'ndwi', 'ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std', 'ndmi_std','ndwi_std','ndbi_std',
#                    'lst_day','lst_night']

imputed_columns = ['ndvi','ndmi', 'ndwi', 'ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std', 'ndmi_std','ndwi_std','ndbi_std',
                   'lst_day','lst_night','lst_jan_mean','lst_feb_mean','lst_mar_mean','lst_apr_mean']

mosquito_data_nuts2[imputed_columns] = imputed_data[imputed_columns]

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <AxesSubplot:>

# %%
step = 15
only_env = True
case_title = 'NN mosq regression'
exp = False
date_col = 'dt_placement'
model_type = 'mosquito_regression'
transform_target = True
augment = True

# %%
mosquito_data_nuts2 = initializer(mosquito_data_nuts2,2,10,25,step,[date_col], env=only_env, date_column = date_col, mosq_column='mosq_now')
# Out:
# Bounds: [  0.  85. 755.]

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.25, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

model = FeedforwardNeuralNetModel(num_features=len(train_X[0]), num_class=1, hidden_layers = [264,128,128,64], dropout=0.2, model_type=model_type, transform = transform_target)

# %%
train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)
# Out:
# Epoch 001: | Train Loss: 19.26871 | Val Loss: 25.16690 | Train Acc: 2.607| Val Acc: 2.069
# Epoch 002: | Train Loss: 18.85865 | Val Loss: 26.44855 | Train Acc: 2.302| Val Acc: 2.087
# Epoch 003: | Train Loss: 18.37672 | Val Loss: 25.73500 | Train Acc: 2.195| Val Acc: 2.076
# Epoch 004: | Train Loss: 17.97638 | Val Loss: 26.38235 | Train Acc: 2.133| Val Acc: 2.095
# Epoch 005: | Train Loss: 17.84687 | Val Loss: 24.72440 | Train Acc: 2.109| Val Acc: 1.969
# Epoch 006: | Train Loss: 17.50499 | Val Loss: 24.43615 | Train Acc: 2.036| Val Acc: 1.968
# Epoch 007: | Train Loss: 17.31731 | Val Loss: 24.27260 | Train Acc: 2.040| Val Acc: 1.981
# Epoch 008: | Train Loss: 17.12694 | Val Loss: 24.43066 | Train Acc: 1.994| Val Acc: 1.990
# Epoch 009: | Train Loss: 16.83035 | Val Loss: 24.03061 | Train Acc: 1.990| Val Acc: 1.971
# Epoch 010: | Train Loss: 16.80632 | Val Loss: 24.09471 | Train Acc: 1.981| Val Acc: 1.987
# Epoch 011: | Train Loss: 16.75847 | Val Loss: 24.04025 | Train Acc: 2.003| Val Acc: 1.987
# Epoch 012: | Train Loss: 16.47684 | Val Loss: 24.06941 | Train Acc: 1.988| Val Acc: 2.044
# Epoch 013: | Train Loss: 16.28062 | Val Loss: 24.10367 | Train Acc: 1.937| Val Acc: 2.011
# Epoch 014: | Train Loss: 16.22324 | Val Loss: 24.51757 | Train Acc: 1.948| Val Acc: 2.059
# Epoch 015: | Train Loss: 16.13117 | Val Loss: 24.83311 | Train Acc: 1.943| Val Acc: 2.092
# Epoch 016: | Train Loss: 15.91590 | Val Loss: 24.29116 | Train Acc: 1.950| Val Acc: 2.092
# Epoch 017: | Train Loss: 16.00043 | Val Loss: 24.70792 | Train Acc: 1.948| Val Acc: 2.087
# Epoch 018: | Train Loss: 15.72181 | Val Loss: 24.65174 | Train Acc: 1.914| Val Acc: 2.067
# Epoch 019: | Train Loss: 15.45431 | Val Loss: 24.95255 | Train Acc: 1.887| Val Acc: 2.161
# Epoch 020: | Train Loss: 15.27719 | Val Loss: 25.63327 | Train Acc: 1.867| Val Acc: 2.153
# Epoch 021: | Train Loss: 15.28298 | Val Loss: 25.55320 | Train Acc: 1.866| Val Acc: 2.206
# Epoch 022: | Train Loss: 15.24758 | Val Loss: 25.42357 | Train Acc: 1.858| Val Acc: 2.166
# Epoch 023: | Train Loss: 14.98522 | Val Loss: 25.68063 | Train Acc: 1.847| Val Acc: 2.212
# Epoch 024: | Train Loss: 14.89873 | Val Loss: 25.69505 | Train Acc: 1.808| Val Acc: 2.141
# Epoch 025: | Train Loss: 14.82312 | Val Loss: 26.00498 | Train Acc: 1.805| Val Acc: 2.257
# Epoch 026: | Train Loss: 14.83965 | Val Loss: 26.01581 | Train Acc: 1.805| Val Acc: 2.214
# Epoch 027: | Train Loss: 14.60637 | Val Loss: 26.17147 | Train Acc: 1.791| Val Acc: 2.212
# Epoch 028: | Train Loss: 14.56487 | Val Loss: 26.18560 | Train Acc: 1.797| Val Acc: 2.237
# Epoch 029: | Train Loss: 14.28771 | Val Loss: 26.49870 | Train Acc: 1.752| Val Acc: 2.205
# Epoch 030: | Train Loss: 14.22755 | Val Loss: 25.88127 | Train Acc: 1.751| Val Acc: 2.243
# Epoch 031: | Train Loss: 14.24147 | Val Loss: 26.67368 | Train Acc: 1.746| Val Acc: 2.269
# Epoch 032: | Train Loss: 14.15357 | Val Loss: 26.52853 | Train Acc: 1.727| Val Acc: 2.234
# Epoch 033: | Train Loss: 14.08044 | Val Loss: 25.71669 | Train Acc: 1.712| Val Acc: 2.156
# Epoch 034: | Train Loss: 13.87991 | Val Loss: 25.79566 | Train Acc: 1.704| Val Acc: 2.136
# Epoch 035: | Train Loss: 13.74080 | Val Loss: 26.31935 | Train Acc: 1.684| Val Acc: 2.213
# Epoch 036: | Train Loss: 13.57342 | Val Loss: 26.10750 | Train Acc: 1.661| Val Acc: 2.201
# Epoch 037: | Train Loss: 13.51995 | Val Loss: 25.68257 | Train Acc: 1.634| Val Acc: 2.160
# Epoch 038: | Train Loss: 13.49018 | Val Loss: 25.80012 | Train Acc: 1.650| Val Acc: 2.151
# Epoch 039: | Train Loss: 13.46841 | Val Loss: 26.33013 | Train Acc: 1.632| Val Acc: 2.154
# Epoch 040: | Train Loss: 13.43904 | Val Loss: 25.66107 | Train Acc: 1.636| Val Acc: 2.131
# Epoch 041: | Train Loss: 13.44089 | Val Loss: 26.24343 | Train Acc: 1.625| Val Acc: 2.117
# Epoch 042: | Train Loss: 13.20724 | Val Loss: 25.59918 | Train Acc: 1.586| Val Acc: 2.112
# Epoch 043: | Train Loss: 13.28564 | Val Loss: 25.70750 | Train Acc: 1.595| Val Acc: 2.138
# Epoch 044: | Train Loss: 13.17654 | Val Loss: 26.05038 | Train Acc: 1.583| Val Acc: 2.161
# Epoch 045: | Train Loss: 12.93911 | Val Loss: 25.93105 | Train Acc: 1.561| Val Acc: 2.131
# Epoch 046: | Train Loss: 13.16161 | Val Loss: 25.03967 | Train Acc: 1.592| Val Acc: 2.135
# Epoch 047: | Train Loss: 12.98267 | Val Loss: 25.62142 | Train Acc: 1.565| Val Acc: 2.094
# Epoch 048: | Train Loss: 13.01527 | Val Loss: 24.96137 | Train Acc: 1.558| Val Acc: 2.071
# Epoch 049: | Train Loss: 12.95978 | Val Loss: 25.64728 | Train Acc: 1.561| Val Acc: 2.108
# Epoch 050: | Train Loss: 12.76545 | Val Loss: 24.99307 | Train Acc: 1.524| Val Acc: 2.100
# Epoch 051: | Train Loss: 12.74264 | Val Loss: 25.44986 | Train Acc: 1.534| Val Acc: 2.079
# Epoch 052: | Train Loss: 12.84314 | Val Loss: 25.67893 | Train Acc: 1.550| Val Acc: 2.077
# Epoch 053: | Train Loss: 12.90048 | Val Loss: 25.48717 | Train Acc: 1.542| Val Acc: 2.086
# Epoch 054: | Train Loss: 12.79237 | Val Loss: 24.91115 | Train Acc: 1.525| Val Acc: 2.051
# Epoch 055: | Train Loss: 12.66151 | Val Loss: 25.16053 | Train Acc: 1.505| Val Acc: 2.036
# Epoch 056: | Train Loss: 12.68942 | Val Loss: 24.99875 | Train Acc: 1.516| Val Acc: 2.027
# Epoch 057: | Train Loss: 12.60769 | Val Loss: 24.67778 | Train Acc: 1.491| Val Acc: 1.987
# Epoch 058: | Train Loss: 12.68286 | Val Loss: 25.38880 | Train Acc: 1.500| Val Acc: 2.067
# Epoch 059: | Train Loss: 12.61187 | Val Loss: 25.33075 | Train Acc: 1.491| Val Acc: 2.064
# Epoch 060: | Train Loss: 12.52356 | Val Loss: 25.19283 | Train Acc: 1.503| Val Acc: 2.032
# Epoch 061: | Train Loss: 12.45852 | Val Loss: 24.52030 | Train Acc: 1.475| Val Acc: 2.002
# Epoch 062: | Train Loss: 12.62839 | Val Loss: 25.36748 | Train Acc: 1.488| Val Acc: 2.064
# Epoch 063: | Train Loss: 12.50486 | Val Loss: 24.79359 | Train Acc: 1.479| Val Acc: 2.040
# Epoch 064: | Train Loss: 12.66675 | Val Loss: 25.25729 | Train Acc: 1.503| Val Acc: 2.071
# Epoch 065: | Train Loss: 12.38699 | Val Loss: 24.44337 | Train Acc: 1.460| Val Acc: 1.981
# Epoch 066: | Train Loss: 12.52616 | Val Loss: 24.55569 | Train Acc: 1.493| Val Acc: 2.019
# Epoch 067: | Train Loss: 12.57078 | Val Loss: 25.13516 | Train Acc: 1.473| Val Acc: 2.056
# Epoch 068: | Train Loss: 12.46434 | Val Loss: 25.41170 | Train Acc: 1.464| Val Acc: 2.051
# Epoch 069: | Train Loss: 12.34291 | Val Loss: 24.32903 | Train Acc: 1.464| Val Acc: 1.975
# Epoch 070: | Train Loss: 12.41900 | Val Loss: 24.42243 | Train Acc: 1.457| Val Acc: 1.954
# Epoch 071: | Train Loss: 12.51071 | Val Loss: 25.30895 | Train Acc: 1.465| Val Acc: 2.060
# Epoch 072: | Train Loss: 12.48137 | Val Loss: 24.20691 | Train Acc: 1.466| Val Acc: 1.955
# Epoch 073: | Train Loss: 12.43804 | Val Loss: 25.10605 | Train Acc: 1.454| Val Acc: 2.001
# Epoch 074: | Train Loss: 12.40226 | Val Loss: 24.62114 | Train Acc: 1.452| Val Acc: 2.028
# Epoch 075: | Train Loss: 12.26327 | Val Loss: 24.67531 | Train Acc: 1.434| Val Acc: 1.970
# Epoch 076: | Train Loss: 12.35518 | Val Loss: 24.35885 | Train Acc: 1.438| Val Acc: 1.954
# Epoch 077: | Train Loss: 12.31652 | Val Loss: 24.46099 | Train Acc: 1.436| Val Acc: 1.962
# Epoch 078: | Train Loss: 12.29583 | Val Loss: 24.29703 | Train Acc: 1.414| Val Acc: 1.966
# Epoch 079: | Train Loss: 12.33109 | Val Loss: 24.76954 | Train Acc: 1.422| Val Acc: 2.001
# Epoch 080: | Train Loss: 12.22837 | Val Loss: 24.05945 | Train Acc: 1.415| Val Acc: 1.967
# Epoch 081: | Train Loss: 12.10905 | Val Loss: 24.55181 | Train Acc: 1.409| Val Acc: 1.953
# Epoch 082: | Train Loss: 12.15114 | Val Loss: 24.62833 | Train Acc: 1.412| Val Acc: 1.990
# Epoch 083: | Train Loss: 12.35594 | Val Loss: 24.34564 | Train Acc: 1.419| Val Acc: 1.936
# Epoch 084: | Train Loss: 12.17689 | Val Loss: 23.89805 | Train Acc: 1.403| Val Acc: 1.922
# Epoch 085: | Train Loss: 12.05518 | Val Loss: 24.46868 | Train Acc: 1.391| Val Acc: 1.970
# Epoch 086: | Train Loss: 12.20756 | Val Loss: 24.49996 | Train Acc: 1.412| Val Acc: 1.953
# Epoch 087: | Train Loss: 12.23534 | Val Loss: 24.25287 | Train Acc: 1.407| Val Acc: 1.897
# Epoch 088: | Train Loss: 12.27880 | Val Loss: 24.78191 | Train Acc: 1.416| Val Acc: 2.036
# Epoch 089: | Train Loss: 12.31345 | Val Loss: 24.29501 | Train Acc: 1.411| Val Acc: 1.894
# Epoch 090: | Train Loss: 12.18422 | Val Loss: 24.56364 | Train Acc: 1.395| Val Acc: 2.004
# Epoch 091: | Train Loss: 12.26354 | Val Loss: 24.64773 | Train Acc: 1.409| Val Acc: 1.962
# Epoch 092: | Train Loss: 12.18708 | Val Loss: 24.88935 | Train Acc: 1.396| Val Acc: 2.002
# Epoch 093: | Train Loss: 12.21522 | Val Loss: 24.22581 | Train Acc: 1.407| Val Acc: 1.926
# Epoch 094: | Train Loss: 12.12801 | Val Loss: 24.47117 | Train Acc: 1.391| Val Acc: 1.900
# Epoch 095: | Train Loss: 12.06359 | Val Loss: 24.19273 | Train Acc: 1.373| Val Acc: 1.920
# Epoch 096: | Train Loss: 12.15681 | Val Loss: 24.88350 | Train Acc: 1.398| Val Acc: 1.959
# Epoch 097: | Train Loss: 12.18696 | Val Loss: 24.58199 | Train Acc: 1.391| Val Acc: 1.972
# Epoch 098: | Train Loss: 12.13921 | Val Loss: 24.42983 | Train Acc: 1.384| Val Acc: 1.932
# Epoch 099: | Train Loss: 12.04685 | Val Loss: 24.90661 | Train Acc: 1.373| Val Acc: 1.961
# Epoch 100: | Train Loss: 12.15202 | Val Loss: 24.40394 | Train Acc: 1.383| Val Acc: 1.919
# Epoch 101: | Train Loss: 12.14081 | Val Loss: 24.25915 | Train Acc: 1.385| Val Acc: 1.949
# Epoch 102: | Train Loss: 12.15070 | Val Loss: 24.53818 | Train Acc: 1.372| Val Acc: 1.948
# Epoch 103: | Train Loss: 12.11975 | Val Loss: 24.01533 | Train Acc: 1.391| Val Acc: 1.925
# Epoch 104: | Train Loss: 12.22398 | Val Loss: 24.62407 | Train Acc: 1.403| Val Acc: 1.954
# Epoch 105: | Train Loss: 12.21940 | Val Loss: 24.43221 | Train Acc: 1.392| Val Acc: 1.944
# Epoch 106: | Train Loss: 12.15764 | Val Loss: 24.47805 | Train Acc: 1.391| Val Acc: 2.003
# Epoch 107: | Train Loss: 12.08321 | Val Loss: 24.49205 | Train Acc: 1.381| Val Acc: 1.911
# Epoch 108: | Train Loss: 12.08887 | Val Loss: 24.40933 | Train Acc: 1.375| Val Acc: 1.923
# Epoch 109: | Train Loss: 12.18493 | Val Loss: 24.42070 | Train Acc: 1.381| Val Acc: 1.933
# Epoch 110: | Train Loss: 12.21863 | Val Loss: 24.08635 | Train Acc: 1.387| Val Acc: 1.915
# Epoch 111: | Train Loss: 12.05992 | Val Loss: 23.84110 | Train Acc: 1.369| Val Acc: 1.903
# Epoch 112: | Train Loss: 11.97892 | Val Loss: 24.01645 | Train Acc: 1.347| Val Acc: 1.911
# Epoch 113: | Train Loss: 11.99555 | Val Loss: 24.11493 | Train Acc: 1.366| Val Acc: 1.930
# Epoch 114: | Train Loss: 12.05705 | Val Loss: 24.98881 | Train Acc: 1.375| Val Acc: 1.999
# Epoch 115: | Train Loss: 11.94472 | Val Loss: 24.04672 | Train Acc: 1.348| Val Acc: 1.915
# Epoch 116: | Train Loss: 11.99458 | Val Loss: 24.38551 | Train Acc: 1.340| Val Acc: 1.959
# Epoch 117: | Train Loss: 11.88825 | Val Loss: 24.25268 | Train Acc: 1.342| Val Acc: 1.917
# Epoch 118: | Train Loss: 11.89634 | Val Loss: 24.28712 | Train Acc: 1.325| Val Acc: 1.916
# Epoch 119: | Train Loss: 11.89113 | Val Loss: 24.21489 | Train Acc: 1.321| Val Acc: 1.922
# Epoch 120: | Train Loss: 11.88186 | Val Loss: 24.70006 | Train Acc: 1.328| Val Acc: 1.982
# Epoch 121: | Train Loss: 11.89786 | Val Loss: 24.37722 | Train Acc: 1.329| Val Acc: 1.940
# Epoch 122: | Train Loss: 11.93153 | Val Loss: 24.36788 | Train Acc: 1.333| Val Acc: 1.963
# Epoch 123: | Train Loss: 11.95018 | Val Loss: 23.39108 | Train Acc: 1.346| Val Acc: 1.863
# Epoch 124: | Train Loss: 11.93968 | Val Loss: 23.86476 | Train Acc: 1.347| Val Acc: 1.870
# Epoch 125: | Train Loss: 11.91916 | Val Loss: 23.93305 | Train Acc: 1.320| Val Acc: 1.872
# Epoch 126: | Train Loss: 11.92482 | Val Loss: 24.09420 | Train Acc: 1.333| Val Acc: 1.903
# Epoch 127: | Train Loss: 11.96249 | Val Loss: 23.80525 | Train Acc: 1.323| Val Acc: 1.883
# Epoch 128: | Train Loss: 11.87729 | Val Loss: 24.70754 | Train Acc: 1.334| Val Acc: 1.960
# Epoch 129: | Train Loss: 11.98124 | Val Loss: 24.68372 | Train Acc: 1.339| Val Acc: 1.934
# Epoch 130: | Train Loss: 11.95437 | Val Loss: 24.53545 | Train Acc: 1.333| Val Acc: 1.945
# Epoch 131: | Train Loss: 11.93016 | Val Loss: 24.39849 | Train Acc: 1.330| Val Acc: 1.952
# Epoch 132: | Train Loss: 11.92140 | Val Loss: 23.94754 | Train Acc: 1.344| Val Acc: 1.899
# Epoch 133: | Train Loss: 11.92590 | Val Loss: 24.82962 | Train Acc: 1.329| Val Acc: 2.036
# Epoch 134: | Train Loss: 11.96400 | Val Loss: 24.40156 | Train Acc: 1.337| Val Acc: 1.910
# Epoch 135: | Train Loss: 11.93848 | Val Loss: 24.44274 | Train Acc: 1.342| Val Acc: 1.949
# Epoch 136: | Train Loss: 11.86544 | Val Loss: 24.10522 | Train Acc: 1.328| Val Acc: 1.943
# Epoch 137: | Train Loss: 11.99200 | Val Loss: 23.73940 | Train Acc: 1.350| Val Acc: 1.852
# Epoch 138: | Train Loss: 11.91236 | Val Loss: 23.94460 | Train Acc: 1.314| Val Acc: 1.896
# Epoch 139: | Train Loss: 11.77452 | Val Loss: 24.03760 | Train Acc: 1.308| Val Acc: 1.906
# Epoch 140: | Train Loss: 11.81571 | Val Loss: 23.87258 | Train Acc: 1.301| Val Acc: 1.870
# Epoch 141: | Train Loss: 11.94276 | Val Loss: 23.72413 | Train Acc: 1.325| Val Acc: 1.873
# Epoch 142: | Train Loss: 11.88675 | Val Loss: 23.89723 | Train Acc: 1.306| Val Acc: 1.915
# Epoch 143: | Train Loss: 11.86962 | Val Loss: 24.00757 | Train Acc: 1.322| Val Acc: 1.912
# Epoch 144: | Train Loss: 11.83538 | Val Loss: 23.68240 | Train Acc: 1.325| Val Acc: 1.874
# Epoch 145: | Train Loss: 11.77074 | Val Loss: 24.09878 | Train Acc: 1.300| Val Acc: 1.886
# Epoch 146: | Train Loss: 11.78388 | Val Loss: 24.38475 | Train Acc: 1.307| Val Acc: 1.877
# Epoch 147: | Train Loss: 11.98535 | Val Loss: 24.06961 | Train Acc: 1.324| Val Acc: 1.905
# Epoch 148: | Train Loss: 12.09770 | Val Loss: 24.40516 | Train Acc: 1.336| Val Acc: 1.891
# Epoch 149: | Train Loss: 12.01292 | Val Loss: 24.53692 | Train Acc: 1.323| Val Acc: 1.964
# Epoch 150: | Train Loss: 11.94679 | Val Loss: 24.11916 | Train Acc: 1.340| Val Acc: 1.904

# %%
metrics(train, test, threshold=30)
# Out:
# MAE on train set:  138.07076447854203
# min prediction: 1
# max prediction: 1298
#
# MAE on test set:  149.63828574105239
# Error ⩽ 30: 24.05 %
# min prediction: 1
# max prediction: 962

# %%
validation_plots(test,model_type)

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.000001, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)
# Out:
# Epoch 001: | Train Loss: 13.89359 | Val Loss: 1.04378 | Train Acc: 1.596| Val Acc: 0.633
# Epoch 002: | Train Loss: 13.79096 | Val Loss: 0.98798 | Train Acc: 1.579| Val Acc: 0.633
# Epoch 003: | Train Loss: 13.53186 | Val Loss: 3.06615 | Train Acc: 1.560| Val Acc: 1.633
# Epoch 004: | Train Loss: 13.28548 | Val Loss: 3.08242 | Train Acc: 1.514| Val Acc: 1.633
# Epoch 005: | Train Loss: 13.35618 | Val Loss: 4.11752 | Train Acc: 1.532| Val Acc: 1.633
# Epoch 006: | Train Loss: 13.08261 | Val Loss: 4.35655 | Train Acc: 1.499| Val Acc: 1.633
# Epoch 007: | Train Loss: 13.05106 | Val Loss: 4.32465 | Train Acc: 1.486| Val Acc: 1.633
# Epoch 008: | Train Loss: 13.02931 | Val Loss: 1.28407 | Train Acc: 1.500| Val Acc: 1.633
# Epoch 009: | Train Loss: 12.99468 | Val Loss: 3.75861 | Train Acc: 1.484| Val Acc: 1.633
# Epoch 010: | Train Loss: 13.00488 | Val Loss: 2.30977 | Train Acc: 1.495| Val Acc: 1.633
# Epoch 011: | Train Loss: 13.07015 | Val Loss: 3.36997 | Train Acc: 1.499| Val Acc: 1.633
# Epoch 012: | Train Loss: 12.77657 | Val Loss: 1.98797 | Train Acc: 1.461| Val Acc: 1.633
# Epoch 013: | Train Loss: 12.87150 | Val Loss: 3.72740 | Train Acc: 1.454| Val Acc: 1.633
# Epoch 014: | Train Loss: 12.79044 | Val Loss: 2.13492 | Train Acc: 1.462| Val Acc: 1.633
# Epoch 015: | Train Loss: 12.77931 | Val Loss: 3.48493 | Train Acc: 1.464| Val Acc: 1.633
# Epoch 016: | Train Loss: 12.71014 | Val Loss: 3.17282 | Train Acc: 1.456| Val Acc: 1.633
# Epoch 017: | Train Loss: 12.69306 | Val Loss: 2.77769 | Train Acc: 1.448| Val Acc: 1.633
# Epoch 018: | Train Loss: 12.70905 | Val Loss: 2.87132 | Train Acc: 1.437| Val Acc: 1.633
# Epoch 019: | Train Loss: 12.61009 | Val Loss: 3.89106 | Train Acc: 1.441| Val Acc: 1.633
# Epoch 020: | Train Loss: 12.32236 | Val Loss: 3.24620 | Train Acc: 1.398| Val Acc: 1.633
# Epoch 021: | Train Loss: 12.80181 | Val Loss: 2.30474 | Train Acc: 1.466| Val Acc: 1.633
# Epoch 022: | Train Loss: 12.70425 | Val Loss: 2.59134 | Train Acc: 1.451| Val Acc: 1.633
# Epoch 023: | Train Loss: 12.68222 | Val Loss: 2.34690 | Train Acc: 1.469| Val Acc: 1.633
# Epoch 024: | Train Loss: 12.75891 | Val Loss: 2.46976 | Train Acc: 1.473| Val Acc: 1.633
# Epoch 025: | Train Loss: 12.82646 | Val Loss: 3.01114 | Train Acc: 1.482| Val Acc: 1.633
# Epoch 026: | Train Loss: 12.46490 | Val Loss: 2.11454 | Train Acc: 1.418| Val Acc: 1.633
# Epoch 027: | Train Loss: 12.59635 | Val Loss: 2.27512 | Train Acc: 1.437| Val Acc: 1.633
# Epoch 028: | Train Loss: 12.64921 | Val Loss: 2.61779 | Train Acc: 1.443| Val Acc: 1.633
# Epoch 029: | Train Loss: 12.55885 | Val Loss: 1.54611 | Train Acc: 1.437| Val Acc: 1.633
# Epoch 030: | Train Loss: 12.55452 | Val Loss: 3.32793 | Train Acc: 1.437| Val Acc: 1.633
# Epoch 031: | Train Loss: 12.64960 | Val Loss: 2.26719 | Train Acc: 1.431| Val Acc: 1.633
# Epoch 032: | Train Loss: 12.72240 | Val Loss: 1.91809 | Train Acc: 1.451| Val Acc: 1.633
# Epoch 033: | Train Loss: 12.79305 | Val Loss: 3.28911 | Train Acc: 1.463| Val Acc: 1.633
# Epoch 034: | Train Loss: 12.35535 | Val Loss: 2.16724 | Train Acc: 1.401| Val Acc: 1.633
# Epoch 035: | Train Loss: 12.52269 | Val Loss: 2.86189 | Train Acc: 1.437| Val Acc: 1.633
# Epoch 036: | Train Loss: 12.50503 | Val Loss: 2.48476 | Train Acc: 1.409| Val Acc: 1.633
# Epoch 037: | Train Loss: 12.66921 | Val Loss: 1.54429 | Train Acc: 1.445| Val Acc: 1.633
# Epoch 038: | Train Loss: 12.41755 | Val Loss: 2.34210 | Train Acc: 1.404| Val Acc: 1.633
# Epoch 039: | Train Loss: 12.42148 | Val Loss: 2.13521 | Train Acc: 1.405| Val Acc: 1.633
# Epoch 040: | Train Loss: 12.34005 | Val Loss: 2.95173 | Train Acc: 1.388| Val Acc: 1.633
# Epoch 041: | Train Loss: 12.37981 | Val Loss: 2.06833 | Train Acc: 1.401| Val Acc: 1.633
# Epoch 042: | Train Loss: 12.29152 | Val Loss: 1.97531 | Train Acc: 1.371| Val Acc: 1.633
# Epoch 043: | Train Loss: 12.29664 | Val Loss: 2.14406 | Train Acc: 1.373| Val Acc: 1.633
# Epoch 044: | Train Loss: 12.18377 | Val Loss: 1.94589 | Train Acc: 1.360| Val Acc: 1.633
# Epoch 045: | Train Loss: 12.32209 | Val Loss: 2.18530 | Train Acc: 1.390| Val Acc: 1.633
# Epoch 046: | Train Loss: 12.38141 | Val Loss: 3.68373 | Train Acc: 1.393| Val Acc: 1.633
# Epoch 047: | Train Loss: 12.46730 | Val Loss: 2.54868 | Train Acc: 1.408| Val Acc: 1.633
# Epoch 048: | Train Loss: 12.35158 | Val Loss: 1.91724 | Train Acc: 1.384| Val Acc: 1.633
# Epoch 049: | Train Loss: 12.27712 | Val Loss: 1.75480 | Train Acc: 1.376| Val Acc: 1.633
# Epoch 050: | Train Loss: 12.28423 | Val Loss: 1.53553 | Train Acc: 1.392| Val Acc: 1.633
# Epoch 051: | Train Loss: 12.21489 | Val Loss: 0.97797 | Train Acc: 1.363| Val Acc: 0.633
# Epoch 052: | Train Loss: 12.18658 | Val Loss: 1.81044 | Train Acc: 1.378| Val Acc: 1.633
# Epoch 053: | Train Loss: 12.55872 | Val Loss: 2.07862 | Train Acc: 1.441| Val Acc: 1.633
# Epoch 054: | Train Loss: 12.36233 | Val Loss: 2.13142 | Train Acc: 1.403| Val Acc: 1.633
# Epoch 055: | Train Loss: 12.37917 | Val Loss: 2.46903 | Train Acc: 1.399| Val Acc: 1.633
# Epoch 056: | Train Loss: 12.42574 | Val Loss: 2.97021 | Train Acc: 1.409| Val Acc: 1.633
# Epoch 057: | Train Loss: 12.57490 | Val Loss: 2.58894 | Train Acc: 1.394| Val Acc: 1.633
# Epoch 058: | Train Loss: 12.37932 | Val Loss: 3.51339 | Train Acc: 1.390| Val Acc: 1.633
# Epoch 059: | Train Loss: 12.30972 | Val Loss: 2.23553 | Train Acc: 1.405| Val Acc: 1.633
# Epoch 060: | Train Loss: 12.39841 | Val Loss: 2.20529 | Train Acc: 1.405| Val Acc: 1.633
# Epoch 061: | Train Loss: 12.40545 | Val Loss: 1.34206 | Train Acc: 1.400| Val Acc: 1.633
# Epoch 062: | Train Loss: 12.43121 | Val Loss: 2.51323 | Train Acc: 1.398| Val Acc: 1.633
# Epoch 063: | Train Loss: 12.36026 | Val Loss: 1.36033 | Train Acc: 1.406| Val Acc: 1.633
# Epoch 064: | Train Loss: 12.37151 | Val Loss: 1.55461 | Train Acc: 1.407| Val Acc: 1.633
# Epoch 065: | Train Loss: 12.10355 | Val Loss: 1.79019 | Train Acc: 1.355| Val Acc: 1.633
# Epoch 066: | Train Loss: 12.25847 | Val Loss: 1.47859 | Train Acc: 1.379| Val Acc: 1.633
# Epoch 067: | Train Loss: 12.35397 | Val Loss: 1.33426 | Train Acc: 1.367| Val Acc: 1.633
# Epoch 068: | Train Loss: 12.18289 | Val Loss: 1.11461 | Train Acc: 1.358| Val Acc: 0.633
# Epoch 069: | Train Loss: 12.23132 | Val Loss: 0.86090 | Train Acc: 1.374| Val Acc: 0.633
# Epoch 070: | Train Loss: 12.24093 | Val Loss: 1.50635 | Train Acc: 1.360| Val Acc: 1.633
# Epoch 071: | Train Loss: 12.26044 | Val Loss: 2.31878 | Train Acc: 1.362| Val Acc: 1.633
# Epoch 072: | Train Loss: 12.12607 | Val Loss: 1.63081 | Train Acc: 1.350| Val Acc: 1.633
# Epoch 073: | Train Loss: 12.08762 | Val Loss: 1.64755 | Train Acc: 1.343| Val Acc: 1.633
# Epoch 074: | Train Loss: 12.23332 | Val Loss: 2.53763 | Train Acc: 1.362| Val Acc: 1.633
# Epoch 075: | Train Loss: 12.15856 | Val Loss: 1.96588 | Train Acc: 1.351| Val Acc: 1.633
# Epoch 076: | Train Loss: 12.11347 | Val Loss: 1.02468 | Train Acc: 1.351| Val Acc: 0.633
# Epoch 077: | Train Loss: 12.05464 | Val Loss: 1.59113 | Train Acc: 1.335| Val Acc: 1.633
# Epoch 078: | Train Loss: 12.09172 | Val Loss: 2.04050 | Train Acc: 1.327| Val Acc: 1.633
# Epoch 079: | Train Loss: 12.06239 | Val Loss: 1.77341 | Train Acc: 1.339| Val Acc: 1.633
# Epoch 080: | Train Loss: 12.08626 | Val Loss: 1.56821 | Train Acc: 1.343| Val Acc: 1.633
# Epoch 081: | Train Loss: 12.12403 | Val Loss: 1.78883 | Train Acc: 1.349| Val Acc: 1.633
# Epoch 082: | Train Loss: 12.03881 | Val Loss: 2.05967 | Train Acc: 1.339| Val Acc: 1.633
# Epoch 083: | Train Loss: 12.00865 | Val Loss: 1.54854 | Train Acc: 1.323| Val Acc: 1.633
# Epoch 084: | Train Loss: 12.09341 | Val Loss: 1.35730 | Train Acc: 1.352| Val Acc: 1.633
# Epoch 085: | Train Loss: 12.13142 | Val Loss: 2.08828 | Train Acc: 1.336| Val Acc: 1.633
# Epoch 086: | Train Loss: 12.03128 | Val Loss: 2.10850 | Train Acc: 1.339| Val Acc: 1.633
# Epoch 087: | Train Loss: 12.09844 | Val Loss: 1.84207 | Train Acc: 1.337| Val Acc: 1.633
# Epoch 088: | Train Loss: 12.05649 | Val Loss: 2.63025 | Train Acc: 1.327| Val Acc: 1.633
# Epoch 089: | Train Loss: 12.15159 | Val Loss: 1.74973 | Train Acc: 1.364| Val Acc: 1.633
# Epoch 090: | Train Loss: 12.18518 | Val Loss: 4.29372 | Train Acc: 1.366| Val Acc: 1.633
# Epoch 091: | Train Loss: 12.35442 | Val Loss: 3.67954 | Train Acc: 1.369| Val Acc: 1.633
# Epoch 092: | Train Loss: 12.16300 | Val Loss: 2.51396 | Train Acc: 1.362| Val Acc: 1.633
# Epoch 093: | Train Loss: 12.23227 | Val Loss: 2.89539 | Train Acc: 1.360| Val Acc: 1.633
# Epoch 094: | Train Loss: 12.23620 | Val Loss: 2.73264 | Train Acc: 1.373| Val Acc: 1.633
# Epoch 095: | Train Loss: 12.24818 | Val Loss: 2.41417 | Train Acc: 1.376| Val Acc: 1.633
# Epoch 096: | Train Loss: 12.18512 | Val Loss: 4.44960 | Train Acc: 1.359| Val Acc: 1.633
# Epoch 097: | Train Loss: 12.19112 | Val Loss: 3.39182 | Train Acc: 1.380| Val Acc: 1.633
# Epoch 098: | Train Loss: 12.08152 | Val Loss: 1.90722 | Train Acc: 1.344| Val Acc: 1.633
# Epoch 099: | Train Loss: 11.98878 | Val Loss: 2.31272 | Train Acc: 1.313| Val Acc: 1.633
# Epoch 100: | Train Loss: 12.10340 | Val Loss: 2.26063 | Train Acc: 1.352| Val Acc: 1.633
# Epoch 101: | Train Loss: 12.15129 | Val Loss: 2.52330 | Train Acc: 1.362| Val Acc: 1.633
# Epoch 102: | Train Loss: 12.02121 | Val Loss: 2.35062 | Train Acc: 1.320| Val Acc: 1.633
# Epoch 103: | Train Loss: 11.97016 | Val Loss: 2.78200 | Train Acc: 1.321| Val Acc: 1.633
# Epoch 104: | Train Loss: 12.25475 | Val Loss: 3.07309 | Train Acc: 1.373| Val Acc: 1.633
# Epoch 105: | Train Loss: 11.99137 | Val Loss: 2.11714 | Train Acc: 1.340| Val Acc: 1.633
# Epoch 106: | Train Loss: 12.00359 | Val Loss: 2.78776 | Train Acc: 1.323| Val Acc: 1.633
# Epoch 107: | Train Loss: 12.10528 | Val Loss: 2.16313 | Train Acc: 1.334| Val Acc: 1.633
# Epoch 108: | Train Loss: 11.95948 | Val Loss: 2.05844 | Train Acc: 1.321| Val Acc: 1.633
# Epoch 109: | Train Loss: 12.00581 | Val Loss: 1.42969 | Train Acc: 1.327| Val Acc: 1.633
# Epoch 110: | Train Loss: 12.24648 | Val Loss: 2.07630 | Train Acc: 1.368| Val Acc: 1.633
# Epoch 111: | Train Loss: 12.23119 | Val Loss: 2.15421 | Train Acc: 1.368| Val Acc: 1.633
# Epoch 112: | Train Loss: 12.11034 | Val Loss: 1.82407 | Train Acc: 1.349| Val Acc: 1.633
# Epoch 113: | Train Loss: 12.09298 | Val Loss: 1.63330 | Train Acc: 1.343| Val Acc: 1.633
# Epoch 114: | Train Loss: 12.06385 | Val Loss: 1.86300 | Train Acc: 1.327| Val Acc: 1.633
# Epoch 115: | Train Loss: 12.08148 | Val Loss: 2.30737 | Train Acc: 1.321| Val Acc: 1.633
# Epoch 116: | Train Loss: 12.08033 | Val Loss: 3.15223 | Train Acc: 1.338| Val Acc: 1.633
# Epoch 117: | Train Loss: 12.00196 | Val Loss: 2.10947 | Train Acc: 1.320| Val Acc: 1.633
# Epoch 118: | Train Loss: 12.01235 | Val Loss: 1.89570 | Train Acc: 1.313| Val Acc: 1.633
# Epoch 119: | Train Loss: 11.98744 | Val Loss: 1.80680 | Train Acc: 1.313| Val Acc: 1.633
# Epoch 120: | Train Loss: 11.97815 | Val Loss: 2.38754 | Train Acc: 1.308| Val Acc: 1.633
# Epoch 121: | Train Loss: 12.07522 | Val Loss: 1.93536 | Train Acc: 1.311| Val Acc: 1.633
# Epoch 122: | Train Loss: 12.14821 | Val Loss: 2.23868 | Train Acc: 1.351| Val Acc: 1.633
# Epoch 123: | Train Loss: 12.07685 | Val Loss: 1.53628 | Train Acc: 1.334| Val Acc: 1.633
# Epoch 124: | Train Loss: 12.02036 | Val Loss: 2.18329 | Train Acc: 1.316| Val Acc: 1.633
# Epoch 125: | Train Loss: 11.97947 | Val Loss: 1.89338 | Train Acc: 1.313| Val Acc: 1.633
# Epoch 126: | Train Loss: 11.91437 | Val Loss: 1.31985 | Train Acc: 1.298| Val Acc: 1.633
# Epoch 127: | Train Loss: 11.91230 | Val Loss: 1.95934 | Train Acc: 1.307| Val Acc: 1.633
# Epoch 128: | Train Loss: 12.03568 | Val Loss: 0.91047 | Train Acc: 1.322| Val Acc: 0.633
# Epoch 129: | Train Loss: 11.96846 | Val Loss: 0.85654 | Train Acc: 1.319| Val Acc: 0.633
# Epoch 130: | Train Loss: 11.96653 | Val Loss: 2.45471 | Train Acc: 1.316| Val Acc: 1.633
# Epoch 131: | Train Loss: 12.01506 | Val Loss: 1.87805 | Train Acc: 1.308| Val Acc: 1.633
# Epoch 132: | Train Loss: 11.95146 | Val Loss: 1.24420 | Train Acc: 1.316| Val Acc: 0.633
# Epoch 133: | Train Loss: 11.97697 | Val Loss: 1.33117 | Train Acc: 1.309| Val Acc: 1.633
# Epoch 134: | Train Loss: 12.00477 | Val Loss: 0.78612 | Train Acc: 1.327| Val Acc: 0.633
# Epoch 135: | Train Loss: 11.83531 | Val Loss: 1.11702 | Train Acc: 1.289| Val Acc: 0.633
# Epoch 136: | Train Loss: 11.89268 | Val Loss: 1.31142 | Train Acc: 1.291| Val Acc: 1.633
# Epoch 137: | Train Loss: 11.92036 | Val Loss: 1.29160 | Train Acc: 1.292| Val Acc: 1.633
# Epoch 138: | Train Loss: 12.01712 | Val Loss: 1.18810 | Train Acc: 1.301| Val Acc: 0.633
# Epoch 139: | Train Loss: 11.88407 | Val Loss: 1.53440 | Train Acc: 1.293| Val Acc: 1.633
# Epoch 140: | Train Loss: 11.94576 | Val Loss: 1.47793 | Train Acc: 1.298| Val Acc: 1.633
# Epoch 141: | Train Loss: 11.94040 | Val Loss: 1.36242 | Train Acc: 1.288| Val Acc: 1.633
# Epoch 142: | Train Loss: 11.91800 | Val Loss: 2.01681 | Train Acc: 1.292| Val Acc: 1.633
# Epoch 143: | Train Loss: 11.90351 | Val Loss: 2.02245 | Train Acc: 1.295| Val Acc: 1.633
# Epoch 144: | Train Loss: 11.93810 | Val Loss: 1.39452 | Train Acc: 1.278| Val Acc: 1.633
# Epoch 145: | Train Loss: 11.86271 | Val Loss: 0.85596 | Train Acc: 1.283| Val Acc: 0.633
# Epoch 146: | Train Loss: 11.96878 | Val Loss: 0.90137 | Train Acc: 1.305| Val Acc: 0.633
# Epoch 147: | Train Loss: 11.98308 | Val Loss: 1.83311 | Train Acc: 1.312| Val Acc: 1.633
# Epoch 148: | Train Loss: 11.91542 | Val Loss: 2.44809 | Train Acc: 1.305| Val Acc: 1.633
# Epoch 149: | Train Loss: 11.87404 | Val Loss: 2.09875 | Train Acc: 1.290| Val Acc: 1.633
# Epoch 150: | Train Loss: 11.91802 | Val Loss: 1.20885 | Train Acc: 1.301| Val Acc: 0.633

# %%
pickle.dump(model, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_Mamoth_NN.pt', 'wb'))
pickle.dump(imputer, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_KNN_Imputer.pkl', 'wb'))
pickle.dump(scaler, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_Scaler.pkl', 'wb'))
