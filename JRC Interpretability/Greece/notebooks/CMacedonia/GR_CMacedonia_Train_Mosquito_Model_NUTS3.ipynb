# %% [markdown]
# ## Produces **Mosquito Predictions** for a specific region using MAMOTH ##

# %%
import pandas as pd
import datetime
import math
import numpy as np
import missingno
import json
from statistics import mean
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
import sys
import pickle

sys.path.insert(0, "../../../../Mamoth")
sys.path.insert(0, "../../../../Modules")

from utils import *

from Preprocessing_Module import read_data, select_columns, reshape_dataset
from Initializer_Module import initializer
from Neural_Network_Module import Dataset, transformations, FeedforwardNeuralNetModel, train_nn, give_predictions
from Model_Validation_Module import validation_plots, metrics

enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 100
pd.options.display.float_format = lambda x: '%.6f' % x

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
NUTS0 = 'GR'
NUTS2 = 'CMacedonia'
NUTS2_EL = 'κεντρικης μακεδονιας'

# %%
mosquito_data = read_data(f'../../data/{NUTS0}_MSQ_culex_2011-2022_processed.csv')
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
mosquito_data.nuts2.unique()
# Out:
# array(['κεντρικης μακεδονιας', 'θεσσαλιας', 'κρητης', 'δυτικης ελλαδας'],
#       dtype=object)

# %%
mosquito_data_nuts2 = mosquito_data.query(f"nuts2 == '{NUTS2_EL}'").copy()
mosquito_data_nuts2.reset_index(inplace = True, drop = True)

# %%
mosq_columns = mosquito_data_nuts2.columns
mosq_columns
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
                'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
                'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
                'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
                'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
                'acc_rainfall_jan', 'mosq_now']

# columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#                 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#                 'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#                 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#                 'lst_night', 'acc_rainfall_1week', 'acc_rainfall_2week',
#                 'acc_rainfall_jan', 'mosq_now']

mosquito_data_nuts2 = select_columns(mosquito_data_nuts2, columns_to_keep, columns_to_keep)

mosquito_data_nuts2 = reshape_dataset(mosquito_data_nuts2,['x','y','dt_placement'])

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()

# %%
#quantile might change based on sns plots
mosq_quantilie = mosquito_data_nuts2['mosq_now'].quantile(0.90)

mosquito_data_nuts2['mosq_now'][mosquito_data_nuts2['mosq_now'] > mosq_quantilie] = mosq_quantilie+1

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <AxesSubplot:>

# %%
imputer = KNNImputer()

features_for_impute = ['x', 'y', 'day', 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 
                        'lst_day', 'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean', 'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan']

# features_for_impute = ['x', 'y', 'day', 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#                         'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 
#                         'lst_day', 'lst_night', 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan']

mosquito_data_sub = mosquito_data_nuts2[features_for_impute]

imputed_data = pd.DataFrame(imputer.fit_transform(mosquito_data_sub), columns = mosquito_data_sub.columns)

# %%
# imputed_columns = ['ndvi','ndmi', 'ndwi', 'ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std', 'ndmi_std','ndwi_std','ndbi_std',
#                    'lst_day','lst_night']

imputed_columns = ['ndvi','ndmi', 'ndwi', 'ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std', 'ndmi_std','ndwi_std','ndbi_std',
                   'lst_day','lst_night','lst_jan_mean','lst_feb_mean','lst_mar_mean','lst_apr_mean']

mosquito_data_nuts2[imputed_columns] = imputed_data[imputed_columns]

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <AxesSubplot:>

# %%
step = 15
only_env = True
case_title = 'NN mosq regression'
exp = False
date_col = 'dt_placement'
model_type = 'mosquito_regression'
transform_target = True
augment = True

# %%
mosquito_data_nuts2 = initializer(mosquito_data_nuts2,2,10,25,step,[date_col], env=only_env, date_column = date_col, mosq_column='mosq_now')
# Out:
# Bounds: [  0.  85. 755.]

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.25, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

model = FeedforwardNeuralNetModel(num_features=len(train_X[0]), num_class=1, hidden_layers = [264,128,128,64], dropout=0.2, model_type=model_type, transform = transform_target)

# %%
train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)
# Out:
# Epoch 001: | Train Loss: 20.18183 | Val Loss: 25.55132 | Train Acc: 2.751| Val Acc: 2.044
# Epoch 002: | Train Loss: 18.82332 | Val Loss: 25.31379 | Train Acc: 2.286| Val Acc: 2.078
# Epoch 003: | Train Loss: 18.41943 | Val Loss: 25.43027 | Train Acc: 2.241| Val Acc: 2.063
# Epoch 004: | Train Loss: 18.18690 | Val Loss: 24.36436 | Train Acc: 2.191| Val Acc: 1.968
# Epoch 005: | Train Loss: 18.02850 | Val Loss: 24.79953 | Train Acc: 2.135| Val Acc: 2.013
# Epoch 006: | Train Loss: 17.52479 | Val Loss: 24.71835 | Train Acc: 2.051| Val Acc: 1.988
# Epoch 007: | Train Loss: 17.40283 | Val Loss: 24.10914 | Train Acc: 2.039| Val Acc: 1.980
# Epoch 008: | Train Loss: 17.27281 | Val Loss: 23.91512 | Train Acc: 2.036| Val Acc: 1.954
# Epoch 009: | Train Loss: 17.08829 | Val Loss: 23.37284 | Train Acc: 1.989| Val Acc: 1.956
# Epoch 010: | Train Loss: 16.82533 | Val Loss: 23.74700 | Train Acc: 1.973| Val Acc: 1.971
# Epoch 011: | Train Loss: 16.71891 | Val Loss: 23.48874 | Train Acc: 1.984| Val Acc: 1.968
# Epoch 012: | Train Loss: 16.64236 | Val Loss: 23.49192 | Train Acc: 2.007| Val Acc: 1.972
# Epoch 013: | Train Loss: 16.44967 | Val Loss: 24.04569 | Train Acc: 1.946| Val Acc: 2.019
# Epoch 014: | Train Loss: 16.33864 | Val Loss: 23.61598 | Train Acc: 1.936| Val Acc: 2.019
# Epoch 015: | Train Loss: 16.14391 | Val Loss: 23.98081 | Train Acc: 1.947| Val Acc: 2.015
# Epoch 016: | Train Loss: 16.02303 | Val Loss: 24.22476 | Train Acc: 1.929| Val Acc: 2.046
# Epoch 017: | Train Loss: 15.71519 | Val Loss: 24.25685 | Train Acc: 1.900| Val Acc: 2.036
# Epoch 018: | Train Loss: 15.84562 | Val Loss: 24.53447 | Train Acc: 1.913| Val Acc: 2.097
# Epoch 019: | Train Loss: 15.46320 | Val Loss: 24.81747 | Train Acc: 1.858| Val Acc: 2.116
# Epoch 020: | Train Loss: 15.62424 | Val Loss: 24.69358 | Train Acc: 1.889| Val Acc: 2.110
# Epoch 021: | Train Loss: 15.34377 | Val Loss: 24.90388 | Train Acc: 1.865| Val Acc: 2.122
# Epoch 022: | Train Loss: 15.30200 | Val Loss: 25.02820 | Train Acc: 1.850| Val Acc: 2.162
# Epoch 023: | Train Loss: 14.92813 | Val Loss: 25.15342 | Train Acc: 1.815| Val Acc: 2.151
# Epoch 024: | Train Loss: 14.98091 | Val Loss: 24.64144 | Train Acc: 1.831| Val Acc: 2.125
# Epoch 025: | Train Loss: 14.67593 | Val Loss: 24.91546 | Train Acc: 1.788| Val Acc: 2.150
# Epoch 026: | Train Loss: 14.68643 | Val Loss: 25.81146 | Train Acc: 1.792| Val Acc: 2.187
# Epoch 027: | Train Loss: 14.48478 | Val Loss: 24.78141 | Train Acc: 1.775| Val Acc: 2.136
# Epoch 028: | Train Loss: 14.59990 | Val Loss: 25.82607 | Train Acc: 1.801| Val Acc: 2.239
# Epoch 029: | Train Loss: 14.33651 | Val Loss: 25.81773 | Train Acc: 1.767| Val Acc: 2.196
# Epoch 030: | Train Loss: 14.21847 | Val Loss: 26.13435 | Train Acc: 1.766| Val Acc: 2.248
# Epoch 031: | Train Loss: 14.25872 | Val Loss: 25.22273 | Train Acc: 1.755| Val Acc: 2.145
# Epoch 032: | Train Loss: 14.29351 | Val Loss: 25.84153 | Train Acc: 1.758| Val Acc: 2.220
# Epoch 033: | Train Loss: 13.98384 | Val Loss: 25.34314 | Train Acc: 1.713| Val Acc: 2.157
# Epoch 034: | Train Loss: 13.87426 | Val Loss: 25.90075 | Train Acc: 1.716| Val Acc: 2.219
# Epoch 035: | Train Loss: 13.82261 | Val Loss: 25.82423 | Train Acc: 1.707| Val Acc: 2.207
# Epoch 036: | Train Loss: 13.54250 | Val Loss: 26.31637 | Train Acc: 1.652| Val Acc: 2.246
# Epoch 037: | Train Loss: 13.49519 | Val Loss: 26.04022 | Train Acc: 1.665| Val Acc: 2.244
# Epoch 038: | Train Loss: 13.65035 | Val Loss: 26.08008 | Train Acc: 1.670| Val Acc: 2.271
# Epoch 039: | Train Loss: 13.50160 | Val Loss: 25.94237 | Train Acc: 1.660| Val Acc: 2.195
# Epoch 040: | Train Loss: 13.43102 | Val Loss: 26.01940 | Train Acc: 1.635| Val Acc: 2.225
# Epoch 041: | Train Loss: 13.32136 | Val Loss: 25.90379 | Train Acc: 1.633| Val Acc: 2.185
# Epoch 042: | Train Loss: 13.54230 | Val Loss: 25.56613 | Train Acc: 1.650| Val Acc: 2.193
# Epoch 043: | Train Loss: 13.32919 | Val Loss: 25.92913 | Train Acc: 1.627| Val Acc: 2.235
# Epoch 044: | Train Loss: 13.23645 | Val Loss: 26.45496 | Train Acc: 1.611| Val Acc: 2.251
# Epoch 045: | Train Loss: 13.03831 | Val Loss: 25.76699 | Train Acc: 1.593| Val Acc: 2.158
# Epoch 046: | Train Loss: 13.02048 | Val Loss: 25.38952 | Train Acc: 1.582| Val Acc: 2.202
# Epoch 047: | Train Loss: 13.25220 | Val Loss: 25.93725 | Train Acc: 1.608| Val Acc: 2.221
# Epoch 048: | Train Loss: 13.02703 | Val Loss: 25.81101 | Train Acc: 1.578| Val Acc: 2.176
# Epoch 049: | Train Loss: 12.78404 | Val Loss: 25.66230 | Train Acc: 1.554| Val Acc: 2.133
# Epoch 050: | Train Loss: 12.91998 | Val Loss: 25.59779 | Train Acc: 1.552| Val Acc: 2.121
# Epoch 051: | Train Loss: 12.96956 | Val Loss: 25.29843 | Train Acc: 1.556| Val Acc: 2.122
# Epoch 052: | Train Loss: 12.91252 | Val Loss: 25.46093 | Train Acc: 1.537| Val Acc: 2.123
# Epoch 053: | Train Loss: 12.79518 | Val Loss: 25.15338 | Train Acc: 1.522| Val Acc: 2.096
# Epoch 054: | Train Loss: 12.77923 | Val Loss: 24.97000 | Train Acc: 1.549| Val Acc: 2.051
# Epoch 055: | Train Loss: 12.61245 | Val Loss: 25.19467 | Train Acc: 1.509| Val Acc: 2.090
# Epoch 056: | Train Loss: 12.72684 | Val Loss: 25.72461 | Train Acc: 1.536| Val Acc: 2.145
# Epoch 057: | Train Loss: 12.76461 | Val Loss: 25.22823 | Train Acc: 1.506| Val Acc: 2.089
# Epoch 058: | Train Loss: 12.69070 | Val Loss: 25.96470 | Train Acc: 1.508| Val Acc: 2.149
# Epoch 059: | Train Loss: 12.64233 | Val Loss: 25.33254 | Train Acc: 1.490| Val Acc: 2.103
# Epoch 060: | Train Loss: 12.44487 | Val Loss: 25.40208 | Train Acc: 1.469| Val Acc: 2.065
# Epoch 061: | Train Loss: 12.62122 | Val Loss: 25.84972 | Train Acc: 1.509| Val Acc: 2.117
# Epoch 062: | Train Loss: 12.51276 | Val Loss: 25.57054 | Train Acc: 1.478| Val Acc: 2.128
# Epoch 063: | Train Loss: 12.52170 | Val Loss: 25.17684 | Train Acc: 1.483| Val Acc: 2.073
# Epoch 064: | Train Loss: 12.57500 | Val Loss: 25.02385 | Train Acc: 1.486| Val Acc: 2.065
# Epoch 065: | Train Loss: 12.48671 | Val Loss: 25.74582 | Train Acc: 1.475| Val Acc: 2.083
# Epoch 066: | Train Loss: 12.66789 | Val Loss: 26.54230 | Train Acc: 1.514| Val Acc: 2.219
# Epoch 067: | Train Loss: 12.67124 | Val Loss: 25.79717 | Train Acc: 1.504| Val Acc: 2.156
# Epoch 068: | Train Loss: 12.46628 | Val Loss: 25.81031 | Train Acc: 1.478| Val Acc: 2.134
# Epoch 069: | Train Loss: 12.51600 | Val Loss: 25.76085 | Train Acc: 1.471| Val Acc: 2.105
# Epoch 070: | Train Loss: 12.46936 | Val Loss: 25.58076 | Train Acc: 1.469| Val Acc: 2.092
# Epoch 071: | Train Loss: 12.40363 | Val Loss: 25.33134 | Train Acc: 1.450| Val Acc: 2.116
# Epoch 072: | Train Loss: 12.61124 | Val Loss: 24.96693 | Train Acc: 1.489| Val Acc: 2.058
# Epoch 073: | Train Loss: 12.43331 | Val Loss: 25.61285 | Train Acc: 1.459| Val Acc: 2.103
# Epoch 074: | Train Loss: 12.51261 | Val Loss: 25.37848 | Train Acc: 1.470| Val Acc: 2.065
# Epoch 075: | Train Loss: 12.38823 | Val Loss: 25.67459 | Train Acc: 1.472| Val Acc: 2.117
# Epoch 076: | Train Loss: 12.33722 | Val Loss: 25.54978 | Train Acc: 1.449| Val Acc: 2.074
# Epoch 077: | Train Loss: 12.50302 | Val Loss: 25.54793 | Train Acc: 1.466| Val Acc: 2.087
# Epoch 078: | Train Loss: 12.47155 | Val Loss: 25.14500 | Train Acc: 1.460| Val Acc: 2.090
# Epoch 079: | Train Loss: 12.51054 | Val Loss: 24.86602 | Train Acc: 1.456| Val Acc: 2.001
# Epoch 080: | Train Loss: 12.38824 | Val Loss: 25.48678 | Train Acc: 1.452| Val Acc: 2.115
# Epoch 081: | Train Loss: 12.33956 | Val Loss: 25.11539 | Train Acc: 1.450| Val Acc: 2.014
# Epoch 082: | Train Loss: 12.33048 | Val Loss: 25.13287 | Train Acc: 1.427| Val Acc: 2.055
# Epoch 083: | Train Loss: 12.36071 | Val Loss: 25.06553 | Train Acc: 1.451| Val Acc: 2.008
# Epoch 084: | Train Loss: 12.14506 | Val Loss: 25.22581 | Train Acc: 1.406| Val Acc: 2.018
# Epoch 085: | Train Loss: 12.12908 | Val Loss: 24.97337 | Train Acc: 1.407| Val Acc: 1.993
# Epoch 086: | Train Loss: 12.12265 | Val Loss: 25.28914 | Train Acc: 1.403| Val Acc: 2.011
# Epoch 087: | Train Loss: 12.24655 | Val Loss: 25.13418 | Train Acc: 1.412| Val Acc: 2.040
# Epoch 088: | Train Loss: 12.19543 | Val Loss: 24.90046 | Train Acc: 1.408| Val Acc: 1.997
# Epoch 089: | Train Loss: 12.20361 | Val Loss: 24.64496 | Train Acc: 1.400| Val Acc: 1.993
# Epoch 090: | Train Loss: 12.10863 | Val Loss: 25.17375 | Train Acc: 1.399| Val Acc: 2.032
# Epoch 091: | Train Loss: 12.17502 | Val Loss: 24.82968 | Train Acc: 1.402| Val Acc: 2.007
# Epoch 092: | Train Loss: 12.29797 | Val Loss: 25.09827 | Train Acc: 1.408| Val Acc: 2.030
# Epoch 093: | Train Loss: 12.10626 | Val Loss: 25.33585 | Train Acc: 1.386| Val Acc: 2.110
# Epoch 094: | Train Loss: 12.26085 | Val Loss: 25.13268 | Train Acc: 1.413| Val Acc: 2.000
# Epoch 095: | Train Loss: 12.29102 | Val Loss: 24.94280 | Train Acc: 1.395| Val Acc: 2.006
# Epoch 096: | Train Loss: 12.19339 | Val Loss: 25.39923 | Train Acc: 1.403| Val Acc: 2.021
# Epoch 097: | Train Loss: 12.05739 | Val Loss: 25.16269 | Train Acc: 1.373| Val Acc: 1.983
# Epoch 098: | Train Loss: 12.09114 | Val Loss: 25.29020 | Train Acc: 1.388| Val Acc: 2.048
# Epoch 099: | Train Loss: 12.28918 | Val Loss: 24.66176 | Train Acc: 1.423| Val Acc: 1.986
# Epoch 100: | Train Loss: 12.30605 | Val Loss: 25.17872 | Train Acc: 1.418| Val Acc: 2.027
# Epoch 101: | Train Loss: 12.20828 | Val Loss: 24.74168 | Train Acc: 1.420| Val Acc: 1.976
# Epoch 102: | Train Loss: 12.14711 | Val Loss: 25.11005 | Train Acc: 1.393| Val Acc: 2.058
# Epoch 103: | Train Loss: 12.22019 | Val Loss: 25.24648 | Train Acc: 1.395| Val Acc: 2.040
# Epoch 104: | Train Loss: 12.18031 | Val Loss: 25.60436 | Train Acc: 1.380| Val Acc: 2.053
# Epoch 105: | Train Loss: 12.26066 | Val Loss: 25.53463 | Train Acc: 1.408| Val Acc: 2.068
# Epoch 106: | Train Loss: 12.08955 | Val Loss: 24.97113 | Train Acc: 1.386| Val Acc: 2.037
# Epoch 107: | Train Loss: 12.08787 | Val Loss: 25.12549 | Train Acc: 1.369| Val Acc: 1.993
# Epoch 108: | Train Loss: 12.20525 | Val Loss: 25.12922 | Train Acc: 1.384| Val Acc: 2.018
# Epoch 109: | Train Loss: 12.10871 | Val Loss: 25.37478 | Train Acc: 1.377| Val Acc: 2.043
# Epoch 110: | Train Loss: 12.31847 | Val Loss: 25.10980 | Train Acc: 1.414| Val Acc: 2.037
# Epoch 111: | Train Loss: 12.21211 | Val Loss: 25.26237 | Train Acc: 1.397| Val Acc: 2.062
# Epoch 112: | Train Loss: 12.12768 | Val Loss: 25.53348 | Train Acc: 1.383| Val Acc: 2.048
# Epoch 113: | Train Loss: 12.28528 | Val Loss: 25.34791 | Train Acc: 1.428| Val Acc: 2.069
# Epoch 114: | Train Loss: 12.41887 | Val Loss: 25.32004 | Train Acc: 1.439| Val Acc: 2.030
# Epoch 115: | Train Loss: 12.21351 | Val Loss: 24.75281 | Train Acc: 1.396| Val Acc: 1.998
# Epoch 116: | Train Loss: 12.04831 | Val Loss: 24.56903 | Train Acc: 1.378| Val Acc: 2.006
# Epoch 117: | Train Loss: 12.02386 | Val Loss: 24.57772 | Train Acc: 1.362| Val Acc: 1.965
# Epoch 118: | Train Loss: 12.07559 | Val Loss: 24.82577 | Train Acc: 1.384| Val Acc: 1.988
# Epoch 119: | Train Loss: 12.02094 | Val Loss: 25.00133 | Train Acc: 1.367| Val Acc: 2.004
# Epoch 120: | Train Loss: 11.96575 | Val Loss: 24.47241 | Train Acc: 1.369| Val Acc: 1.964
# Epoch 121: | Train Loss: 11.94480 | Val Loss: 24.88401 | Train Acc: 1.355| Val Acc: 1.976
# Epoch 122: | Train Loss: 11.89493 | Val Loss: 24.72667 | Train Acc: 1.343| Val Acc: 1.966
# Epoch 123: | Train Loss: 11.96313 | Val Loss: 24.88341 | Train Acc: 1.336| Val Acc: 2.012
# Epoch 124: | Train Loss: 11.94605 | Val Loss: 24.82199 | Train Acc: 1.355| Val Acc: 2.006
# Epoch 125: | Train Loss: 11.94223 | Val Loss: 24.70886 | Train Acc: 1.358| Val Acc: 1.958
# Epoch 126: | Train Loss: 12.08512 | Val Loss: 25.11182 | Train Acc: 1.378| Val Acc: 2.004
# Epoch 127: | Train Loss: 11.95148 | Val Loss: 25.05295 | Train Acc: 1.338| Val Acc: 2.010
# Epoch 128: | Train Loss: 12.04499 | Val Loss: 25.04323 | Train Acc: 1.349| Val Acc: 2.021
# Epoch 129: | Train Loss: 12.06721 | Val Loss: 25.12062 | Train Acc: 1.388| Val Acc: 2.009
# Epoch 130: | Train Loss: 12.04941 | Val Loss: 25.12596 | Train Acc: 1.351| Val Acc: 2.003
# Epoch 131: | Train Loss: 11.96129 | Val Loss: 24.79752 | Train Acc: 1.344| Val Acc: 1.990
# Epoch 132: | Train Loss: 12.04435 | Val Loss: 24.85071 | Train Acc: 1.364| Val Acc: 1.997
# Epoch 133: | Train Loss: 12.01603 | Val Loss: 24.86213 | Train Acc: 1.378| Val Acc: 1.979
# Epoch 134: | Train Loss: 12.03743 | Val Loss: 25.33509 | Train Acc: 1.370| Val Acc: 2.040
# Epoch 135: | Train Loss: 12.07923 | Val Loss: 24.54101 | Train Acc: 1.376| Val Acc: 1.988
# Epoch 136: | Train Loss: 11.92579 | Val Loss: 25.32518 | Train Acc: 1.330| Val Acc: 2.087
# Epoch 137: | Train Loss: 12.01807 | Val Loss: 24.62069 | Train Acc: 1.354| Val Acc: 1.986
# Epoch 138: | Train Loss: 12.03344 | Val Loss: 24.94655 | Train Acc: 1.346| Val Acc: 1.973
# Epoch 139: | Train Loss: 12.10663 | Val Loss: 24.88475 | Train Acc: 1.374| Val Acc: 1.978
# Epoch 140: | Train Loss: 12.04736 | Val Loss: 24.90788 | Train Acc: 1.343| Val Acc: 2.007
# Epoch 141: | Train Loss: 12.06749 | Val Loss: 24.90728 | Train Acc: 1.360| Val Acc: 1.992
# Epoch 142: | Train Loss: 11.96924 | Val Loss: 24.88780 | Train Acc: 1.354| Val Acc: 2.022
# Epoch 143: | Train Loss: 11.89876 | Val Loss: 24.89319 | Train Acc: 1.320| Val Acc: 1.985
# Epoch 144: | Train Loss: 11.88311 | Val Loss: 24.97957 | Train Acc: 1.330| Val Acc: 1.968
# Epoch 145: | Train Loss: 11.95975 | Val Loss: 25.10482 | Train Acc: 1.323| Val Acc: 2.034
# Epoch 146: | Train Loss: 11.93520 | Val Loss: 24.59639 | Train Acc: 1.331| Val Acc: 1.965
# Epoch 147: | Train Loss: 11.86853 | Val Loss: 25.37117 | Train Acc: 1.310| Val Acc: 2.028
# Epoch 148: | Train Loss: 11.89880 | Val Loss: 24.96565 | Train Acc: 1.329| Val Acc: 2.014
# Epoch 149: | Train Loss: 11.86730 | Val Loss: 25.15653 | Train Acc: 1.327| Val Acc: 2.013
# Epoch 150: | Train Loss: 11.99736 | Val Loss: 24.75019 | Train Acc: 1.336| Val Acc: 1.961

# %%
metrics(train, test, threshold=30)
# Out:
# MAE on train set:  143.00279142549238
# min prediction: 1
# max prediction: 1104
#
# MAE on test set:  151.03662892574332
# Error ⩽ 30: 19.09 %
# min prediction: 1
# max prediction: 1094

# %%
validation_plots(test,model_type)

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.000001, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)
# Out:
# Epoch 001: | Train Loss: 13.72409 | Val Loss: 4.81637 | Train Acc: 1.557| Val Acc: 2.633
# Epoch 002: | Train Loss: 13.44189 | Val Loss: 6.96844 | Train Acc: 1.525| Val Acc: 2.633
# Epoch 003: | Train Loss: 13.28064 | Val Loss: 6.81026 | Train Acc: 1.517| Val Acc: 2.633
# Epoch 004: | Train Loss: 13.19472 | Val Loss: 5.35863 | Train Acc: 1.481| Val Acc: 2.633
# Epoch 005: | Train Loss: 13.06716 | Val Loss: 4.95701 | Train Acc: 1.471| Val Acc: 2.633
# Epoch 006: | Train Loss: 12.90266 | Val Loss: 5.65886 | Train Acc: 1.453| Val Acc: 2.633
# Epoch 007: | Train Loss: 12.84213 | Val Loss: 5.35060 | Train Acc: 1.445| Val Acc: 2.633
# Epoch 008: | Train Loss: 13.08467 | Val Loss: 4.71024 | Train Acc: 1.484| Val Acc: 2.633
# Epoch 009: | Train Loss: 13.07357 | Val Loss: 4.48110 | Train Acc: 1.476| Val Acc: 1.633
# Epoch 010: | Train Loss: 12.99045 | Val Loss: 3.91117 | Train Acc: 1.464| Val Acc: 1.633
# Epoch 011: | Train Loss: 12.90586 | Val Loss: 3.50997 | Train Acc: 1.473| Val Acc: 1.633
# Epoch 012: | Train Loss: 13.04013 | Val Loss: 4.96291 | Train Acc: 1.487| Val Acc: 2.633
# Epoch 013: | Train Loss: 12.74244 | Val Loss: 4.41746 | Train Acc: 1.452| Val Acc: 1.633
# Epoch 014: | Train Loss: 12.88148 | Val Loss: 5.13475 | Train Acc: 1.473| Val Acc: 2.633
# Epoch 015: | Train Loss: 13.05187 | Val Loss: 6.22491 | Train Acc: 1.487| Val Acc: 2.633
# Epoch 016: | Train Loss: 12.82081 | Val Loss: 4.48160 | Train Acc: 1.443| Val Acc: 1.633
# Epoch 017: | Train Loss: 12.77116 | Val Loss: 5.34683 | Train Acc: 1.447| Val Acc: 2.633
# Epoch 018: | Train Loss: 12.74601 | Val Loss: 6.55092 | Train Acc: 1.426| Val Acc: 2.633
# Epoch 019: | Train Loss: 12.63770 | Val Loss: 4.65398 | Train Acc: 1.414| Val Acc: 2.633
# Epoch 020: | Train Loss: 12.75155 | Val Loss: 4.41981 | Train Acc: 1.435| Val Acc: 1.633
# Epoch 021: | Train Loss: 12.64010 | Val Loss: 4.69046 | Train Acc: 1.415| Val Acc: 2.633
# Epoch 022: | Train Loss: 12.51429 | Val Loss: 3.47969 | Train Acc: 1.412| Val Acc: 1.633
# Epoch 023: | Train Loss: 12.60770 | Val Loss: 3.04295 | Train Acc: 1.428| Val Acc: 1.633
# Epoch 024: | Train Loss: 12.44533 | Val Loss: 3.29392 | Train Acc: 1.394| Val Acc: 1.633
# Epoch 025: | Train Loss: 12.57616 | Val Loss: 3.67676 | Train Acc: 1.411| Val Acc: 1.633
# Epoch 026: | Train Loss: 12.49544 | Val Loss: 3.92209 | Train Acc: 1.395| Val Acc: 1.633
# Epoch 027: | Train Loss: 12.51120 | Val Loss: 3.88253 | Train Acc: 1.400| Val Acc: 1.633
# Epoch 028: | Train Loss: 12.49892 | Val Loss: 4.70556 | Train Acc: 1.417| Val Acc: 2.633
# Epoch 029: | Train Loss: 12.45788 | Val Loss: 4.17829 | Train Acc: 1.390| Val Acc: 1.633
# Epoch 030: | Train Loss: 12.46583 | Val Loss: 5.29878 | Train Acc: 1.399| Val Acc: 2.633
# Epoch 031: | Train Loss: 12.43678 | Val Loss: 4.62558 | Train Acc: 1.398| Val Acc: 2.633
# Epoch 032: | Train Loss: 12.58673 | Val Loss: 6.04006 | Train Acc: 1.412| Val Acc: 2.633
# Epoch 033: | Train Loss: 12.48221 | Val Loss: 5.01885 | Train Acc: 1.397| Val Acc: 2.633
# Epoch 034: | Train Loss: 12.53926 | Val Loss: 4.79306 | Train Acc: 1.399| Val Acc: 2.633
# Epoch 035: | Train Loss: 12.57850 | Val Loss: 4.80913 | Train Acc: 1.416| Val Acc: 2.633
# Epoch 036: | Train Loss: 12.43610 | Val Loss: 4.27551 | Train Acc: 1.408| Val Acc: 1.633
# Epoch 037: | Train Loss: 12.49627 | Val Loss: 4.07711 | Train Acc: 1.410| Val Acc: 1.633
# Epoch 038: | Train Loss: 12.44696 | Val Loss: 4.58125 | Train Acc: 1.394| Val Acc: 2.633
# Epoch 039: | Train Loss: 12.38752 | Val Loss: 8.38174 | Train Acc: 1.387| Val Acc: 2.633
# Epoch 040: | Train Loss: 12.23913 | Val Loss: 7.31138 | Train Acc: 1.363| Val Acc: 2.633
# Epoch 041: | Train Loss: 12.37820 | Val Loss: 7.30626 | Train Acc: 1.375| Val Acc: 2.633
# Epoch 042: | Train Loss: 12.28724 | Val Loss: 4.77820 | Train Acc: 1.378| Val Acc: 2.633
# Epoch 043: | Train Loss: 12.26121 | Val Loss: 5.80935 | Train Acc: 1.375| Val Acc: 2.633
# Epoch 044: | Train Loss: 12.49573 | Val Loss: 5.48133 | Train Acc: 1.406| Val Acc: 2.633
# Epoch 045: | Train Loss: 12.27163 | Val Loss: 4.51813 | Train Acc: 1.357| Val Acc: 1.633
# Epoch 046: | Train Loss: 12.45264 | Val Loss: 4.59444 | Train Acc: 1.393| Val Acc: 2.633
# Epoch 047: | Train Loss: 12.25896 | Val Loss: 4.22807 | Train Acc: 1.376| Val Acc: 1.633
# Epoch 048: | Train Loss: 12.46255 | Val Loss: 4.56179 | Train Acc: 1.397| Val Acc: 2.633
# Epoch 049: | Train Loss: 12.44781 | Val Loss: 3.28756 | Train Acc: 1.409| Val Acc: 1.633
# Epoch 050: | Train Loss: 12.35011 | Val Loss: 3.55728 | Train Acc: 1.381| Val Acc: 1.633
# Epoch 051: | Train Loss: 12.32279 | Val Loss: 4.34747 | Train Acc: 1.384| Val Acc: 1.633
# Epoch 052: | Train Loss: 12.35311 | Val Loss: 6.20581 | Train Acc: 1.373| Val Acc: 2.633
# Epoch 053: | Train Loss: 12.18019 | Val Loss: 5.79402 | Train Acc: 1.356| Val Acc: 2.633
# Epoch 054: | Train Loss: 12.29646 | Val Loss: 4.21124 | Train Acc: 1.377| Val Acc: 1.633
# Epoch 055: | Train Loss: 12.36413 | Val Loss: 3.43754 | Train Acc: 1.380| Val Acc: 1.633
# Epoch 056: | Train Loss: 12.25307 | Val Loss: 5.92754 | Train Acc: 1.373| Val Acc: 2.633
# Epoch 057: | Train Loss: 12.35862 | Val Loss: 5.63541 | Train Acc: 1.376| Val Acc: 2.633
# Epoch 058: | Train Loss: 12.35696 | Val Loss: 5.32176 | Train Acc: 1.377| Val Acc: 2.633
# Epoch 059: | Train Loss: 12.26866 | Val Loss: 5.58934 | Train Acc: 1.362| Val Acc: 2.633
# Epoch 060: | Train Loss: 12.21970 | Val Loss: 4.14921 | Train Acc: 1.354| Val Acc: 1.633
# Epoch 061: | Train Loss: 12.18330 | Val Loss: 4.11693 | Train Acc: 1.354| Val Acc: 1.633
# Epoch 062: | Train Loss: 12.27679 | Val Loss: 4.40359 | Train Acc: 1.352| Val Acc: 1.633
# Epoch 063: | Train Loss: 12.39185 | Val Loss: 4.46017 | Train Acc: 1.384| Val Acc: 1.633
# Epoch 064: | Train Loss: 12.13765 | Val Loss: 2.92948 | Train Acc: 1.364| Val Acc: 1.633
# Epoch 065: | Train Loss: 12.22481 | Val Loss: 3.80916 | Train Acc: 1.374| Val Acc: 1.633
# Epoch 066: | Train Loss: 12.23682 | Val Loss: 4.19003 | Train Acc: 1.347| Val Acc: 1.633
# Epoch 067: | Train Loss: 12.13664 | Val Loss: 2.63801 | Train Acc: 1.355| Val Acc: 1.633
# Epoch 068: | Train Loss: 12.42198 | Val Loss: 4.49733 | Train Acc: 1.388| Val Acc: 1.633
# Epoch 069: | Train Loss: 12.32247 | Val Loss: 5.56613 | Train Acc: 1.383| Val Acc: 2.633
# Epoch 070: | Train Loss: 12.26901 | Val Loss: 3.98174 | Train Acc: 1.348| Val Acc: 1.633
# Epoch 071: | Train Loss: 12.15287 | Val Loss: 5.61581 | Train Acc: 1.341| Val Acc: 2.633
# Epoch 072: | Train Loss: 12.05315 | Val Loss: 5.02361 | Train Acc: 1.349| Val Acc: 2.633
# Epoch 073: | Train Loss: 12.16983 | Val Loss: 4.81948 | Train Acc: 1.347| Val Acc: 2.633
# Epoch 074: | Train Loss: 12.16133 | Val Loss: 4.09151 | Train Acc: 1.358| Val Acc: 1.633
# Epoch 075: | Train Loss: 12.13928 | Val Loss: 5.18391 | Train Acc: 1.349| Val Acc: 2.633
# Epoch 076: | Train Loss: 12.11699 | Val Loss: 5.01643 | Train Acc: 1.340| Val Acc: 2.633
# Epoch 077: | Train Loss: 12.13457 | Val Loss: 4.30218 | Train Acc: 1.350| Val Acc: 1.633
# Epoch 078: | Train Loss: 12.12017 | Val Loss: 5.04753 | Train Acc: 1.338| Val Acc: 2.633
# Epoch 079: | Train Loss: 12.23996 | Val Loss: 5.47024 | Train Acc: 1.344| Val Acc: 2.633
# Epoch 080: | Train Loss: 12.17148 | Val Loss: 5.08992 | Train Acc: 1.348| Val Acc: 2.633
# Epoch 081: | Train Loss: 12.20050 | Val Loss: 5.04779 | Train Acc: 1.355| Val Acc: 2.633
# Epoch 082: | Train Loss: 12.22226 | Val Loss: 4.40002 | Train Acc: 1.370| Val Acc: 1.633
# Epoch 083: | Train Loss: 12.14325 | Val Loss: 4.32327 | Train Acc: 1.361| Val Acc: 1.633
# Epoch 084: | Train Loss: 12.17009 | Val Loss: 4.83848 | Train Acc: 1.362| Val Acc: 2.633
# Epoch 085: | Train Loss: 12.13465 | Val Loss: 4.59558 | Train Acc: 1.323| Val Acc: 2.633
# Epoch 086: | Train Loss: 12.10365 | Val Loss: 4.16503 | Train Acc: 1.331| Val Acc: 1.633
# Epoch 087: | Train Loss: 12.08994 | Val Loss: 4.61601 | Train Acc: 1.336| Val Acc: 2.633
# Epoch 088: | Train Loss: 12.02783 | Val Loss: 4.38085 | Train Acc: 1.345| Val Acc: 1.633
# Epoch 089: | Train Loss: 11.96141 | Val Loss: 5.40535 | Train Acc: 1.316| Val Acc: 2.633
# Epoch 090: | Train Loss: 11.99665 | Val Loss: 7.30738 | Train Acc: 1.319| Val Acc: 2.633
# Epoch 091: | Train Loss: 12.11329 | Val Loss: 4.92116 | Train Acc: 1.343| Val Acc: 2.633
# Epoch 092: | Train Loss: 12.13331 | Val Loss: 5.08354 | Train Acc: 1.340| Val Acc: 2.633
# Epoch 093: | Train Loss: 12.12053 | Val Loss: 4.62507 | Train Acc: 1.330| Val Acc: 2.633
# Epoch 094: | Train Loss: 12.06564 | Val Loss: 4.20372 | Train Acc: 1.336| Val Acc: 1.633
# Epoch 095: | Train Loss: 12.16750 | Val Loss: 6.52790 | Train Acc: 1.353| Val Acc: 2.633
# Epoch 096: | Train Loss: 12.24362 | Val Loss: 6.41871 | Train Acc: 1.343| Val Acc: 2.633
# Epoch 097: | Train Loss: 12.12015 | Val Loss: 4.00096 | Train Acc: 1.347| Val Acc: 1.633
# Epoch 098: | Train Loss: 12.15056 | Val Loss: 4.93490 | Train Acc: 1.348| Val Acc: 2.633
# Epoch 099: | Train Loss: 12.13099 | Val Loss: 5.71602 | Train Acc: 1.339| Val Acc: 2.633
# Epoch 100: | Train Loss: 12.10968 | Val Loss: 4.45224 | Train Acc: 1.365| Val Acc: 1.633
# Epoch 101: | Train Loss: 12.10294 | Val Loss: 5.80868 | Train Acc: 1.337| Val Acc: 2.633
# Epoch 102: | Train Loss: 12.20723 | Val Loss: 6.79843 | Train Acc: 1.351| Val Acc: 2.633
# Epoch 103: | Train Loss: 12.18265 | Val Loss: 6.46975 | Train Acc: 1.348| Val Acc: 2.633
# Epoch 104: | Train Loss: 12.01802 | Val Loss: 5.15581 | Train Acc: 1.333| Val Acc: 2.633
# Epoch 105: | Train Loss: 12.09614 | Val Loss: 5.23006 | Train Acc: 1.342| Val Acc: 2.633
# Epoch 106: | Train Loss: 12.08176 | Val Loss: 6.77652 | Train Acc: 1.344| Val Acc: 2.633
# Epoch 107: | Train Loss: 12.21641 | Val Loss: 7.70306 | Train Acc: 1.353| Val Acc: 2.633
# Epoch 108: | Train Loss: 12.07071 | Val Loss: 6.70326 | Train Acc: 1.337| Val Acc: 2.633
# Epoch 109: | Train Loss: 12.18802 | Val Loss: 5.95683 | Train Acc: 1.355| Val Acc: 2.633
# Epoch 110: | Train Loss: 12.26783 | Val Loss: 7.91522 | Train Acc: 1.353| Val Acc: 2.633
# Epoch 111: | Train Loss: 12.11909 | Val Loss: 5.83419 | Train Acc: 1.343| Val Acc: 2.633
# Epoch 112: | Train Loss: 12.10896 | Val Loss: 4.72799 | Train Acc: 1.330| Val Acc: 2.633
# Epoch 113: | Train Loss: 12.10618 | Val Loss: 5.50283 | Train Acc: 1.335| Val Acc: 2.633
# Epoch 114: | Train Loss: 12.14113 | Val Loss: 5.95754 | Train Acc: 1.347| Val Acc: 2.633
# Epoch 115: | Train Loss: 12.03252 | Val Loss: 6.04664 | Train Acc: 1.323| Val Acc: 2.633
# Epoch 116: | Train Loss: 12.05968 | Val Loss: 5.81619 | Train Acc: 1.328| Val Acc: 2.633
# Epoch 117: | Train Loss: 12.10274 | Val Loss: 6.39016 | Train Acc: 1.333| Val Acc: 2.633
# Epoch 118: | Train Loss: 11.97099 | Val Loss: 5.36000 | Train Acc: 1.317| Val Acc: 2.633
# Epoch 119: | Train Loss: 11.99457 | Val Loss: 5.52102 | Train Acc: 1.307| Val Acc: 2.633
# Epoch 120: | Train Loss: 11.90592 | Val Loss: 6.05474 | Train Acc: 1.301| Val Acc: 2.633
# Epoch 121: | Train Loss: 11.96581 | Val Loss: 3.36060 | Train Acc: 1.309| Val Acc: 1.633
# Epoch 122: | Train Loss: 12.21504 | Val Loss: 3.98257 | Train Acc: 1.361| Val Acc: 1.633
# Epoch 123: | Train Loss: 12.12478 | Val Loss: 4.59717 | Train Acc: 1.341| Val Acc: 2.633
# Epoch 124: | Train Loss: 12.00582 | Val Loss: 5.97339 | Train Acc: 1.330| Val Acc: 2.633
# Epoch 125: | Train Loss: 11.91151 | Val Loss: 6.97846 | Train Acc: 1.302| Val Acc: 2.633
# Epoch 126: | Train Loss: 12.09670 | Val Loss: 6.99298 | Train Acc: 1.316| Val Acc: 2.633
# Epoch 127: | Train Loss: 12.10658 | Val Loss: 5.04839 | Train Acc: 1.351| Val Acc: 2.633
# Epoch 128: | Train Loss: 12.10575 | Val Loss: 4.80603 | Train Acc: 1.339| Val Acc: 2.633
# Epoch 129: | Train Loss: 12.03543 | Val Loss: 6.37433 | Train Acc: 1.317| Val Acc: 2.633
# Epoch 130: | Train Loss: 12.07252 | Val Loss: 5.73857 | Train Acc: 1.332| Val Acc: 2.633
# Epoch 131: | Train Loss: 12.33444 | Val Loss: 4.39105 | Train Acc: 1.373| Val Acc: 1.633
# Epoch 132: | Train Loss: 12.07771 | Val Loss: 4.79620 | Train Acc: 1.329| Val Acc: 2.633
# Epoch 133: | Train Loss: 12.36932 | Val Loss: 5.83309 | Train Acc: 1.381| Val Acc: 2.633
# Epoch 134: | Train Loss: 12.10987 | Val Loss: 5.81071 | Train Acc: 1.340| Val Acc: 2.633
# Epoch 135: | Train Loss: 12.20710 | Val Loss: 5.19624 | Train Acc: 1.343| Val Acc: 2.633
# Epoch 136: | Train Loss: 11.98637 | Val Loss: 5.50241 | Train Acc: 1.328| Val Acc: 2.633
# Epoch 137: | Train Loss: 11.95718 | Val Loss: 5.15591 | Train Acc: 1.317| Val Acc: 2.633
# Epoch 138: | Train Loss: 11.89539 | Val Loss: 3.89433 | Train Acc: 1.308| Val Acc: 1.633
# Epoch 139: | Train Loss: 12.04715 | Val Loss: 4.43532 | Train Acc: 1.312| Val Acc: 1.633
# Epoch 140: | Train Loss: 11.96560 | Val Loss: 4.70864 | Train Acc: 1.316| Val Acc: 2.633
# Epoch 141: | Train Loss: 11.99515 | Val Loss: 4.95500 | Train Acc: 1.308| Val Acc: 2.633
# Epoch 142: | Train Loss: 12.06488 | Val Loss: 6.47995 | Train Acc: 1.317| Val Acc: 2.633
# Epoch 143: | Train Loss: 12.05310 | Val Loss: 6.02023 | Train Acc: 1.318| Val Acc: 2.633
# Epoch 144: | Train Loss: 11.95917 | Val Loss: 6.70243 | Train Acc: 1.314| Val Acc: 2.633
# Epoch 145: | Train Loss: 12.20634 | Val Loss: 6.28268 | Train Acc: 1.366| Val Acc: 2.633
# Epoch 146: | Train Loss: 12.01216 | Val Loss: 6.84783 | Train Acc: 1.319| Val Acc: 2.633
# Epoch 147: | Train Loss: 12.08384 | Val Loss: 5.22096 | Train Acc: 1.313| Val Acc: 2.633
# Epoch 148: | Train Loss: 12.00674 | Val Loss: 5.58570 | Train Acc: 1.313| Val Acc: 2.633
# Epoch 149: | Train Loss: 11.97018 | Val Loss: 6.00445 | Train Acc: 1.306| Val Acc: 2.633
# Epoch 150: | Train Loss: 12.05263 | Val Loss: 6.29352 | Train Acc: 1.317| Val Acc: 2.633

# %%
pickle.dump(model, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_Mamoth_NN.pt', 'wb'))
pickle.dump(imputer, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_KNN_Imputer.pkl', 'wb'))
pickle.dump(scaler, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_Scaler.pkl', 'wb'))
