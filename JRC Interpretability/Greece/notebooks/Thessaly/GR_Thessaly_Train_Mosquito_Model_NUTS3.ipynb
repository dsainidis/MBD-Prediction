# %% [markdown]
# ## Produces **Mosquito Predictions** for a specific region using MAMOTH ##

# %%
import pandas as pd
import datetime
import math
import numpy as np
import missingno
import json
from statistics import mean
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
import sys
import pickle

sys.path.insert(0, "../../../../Mamoth")
sys.path.insert(0, "../../../../Modules")

from utils import *

from Preprocessing_Module import read_data, select_columns, reshape_dataset
from Initializer_Module import initializer
from Neural_Network_Module import Dataset, transformations, FeedforwardNeuralNetModel, train_nn, give_predictions
from Model_Validation_Module import validation_plots, metrics

enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 100
pd.options.display.float_format = lambda x: '%.6f' % x

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
NUTS0 = 'GR'
NUTS2 = 'Thessaly'
NUTS2_EL = 'θεσσαλιας'

# %%
mosquito_data = read_data(f'../../data/{NUTS0}_MSQ_culex_2011-2022_processed.csv')
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
mosquito_data.nuts2.unique()
# Out:
# array(['κεντρικης μακεδονιας', 'θεσσαλιας', 'κρητης', 'δυτικης ελλαδας'],
#       dtype=object)

# %%
mosquito_data_nuts2 = mosquito_data.query(f"nuts2 == '{NUTS2_EL}'").copy()
mosquito_data_nuts2.reset_index(inplace = True, drop = True)

# %%
mosq_columns = mosquito_data_nuts2.columns
mosq_columns
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
                'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
                'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
                'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
                'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
                'acc_rainfall_jan', 'mosq_now']

# columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#                 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#                 'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#                 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#                 'lst_night', 'acc_rainfall_1week', 'acc_rainfall_2week',
#                 'acc_rainfall_jan', 'mosq_now']

mosquito_data_nuts2 = select_columns(mosquito_data_nuts2, columns_to_keep, columns_to_keep)

mosquito_data_nuts2 = reshape_dataset(mosquito_data_nuts2,['x','y','dt_placement'])

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()

# %%
#quantile might change based on sns plots
mosq_quantilie = mosquito_data_nuts2['mosq_now'].quantile(0.95)

mosquito_data_nuts2['mosq_now'][mosquito_data_nuts2['mosq_now'] > mosq_quantilie] = mosq_quantilie+1

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <AxesSubplot:>

# %%
imputer = KNNImputer()

features_for_impute = ['x', 'y', 'day', 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 
                        'lst_day', 'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean', 'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan']

# features_for_impute = ['x', 'y', 'day', 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#                         'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 
#                         'lst_day', 'lst_night', 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan']

mosquito_data_sub = mosquito_data_nuts2[features_for_impute]

imputed_data = pd.DataFrame(imputer.fit_transform(mosquito_data_sub), columns = mosquito_data_sub.columns)

# %%
# imputed_columns = ['ndvi','ndmi', 'ndwi', 'ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std', 'ndmi_std','ndwi_std','ndbi_std',
#                    'lst_day','lst_night']

imputed_columns = ['ndvi','ndmi', 'ndwi', 'ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std', 'ndmi_std','ndwi_std','ndbi_std',
                   'lst_day','lst_night','lst_jan_mean','lst_feb_mean','lst_mar_mean','lst_apr_mean']

mosquito_data_nuts2[imputed_columns] = imputed_data[imputed_columns]

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <AxesSubplot:>

# %%
step = 15
only_env = True
case_title = 'NN mosq regression'
exp = False
date_col = 'dt_placement'
model_type = 'mosquito_regression'
transform_target = True
augment = True

# %%
mosquito_data_nuts2 = initializer(mosquito_data_nuts2,2,10,25,step,[date_col], env=only_env, date_column = date_col, mosq_column='mosq_now')
# Out:
# Bounds: [  0.    16.5  255.15]

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.25, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

model = FeedforwardNeuralNetModel(num_features=len(train_X[0]), num_class=1, hidden_layers = [264,128,128,64], dropout=0.2, model_type=model_type, transform = transform_target)

# %%
train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)
# Out:
# Epoch 001: | Train Loss: 43.22783 | Val Loss: 28.34548 | Train Acc: 4.565| Val Acc: 3.324
# Epoch 002: | Train Loss: 39.62741 | Val Loss: 27.95072 | Train Acc: 4.042| Val Acc: 2.979
# Epoch 003: | Train Loss: 37.04318 | Val Loss: 26.77983 | Train Acc: 3.541| Val Acc: 2.932
# Epoch 004: | Train Loss: 35.43220 | Val Loss: 26.37848 | Train Acc: 3.239| Val Acc: 2.901
# Epoch 005: | Train Loss: 34.82609 | Val Loss: 26.23324 | Train Acc: 3.044| Val Acc: 2.866
# Epoch 006: | Train Loss: 34.03999 | Val Loss: 25.43657 | Train Acc: 2.928| Val Acc: 2.656
# Epoch 007: | Train Loss: 33.77046 | Val Loss: 24.77346 | Train Acc: 2.857| Val Acc: 2.426
# Epoch 008: | Train Loss: 33.43363 | Val Loss: 24.05402 | Train Acc: 2.797| Val Acc: 2.374
# Epoch 009: | Train Loss: 33.11947 | Val Loss: 24.07581 | Train Acc: 2.772| Val Acc: 2.206
# Epoch 010: | Train Loss: 32.58488 | Val Loss: 23.69780 | Train Acc: 2.721| Val Acc: 2.202
# Epoch 011: | Train Loss: 32.70938 | Val Loss: 23.33260 | Train Acc: 2.685| Val Acc: 2.004
# Epoch 012: | Train Loss: 32.50949 | Val Loss: 23.77598 | Train Acc: 2.631| Val Acc: 1.985
# Epoch 013: | Train Loss: 32.57867 | Val Loss: 23.70047 | Train Acc: 2.634| Val Acc: 2.153
# Epoch 014: | Train Loss: 32.16926 | Val Loss: 23.76291 | Train Acc: 2.668| Val Acc: 2.149
# Epoch 015: | Train Loss: 32.30240 | Val Loss: 24.20646 | Train Acc: 2.601| Val Acc: 2.491
# Epoch 016: | Train Loss: 31.93939 | Val Loss: 23.73397 | Train Acc: 2.580| Val Acc: 2.130
# Epoch 017: | Train Loss: 31.91871 | Val Loss: 23.56265 | Train Acc: 2.534| Val Acc: 1.959
# Epoch 018: | Train Loss: 32.13014 | Val Loss: 23.59500 | Train Acc: 2.564| Val Acc: 1.819
# Epoch 019: | Train Loss: 31.83455 | Val Loss: 23.39343 | Train Acc: 2.550| Val Acc: 1.831
# Epoch 020: | Train Loss: 31.62652 | Val Loss: 23.06260 | Train Acc: 2.523| Val Acc: 1.953
# Epoch 021: | Train Loss: 31.78243 | Val Loss: 22.72647 | Train Acc: 2.520| Val Acc: 1.939
# Epoch 022: | Train Loss: 31.76648 | Val Loss: 22.58310 | Train Acc: 2.536| Val Acc: 1.950
# Epoch 023: | Train Loss: 31.96160 | Val Loss: 23.08479 | Train Acc: 2.499| Val Acc: 1.938
# Epoch 024: | Train Loss: 31.71000 | Val Loss: 23.66846 | Train Acc: 2.505| Val Acc: 1.954
# Epoch 025: | Train Loss: 31.55501 | Val Loss: 24.27233 | Train Acc: 2.497| Val Acc: 2.085
# Epoch 026: | Train Loss: 31.54196 | Val Loss: 24.15589 | Train Acc: 2.452| Val Acc: 1.788
# Epoch 027: | Train Loss: 31.39632 | Val Loss: 23.45462 | Train Acc: 2.413| Val Acc: 1.788
# Epoch 028: | Train Loss: 31.41522 | Val Loss: 22.93138 | Train Acc: 2.438| Val Acc: 1.607
# Epoch 029: | Train Loss: 31.25614 | Val Loss: 23.34081 | Train Acc: 2.366| Val Acc: 1.770
# Epoch 030: | Train Loss: 31.46534 | Val Loss: 23.13989 | Train Acc: 2.388| Val Acc: 1.947
# Epoch 031: | Train Loss: 31.33028 | Val Loss: 23.61071 | Train Acc: 2.390| Val Acc: 1.779
# Epoch 032: | Train Loss: 31.08076 | Val Loss: 23.75818 | Train Acc: 2.351| Val Acc: 1.614
# Epoch 033: | Train Loss: 31.38002 | Val Loss: 23.41383 | Train Acc: 2.397| Val Acc: 1.579
# Epoch 034: | Train Loss: 31.09143 | Val Loss: 23.59328 | Train Acc: 2.357| Val Acc: 1.592
# Epoch 035: | Train Loss: 30.98689 | Val Loss: 23.53319 | Train Acc: 2.248| Val Acc: 1.618
# Epoch 036: | Train Loss: 31.35617 | Val Loss: 23.74356 | Train Acc: 2.323| Val Acc: 1.631
# Epoch 037: | Train Loss: 31.25649 | Val Loss: 23.53985 | Train Acc: 2.327| Val Acc: 1.623
# Epoch 038: | Train Loss: 30.98251 | Val Loss: 23.45644 | Train Acc: 2.296| Val Acc: 1.764
# Epoch 039: | Train Loss: 30.86560 | Val Loss: 23.40055 | Train Acc: 2.317| Val Acc: 1.772
# Epoch 040: | Train Loss: 31.08949 | Val Loss: 23.17430 | Train Acc: 2.303| Val Acc: 1.608
# Epoch 041: | Train Loss: 30.77654 | Val Loss: 23.04648 | Train Acc: 2.260| Val Acc: 1.600
# Epoch 042: | Train Loss: 31.00121 | Val Loss: 23.12904 | Train Acc: 2.268| Val Acc: 1.619
# Epoch 043: | Train Loss: 31.00973 | Val Loss: 22.93067 | Train Acc: 2.316| Val Acc: 1.639
# Epoch 044: | Train Loss: 30.83156 | Val Loss: 23.03610 | Train Acc: 2.243| Val Acc: 1.636
# Epoch 045: | Train Loss: 30.94571 | Val Loss: 23.31510 | Train Acc: 2.263| Val Acc: 1.796
# Epoch 046: | Train Loss: 30.61209 | Val Loss: 23.59580 | Train Acc: 2.236| Val Acc: 1.783
# Epoch 047: | Train Loss: 30.83899 | Val Loss: 22.89103 | Train Acc: 2.279| Val Acc: 1.609
# Epoch 048: | Train Loss: 30.67176 | Val Loss: 22.63612 | Train Acc: 2.169| Val Acc: 1.555
# Epoch 049: | Train Loss: 30.61071 | Val Loss: 23.06129 | Train Acc: 2.181| Val Acc: 1.541
# Epoch 050: | Train Loss: 30.56516 | Val Loss: 23.35337 | Train Acc: 2.190| Val Acc: 1.545
# Epoch 051: | Train Loss: 30.75896 | Val Loss: 22.86361 | Train Acc: 2.173| Val Acc: 1.558
# Epoch 052: | Train Loss: 30.74009 | Val Loss: 23.35223 | Train Acc: 2.181| Val Acc: 1.587
# Epoch 053: | Train Loss: 30.90996 | Val Loss: 23.09240 | Train Acc: 2.238| Val Acc: 1.584
# Epoch 054: | Train Loss: 30.69031 | Val Loss: 22.95112 | Train Acc: 2.230| Val Acc: 1.777
# Epoch 055: | Train Loss: 30.63631 | Val Loss: 22.59965 | Train Acc: 2.194| Val Acc: 1.949
# Epoch 056: | Train Loss: 30.65610 | Val Loss: 22.95887 | Train Acc: 2.186| Val Acc: 1.728
# Epoch 057: | Train Loss: 30.52908 | Val Loss: 23.45774 | Train Acc: 2.175| Val Acc: 1.738
# Epoch 058: | Train Loss: 30.45164 | Val Loss: 23.81085 | Train Acc: 2.104| Val Acc: 1.567
# Epoch 059: | Train Loss: 30.35280 | Val Loss: 24.00479 | Train Acc: 2.130| Val Acc: 1.568
# Epoch 060: | Train Loss: 30.33190 | Val Loss: 24.01381 | Train Acc: 2.138| Val Acc: 1.573
# Epoch 061: | Train Loss: 30.33637 | Val Loss: 23.65551 | Train Acc: 2.130| Val Acc: 1.574
# Epoch 062: | Train Loss: 30.45313 | Val Loss: 23.24678 | Train Acc: 2.101| Val Acc: 1.588
# Epoch 063: | Train Loss: 30.31725 | Val Loss: 23.43853 | Train Acc: 2.120| Val Acc: 1.639
# Epoch 064: | Train Loss: 30.56696 | Val Loss: 23.79479 | Train Acc: 2.178| Val Acc: 1.627
# Epoch 065: | Train Loss: 30.25409 | Val Loss: 23.92377 | Train Acc: 2.081| Val Acc: 1.619
# Epoch 066: | Train Loss: 30.48637 | Val Loss: 24.09259 | Train Acc: 2.133| Val Acc: 1.606
# Epoch 067: | Train Loss: 30.47674 | Val Loss: 23.23577 | Train Acc: 2.135| Val Acc: 1.614
# Epoch 068: | Train Loss: 30.50171 | Val Loss: 22.84813 | Train Acc: 2.143| Val Acc: 1.763
# Epoch 069: | Train Loss: 30.58001 | Val Loss: 23.10071 | Train Acc: 2.170| Val Acc: 1.737
# Epoch 070: | Train Loss: 30.38859 | Val Loss: 23.54469 | Train Acc: 2.127| Val Acc: 1.549
# Epoch 071: | Train Loss: 30.45346 | Val Loss: 23.70062 | Train Acc: 2.132| Val Acc: 1.555
# Epoch 072: | Train Loss: 30.51905 | Val Loss: 23.89040 | Train Acc: 2.123| Val Acc: 1.597
# Epoch 073: | Train Loss: 30.27560 | Val Loss: 23.64233 | Train Acc: 2.102| Val Acc: 1.626
# Epoch 074: | Train Loss: 30.27940 | Val Loss: 23.48870 | Train Acc: 2.078| Val Acc: 1.618
# Epoch 075: | Train Loss: 30.19189 | Val Loss: 23.44120 | Train Acc: 2.087| Val Acc: 1.579
# Epoch 076: | Train Loss: 30.16762 | Val Loss: 23.36573 | Train Acc: 2.069| Val Acc: 1.584
# Epoch 077: | Train Loss: 30.17248 | Val Loss: 23.34532 | Train Acc: 2.062| Val Acc: 1.581
# Epoch 078: | Train Loss: 30.18105 | Val Loss: 23.57168 | Train Acc: 2.090| Val Acc: 1.572
# Epoch 079: | Train Loss: 30.26777 | Val Loss: 23.77146 | Train Acc: 2.096| Val Acc: 1.589
# Epoch 080: | Train Loss: 30.24681 | Val Loss: 23.78511 | Train Acc: 2.073| Val Acc: 1.589
# Epoch 081: | Train Loss: 30.20952 | Val Loss: 23.62764 | Train Acc: 2.034| Val Acc: 1.608
# Epoch 082: | Train Loss: 30.22819 | Val Loss: 23.57890 | Train Acc: 2.047| Val Acc: 1.566
# Epoch 083: | Train Loss: 30.24160 | Val Loss: 23.80872 | Train Acc: 2.089| Val Acc: 1.775
# Epoch 084: | Train Loss: 30.14679 | Val Loss: 24.00788 | Train Acc: 2.057| Val Acc: 1.785
# Epoch 085: | Train Loss: 30.18712 | Val Loss: 23.90135 | Train Acc: 2.073| Val Acc: 1.768
# Epoch 086: | Train Loss: 30.26677 | Val Loss: 23.82315 | Train Acc: 2.095| Val Acc: 1.769
# Epoch 087: | Train Loss: 30.36716 | Val Loss: 23.86143 | Train Acc: 2.023| Val Acc: 1.710
# Epoch 088: | Train Loss: 30.25241 | Val Loss: 23.85465 | Train Acc: 2.097| Val Acc: 1.706
# Epoch 089: | Train Loss: 30.13021 | Val Loss: 23.76259 | Train Acc: 2.029| Val Acc: 1.719
# Epoch 090: | Train Loss: 30.22832 | Val Loss: 23.91324 | Train Acc: 2.012| Val Acc: 1.786
# Epoch 091: | Train Loss: 30.14123 | Val Loss: 24.14041 | Train Acc: 2.007| Val Acc: 1.629
# Epoch 092: | Train Loss: 30.17231 | Val Loss: 23.89936 | Train Acc: 2.073| Val Acc: 1.604
# Epoch 093: | Train Loss: 30.23427 | Val Loss: 23.85563 | Train Acc: 2.105| Val Acc: 1.586
# Epoch 094: | Train Loss: 30.10598 | Val Loss: 23.92800 | Train Acc: 2.021| Val Acc: 1.603
# Epoch 095: | Train Loss: 30.34100 | Val Loss: 23.92690 | Train Acc: 2.058| Val Acc: 1.589
# Epoch 096: | Train Loss: 30.12854 | Val Loss: 23.87439 | Train Acc: 2.058| Val Acc: 1.567
# Epoch 097: | Train Loss: 30.07140 | Val Loss: 24.03280 | Train Acc: 2.034| Val Acc: 1.633
# Epoch 098: | Train Loss: 30.34356 | Val Loss: 23.65545 | Train Acc: 2.012| Val Acc: 1.584
# Epoch 099: | Train Loss: 30.61238 | Val Loss: 23.54627 | Train Acc: 2.087| Val Acc: 1.614
# Epoch 100: | Train Loss: 30.33106 | Val Loss: 23.02381 | Train Acc: 2.101| Val Acc: 1.591
# Epoch 101: | Train Loss: 30.19044 | Val Loss: 22.74847 | Train Acc: 2.054| Val Acc: 1.536
# Epoch 102: | Train Loss: 30.18874 | Val Loss: 22.88109 | Train Acc: 2.072| Val Acc: 1.702
# Epoch 103: | Train Loss: 30.02354 | Val Loss: 23.14855 | Train Acc: 2.021| Val Acc: 1.710
# Epoch 104: | Train Loss: 30.23309 | Val Loss: 23.59877 | Train Acc: 2.084| Val Acc: 1.701
# Epoch 105: | Train Loss: 30.18765 | Val Loss: 24.01529 | Train Acc: 2.087| Val Acc: 1.584
# Epoch 106: | Train Loss: 30.20086 | Val Loss: 23.89989 | Train Acc: 2.079| Val Acc: 1.627
# Epoch 107: | Train Loss: 30.21642 | Val Loss: 23.48155 | Train Acc: 1.994| Val Acc: 1.539
# Epoch 108: | Train Loss: 30.38532 | Val Loss: 23.31351 | Train Acc: 1.996| Val Acc: 1.689
# Epoch 109: | Train Loss: 30.08748 | Val Loss: 23.11965 | Train Acc: 2.062| Val Acc: 1.693
# Epoch 110: | Train Loss: 30.10344 | Val Loss: 23.00977 | Train Acc: 2.054| Val Acc: 1.679
# Epoch 111: | Train Loss: 30.51473 | Val Loss: 22.87548 | Train Acc: 2.087| Val Acc: 1.548
# Epoch 112: | Train Loss: 30.16801 | Val Loss: 23.04211 | Train Acc: 2.038| Val Acc: 1.532
# Epoch 113: | Train Loss: 30.07277 | Val Loss: 23.19577 | Train Acc: 2.012| Val Acc: 1.541
# Epoch 114: | Train Loss: 30.29478 | Val Loss: 23.09050 | Train Acc: 2.068| Val Acc: 1.529
# Epoch 115: | Train Loss: 30.39750 | Val Loss: 23.84516 | Train Acc: 2.033| Val Acc: 1.576
# Epoch 116: | Train Loss: 30.22092 | Val Loss: 23.92658 | Train Acc: 2.049| Val Acc: 1.605
# Epoch 117: | Train Loss: 30.16043 | Val Loss: 23.45159 | Train Acc: 2.048| Val Acc: 1.738
# Epoch 118: | Train Loss: 30.28526 | Val Loss: 23.58994 | Train Acc: 2.090| Val Acc: 1.560
# Epoch 119: | Train Loss: 30.14270 | Val Loss: 23.71161 | Train Acc: 2.041| Val Acc: 1.737
# Epoch 120: | Train Loss: 30.19544 | Val Loss: 23.54567 | Train Acc: 2.057| Val Acc: 1.739
# Epoch 121: | Train Loss: 30.10984 | Val Loss: 23.32255 | Train Acc: 2.029| Val Acc: 1.585
# Epoch 122: | Train Loss: 30.40118 | Val Loss: 23.15851 | Train Acc: 2.075| Val Acc: 1.560
# Epoch 123: | Train Loss: 30.41234 | Val Loss: 23.06784 | Train Acc: 2.064| Val Acc: 1.535
# Epoch 124: | Train Loss: 30.12620 | Val Loss: 22.94607 | Train Acc: 2.028| Val Acc: 1.532
# Epoch 125: | Train Loss: 30.06133 | Val Loss: 22.87973 | Train Acc: 2.014| Val Acc: 1.537
# Epoch 126: | Train Loss: 30.00854 | Val Loss: 23.04552 | Train Acc: 2.008| Val Acc: 1.552
# Epoch 127: | Train Loss: 30.07328 | Val Loss: 23.31092 | Train Acc: 1.962| Val Acc: 1.561
# Epoch 128: | Train Loss: 30.22475 | Val Loss: 23.45017 | Train Acc: 2.041| Val Acc: 1.548
# Epoch 129: | Train Loss: 30.10446 | Val Loss: 23.16968 | Train Acc: 2.008| Val Acc: 1.553
# Epoch 130: | Train Loss: 30.12504 | Val Loss: 22.90944 | Train Acc: 2.023| Val Acc: 1.544
# Epoch 131: | Train Loss: 29.87135 | Val Loss: 22.90117 | Train Acc: 1.956| Val Acc: 1.551
# Epoch 132: | Train Loss: 29.97397 | Val Loss: 22.91342 | Train Acc: 2.006| Val Acc: 1.546
# Epoch 133: | Train Loss: 30.03448 | Val Loss: 23.20324 | Train Acc: 2.005| Val Acc: 1.554
# Epoch 134: | Train Loss: 30.08540 | Val Loss: 23.24222 | Train Acc: 2.051| Val Acc: 1.551
# Epoch 135: | Train Loss: 29.94547 | Val Loss: 23.46186 | Train Acc: 1.984| Val Acc: 1.706
# Epoch 136: | Train Loss: 29.91972 | Val Loss: 23.88711 | Train Acc: 1.976| Val Acc: 1.535
# Epoch 137: | Train Loss: 29.94423 | Val Loss: 23.84723 | Train Acc: 1.981| Val Acc: 1.546
# Epoch 138: | Train Loss: 29.92226 | Val Loss: 23.33298 | Train Acc: 1.952| Val Acc: 1.541
# Epoch 139: | Train Loss: 29.91704 | Val Loss: 23.18359 | Train Acc: 1.981| Val Acc: 1.541
# Epoch 140: | Train Loss: 30.00032 | Val Loss: 23.02923 | Train Acc: 1.984| Val Acc: 1.538
# Epoch 141: | Train Loss: 29.96550 | Val Loss: 23.21029 | Train Acc: 1.985| Val Acc: 1.543
# Epoch 142: | Train Loss: 29.87166 | Val Loss: 23.37710 | Train Acc: 1.968| Val Acc: 1.540
# Epoch 143: | Train Loss: 29.99764 | Val Loss: 23.64107 | Train Acc: 1.950| Val Acc: 1.568
# Epoch 144: | Train Loss: 29.96424 | Val Loss: 23.60041 | Train Acc: 1.975| Val Acc: 1.735
# Epoch 145: | Train Loss: 29.93066 | Val Loss: 23.70550 | Train Acc: 1.983| Val Acc: 1.726
# Epoch 146: | Train Loss: 29.89179 | Val Loss: 23.78538 | Train Acc: 1.948| Val Acc: 1.695
# Epoch 147: | Train Loss: 29.85712 | Val Loss: 23.69846 | Train Acc: 1.944| Val Acc: 1.698
# Epoch 148: | Train Loss: 29.87357 | Val Loss: 23.79894 | Train Acc: 1.957| Val Acc: 1.719
# Epoch 149: | Train Loss: 29.77736 | Val Loss: 23.93247 | Train Acc: 1.900| Val Acc: 1.715
# Epoch 150: | Train Loss: 29.86473 | Val Loss: 23.96296 | Train Acc: 1.960| Val Acc: 1.732

# %%
metrics(train, test, threshold=30)
# Out:
# MAE on train set:  30.166908768823568
# min prediction: 1
# max prediction: 231
#
# MAE on test set:  31.224809329712503
# Error ⩽ 30: 69.47 %
# min prediction: 1
# max prediction: 366

# %%
validation_plots(test,model_type)

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.000001, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)
# Out:
# Epoch 001: | Train Loss: 34.49222 | Val Loss: 0.00630 | Train Acc: 2.546| Val Acc: 0.458
# Epoch 002: | Train Loss: 34.12175 | Val Loss: 0.04648 | Train Acc: 2.413| Val Acc: 0.458
# Epoch 003: | Train Loss: 33.12702 | Val Loss: 0.21365 | Train Acc: 2.322| Val Acc: 0.542
# Epoch 004: | Train Loss: 33.02405 | Val Loss: 0.40912 | Train Acc: 2.342| Val Acc: 0.542
# Epoch 005: | Train Loss: 32.80222 | Val Loss: 0.13834 | Train Acc: 2.239| Val Acc: 0.542
# Epoch 006: | Train Loss: 32.60882 | Val Loss: 0.04369 | Train Acc: 2.234| Val Acc: 0.542
# Epoch 007: | Train Loss: 32.81027 | Val Loss: 0.01418 | Train Acc: 2.252| Val Acc: 0.542
# Epoch 008: | Train Loss: 32.45110 | Val Loss: 0.03516 | Train Acc: 2.194| Val Acc: 0.542
# Epoch 009: | Train Loss: 32.48432 | Val Loss: 0.01462 | Train Acc: 2.170| Val Acc: 0.542
# Epoch 010: | Train Loss: 32.37738 | Val Loss: 0.00608 | Train Acc: 2.159| Val Acc: 0.458
# Epoch 011: | Train Loss: 32.38001 | Val Loss: 0.01813 | Train Acc: 2.221| Val Acc: 0.458
# Epoch 012: | Train Loss: 32.26165 | Val Loss: 0.01589 | Train Acc: 2.147| Val Acc: 0.542
# Epoch 013: | Train Loss: 32.45138 | Val Loss: 0.05390 | Train Acc: 2.180| Val Acc: 0.542
# Epoch 014: | Train Loss: 32.32613 | Val Loss: 0.00301 | Train Acc: 2.180| Val Acc: 0.458
# Epoch 015: | Train Loss: 32.22722 | Val Loss: 0.02885 | Train Acc: 2.169| Val Acc: 0.542
# Epoch 016: | Train Loss: 32.22044 | Val Loss: 0.05113 | Train Acc: 2.154| Val Acc: 0.542
# Epoch 017: | Train Loss: 32.44671 | Val Loss: 0.01536 | Train Acc: 2.194| Val Acc: 0.458
# Epoch 018: | Train Loss: 32.06141 | Val Loss: 0.05061 | Train Acc: 2.104| Val Acc: 0.458
# Epoch 019: | Train Loss: 32.14686 | Val Loss: 0.25276 | Train Acc: 2.132| Val Acc: 0.458
# Epoch 020: | Train Loss: 32.24764 | Val Loss: 0.04940 | Train Acc: 2.125| Val Acc: 0.458
# Epoch 021: | Train Loss: 32.32796 | Val Loss: 0.00200 | Train Acc: 2.118| Val Acc: 0.542
# Epoch 022: | Train Loss: 32.30375 | Val Loss: 0.02581 | Train Acc: 2.117| Val Acc: 0.458
# Epoch 023: | Train Loss: 32.03293 | Val Loss: 0.01200 | Train Acc: 2.097| Val Acc: 0.458
# Epoch 024: | Train Loss: 32.00827 | Val Loss: 0.00544 | Train Acc: 2.085| Val Acc: 0.458
# Epoch 025: | Train Loss: 31.98366 | Val Loss: 0.00149 | Train Acc: 2.091| Val Acc: 0.458
# Epoch 026: | Train Loss: 32.06700 | Val Loss: 0.00425 | Train Acc: 2.074| Val Acc: 0.542
# Epoch 027: | Train Loss: 32.08489 | Val Loss: 0.00811 | Train Acc: 2.101| Val Acc: 0.458
# Epoch 028: | Train Loss: 32.02745 | Val Loss: 0.00021 | Train Acc: 2.080| Val Acc: 0.458
# Epoch 029: | Train Loss: 32.03247 | Val Loss: 0.01050 | Train Acc: 2.063| Val Acc: 0.542
# Epoch 030: | Train Loss: 32.44086 | Val Loss: 0.05063 | Train Acc: 2.107| Val Acc: 0.542
# Epoch 031: | Train Loss: 32.15095 | Val Loss: 0.12820 | Train Acc: 2.089| Val Acc: 0.542
# Epoch 032: | Train Loss: 32.16555 | Val Loss: 0.02651 | Train Acc: 2.108| Val Acc: 0.542
# Epoch 033: | Train Loss: 32.27666 | Val Loss: 0.00191 | Train Acc: 2.154| Val Acc: 0.458
# Epoch 034: | Train Loss: 32.03195 | Val Loss: 0.00008 | Train Acc: 2.111| Val Acc: 0.458
# Epoch 035: | Train Loss: 31.97875 | Val Loss: 0.11233 | Train Acc: 2.052| Val Acc: 0.542
# Epoch 036: | Train Loss: 32.09786 | Val Loss: 0.20616 | Train Acc: 2.078| Val Acc: 0.542
# Epoch 037: | Train Loss: 32.05551 | Val Loss: 0.27559 | Train Acc: 2.118| Val Acc: 0.542
# Epoch 038: | Train Loss: 32.21830 | Val Loss: 0.28565 | Train Acc: 2.107| Val Acc: 0.542
# Epoch 039: | Train Loss: 32.00535 | Val Loss: 0.03865 | Train Acc: 2.054| Val Acc: 0.542
# Epoch 040: | Train Loss: 31.97764 | Val Loss: 0.00341 | Train Acc: 2.059| Val Acc: 0.542
# Epoch 041: | Train Loss: 32.03124 | Val Loss: 0.15911 | Train Acc: 2.075| Val Acc: 0.542
# Epoch 042: | Train Loss: 32.15824 | Val Loss: 0.01829 | Train Acc: 2.106| Val Acc: 0.542
# Epoch 043: | Train Loss: 32.02392 | Val Loss: 0.02752 | Train Acc: 2.066| Val Acc: 0.458
# Epoch 044: | Train Loss: 32.30181 | Val Loss: 0.14231 | Train Acc: 2.118| Val Acc: 0.542
# Epoch 045: | Train Loss: 32.13008 | Val Loss: 0.32372 | Train Acc: 2.129| Val Acc: 0.542
# Epoch 046: | Train Loss: 32.20866 | Val Loss: 0.02373 | Train Acc: 2.162| Val Acc: 0.542
# Epoch 047: | Train Loss: 32.22544 | Val Loss: 0.01538 | Train Acc: 2.119| Val Acc: 0.542
# Epoch 048: | Train Loss: 31.96066 | Val Loss: 0.04044 | Train Acc: 2.068| Val Acc: 0.542
# Epoch 049: | Train Loss: 32.19474 | Val Loss: 0.08051 | Train Acc: 2.076| Val Acc: 0.542
# Epoch 050: | Train Loss: 31.98239 | Val Loss: 0.18027 | Train Acc: 2.072| Val Acc: 0.542
# Epoch 051: | Train Loss: 32.01041 | Val Loss: 0.04916 | Train Acc: 2.053| Val Acc: 0.542
# Epoch 052: | Train Loss: 31.92005 | Val Loss: 0.17810 | Train Acc: 2.061| Val Acc: 0.542
# Epoch 053: | Train Loss: 31.93440 | Val Loss: 0.14239 | Train Acc: 2.035| Val Acc: 0.542
# Epoch 054: | Train Loss: 31.88249 | Val Loss: 0.02999 | Train Acc: 2.038| Val Acc: 0.542
# Epoch 055: | Train Loss: 31.94209 | Val Loss: 0.02190 | Train Acc: 2.045| Val Acc: 0.542
# Epoch 056: | Train Loss: 31.91232 | Val Loss: 0.17963 | Train Acc: 2.055| Val Acc: 0.542
# Epoch 057: | Train Loss: 31.92635 | Val Loss: 0.11242 | Train Acc: 2.056| Val Acc: 0.542
# Epoch 058: | Train Loss: 31.87856 | Val Loss: 0.01337 | Train Acc: 2.013| Val Acc: 0.542
# Epoch 059: | Train Loss: 32.15486 | Val Loss: 0.20104 | Train Acc: 2.129| Val Acc: 0.542
# Epoch 060: | Train Loss: 31.95870 | Val Loss: 0.27516 | Train Acc: 2.061| Val Acc: 0.542
# Epoch 061: | Train Loss: 31.94688 | Val Loss: 0.14458 | Train Acc: 2.036| Val Acc: 0.542
# Epoch 062: | Train Loss: 31.86696 | Val Loss: 0.20878 | Train Acc: 2.053| Val Acc: 0.542
# Epoch 063: | Train Loss: 31.95141 | Val Loss: 0.46295 | Train Acc: 2.063| Val Acc: 0.542
# Epoch 064: | Train Loss: 31.88156 | Val Loss: 0.70461 | Train Acc: 2.065| Val Acc: 0.542
# Epoch 065: | Train Loss: 31.93019 | Val Loss: 0.24351 | Train Acc: 2.038| Val Acc: 0.542
# Epoch 066: | Train Loss: 31.82859 | Val Loss: 0.00399 | Train Acc: 2.000| Val Acc: 0.542
# Epoch 067: | Train Loss: 31.92347 | Val Loss: 0.04640 | Train Acc: 2.035| Val Acc: 0.458
# Epoch 068: | Train Loss: 31.89718 | Val Loss: 0.01256 | Train Acc: 2.035| Val Acc: 0.458
# Epoch 069: | Train Loss: 31.86703 | Val Loss: 0.21093 | Train Acc: 2.044| Val Acc: 0.542
# Epoch 070: | Train Loss: 31.81479 | Val Loss: 0.31291 | Train Acc: 2.000| Val Acc: 0.542
# Epoch 071: | Train Loss: 31.92582 | Val Loss: 0.06372 | Train Acc: 2.020| Val Acc: 0.542
# Epoch 072: | Train Loss: 31.87390 | Val Loss: 0.03967 | Train Acc: 2.009| Val Acc: 0.542
# Epoch 073: | Train Loss: 31.85600 | Val Loss: 0.12485 | Train Acc: 2.021| Val Acc: 0.542
# Epoch 074: | Train Loss: 31.97056 | Val Loss: 0.00179 | Train Acc: 2.041| Val Acc: 0.542
# Epoch 075: | Train Loss: 31.98771 | Val Loss: 0.00038 | Train Acc: 2.071| Val Acc: 0.458
# Epoch 076: | Train Loss: 32.04317 | Val Loss: 0.03256 | Train Acc: 2.020| Val Acc: 0.542
# Epoch 077: | Train Loss: 31.86939 | Val Loss: 0.15892 | Train Acc: 2.018| Val Acc: 0.542
# Epoch 078: | Train Loss: 31.88021 | Val Loss: 0.09853 | Train Acc: 2.013| Val Acc: 0.542
# Epoch 079: | Train Loss: 31.78690 | Val Loss: 0.00732 | Train Acc: 1.985| Val Acc: 0.542
# Epoch 080: | Train Loss: 31.73639 | Val Loss: 0.00049 | Train Acc: 1.963| Val Acc: 0.458
# Epoch 081: | Train Loss: 31.85558 | Val Loss: 0.00718 | Train Acc: 2.020| Val Acc: 0.542
# Epoch 082: | Train Loss: 31.84275 | Val Loss: 0.01720 | Train Acc: 2.014| Val Acc: 0.542
# Epoch 083: | Train Loss: 32.01121 | Val Loss: 0.00489 | Train Acc: 2.008| Val Acc: 0.542
# Epoch 084: | Train Loss: 31.93935 | Val Loss: 0.02859 | Train Acc: 2.027| Val Acc: 0.458
# Epoch 085: | Train Loss: 32.05850 | Val Loss: 0.01157 | Train Acc: 2.038| Val Acc: 0.458
# Epoch 086: | Train Loss: 31.93516 | Val Loss: 0.06325 | Train Acc: 2.048| Val Acc: 0.542
# Epoch 087: | Train Loss: 31.85715 | Val Loss: 0.35507 | Train Acc: 2.023| Val Acc: 0.542
# Epoch 088: | Train Loss: 31.85944 | Val Loss: 0.39667 | Train Acc: 2.019| Val Acc: 0.542
# Epoch 089: | Train Loss: 31.83961 | Val Loss: 0.12936 | Train Acc: 2.007| Val Acc: 0.542
# Epoch 090: | Train Loss: 32.01323 | Val Loss: 0.03081 | Train Acc: 1.980| Val Acc: 0.542
# Epoch 091: | Train Loss: 32.04683 | Val Loss: 0.26172 | Train Acc: 2.059| Val Acc: 0.542
# Epoch 092: | Train Loss: 31.81717 | Val Loss: 0.37776 | Train Acc: 2.011| Val Acc: 0.542
# Epoch 093: | Train Loss: 31.88494 | Val Loss: 0.12441 | Train Acc: 1.990| Val Acc: 0.542
# Epoch 094: | Train Loss: 31.83021 | Val Loss: 0.07023 | Train Acc: 2.014| Val Acc: 0.542
# Epoch 095: | Train Loss: 31.83595 | Val Loss: 0.20282 | Train Acc: 2.020| Val Acc: 0.542
# Epoch 096: | Train Loss: 31.76017 | Val Loss: 0.30658 | Train Acc: 1.990| Val Acc: 0.542
# Epoch 097: | Train Loss: 31.74480 | Val Loss: 0.05099 | Train Acc: 1.974| Val Acc: 0.542
# Epoch 098: | Train Loss: 31.77977 | Val Loss: 0.14845 | Train Acc: 2.027| Val Acc: 0.542
# Epoch 099: | Train Loss: 31.79317 | Val Loss: 0.19064 | Train Acc: 1.975| Val Acc: 0.542
# Epoch 100: | Train Loss: 31.75055 | Val Loss: 0.09515 | Train Acc: 1.982| Val Acc: 0.542
# Epoch 101: | Train Loss: 31.75076 | Val Loss: 0.15999 | Train Acc: 1.989| Val Acc: 0.542
# Epoch 102: | Train Loss: 31.73500 | Val Loss: 0.03226 | Train Acc: 1.969| Val Acc: 0.542
# Epoch 103: | Train Loss: 31.72948 | Val Loss: 0.06326 | Train Acc: 1.975| Val Acc: 0.542
# Epoch 104: | Train Loss: 31.87193 | Val Loss: 0.04812 | Train Acc: 1.958| Val Acc: 0.542
# Epoch 105: | Train Loss: 31.71936 | Val Loss: 0.00269 | Train Acc: 1.951| Val Acc: 0.542
# Epoch 106: | Train Loss: 31.78685 | Val Loss: 0.02749 | Train Acc: 2.011| Val Acc: 0.542
# Epoch 107: | Train Loss: 31.80200 | Val Loss: 0.14442 | Train Acc: 2.006| Val Acc: 0.542
# Epoch 108: | Train Loss: 31.77108 | Val Loss: 0.02089 | Train Acc: 1.948| Val Acc: 0.542
# Epoch 109: | Train Loss: 31.75062 | Val Loss: 0.00794 | Train Acc: 1.990| Val Acc: 0.542
# Epoch 110: | Train Loss: 31.77164 | Val Loss: 0.34575 | Train Acc: 1.976| Val Acc: 0.542
# Epoch 111: | Train Loss: 31.79378 | Val Loss: 0.26249 | Train Acc: 1.986| Val Acc: 0.542
# Epoch 112: | Train Loss: 31.69557 | Val Loss: 0.05568 | Train Acc: 1.959| Val Acc: 0.542
# Epoch 113: | Train Loss: 31.76182 | Val Loss: 0.11598 | Train Acc: 1.970| Val Acc: 0.542
# Epoch 114: | Train Loss: 31.70955 | Val Loss: 0.08411 | Train Acc: 1.975| Val Acc: 0.542
# Epoch 115: | Train Loss: 31.67766 | Val Loss: 0.13166 | Train Acc: 1.954| Val Acc: 0.542
# Epoch 116: | Train Loss: 31.69098 | Val Loss: 0.08669 | Train Acc: 1.959| Val Acc: 0.542
# Epoch 117: | Train Loss: 31.69330 | Val Loss: 0.17119 | Train Acc: 1.967| Val Acc: 0.542
# Epoch 118: | Train Loss: 31.73982 | Val Loss: 0.22619 | Train Acc: 1.975| Val Acc: 0.542
# Epoch 119: | Train Loss: 31.69545 | Val Loss: 0.24212 | Train Acc: 1.950| Val Acc: 0.542
# Epoch 120: | Train Loss: 31.65419 | Val Loss: 0.15242 | Train Acc: 1.932| Val Acc: 0.542
# Epoch 121: | Train Loss: 31.71345 | Val Loss: 0.05602 | Train Acc: 1.925| Val Acc: 0.542
# Epoch 122: | Train Loss: 31.70328 | Val Loss: 0.34206 | Train Acc: 1.976| Val Acc: 0.542
# Epoch 123: | Train Loss: 31.70759 | Val Loss: 0.28642 | Train Acc: 1.980| Val Acc: 0.542
# Epoch 124: | Train Loss: 31.66309 | Val Loss: 0.09013 | Train Acc: 1.947| Val Acc: 0.542
# Epoch 125: | Train Loss: 31.66334 | Val Loss: 0.08865 | Train Acc: 1.948| Val Acc: 0.542
# Epoch 126: | Train Loss: 31.64139 | Val Loss: 0.13877 | Train Acc: 1.931| Val Acc: 0.542
# Epoch 127: | Train Loss: 31.68914 | Val Loss: 0.28172 | Train Acc: 1.948| Val Acc: 0.542
# Epoch 128: | Train Loss: 31.69021 | Val Loss: 0.28176 | Train Acc: 1.935| Val Acc: 0.542
# Epoch 129: | Train Loss: 31.69987 | Val Loss: 0.28568 | Train Acc: 1.937| Val Acc: 0.542
# Epoch 130: | Train Loss: 31.72149 | Val Loss: 0.42096 | Train Acc: 1.961| Val Acc: 0.542
# Epoch 131: | Train Loss: 31.71634 | Val Loss: 0.15799 | Train Acc: 1.953| Val Acc: 0.542
# Epoch 132: | Train Loss: 31.74731 | Val Loss: 0.08325 | Train Acc: 1.936| Val Acc: 0.542
# Epoch 133: | Train Loss: 31.90185 | Val Loss: 0.10042 | Train Acc: 1.971| Val Acc: 0.542
# Epoch 134: | Train Loss: 31.76666 | Val Loss: 0.14531 | Train Acc: 1.942| Val Acc: 0.542
# Epoch 135: | Train Loss: 31.80323 | Val Loss: 0.26337 | Train Acc: 1.963| Val Acc: 0.542
# Epoch 136: | Train Loss: 31.74246 | Val Loss: 0.34024 | Train Acc: 1.983| Val Acc: 0.542
# Epoch 137: | Train Loss: 31.67515 | Val Loss: 0.35963 | Train Acc: 1.936| Val Acc: 0.542
# Epoch 138: | Train Loss: 31.75320 | Val Loss: 0.29864 | Train Acc: 1.972| Val Acc: 0.542
# Epoch 139: | Train Loss: 31.74318 | Val Loss: 0.26826 | Train Acc: 1.963| Val Acc: 0.542
# Epoch 140: | Train Loss: 31.77922 | Val Loss: 0.42457 | Train Acc: 1.994| Val Acc: 0.542
# Epoch 141: | Train Loss: 31.76305 | Val Loss: 0.51137 | Train Acc: 1.952| Val Acc: 0.542
# Epoch 142: | Train Loss: 31.68402 | Val Loss: 0.83622 | Train Acc: 1.931| Val Acc: 0.542
# Epoch 143: | Train Loss: 31.79967 | Val Loss: 0.12779 | Train Acc: 1.980| Val Acc: 0.542
# Epoch 144: | Train Loss: 32.12431 | Val Loss: 0.21817 | Train Acc: 2.005| Val Acc: 0.542
# Epoch 145: | Train Loss: 31.83859 | Val Loss: 0.13806 | Train Acc: 1.983| Val Acc: 0.542
# Epoch 146: | Train Loss: 31.74501 | Val Loss: 0.15443 | Train Acc: 1.973| Val Acc: 0.542
# Epoch 147: | Train Loss: 31.74277 | Val Loss: 0.42336 | Train Acc: 1.985| Val Acc: 0.542
# Epoch 148: | Train Loss: 31.75803 | Val Loss: 0.27835 | Train Acc: 1.932| Val Acc: 0.542
# Epoch 149: | Train Loss: 31.73437 | Val Loss: 0.06090 | Train Acc: 1.979| Val Acc: 0.542
# Epoch 150: | Train Loss: 31.78977 | Val Loss: 0.01996 | Train Acc: 1.966| Val Acc: 0.542

# %%
pickle.dump(model, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_Mamoth_NN.pt', 'wb'))
pickle.dump(imputer, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_KNN_Imputer.pkl', 'wb'))
pickle.dump(scaler, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_Scaler.pkl', 'wb'))
