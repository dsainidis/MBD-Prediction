# %% [markdown]
# ## Produces **Mosquito Predictions** for a specific region using MAMOTH ##

# %%
import pandas as pd
import datetime
import math
import numpy as np
import missingno
import json
from statistics import mean
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
import sys
import pickle

sys.path.insert(0, "../../../../Mamoth")
sys.path.insert(0, "../../../../Modules")

from utils import *

from Preprocessing_Module import read_data, select_columns, reshape_dataset
from Initializer_Module import initializer
from Neural_Network_Module import Dataset, transformations, FeedforwardNeuralNetModel, train_nn, give_predictions
from Model_Validation_Module import validation_plots, metrics

enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 100
pd.options.display.float_format = lambda x: '%.6f' % x

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
NUTS0 = 'GR'
NUTS2 = 'Thessaly'
NUTS2_EL = 'θεσσαλιας'

# %%
mosquito_data = read_data(f'../../data/{NUTS0}_MSQ_culex_2011-2022_processed.csv')
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
mosquito_data.nuts2.unique()
# Out:
# array(['κεντρικης μακεδονιας', 'θεσσαλιας', 'κρητης', 'δυτικης ελλαδας'],
#       dtype=object)

# %%
mosquito_data_nuts2 = mosquito_data.query(f"nuts2 == '{NUTS2_EL}'").copy()
mosquito_data_nuts2.reset_index(inplace = True, drop = True)

# %%
mosq_columns = mosquito_data_nuts2.columns
mosq_columns
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
                'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
                'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
                'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
                'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
                'acc_rainfall_jan', 'mosq_now']

# columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#                 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#                 'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#                 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#                 'lst_night', 'acc_rainfall_1week', 'acc_rainfall_2week',
#                 'acc_rainfall_jan', 'mosq_now']

mosquito_data_nuts2 = select_columns(mosquito_data_nuts2, columns_to_keep, columns_to_keep)

mosquito_data_nuts2 = reshape_dataset(mosquito_data_nuts2,['x','y','dt_placement'])

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()

# %%
#quantile might change based on sns plots
mosq_quantilie = mosquito_data_nuts2['mosq_now'].quantile(0.95)

mosquito_data_nuts2['mosq_now'][mosquito_data_nuts2['mosq_now'] > mosq_quantilie] = mosq_quantilie+1

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <AxesSubplot:>

# %%
imputer = KNNImputer()

features_for_impute = ['x', 'y', 'day', 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 
                        'lst_day', 'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean', 'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan']

# features_for_impute = ['x', 'y', 'day', 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#                         'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 
#                         'lst_day', 'lst_night', 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan']

mosquito_data_sub = mosquito_data_nuts2[features_for_impute]

imputed_data = pd.DataFrame(imputer.fit_transform(mosquito_data_sub), columns = mosquito_data_sub.columns)

# %%
# imputed_columns = ['ndvi','ndmi', 'ndwi', 'ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std', 'ndmi_std','ndwi_std','ndbi_std',
#                    'lst_day','lst_night']

imputed_columns = ['ndvi','ndmi', 'ndwi', 'ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std', 'ndmi_std','ndwi_std','ndbi_std',
                   'lst_day','lst_night','lst_jan_mean','lst_feb_mean','lst_mar_mean','lst_apr_mean']

mosquito_data_nuts2[imputed_columns] = imputed_data[imputed_columns]

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <AxesSubplot:>

# %%
step = 15
only_env = True
case_title = 'NN mosq regression'
exp = False
date_col = 'dt_placement'
model_type = 'mosquito_regression'
transform_target = True
augment = True

# %%
mosquito_data_nuts2 = initializer(mosquito_data_nuts2,2,10,25,step,[date_col], env=only_env, date_column = date_col, mosq_column='mosq_now')
# Out:
# Bounds: [  0.    16.5  255.15]

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.25, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

model = FeedforwardNeuralNetModel(num_features=len(train_X[0]), num_class=1, hidden_layers = [264,128,128,64], dropout=0.2, model_type=model_type, transform = transform_target)

# %%
train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)
# Out:
# Epoch 001: | Train Loss: 41.37006 | Val Loss: 31.07980 | Train Acc: 4.247| Val Acc: 3.931
# Epoch 002: | Train Loss: 37.01476 | Val Loss: 30.11151 | Train Acc: 3.574| Val Acc: 3.599
# Epoch 003: | Train Loss: 35.38725 | Val Loss: 28.32128 | Train Acc: 3.224| Val Acc: 3.209
# Epoch 004: | Train Loss: 34.65796 | Val Loss: 25.62308 | Train Acc: 3.030| Val Acc: 2.614
# Epoch 005: | Train Loss: 34.15333 | Val Loss: 24.51717 | Train Acc: 2.939| Val Acc: 2.547
# Epoch 006: | Train Loss: 33.81182 | Val Loss: 23.37563 | Train Acc: 2.878| Val Acc: 2.082
# Epoch 007: | Train Loss: 33.56280 | Val Loss: 23.24399 | Train Acc: 2.833| Val Acc: 2.004
# Epoch 008: | Train Loss: 33.37260 | Val Loss: 23.47905 | Train Acc: 2.812| Val Acc: 1.989
# Epoch 009: | Train Loss: 32.90983 | Val Loss: 23.95063 | Train Acc: 2.750| Val Acc: 1.989
# Epoch 010: | Train Loss: 32.90479 | Val Loss: 23.97583 | Train Acc: 2.764| Val Acc: 2.000
# Epoch 011: | Train Loss: 32.66969 | Val Loss: 23.82156 | Train Acc: 2.653| Val Acc: 1.993
# Epoch 012: | Train Loss: 32.46809 | Val Loss: 23.78542 | Train Acc: 2.659| Val Acc: 1.988
# Epoch 013: | Train Loss: 32.61611 | Val Loss: 23.73170 | Train Acc: 2.687| Val Acc: 1.811
# Epoch 014: | Train Loss: 32.46876 | Val Loss: 23.63953 | Train Acc: 2.587| Val Acc: 1.809
# Epoch 015: | Train Loss: 32.49391 | Val Loss: 23.36675 | Train Acc: 2.671| Val Acc: 1.660
# Epoch 016: | Train Loss: 32.12488 | Val Loss: 23.30297 | Train Acc: 2.556| Val Acc: 1.646
# Epoch 017: | Train Loss: 31.85081 | Val Loss: 23.28334 | Train Acc: 2.560| Val Acc: 1.620
# Epoch 018: | Train Loss: 31.89506 | Val Loss: 23.65098 | Train Acc: 2.499| Val Acc: 1.628
# Epoch 019: | Train Loss: 31.97884 | Val Loss: 23.93207 | Train Acc: 2.515| Val Acc: 1.661
# Epoch 020: | Train Loss: 31.73916 | Val Loss: 23.74264 | Train Acc: 2.522| Val Acc: 1.661
# Epoch 021: | Train Loss: 32.10719 | Val Loss: 23.38585 | Train Acc: 2.485| Val Acc: 1.624
# Epoch 022: | Train Loss: 32.02923 | Val Loss: 23.44656 | Train Acc: 2.437| Val Acc: 1.786
# Epoch 023: | Train Loss: 31.97810 | Val Loss: 22.94263 | Train Acc: 2.533| Val Acc: 1.631
# Epoch 024: | Train Loss: 31.54361 | Val Loss: 22.75776 | Train Acc: 2.465| Val Acc: 1.631
# Epoch 025: | Train Loss: 31.80961 | Val Loss: 22.76781 | Train Acc: 2.482| Val Acc: 1.792
# Epoch 026: | Train Loss: 31.66558 | Val Loss: 23.24957 | Train Acc: 2.462| Val Acc: 1.770
# Epoch 027: | Train Loss: 31.67215 | Val Loss: 23.44631 | Train Acc: 2.481| Val Acc: 1.949
# Epoch 028: | Train Loss: 31.56032 | Val Loss: 23.25782 | Train Acc: 2.393| Val Acc: 1.946
# Epoch 029: | Train Loss: 31.33382 | Val Loss: 23.06453 | Train Acc: 2.412| Val Acc: 1.788
# Epoch 030: | Train Loss: 31.48873 | Val Loss: 23.09355 | Train Acc: 2.396| Val Acc: 1.642
# Epoch 031: | Train Loss: 31.30214 | Val Loss: 23.41981 | Train Acc: 2.347| Val Acc: 1.651
# Epoch 032: | Train Loss: 31.39759 | Val Loss: 24.03245 | Train Acc: 2.384| Val Acc: 1.651
# Epoch 033: | Train Loss: 31.24916 | Val Loss: 24.12779 | Train Acc: 2.356| Val Acc: 1.624
# Epoch 034: | Train Loss: 31.46647 | Val Loss: 23.75180 | Train Acc: 2.379| Val Acc: 1.582
# Epoch 035: | Train Loss: 31.35128 | Val Loss: 22.93515 | Train Acc: 2.317| Val Acc: 1.676
# Epoch 036: | Train Loss: 31.19055 | Val Loss: 22.86062 | Train Acc: 2.330| Val Acc: 1.638
# Epoch 037: | Train Loss: 31.27863 | Val Loss: 22.99594 | Train Acc: 2.318| Val Acc: 1.809
# Epoch 038: | Train Loss: 31.25181 | Val Loss: 23.10331 | Train Acc: 2.339| Val Acc: 1.990
# Epoch 039: | Train Loss: 31.06164 | Val Loss: 22.73097 | Train Acc: 2.330| Val Acc: 1.768
# Epoch 040: | Train Loss: 31.18965 | Val Loss: 22.81685 | Train Acc: 2.309| Val Acc: 1.792
# Epoch 041: | Train Loss: 31.03639 | Val Loss: 23.01597 | Train Acc: 2.289| Val Acc: 1.781
# Epoch 042: | Train Loss: 31.01971 | Val Loss: 23.08281 | Train Acc: 2.289| Val Acc: 1.666
# Epoch 043: | Train Loss: 31.03112 | Val Loss: 23.36776 | Train Acc: 2.288| Val Acc: 1.649
# Epoch 044: | Train Loss: 30.94916 | Val Loss: 23.44306 | Train Acc: 2.270| Val Acc: 1.601
# Epoch 045: | Train Loss: 30.89521 | Val Loss: 23.50534 | Train Acc: 2.248| Val Acc: 1.600
# Epoch 046: | Train Loss: 31.00833 | Val Loss: 23.90057 | Train Acc: 2.241| Val Acc: 1.628
# Epoch 047: | Train Loss: 30.95629 | Val Loss: 23.82868 | Train Acc: 2.272| Val Acc: 1.640
# Epoch 048: | Train Loss: 30.83387 | Val Loss: 23.74260 | Train Acc: 2.232| Val Acc: 1.625
# Epoch 049: | Train Loss: 31.02274 | Val Loss: 23.71595 | Train Acc: 2.280| Val Acc: 1.614
# Epoch 050: | Train Loss: 30.84163 | Val Loss: 23.61460 | Train Acc: 2.254| Val Acc: 1.598
# Epoch 051: | Train Loss: 31.05618 | Val Loss: 23.15628 | Train Acc: 2.227| Val Acc: 1.583
# Epoch 052: | Train Loss: 30.67187 | Val Loss: 22.96404 | Train Acc: 2.210| Val Acc: 1.588
# Epoch 053: | Train Loss: 30.96163 | Val Loss: 23.26114 | Train Acc: 2.258| Val Acc: 1.765
# Epoch 054: | Train Loss: 30.95732 | Val Loss: 23.24042 | Train Acc: 2.295| Val Acc: 1.749
# Epoch 055: | Train Loss: 30.64853 | Val Loss: 23.27537 | Train Acc: 2.180| Val Acc: 1.766
# Epoch 056: | Train Loss: 30.87951 | Val Loss: 23.37669 | Train Acc: 2.179| Val Acc: 1.601
# Epoch 057: | Train Loss: 30.81099 | Val Loss: 23.56092 | Train Acc: 2.238| Val Acc: 1.584
# Epoch 058: | Train Loss: 30.99594 | Val Loss: 24.07506 | Train Acc: 2.240| Val Acc: 1.738
# Epoch 059: | Train Loss: 30.74956 | Val Loss: 23.91538 | Train Acc: 2.185| Val Acc: 1.584
# Epoch 060: | Train Loss: 30.83513 | Val Loss: 23.73634 | Train Acc: 2.230| Val Acc: 1.559
# Epoch 061: | Train Loss: 30.73445 | Val Loss: 23.81071 | Train Acc: 2.213| Val Acc: 1.715
# Epoch 062: | Train Loss: 30.57703 | Val Loss: 23.86575 | Train Acc: 2.152| Val Acc: 1.732
# Epoch 063: | Train Loss: 30.74394 | Val Loss: 23.66369 | Train Acc: 2.173| Val Acc: 1.728
# Epoch 064: | Train Loss: 30.61378 | Val Loss: 23.55005 | Train Acc: 2.183| Val Acc: 1.730
# Epoch 065: | Train Loss: 30.41808 | Val Loss: 23.60553 | Train Acc: 2.129| Val Acc: 1.693
# Epoch 066: | Train Loss: 30.62312 | Val Loss: 23.74716 | Train Acc: 2.151| Val Acc: 1.558
# Epoch 067: | Train Loss: 30.51091 | Val Loss: 23.38971 | Train Acc: 2.165| Val Acc: 1.547
# Epoch 068: | Train Loss: 30.50293 | Val Loss: 23.57791 | Train Acc: 2.145| Val Acc: 1.566
# Epoch 069: | Train Loss: 30.54603 | Val Loss: 23.88201 | Train Acc: 2.174| Val Acc: 1.612
# Epoch 070: | Train Loss: 30.74886 | Val Loss: 23.44834 | Train Acc: 2.133| Val Acc: 1.610
# Epoch 071: | Train Loss: 30.45592 | Val Loss: 23.53223 | Train Acc: 2.146| Val Acc: 1.630
# Epoch 072: | Train Loss: 30.50409 | Val Loss: 23.47367 | Train Acc: 2.150| Val Acc: 1.640
# Epoch 073: | Train Loss: 30.34773 | Val Loss: 23.46773 | Train Acc: 2.109| Val Acc: 1.577
# Epoch 074: | Train Loss: 30.37188 | Val Loss: 23.76705 | Train Acc: 2.113| Val Acc: 1.586
# Epoch 075: | Train Loss: 30.34562 | Val Loss: 23.80508 | Train Acc: 2.109| Val Acc: 1.778
# Epoch 076: | Train Loss: 30.29074 | Val Loss: 23.60931 | Train Acc: 2.085| Val Acc: 1.781
# Epoch 077: | Train Loss: 30.38966 | Val Loss: 22.96687 | Train Acc: 2.116| Val Acc: 1.740
# Epoch 078: | Train Loss: 30.48866 | Val Loss: 22.92462 | Train Acc: 2.114| Val Acc: 1.727
# Epoch 079: | Train Loss: 30.62928 | Val Loss: 22.90906 | Train Acc: 2.068| Val Acc: 1.545
# Epoch 080: | Train Loss: 30.61996 | Val Loss: 23.23272 | Train Acc: 2.083| Val Acc: 1.583
# Epoch 081: | Train Loss: 30.40417 | Val Loss: 23.19572 | Train Acc: 2.111| Val Acc: 1.574
# Epoch 082: | Train Loss: 30.49858 | Val Loss: 23.14447 | Train Acc: 2.138| Val Acc: 1.581
# Epoch 083: | Train Loss: 30.57581 | Val Loss: 23.06700 | Train Acc: 2.120| Val Acc: 1.588
# Epoch 084: | Train Loss: 30.43015 | Val Loss: 22.99642 | Train Acc: 2.143| Val Acc: 1.583
# Epoch 085: | Train Loss: 30.46274 | Val Loss: 23.16647 | Train Acc: 2.126| Val Acc: 1.781
# Epoch 086: | Train Loss: 30.39708 | Val Loss: 23.29613 | Train Acc: 2.092| Val Acc: 1.734
# Epoch 087: | Train Loss: 30.34624 | Val Loss: 23.34238 | Train Acc: 2.077| Val Acc: 1.739
# Epoch 088: | Train Loss: 30.28710 | Val Loss: 23.04891 | Train Acc: 2.068| Val Acc: 1.733
# Epoch 089: | Train Loss: 30.24331 | Val Loss: 22.91802 | Train Acc: 2.068| Val Acc: 1.743
# Epoch 090: | Train Loss: 30.42024 | Val Loss: 22.78189 | Train Acc: 2.068| Val Acc: 1.510
# Epoch 091: | Train Loss: 30.48790 | Val Loss: 23.27464 | Train Acc: 2.095| Val Acc: 1.567
# Epoch 092: | Train Loss: 30.49472 | Val Loss: 23.19495 | Train Acc: 2.184| Val Acc: 1.606
# Epoch 093: | Train Loss: 30.49831 | Val Loss: 23.22490 | Train Acc: 2.138| Val Acc: 1.642
# Epoch 094: | Train Loss: 30.40026 | Val Loss: 23.11120 | Train Acc: 2.101| Val Acc: 1.605
# Epoch 095: | Train Loss: 30.53165 | Val Loss: 22.88616 | Train Acc: 2.140| Val Acc: 1.607
# Epoch 096: | Train Loss: 30.41886 | Val Loss: 22.84196 | Train Acc: 2.118| Val Acc: 1.625
# Epoch 097: | Train Loss: 30.49020 | Val Loss: 22.92393 | Train Acc: 2.134| Val Acc: 1.591
# Epoch 098: | Train Loss: 30.24836 | Val Loss: 23.04358 | Train Acc: 2.069| Val Acc: 1.611
# Epoch 099: | Train Loss: 30.33307 | Val Loss: 23.26353 | Train Acc: 2.088| Val Acc: 1.564
# Epoch 100: | Train Loss: 30.22586 | Val Loss: 22.77008 | Train Acc: 2.062| Val Acc: 1.551
# Epoch 101: | Train Loss: 30.23303 | Val Loss: 22.72661 | Train Acc: 2.052| Val Acc: 1.523
# Epoch 102: | Train Loss: 30.23255 | Val Loss: 22.86001 | Train Acc: 2.073| Val Acc: 1.526
# Epoch 103: | Train Loss: 30.36483 | Val Loss: 22.90780 | Train Acc: 2.091| Val Acc: 1.681
# Epoch 104: | Train Loss: 30.20028 | Val Loss: 23.21121 | Train Acc: 2.050| Val Acc: 1.710
# Epoch 105: | Train Loss: 30.19155 | Val Loss: 23.46345 | Train Acc: 2.029| Val Acc: 1.703
# Epoch 106: | Train Loss: 30.35242 | Val Loss: 23.60887 | Train Acc: 2.064| Val Acc: 1.539
# Epoch 107: | Train Loss: 30.23089 | Val Loss: 23.65129 | Train Acc: 2.069| Val Acc: 1.557
# Epoch 108: | Train Loss: 30.17202 | Val Loss: 23.73053 | Train Acc: 2.056| Val Acc: 1.565
# Epoch 109: | Train Loss: 30.18237 | Val Loss: 23.74031 | Train Acc: 2.035| Val Acc: 1.566
# Epoch 110: | Train Loss: 30.20614 | Val Loss: 24.04719 | Train Acc: 2.034| Val Acc: 1.622
# Epoch 111: | Train Loss: 30.19261 | Val Loss: 23.47336 | Train Acc: 2.077| Val Acc: 1.559
# Epoch 112: | Train Loss: 30.27041 | Val Loss: 23.37242 | Train Acc: 2.035| Val Acc: 1.570
# Epoch 113: | Train Loss: 30.29614 | Val Loss: 23.16370 | Train Acc: 2.081| Val Acc: 1.575
# Epoch 114: | Train Loss: 30.24270 | Val Loss: 22.81052 | Train Acc: 2.049| Val Acc: 1.569
# Epoch 115: | Train Loss: 30.17263 | Val Loss: 22.85651 | Train Acc: 2.013| Val Acc: 1.607
# Epoch 116: | Train Loss: 30.13951 | Val Loss: 22.97482 | Train Acc: 2.043| Val Acc: 1.581
# Epoch 117: | Train Loss: 30.24697 | Val Loss: 23.63088 | Train Acc: 2.054| Val Acc: 1.614
# Epoch 118: | Train Loss: 30.24016 | Val Loss: 23.78923 | Train Acc: 2.056| Val Acc: 1.604
# Epoch 119: | Train Loss: 30.41486 | Val Loss: 24.15857 | Train Acc: 2.064| Val Acc: 1.587
# Epoch 120: | Train Loss: 30.39183 | Val Loss: 23.86310 | Train Acc: 2.067| Val Acc: 1.557
# Epoch 121: | Train Loss: 30.24558 | Val Loss: 23.33760 | Train Acc: 2.053| Val Acc: 1.519
# Epoch 122: | Train Loss: 30.08566 | Val Loss: 23.25636 | Train Acc: 2.004| Val Acc: 1.516
# Epoch 123: | Train Loss: 30.12685 | Val Loss: 23.70203 | Train Acc: 1.995| Val Acc: 1.538
# Epoch 124: | Train Loss: 30.24771 | Val Loss: 24.50371 | Train Acc: 2.037| Val Acc: 1.567
# Epoch 125: | Train Loss: 30.17001 | Val Loss: 24.63838 | Train Acc: 2.039| Val Acc: 1.609
# Epoch 126: | Train Loss: 30.54167 | Val Loss: 24.39281 | Train Acc: 2.072| Val Acc: 1.629
# Epoch 127: | Train Loss: 30.22715 | Val Loss: 23.83212 | Train Acc: 2.056| Val Acc: 1.624
# Epoch 128: | Train Loss: 30.05065 | Val Loss: 23.17823 | Train Acc: 1.988| Val Acc: 1.568
# Epoch 129: | Train Loss: 30.01804 | Val Loss: 22.75485 | Train Acc: 1.981| Val Acc: 1.542
# Epoch 130: | Train Loss: 30.20927 | Val Loss: 22.74558 | Train Acc: 2.060| Val Acc: 1.551
# Epoch 131: | Train Loss: 30.17085 | Val Loss: 22.71239 | Train Acc: 2.047| Val Acc: 1.547
# Epoch 132: | Train Loss: 30.05267 | Val Loss: 22.78483 | Train Acc: 2.004| Val Acc: 1.551
# Epoch 133: | Train Loss: 30.10950 | Val Loss: 22.95356 | Train Acc: 1.997| Val Acc: 1.556
# Epoch 134: | Train Loss: 30.05813 | Val Loss: 22.84917 | Train Acc: 2.016| Val Acc: 1.543
# Epoch 135: | Train Loss: 30.17444 | Val Loss: 23.15493 | Train Acc: 1.979| Val Acc: 1.589
# Epoch 136: | Train Loss: 30.04079 | Val Loss: 23.26349 | Train Acc: 1.989| Val Acc: 1.593
# Epoch 137: | Train Loss: 30.16568 | Val Loss: 23.58109 | Train Acc: 2.010| Val Acc: 1.604
# Epoch 138: | Train Loss: 30.16132 | Val Loss: 23.80477 | Train Acc: 2.033| Val Acc: 1.737
# Epoch 139: | Train Loss: 30.19248 | Val Loss: 23.55477 | Train Acc: 2.020| Val Acc: 1.564
# Epoch 140: | Train Loss: 30.03165 | Val Loss: 23.26333 | Train Acc: 1.981| Val Acc: 1.565
# Epoch 141: | Train Loss: 30.05722 | Val Loss: 23.06067 | Train Acc: 1.995| Val Acc: 1.546
# Epoch 142: | Train Loss: 30.41024 | Val Loss: 22.86791 | Train Acc: 2.012| Val Acc: 1.590
# Epoch 143: | Train Loss: 30.06869 | Val Loss: 22.86592 | Train Acc: 2.001| Val Acc: 1.603
# Epoch 144: | Train Loss: 30.00979 | Val Loss: 22.45153 | Train Acc: 1.965| Val Acc: 1.580
# Epoch 145: | Train Loss: 30.15213 | Val Loss: 22.50581 | Train Acc: 2.025| Val Acc: 1.543
# Epoch 146: | Train Loss: 30.13791 | Val Loss: 22.61106 | Train Acc: 2.001| Val Acc: 1.557
# Epoch 147: | Train Loss: 30.00441 | Val Loss: 22.80176 | Train Acc: 1.970| Val Acc: 1.576
# Epoch 148: | Train Loss: 29.96647 | Val Loss: 22.97454 | Train Acc: 1.988| Val Acc: 1.556
# Epoch 149: | Train Loss: 30.12959 | Val Loss: 22.82163 | Train Acc: 1.987| Val Acc: 1.529
# Epoch 150: | Train Loss: 30.05427 | Val Loss: 22.46416 | Train Acc: 1.992| Val Acc: 1.531

# %%
metrics(train, test, threshold=30)
# Out:
# MAE on train set:  31.079157946981983
# min prediction: 1
# max prediction: 201
#
# MAE on test set:  29.326335817412918
# Error ⩽ 30: 69.47 %
# min prediction: 1
# max prediction: 228

# %%
validation_plots(test,model_type)

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.000001, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)
# Out:
# Epoch 001: | Train Loss: 33.66558 | Val Loss: 0.00010 | Train Acc: 2.450| Val Acc: 0.458
# Epoch 002: | Train Loss: 33.13856 | Val Loss: 0.19758 | Train Acc: 2.354| Val Acc: 0.542
# Epoch 003: | Train Loss: 32.78941 | Val Loss: 0.59817 | Train Acc: 2.260| Val Acc: 0.542
# Epoch 004: | Train Loss: 32.96069 | Val Loss: 0.42913 | Train Acc: 2.277| Val Acc: 0.542
# Epoch 005: | Train Loss: 32.59471 | Val Loss: 0.17822 | Train Acc: 2.242| Val Acc: 0.542
# Epoch 006: | Train Loss: 32.70112 | Val Loss: 0.00771 | Train Acc: 2.195| Val Acc: 0.542
# Epoch 007: | Train Loss: 32.67875 | Val Loss: 0.03112 | Train Acc: 2.216| Val Acc: 0.542
# Epoch 008: | Train Loss: 32.45843 | Val Loss: 0.24994 | Train Acc: 2.166| Val Acc: 0.542
# Epoch 009: | Train Loss: 32.52364 | Val Loss: 0.28905 | Train Acc: 2.225| Val Acc: 0.542
# Epoch 010: | Train Loss: 32.47745 | Val Loss: 0.08039 | Train Acc: 2.176| Val Acc: 0.542
# Epoch 011: | Train Loss: 32.56701 | Val Loss: 0.01370 | Train Acc: 2.154| Val Acc: 0.542
# Epoch 012: | Train Loss: 32.59613 | Val Loss: 0.02139 | Train Acc: 2.175| Val Acc: 0.542
# Epoch 013: | Train Loss: 32.43460 | Val Loss: 0.10929 | Train Acc: 2.213| Val Acc: 0.542
# Epoch 014: | Train Loss: 32.21117 | Val Loss: 0.27350 | Train Acc: 2.153| Val Acc: 0.542
# Epoch 015: | Train Loss: 32.14540 | Val Loss: 0.30839 | Train Acc: 2.133| Val Acc: 0.542
# Epoch 016: | Train Loss: 32.49522 | Val Loss: 0.42286 | Train Acc: 2.154| Val Acc: 0.542
# Epoch 017: | Train Loss: 32.36518 | Val Loss: 0.38765 | Train Acc: 2.140| Val Acc: 0.542
# Epoch 018: | Train Loss: 32.14613 | Val Loss: 0.17883 | Train Acc: 2.133| Val Acc: 0.542
# Epoch 019: | Train Loss: 32.16592 | Val Loss: 0.22851 | Train Acc: 2.141| Val Acc: 0.542
# Epoch 020: | Train Loss: 32.15765 | Val Loss: 0.23860 | Train Acc: 2.138| Val Acc: 0.542
# Epoch 021: | Train Loss: 32.29527 | Val Loss: 0.27242 | Train Acc: 2.116| Val Acc: 0.542
# Epoch 022: | Train Loss: 32.17497 | Val Loss: 0.31146 | Train Acc: 2.076| Val Acc: 0.542
# Epoch 023: | Train Loss: 32.22459 | Val Loss: 0.19011 | Train Acc: 2.135| Val Acc: 0.542
# Epoch 024: | Train Loss: 32.18345 | Val Loss: 0.03834 | Train Acc: 2.130| Val Acc: 0.542
# Epoch 025: | Train Loss: 32.25026 | Val Loss: 0.02483 | Train Acc: 2.127| Val Acc: 0.542
# Epoch 026: | Train Loss: 32.20099 | Val Loss: 0.13091 | Train Acc: 2.076| Val Acc: 0.542
# Epoch 027: | Train Loss: 32.13204 | Val Loss: 0.23324 | Train Acc: 2.111| Val Acc: 0.542
# Epoch 028: | Train Loss: 32.07417 | Val Loss: 0.17821 | Train Acc: 2.069| Val Acc: 0.542
# Epoch 029: | Train Loss: 32.26313 | Val Loss: 0.04204 | Train Acc: 2.114| Val Acc: 0.542
# Epoch 030: | Train Loss: 32.22873 | Val Loss: 0.00715 | Train Acc: 2.080| Val Acc: 0.542
# Epoch 031: | Train Loss: 32.03308 | Val Loss: 0.06809 | Train Acc: 2.110| Val Acc: 0.542
# Epoch 032: | Train Loss: 32.17523 | Val Loss: 0.10776 | Train Acc: 2.139| Val Acc: 0.542
# Epoch 033: | Train Loss: 32.22325 | Val Loss: 0.03140 | Train Acc: 2.100| Val Acc: 0.542
# Epoch 034: | Train Loss: 32.06974 | Val Loss: 0.05366 | Train Acc: 2.096| Val Acc: 0.542
# Epoch 035: | Train Loss: 32.15362 | Val Loss: 0.22374 | Train Acc: 2.106| Val Acc: 0.542
# Epoch 036: | Train Loss: 32.24246 | Val Loss: 0.34077 | Train Acc: 2.128| Val Acc: 0.542
# Epoch 037: | Train Loss: 32.13758 | Val Loss: 0.27788 | Train Acc: 2.115| Val Acc: 0.542
# Epoch 038: | Train Loss: 32.06731 | Val Loss: 0.24776 | Train Acc: 2.103| Val Acc: 0.542
# Epoch 039: | Train Loss: 32.09831 | Val Loss: 0.26028 | Train Acc: 2.085| Val Acc: 0.542
# Epoch 040: | Train Loss: 32.01327 | Val Loss: 0.13811 | Train Acc: 2.085| Val Acc: 0.542
# Epoch 041: | Train Loss: 32.00480 | Val Loss: 0.03365 | Train Acc: 2.063| Val Acc: 0.542
# Epoch 042: | Train Loss: 32.06908 | Val Loss: 0.05988 | Train Acc: 2.111| Val Acc: 0.542
# Epoch 043: | Train Loss: 31.99153 | Val Loss: 0.27074 | Train Acc: 2.069| Val Acc: 0.542
# Epoch 044: | Train Loss: 31.97930 | Val Loss: 0.59246 | Train Acc: 2.075| Val Acc: 0.542
# Epoch 045: | Train Loss: 31.96083 | Val Loss: 0.40382 | Train Acc: 2.057| Val Acc: 0.542
# Epoch 046: | Train Loss: 32.11127 | Val Loss: 0.27109 | Train Acc: 2.068| Val Acc: 0.542
# Epoch 047: | Train Loss: 32.07077 | Val Loss: 0.12262 | Train Acc: 2.089| Val Acc: 0.542
# Epoch 048: | Train Loss: 31.94243 | Val Loss: 0.19271 | Train Acc: 2.057| Val Acc: 0.542
# Epoch 049: | Train Loss: 31.89909 | Val Loss: 0.32407 | Train Acc: 2.049| Val Acc: 0.542
# Epoch 050: | Train Loss: 31.87068 | Val Loss: 0.34255 | Train Acc: 2.043| Val Acc: 0.542
# Epoch 051: | Train Loss: 32.06767 | Val Loss: 0.12669 | Train Acc: 2.048| Val Acc: 0.542
# Epoch 052: | Train Loss: 32.17972 | Val Loss: 0.05097 | Train Acc: 2.048| Val Acc: 0.542
# Epoch 053: | Train Loss: 32.02130 | Val Loss: 0.07738 | Train Acc: 2.049| Val Acc: 0.542
# Epoch 054: | Train Loss: 31.90211 | Val Loss: 0.04037 | Train Acc: 2.033| Val Acc: 0.542
# Epoch 055: | Train Loss: 31.94680 | Val Loss: 0.07781 | Train Acc: 2.059| Val Acc: 0.542
# Epoch 056: | Train Loss: 32.10572 | Val Loss: 0.14904 | Train Acc: 2.089| Val Acc: 0.542
# Epoch 057: | Train Loss: 31.94676 | Val Loss: 0.18894 | Train Acc: 2.045| Val Acc: 0.542
# Epoch 058: | Train Loss: 31.91198 | Val Loss: 0.19448 | Train Acc: 2.047| Val Acc: 0.542
# Epoch 059: | Train Loss: 31.91368 | Val Loss: 0.08543 | Train Acc: 2.040| Val Acc: 0.542
# Epoch 060: | Train Loss: 31.86613 | Val Loss: 0.10221 | Train Acc: 2.044| Val Acc: 0.542
# Epoch 061: | Train Loss: 31.93465 | Val Loss: 0.11479 | Train Acc: 2.051| Val Acc: 0.542
# Epoch 062: | Train Loss: 31.85976 | Val Loss: 0.32134 | Train Acc: 2.030| Val Acc: 0.542
# Epoch 063: | Train Loss: 31.84677 | Val Loss: 0.32686 | Train Acc: 2.043| Val Acc: 0.542
# Epoch 064: | Train Loss: 31.92323 | Val Loss: 0.38581 | Train Acc: 2.039| Val Acc: 0.542
# Epoch 065: | Train Loss: 31.94427 | Val Loss: 0.27584 | Train Acc: 2.038| Val Acc: 0.542
# Epoch 066: | Train Loss: 31.91194 | Val Loss: 0.06114 | Train Acc: 2.029| Val Acc: 0.542
# Epoch 067: | Train Loss: 32.07008 | Val Loss: 0.08110 | Train Acc: 2.042| Val Acc: 0.542
# Epoch 068: | Train Loss: 31.89657 | Val Loss: 0.34648 | Train Acc: 2.043| Val Acc: 0.542
# Epoch 069: | Train Loss: 32.03410 | Val Loss: 0.26904 | Train Acc: 2.050| Val Acc: 0.542
# Epoch 070: | Train Loss: 31.94092 | Val Loss: 0.36788 | Train Acc: 2.067| Val Acc: 0.542
# Epoch 071: | Train Loss: 31.85826 | Val Loss: 0.35682 | Train Acc: 2.017| Val Acc: 0.542
# Epoch 072: | Train Loss: 31.87358 | Val Loss: 0.45809 | Train Acc: 2.023| Val Acc: 0.542
# Epoch 073: | Train Loss: 32.13419 | Val Loss: 0.58379 | Train Acc: 2.051| Val Acc: 0.542
# Epoch 074: | Train Loss: 31.99231 | Val Loss: 0.41519 | Train Acc: 2.032| Val Acc: 0.542
# Epoch 075: | Train Loss: 32.12430 | Val Loss: 0.15314 | Train Acc: 2.053| Val Acc: 0.542
# Epoch 076: | Train Loss: 32.04578 | Val Loss: 0.07222 | Train Acc: 2.085| Val Acc: 0.542
# Epoch 077: | Train Loss: 31.99691 | Val Loss: 0.30998 | Train Acc: 2.052| Val Acc: 0.542
# Epoch 078: | Train Loss: 32.15240 | Val Loss: 0.60843 | Train Acc: 2.098| Val Acc: 0.542
# Epoch 079: | Train Loss: 31.99595 | Val Loss: 0.54248 | Train Acc: 2.046| Val Acc: 0.542
# Epoch 080: | Train Loss: 31.84484 | Val Loss: 0.37466 | Train Acc: 2.018| Val Acc: 0.542
# Epoch 081: | Train Loss: 31.92919 | Val Loss: 0.22761 | Train Acc: 2.029| Val Acc: 0.542
# Epoch 082: | Train Loss: 31.86091 | Val Loss: 0.09395 | Train Acc: 2.023| Val Acc: 0.542
# Epoch 083: | Train Loss: 31.89807 | Val Loss: 0.22895 | Train Acc: 2.031| Val Acc: 0.542
# Epoch 084: | Train Loss: 31.85369 | Val Loss: 0.35934 | Train Acc: 2.015| Val Acc: 0.542
# Epoch 085: | Train Loss: 31.77773 | Val Loss: 0.49374 | Train Acc: 1.987| Val Acc: 0.542
# Epoch 086: | Train Loss: 31.96298 | Val Loss: 0.51348 | Train Acc: 1.986| Val Acc: 0.542
# Epoch 087: | Train Loss: 32.05517 | Val Loss: 0.21383 | Train Acc: 2.077| Val Acc: 0.542
# Epoch 088: | Train Loss: 31.89751 | Val Loss: 0.08256 | Train Acc: 2.031| Val Acc: 0.542
# Epoch 089: | Train Loss: 31.90158 | Val Loss: 0.30164 | Train Acc: 2.030| Val Acc: 0.542
# Epoch 090: | Train Loss: 31.98207 | Val Loss: 0.26371 | Train Acc: 2.029| Val Acc: 0.542
# Epoch 091: | Train Loss: 32.03311 | Val Loss: 0.13003 | Train Acc: 2.017| Val Acc: 0.542
# Epoch 092: | Train Loss: 31.80436 | Val Loss: 0.10338 | Train Acc: 2.007| Val Acc: 0.542
# Epoch 093: | Train Loss: 31.81648 | Val Loss: 0.15335 | Train Acc: 2.017| Val Acc: 0.542
# Epoch 094: | Train Loss: 31.76958 | Val Loss: 0.02282 | Train Acc: 1.968| Val Acc: 0.542
# Epoch 095: | Train Loss: 31.97076 | Val Loss: 0.00013 | Train Acc: 1.987| Val Acc: 0.458
# Epoch 096: | Train Loss: 31.80791 | Val Loss: 0.08311 | Train Acc: 1.986| Val Acc: 0.542
# Epoch 097: | Train Loss: 31.81330 | Val Loss: 0.28049 | Train Acc: 2.026| Val Acc: 0.542
# Epoch 098: | Train Loss: 31.76157 | Val Loss: 0.31524 | Train Acc: 1.970| Val Acc: 0.542
# Epoch 099: | Train Loss: 31.84247 | Val Loss: 0.52158 | Train Acc: 2.022| Val Acc: 0.542
# Epoch 100: | Train Loss: 31.80000 | Val Loss: 0.35482 | Train Acc: 1.997| Val Acc: 0.542
# Epoch 101: | Train Loss: 31.73988 | Val Loss: 0.20846 | Train Acc: 1.977| Val Acc: 0.542
# Epoch 102: | Train Loss: 31.74090 | Val Loss: 0.19716 | Train Acc: 1.971| Val Acc: 0.542
# Epoch 103: | Train Loss: 31.73619 | Val Loss: 0.24431 | Train Acc: 1.986| Val Acc: 0.542
# Epoch 104: | Train Loss: 31.73948 | Val Loss: 0.34208 | Train Acc: 1.962| Val Acc: 0.542
# Epoch 105: | Train Loss: 31.71732 | Val Loss: 0.41425 | Train Acc: 1.980| Val Acc: 0.542
# Epoch 106: | Train Loss: 31.67560 | Val Loss: 0.43216 | Train Acc: 1.961| Val Acc: 0.542
# Epoch 107: | Train Loss: 31.74980 | Val Loss: 0.16121 | Train Acc: 1.952| Val Acc: 0.542
# Epoch 108: | Train Loss: 31.73460 | Val Loss: 0.19989 | Train Acc: 1.949| Val Acc: 0.542
# Epoch 109: | Train Loss: 31.76577 | Val Loss: 0.62540 | Train Acc: 1.972| Val Acc: 0.542
# Epoch 110: | Train Loss: 31.69218 | Val Loss: 0.37469 | Train Acc: 1.945| Val Acc: 0.542
# Epoch 111: | Train Loss: 31.84639 | Val Loss: 0.23609 | Train Acc: 1.985| Val Acc: 0.542
# Epoch 112: | Train Loss: 31.77783 | Val Loss: 0.36747 | Train Acc: 1.976| Val Acc: 0.542
# Epoch 113: | Train Loss: 31.73593 | Val Loss: 0.12663 | Train Acc: 1.948| Val Acc: 0.542
# Epoch 114: | Train Loss: 31.74280 | Val Loss: 0.13852 | Train Acc: 1.968| Val Acc: 0.542
# Epoch 115: | Train Loss: 31.68970 | Val Loss: 0.43479 | Train Acc: 1.935| Val Acc: 0.542
# Epoch 116: | Train Loss: 31.72747 | Val Loss: 0.39033 | Train Acc: 1.978| Val Acc: 0.542
# Epoch 117: | Train Loss: 31.70908 | Val Loss: 0.28599 | Train Acc: 1.966| Val Acc: 0.542
# Epoch 118: | Train Loss: 31.86723 | Val Loss: 0.32198 | Train Acc: 1.951| Val Acc: 0.542
# Epoch 119: | Train Loss: 31.75184 | Val Loss: 0.16029 | Train Acc: 1.943| Val Acc: 0.542
# Epoch 120: | Train Loss: 31.78158 | Val Loss: 0.05209 | Train Acc: 1.974| Val Acc: 0.542
# Epoch 121: | Train Loss: 31.72881 | Val Loss: 0.26319 | Train Acc: 1.964| Val Acc: 0.542
# Epoch 122: | Train Loss: 31.84803 | Val Loss: 0.49528 | Train Acc: 1.988| Val Acc: 0.542
# Epoch 123: | Train Loss: 31.77801 | Val Loss: 0.40963 | Train Acc: 1.983| Val Acc: 0.542
# Epoch 124: | Train Loss: 31.79735 | Val Loss: 0.45467 | Train Acc: 1.997| Val Acc: 0.542
# Epoch 125: | Train Loss: 31.74479 | Val Loss: 0.53314 | Train Acc: 1.967| Val Acc: 0.542
# Epoch 126: | Train Loss: 31.70033 | Val Loss: 0.39918 | Train Acc: 1.946| Val Acc: 0.542
# Epoch 127: | Train Loss: 31.70373 | Val Loss: 0.33761 | Train Acc: 1.953| Val Acc: 0.542
# Epoch 128: | Train Loss: 31.69645 | Val Loss: 0.34833 | Train Acc: 1.971| Val Acc: 0.542
# Epoch 129: | Train Loss: 31.70077 | Val Loss: 0.27208 | Train Acc: 1.948| Val Acc: 0.542
# Epoch 130: | Train Loss: 31.71736 | Val Loss: 0.19520 | Train Acc: 1.979| Val Acc: 0.542
# Epoch 131: | Train Loss: 31.67988 | Val Loss: 0.11682 | Train Acc: 1.972| Val Acc: 0.542
# Epoch 132: | Train Loss: 31.73420 | Val Loss: 0.46525 | Train Acc: 1.960| Val Acc: 0.542
# Epoch 133: | Train Loss: 31.81205 | Val Loss: 0.38446 | Train Acc: 1.971| Val Acc: 0.542
# Epoch 134: | Train Loss: 31.68714 | Val Loss: 0.02869 | Train Acc: 1.957| Val Acc: 0.542
# Epoch 135: | Train Loss: 31.69726 | Val Loss: 0.09998 | Train Acc: 1.949| Val Acc: 0.542
# Epoch 136: | Train Loss: 31.70618 | Val Loss: 0.35784 | Train Acc: 1.964| Val Acc: 0.542
# Epoch 137: | Train Loss: 31.77055 | Val Loss: 0.27989 | Train Acc: 1.947| Val Acc: 0.542
# Epoch 138: | Train Loss: 31.68446 | Val Loss: 0.10256 | Train Acc: 1.945| Val Acc: 0.542
# Epoch 139: | Train Loss: 31.74255 | Val Loss: 0.03192 | Train Acc: 1.911| Val Acc: 0.542
# Epoch 140: | Train Loss: 31.64687 | Val Loss: 0.12659 | Train Acc: 1.938| Val Acc: 0.542
# Epoch 141: | Train Loss: 31.65582 | Val Loss: 0.24091 | Train Acc: 1.935| Val Acc: 0.542
# Epoch 142: | Train Loss: 31.62348 | Val Loss: 0.17494 | Train Acc: 1.921| Val Acc: 0.542
# Epoch 143: | Train Loss: 31.63354 | Val Loss: 0.32222 | Train Acc: 1.920| Val Acc: 0.542
# Epoch 144: | Train Loss: 31.67117 | Val Loss: 0.32158 | Train Acc: 1.971| Val Acc: 0.542
# Epoch 145: | Train Loss: 31.82730 | Val Loss: 0.29684 | Train Acc: 1.955| Val Acc: 0.542
# Epoch 146: | Train Loss: 31.62450 | Val Loss: 0.28300 | Train Acc: 1.932| Val Acc: 0.542
# Epoch 147: | Train Loss: 31.64556 | Val Loss: 0.41700 | Train Acc: 1.929| Val Acc: 0.542
# Epoch 148: | Train Loss: 31.63627 | Val Loss: 0.39662 | Train Acc: 1.939| Val Acc: 0.542
# Epoch 149: | Train Loss: 31.73289 | Val Loss: 0.08994 | Train Acc: 1.919| Val Acc: 0.542
# Epoch 150: | Train Loss: 31.64674 | Val Loss: 0.01562 | Train Acc: 1.928| Val Acc: 0.542

# %%
pickle.dump(model, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_Mamoth_NN.pt', 'wb'))
pickle.dump(imputer, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_KNN_Imputer.pkl', 'wb'))
pickle.dump(scaler, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_Scaler.pkl', 'wb'))
