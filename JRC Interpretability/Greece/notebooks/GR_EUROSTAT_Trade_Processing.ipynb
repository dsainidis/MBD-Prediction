# %%
import pandas as pd
import missingno

enc = 'utf-8'

# %%
df_loading = pd.read_csv('../data/GR_EUROSTAT_Trade_Loading_Raw.csv', encoding=enc)
df_loading
# Out:
#                           DATAFLOW        LAST UPDATE freq  nst07   unit  \
# 0       ESTAT:ROAD_GO_NA_RL3G(1.0)  17/04/23 23:00:00    A   GT01  THS_T
# 1       ESTAT:ROAD_GO_NA_RL3G(1.0)  17/04/23 23:00:00    A   GT01  THS_T
# 2       ESTAT:ROAD_GO_NA_RL3G(1.0)  17/04/23 23:00:00    A   GT01  THS_T
# 3       ESTAT:ROAD_GO_NA_RL3G(1.0)  17/04/23 23:00:00    A   GT01  THS_T
# 4       ESTAT:ROAD_GO_NA_RL3G(1.0)  17/04/23 23:00:00    A   GT01  THS_T
# ...                            ...                ...  ...    ...    ...
# 340915  ESTAT:ROAD_GO_NA_RL3G(1.0)  17/04/23 23:00:00    A  TOTAL  THS_T
# 340916  ESTAT:ROAD_GO_NA_RL3G(1.0)  17/04/23 23:00:00    A  TOTAL  THS_T
# 340917  ESTAT:ROAD_GO_NA_RL3G(1.0)  17/04/23 23:00:00    A  TOTAL  THS_T
# 340918  ESTAT:ROAD_GO_NA_RL3G(1.0)  17/04/23 23:00:00    A  TOTAL  THS_T
# 340919  ESTAT:ROAD_GO_NA_RL3G(1.0)  17/04/23 23:00:00    A    UNK  THS_T
#
#           geo  TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0       AT111         2008       79.0      NaN
# 1       AT111         2009      297.0      NaN
# 2       AT111         2010      450.0      NaN
# 3       AT111         2011       53.0      NaN
# 4       AT111         2012      128.0      NaN
# ...       ...          ...        ...      ...
# 340915  UKN15         2018     4351.0      NaN
# 340916  UKN15         2019     4629.0      NaN
# 340917  UKN16         2018     3853.0      NaN
# 340918  UKN16         2019     4263.0      NaN
# 340919  ME000         2017        NaN        u
#
# [340920 rows x 9 columns]

# %%
df_unloading = pd.read_csv('../data/GR_EUROSTAT_Trade_Unloading_Raw.csv', encoding=enc)
df_unloading
# Out:
#                           DATAFLOW        LAST UPDATE freq  nst07   unit  \
# 0       ESTAT:ROAD_GO_NA_RU3G(1.0)  17/04/23 23:00:00    A   GT01  THS_T
# 1       ESTAT:ROAD_GO_NA_RU3G(1.0)  17/04/23 23:00:00    A   GT01  THS_T
# 2       ESTAT:ROAD_GO_NA_RU3G(1.0)  17/04/23 23:00:00    A   GT01  THS_T
# 3       ESTAT:ROAD_GO_NA_RU3G(1.0)  17/04/23 23:00:00    A   GT01  THS_T
# 4       ESTAT:ROAD_GO_NA_RU3G(1.0)  17/04/23 23:00:00    A   GT01  THS_T
# ...                            ...                ...  ...    ...    ...
# 349467  ESTAT:ROAD_GO_NA_RU3G(1.0)  17/04/23 23:00:00    A  TOTAL  THS_T
# 349468  ESTAT:ROAD_GO_NA_RU3G(1.0)  17/04/23 23:00:00    A  TOTAL  THS_T
# 349469  ESTAT:ROAD_GO_NA_RU3G(1.0)  17/04/23 23:00:00    A  TOTAL  THS_T
# 349470  ESTAT:ROAD_GO_NA_RU3G(1.0)  17/04/23 23:00:00    A  TOTAL  THS_T
# 349471  ESTAT:ROAD_GO_NA_RU3G(1.0)  17/04/23 23:00:00    A    UNK  THS_T
#
#           geo  TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0       AT111         2008       59.0      NaN
# 1       AT111         2009      372.0      NaN
# 2       AT111         2010      420.0      NaN
# 3       AT111         2011       56.0      NaN
# 4       AT111         2012      119.0      NaN
# ...       ...          ...        ...      ...
# 349467  UKN15         2018     3111.0      NaN
# 349468  UKN15         2019     5344.0      NaN
# 349469  UKN16         2018     4593.0      NaN
# 349470  UKN16         2019     4437.0      NaN
# 349471  ME000         2017        NaN        u
#
# [349472 rows x 9 columns]

# %%
df_loading.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 340920 entries, 0 to 340919
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   DATAFLOW     340920 non-null  object
#  1   LAST UPDATE  340920 non-null  object
#  2   freq         340920 non-null  object
#  3   nst07        340920 non-null  object
#  4   unit         340920 non-null  object
#  5   geo          340920 non-null  object
#  6   TIME_PERIOD  340920 non-null  int64
#  7   OBS_VALUE    271461 non-null  float64
#  8   OBS_FLAG     69459 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 23.4+ MB

# %%
df_unloading.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349472 entries, 0 to 349471
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   DATAFLOW     349472 non-null  object
#  1   LAST UPDATE  349472 non-null  object
#  2   freq         349472 non-null  object
#  3   nst07        349472 non-null  object
#  4   unit         349472 non-null  object
#  5   geo          349472 non-null  object
#  6   TIME_PERIOD  349472 non-null  int64
#  7   OBS_VALUE    280629 non-null  float64
#  8   OBS_FLAG     68843 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 24.0+ MB

# %%
df_loading.DATAFLOW.unique()
# Out:
# array(['ESTAT:ROAD_GO_NA_RL3G(1.0)'], dtype=object)

# %%
df_unloading.DATAFLOW.unique()
# Out:
# array(['ESTAT:ROAD_GO_NA_RU3G(1.0)'], dtype=object)

# %%
df_loading['LAST UPDATE'].unique()
# Out:
# array(['17/04/23 23:00:00'], dtype=object)

# %%
df_unloading['LAST UPDATE'].unique()
# Out:
# array(['17/04/23 23:00:00'], dtype=object)

# %%
df_loading.freq.unique()
# Out:
# array(['A'], dtype=object)

# %%
df_unloading.freq.unique()
# Out:
# array(['A'], dtype=object)

# %%
df_loading.nst07.unique()
# Out:
# array(['GT01', 'GT02', 'GT03', 'GT04', 'GT05', 'GT06', 'GT07', 'GT08',
#        'GT09', 'GT10', 'GT11', 'GT12', 'GT13', 'GT14', 'GT15', 'GT16',
#        'GT17', 'GT18', 'GT19', 'GT20', 'TOTAL', 'UNK'], dtype=object)

# %%
df_unloading.nst07.unique()
# Out:
# array(['GT01', 'GT02', 'GT03', 'GT04', 'GT05', 'GT06', 'GT07', 'GT08',
#        'GT09', 'GT10', 'GT11', 'GT12', 'GT13', 'GT14', 'GT15', 'GT16',
#        'GT17', 'GT18', 'GT19', 'GT20', 'TOTAL', 'UNK'], dtype=object)

# %%
df_loading.unit.unique()
# Out:
# array(['THS_T'], dtype=object)

# %%
df_unloading.unit.unique()
# Out:
# array(['THS_T'], dtype=object)

# %%
df_loading.TIME_PERIOD.unique()
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020, 2021], dtype=int64)

# %%
df_unloading.TIME_PERIOD.unique()
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020, 2021], dtype=int64)

# %%
df_loading_gr = df_loading.query("geo.str.match('EL\d{3}')").copy()

# %%
df_unloading_gr = df_unloading.query("geo.str.match('EL\d{3}')").copy()

# %%
df_loading_gr = df_loading_gr[df_loading_gr.nst07 == 'TOTAL'].copy()

# %%
df_unloading_gr = df_unloading_gr[df_unloading_gr.nst07 == 'TOTAL'].copy()

# %%
df_loading_gr.drop(columns=['DATAFLOW', 'LAST UPDATE', 'freq', 'nst07', 'unit', 'OBS_FLAG'], inplace=True)

# %%
df_unloading_gr.drop(columns=['DATAFLOW', 'LAST UPDATE', 'freq', 'nst07', 'unit', 'OBS_FLAG'], inplace=True)

# %%
df_loading_gr.reset_index(drop=True, inplace=True)

# %%
df_unloading_gr.reset_index(drop=True, inplace=True)

# %%
df_loading_gr
# Out:
#        geo  TIME_PERIOD  OBS_VALUE
# 0    EL111         2008     6704.0
# 1    EL111         2009     3031.0
# 2    EL111         2010     2663.0
# 3    EL111         2011     4163.0
# 4    EL111         2012     4379.0
# ..     ...          ...        ...
# 714  EL653         2017     3065.0
# 715  EL653         2018     2358.0
# 716  EL653         2019     2914.0
# 717  EL653         2020     4062.0
# 718  EL653         2021     3040.0
#
# [719 rows x 3 columns]

# %%
df_unloading_gr
# Out:
#        geo  TIME_PERIOD  OBS_VALUE
# 0    EL111         2008     7125.0
# 1    EL111         2009     3303.0
# 2    EL111         2010     2085.0
# 3    EL111         2011     4212.0
# 4    EL111         2012     5029.0
# ..     ...          ...        ...
# 714  EL653         2017     3506.0
# 715  EL653         2018     2885.0
# 716  EL653         2019     3549.0
# 717  EL653         2020     4514.0
# 718  EL653         2021     3666.0
#
# [719 rows x 3 columns]

# %%
df_out_loading = df_loading_gr.rename(columns={"geo": "NUTS3_CODE", "TIME_PERIOD": "YEAR", "OBS_VALUE": "L_TOTAL"}, errors="raise")

# %%
df_out_unloading = df_unloading_gr.rename(columns={"geo": "NUTS3_CODE", "TIME_PERIOD": "YEAR", "OBS_VALUE": "UNL_TOTAL"}, errors="raise")

# %%
missingno.matrix(df_out_loading)
# Out:
# <AxesSubplot:>

# %%
missingno.matrix(df_out_unloading)
# Out:
# <AxesSubplot:>

# %%
df_out = pd.merge(df_out_loading, df_out_unloading,  how='left', on=['NUTS3_CODE', 'YEAR'])

# %%
missingno.matrix(df_out)
# Out:
# <AxesSubplot:>

# %%
nuts3_all = df_out.NUTS3_CODE.unique()

# %%
df_out.to_csv('../data/GR_EUROSTAT_Trade_Processed.csv', index=False)
