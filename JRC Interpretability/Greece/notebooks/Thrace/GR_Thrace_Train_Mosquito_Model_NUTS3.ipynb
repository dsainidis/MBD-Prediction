# %% [markdown]
# ## Produces **Mosquito Predictions** for a specific region using MAMOTH ##

# %%
import pandas as pd
import datetime
import math
import numpy as np
import missingno
import json
from statistics import mean
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
import sys
import pickle

sys.path.insert(0, "../../../../Mamoth")
sys.path.insert(0, "../../../../Modules")

from utils import *

from Preprocessing_Module import read_data, select_columns, reshape_dataset
from Initializer_Module import initializer
from Neural_Network_Module import Dataset, transformations, FeedforwardNeuralNetModel, train_nn, give_predictions
from Model_Validation_Module import validation_plots, metrics

enc = 'utf-8'
dec = 'greek8'

pd.options.display.max_columns = None
pd.options.display.max_rows = 100
pd.options.display.float_format = lambda x: '%.6f' % x

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
NUTS0 = 'GR'
NUTS2 = 'Thrace'
NUTS2_EL = 'κεντρικης μακεδονιας'

# %%
mosquito_data = read_data(f'../../data/{NUTS0}_MSQ_culex_2011-2022_processed.csv')
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
mosquito_data.nuts2.unique()
# Out:
# array(['κεντρικης μακεδονιας', 'θεσσαλιας', 'κρητης', 'δυτικης ελλαδας'],
#       dtype=object)

# %%
mosquito_data_nuts2 = mosquito_data.query(f"nuts2 == '{NUTS2_EL}'").copy()
mosquito_data_nuts2.reset_index(inplace = True, drop = True)

# %%
mosq_columns = mosquito_data_nuts2.columns
mosq_columns
# Out:
# Index(['nuts2', 'x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#        'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#        'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
#        'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km', 'wc_l_1km',
#        'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1000',
#        'coast_mean_dist_1000', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'mosq_now'],
#       dtype='object')

# %%
columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
                'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
                'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
                'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean',
                'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week',
                'acc_rainfall_jan', 'mosq_now']

# columns_to_keep = ['x', 'y', 'dt_placement', 'day', 'month', 'week', 'year',
#                 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#                 'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean',
#                 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day',
#                 'lst_night', 'acc_rainfall_1week', 'acc_rainfall_2week',
#                 'acc_rainfall_jan', 'mosq_now']

mosquito_data_nuts2 = select_columns(mosquito_data_nuts2, columns_to_keep, columns_to_keep)

mosquito_data_nuts2 = reshape_dataset(mosquito_data_nuts2,['x','y','dt_placement'])

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()

# %%
#quantile might change based on sns plots
mosq_quantilie = mosquito_data_nuts2['mosq_now'].quantile(0.95)

mosquito_data_nuts2['mosq_now'][mosquito_data_nuts2['mosq_now'] > mosq_quantilie] = mosq_quantilie+1

# %%
plt.figure(figsize=(12,6))
sns.distplot(mosquito_data_nuts2['mosq_now'])
plt.title('Count Distribution')
plt.show()

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <AxesSubplot:>

# %%
imputer = KNNImputer()

features_for_impute = ['x', 'y', 'day', 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
                        'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 
                        'lst_day', 'lst_night', 'lst_jan_mean', 'lst_feb_mean', 'lst_mar_mean', 'lst_apr_mean', 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan']

# features_for_impute = ['x', 'y', 'day', 'month', 'week', 'year', 'day_sin', 'day_cos', 'month_sin', 'month_cos', 'week_sin', 'week_cos',
#                         'ndvi', 'ndwi', 'ndmi', 'ndbi', 'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean', 'ndmi_std', 'ndbi_mean', 'ndbi_std', 
#                         'lst_day', 'lst_night', 'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan']

mosquito_data_sub = mosquito_data_nuts2[features_for_impute]

imputed_data = pd.DataFrame(imputer.fit_transform(mosquito_data_sub), columns = mosquito_data_sub.columns)

# %%
# imputed_columns = ['ndvi','ndmi', 'ndwi', 'ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std', 'ndmi_std','ndwi_std','ndbi_std',
#                    'lst_day','lst_night']

imputed_columns = ['ndvi','ndmi', 'ndwi', 'ndbi','ndvi_mean','ndmi_mean','ndwi_mean','ndbi_mean','ndvi_std', 'ndmi_std','ndwi_std','ndbi_std',
                   'lst_day','lst_night','lst_jan_mean','lst_feb_mean','lst_mar_mean','lst_apr_mean']

mosquito_data_nuts2[imputed_columns] = imputed_data[imputed_columns]

# %%
missingno.matrix(mosquito_data_nuts2)
# Out:
# <AxesSubplot:>

# %%
step = 15
only_env = True
case_title = 'NN mosq regression'
exp = False
date_col = 'dt_placement'
model_type = 'mosquito_regression'
transform_target = True
augment = True

# %%
mosquito_data_nuts2 = initializer(mosquito_data_nuts2,2,10,25,step,[date_col], env=only_env, date_column = date_col, mosq_column='mosq_now')
# Out:
# Bounds: [   0.   85. 1211.]

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.25, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

model = FeedforwardNeuralNetModel(num_features=len(train_X[0]), num_class=1, hidden_layers = [264,128,128,64], dropout=0.2, model_type=model_type, transform = transform_target)

# %%
train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)
# Out:
# Epoch 001: | Train Loss: 19.97431 | Val Loss: 23.72436 | Train Acc: 2.703| Val Acc: 2.114
# Epoch 002: | Train Loss: 18.76796 | Val Loss: 25.50734 | Train Acc: 2.286| Val Acc: 2.030
# Epoch 003: | Train Loss: 19.16035 | Val Loss: 24.34754 | Train Acc: 2.328| Val Acc: 1.977
# Epoch 004: | Train Loss: 18.58744 | Val Loss: 25.65035 | Train Acc: 2.224| Val Acc: 2.079
# Epoch 005: | Train Loss: 18.30179 | Val Loss: 23.99074 | Train Acc: 2.196| Val Acc: 1.990
# Epoch 006: | Train Loss: 17.98573 | Val Loss: 25.02979 | Train Acc: 2.123| Val Acc: 2.018
# Epoch 007: | Train Loss: 17.87419 | Val Loss: 24.26959 | Train Acc: 2.122| Val Acc: 2.005
# Epoch 008: | Train Loss: 17.59200 | Val Loss: 24.19600 | Train Acc: 2.096| Val Acc: 2.012
# Epoch 009: | Train Loss: 17.43417 | Val Loss: 24.38018 | Train Acc: 2.084| Val Acc: 2.021
# Epoch 010: | Train Loss: 17.11664 | Val Loss: 24.73913 | Train Acc: 2.047| Val Acc: 2.070
# Epoch 011: | Train Loss: 16.99771 | Val Loss: 24.59260 | Train Acc: 2.045| Val Acc: 2.078
# Epoch 012: | Train Loss: 16.75353 | Val Loss: 24.30844 | Train Acc: 2.016| Val Acc: 2.068
# Epoch 013: | Train Loss: 16.55242 | Val Loss: 24.74999 | Train Acc: 2.013| Val Acc: 2.122
# Epoch 014: | Train Loss: 16.50317 | Val Loss: 24.79103 | Train Acc: 1.997| Val Acc: 2.119
# Epoch 015: | Train Loss: 16.31497 | Val Loss: 25.71505 | Train Acc: 1.981| Val Acc: 2.169
# Epoch 016: | Train Loss: 16.28683 | Val Loss: 25.16134 | Train Acc: 2.011| Val Acc: 2.120
# Epoch 017: | Train Loss: 16.13806 | Val Loss: 24.77414 | Train Acc: 1.992| Val Acc: 2.146
# Epoch 018: | Train Loss: 15.90977 | Val Loss: 25.67012 | Train Acc: 1.943| Val Acc: 2.181
# Epoch 019: | Train Loss: 16.05946 | Val Loss: 25.78868 | Train Acc: 1.973| Val Acc: 2.239
# Epoch 020: | Train Loss: 15.74720 | Val Loss: 25.57023 | Train Acc: 1.940| Val Acc: 2.168
# Epoch 021: | Train Loss: 15.84261 | Val Loss: 25.31355 | Train Acc: 1.949| Val Acc: 2.147
# Epoch 022: | Train Loss: 15.61682 | Val Loss: 25.25061 | Train Acc: 1.923| Val Acc: 2.163
# Epoch 023: | Train Loss: 15.46938 | Val Loss: 25.62808 | Train Acc: 1.926| Val Acc: 2.188
# Epoch 024: | Train Loss: 15.51703 | Val Loss: 26.05029 | Train Acc: 1.918| Val Acc: 2.253
# Epoch 025: | Train Loss: 15.11986 | Val Loss: 25.81495 | Train Acc: 1.897| Val Acc: 2.234
# Epoch 026: | Train Loss: 15.03769 | Val Loss: 25.42119 | Train Acc: 1.904| Val Acc: 2.168
# Epoch 027: | Train Loss: 14.78580 | Val Loss: 25.93769 | Train Acc: 1.851| Val Acc: 2.186
# Epoch 028: | Train Loss: 15.00396 | Val Loss: 25.82879 | Train Acc: 1.892| Val Acc: 2.170
# Epoch 029: | Train Loss: 14.90831 | Val Loss: 25.53505 | Train Acc: 1.883| Val Acc: 2.190
# Epoch 030: | Train Loss: 14.55958 | Val Loss: 25.26785 | Train Acc: 1.817| Val Acc: 2.180
# Epoch 031: | Train Loss: 14.56121 | Val Loss: 26.49495 | Train Acc: 1.830| Val Acc: 2.259
# Epoch 032: | Train Loss: 14.37869 | Val Loss: 26.19880 | Train Acc: 1.809| Val Acc: 2.195
# Epoch 033: | Train Loss: 14.41655 | Val Loss: 25.93351 | Train Acc: 1.807| Val Acc: 2.265
# Epoch 034: | Train Loss: 14.29060 | Val Loss: 26.75559 | Train Acc: 1.783| Val Acc: 2.303
# Epoch 035: | Train Loss: 14.16249 | Val Loss: 26.42318 | Train Acc: 1.785| Val Acc: 2.233
# Epoch 036: | Train Loss: 13.90052 | Val Loss: 25.95497 | Train Acc: 1.725| Val Acc: 2.173
# Epoch 037: | Train Loss: 14.11149 | Val Loss: 26.45055 | Train Acc: 1.758| Val Acc: 2.280
# Epoch 038: | Train Loss: 13.84211 | Val Loss: 26.36826 | Train Acc: 1.733| Val Acc: 2.262
# Epoch 039: | Train Loss: 13.87711 | Val Loss: 26.50946 | Train Acc: 1.730| Val Acc: 2.246
# Epoch 040: | Train Loss: 13.92504 | Val Loss: 26.34043 | Train Acc: 1.742| Val Acc: 2.238
# Epoch 041: | Train Loss: 13.72317 | Val Loss: 26.62749 | Train Acc: 1.699| Val Acc: 2.248
# Epoch 042: | Train Loss: 13.67658 | Val Loss: 26.07617 | Train Acc: 1.710| Val Acc: 2.218
# Epoch 043: | Train Loss: 13.66566 | Val Loss: 26.93600 | Train Acc: 1.718| Val Acc: 2.287
# Epoch 044: | Train Loss: 13.43290 | Val Loss: 26.74684 | Train Acc: 1.678| Val Acc: 2.226
# Epoch 045: | Train Loss: 13.54589 | Val Loss: 26.06830 | Train Acc: 1.661| Val Acc: 2.199
# Epoch 046: | Train Loss: 13.39120 | Val Loss: 26.55435 | Train Acc: 1.667| Val Acc: 2.249
# Epoch 047: | Train Loss: 13.39535 | Val Loss: 25.94907 | Train Acc: 1.651| Val Acc: 2.167
# Epoch 048: | Train Loss: 13.21981 | Val Loss: 26.14462 | Train Acc: 1.636| Val Acc: 2.198
# Epoch 049: | Train Loss: 13.14201 | Val Loss: 26.29933 | Train Acc: 1.607| Val Acc: 2.188
# Epoch 050: | Train Loss: 13.18150 | Val Loss: 26.34170 | Train Acc: 1.622| Val Acc: 2.203
# Epoch 051: | Train Loss: 13.22000 | Val Loss: 25.45079 | Train Acc: 1.615| Val Acc: 2.148
# Epoch 052: | Train Loss: 12.98058 | Val Loss: 25.59662 | Train Acc: 1.591| Val Acc: 2.146
# Epoch 053: | Train Loss: 13.01136 | Val Loss: 25.66167 | Train Acc: 1.597| Val Acc: 2.154
# Epoch 054: | Train Loss: 13.23432 | Val Loss: 25.72480 | Train Acc: 1.600| Val Acc: 2.140
# Epoch 055: | Train Loss: 13.10754 | Val Loss: 25.84704 | Train Acc: 1.612| Val Acc: 2.134
# Epoch 056: | Train Loss: 13.06121 | Val Loss: 25.86879 | Train Acc: 1.594| Val Acc: 2.161
# Epoch 057: | Train Loss: 13.02200 | Val Loss: 25.82955 | Train Acc: 1.587| Val Acc: 2.154
# Epoch 058: | Train Loss: 12.97056 | Val Loss: 25.25936 | Train Acc: 1.599| Val Acc: 2.117
# Epoch 059: | Train Loss: 12.94004 | Val Loss: 25.58307 | Train Acc: 1.571| Val Acc: 2.137
# Epoch 060: | Train Loss: 12.78105 | Val Loss: 25.66073 | Train Acc: 1.549| Val Acc: 2.116
# Epoch 061: | Train Loss: 13.09648 | Val Loss: 26.13428 | Train Acc: 1.591| Val Acc: 2.232
# Epoch 062: | Train Loss: 12.81487 | Val Loss: 25.16644 | Train Acc: 1.539| Val Acc: 2.094
# Epoch 063: | Train Loss: 12.85171 | Val Loss: 25.06644 | Train Acc: 1.568| Val Acc: 2.071
# Epoch 064: | Train Loss: 12.76557 | Val Loss: 24.86921 | Train Acc: 1.534| Val Acc: 2.047
# Epoch 065: | Train Loss: 12.67390 | Val Loss: 24.86181 | Train Acc: 1.508| Val Acc: 2.048
# Epoch 066: | Train Loss: 12.76151 | Val Loss: 24.98803 | Train Acc: 1.542| Val Acc: 2.036
# Epoch 067: | Train Loss: 12.66667 | Val Loss: 26.10067 | Train Acc: 1.534| Val Acc: 2.115
# Epoch 068: | Train Loss: 12.76799 | Val Loss: 25.18455 | Train Acc: 1.531| Val Acc: 2.076
# Epoch 069: | Train Loss: 12.58577 | Val Loss: 25.27016 | Train Acc: 1.512| Val Acc: 2.057
# Epoch 070: | Train Loss: 12.65001 | Val Loss: 24.64224 | Train Acc: 1.519| Val Acc: 2.009
# Epoch 071: | Train Loss: 12.53515 | Val Loss: 25.31120 | Train Acc: 1.500| Val Acc: 2.062
# Epoch 072: | Train Loss: 12.57682 | Val Loss: 25.14936 | Train Acc: 1.485| Val Acc: 2.072
# Epoch 073: | Train Loss: 12.58915 | Val Loss: 24.79242 | Train Acc: 1.505| Val Acc: 2.022
# Epoch 074: | Train Loss: 12.53006 | Val Loss: 24.92088 | Train Acc: 1.483| Val Acc: 2.060
# Epoch 075: | Train Loss: 12.45444 | Val Loss: 24.07873 | Train Acc: 1.459| Val Acc: 1.978
# Epoch 076: | Train Loss: 12.37594 | Val Loss: 24.81024 | Train Acc: 1.452| Val Acc: 2.004
# Epoch 077: | Train Loss: 12.50839 | Val Loss: 24.84139 | Train Acc: 1.483| Val Acc: 2.055
# Epoch 078: | Train Loss: 12.33827 | Val Loss: 24.49706 | Train Acc: 1.445| Val Acc: 2.002
# Epoch 079: | Train Loss: 12.44558 | Val Loss: 24.53791 | Train Acc: 1.445| Val Acc: 1.997
# Epoch 080: | Train Loss: 12.35480 | Val Loss: 24.51613 | Train Acc: 1.452| Val Acc: 1.990
# Epoch 081: | Train Loss: 12.33002 | Val Loss: 24.10620 | Train Acc: 1.440| Val Acc: 1.991
# Epoch 082: | Train Loss: 12.67380 | Val Loss: 25.89753 | Train Acc: 1.518| Val Acc: 2.180
# Epoch 083: | Train Loss: 12.46987 | Val Loss: 24.98072 | Train Acc: 1.450| Val Acc: 2.076
# Epoch 084: | Train Loss: 12.36742 | Val Loss: 24.74062 | Train Acc: 1.441| Val Acc: 2.003
# Epoch 085: | Train Loss: 12.64425 | Val Loss: 24.68179 | Train Acc: 1.471| Val Acc: 2.055
# Epoch 086: | Train Loss: 12.64799 | Val Loss: 25.21236 | Train Acc: 1.462| Val Acc: 2.111
# Epoch 087: | Train Loss: 12.47981 | Val Loss: 24.23695 | Train Acc: 1.479| Val Acc: 1.970
# Epoch 088: | Train Loss: 12.42671 | Val Loss: 24.37162 | Train Acc: 1.447| Val Acc: 1.977
# Epoch 089: | Train Loss: 12.39327 | Val Loss: 24.53906 | Train Acc: 1.461| Val Acc: 2.007
# Epoch 090: | Train Loss: 12.28928 | Val Loss: 24.98737 | Train Acc: 1.443| Val Acc: 2.040
# Epoch 091: | Train Loss: 12.36868 | Val Loss: 24.13871 | Train Acc: 1.438| Val Acc: 1.945
# Epoch 092: | Train Loss: 12.36891 | Val Loss: 24.43459 | Train Acc: 1.438| Val Acc: 2.011
# Epoch 093: | Train Loss: 12.39366 | Val Loss: 24.75602 | Train Acc: 1.446| Val Acc: 2.056
# Epoch 094: | Train Loss: 12.29005 | Val Loss: 24.12489 | Train Acc: 1.430| Val Acc: 1.941
# Epoch 095: | Train Loss: 12.31139 | Val Loss: 24.70212 | Train Acc: 1.430| Val Acc: 2.019
# Epoch 096: | Train Loss: 12.35475 | Val Loss: 24.36574 | Train Acc: 1.426| Val Acc: 2.010
# Epoch 097: | Train Loss: 12.27948 | Val Loss: 24.14591 | Train Acc: 1.413| Val Acc: 1.977
# Epoch 098: | Train Loss: 12.11133 | Val Loss: 24.03257 | Train Acc: 1.409| Val Acc: 1.977
# Epoch 099: | Train Loss: 12.45147 | Val Loss: 25.49613 | Train Acc: 1.445| Val Acc: 2.071
# Epoch 100: | Train Loss: 12.26074 | Val Loss: 24.34502 | Train Acc: 1.418| Val Acc: 1.952
# Epoch 101: | Train Loss: 12.10851 | Val Loss: 25.22740 | Train Acc: 1.404| Val Acc: 2.076
# Epoch 102: | Train Loss: 12.18382 | Val Loss: 24.84632 | Train Acc: 1.394| Val Acc: 1.977
# Epoch 103: | Train Loss: 12.22586 | Val Loss: 25.19568 | Train Acc: 1.398| Val Acc: 2.016
# Epoch 104: | Train Loss: 12.10113 | Val Loss: 24.93779 | Train Acc: 1.376| Val Acc: 2.016
# Epoch 105: | Train Loss: 12.11871 | Val Loss: 25.05157 | Train Acc: 1.373| Val Acc: 2.019
# Epoch 106: | Train Loss: 12.14890 | Val Loss: 25.26120 | Train Acc: 1.399| Val Acc: 2.031
# Epoch 107: | Train Loss: 12.12728 | Val Loss: 24.37392 | Train Acc: 1.393| Val Acc: 1.998
# Epoch 108: | Train Loss: 12.16747 | Val Loss: 24.54015 | Train Acc: 1.388| Val Acc: 2.008
# Epoch 109: | Train Loss: 12.38577 | Val Loss: 24.16353 | Train Acc: 1.424| Val Acc: 1.925
# Epoch 110: | Train Loss: 12.26918 | Val Loss: 24.38059 | Train Acc: 1.394| Val Acc: 1.953
# Epoch 111: | Train Loss: 12.40817 | Val Loss: 24.52625 | Train Acc: 1.420| Val Acc: 1.951
# Epoch 112: | Train Loss: 12.35378 | Val Loss: 25.56699 | Train Acc: 1.419| Val Acc: 2.079
# Epoch 113: | Train Loss: 12.12997 | Val Loss: 24.79708 | Train Acc: 1.400| Val Acc: 1.985
# Epoch 114: | Train Loss: 12.17602 | Val Loss: 24.36546 | Train Acc: 1.386| Val Acc: 1.976
# Epoch 115: | Train Loss: 12.13476 | Val Loss: 24.56802 | Train Acc: 1.387| Val Acc: 1.978
# Epoch 116: | Train Loss: 12.08554 | Val Loss: 25.29341 | Train Acc: 1.373| Val Acc: 2.041
# Epoch 117: | Train Loss: 12.06100 | Val Loss: 25.04813 | Train Acc: 1.366| Val Acc: 2.034
# Epoch 118: | Train Loss: 12.03637 | Val Loss: 24.99514 | Train Acc: 1.356| Val Acc: 1.995
# Epoch 119: | Train Loss: 12.08689 | Val Loss: 24.30023 | Train Acc: 1.361| Val Acc: 1.945
# Epoch 120: | Train Loss: 12.07914 | Val Loss: 24.76157 | Train Acc: 1.379| Val Acc: 2.006
# Epoch 121: | Train Loss: 12.11906 | Val Loss: 24.85856 | Train Acc: 1.378| Val Acc: 2.007
# Epoch 122: | Train Loss: 12.19891 | Val Loss: 24.47734 | Train Acc: 1.390| Val Acc: 1.992
# Epoch 123: | Train Loss: 12.08193 | Val Loss: 24.76492 | Train Acc: 1.382| Val Acc: 1.989
# Epoch 124: | Train Loss: 12.23287 | Val Loss: 24.82808 | Train Acc: 1.403| Val Acc: 2.049
# Epoch 125: | Train Loss: 12.18424 | Val Loss: 24.48509 | Train Acc: 1.398| Val Acc: 1.985
# Epoch 126: | Train Loss: 12.36450 | Val Loss: 25.07608 | Train Acc: 1.419| Val Acc: 2.073
# Epoch 127: | Train Loss: 12.26022 | Val Loss: 24.66141 | Train Acc: 1.389| Val Acc: 2.008
# Epoch 128: | Train Loss: 12.24029 | Val Loss: 24.51821 | Train Acc: 1.388| Val Acc: 1.993
# Epoch 129: | Train Loss: 12.12766 | Val Loss: 24.39546 | Train Acc: 1.383| Val Acc: 1.969
# Epoch 130: | Train Loss: 12.02104 | Val Loss: 24.20099 | Train Acc: 1.367| Val Acc: 1.941
# Epoch 131: | Train Loss: 11.97494 | Val Loss: 24.18316 | Train Acc: 1.353| Val Acc: 1.984
# Epoch 132: | Train Loss: 12.10083 | Val Loss: 24.41050 | Train Acc: 1.359| Val Acc: 1.972
# Epoch 133: | Train Loss: 11.98498 | Val Loss: 24.47990 | Train Acc: 1.348| Val Acc: 1.985
# Epoch 134: | Train Loss: 12.04222 | Val Loss: 24.11470 | Train Acc: 1.357| Val Acc: 1.928
# Epoch 135: | Train Loss: 12.02364 | Val Loss: 24.35240 | Train Acc: 1.352| Val Acc: 1.972
# Epoch 136: | Train Loss: 12.06446 | Val Loss: 24.12309 | Train Acc: 1.359| Val Acc: 1.932
# Epoch 137: | Train Loss: 12.07132 | Val Loss: 24.10682 | Train Acc: 1.365| Val Acc: 1.936
# Epoch 138: | Train Loss: 12.04830 | Val Loss: 24.46989 | Train Acc: 1.335| Val Acc: 1.959
# Epoch 139: | Train Loss: 12.02097 | Val Loss: 24.30056 | Train Acc: 1.363| Val Acc: 1.930
# Epoch 140: | Train Loss: 12.07906 | Val Loss: 24.35401 | Train Acc: 1.350| Val Acc: 1.944
# Epoch 141: | Train Loss: 11.97878 | Val Loss: 24.34064 | Train Acc: 1.338| Val Acc: 1.936
# Epoch 142: | Train Loss: 12.13234 | Val Loss: 24.05241 | Train Acc: 1.369| Val Acc: 1.947
# Epoch 143: | Train Loss: 12.10434 | Val Loss: 24.81437 | Train Acc: 1.357| Val Acc: 1.972
# Epoch 144: | Train Loss: 12.02143 | Val Loss: 24.42136 | Train Acc: 1.354| Val Acc: 1.962
# Epoch 145: | Train Loss: 11.95499 | Val Loss: 24.39844 | Train Acc: 1.341| Val Acc: 1.938
# Epoch 146: | Train Loss: 11.95703 | Val Loss: 24.61233 | Train Acc: 1.322| Val Acc: 1.967
# Epoch 147: | Train Loss: 11.97091 | Val Loss: 24.35094 | Train Acc: 1.330| Val Acc: 1.919
# Epoch 148: | Train Loss: 11.89936 | Val Loss: 24.87741 | Train Acc: 1.326| Val Acc: 1.989
# Epoch 149: | Train Loss: 11.87075 | Val Loss: 24.69292 | Train Acc: 1.311| Val Acc: 1.939
# Epoch 150: | Train Loss: 11.84495 | Val Loss: 24.90449 | Train Acc: 1.304| Val Acc: 2.015

# %%
metrics(train, test, threshold=30)
# Out:
# MAE on train set:  206.58766341002058
# min prediction: 1
# max prediction: 2491
#
# MAE on test set:  194.8061446425043
# Error ⩽ 30: 18.62 %
# min prediction: 1
# max prediction: 1632

# %%
validation_plots(test,model_type)

# %%
train_X, train_y, test_X, test_y, scaler = transformations(mosquito_data_nuts2, model_type = model_type, split = 0.000001, augment=augment)

training_set = Dataset(train_X, train_y, model_type=model_type, transform = transform_target)
testing_set = Dataset(test_X, test_y, model_type=model_type, transform = transform_target)

train, test, model = train_nn(model = model, learning_rate = 0.005, epochs = 150, batch_size = 128, train_set = training_set, test_set = testing_set, early_stop = False)
# Out:
# Epoch 001: | Train Loss: 13.88745 | Val Loss: 3.63873 | Train Acc: 1.589| Val Acc: 1.633
# Epoch 002: | Train Loss: 13.92678 | Val Loss: 4.20667 | Train Acc: 1.612| Val Acc: 1.633
# Epoch 003: | Train Loss: 13.67510 | Val Loss: 3.48981 | Train Acc: 1.562| Val Acc: 1.633
# Epoch 004: | Train Loss: 13.81824 | Val Loss: 3.35834 | Train Acc: 1.584| Val Acc: 1.633
# Epoch 005: | Train Loss: 13.35283 | Val Loss: 4.09067 | Train Acc: 1.521| Val Acc: 1.633
# Epoch 006: | Train Loss: 13.05533 | Val Loss: 3.25583 | Train Acc: 1.497| Val Acc: 1.633
# Epoch 007: | Train Loss: 13.15320 | Val Loss: 5.04335 | Train Acc: 1.490| Val Acc: 2.633
# Epoch 008: | Train Loss: 13.46685 | Val Loss: 3.92454 | Train Acc: 1.556| Val Acc: 1.633
# Epoch 009: | Train Loss: 13.37775 | Val Loss: 3.72101 | Train Acc: 1.562| Val Acc: 1.633
# Epoch 010: | Train Loss: 13.05389 | Val Loss: 4.59568 | Train Acc: 1.506| Val Acc: 2.633
# Epoch 011: | Train Loss: 13.15938 | Val Loss: 3.48353 | Train Acc: 1.521| Val Acc: 1.633
# Epoch 012: | Train Loss: 13.02326 | Val Loss: 2.49481 | Train Acc: 1.513| Val Acc: 1.633
# Epoch 013: | Train Loss: 13.07934 | Val Loss: 2.97058 | Train Acc: 1.491| Val Acc: 1.633
# Epoch 014: | Train Loss: 12.85456 | Val Loss: 3.12664 | Train Acc: 1.469| Val Acc: 1.633
# Epoch 015: | Train Loss: 12.93879 | Val Loss: 3.07873 | Train Acc: 1.482| Val Acc: 1.633
# Epoch 016: | Train Loss: 13.04647 | Val Loss: 3.67236 | Train Acc: 1.515| Val Acc: 1.633
# Epoch 017: | Train Loss: 12.83471 | Val Loss: 3.78115 | Train Acc: 1.482| Val Acc: 1.633
# Epoch 018: | Train Loss: 12.79631 | Val Loss: 4.19392 | Train Acc: 1.458| Val Acc: 1.633
# Epoch 019: | Train Loss: 12.82274 | Val Loss: 4.00669 | Train Acc: 1.473| Val Acc: 1.633
# Epoch 020: | Train Loss: 12.79041 | Val Loss: 3.15089 | Train Acc: 1.462| Val Acc: 1.633
# Epoch 021: | Train Loss: 12.68840 | Val Loss: 3.57941 | Train Acc: 1.462| Val Acc: 1.633
# Epoch 022: | Train Loss: 12.82607 | Val Loss: 3.21892 | Train Acc: 1.500| Val Acc: 1.633
# Epoch 023: | Train Loss: 12.80529 | Val Loss: 5.71300 | Train Acc: 1.468| Val Acc: 2.633
# Epoch 024: | Train Loss: 12.78043 | Val Loss: 4.03802 | Train Acc: 1.465| Val Acc: 1.633
# Epoch 025: | Train Loss: 12.60393 | Val Loss: 4.16239 | Train Acc: 1.462| Val Acc: 1.633
# Epoch 026: | Train Loss: 12.66820 | Val Loss: 3.79926 | Train Acc: 1.436| Val Acc: 1.633
# Epoch 027: | Train Loss: 12.63763 | Val Loss: 3.57126 | Train Acc: 1.445| Val Acc: 1.633
# Epoch 028: | Train Loss: 12.62890 | Val Loss: 3.46241 | Train Acc: 1.457| Val Acc: 1.633
# Epoch 029: | Train Loss: 12.52860 | Val Loss: 3.46890 | Train Acc: 1.436| Val Acc: 1.633
# Epoch 030: | Train Loss: 12.67470 | Val Loss: 3.70329 | Train Acc: 1.454| Val Acc: 1.633
# Epoch 031: | Train Loss: 12.67051 | Val Loss: 3.20580 | Train Acc: 1.456| Val Acc: 1.633
# Epoch 032: | Train Loss: 12.63078 | Val Loss: 3.20055 | Train Acc: 1.446| Val Acc: 1.633
# Epoch 033: | Train Loss: 12.69720 | Val Loss: 3.36747 | Train Acc: 1.444| Val Acc: 1.633
# Epoch 034: | Train Loss: 12.63731 | Val Loss: 4.93521 | Train Acc: 1.437| Val Acc: 2.633
# Epoch 035: | Train Loss: 12.56936 | Val Loss: 3.53361 | Train Acc: 1.435| Val Acc: 1.633
# Epoch 036: | Train Loss: 12.49066 | Val Loss: 4.11235 | Train Acc: 1.416| Val Acc: 1.633
# Epoch 037: | Train Loss: 12.49478 | Val Loss: 4.17922 | Train Acc: 1.418| Val Acc: 1.633
# Epoch 038: | Train Loss: 12.49668 | Val Loss: 4.52835 | Train Acc: 1.407| Val Acc: 1.633
# Epoch 039: | Train Loss: 12.67919 | Val Loss: 4.42647 | Train Acc: 1.446| Val Acc: 1.633
# Epoch 040: | Train Loss: 12.50201 | Val Loss: 6.05059 | Train Acc: 1.429| Val Acc: 2.633
# Epoch 041: | Train Loss: 12.47216 | Val Loss: 5.15452 | Train Acc: 1.420| Val Acc: 2.633
# Epoch 042: | Train Loss: 12.42941 | Val Loss: 4.94825 | Train Acc: 1.415| Val Acc: 2.633
# Epoch 043: | Train Loss: 12.49566 | Val Loss: 4.49358 | Train Acc: 1.432| Val Acc: 1.633
# Epoch 044: | Train Loss: 12.54260 | Val Loss: 3.53201 | Train Acc: 1.424| Val Acc: 1.633
# Epoch 045: | Train Loss: 12.55366 | Val Loss: 3.30660 | Train Acc: 1.412| Val Acc: 1.633
# Epoch 046: | Train Loss: 12.31951 | Val Loss: 5.12609 | Train Acc: 1.393| Val Acc: 2.633
# Epoch 047: | Train Loss: 12.41762 | Val Loss: 3.72136 | Train Acc: 1.408| Val Acc: 1.633
# Epoch 048: | Train Loss: 12.37412 | Val Loss: 4.07044 | Train Acc: 1.394| Val Acc: 1.633
# Epoch 049: | Train Loss: 12.40181 | Val Loss: 3.34610 | Train Acc: 1.419| Val Acc: 1.633
# Epoch 050: | Train Loss: 12.41031 | Val Loss: 3.29427 | Train Acc: 1.400| Val Acc: 1.633
# Epoch 051: | Train Loss: 12.39445 | Val Loss: 3.34307 | Train Acc: 1.389| Val Acc: 1.633
# Epoch 052: | Train Loss: 12.35648 | Val Loss: 5.54471 | Train Acc: 1.401| Val Acc: 2.633
# Epoch 053: | Train Loss: 12.21460 | Val Loss: 4.35959 | Train Acc: 1.379| Val Acc: 1.633
# Epoch 054: | Train Loss: 12.47642 | Val Loss: 3.91033 | Train Acc: 1.408| Val Acc: 1.633
# Epoch 055: | Train Loss: 12.54881 | Val Loss: 5.47408 | Train Acc: 1.404| Val Acc: 2.633
# Epoch 056: | Train Loss: 12.25958 | Val Loss: 3.66715 | Train Acc: 1.383| Val Acc: 1.633
# Epoch 057: | Train Loss: 12.29549 | Val Loss: 3.60315 | Train Acc: 1.389| Val Acc: 1.633
# Epoch 058: | Train Loss: 12.36347 | Val Loss: 4.44116 | Train Acc: 1.394| Val Acc: 1.633
# Epoch 059: | Train Loss: 12.32174 | Val Loss: 3.06287 | Train Acc: 1.398| Val Acc: 1.633
# Epoch 060: | Train Loss: 12.38057 | Val Loss: 4.06011 | Train Acc: 1.417| Val Acc: 1.633
# Epoch 061: | Train Loss: 12.40765 | Val Loss: 3.49905 | Train Acc: 1.393| Val Acc: 1.633
# Epoch 062: | Train Loss: 12.47512 | Val Loss: 3.54537 | Train Acc: 1.397| Val Acc: 1.633
# Epoch 063: | Train Loss: 12.32526 | Val Loss: 3.33005 | Train Acc: 1.389| Val Acc: 1.633
# Epoch 064: | Train Loss: 12.16782 | Val Loss: 3.62525 | Train Acc: 1.373| Val Acc: 1.633
# Epoch 065: | Train Loss: 12.23612 | Val Loss: 3.29118 | Train Acc: 1.372| Val Acc: 1.633
# Epoch 066: | Train Loss: 12.27353 | Val Loss: 3.92170 | Train Acc: 1.379| Val Acc: 1.633
# Epoch 067: | Train Loss: 12.25046 | Val Loss: 3.26526 | Train Acc: 1.383| Val Acc: 1.633
# Epoch 068: | Train Loss: 12.31279 | Val Loss: 4.09879 | Train Acc: 1.375| Val Acc: 1.633
# Epoch 069: | Train Loss: 12.23749 | Val Loss: 4.43334 | Train Acc: 1.375| Val Acc: 1.633
# Epoch 070: | Train Loss: 12.33072 | Val Loss: 3.54553 | Train Acc: 1.383| Val Acc: 1.633
# Epoch 071: | Train Loss: 12.33214 | Val Loss: 4.46839 | Train Acc: 1.390| Val Acc: 1.633
# Epoch 072: | Train Loss: 12.27047 | Val Loss: 4.26151 | Train Acc: 1.372| Val Acc: 1.633
# Epoch 073: | Train Loss: 12.24589 | Val Loss: 4.03723 | Train Acc: 1.372| Val Acc: 1.633
# Epoch 074: | Train Loss: 12.20670 | Val Loss: 3.27755 | Train Acc: 1.362| Val Acc: 1.633
# Epoch 075: | Train Loss: 12.28453 | Val Loss: 3.31913 | Train Acc: 1.383| Val Acc: 1.633
# Epoch 076: | Train Loss: 12.26008 | Val Loss: 3.89475 | Train Acc: 1.370| Val Acc: 1.633
# Epoch 077: | Train Loss: 12.19590 | Val Loss: 3.51340 | Train Acc: 1.373| Val Acc: 1.633
# Epoch 078: | Train Loss: 12.16935 | Val Loss: 3.58571 | Train Acc: 1.360| Val Acc: 1.633
# Epoch 079: | Train Loss: 12.21949 | Val Loss: 3.83401 | Train Acc: 1.371| Val Acc: 1.633
# Epoch 080: | Train Loss: 12.20706 | Val Loss: 3.56571 | Train Acc: 1.368| Val Acc: 1.633
# Epoch 081: | Train Loss: 12.18013 | Val Loss: 2.86703 | Train Acc: 1.357| Val Acc: 1.633
# Epoch 082: | Train Loss: 12.16968 | Val Loss: 4.74948 | Train Acc: 1.348| Val Acc: 2.633
# Epoch 083: | Train Loss: 12.19414 | Val Loss: 4.33799 | Train Acc: 1.364| Val Acc: 1.633
# Epoch 084: | Train Loss: 12.20604 | Val Loss: 3.45570 | Train Acc: 1.368| Val Acc: 1.633
# Epoch 085: | Train Loss: 12.19456 | Val Loss: 4.03651 | Train Acc: 1.363| Val Acc: 1.633
# Epoch 086: | Train Loss: 12.25154 | Val Loss: 4.14784 | Train Acc: 1.385| Val Acc: 1.633
# Epoch 087: | Train Loss: 12.28410 | Val Loss: 2.45860 | Train Acc: 1.371| Val Acc: 1.633
# Epoch 088: | Train Loss: 12.35585 | Val Loss: 3.05386 | Train Acc: 1.386| Val Acc: 1.633
# Epoch 089: | Train Loss: 12.39692 | Val Loss: 2.45087 | Train Acc: 1.389| Val Acc: 1.633
# Epoch 090: | Train Loss: 12.19371 | Val Loss: 2.89007 | Train Acc: 1.358| Val Acc: 1.633
# Epoch 091: | Train Loss: 12.22802 | Val Loss: 3.31831 | Train Acc: 1.376| Val Acc: 1.633
# Epoch 092: | Train Loss: 12.16497 | Val Loss: 3.23069 | Train Acc: 1.360| Val Acc: 1.633
# Epoch 093: | Train Loss: 12.09112 | Val Loss: 4.58171 | Train Acc: 1.344| Val Acc: 2.633
# Epoch 094: | Train Loss: 12.18910 | Val Loss: 2.74303 | Train Acc: 1.362| Val Acc: 1.633
# Epoch 095: | Train Loss: 12.15272 | Val Loss: 3.50355 | Train Acc: 1.340| Val Acc: 1.633
# Epoch 096: | Train Loss: 12.21034 | Val Loss: 2.74991 | Train Acc: 1.356| Val Acc: 1.633
# Epoch 097: | Train Loss: 12.03252 | Val Loss: 3.95164 | Train Acc: 1.336| Val Acc: 1.633
# Epoch 098: | Train Loss: 12.06997 | Val Loss: 3.87640 | Train Acc: 1.341| Val Acc: 1.633
# Epoch 099: | Train Loss: 12.15266 | Val Loss: 2.59910 | Train Acc: 1.354| Val Acc: 1.633
# Epoch 100: | Train Loss: 12.11752 | Val Loss: 3.07377 | Train Acc: 1.326| Val Acc: 1.633
# Epoch 101: | Train Loss: 12.29116 | Val Loss: 4.27343 | Train Acc: 1.362| Val Acc: 1.633
# Epoch 102: | Train Loss: 12.13449 | Val Loss: 2.90346 | Train Acc: 1.348| Val Acc: 1.633
# Epoch 103: | Train Loss: 12.21388 | Val Loss: 3.19940 | Train Acc: 1.372| Val Acc: 1.633
# Epoch 104: | Train Loss: 12.18029 | Val Loss: 3.05064 | Train Acc: 1.359| Val Acc: 1.633
# Epoch 105: | Train Loss: 12.42403 | Val Loss: 2.09502 | Train Acc: 1.406| Val Acc: 1.633
# Epoch 106: | Train Loss: 12.20803 | Val Loss: 3.38840 | Train Acc: 1.382| Val Acc: 1.633
# Epoch 107: | Train Loss: 12.24945 | Val Loss: 3.03455 | Train Acc: 1.383| Val Acc: 1.633
# Epoch 108: | Train Loss: 12.05373 | Val Loss: 3.69433 | Train Acc: 1.343| Val Acc: 1.633
# Epoch 109: | Train Loss: 12.16616 | Val Loss: 3.70378 | Train Acc: 1.348| Val Acc: 1.633
# Epoch 110: | Train Loss: 12.12960 | Val Loss: 1.91365 | Train Acc: 1.354| Val Acc: 1.633
# Epoch 111: | Train Loss: 12.19030 | Val Loss: 2.31743 | Train Acc: 1.353| Val Acc: 1.633
# Epoch 112: | Train Loss: 12.01305 | Val Loss: 2.53876 | Train Acc: 1.345| Val Acc: 1.633
# Epoch 113: | Train Loss: 12.25108 | Val Loss: 2.86680 | Train Acc: 1.363| Val Acc: 1.633
# Epoch 114: | Train Loss: 12.06306 | Val Loss: 2.92363 | Train Acc: 1.344| Val Acc: 1.633
# Epoch 115: | Train Loss: 12.09174 | Val Loss: 3.45560 | Train Acc: 1.353| Val Acc: 1.633
# Epoch 116: | Train Loss: 12.07702 | Val Loss: 2.37670 | Train Acc: 1.341| Val Acc: 1.633
# Epoch 117: | Train Loss: 12.01849 | Val Loss: 1.95244 | Train Acc: 1.317| Val Acc: 1.633
# Epoch 118: | Train Loss: 12.09874 | Val Loss: 2.24422 | Train Acc: 1.329| Val Acc: 1.633
# Epoch 119: | Train Loss: 12.17746 | Val Loss: 2.28313 | Train Acc: 1.356| Val Acc: 1.633
# Epoch 120: | Train Loss: 12.14265 | Val Loss: 3.53679 | Train Acc: 1.353| Val Acc: 1.633
# Epoch 121: | Train Loss: 12.06088 | Val Loss: 2.94583 | Train Acc: 1.340| Val Acc: 1.633
# Epoch 122: | Train Loss: 12.21251 | Val Loss: 2.13198 | Train Acc: 1.356| Val Acc: 1.633
# Epoch 123: | Train Loss: 12.09451 | Val Loss: 3.62105 | Train Acc: 1.331| Val Acc: 1.633
# Epoch 124: | Train Loss: 12.09174 | Val Loss: 3.22206 | Train Acc: 1.330| Val Acc: 1.633
# Epoch 125: | Train Loss: 12.15128 | Val Loss: 2.32158 | Train Acc: 1.360| Val Acc: 1.633
# Epoch 126: | Train Loss: 12.14403 | Val Loss: 3.29086 | Train Acc: 1.356| Val Acc: 1.633
# Epoch 127: | Train Loss: 12.26420 | Val Loss: 4.50320 | Train Acc: 1.363| Val Acc: 1.633
# Epoch 128: | Train Loss: 12.22027 | Val Loss: 2.94830 | Train Acc: 1.371| Val Acc: 1.633
# Epoch 129: | Train Loss: 12.16953 | Val Loss: 2.76298 | Train Acc: 1.342| Val Acc: 1.633
# Epoch 130: | Train Loss: 12.20785 | Val Loss: 3.71821 | Train Acc: 1.390| Val Acc: 1.633
# Epoch 131: | Train Loss: 12.20964 | Val Loss: 2.50429 | Train Acc: 1.335| Val Acc: 1.633
# Epoch 132: | Train Loss: 12.04512 | Val Loss: 2.84749 | Train Acc: 1.338| Val Acc: 1.633
# Epoch 133: | Train Loss: 12.11250 | Val Loss: 2.93790 | Train Acc: 1.353| Val Acc: 1.633
# Epoch 134: | Train Loss: 12.28825 | Val Loss: 2.89821 | Train Acc: 1.353| Val Acc: 1.633
# Epoch 135: | Train Loss: 12.06353 | Val Loss: 3.15278 | Train Acc: 1.349| Val Acc: 1.633
# Epoch 136: | Train Loss: 12.11984 | Val Loss: 2.59680 | Train Acc: 1.348| Val Acc: 1.633
# Epoch 137: | Train Loss: 12.11104 | Val Loss: 2.87849 | Train Acc: 1.340| Val Acc: 1.633
# Epoch 138: | Train Loss: 12.09123 | Val Loss: 1.86652 | Train Acc: 1.343| Val Acc: 1.633
# Epoch 139: | Train Loss: 12.17988 | Val Loss: 2.08660 | Train Acc: 1.360| Val Acc: 1.633
# Epoch 140: | Train Loss: 12.12379 | Val Loss: 2.68345 | Train Acc: 1.344| Val Acc: 1.633
# Epoch 141: | Train Loss: 12.15069 | Val Loss: 2.33943 | Train Acc: 1.365| Val Acc: 1.633
# Epoch 142: | Train Loss: 12.11381 | Val Loss: 1.92971 | Train Acc: 1.354| Val Acc: 1.633
# Epoch 143: | Train Loss: 12.05977 | Val Loss: 2.06573 | Train Acc: 1.339| Val Acc: 1.633
# Epoch 144: | Train Loss: 12.12683 | Val Loss: 1.82451 | Train Acc: 1.339| Val Acc: 1.633
# Epoch 145: | Train Loss: 12.03305 | Val Loss: 2.15259 | Train Acc: 1.326| Val Acc: 1.633
# Epoch 146: | Train Loss: 12.03008 | Val Loss: 2.55001 | Train Acc: 1.341| Val Acc: 1.633
# Epoch 147: | Train Loss: 12.06189 | Val Loss: 3.76545 | Train Acc: 1.343| Val Acc: 1.633
# Epoch 148: | Train Loss: 12.12625 | Val Loss: 2.71797 | Train Acc: 1.342| Val Acc: 1.633
# Epoch 149: | Train Loss: 12.10377 | Val Loss: 2.92761 | Train Acc: 1.331| Val Acc: 1.633
# Epoch 150: | Train Loss: 12.20491 | Val Loss: 3.17678 | Train Acc: 1.365| Val Acc: 1.633

# %%
pickle.dump(model, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_Mamoth_NN.pt', 'wb'))
pickle.dump(imputer, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_KNN_Imputer.pkl', 'wb'))
pickle.dump(scaler, open(f'../../data/{NUTS2}/{NUTS0}_{NUTS2}_NUTS3_Culex_Scaler.pkl', 'wb'))
