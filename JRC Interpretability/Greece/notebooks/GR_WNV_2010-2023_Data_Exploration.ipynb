# %%
import pandas as pd
import missingno
import numpy as np
import matplotlib.pyplot as plt

import sys

sys.path.insert(0, "../../../Modules")

from utils import *

enc = 'utf-8' 
dec = 'greek8'

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
raw_data_2021 = pd.read_csv('../data/GR_WNV_cases_2010-2021.csv', encoding = enc)
raw_data_2021.head(5)
# Out:
#     αα  Id διαχείρισης δεδομένων    Έτος  Ηλικία \n(σε έτη)   Φύλο  \
# 0  1.0                       3.0  2010.0               75.0   ΘΗΛΥ
# 1  2.0                      17.0  2010.0               78.0  ΑΡΡΕΝ
# 2  3.0                       4.0  2010.0               70.0   ΘΗΛΥ
# 3  4.0                      21.0  2010.0               74.0  ΑΡΡΕΝ
# 4  5.0                      59.0  2010.0               19.0   ΘΗΛΥ
#
#   Ημ/νία έναρξης συμπτωμάτων Προσβολή ΚΝΣ (ΝΑΙ/ΟΧΙ)  \
# 0                   28-07-10                    NAI
# 1                   22-07-10                    NAI
# 2                   24-07-10                    NAI
# 3                  30-7-2010                    NAI
# 4                   06-07-10                    NAI
#
#   Περιφέρεια πιθανής έκθεσης Περιφερειακή ενότητα πιθανής έκθεσης  \
# 0       Κεντρικής Μακεδονίας                         Θεσσαλονίκης
# 1       Κεντρικής Μακεδονίας                              Ημαθίας
# 2       Κεντρικής Μακεδονίας                               Κιλκίς
# 3       Κεντρικής Μακεδονίας                               Κιλκίς
# 4       Κεντρικής Μακεδονίας                               Σερρών
#
#   Δήμος πιθανής έκθεσης Πόλη/χωριό (/συνοικία Αθήνας) πιθανής έκθεσης   \
# 0          Θεσσαλονίκης                            Παπάφη, Θεσσαλονίκη
# 1               Βέροιας                                         Βέροια
# 2                Κιλκίς                                    Λεβεντοχώρι
# 3                Κιλκίς                                        Καμπάνη
# 4             Ηράκλειας                                     Ποντισμένο
#
#    Κωδικός κανάβου κελιού 1x1 χλμ πιθανής έκθεσης   Unnamed: 12
# 0                                              NaN          NaN
# 1                                              NaN          NaN
# 2                                              NaN          NaN
# 3                                              NaN          NaN
# 4                                              NaN          NaN

# %%
raw_data_2022 = pd.read_csv('../data/GR_WNV_cases_2022.csv', encoding = enc)
raw_data_2022.head(5)
# Out:
#    Έτος Ημ/νία έναρξης συμπτωμάτων Περιφέρεια πιθανής έκθεσης  \
# 0  2022                   12-07-22       Κεντρικής Μακεδονίας
# 1  2022                   19-07-22       Κεντρικής Μακεδονίας
# 2  2022                   19-07-22       Κεντρικής Μακεδονίας
# 3  2022                   16-07-22       Κεντρικής Μακεδονίας
# 4  2022                   16-07-22       Κεντρικής Μακεδονίας
#
#   Περιφερειακή ενότητα πιθανής έκθεσης    Δήμος πιθανής έκθεσης  \
# 0                         Θεσσαλονίκης  Αμπελοκήπων - Μενεμένης
# 1                         Θεσσαλονίκης                    Δέλτα
# 2                         Θεσσαλονίκης               Χαλκηδόνος
# 3                         Θεσσαλονίκης                    Δέλτα
# 4                         Θεσσαλονίκης                   Θέρμης
#
#    Αριθμός ασθενών ΜΕ εκδηλώσεις από το ΚΝΣ  \
# 0                                         1
# 1                                         2
# 2                                         1
# 3                                         1
# 4                                         1
#
#    Αριθμός ασθενών ΧΩΡΙΣ εκδηλώσεις από το ΚΝΣ  Συνολικός αριθμός ασθενών
# 0                                            0                          1
# 1                                            0                          2
# 2                                            0                          1
# 3                                            0                          1
# 4                                            0                          1

# %%
raw_data_2023 = pd.read_csv('../data/GR_WNV_cases_2023.csv', encoding = enc)
raw_data_2023.head(5)
# Out:
#    Έτος Ημ/νία έναρξης συμπτωμάτων Περιφέρεια πιθανής έκθεσης  \
# 0  2023                   17-10-23               Πελοποννήσου
# 1  2023                   14-08-23                    Ηπείρου
# 2  2023                   29-08-23                    Ηπείρου
# 3  2023                   29-08-23                    Ηπείρου
# 4  2023                   17-10-23            Δυτικής Ελλάδας
#
#   Περιφερειακή ενότητα πιθανής έκθεσης Δήμος πιθανής έκθεσης  \
# 0                            Αργολίδας      Άργους - Μυκηνών
# 1                                Άρτας               Αρταίων
# 2                                Άρτας               Αρταίων
# 3                                Άρτας       Νικολάου Σκουφά
# 4                               Αχαΐας            Αιγιαλείας
#
#    Αριθμός ασθενών ΜΕ εκδηλώσεις από το ΚΝΣ  \
# 0                                         1
# 1                                         2
# 2                                         1
# 3                                         1
# 4                                         1
#
#    Αριθμός ασθενών ΧΩΡΙΣ εκδηλώσεις από το ΚΝΣ  Συνολικός αριθμός ασθενών
# 0                                            0                          1
# 1                                            0                          2
# 2                                            1                          2
# 3                                            0                          1
# 4                                            0                          1

# %%
raw_data_2021.shape
# Out:
# (1421, 13)

# %%
raw_data_2022.shape
# Out:
# (177, 8)

# %%
raw_data_2023.shape
# Out:
# (125, 8)

# %%
data_2021 = raw_data_2021.set_axis(['idx', 'id', 'year', 'age', 'sex', 'onset of symptoms', 'cns attack', 'nuts2', 'nuts3', 'lau1', 'lau2', 'cell_code', 'unnamed'], axis=1, inplace=False)
data_2022 = raw_data_2022.set_axis(['year', 'onset of symptoms', 'nuts2', 'nuts3', 'lau1', 'cases_CNS', 'cases_WO_CNS', 'cases'], axis=1, inplace=False)
data_2023 = raw_data_2023.set_axis(['year', 'onset of symptoms', 'nuts2', 'nuts3', 'lau1', 'cases_CNS', 'cases_WO_CNS', 'cases'], axis=1, inplace=False)

# %%
data_2021.drop(columns = ['idx', 'id', 'cell_code', 'unnamed'], inplace = True)
data_2021.dropna(axis = 0, subset = ['onset of symptoms', 'lau1'], how = 'any', inplace = True)
data_2021['onset of symptoms'] = data_2021['onset of symptoms'].apply(lambda x : x.replace("~", ""))
data_2021 = data_2021[data_2021['onset of symptoms'] != 'Άγνωστη']
data_2021 = data_2021[data_2021['nuts2'] != 'Άγνωστη']
data_2021 = data_2021[data_2021['nuts2'] != 'Απροσδιόριστη']
data_2021 = data_2021[data_2021['nuts2'] != 'Απροσδιόριστη (Ανατολικής Μακεδονίας & Θράκης Ή Κεντρικής Μακεδονίας)']
data_2021['onset of symptoms'] = pd.to_datetime(data_2021['onset of symptoms'], dayfirst=True, errors='coerce')
data_2021['cases'] = 1
data_2021 = data_2021.astype({"year":'int'})

# %%
data_2021.drop(columns = ['age', 'sex', 'cns attack', 'lau1', 'lau2'], inplace = True)

# %%
data_2021
# Out:
#       year onset of symptoms                           nuts2         nuts3  \
# 0     2010        2010-07-28            Κεντρικής Μακεδονίας  Θεσσαλονίκης
# 1     2010        2010-07-22            Κεντρικής Μακεδονίας       Ημαθίας
# 2     2010        2010-07-24            Κεντρικής Μακεδονίας        Κιλκίς
# 3     2010        2010-07-30            Κεντρικής Μακεδονίας        Κιλκίς
# 4     2010        2010-07-06            Κεντρικής Μακεδονίας        Σερρών
# ...    ...               ...                             ...           ...
# 1414  2021        2021-08-31  Ανατολικής Μακεδονίας & Θράκης       Καβάλας
# 1415  2021        2021-09-13            Κεντρικής Μακεδονίας       Ημαθίας
# 1416  2021        2021-09-03            Κεντρικής Μακεδονίας       Ημαθίας
# 1418  2021        2021-10-04            Κεντρικής Μακεδονίας  Θεσσαλονίκης
# 1419  2021        2021-10-25            Κεντρικής Μακεδονίας       Ημαθίας
#
#       cases
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 1414      1
# 1415      1
# 1416      1
# 1418      1
# 1419      1
#
# [1394 rows x 5 columns]

# %%
data_2022.drop(columns = ['lau1', 'cases_CNS', 'cases_WO_CNS'], inplace = True)
data_2022['onset of symptoms'] = pd.to_datetime(data_2022['onset of symptoms'], dayfirst=True, errors='coerce')

# %%
data_2023.drop(columns = ['lau1', 'cases_CNS', 'cases_WO_CNS'], inplace = True)
data_2023['onset of symptoms'] = pd.to_datetime(data_2023['onset of symptoms'], dayfirst=True, errors='coerce')

# %%
data_2022
# Out:
#      year onset of symptoms                             nuts2         nuts3  \
# 0    2022        2022-07-12              Κεντρικής Μακεδονίας  Θεσσαλονίκης
# 1    2022        2022-07-19              Κεντρικής Μακεδονίας  Θεσσαλονίκης
# 2    2022        2022-07-19              Κεντρικής Μακεδονίας  Θεσσαλονίκης
# 3    2022        2022-07-16              Κεντρικής Μακεδονίας  Θεσσαλονίκης
# 4    2022        2022-07-16              Κεντρικής Μακεδονίας  Θεσσαλονίκης
# ..    ...               ...                               ...           ...
# 172  2022        2022-10-18                         Θεσσαλίας       Λάρισας
# 173  2022        2022-10-18  Ανατολικής Μακεδονίας και Θράκης        Δράμας
# 174  2022        2022-10-18                      Ιονίων Νήσων      Λευκάδας
# 175  2022        2022-10-25              Κεντρικής Μακεδονίας  Θεσσαλονίκης
# 176  2022        2022-11-22              Κεντρικής Μακεδονίας  Θεσσαλονίκης
#
#      cases
# 0        1
# 1        2
# 2        1
# 3        1
# 4        1
# ..     ...
# 172      1
# 173      1
# 174      1
# 175      1
# 176      1
#
# [177 rows x 5 columns]

# %%
data_2023
# Out:
#      year onset of symptoms                 nuts2       nuts3  cases
# 0    2023        2023-10-17          Πελοποννήσου   Αργολίδας      1
# 1    2023        2023-08-14               Ηπείρου       Άρτας      2
# 2    2023        2023-08-29               Ηπείρου       Άρτας      2
# 3    2023        2023-08-29               Ηπείρου       Άρτας      1
# 4    2023        2023-10-17       Δυτικής Ελλάδας      Αχαΐας      1
# ..    ...               ...                   ...         ...    ...
# 120  2023        2023-10-10             Θεσσαλίας    Τρικάλων      1
# 121  2023        2023-09-05  Κεντρικής Μακεδονίας  Χαλκιδικής      1
# 122  2023        2023-09-12  Κεντρικής Μακεδονίας  Χαλκιδικής      1
# 123  2023        2023-09-19  Κεντρικής Μακεδονίας  Χαλκιδικής      3
# 124  2023        2023-09-26  Κεντρικής Μακεδονίας  Χαλκιδικής      1
#
# [125 rows x 5 columns]

# %%
data_2021.cases.unique()
# Out:
# array([1], dtype=int64)

# %%
data_2022.cases.unique()
# Out:
# array([ 1,  2,  4,  3,  6,  5, 10], dtype=int64)

# %%
data_2023.cases.unique()
# Out:
# array([1, 2, 5, 3, 4], dtype=int64)

# %%
data_2021_grouped = data_2021.groupby(['year', 'onset of symptoms',	'nuts2', 'nuts3'], as_index = False)
data_2021 = data_2021_grouped.sum()

# %%
data_2021.cases.unique()
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=int64)

# %%
data_2021.head()
# Out:
#    year onset of symptoms                 nuts2         nuts3  cases
# 0  2010        2010-07-06  Κεντρικής Μακεδονίας        Σερρών      1
# 1  2010        2010-07-16  Κεντρικής Μακεδονίας        Κιλκίς      1
# 2  2010        2010-07-18  Κεντρικής Μακεδονίας        Πέλλας      1
# 3  2010        2010-07-19  Κεντρικής Μακεδονίας  Θεσσαλονίκης      2
# 4  2010        2010-07-20  Κεντρικής Μακεδονίας       Ημαθίας      1

# %%
data_2022.head()
# Out:
#    year onset of symptoms                 nuts2         nuts3  cases
# 0  2022        2022-07-12  Κεντρικής Μακεδονίας  Θεσσαλονίκης      1
# 1  2022        2022-07-19  Κεντρικής Μακεδονίας  Θεσσαλονίκης      2
# 2  2022        2022-07-19  Κεντρικής Μακεδονίας  Θεσσαλονίκης      1
# 3  2022        2022-07-16  Κεντρικής Μακεδονίας  Θεσσαλονίκης      1
# 4  2022        2022-07-16  Κεντρικής Μακεδονίας  Θεσσαλονίκης      1

# %%
data_2023.head()
# Out:
#    year onset of symptoms            nuts2      nuts3  cases
# 0  2023        2023-10-17     Πελοποννήσου  Αργολίδας      1
# 1  2023        2023-08-14          Ηπείρου      Άρτας      2
# 2  2023        2023-08-29          Ηπείρου      Άρτας      2
# 3  2023        2023-08-29          Ηπείρου      Άρτας      1
# 4  2023        2023-10-17  Δυτικής Ελλάδας     Αχαΐας      1

# %%
data = pd.concat([data_2021,data_2022,data_2023], ignore_index=True)

# %%
data
# Out:
#       year onset of symptoms                 nuts2         nuts3  cases
# 0     2010        2010-07-06  Κεντρικής Μακεδονίας        Σερρών      1
# 1     2010        2010-07-16  Κεντρικής Μακεδονίας        Κιλκίς      1
# 2     2010        2010-07-18  Κεντρικής Μακεδονίας        Πέλλας      1
# 3     2010        2010-07-19  Κεντρικής Μακεδονίας  Θεσσαλονίκης      2
# 4     2010        2010-07-20  Κεντρικής Μακεδονίας       Ημαθίας      1
# ...    ...               ...                   ...           ...    ...
# 1426  2023        2023-10-10             Θεσσαλίας      Τρικάλων      1
# 1427  2023        2023-09-05  Κεντρικής Μακεδονίας    Χαλκιδικής      1
# 1428  2023        2023-09-12  Κεντρικής Μακεδονίας    Χαλκιδικής      1
# 1429  2023        2023-09-19  Κεντρικής Μακεδονίας    Χαλκιδικής      3
# 1430  2023        2023-09-26  Κεντρικής Μακεδονίας    Χαλκιδικής      1
#
# [1431 rows x 5 columns]

# %%
data.dropna(axis = 0, subset = ['onset of symptoms'], how = 'any', inplace = True)

# %%
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#       year onset of symptoms                 nuts2         nuts3  cases
# 0     2010        2010-07-06  Κεντρικής Μακεδονίας        Σερρών      1
# 1     2010        2010-07-16  Κεντρικής Μακεδονίας        Κιλκίς      1
# 2     2010        2010-07-18  Κεντρικής Μακεδονίας        Πέλλας      1
# 3     2010        2010-07-19  Κεντρικής Μακεδονίας  Θεσσαλονίκης      2
# 4     2010        2010-07-20  Κεντρικής Μακεδονίας       Ημαθίας      1
# ...    ...               ...                   ...           ...    ...
# 1426  2023        2023-10-10             Θεσσαλίας      Τρικάλων      1
# 1427  2023        2023-09-05  Κεντρικής Μακεδονίας    Χαλκιδικής      1
# 1428  2023        2023-09-12  Κεντρικής Μακεδονίας    Χαλκιδικής      1
# 1429  2023        2023-09-19  Κεντρικής Μακεδονίας    Χαλκιδικής      3
# 1430  2023        2023-09-26  Κεντρικής Μακεδονίας    Χαλκιδικής      1
#
# [1431 rows x 5 columns]

# %%
missingno.matrix(data)
# Out:
# <AxesSubplot:>

# %%
data.cases.unique()
# Out:
# array([ 1,  2,  3,  4,  5,  6, 10], dtype=int64)

# %%
process_greek(data, 'nuts2')
process_greek(data, 'nuts3')

data['day'] = data['onset of symptoms'].apply(lambda x : x.day)
data['month'] = data['onset of symptoms'].apply(lambda x : x.month)

# %%
data = data.reindex(columns=['onset of symptoms', 'year', 'month', 'day', 'nuts2', 'nuts3', 'cases'])

# %%
data
# Out:
#      onset of symptoms  year  month  day                 nuts2         nuts3  \
# 0           2010-07-06  2010      7    6  κεντρικης μακεδονιας        σερρων
# 1           2010-07-16  2010      7   16  κεντρικης μακεδονιας        κιλκις
# 2           2010-07-18  2010      7   18  κεντρικης μακεδονιας        πελλας
# 3           2010-07-19  2010      7   19  κεντρικης μακεδονιας  θεσσαλονικης
# 4           2010-07-20  2010      7   20  κεντρικης μακεδονιας       ημαθιας
# ...                ...   ...    ...  ...                   ...           ...
# 1426        2023-10-10  2023     10   10             θεσσαλιας      τρικαλων
# 1427        2023-09-05  2023      9    5  κεντρικης μακεδονιας    χαλκιδικης
# 1428        2023-09-12  2023      9   12  κεντρικης μακεδονιας    χαλκιδικης
# 1429        2023-09-19  2023      9   19  κεντρικης μακεδονιας    χαλκιδικης
# 1430        2023-09-26  2023      9   26  κεντρικης μακεδονιας    χαλκιδικης
#
#       cases
# 0         1
# 1         1
# 2         1
# 3         2
# 4         1
# ...     ...
# 1426      1
# 1427      1
# 1428      1
# 1429      3
# 1430      1
#
# [1431 rows x 7 columns]

# %%
data.to_csv("../data/GR_WNV_cases_2010-2023_processed.csv", encoding = enc, index = False)

# %%
data = convert_multiple_cases(data, target_col = 'cases')

# %%
data
# Out:
#      onset of symptoms  year  month  day                 nuts2         nuts3  \
# 0           2010-07-06  2010      7    6  κεντρικης μακεδονιας        σερρων
# 1           2010-07-16  2010      7   16  κεντρικης μακεδονιας        κιλκις
# 2           2010-07-18  2010      7   18  κεντρικης μακεδονιας        πελλας
# 3           2010-07-19  2010      7   19  κεντρικης μακεδονιας  θεσσαλονικης
# 4           2010-07-20  2010      7   20  κεντρικης μακεδονιας       ημαθιας
# ...                ...   ...    ...  ...                   ...           ...
# 1825        2022-09-20  2022      9   20             θεσσαλιας       λαρισας
# 1826        2022-09-20  2022      9   20             θεσσαλιας       λαρισας
# 1827        2022-09-20  2022      9   20             θεσσαλιας       λαρισας
# 1828        2022-09-20  2022      9   20             θεσσαλιας       λαρισας
# 1829        2022-09-20  2022      9   20             θεσσαλιας       λαρισας
#
#       cases
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 1825      1
# 1826      1
# 1827      1
# 1828      1
# 1829      1
#
# [1830 rows x 7 columns]

# %%
years = [year for year in range(2010, 2024)]
cases = [len(data.query(f"year == {year}")) for year in years]

plt.figure(num = None, figsize = (15,8), facecolor='w', edgecolor='b')
#plt.bar(years, cases)
plt.barh(years, cases)

#ax.bar_label(bars)
y_t = plt.xticks(np.arange(0, max(cases) + 10, step = 50), size = 14)
x_t = plt.yticks(np.arange(min(years), max(years) + 1, step = 1), size = 14)
x_l  = plt.ylabel('Years', size = 18)
y_l =  plt.xlabel('Cases', size = 18)
title = plt.title('WNV Cases in Greece per Year', size = 22)
for year, case in zip(years,cases):
    plt.text(case+0.15, year-0.15, str(case), size = 12)
ax = plt.gca()
ax.xaxis.grid(True)
plt.show()

# %%
nuts2 = data['nuts2'].drop_duplicates().sort_values().tolist()
cases = [len(data.query(f"nuts2 == '{nuts2_unit}'")) for nuts2_unit in nuts2]

cases, nuts2 = zip(*sorted(zip(cases, nuts2)))

plt.figure(num = None, figsize = (18,10), facecolor='w', edgecolor='b')
plt.barh(nuts2, cases)

y_t = plt.xticks(np.arange(0, max(cases) + 100, step = 50), size = 14)
x_t = plt.yticks(nuts2, size = 14)
x_l  = plt.ylabel('NUTS2', size = 18)
y_l =  plt.xlabel('Cases', size = 18)
title = plt.title('WNV Cases in Greece per NUTS2', size = 22)
for nuts2, case in zip(nuts2,cases):
    plt.text(case+0.15, nuts2, str(case), size = 14)
ax = plt.gca()
ax.xaxis.grid(True)
plt.show()

# %%
nuts3 = data['nuts3'].drop_duplicates().sort_values().tolist()
cases = [len(data.query(f"nuts3 == '{nuts2_unit}'")) for nuts2_unit in nuts3]

cases, nuts3 = zip(*sorted(zip(cases, nuts3)))

plt.figure(num = None, figsize = (16,20), facecolor='w', edgecolor='b')
plt.barh(nuts3, cases)

y_t = plt.xticks(np.arange(0, max(cases) + 100, step = 50), size = 14)
x_t = plt.yticks(nuts3, size = 14)
x_l  = plt.ylabel('LAU1', size = 18)
y_l =  plt.xlabel('Cases', size = 18)
title = plt.title('WNV Cases in Greece per LAU1', size = 22)
for nuts3, case in zip(nuts3,cases):
    plt.text(case+0.15, nuts3, str(case), size = 14)
ax = plt.gca()
ax.xaxis.grid(True)
plt.show()
